# %% [markdown]
# # practice one

# %% [markdown]
# # mabahese vizhe

# %% [markdown]
# # Mohammadali Lotfi kooshali      -        404198471

# %% [markdown]
# # install , download and import libraries

# %%
# !pip install spacy nltk
# !python -m spacy download en_core_web_sm

import re
import spacy
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize, sent_tokenize
from nltk.stem import PorterStemmer, WordNetLemmatizer, SnowballStemmer
from nltk import pos_tag
from nltk.corpus import wordnet as wn
from string import punctuation
from nltk.chunk import RegexpParser
from nltk import Tree
import time

# Download required NLTK data
nltk.download('punkt')
nltk.download('stopwords')
nltk.download('wordnet')
nltk.download('averaged_perceptron_tagger')
nltk.download('omw-1.4')

# Load spaCy model
nlp = spacy.load("en_core_web_sm")
# Out:
# Requirement already satisfied: spacy in D:\.venv\Lib\site-packages (3.8.14)
# Requirement already satisfied: nltk in D:\.venv\Lib\site-packages (3.9.4)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in D:\.venv\Lib\site-packages (from spacy) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in D:\.venv\Lib\site-packages (from spacy) (1.0.0)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in D:\.venv\Lib\site-packages (from spacy) (1.0.10)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in D:\.venv\Lib\site-packages (from spacy) (2.0.13)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in D:\.venv\Lib\site-packages (from spacy) (3.0.13)
# Requirement already satisfied: thinc<8.4.0,>=8.3.12 in D:\.venv\Lib\site-packages (from spacy) (8.3.13)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in D:\.venv\Lib\site-packages (from spacy) (0.10.1)
# Requirement already satisfied: srsly<3.0.0,>=2.5.3 in D:\.venv\Lib\site-packages (from spacy) (2.5.3)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in D:\.venv\Lib\site-packages (from spacy) (2.0.10)
# Requirement already satisfied: weasel<2.0.0,>=1.0.0 in D:\.venv\Lib\site-packages (from spacy) (1.0.0)
# Requirement already satisfied: confection<2.0.0,>=1.3.2 in D:\.venv\Lib\site-packages (from spacy) (1.3.3)
# Requirement already satisfied: typer<1.0.0,>=0.3.0 in D:\.venv\Lib\site-packages (from spacy) (0.23.1)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in D:\.venv\Lib\site-packages (from spacy) (4.67.3)
# Requirement already satisfied: numpy>=1.19.0 in D:\.venv\Lib\site-packages (from spacy) (2.3.5)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in D:\.venv\Lib\site-packages (from spacy) (2.32.5)
# Requirement already satisfied: pydantic<3.0.0,>=2.0.0 in D:\.venv\Lib\site-packages (from spacy) (2.12.5)
# Requirement already satisfied: jinja2 in D:\.venv\Lib\site-packages (from spacy) (3.1.6)
# Requirement already satisfied: setuptools in D:\.venv\Lib\site-packages (from spacy) (81.0.0)
# Requirement already satisfied: packaging>=20.0 in D:\.venv\Lib\site-packages (from spacy) (25.0)
# Requirement already satisfied: annotated-types>=0.6.0 in D:\.venv\Lib\site-packages (from pydantic<3.0.0,>=2.0.0->spacy) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in D:\.venv\Lib\site-packages (from pydantic<3.0.0,>=2.0.0->spacy) (2.41.5)
# Requirement already satisfied: typing-extensions>=4.14.1 in D:\.venv\Lib\site-packages (from pydantic<3.0.0,>=2.0.0->spacy) (4.15.0)
# Requirement already satisfied: typing-inspection>=0.4.2 in D:\.venv\Lib\site-packages (from pydantic<3.0.0,>=2.0.0->spacy) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in D:\.venv\Lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in D:\.venv\Lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in D:\.venv\Lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (2.6.3)
# Requirement already satisfied: certifi>=2017.4.17 in D:\.venv\Lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (2026.1.4)
# Requirement already satisfied: blis<1.4.0,>=1.3.0 in D:\.venv\Lib\site-packages (from thinc<8.4.0,>=8.3.12->spacy) (1.3.3)
# Requirement already satisfied: colorama in D:\.venv\Lib\site-packages (from tqdm<5.0.0,>=4.38.0->spacy) (0.4.6)
# Requirement already satisfied: click>=8.0.0 in D:\.venv\Lib\site-packages (from typer<1.0.0,>=0.3.0->spacy) (8.3.1)
# Requirement already satisfied: shellingham>=1.3.0 in D:\.venv\Lib\site-packages (from typer<1.0.0,>=0.3.0->spacy) (1.5.4)
# Requirement already satisfied: rich>=10.11.0 in D:\.venv\Lib\site-packages (from typer<1.0.0,>=0.3.0->spacy) (14.3.2)
# Requirement already satisfied: annotated-doc>=0.0.2 in D:\.venv\Lib\site-packages (from typer<1.0.0,>=0.3.0->spacy) (0.0.4)
# Requirement already satisfied: cloudpathlib>=0.7.0 in D:\.venv\Lib\site-packages (from weasel<2.0.0,>=1.0.0->spacy) (0.23.0)
# Requirement already satisfied: smart-open>=5.2.1 in D:\.venv\Lib\site-packages (from weasel<2.0.0,>=1.0.0->spacy) (7.6.0)
# Requirement already satisfied: httpx>=0.24.0 in D:\.venv\Lib\site-packages (from weasel<2.0.0,>=1.0.0->spacy) (0.28.1)
# Requirement already satisfied: joblib in D:\.venv\Lib\site-packages (from nltk) (1.5.3)
# Requirement already satisfied: regex>=2021.8.3 in D:\.venv\Lib\site-packages (from nltk) (2026.1.15)
# Requirement already satisfied: anyio in D:\.venv\Lib\site-packages (from httpx>=0.24.0->weasel<2.0.0,>=1.0.0->spacy) (4.12.1)
# Requirement already satisfied: httpcore==1.* in D:\.venv\Lib\site-packages (from httpx>=0.24.0->weasel<2.0.0,>=1.0.0->spacy) (1.0.9)
# Requirement already satisfied: h11>=0.16 in D:\.venv\Lib\site-packages (from httpcore==1.*->httpx>=0.24.0->weasel<2.0.0,>=1.0.0->spacy) (0.16.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in D:\.venv\Lib\site-packages (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in D:\.venv\Lib\site-packages (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in D:\.venv\Lib\site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy) (0.1.2)
# Requirement already satisfied: wrapt in D:\.venv\Lib\site-packages (from smart-open>=5.2.1->weasel<2.0.0,>=1.0.0->spacy) (2.1.2)
# Requirement already satisfied: MarkupSafe>=2.0 in D:\.venv\Lib\site-packages (from jinja2->spacy) (3.0.3)
# Collecting en-core-web-sm==3.8.0
#   WARNING: Retrying (Retry(total=4, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ProtocolError('Connection aborted.', ConnectionResetError(10054, 'An existing connection was forcibly closed by the remote host', None, 10054, None))': /github-production-release-asset/84940268/15132ab6-4050-4914-8fe8-ac2c2fdcb9cf?sp=r&sv=2018-11-09&sr=b&spr=https&se=2026-04-27T22%3A17%3A50Z&rscd=attachment%3B+filename%3Den_core_web_sm-3.8.0-py3-none-any.whl&rsct=application%2Foctet-stream&skoid=96c2d410-5711-43a1-aedd-ab1947aa7ab0&sktid=398a6654-997b-47e9-b12b-9515b896b4de&skt=2026-04-27T21%3A17%3A18Z&ske=2026-04-27T22%3A17%3A50Z&sks=b&skv=2018-11-09&sig=d5Q9wkyaGaUBxU%2FzrmWOcxc5XPaQfEX%2BNhu5okx8ROU%3D&jwt=eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9.eyJpc3MiOiJnaXRodWIuY29tIiwiYXVkIjoicmVsZWFzZS1hc3NldHMuZ2l0aHVidXNlcmNvbnRlbnQuY29tIiwia2V5Ijoia2V5MSIsImV4cCI6MTc3NzMyNjU1MywibmJmIjoxNzc3MzI0NzUzLCJwYXRoIjoicmVsZWFzZWFzc2V0cHJvZHVjdGlvbi5ibG9iLmNvcmUud2luZG93cy5uZXQifQ.CESst-f3Iy04MafJVN41MbrjE1pQLJTmS3xecM1SUc0&response-content-disposition=attachment%3B%20filename%3Den_core_web_sm-3.8.0-py3-none-any.whl&response-content-type=application%2Foctet-stream
#   WARNING: Retrying (Retry(total=3, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ProtocolError('Connection aborted.', ConnectionResetError(10054, 'An existing connection was forcibly closed by the remote host', None, 10054, None))': /github-production-release-asset/84940268/15132ab6-4050-4914-8fe8-ac2c2fdcb9cf?sp=r&sv=2018-11-09&sr=b&spr=https&se=2026-04-27T22%3A17%3A50Z&rscd=attachment%3B+filename%3Den_core_web_sm-3.8.0-py3-none-any.whl&rsct=application%2Foctet-stream&skoid=96c2d410-5711-43a1-aedd-ab1947aa7ab0&sktid=398a6654-997b-47e9-b12b-9515b896b4de&skt=2026-04-27T21%3A17%3A18Z&ske=2026-04-27T22%3A17%3A50Z&sks=b&skv=2018-11-09&sig=d5Q9wkyaGaUBxU%2FzrmWOcxc5XPaQfEX%2BNhu5okx8ROU%3D&jwt=eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9.eyJpc3MiOiJnaXRodWIuY29tIiwiYXVkIjoicmVsZWFzZS1hc3NldHMuZ2l0aHVidXNlcmNvbnRlbnQuY29tIiwia2V5Ijoia2V5MSIsImV4cCI6MTc3NzMyNjU1MywibmJmIjoxNzc3MzI0NzUzLCJwYXRoIjoicmVsZWFzZWFzc2V0cHJvZHVjdGlvbi5ibG9iLmNvcmUud2luZG93cy5uZXQifQ.CESst-f3Iy04MafJVN41MbrjE1pQLJTmS3xecM1SUc0&response-content-disposition=attachment%3B%20filename%3Den_core_web_sm-3.8.0-py3-none-any.whl&response-content-type=application%2Foctet-stream
#   WARNING: Retrying (Retry(total=2, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ProtocolError('Connection aborted.', ConnectionResetError(10054, 'An existing connection was forcibly closed by the remote host', None, 10054, None))': /github-production-release-asset/84940268/15132ab6-4050-4914-8fe8-ac2c2fdcb9cf?sp=r&sv=2018-11-09&sr=b&spr=https&se=2026-04-27T22%3A17%3A50Z&rscd=attachment%3B+filename%3Den_core_web_sm-3.8.0-py3-none-any.whl&rsct=application%2Foctet-stream&skoid=96c2d410-5711-43a1-aedd-ab1947aa7ab0&sktid=398a6654-997b-47e9-b12b-9515b896b4de&skt=2026-04-27T21%3A17%3A18Z&ske=2026-04-27T22%3A17%3A50Z&sks=b&skv=2018-11-09&sig=d5Q9wkyaGaUBxU%2FzrmWOcxc5XPaQfEX%2BNhu5okx8ROU%3D&jwt=eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9.eyJpc3MiOiJnaXRodWIuY29tIiwiYXVkIjoicmVsZWFzZS1hc3NldHMuZ2l0aHVidXNlcmNvbnRlbnQuY29tIiwia2V5Ijoia2V5MSIsImV4cCI6MTc3NzMyNjU1MywibmJmIjoxNzc3MzI0NzUzLCJwYXRoIjoicmVsZWFzZWFzc2V0cHJvZHVjdGlvbi5ibG9iLmNvcmUud2luZG93cy5uZXQifQ.CESst-f3Iy04MafJVN41MbrjE1pQLJTmS3xecM1SUc0&response-content-disposition=attachment%3B%20filename%3Den_core_web_sm-3.8.0-py3-none-any.whl&response-content-type=application%2Foctet-stream
#   WARNING: Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ProtocolError('Connection aborted.', ConnectionResetError(10054, 'An existing connection was forcibly closed by the remote host', None, 10054, None))': /github-production-release-asset/84940268/15132ab6-4050-4914-8fe8-ac2c2fdcb9cf?sp=r&sv=2018-11-09&sr=b&spr=https&se=2026-04-27T22%3A17%3A50Z&rscd=attachment%3B+filename%3Den_core_web_sm-3.8.0-py3-none-any.whl&rsct=application%2Foctet-stream&skoid=96c2d410-5711-43a1-aedd-ab1947aa7ab0&sktid=398a6654-997b-47e9-b12b-9515b896b4de&skt=2026-04-27T21%3A17%3A18Z&ske=2026-04-27T22%3A17%3A50Z&sks=b&skv=2018-11-09&sig=d5Q9wkyaGaUBxU%2FzrmWOcxc5XPaQfEX%2BNhu5okx8ROU%3D&jwt=eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9.eyJpc3MiOiJnaXRodWIuY29tIiwiYXVkIjoicmVsZWFzZS1hc3NldHMuZ2l0aHVidXNlcmNvbnRlbnQuY29tIiwia2V5Ijoia2V5MSIsImV4cCI6MTc3NzMyNjU1MywibmJmIjoxNzc3MzI0NzUzLCJwYXRoIjoicmVsZWFzZWFzc2V0cHJvZHVjdGlvbi5ibG9iLmNvcmUud2luZG93cy5uZXQifQ.CESst-f3Iy04MafJVN41MbrjE1pQLJTmS3xecM1SUc0&response-content-disposition=attachment%3B%20filename%3Den_core_web_sm-3.8.0-py3-none-any.whl&response-content-type=application%2Foctet-stream
#   WARNING: Retrying (Retry(total=0, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ProtocolError('Connection aborted.', ConnectionResetError(10054, 'An existing connection was forcibly closed by the remote host', None, 10054, None))': /github-production-release-asset/84940268/15132ab6-4050-4914-8fe8-ac2c2fdcb9cf?sp=r&sv=2018-11-09&sr=b&spr=https&se=2026-04-27T22%3A17%3A50Z&rscd=attachment%3B+filename%3Den_core_web_sm-3.8.0-py3-none-any.whl&rsct=application%2Foctet-stream&skoid=96c2d410-5711-43a1-aedd-ab1947aa7ab0&sktid=398a6654-997b-47e9-b12b-9515b896b4de&skt=2026-04-27T21%3A17%3A18Z&ske=2026-04-27T22%3A17%3A50Z&sks=b&skv=2018-11-09&sig=d5Q9wkyaGaUBxU%2FzrmWOcxc5XPaQfEX%2BNhu5okx8ROU%3D&jwt=eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9.eyJpc3MiOiJnaXRodWIuY29tIiwiYXVkIjoicmVsZWFzZS1hc3NldHMuZ2l0aHVidXNlcmNvbnRlbnQuY29tIiwia2V5Ijoia2V5MSIsImV4cCI6MTc3NzMyNjU1MywibmJmIjoxNzc3MzI0NzUzLCJwYXRoIjoicmVsZWFzZWFzc2V0cHJvZHVjdGlvbi5ibG9iLmNvcmUud2luZG93cy5uZXQifQ.CESst-f3Iy04MafJVN41MbrjE1pQLJTmS3xecM1SUc0&response-content-disposition=attachment%3B%20filename%3Den_core_web_sm-3.8.0-py3-none-any.whl&response-content-type=application%2Foctet-stream
# ERROR: Could not install packages due to an OSError: HTTPSConnectionPool(host='release-assets.githubusercontent.com', port=443): Max retries exceeded with url: /github-production-release-asset/84940268/15132ab6-4050-4914-8fe8-ac2c2fdcb9cf?sp=r&sv=2018-11-09&sr=b&spr=https&se=2026-04-27T22%3A17%3A50Z&rscd=attachment%3B+filename%3Den_core_web_sm-3.8.0-py3-none-any.whl&rsct=application%2Foctet-stream&skoid=96c2d410-5711-43a1-aedd-ab1947aa7ab0&sktid=398a6654-997b-47e9-b12b-9515b896b4de&skt=2026-04-27T21%3A17%3A18Z&ske=2026-04-27T22%3A17%3A50Z&sks=b&skv=2018-11-09&sig=d5Q9wkyaGaUBxU%2FzrmWOcxc5XPaQfEX%2BNhu5okx8ROU%3D&jwt=eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9.eyJpc3MiOiJnaXRodWIuY29tIiwiYXVkIjoicmVsZWFzZS1hc3NldHMuZ2l0aHVidXNlcmNvbnRlbnQuY29tIiwia2V5Ijoia2V5MSIsImV4cCI6MTc3NzMyNjU1MywibmJmIjoxNzc3MzI0NzUzLCJwYXRoIjoicmVsZWFzZWFzc2V0cHJvZHVjdGlvbi5ibG9iLmNvcmUud2luZG93cy5uZXQifQ.CESst-f3Iy04MafJVN41MbrjE1pQLJTmS3xecM1SUc0&response-content-disposition=attachment%3B%20filename%3Den_core_web_sm-3.8.0-py3-none-any.whl&response-content-type=application%2Foctet-stream (Caused by ProtocolError('Connection aborted.', ConnectionResetError(10054, 'An existing connection was forcibly closed by the remote host', None, 10054, None)))
#
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\ASUS\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\ASUS\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\ASUS\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     C:\Users\ASUS\AppData\Roaming\nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package omw-1.4 to
# [nltk_data]     C:\Users\ASUS\AppData\Roaming\nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!

# %% [markdown]
# # reading text file

# %%
with open('investor_email.txt', 'r', encoding='utf-8') as file:
    raw_text = file.read()

print("original text:")
print(raw_text)
print(f"Total characters: {len(raw_text)}")
# Out:
# original text:
# Dear Investors,
#
# We are excited to share our Q4 milestones! 🎉
#
# Key achievements:
# - 150% revenue growth ($2.5M → $6.25M) 📈
# - Launched mobile app (50K+ downloads on iOS and Android) 📱
# - Hired 12 new engineers (team now 45 people) 👥
# - Expanded to EU market (Germany, France, Spain) 🌍
#
# We are now raising our Series B round ($15M valuation).
#
# Deck attached: https://drive.google.com/startup/pitch_deck_q4.pdf
#
# Let's schedule a call: calendly.com/startup-ceo/30min
#
# Best,
# Jennifer Park
# CEO, TechFlow Inc.
# jennifer@techflow.ai
# +1 (650) 555-8901
# Total characters: 539

# %% [markdown]
# # 1. Cleaning Text with re.sub

# %%
# Remove numbers
text_no_numbers = re.sub(r'\d+', '', raw_text)
print("After removing numbers:")
print(text_no_numbers)
print("-" * 80)

# Remove extra whitespaces
text_cleaned = re.sub(r'\s+', ' ', text_no_numbers)
print("After removing extra whitespaces:")
print(text_cleaned)
print("-" * 80)

# Remove special characters (keep letters, spaces, dots, commas)
text_cleaned = re.sub(r'[^\w\s\.\,]', '', text_cleaned)
print("After removing special characters:")
print(text_cleaned)
print(f"Cleaned text length: {len(text_cleaned)} characters")
# Out:
# After removing numbers:
# Dear Investors,
#
# We are excited to share our Q milestones! 🎉
#
# Key achievements:
# - % revenue growth ($.M → $.M) 📈
# - Launched mobile app (K+ downloads on iOS and Android) 📱
# - Hired  new engineers (team now  people) 👥
# - Expanded to EU market (Germany, France, Spain) 🌍
#
# We are now raising our Series B round ($M valuation).
#
# Deck attached: https://drive.google.com/startup/pitch_deck_q.pdf
#
# Let's schedule a call: calendly.com/startup-ceo/min
#
# Best,
# Jennifer Park
# CEO, TechFlow Inc.
# jennifer@techflow.ai
# + () -
# --------------------------------------------------------------------------------
# After removing extra whitespaces:
# Dear Investors, We are excited to share our Q milestones! 🎉 Key achievements: - % revenue growth ($.M → $.M) 📈 - Launched mobile app (K+ downloads on iOS and Android) 📱 - Hired new engineers (team now people) 👥 - Expanded to EU market (Germany, France, Spain) 🌍 We are now raising our Series B round ($M valuation). Deck attached: https://drive.google.com/startup/pitch_deck_q.pdf Let's schedule a call: calendly.com/startup-ceo/min Best, Jennifer Park CEO, TechFlow Inc. jennifer@techflow.ai + () -
# --------------------------------------------------------------------------------
# After removing special characters:
# Dear Investors, We are excited to share our Q milestones  Key achievements   revenue growth .M  .M   Launched mobile app K downloads on iOS and Android   Hired new engineers team now people   Expanded to EU market Germany, France, Spain  We are now raising our Series B round M valuation. Deck attached httpsdrive.google.comstartuppitch_deck_q.pdf Lets schedule a call calendly.comstartupceomin Best, Jennifer Park CEO, TechFlow Inc. jennifertechflow.ai
# Cleaned text length: 456 characters

# %% [markdown]
# # 2. Lowercasing

# %%
text_lower = text_cleaned.lower()
print("Text after lowercasing:")
print(text_lower)
# Out:
# Text after lowercasing:
# dear investors, we are excited to share our q milestones  key achievements   revenue growth .m  .m   launched mobile app k downloads on ios and android   hired new engineers team now people   expanded to eu market germany, france, spain  we are now raising our series b round m valuation. deck attached httpsdrive.google.comstartuppitch_deck_q.pdf lets schedule a call calendly.comstartupceomin best, jennifer park ceo, techflow inc. jennifertechflow.ai

# %% [markdown]
# # 3. Punctuation Removal

# %%
print("Punctuation removed:", punctuation)
text_no_punct = ''.join([char for char in text_lower if char not in punctuation])
print("Text after punctuation removal:")
print(text_no_punct)
# Out:
# Punctuation removed: !"#$%&'()*+,-./:;<=>?@[\]^_`{|}~
# Text after punctuation removal:
# dear investors we are excited to share our q milestones  key achievements   revenue growth m  m   launched mobile app k downloads on ios and android   hired new engineers team now people   expanded to eu market germany france spain  we are now raising our series b round m valuation deck attached httpsdrivegooglecomstartuppitchdeckqpdf lets schedule a call calendlycomstartupceomin best jennifer park ceo techflow inc jennifertechflowai

# %% [markdown]
# # 4. Stopword Removal

# %%
# Get English stopwords
stop_words = set(stopwords.words('english'))
print("English stopwords :")
print(list(stop_words))

# Tokenize first
tokens = word_tokenize(text_no_punct)
print(f"Total tokens before stopword removal: {len(tokens)}")
print("tokens before removal:")
print(tokens)

# Remove stopwords
filtered_tokens = [word for word in tokens if word not in stop_words]
print(f"Total tokens after stopword removal: {len(filtered_tokens)}")
print("tokens after removal:")
print(filtered_tokens)

# Convert back to text
text_no_stopwords = ' '.join(filtered_tokens)
print("Complete text after stopword removal:")
print(text_no_stopwords)
# Out:
# English stopwords :
# ["she's", 'do', 'mightn', "didn't", 'in', 'is', 'over', 'them', "it's", "don't", 'doing', 'his', 'as', "weren't", 'himself', 'because', 'ourselves', "we've", 'isn', 'haven', "they're", 'down', 'this', 'couldn', 'ma', 'through', 'each', 'very', 'her', 't', 'not', "couldn't", 'my', "doesn't", 'against', 'm', 'their', 'are', 'further', 'theirs', 'most', 'can', 'more', 'o', 'below', 'they', 'will', 'our', 'wasn', "i'm", 'only', 'to', 'needn', "you'd", 'hasn', 'you', 'having', "needn't", "they've", "hasn't", 'too', 'by', 'which', 'after', "haven't", 'weren', 'other', "she'd", 'your', 'of', 'above', 'there', 'we', 'under', 'why', "you've", 'once', 'don', 'or', 'i', 'myself', 'these', 'who', "shouldn't", "they'd", 'ours', 'whom', "she'll", 'such', 'about', 'herself', 'some', 'does', "won't", 'between', "mustn't", "hadn't", "it'll", 'out', 'itself', 'just', 'll', "we'd", 'with', 'its', 'hers', "isn't", "we'll", "i'll", 'am', 'then', 'yours', "should've", "you're", 'how', "wouldn't", 'aren', 'doesn', 'mustn', 'was', 'off', 'into', 'won', 'both', 'he', 'themselves', "he'll", 'up', 'be', 'the', 'again', "he'd", 'didn', 'it', "they'll", 'being', 'than', 'shan', 'and', 'hadn', 'those', 're', 'been', 'here', 'shouldn', 'him', 'an', 'before', 'had', 'nor', "we're", 'yourselves', 'all', 'have', 'few', 'so', 'own', 'on', 'when', 'what', 'ain', "mightn't", 'a', 'but', 'has', 'during', "i've", 'from', "wasn't", 'where', 'did', 'until', 'for', "aren't", 'if', 'any', "shan't", 'should', "that'll", "you'll", 'now', 'yourself', "he's", 'no', 'me', 'same', 'at', 'y', 'd', "it'd", 'she', 'while', 'wouldn', 's', 'were', 've', "i'd", 'that']
# Total tokens before stopword removal: 63
# tokens before removal:
# ['dear', 'investors', 'we', 'are', 'excited', 'to', 'share', 'our', 'q', 'milestones', 'key', 'achievements', 'revenue', 'growth', 'm', 'm', 'launched', 'mobile', 'app', 'k', 'downloads', 'on', 'ios', 'and', 'android', 'hired', 'new', 'engineers', 'team', 'now', 'people', 'expanded', 'to', 'eu', 'market', 'germany', 'france', 'spain', 'we', 'are', 'now', 'raising', 'our', 'series', 'b', 'round', 'm', 'valuation', 'deck', 'attached', 'httpsdrivegooglecomstartuppitchdeckqpdf', 'lets', 'schedule', 'a', 'call', 'calendlycomstartupceomin', 'best', 'jennifer', 'park', 'ceo', 'techflow', 'inc', 'jennifertechflowai']
# Total tokens after stopword removal: 47
# tokens after removal:
# ['dear', 'investors', 'excited', 'share', 'q', 'milestones', 'key', 'achievements', 'revenue', 'growth', 'launched', 'mobile', 'app', 'k', 'downloads', 'ios', 'android', 'hired', 'new', 'engineers', 'team', 'people', 'expanded', 'eu', 'market', 'germany', 'france', 'spain', 'raising', 'series', 'b', 'round', 'valuation', 'deck', 'attached', 'httpsdrivegooglecomstartuppitchdeckqpdf', 'lets', 'schedule', 'call', 'calendlycomstartupceomin', 'best', 'jennifer', 'park', 'ceo', 'techflow', 'inc', 'jennifertechflowai']
# Complete text after stopword removal:
# dear investors excited share q milestones key achievements revenue growth launched mobile app k downloads ios android hired new engineers team people expanded eu market germany france spain raising series b round valuation deck attached httpsdrivegooglecomstartuppitchdeckqpdf lets schedule call calendlycomstartupceomin best jennifer park ceo techflow inc jennifertechflowai

# %% [markdown]
# # 5. Tokenization (Sentence, Word, Character)

# %%
# Sentence Tokenization
sentences = sent_tokenize(text_lower)
print("Sentence Tokenization:")
print(f"Total number of sentences: {len(sentences)}")
print("All sentences:")
for i, sent in enumerate(sentences, 1):
    print(f"{i}. {sent}")

# Word Tokenization
words = word_tokenize(text_lower)
print("Word Tokenization:")
print(f"Total number of words: {len(words)}")
print("All words:")
print(words)

# Character Tokenization
chars = [char for char in text_lower if char != ' ']
print("Character Tokenization:")
print(f"Total number of characters (without spaces): {len(chars)}")
print("All characters:")
print(chars)
# Out:
# Sentence Tokenization:
# Total number of sentences: 2
# All sentences:
# 1. dear investors, we are excited to share our q milestones  key achievements   revenue growth .m  .m   launched mobile app k downloads on ios and android   hired new engineers team now people   expanded to eu market germany, france, spain  we are now raising our series b round m valuation.
# 2. deck attached httpsdrive.google.comstartuppitch_deck_q.pdf lets schedule a call calendly.comstartupceomin best, jennifer park ceo, techflow inc. jennifertechflow.ai
# Word Tokenization:
# Total number of words: 69
# All words:
# ['dear', 'investors', ',', 'we', 'are', 'excited', 'to', 'share', 'our', 'q', 'milestones', 'key', 'achievements', 'revenue', 'growth', '.m', '.m', 'launched', 'mobile', 'app', 'k', 'downloads', 'on', 'ios', 'and', 'android', 'hired', 'new', 'engineers', 'team', 'now', 'people', 'expanded', 'to', 'eu', 'market', 'germany', ',', 'france', ',', 'spain', 'we', 'are', 'now', 'raising', 'our', 'series', 'b', 'round', 'm', 'valuation', '.', 'deck', 'attached', 'httpsdrive.google.comstartuppitch_deck_q.pdf', 'lets', 'schedule', 'a', 'call', 'calendly.comstartupceomin', 'best', ',', 'jennifer', 'park', 'ceo', ',', 'techflow', 'inc.', 'jennifertechflow.ai']
# Character Tokenization:
# Total number of characters (without spaces): 380
# All characters:
# ['d', 'e', 'a', 'r', 'i', 'n', 'v', 'e', 's', 't', 'o', 'r', 's', ',', 'w', 'e', 'a', 'r', 'e', 'e', 'x', 'c', 'i', 't', 'e', 'd', 't', 'o', 's', 'h', 'a', 'r', 'e', 'o', 'u', 'r', 'q', 'm', 'i', 'l', 'e', 's', 't', 'o', 'n', 'e', 's', 'k', 'e', 'y', 'a', 'c', 'h', 'i', 'e', 'v', 'e', 'm', 'e', 'n', 't', 's', 'r', 'e', 'v', 'e', 'n', 'u', 'e', 'g', 'r', 'o', 'w', 't', 'h', '.', 'm', '.', 'm', 'l', 'a', 'u', 'n', 'c', 'h', 'e', 'd', 'm', 'o', 'b', 'i', 'l', 'e', 'a', 'p', 'p', 'k', 'd', 'o', 'w', 'n', 'l', 'o', 'a', 'd', 's', 'o', 'n', 'i', 'o', 's', 'a', 'n', 'd', 'a', 'n', 'd', 'r', 'o', 'i', 'd', 'h', 'i', 'r', 'e', 'd', 'n', 'e', 'w', 'e', 'n', 'g', 'i', 'n', 'e', 'e', 'r', 's', 't', 'e', 'a', 'm', 'n', 'o', 'w', 'p', 'e', 'o', 'p', 'l', 'e', 'e', 'x', 'p', 'a', 'n', 'd', 'e', 'd', 't', 'o', 'e', 'u', 'm', 'a', 'r', 'k', 'e', 't', 'g', 'e', 'r', 'm', 'a', 'n', 'y', ',', 'f', 'r', 'a', 'n', 'c', 'e', ',', 's', 'p', 'a', 'i', 'n', 'w', 'e', 'a', 'r', 'e', 'n', 'o', 'w', 'r', 'a', 'i', 's', 'i', 'n', 'g', 'o', 'u', 'r', 's', 'e', 'r', 'i', 'e', 's', 'b', 'r', 'o', 'u', 'n', 'd', 'm', 'v', 'a', 'l', 'u', 'a', 't', 'i', 'o', 'n', '.', 'd', 'e', 'c', 'k', 'a', 't', 't', 'a', 'c', 'h', 'e', 'd', 'h', 't', 't', 'p', 's', 'd', 'r', 'i', 'v', 'e', '.', 'g', 'o', 'o', 'g', 'l', 'e', '.', 'c', 'o', 'm', 's', 't', 'a', 'r', 't', 'u', 'p', 'p', 'i', 't', 'c', 'h', '_', 'd', 'e', 'c', 'k', '_', 'q', '.', 'p', 'd', 'f', 'l', 'e', 't', 's', 's', 'c', 'h', 'e', 'd', 'u', 'l', 'e', 'a', 'c', 'a', 'l', 'l', 'c', 'a', 'l', 'e', 'n', 'd', 'l', 'y', '.', 'c', 'o', 'm', 's', 't', 'a', 'r', 't', 'u', 'p', 'c', 'e', 'o', 'm', 'i', 'n', 'b', 'e', 's', 't', ',', 'j', 'e', 'n', 'n', 'i', 'f', 'e', 'r', 'p', 'a', 'r', 'k', 'c', 'e', 'o', ',', 't', 'e', 'c', 'h', 'f', 'l', 'o', 'w', 'i', 'n', 'c', '.', 'j', 'e', 'n', 'n', 'i', 'f', 'e', 'r', 't', 'e', 'c', 'h', 'f', 'l', 'o', 'w', '.', 'a', 'i']

# %% [markdown]
# # 6. Stemming (PorterStemmer and SnowballStemmer)

# %%
# Initialize both stemmers
porter_stemmer = PorterStemmer()
snowball_stemmer = SnowballStemmer("english")

# Apply both stemmers
porter_stemmed_tokens = [porter_stemmer.stem(word) for word in filtered_tokens]
snowball_stemmed_tokens = [snowball_stemmer.stem(word) for word in filtered_tokens]

print("COMPLETE COMPARISON (Original vs Porter vs Snowball):")
print(f"{'#':<5} | {'Original Word':<25} | {'Porter Stemmer':<20} | {'Snowball Stemmer':<20} | {'Difference'}")

difference_count = 0
for i, (original, porter, snowball) in enumerate(zip(filtered_tokens, porter_stemmed_tokens, snowball_stemmed_tokens), 1):
    difference = "DIFFERENT" if porter != snowball else "SAME"
    if porter != snowball:
        difference_count += 1
    print(f"{i:<5} | {original:<25} | {porter:<20} | {snowball:<20} | {difference}")

print(f"\nTotal words with different stemming results: {difference_count} out of {len(filtered_tokens)}")
print(f"Percentage of differences: {(difference_count/len(filtered_tokens))*100:.2f}%")

# Show detailed comparison for words that differ
print("\nDETAILED COMPARISON FOR WORDS WITH DIFFERENT STEMMING RESULTS:")

different_words = []
for original, porter, snowball in zip(filtered_tokens, porter_stemmed_tokens, snowball_stemmed_tokens):
    if porter != snowball:
        different_words.append((original, porter, snowball))

if different_words:
    print(f"{'#':<5} | {'Original Word':<25} | {'Porter Result':<20} | {'Snowball Result':<20} | {'Analysis'}")
    for i, (original, porter, snowball) in enumerate(different_words, 1):
        analysis = ""
        if len(porter) < len(snowball):
            analysis = "Porter shorter"
        elif len(snowball) < len(porter):
            analysis = "Snowball shorter"
        elif porter.endswith('ing') and not snowball.endswith('ing'):
            analysis = "Porter keeps -ing"
        elif snowball.endswith('ing') and not porter.endswith('ing'):
            analysis = "Snowball keeps -ing"
        else:
            analysis = "Different algorithm"
        print(f"{i:<5} | {original:<25} | {porter:<20} | {snowball:<20} | {analysis}")
else:
    print("No differences found between Porter and Snowball stemmers for this text.")

# Show complete stemmed texts
print("\nCOMPLETE PORTER STEMMED TEXT:")
porter_stemmed_text = ' '.join(porter_stemmed_tokens)
print(porter_stemmed_text)

print("\nCOMPLETE SNOWBALL STEMMED TEXT:")
snowball_stemmed_text = ' '.join(snowball_stemmed_tokens)
print(snowball_stemmed_text)

# Performance comparison
print("\nPERFORMANCE COMPARISON:")

# Test Porter speed
start_time = time.time()
for word in filtered_tokens * 10:
    porter_stemmer.stem(word)
porter_time = time.time() - start_time

# Test Snowball speed
start_time = time.time()
for word in filtered_tokens * 10:
    snowball_stemmer.stem(word)
snowball_time = time.time() - start_time

print(f"PorterStemmer processing time (10 repetitions): {porter_time:.6f} seconds")
print(f"SnowballStemmer processing time (10 repetitions): {snowball_time:.6f} seconds")
# Out:
# COMPLETE COMPARISON (Original vs Porter vs Snowball):
# #     | Original Word             | Porter Stemmer       | Snowball Stemmer     | Difference
# 1     | dear                      | dear                 | dear                 | SAME
# 2     | investors                 | investor             | investor             | SAME
# 3     | excited                   | excit                | excit                | SAME
# 4     | share                     | share                | share                | SAME
# 5     | q                         | q                    | q                    | SAME
# 6     | milestones                | mileston             | mileston             | SAME
# 7     | key                       | key                  | key                  | SAME
# 8     | achievements              | achiev               | achiev               | SAME
# 9     | revenue                   | revenu               | revenu               | SAME
# 10    | growth                    | growth               | growth               | SAME
# 11    | launched                  | launch               | launch               | SAME
# 12    | mobile                    | mobil                | mobil                | SAME
# 13    | app                       | app                  | app                  | SAME
# 14    | k                         | k                    | k                    | SAME
# 15    | downloads                 | download             | download             | SAME
# 16    | ios                       | io                   | io                   | SAME
# 17    | android                   | android              | android              | SAME
# 18    | hired                     | hire                 | hire                 | SAME
# 19    | new                       | new                  | new                  | SAME
# 20    | engineers                 | engin                | engin                | SAME
# 21    | team                      | team                 | team                 | SAME
# 22    | people                    | peopl                | peopl                | SAME
# 23    | expanded                  | expand               | expand               | SAME
# 24    | eu                        | eu                   | eu                   | SAME
# 25    | market                    | market               | market               | SAME
# 26    | germany                   | germani              | germani              | SAME
# 27    | france                    | franc                | franc                | SAME
# 28    | spain                     | spain                | spain                | SAME
# 29    | raising                   | rais                 | rais                 | SAME
# 30    | series                    | seri                 | seri                 | SAME
# 31    | b                         | b                    | b                    | SAME
# 32    | round                     | round                | round                | SAME
# 33    | valuation                 | valuat               | valuat               | SAME
# 34    | deck                      | deck                 | deck                 | SAME
# 35    | attached                  | attach               | attach               | SAME
# 36    | httpsdrivegooglecomstartuppitchdeckqpdf | httpsdrivegooglecomstartuppitchdeckqpdf | httpsdrivegooglecomstartuppitchdeckqpdf | SAME
# 37    | lets                      | let                  | let                  | SAME
# 38    | schedule                  | schedul              | schedul              | SAME
# 39    | call                      | call                 | call                 | SAME
# 40    | calendlycomstartupceomin  | calendlycomstartupceomin | calendlycomstartupceomin | SAME
# 41    | best                      | best                 | best                 | SAME
# 42    | jennifer                  | jennif               | jennif               | SAME
# 43    | park                      | park                 | park                 | SAME
# 44    | ceo                       | ceo                  | ceo                  | SAME
# 45    | techflow                  | techflow             | techflow             | SAME
# 46    | inc                       | inc                  | inc                  | SAME
# 47    | jennifertechflowai        | jennifertechflowai   | jennifertechflowai   | SAME
#
# Total words with different stemming results: 0 out of 47
# Percentage of differences: 0.00%
#
# DETAILED COMPARISON FOR WORDS WITH DIFFERENT STEMMING RESULTS:
# No differences found between Porter and Snowball stemmers for this text.
#
# COMPLETE PORTER STEMMED TEXT:
# dear investor excit share q mileston key achiev revenu growth launch mobil app k download io android hire new engin team peopl expand eu market germani franc spain rais seri b round valuat deck attach httpsdrivegooglecomstartuppitchdeckqpdf let schedul call calendlycomstartupceomin best jennif park ceo techflow inc jennifertechflowai
#
# COMPLETE SNOWBALL STEMMED TEXT:
# dear investor excit share q mileston key achiev revenu growth launch mobil app k download io android hire new engin team peopl expand eu market germani franc spain rais seri b round valuat deck attach httpsdrivegooglecomstartuppitchdeckqpdf let schedul call calendlycomstartupceomin best jennif park ceo techflow inc jennifertechflowai
#
# PERFORMANCE COMPARISON:
# PorterStemmer processing time (10 repetitions): 0.005041 seconds
# SnowballStemmer processing time (10 repetitions): 0.003001 seconds

# %% [markdown]
# # 7. Lemmatization (WordNetLemmatizer)

# %%
lemmatizer = WordNetLemmatizer()
lemmatized_tokens = [lemmatizer.lemmatize(word) for word in filtered_tokens]

print("COMPLETE COMPARISON (Original vs Lemmatized):")
print(f"{'#':<5} | {'Original Word':<25} | {'Lemmatized':<25}")
for i, (original, lemmatized) in enumerate(zip(filtered_tokens, lemmatized_tokens), 1):
    print(f"{i:<5} | {original:<25} | {lemmatized:<25}")

lemmatized_text = ' '.join(lemmatized_tokens)
print("\nCOMPLETE LEMMATIZED TEXT:")
print(lemmatized_text)

print("\nSTEMMING vs LEMMATIZATION COMPARISON:")
print(f"{'#':<5} | {'Original Word':<25} | {'Porter Stemmer':<20} | {'Snowball Stemmer':<20} | {'Lemmatized':<25}")
for i, (original, porter, snowball, lemmatized) in enumerate(zip(filtered_tokens, porter_stemmed_tokens, snowball_stemmed_tokens, lemmatized_tokens), 1):
    print(f"{i:<5} | {original:<25} | {porter:<20} | {snowball:<20} | {lemmatized:<25}")

# Performance comparison for Lemmatizer
print("\nPERFORMANCE COMPARISON (Lemmatizer vs Stemmers):")

# Test Lemmatizer speed
start_time = time.time()
for word in filtered_tokens * 10:
    lemmatizer.lemmatize(word)
lemmatizer_time = time.time() - start_time

print(f"WordNetLemmatizer processing time (10 repetitions): {lemmatizer_time:.6f} seconds")
print(f"PorterStemmer processing time (10 repetitions): {porter_time:.6f} seconds")
print(f"SnowballStemmer processing time (10 repetitions): {snowball_time:.6f} seconds")
# Out:
# COMPLETE COMPARISON (Original vs Lemmatized):
# #     | Original Word             | Lemmatized
# 1     | dear                      | dear
# 2     | investors                 | investor
# 3     | excited                   | excited
# 4     | share                     | share
# 5     | q                         | q
# 6     | milestones                | milestone
# 7     | key                       | key
# 8     | achievements              | achievement
# 9     | revenue                   | revenue
# 10    | growth                    | growth
# 11    | launched                  | launched
# 12    | mobile                    | mobile
# 13    | app                       | app
# 14    | k                         | k
# 15    | downloads                 | downloads
# 16    | ios                       | io
# 17    | android                   | android
# 18    | hired                     | hired
# 19    | new                       | new
# 20    | engineers                 | engineer
# 21    | team                      | team
# 22    | people                    | people
# 23    | expanded                  | expanded
# 24    | eu                        | eu
# 25    | market                    | market
# 26    | germany                   | germany
# 27    | france                    | france
# 28    | spain                     | spain
# 29    | raising                   | raising
# 30    | series                    | series
# 31    | b                         | b
# 32    | round                     | round
# 33    | valuation                 | valuation
# 34    | deck                      | deck
# 35    | attached                  | attached
# 36    | httpsdrivegooglecomstartuppitchdeckqpdf | httpsdrivegooglecomstartuppitchdeckqpdf
# 37    | lets                      | let
# 38    | schedule                  | schedule
# 39    | call                      | call
# 40    | calendlycomstartupceomin  | calendlycomstartupceomin
# 41    | best                      | best
# 42    | jennifer                  | jennifer
# 43    | park                      | park
# 44    | ceo                       | ceo
# 45    | techflow                  | techflow
# 46    | inc                       | inc
# 47    | jennifertechflowai        | jennifertechflowai
#
# COMPLETE LEMMATIZED TEXT:
# dear investor excited share q milestone key achievement revenue growth launched mobile app k downloads io android hired new engineer team people expanded eu market germany france spain raising series b round valuation deck attached httpsdrivegooglecomstartuppitchdeckqpdf let schedule call calendlycomstartupceomin best jennifer park ceo techflow inc jennifertechflowai
#
# STEMMING vs LEMMATIZATION COMPARISON:
# #     | Original Word             | Porter Stemmer       | Snowball Stemmer     | Lemmatized
# 1     | dear                      | dear                 | dear                 | dear
# 2     | investors                 | investor             | investor             | investor
# 3     | excited                   | excit                | excit                | excited
# 4     | share                     | share                | share                | share
# 5     | q                         | q                    | q                    | q
# 6     | milestones                | mileston             | mileston             | milestone
# 7     | key                       | key                  | key                  | key
# 8     | achievements              | achiev               | achiev               | achievement
# 9     | revenue                   | revenu               | revenu               | revenue
# 10    | growth                    | growth               | growth               | growth
# 11    | launched                  | launch               | launch               | launched
# 12    | mobile                    | mobil                | mobil                | mobile
# 13    | app                       | app                  | app                  | app
# 14    | k                         | k                    | k                    | k
# 15    | downloads                 | download             | download             | downloads
# 16    | ios                       | io                   | io                   | io
# 17    | android                   | android              | android              | android
# 18    | hired                     | hire                 | hire                 | hired
# 19    | new                       | new                  | new                  | new
# 20    | engineers                 | engin                | engin                | engineer
# 21    | team                      | team                 | team                 | team
# 22    | people                    | peopl                | peopl                | people
# 23    | expanded                  | expand               | expand               | expanded
# 24    | eu                        | eu                   | eu                   | eu
# 25    | market                    | market               | market               | market
# 26    | germany                   | germani              | germani              | germany
# 27    | france                    | franc                | franc                | france
# 28    | spain                     | spain                | spain                | spain
# 29    | raising                   | rais                 | rais                 | raising
# 30    | series                    | seri                 | seri                 | series
# 31    | b                         | b                    | b                    | b
# 32    | round                     | round                | round                | round
# 33    | valuation                 | valuat               | valuat               | valuation
# 34    | deck                      | deck                 | deck                 | deck
# 35    | attached                  | attach               | attach               | attached
# 36    | httpsdrivegooglecomstartuppitchdeckqpdf | httpsdrivegooglecomstartuppitchdeckqpdf | httpsdrivegooglecomstartuppitchdeckqpdf | httpsdrivegooglecomstartuppitchdeckqpdf
# 37    | lets                      | let                  | let                  | let
# 38    | schedule                  | schedul              | schedul              | schedule
# 39    | call                      | call                 | call                 | call
# 40    | calendlycomstartupceomin  | calendlycomstartupceomin | calendlycomstartupceomin | calendlycomstartupceomin
# 41    | best                      | best                 | best                 | best
# 42    | jennifer                  | jennif               | jennif               | jennifer
# 43    | park                      | park                 | park                 | park
# 44    | ceo                       | ceo                  | ceo                  | ceo
# 45    | techflow                  | techflow             | techflow             | techflow
# 46    | inc                       | inc                  | inc                  | inc
# 47    | jennifertechflowai        | jennifertechflowai   | jennifertechflowai   | jennifertechflowai
#
# PERFORMANCE COMPARISON (Lemmatizer vs Stemmers):
# WordNetLemmatizer processing time (10 repetitions): 0.015943 seconds
# PorterStemmer processing time (10 repetitions): 0.005041 seconds
# SnowballStemmer processing time (10 repetitions): 0.003001 seconds

# %% [markdown]
# # 8. Part-of-Speech (POS) Tagging

# %%
# Cell 10: 8. POS Tagging (Part-of-Speech Tagging)
print("8. PART-OF-SPEECH (POS) TAGGING")

# Perform POS tagging on all filtered tokens
pos_tagged = pos_tag(filtered_tokens)

print("COMPLETE POS TAGGING RESULTS:")
print(f"{'#':<4} | {'Word':<20} | {'POS Tag':<10} | {'Description'}")

pos_descriptions = {
    'NN': 'Noun, singular', 'NNS': 'Noun, plural',
    'NNP': 'Proper noun, singular', 'NNPS': 'Proper noun, plural',
    'VB': 'Verb, base form', 'VBD': 'Verb, past tense',
    'VBG': 'Verb, gerund/present participle', 'VBN': 'Verb, past participle',
    'VBP': 'Verb, non-3rd person singular present', 'VBZ': 'Verb, 3rd person singular present',
    'JJ': 'Adjective', 'JJR': 'Adjective, comparative', 'JJS': 'Adjective, superlative',
    'RB': 'Adverb', 'RBR': 'Adverb, comparative', 'RBS': 'Adverb, superlative',
    'IN': 'Preposition/subordinating conjunction', 'DT': 'Determiner',
    'CC': 'Coordinating conjunction', 'PRP': 'Personal pronoun', 'PRP$': 'Possessive pronoun',
    'MD': 'Modal auxiliary', 'TO': 'to', 'UH': 'Interjection',
    'CD': 'Cardinal number', 'EX': 'Existential there', 'FW': 'Foreign word',
    'LS': 'List item marker', 'POS': 'Possessive ending', 'RP': 'Particle',
    'SYM': 'Symbol', 'WDT': 'Wh-determiner', 'WP': 'Wh-pronoun',
    'WP$': 'Possessive wh-pronoun', 'WRB': 'Wh-adverb'
}

for i, (word, tag) in enumerate(pos_tagged, 1):
    desc = pos_descriptions.get(tag, 'Other')
    print(f"{i:<4} | {word:<20} | {tag:<10} | {desc}")
# Out:
# 8. PART-OF-SPEECH (POS) TAGGING
# COMPLETE POS TAGGING RESULTS:
# #    | Word                 | POS Tag    | Description
# 1    | dear                 | JJ         | Adjective
# 2    | investors            | NNS        | Noun, plural
# 3    | excited              | VBD        | Verb, past tense
# 4    | share                | NN         | Noun, singular
# 5    | q                    | JJ         | Adjective
# 6    | milestones           | NNS        | Noun, plural
# 7    | key                  | JJ         | Adjective
# 8    | achievements         | NNS        | Noun, plural
# 9    | revenue              | NN         | Noun, singular
# 10   | growth               | NN         | Noun, singular
# 11   | launched             | VBN        | Verb, past participle
# 12   | mobile               | IN         | Preposition/subordinating conjunction
# 13   | app                  | NN         | Noun, singular
# 14   | k                    | NN         | Noun, singular
# 15   | downloads            | VBZ        | Verb, 3rd person singular present
# 16   | ios                  | NNS        | Noun, plural
# 17   | android              | RB         | Adverb
# 18   | hired                | VBD        | Verb, past tense
# 19   | new                  | JJ         | Adjective
# 20   | engineers            | NNS        | Noun, plural
# 21   | team                 | VBP        | Verb, non-3rd person singular present
# 22   | people               | NNS        | Noun, plural
# 23   | expanded             | VBD        | Verb, past tense
# 24   | eu                   | JJ         | Adjective
# 25   | market               | NN         | Noun, singular
# 26   | germany              | JJ         | Adjective
# 27   | france               | NN         | Noun, singular
# 28   | spain                | NN         | Noun, singular
# 29   | raising              | VBG        | Verb, gerund/present participle
# 30   | series               | NN         | Noun, singular
# 31   | b                    | NN         | Noun, singular
# 32   | round                | NN         | Noun, singular
# 33   | valuation            | NN         | Noun, singular
# 34   | deck                 | NN         | Noun, singular
# 35   | attached             | VBD        | Verb, past tense
# 36   | httpsdrivegooglecomstartuppitchdeckqpdf | JJ         | Adjective
# 37   | lets                 | NNS        | Noun, plural
# 38   | schedule             | VBP        | Verb, non-3rd person singular present
# 39   | call                 | VB         | Verb, base form
# 40   | calendlycomstartupceomin | NN         | Noun, singular
# 41   | best                 | JJS        | Adjective, superlative
# 42   | jennifer             | NN         | Noun, singular
# 43   | park                 | NN         | Noun, singular
# 44   | ceo                  | NN         | Noun, singular
# 45   | techflow             | IN         | Preposition/subordinating conjunction
# 46   | inc                  | NN         | Noun, singular
# 47   | jennifertechflowai   | NN         | Noun, singular

# %% [markdown]
# # 9. Chunking

# %%
# Define chunk grammar
chunk_grammar = r"""
    NP: {<DT>?<JJ>*<NN.*>+}
    NP: {<NNP>+}
    NP: {<NNP><POS>?<NNP>*}
    VP: {<VB.*><NP|PP|CLAUSE>+$}
    PP: {<IN><NP>}
"""
chunk_parser = RegexpParser(chunk_grammar)

# Process ALL sentences for chunking
all_sentences = sent_tokenize(text_lower)

for sent_idx, sentence in enumerate(all_sentences, 1):
    print(f"\nSentence {sent_idx}: {sentence}")

    # Tokenize and tag
    tokens = word_tokenize(sentence)
    pos_tags = pos_tag(tokens)

    # Parse chunks
    chunk_tree = chunk_parser.parse(pos_tags)

    print("Chunk Tree Structure:")
    print(chunk_tree)

    print("Chunks extracted:")
    for subtree in chunk_tree.subtrees():
        if subtree.label() in ['NP', 'VP', 'PP']:
            chunk_words = ' '.join(word for word, tag in subtree.leaves())
            print(f"  {subtree.label()}: {chunk_words}")
# Out:
# Sentence 1: dear investors, we are excited to share our q milestones  key achievements   revenue growth .m  .m   launched mobile app k downloads on ios and android   hired new engineers team now people   expanded to eu market germany, france, spain  we are now raising our series b round m valuation.
# Chunk Tree Structure:
# (S
#   (NP dear/JJ investors/NNS)
#   ,/,
#   we/PRP
#   are/VBP
#   excited/VBN
#   to/TO
#   (NP share/NN)
#   our/PRP$
#   (NP q/NN milestones/NNS)
#   (NP key/JJ achievements/NNS revenue/NN growth/NN .m/NNP .m/NNP)
#   launched/VBD
#   (NP mobile/JJ app/NN k/NN downloads/NNS)
#   (PP on/IN (NP ios/NNS))
#   and/CC
#   android/VB
#   hired/VBN
#   (NP new/JJ engineers/NNS)
#   team/VBP
#   now/RB
#   (NP people/NNS)
#   expanded/VBD
#   to/TO
#   eu/VB
#   (NP market/NN germany/NN)
#   ,/,
#   (NP france/NN)
#   ,/,
#   (NP spain/NN)
#   we/PRP
#   are/VBP
#   now/RB
#   raising/VBG
#   our/PRP$
#   (NP series/NN b/NN round/NN m/NN valuation/NN)
#   ./.)
# Chunks extracted:
#   NP: dear investors
#   NP: share
#   NP: q milestones
#   NP: key achievements revenue growth .m .m
#   NP: mobile app k downloads
#   PP: on ios
#   NP: ios
#   NP: new engineers
#   NP: people
#   NP: market germany
#   NP: france
#   NP: spain
#   NP: series b round m valuation
#
# Sentence 2: deck attached httpsdrive.google.comstartuppitch_deck_q.pdf lets schedule a call calendly.comstartupceomin best, jennifer park ceo, techflow inc. jennifertechflow.ai
# Chunk Tree Structure:
# (S
#   (NP deck/NN)
#   attached/VBD
#   (NP httpsdrive.google.comstartuppitch_deck_q.pdf/JJ lets/NNS)
#   schedule/VBP
#   (NP a/DT call/NN calendly.comstartupceomin/NN)
#   best/RBS
#   ,/,
#   (NP jennifer/NN park/NN ceo/NN)
#   ,/,
#   (VP techflow/VB (NP inc./NN jennifertechflow.ai/NN)))
# Chunks extracted:
#   NP: deck
#   NP: httpsdrive.google.comstartuppitch_deck_q.pdf lets
#   NP: a call calendly.comstartupceomin
#   NP: jennifer park ceo
#   VP: techflow inc. jennifertechflow.ai
#   NP: inc. jennifertechflow.ai

# %% [markdown]
# # 10. Parsing ( Dependency Parsing and Tree Structure Parsing )

# %%
# Process entire text with spaCy
doc = nlp(text_lower)

print("DEPENDENCY RELATIONS FOR ENTIRE TEXT:")

for token in doc:
    print(f"Word: '{token.text}'")
    print(f"  Head word: '{token.head.text}'")
    print(f"  Dependency relation: {token.dep_}")
    print(f"  Explanation: {spacy.explain(token.dep_)}")
    print(f"  Children: {[child.text for child in token.children]}")
# Out:
# DEPENDENCY RELATIONS FOR ENTIRE TEXT:
# Word: 'dear'
#   Head word: 'investors'
#   Dependency relation: amod
#   Explanation: adjectival modifier
#   Children: []
# Word: 'investors'
#   Head word: 'are'
#   Dependency relation: npadvmod
#   Explanation: noun phrase as adverbial modifier
#   Children: ['dear']
# Word: ','
#   Head word: 'are'
#   Dependency relation: punct
#   Explanation: punctuation
#   Children: []
# Word: 'we'
#   Head word: 'are'
#   Dependency relation: nsubj
#   Explanation: nominal subject
#   Children: []
# Word: 'are'
#   Head word: 'downloads'
#   Dependency relation: ccomp
#   Explanation: clausal complement
#   Children: ['investors', ',', 'we', 'excited', '.m']
# Word: 'excited'
#   Head word: 'are'
#   Dependency relation: acomp
#   Explanation: adjectival complement
#   Children: ['share']
# Word: 'to'
#   Head word: 'share'
#   Dependency relation: aux
#   Explanation: auxiliary
#   Children: []
# Word: 'share'
#   Head word: 'excited'
#   Dependency relation: xcomp
#   Explanation: open clausal complement
#   Children: ['to', 'growth']
# Word: 'our'
#   Head word: 'growth'
#   Dependency relation: poss
#   Explanation: possession modifier
#   Children: []
# Word: 'q'
#   Head word: 'milestones'
#   Dependency relation: nmod
#   Explanation: modifier of nominal
#   Children: []
# Word: 'milestones'
#   Head word: 'growth'
#   Dependency relation: compound
#   Explanation: compound
#   Children: ['q', ' ']
# Word: ' '
#   Head word: 'milestones'
#   Dependency relation: dep
#   Explanation: unclassified dependent
#   Children: []
# Word: 'key'
#   Head word: 'achievements'
#   Dependency relation: amod
#   Explanation: adjectival modifier
#   Children: []
# Word: 'achievements'
#   Head word: 'growth'
#   Dependency relation: compound
#   Explanation: compound
#   Children: ['key', '  ']
# Word: '  '
#   Head word: 'achievements'
#   Dependency relation: dep
#   Explanation: unclassified dependent
#   Children: []
# Word: 'revenue'
#   Head word: 'growth'
#   Dependency relation: compound
#   Explanation: compound
#   Children: []
# Word: 'growth'
#   Head word: 'share'
#   Dependency relation: dobj
#   Explanation: direct object
#   Children: ['our', 'milestones', 'achievements', 'revenue']
# Word: '.m'
#   Head word: 'are'
#   Dependency relation: dep
#   Explanation: unclassified dependent
#   Children: [' ', 'launched']
# Word: ' '
#   Head word: '.m'
#   Dependency relation: dep
#   Explanation: unclassified dependent
#   Children: []
# Word: '.m'
#   Head word: 'launched'
#   Dependency relation: nsubj
#   Explanation: nominal subject
#   Children: ['  ']
# Word: '  '
#   Head word: '.m'
#   Dependency relation: dep
#   Explanation: unclassified dependent
#   Children: []
# Word: 'launched'
#   Head word: '.m'
#   Dependency relation: ccomp
#   Explanation: clausal complement
#   Children: ['.m']
# Word: 'mobile'
#   Head word: 'app'
#   Dependency relation: amod
#   Explanation: adjectival modifier
#   Children: []
# Word: 'app'
#   Head word: 'k'
#   Dependency relation: compound
#   Explanation: compound
#   Children: ['mobile']
# Word: 'k'
#   Head word: 'downloads'
#   Dependency relation: nsubj
#   Explanation: nominal subject
#   Children: ['app']
# Word: 'downloads'
#   Head word: 'downloads'
#   Dependency relation: ROOT
#   Explanation: root
#   Children: ['are', 'k', 'on', 'hired', 'expanded', '.']
# Word: 'on'
#   Head word: 'downloads'
#   Dependency relation: prep
#   Explanation: prepositional modifier
#   Children: ['ios']
# Word: 'ios'
#   Head word: 'on'
#   Dependency relation: pobj
#   Explanation: object of preposition
#   Children: ['and', 'android']
# Word: 'and'
#   Head word: 'ios'
#   Dependency relation: cc
#   Explanation: coordinating conjunction
#   Children: []
# Word: 'android'
#   Head word: 'ios'
#   Dependency relation: conj
#   Explanation: conjunct
#   Children: ['  ']
# Word: '  '
#   Head word: 'android'
#   Dependency relation: dep
#   Explanation: unclassified dependent
#   Children: []
# Word: 'hired'
#   Head word: 'downloads'
#   Dependency relation: conj
#   Explanation: conjunct
#   Children: ['team']
# Word: 'new'
#   Head word: 'engineers'
#   Dependency relation: amod
#   Explanation: adjectival modifier
#   Children: []
# Word: 'engineers'
#   Head word: 'team'
#   Dependency relation: compound
#   Explanation: compound
#   Children: ['new']
# Word: 'team'
#   Head word: 'hired'
#   Dependency relation: dobj
#   Explanation: direct object
#   Children: ['engineers']
# Word: 'now'
#   Head word: 'expanded'
#   Dependency relation: advmod
#   Explanation: adverbial modifier
#   Children: []
# Word: 'people'
#   Head word: 'expanded'
#   Dependency relation: nsubj
#   Explanation: nominal subject
#   Children: ['  ']
# Word: '  '
#   Head word: 'people'
#   Dependency relation: dep
#   Explanation: unclassified dependent
#   Children: []
# Word: 'expanded'
#   Head word: 'downloads'
#   Dependency relation: advcl
#   Explanation: adverbial clause modifier
#   Children: ['now', 'people', 'to', 'raising']
# Word: 'to'
#   Head word: 'expanded'
#   Dependency relation: prep
#   Explanation: prepositional modifier
#   Children: ['germany']
# Word: 'eu'
#   Head word: 'germany'
#   Dependency relation: compound
#   Explanation: compound
#   Children: []
# Word: 'market'
#   Head word: 'germany'
#   Dependency relation: compound
#   Explanation: compound
#   Children: []
# Word: 'germany'
#   Head word: 'to'
#   Dependency relation: pobj
#   Explanation: object of preposition
#   Children: ['eu', 'market', ',', 'france']
# Word: ','
#   Head word: 'germany'
#   Dependency relation: punct
#   Explanation: punctuation
#   Children: []
# Word: 'france'
#   Head word: 'germany'
#   Dependency relation: appos
#   Explanation: appositional modifier
#   Children: [',', 'spain']
# Word: ','
#   Head word: 'france'
#   Dependency relation: punct
#   Explanation: punctuation
#   Children: []
# Word: 'spain'
#   Head word: 'france'
#   Dependency relation: conj
#   Explanation: conjunct
#   Children: [' ']
# Word: ' '
#   Head word: 'spain'
#   Dependency relation: dep
#   Explanation: unclassified dependent
#   Children: []
# Word: 'we'
#   Head word: 'raising'
#   Dependency relation: nsubj
#   Explanation: nominal subject
#   Children: []
# Word: 'are'
#   Head word: 'raising'
#   Dependency relation: aux
#   Explanation: auxiliary
#   Children: []
# Word: 'now'
#   Head word: 'raising'
#   Dependency relation: advmod
#   Explanation: adverbial modifier
#   Children: []
# Word: 'raising'
#   Head word: 'expanded'
#   Dependency relation: advcl
#   Explanation: adverbial clause modifier
#   Children: ['we', 'are', 'now', 'series', 'valuation']
# Word: 'our'
#   Head word: 'series'
#   Dependency relation: poss
#   Explanation: possession modifier
#   Children: []
# Word: 'series'
#   Head word: 'raising'
#   Dependency relation: dobj
#   Explanation: direct object
#   Children: ['our']
# Word: 'b'
#   Head word: 'valuation'
#   Dependency relation: nmod
#   Explanation: modifier of nominal
#   Children: []
# Word: 'round'
#   Head word: 'valuation'
#   Dependency relation: nmod
#   Explanation: modifier of nominal
#   Children: []
# Word: 'm'
#   Head word: 'valuation'
#   Dependency relation: compound
#   Explanation: compound
#   Children: []
# Word: 'valuation'
#   Head word: 'raising'
#   Dependency relation: dobj
#   Explanation: direct object
#   Children: ['b', 'round', 'm']
# Word: '.'
#   Head word: 'downloads'
#   Dependency relation: punct
#   Explanation: punctuation
#   Children: []
# Word: 'deck'
#   Head word: 'attached'
#   Dependency relation: nsubj
#   Explanation: nominal subject
#   Children: []
# Word: 'attached'
#   Head word: 'attached'
#   Dependency relation: ROOT
#   Explanation: root
#   Children: ['deck', 'lets', 'schedule', 'ceo', '.']
# Word: 'httpsdrive.google.comstartuppitch_deck_q.pdf'
#   Head word: 'lets'
#   Dependency relation: compound
#   Explanation: compound
#   Children: []
# Word: 'lets'
#   Head word: 'attached'
#   Dependency relation: dobj
#   Explanation: direct object
#   Children: ['httpsdrive.google.comstartuppitch_deck_q.pdf']
# Word: 'schedule'
#   Head word: 'attached'
#   Dependency relation: xcomp
#   Explanation: open clausal complement
#   Children: ['calendly.comstartupceomin', 'best', ',']
# Word: 'a'
#   Head word: 'call'
#   Dependency relation: det
#   Explanation: determiner
#   Children: []
# Word: 'call'
#   Head word: 'calendly.comstartupceomin'
#   Dependency relation: compound
#   Explanation: compound
#   Children: ['a']
# Word: 'calendly.comstartupceomin'
#   Head word: 'schedule'
#   Dependency relation: dobj
#   Explanation: direct object
#   Children: ['call']
# Word: 'best'
#   Head word: 'schedule'
#   Dependency relation: advmod
#   Explanation: adverbial modifier
#   Children: []
# Word: ','
#   Head word: 'schedule'
#   Dependency relation: punct
#   Explanation: punctuation
#   Children: []
# Word: 'jennifer'
#   Head word: 'park'
#   Dependency relation: compound
#   Explanation: compound
#   Children: []
# Word: 'park'
#   Head word: 'ceo'
#   Dependency relation: compound
#   Explanation: compound
#   Children: ['jennifer']
# Word: 'ceo'
#   Head word: 'attached'
#   Dependency relation: dep
#   Explanation: unclassified dependent
#   Children: ['park', ',', 'inc']
# Word: ','
#   Head word: 'ceo'
#   Dependency relation: punct
#   Explanation: punctuation
#   Children: []
# Word: 'techflow'
#   Head word: 'inc'
#   Dependency relation: compound
#   Explanation: compound
#   Children: []
# Word: 'inc'
#   Head word: 'ceo'
#   Dependency relation: appos
#   Explanation: appositional modifier
#   Children: ['techflow']
# Word: '.'
#   Head word: 'attached'
#   Dependency relation: punct
#   Explanation: punctuation
#   Children: ['jennifertechflow.ai']
# Word: 'jennifertechflow.ai'
#   Head word: '.'
#   Dependency relation: nummod
#   Explanation: numeric modifier
#   Children: ['  ']
# Word: '  '
#   Head word: 'jennifertechflow.ai'
#   Dependency relation: dep
#   Explanation: unclassified dependent
#   Children: []

# %%
all_sentences = sent_tokenize(text_lower)

for sent_idx, sentence in enumerate(all_sentences, 1):
    print(f"\nSentence {sent_idx}: {sentence}")

    # Tokenize and tag
    tokens = word_tokenize(sentence)
    pos_tags = pos_tag(tokens)

    # Create a simple binary tree structure for visualization
    def create_simple_tree(tokens, pos_tags):
        """Create a simple constituency-like tree structure"""
        if len(tokens) == 1:
            return Tree(pos_tags[0][1], [tokens[0]])
        else:
            mid = len(tokens) // 2
            left_tree = create_simple_tree(tokens[:mid], pos_tags[:mid])
            right_tree = create_simple_tree(tokens[mid:], pos_tags[mid:])
            return Tree('S', [left_tree, right_tree])

    try:
        constituency_tree = create_simple_tree(tokens, pos_tags)
        print("Constituency Tree:")
        constituency_tree.pretty_print()

        print("Tree in bracketed notation:")
        print(constituency_tree)
    except Exception as e:
        print(f"Error creating tree: {e}")

print("\nALTERNATIVE TREE VISUALIZATION (ALL SENTENCES - Detailed NP chunks):")

# More detailed tree structure for ALL sentences
for sent_idx, sentence in enumerate(all_sentences, 1):
    print(f"\nSentence {sent_idx}: {sentence}")

    tokens = word_tokenize(sentence)
    pos_tags = pos_tag(tokens)

    # Manual tree building
    tree = Tree('S', [])
    current_np = []

    for word, tag in pos_tags:
        if tag.startswith('NN') or tag.startswith('JJ') or tag == 'DT':
            current_np.append((word, tag))
        else:
            if current_np:
                np_tree = Tree('NP', [f"{w}/{t}" for w, t in current_np])
                tree.append(np_tree)
                current_np = []
            tree.append(f"{word}/{tag}")

    if current_np:
        np_tree = Tree('NP', [f"{w}/{t}" for w, t in current_np])
        tree.append(np_tree)

    print("Detailed Constituency Tree (NP chunks):")
    tree.pretty_print()
    print("\nTree as string:")
    print(tree)
# Out:
# Sentence 1: dear investors, we are excited to share our q milestones  key achievements   revenue growth .m  .m   launched mobile app k downloads on ios and android   hired new engineers team now people   expanded to eu market germany, france, spain  we are now raising our series b round m valuation.
# Constituency Tree:
#                                                                                                                                                                                                           S
#                                                                                                    _______________________________________________________________________________________________________|______________________________________________________________________________________________________
#                                                                                                   S                                                                                                                                                                                                              S
#                                              _____________________________________________________|_______________________________________________________                                                                                                     __________________________________________________|___________________________________________
#                                             S                                                                                                             S                                                                                                   S                                                                                              S
#                      _______________________|__________________                                                                ___________________________|_____________________                                                  ____________________________|___________________                                                    _______________________|____________________
#                     S                                          S                                                              S                                                 S                                                S                                                S                                                  S                                            S
#           __________|_______                      _____________|__________________                                   _________|_________                       _________________|___________                           __________|___________                         ____________|_________________                         ________|_______                       ______________|____________
#          S                  S                    S                                S                                 S                   S                     S                             S                         S                      S                       S                              S                       S                S                     S                           S
#   _______|______         ___|___             ____|____              ______________|_______                    ______|_____         _____|______            ___|___                   _______|_______              ____|___               ____|___              ______|___                ___________|_______            ____|____         ___|___             _____|_____               _______|_____________
#  |              S       |       S           |         S            S                      S                  |            S       |            S          |       S                 S               S            |        S             |        S            |          S              S                   S          |         S       |       S           |           S             S                     S
#  |        ______|___    |    ___|_____      |     ____|___      ___|______             ___|_______           |       _____|___    |      ______|____      |    ___|______        ___|___         ___|_____       |     ___|______       |     ___|____        |       ___|___      _____|_____           ___|____      |     ____|___    |    ___|_____      |      _____|___      ____|___            ______|___
#  JJ     NNS         ,  PRP VBP       VBN    TO   NN      PRP$  NN        NNS          JJ         NNS         NN     NN       NNP NNP   VBD          JJ    NN  NN        NNS     IN     NNS      CC        VB    VBN   JJ        NNS    VBP   RB      NNS     VBD     TO      VB   NN          NN        ,        NN    ,    NN      PRP VBP  RB       VBG   PRP$   NN        NN   NN       NN         NN         .
#  |       |          |   |   |         |     |    |        |    |          |           |           |          |      |         |   |     |           |     |   |          |      |       |       |         |      |    |          |      |    |        |       |      |       |    |           |         |        |     |    |        |   |   |         |     |     |         |    |        |          |          |
# dear investors      ,   we are     excited  to share     our   q      milestones     key     achievements revenue growth      .m  .m launched     mobile app  k      downloads  on     ios     and     android hired new     engineers team now     people expanded  to      eu market     germany      ,      france  ,  spain      we are now     raising our  series      b  round      m      valuation      .
#
# Tree in bracketed notation:
# (S
#   (S
#     (S
#       (S
#         (S (JJ dear) (S (NNS investors) (, ,)))
#         (S (PRP we) (S (VBP are) (VBN excited))))
#       (S
#         (S (TO to) (S (NN share) (PRP$ our)))
#         (S
#           (S (NN q) (NNS milestones))
#           (S (JJ key) (NNS achievements)))))
#     (S
#       (S
#         (S (NN revenue) (S (NN growth) (NNP .m)))
#         (S (NNP .m) (S (VBD launched) (JJ mobile))))
#       (S
#         (S (NN app) (S (NN k) (NNS downloads)))
#         (S (S (IN on) (NNS ios)) (S (CC and) (VB android))))))
#   (S
#     (S
#       (S
#         (S (VBN hired) (S (JJ new) (NNS engineers)))
#         (S (VBP team) (S (RB now) (NNS people))))
#       (S
#         (S (VBD expanded) (S (TO to) (VB eu)))
#         (S (S (NN market) (NN germany)) (S (, ,) (NN france)))))
#     (S
#       (S
#         (S (, ,) (S (NN spain) (PRP we)))
#         (S (VBP are) (S (RB now) (VBG raising))))
#       (S
#         (S (PRP$ our) (S (NN series) (NN b)))
#         (S (S (NN round) (NN m)) (S (NN valuation) (. .)))))))
#
# Sentence 2: deck attached httpsdrive.google.comstartuppitch_deck_q.pdf lets schedule a call calendly.comstartupceomin best, jennifer park ceo, techflow inc. jennifertechflow.ai
# Constituency Tree:
#                                                                                                 S
#                                              ___________________________________________________|__________________________________
#                                             |                                                                                      S
#                                             |                                                                 _____________________|_____________
#                                             S                                                                |                                   S
#                     ________________________|_____________________                                           |                          _________|______
#                    S                                              S                                          S                         |                S
#        ____________|____________________                   _______|________                           _______|____________             |          ______|____
#       S                                 S                 S                S                         S                    S            S         |           S
#   ____|_____                  __________|___        ______|___         ____|_________            ____|___           ______|___      ___|___      |       ____|__________
#  NN        VBD               JJ            NNS    VBP         DT      NN             NN        RBS       ,         NN         NN   NN      ,     VB     NN              NN
#  |          |                |              |      |          |       |              |          |        |         |          |    |       |     |      |               |
# deck     attached     httpsdrive.googl     lets schedule      a      call     calendly.comstar best      ,      jennifer     park ceo      ,  techflow inc.     jennifertechflow.
#                       e.comstartuppitc                                           tupceomin                                                                              ai
#                         h_deck_q.pdf
#
# Tree in bracketed notation:
# (S
#   (S
#     (S
#       (S (NN deck) (VBD attached))
#       (S
#         (JJ httpsdrive.google.comstartuppitch_deck_q.pdf)
#         (NNS lets)))
#     (S
#       (S (VBP schedule) (DT a))
#       (S (NN call) (NN calendly.comstartupceomin))))
#   (S
#     (S (S (RBS best) (, ,)) (S (NN jennifer) (NN park)))
#     (S
#       (S (NN ceo) (, ,))
#       (S (VB techflow) (S (NN inc.) (NN jennifertechflow.ai))))))
#
# ALTERNATIVE TREE VISUALIZATION (ALL SENTENCES - Detailed NP chunks):
#
# Sentence 1: dear investors, we are excited to share our q milestones  key achievements   revenue growth .m  .m   launched mobile app k downloads on ios and android   hired new engineers team now people   expanded to eu market germany, france, spain  we are now raising our series b round m valuation.
# Detailed Constituency Tree (NP chunks):
#                                                                                                                                                                                                                S
#   _____________________________________________________________________________________________________________________________________________________________________________________________________________|_____________________________________________________________________________________________________________________________________________________________________________________________________________________________________________
#  |    |       |         |        |      |          |         |     |        |          |        |       |         |         |     |    |   |    |       |      |         |         |      |           NP                  NP                                      NP                                                       NP                         NP           NP                   NP                NP                NP       NP                      NP
#  |    |       |         |        |      |          |         |     |        |          |        |       |         |         |     |    |   |    |       |      |         |         |      |      _____|________           |       ________________________________|_______________________________________          _______|_______________           |       _____|________            |           ______|______           |        |          _____________|_______________
# ,/, we/PRP are/VBP excited/VBN to/TO our/PRP$ launched/VBD on/IN and/CC android/VB hired/VBN team/VBP now/RB expanded/VBD to/TO eu/VB ,/, ,/, we/PRP are/VBP now/RB raising/VBG our/PRP$ ./. dear/JJ     investors/NNS share/NN q/NN milestones/NNS key/JJ achievements/NNS revenue/NN growth/NN .m/NNP .m/NNP mobile/JJ app/NN k/NN downloads/NNS ios/NNS new/JJ     engineers/NNS people/NNS market/NN     germany/NN france/NN spain/NN series/NN b/NN round/NN m/NN valuation/NN
#
#
# Tree as string:
# (S
#   (NP dear/JJ investors/NNS)
#   ,/,
#   we/PRP
#   are/VBP
#   excited/VBN
#   to/TO
#   (NP share/NN)
#   our/PRP$
#   (NP
#     q/NN
#     milestones/NNS
#     key/JJ
#     achievements/NNS
#     revenue/NN
#     growth/NN
#     .m/NNP
#     .m/NNP)
#   launched/VBD
#   (NP mobile/JJ app/NN k/NN downloads/NNS)
#   on/IN
#   (NP ios/NNS)
#   and/CC
#   android/VB
#   hired/VBN
#   (NP new/JJ engineers/NNS)
#   team/VBP
#   now/RB
#   (NP people/NNS)
#   expanded/VBD
#   to/TO
#   eu/VB
#   (NP market/NN germany/NN)
#   ,/,
#   (NP france/NN)
#   ,/,
#   (NP spain/NN)
#   we/PRP
#   are/VBP
#   now/RB
#   raising/VBG
#   our/PRP$
#   (NP series/NN b/NN round/NN m/NN valuation/NN)
#   ./.)
#
# Sentence 2: deck attached httpsdrive.google.comstartuppitch_deck_q.pdf lets schedule a call calendly.comstartupceomin best, jennifer park ceo, techflow inc. jennifertechflow.ai
# Detailed Constituency Tree (NP chunks):
#                                                                                        S
#       _________________________________________________________________________________|_______________________________________________________________________
#      |            |          |      |   |       |         NP                     NP                  NP                                   NP                   NP
#      |            |          |      |   |       |         |            __________|_____        ______|___________                _________|______         _____|__________
# attached/VBD schedule/VBP best/RBS ,/, ,/, techflow/VB deck/NN httpsdrive.googl     lets/NNS a/DT call/NN calendly.comstar jennifer/NN park/NN ceo/NN inc./NN     jennifertechflow.
#                                                                e.comstartuppitc                             tupceomin/NN                                                ai/NN
#                                                                h_deck_q.pdf/JJ
#
#
# Tree as string:
# (S
#   (NP deck/NN)
#   attached/VBD
#   (NP httpsdrive.google.comstartuppitch_deck_q.pdf/JJ lets/NNS)
#   schedule/VBP
#   (NP a/DT call/NN calendly.comstartupceomin/NN)
#   best/RBS
#   ,/,
#   (NP jennifer/NN park/NN ceo/NN)
#   ,/,
#   techflow/VB
#   (NP inc./NN jennifertechflow.ai/NN))

# %% [markdown]
# # 11. Hypernyms and Hyponyms (WordNet)

# %%
# Extract ALL unique words from filtered tokens
unique_words = list(set(filtered_tokens))

for word in unique_words:
    print(f"\nWORD: '{word}'")

    # Get synsets for the word
    synsets = wn.synsets(word)

    if not synsets:
        print(f"  No synsets found for '{word}'")
        continue

    # Take first synset
    synset = synsets[0]
    print(f"  Definition: {synset.definition()}")
    print(f"  Example: {synset.examples() if synset.examples() else 'No example'}")

    # Hypernyms (more general concepts)
    hypernyms = synset.hypernyms()
    if hypernyms:
        print(f"\n  HYPERNYMS (more general): {len(hypernyms)} found")
        for hyp in hypernyms:
            print(f"    → {hyp.name()}")
            print(f"      Definition: {hyp.definition()}")
            # Get path hypernyms (higher level)
            hyper_paths = hyp.hypernyms()
            if hyper_paths:
                for path_hyp in hyper_paths:
                    print(f"        ↑ {path_hyp.name()}: {path_hyp.definition()}")
    else:
        print(f"\n  HYPERNYMS: None found")

    # Hyponyms (more specific concepts)
    hyponyms = synset.hyponyms()
    if hyponyms:
        print(f"\n  HYPONYMS (more specific): {len(hyponyms)} found")
        for hyp in hyponyms:
            print(f"    → {hyp.name()}")
            print(f"      Definition: {hyp.definition()}")
    else:
        print(f"\n  HYPONYMS: None found")

    # Full hierarchy path (no depth limit)
    print(f"\n  HIERARCHY PATH (up to root):")
    def show_path(s, level=0):
        print(f"    {'  ' * level}└─ {s.name()}")
        for hyp in s.hypernyms():
            show_path(hyp, level + 1)

    show_path(synset)

# Detailed example for ALL specific words from the text
print("\nDETAILED EXAMPLE FOR KEY WORDS FROM TEXT")

key_words = ['apple', 'computer', 'company', 'inventor', 'founder', 'ceo', 'pixar', 'next']

for word in key_words:
    print(f"\nDEEP ANALYSIS FOR: '{word}'")

    synsets = wn.synsets(word)
    if synsets:
        primary_synset = synsets[0]

        print(f"  Definition: {primary_synset.definition()}")
        print(f"  Lemmas: {primary_synset.lemma_names()}")

        # Get all hypernym paths (no limit)
        print("\n  All Hypernym Paths:")
        hypernym_paths = primary_synset.hypernym_paths()
        for i, path in enumerate(hypernym_paths, 1):
            print(f"    Path {i}: {' -> '.join([s.name().split('.')[0] for s in path])}")

        # Get all hyponyms (no limit on display)
        all_hyponyms = primary_synset.hyponyms()
        print(f"\n  Total hyponyms found: {len(all_hyponyms)}")
        if all_hyponyms:
            print("  All hyponyms:")
            for hyp in all_hyponyms:
                print(f"    - {hyp.name()}: {hyp.definition()}")
# Out:
# WORD: 'schedule'
#   Definition: a temporally organized plan for matters to be attended to
#   Example: No example
#
#   HYPERNYMS (more general): 1 found
#     → plan.n.01
#       Definition: a series of steps to be carried out or goals to be accomplished
#         ↑ idea.n.01: the content of cognition; the main thing you are thinking about
#
#   HYPONYMS (more specific): 1 found
#     → menu.n.04
#       Definition: an agenda of things to do
#
#   HIERARCHY PATH (up to root):
#     └─ agenda.n.01
#       └─ plan.n.01
#         └─ idea.n.01
#           └─ content.n.05
#             └─ cognition.n.01
#               └─ psychological_feature.n.01
#                 └─ abstraction.n.06
#                   └─ entity.n.01
#
# WORD: 'germany'
#   Definition: a republic in central Europe; split into East Germany and West Germany after World War II and reunited in 1990
#   Example: No example
#
#   HYPERNYMS: None found
#
#   HYPONYMS: None found
#
#   HIERARCHY PATH (up to root):
#     └─ germany.n.01
#
# WORD: 'dear'
#   Definition: a beloved person; used as terms of endearment
#   Example: No example
#
#   HYPERNYMS (more general): 1 found
#     → lover.n.01
#       Definition: a person who loves someone or is loved by someone
#         ↑ person.n.01: a human being
#
#   HYPONYMS: None found
#
#   HIERARCHY PATH (up to root):
#     └─ beloved.n.01
#       └─ lover.n.01
#         └─ person.n.01
#           └─ causal_agent.n.01
#             └─ physical_entity.n.01
#               └─ entity.n.01
#           └─ organism.n.01
#             └─ living_thing.n.01
#               └─ whole.n.02
#                 └─ object.n.01
#                   └─ physical_entity.n.01
#                     └─ entity.n.01
#
# WORD: 'mobile'
#   Definition: a river in southwestern Alabama; flows into Mobile Bay
#   Example: No example
#
#   HYPERNYMS: None found
#
#   HYPONYMS: None found
#
#   HIERARCHY PATH (up to root):
#     └─ mobile.n.01
#
# WORD: 'new'
#   Definition: not of long duration; having just (or relatively recently) come into being or been made or acquired or discovered
#   Example: ['a new law', 'new cars', 'a new comet', 'a new friend', 'a new year', 'the New World']
#
#   HYPERNYMS: None found
#
#   HYPONYMS: None found
#
#   HIERARCHY PATH (up to root):
#     └─ new.a.01
#
# WORD: 'ceo'
#   Definition: the corporate executive responsible for the operations of the firm; reports to a board of directors; may appoint other managers (including a president)
#   Example: No example
#
#   HYPERNYMS (more general): 1 found
#     → corporate_executive.n.01
#       Definition: an executive in a business corporation
#         ↑ executive.n.01: a person responsible for the administration of a business
#
#   HYPONYMS: None found
#
#   HIERARCHY PATH (up to root):
#     └─ chief_executive_officer.n.01
#       └─ corporate_executive.n.01
#         └─ executive.n.01
#           └─ administrator.n.01
#             └─ head.n.04
#               └─ leader.n.01
#                 └─ person.n.01
#                   └─ causal_agent.n.01
#                     └─ physical_entity.n.01
#                       └─ entity.n.01
#                   └─ organism.n.01
#                     └─ living_thing.n.01
#                       └─ whole.n.02
#                         └─ object.n.01
#                           └─ physical_entity.n.01
#                             └─ entity.n.01
#
# WORD: 'investors'
#   Definition: someone who commits capital in order to gain financial returns
#   Example: No example
#
#   HYPERNYMS (more general): 1 found
#     → capitalist.n.02
#       Definition: a person who invests capital in a business (especially a large business)
#         ↑ person.n.01: a human being
#
#   HYPONYMS (more specific): 9 found
#     → rentier.n.01
#       Definition: someone whose income is from property rents or bond interest and other investments
#     → stockholder.n.01
#       Definition: someone who holds shares of stock in a corporation
#     → bull.n.06
#       Definition: an investor with an optimistic market outlook; an investor who expects prices to rise and so buys now for resale later
#     → depositor.n.01
#       Definition: a person who has deposited money in a bank or similar institution
#     → caller.n.02
#       Definition: an investor who buys a call option
#     → contrarian.n.01
#       Definition: an investor who deliberately decides to go against the prevailing wisdom of other investors
#     → lender.n.01
#       Definition: someone who lends money or gives credit in business matters
#     → bondholder.n.01
#       Definition: a holder of bonds issued by a government or corporation
#     → bear.n.02
#       Definition: an investor with a pessimistic market outlook; an investor who expects prices to fall and so sells now in order to buy later at a lower price
#
#   HIERARCHY PATH (up to root):
#     └─ investor.n.01
#       └─ capitalist.n.02
#         └─ person.n.01
#           └─ causal_agent.n.01
#             └─ physical_entity.n.01
#               └─ entity.n.01
#           └─ organism.n.01
#             └─ living_thing.n.01
#               └─ whole.n.02
#                 └─ object.n.01
#                   └─ physical_entity.n.01
#                     └─ entity.n.01
#
# WORD: 'team'
#   Definition: a cooperative unit (especially in sports)
#   Example: No example
#
#   HYPERNYMS (more general): 1 found
#     → unit.n.03
#       Definition: an organization regarded as part of a larger social group
#         ↑ organization.n.01: a group of people who work together
#
#   HYPONYMS (more specific): 20 found
#     → second_string.n.01
#       Definition: a squad of players that are available either individually or as a team to relieve or replace the players who started the game
#     → section.n.05
#       Definition: a small team of policemen working as part of a police platoon
#     → baseball_team.n.01
#       Definition: a team that plays baseball
#     → offense.n.04
#       Definition: the team that has the ball (or puck) and is trying to score
#     → varsity.n.02
#       Definition: a team representing a college or university
#     → battery.n.04
#       Definition: a unit composed of the pitcher and catcher
#     → hockey_team.n.01
#       Definition: a team that plays ice hockey
#     → flying_squad.n.01
#       Definition: a mobile group of trained people (police or executives or officials) able to move quickly in the case of emergencies
#     → little-league_team.n.01
#       Definition: a team that plays in a little league
#     → basketball_team.n.01
#       Definition: a team that plays basketball
#     → police_squad.n.01
#       Definition: a small squad of policemen trained to deal with a particular kind of crime
#     → minor-league_team.n.01
#       Definition: a team that plays in a minor league
#     → powerhouse.n.02
#       Definition: a team considered to be the best of its class
#     → football_team.n.01
#       Definition: a team that plays football
#     → crew.n.04
#       Definition: the team of men manning a racing shell
#     → junior_varsity.n.01
#       Definition: a college or university team that competes at a level below the varsity team
#     → a-team.n.01
#       Definition: a group of elite soldiers or a leadership group of advisors or workers in an organization
#     → hit_squad.n.01
#       Definition: a team of assassins
#     → major-league_team.n.01
#       Definition: a team that plays in a major league
#     → defense.n.03
#       Definition: (sports) the team that is trying to prevent the other team from scoring
#
#   HIERARCHY PATH (up to root):
#     └─ team.n.01
#       └─ unit.n.03
#         └─ organization.n.01
#           └─ social_group.n.01
#             └─ group.n.01
#               └─ abstraction.n.06
#                 └─ entity.n.01
#
# WORD: 'httpsdrivegooglecomstartuppitchdeckqpdf'
#   No synsets found for 'httpsdrivegooglecomstartuppitchdeckqpdf'
#
# WORD: 'inc'
#   Definition: a heterogeneous collection of groups united in their opposition to Saddam Hussein's government of Iraq; formed in 1992 it is comprised of Sunni and Shiite Arabs and Kurds who hope to build a new government
#   Example: No example
#
#   HYPERNYMS (more general): 1 found
#     → opposition.n.05
#       Definition: a body of people united in opposing something
#         ↑ body.n.02: a group of persons associated by some common tie or occupation and regarded as an entity
#
#   HYPONYMS: None found
#
#   HIERARCHY PATH (up to root):
#     └─ iraqi_national_congress.n.01
#       └─ opposition.n.05
#         └─ body.n.02
#           └─ social_group.n.01
#             └─ group.n.01
#               └─ abstraction.n.06
#                 └─ entity.n.01
#
# WORD: 'park'
#   Definition: a large area of land preserved in its natural state as public property
#   Example: ['there are laws that protect the wildlife in this park']
#
#   HYPERNYMS (more general): 1 found
#     → tract.n.01
#       Definition: an extended area of land
#         ↑ geographical_area.n.01: a demarcated area of the Earth
#
#   HYPONYMS (more specific): 2 found
#     → national_park.n.01
#       Definition: a tract of land declared by the national government to be public property
#     → safari_park.n.01
#       Definition: an area of parkland where wild animals are kept and can be viewed by visitors driving through
#
#   HIERARCHY PATH (up to root):
#     └─ park.n.01
#       └─ tract.n.01
#         └─ geographical_area.n.01
#           └─ region.n.03
#             └─ location.n.01
#               └─ object.n.01
#                 └─ physical_entity.n.01
#                   └─ entity.n.01
#
# WORD: 'lets'
#   Definition: a brutal terrorist group active in Kashmir; fights against India with the goal of restoring Islamic rule of India
#   Example: ['Lashkar-e-Toiba has committed mass murders of civilian Hindus']
#
#   HYPERNYMS: None found
#
#   HYPONYMS: None found
#
#   HIERARCHY PATH (up to root):
#     └─ lashkar-e-taiba.n.01
#
# WORD: 'spain'
#   Definition: a parliamentary monarchy in southwestern Europe on the Iberian Peninsula; a former colonial power
#   Example: No example
#
#   HYPERNYMS: None found
#
#   HYPONYMS (more specific): 1 found
#     → logrono.n.01
#       Definition: a city in northern Spain on the Ebro River
#
#   HIERARCHY PATH (up to root):
#     └─ spain.n.01
#
# WORD: 'excited'
#   Definition: arouse or elicit a feeling
#   Example: No example
#
#   HYPERNYMS (more general): 1 found
#     → arouse.v.01
#       Definition: call forth (emotions, feelings, and responses)
#         ↑ make.v.03: make or cause to be or to become
#
#   HYPONYMS (more specific): 1 found
#     → enthuse.v.01
#       Definition: cause to feel enthusiasm
#
#   HIERARCHY PATH (up to root):
#     └─ excite.v.01
#       └─ arouse.v.01
#         └─ make.v.03
#
# WORD: 'round'
#   Definition: a charge of ammunition for a single shot
#   Example: No example
#
#   HYPERNYMS (more general): 1 found
#     → ammunition.n.01
#       Definition: projectiles to be fired from a gun
#         ↑ weaponry.n.01: weapons considered collectively
#
#   HYPONYMS: None found
#
#   HIERARCHY PATH (up to root):
#     └─ round.n.01
#       └─ ammunition.n.01
#         └─ weaponry.n.01
#           └─ instrumentality.n.03
#             └─ artifact.n.01
#               └─ whole.n.02
#                 └─ object.n.01
#                   └─ physical_entity.n.01
#                     └─ entity.n.01
#
# WORD: 'best'
#   Definition: the supreme effort one can make
#   Example: ['they did their best']
#
#   HYPERNYMS (more general): 1 found
#     → attempt.n.01
#       Definition: earnest and conscientious activity intended to do or accomplish something
#         ↑ activity.n.01: any specific behavior
#
#   HYPONYMS: None found
#
#   HIERARCHY PATH (up to root):
#     └─ best.n.01
#       └─ attempt.n.01
#         └─ activity.n.01
#           └─ act.n.02
#             └─ event.n.01
#               └─ psychological_feature.n.01
#                 └─ abstraction.n.06
#                   └─ entity.n.01
#
# WORD: 'jennifertechflowai'
#   No synsets found for 'jennifertechflowai'
#
# WORD: 'ios'
#   Definition: (Greek mythology) a maiden seduced by Zeus; when Hera was about to discover them together Zeus turned her into a white heifer
#   Example: No example
#
#   HYPERNYMS: None found
#
#   HYPONYMS: None found
#
#   HIERARCHY PATH (up to root):
#     └─ io.n.01
#
# WORD: 'series'
#   Definition: similar things placed in order or happening one after another
#   Example: ['they were investigating a series of bank robberies']
#
#   HYPERNYMS (more general): 1 found
#     → ordering.n.01
#       Definition: logical or comprehensible arrangement of separate elements
#         ↑ arrangement.n.02: an orderly grouping (of things or persons) considered as a unit; the result of arranging
#
#   HYPONYMS (more specific): 17 found
#     → string.n.04
#       Definition: a sequentially ordered set of things or events or ideas in which each successive member is related to the preceding
#     → stations.n.01
#       Definition: (Roman Catholic Church) a devotion consisting of fourteen prayers said before a series of fourteen pictures or carvings representing successive incidents during Jesus' passage from Pilate's house to his crucifixion at Calvary
#     → course.n.02
#       Definition: a connected series of events or actions or developments
#     → progression.n.01
#       Definition: a series with a definite pattern of advance
#     → electromotive_series.n.01
#       Definition: a serial arrangement of metallic elements or ions according to their electrode potentials determined under specified conditions; the order shows the tendency of one metal to reduce the ions of any other metal below it in the series
#     → cordon.n.01
#       Definition: a series of sentinels or of military posts enclosing or guarding some place or thing
#     → cycle.n.02
#       Definition: a series of poems or songs on the same theme
#     → succession.n.02
#       Definition: a group of people or things arranged or following in order
#     → wave_train.n.01
#       Definition: a succession of waves spaced at regular intervals
#     → sequence.n.01
#       Definition: serial arrangement in which things follow in logical order or a recurrent pattern
#     → lanthanide_series.n.01
#       Definition: the rare-earth elements with atomic numbers 57 through 71; having properties similar to lanthanum
#     → actinide_series.n.01
#       Definition: (chemistry) a series of 15 radioactive elements with increasing atomic numbers from actinium to lawrencium
#     → rash.n.02
#       Definition: a series of unexpected and unpleasant occurrences
#     → hierarchy.n.01
#       Definition: a series of ordered groupings of people or things within a system
#     → helium_group.n.01
#       Definition: the series of inert gases
#     → chain.n.01
#       Definition: a series of things depending on each other as if linked together
#     → nexus.n.02
#       Definition: a connected series or group
#
#   HIERARCHY PATH (up to root):
#     └─ series.n.01
#       └─ ordering.n.01
#         └─ arrangement.n.02
#           └─ group.n.01
#             └─ abstraction.n.06
#               └─ entity.n.01
#
# WORD: 'share'
#   Definition: assets belonging to or due to or contributed by an individual person or group
#   Example: ['he wanted his share in cash']
#
#   HYPERNYMS (more general): 1 found
#     → assets.n.01
#       Definition: anything of material value or usefulness that is owned by a person or company
#         ↑ possession.n.02: anything owned or possessed
#
#   HYPONYMS (more specific): 12 found
#     → dispensation.n.02
#       Definition: a share that has been dispensed or distributed
#     → dole.n.01
#       Definition: a share of money or food or clothing that has been charitably given
#     → allowance.n.01
#       Definition: an amount allowed or granted (as during a given period)
#     → slice.n.01
#       Definition: a share of something
#     → ration.n.02
#       Definition: a fixed portion that is allotted (especially in times of scarcity)
#     → cut.n.01
#       Definition: a share of the profits
#     → way.n.12
#       Definition: a portion of something divided into shares
#     → allotment.n.01
#       Definition: a share set aside for a specific purpose
#     → profit_sharing.n.01
#       Definition: a system in which employees receive a share of the net profits of the business
#     → tranche.n.01
#       Definition: a portion of something (especially money)
#     → interest.n.05
#       Definition: (law) a right or legal share of something; a financial involvement with something
#     → split.n.03
#       Definition: a promised or claimed share of loot or money
#
#   HIERARCHY PATH (up to root):
#     └─ share.n.01
#       └─ assets.n.01
#         └─ possession.n.02
#           └─ relation.n.01
#             └─ abstraction.n.06
#               └─ entity.n.01
#
# WORD: 'achievements'
#   Definition: the action of accomplishing something
#   Example: No example
#
#   HYPERNYMS (more general): 1 found
#     → action.n.01
#       Definition: something done (usually as opposed to something said)
#         ↑ act.n.02: something that people do or cause to happen
#
#   HYPONYMS (more specific): 19 found
#     → cakewalk.n.02
#       Definition: an easy accomplishment
#     → arrival.n.01
#       Definition: accomplishment of an objective
#     → beachhead.n.02
#       Definition: an initial accomplishment that opens the way for further developments
#     → going.n.03
#       Definition: advancing toward a goal
#     → haymaking.n.01
#       Definition: taking full advantage of an opportunity while it lasts
#     → fait_accompli.n.01
#       Definition: an irreversible accomplishment
#     → close_call.n.01
#       Definition: something achieved (or escaped) by a narrow margin
#     → smooth.n.01
#       Definition: the act of smoothing
#     → face_saver.n.01
#       Definition: an act that avoids a loss of face (of dignity or prestige)
#     → feat.n.01
#       Definition: a notable achievement
#     → masterpiece.n.02
#       Definition: an outstanding achievement
#     → record.n.04
#       Definition: the sum of recognized accomplishments
#     → base_on_balls.n.01
#       Definition: (baseball) an advance to first base by a batter who receives four balls
#     → attainment.n.01
#       Definition: the act of achieving an aim
#     → liberation.n.01
#       Definition: the act of liberating someone or something
#     → credit.n.04
#       Definition: used in the phrase `to your credit' in order to indicate an achievement deserving praise
#     → masterstroke.n.01
#       Definition: an achievement demonstrating great skill or mastery
#     → performance.n.04
#       Definition: any recognized accomplishment
#     → recruitment.n.01
#       Definition: the act of getting recruits; enlisting people for the army (or for a job or a cause etc.)
#
#   HIERARCHY PATH (up to root):
#     └─ accomplishment.n.01
#       └─ action.n.01
#         └─ act.n.02
#           └─ event.n.01
#             └─ psychological_feature.n.01
#               └─ abstraction.n.06
#                 └─ entity.n.01
#
# WORD: 'downloads'
#   Definition: transfer a file or program from a central computer to a smaller computer or to a computer at a remote location
#   Example: No example
#
#   HYPERNYMS (more general): 1 found
#     → transfer.v.02
#       Definition: move from one place to another
#         ↑ move.v.02: cause to move or shift into a new position or place, both in a concrete and in an abstract sense
#
#   HYPONYMS: None found
#
#   HIERARCHY PATH (up to root):
#     └─ download.v.01
#       └─ transfer.v.02
#         └─ move.v.02
#
# WORD: 'techflow'
#   No synsets found for 'techflow'
#
# WORD: 'market'
#   Definition: the world of commercial activity where goods and services are bought and sold
#   Example: ['without competition there would be no market', 'they were driven from the marketplace']
#
#   HYPERNYMS (more general): 1 found
#     → activity.n.01
#       Definition: any specific behavior
#         ↑ act.n.02: something that people do or cause to happen
#
#   HYPONYMS (more specific): 8 found
#     → labor_market.n.01
#       Definition: the market in which workers compete for jobs and employers compete for workers
#     → seller's_market.n.01
#       Definition: a market in which more people want to buy than want to sell
#     → oligopoly.n.01
#       Definition: (economics) a market in which control over the supply of a commodity is in the hands of a small number of producers and each one can influence prices and affect competitors
#     → monopoly.n.01
#       Definition: (economics) a market in which there are many buyers but only one seller
#     → grey_market.n.01
#       Definition: an unofficial market in which goods are bought and sold at prices lower than the official price set by a regulatory agency
#     → buyer's_market.n.01
#       Definition: a market in which more people want to sell than want to buy
#     → monopsony.n.01
#       Definition: (economics) a market in which goods or services are offered by several sellers but there is only one buyer
#     → black_market.n.02
#       Definition: an illegal market in which goods or currencies are bought and sold in violation of rationing or controls
#
#   HIERARCHY PATH (up to root):
#     └─ market.n.01
#       └─ activity.n.01
#         └─ act.n.02
#           └─ event.n.01
#             └─ psychological_feature.n.01
#               └─ abstraction.n.06
#                 └─ entity.n.01
#
# WORD: 'attached'
#   Definition: cause to be attached
#   Example: No example
#
#   HYPERNYMS (more general): 1 found
#     → connect.v.01
#       Definition: connect, fasten, or put together two or more pieces
#
#   HYPONYMS (more specific): 29 found
#     → hitch.v.01
#       Definition: to hook or entangle
#     → tag.v.01
#       Definition: attach a tag or label to
#     → mount.v.01
#       Definition: attach to a support
#     → tape.v.01
#       Definition: fasten or attach with tape
#     → couple.v.02
#       Definition: link together
#     → affix.v.03
#       Definition: attach or become attached to a stem word
#     → tether.v.01
#       Definition: tie with a tether
#     → yoke.v.02
#       Definition: link with or as with a yoke
#     → ring.v.06
#       Definition: attach a ring to the foot of, in order to identify
#     → glue.v.01
#       Definition: join or attach with or as if with glue
#     → fasten.v.01
#       Definition: cause to be firmly attached
#     → clip.v.03
#       Definition: attach with a clip
#     → append.v.02
#       Definition: fix to; attach
#     → hook_up.v.01
#       Definition: connect or link
#     → pin_down.v.03
#       Definition: attach with or as if with a pin
#     → append.v.01
#       Definition: add to the very end
#     → fixate.v.03
#       Definition: make fixed, stable or stationary
#     → peg.v.03
#       Definition: fasten or secure with a wooden pin
#     → insert.v.01
#       Definition: put or introduce into something
#     → fasten.v.03
#       Definition: attach to
#     → harness.v.01
#       Definition: put a harness
#     → affix.v.01
#       Definition: attach to
#     → hinge.v.01
#       Definition: attach with a hinge
#     → nail.v.01
#       Definition: attach something somewhere by means of nails
#     → bind.v.03
#       Definition: make fast; tie or secure, with or as if with a rope
#     → limber.v.01
#       Definition: attach the limber
#     → yoke.v.03
#       Definition: put a yoke on or join with a yoke
#     → saddle.v.01
#       Definition: put a saddle on
#     → bell.v.01
#       Definition: attach a bell to
#
#   HIERARCHY PATH (up to root):
#     └─ attach.v.01
#       └─ connect.v.01
#
# WORD: 'engineers'
#   Definition: a person who uses scientific knowledge to solve practical problems
#   Example: No example
#
#   HYPERNYMS (more general): 1 found
#     → person.n.01
#       Definition: a human being
#         ↑ causal_agent.n.01: any entity that produces an effect or is responsible for events or results
#         ↑ organism.n.01: a living thing that has (or can develop) the ability to act or function independently
#
#   HYPONYMS (more specific): 13 found
#     → mining_engineer.n.01
#       Definition: an engineer concerned with the construction and operation of mines
#     → mechanical_engineer.n.01
#       Definition: a person trained to design and construct machines
#     → aerospace_engineer.n.01
#       Definition: an engineer of aircraft and space vehicles
#     → marine_engineer.n.01
#       Definition: a naval officer responsible for the operation and maintenance of the ship's engines
#     → electrical_engineer.n.01
#       Definition: a person trained in practical applications of the theory of electricity
#     → automotive_engineer.n.01
#       Definition: an engineer concerned with the design and construction of automobiles
#     → metallurgist.n.01
#       Definition: an engineer trained in the extraction and refining and alloying and fabrication of metals
#     → rocket_engineer.n.01
#       Definition: an engineer who builds and tests rockets
#     → surveyor.n.01
#       Definition: an engineer who determines the boundaries and elevations of land or structures
#     → aeronautical_engineer.n.01
#       Definition: an engineer concerned with the design and construction of aircraft
#     → army_engineer.n.01
#       Definition: a member of the military who is trained in engineering and construction work
#     → programmer.n.01
#       Definition: a person who designs and writes and tests computer programs
#     → civil_engineer.n.01
#       Definition: an engineer trained to design and construct and maintain public works (roads or bridges or harbors etc.)
#
#   HIERARCHY PATH (up to root):
#     └─ engineer.n.01
#       └─ person.n.01
#         └─ causal_agent.n.01
#           └─ physical_entity.n.01
#             └─ entity.n.01
#         └─ organism.n.01
#           └─ living_thing.n.01
#             └─ whole.n.02
#               └─ object.n.01
#                 └─ physical_entity.n.01
#                   └─ entity.n.01
#
# WORD: 'android'
#   Definition: an automaton that resembles a human being
#   Example: No example
#
#   HYPERNYMS (more general): 1 found
#     → automaton.n.02
#       Definition: a mechanism that can move automatically
#         ↑ mechanism.n.05: device consisting of a piece of machinery; has moving parts that perform some function
#
#   HYPONYMS: None found
#
#   HIERARCHY PATH (up to root):
#     └─ android.n.01
#       └─ automaton.n.02
#         └─ mechanism.n.05
#           └─ device.n.01
#             └─ instrumentality.n.03
#               └─ artifact.n.01
#                 └─ whole.n.02
#                   └─ object.n.01
#                     └─ physical_entity.n.01
#                       └─ entity.n.01
#
# WORD: 'milestones'
#   Definition: stone post at side of a road to show distances
#   Example: No example
#
#   HYPERNYMS (more general): 1 found
#     → marker.n.02
#       Definition: a distinguishing symbol
#         ↑ symbol.n.01: an arbitrary sign (written or printed) that has acquired a conventional significance
#
#   HYPONYMS: None found
#
#   HIERARCHY PATH (up to root):
#     └─ milestone.n.01
#       └─ marker.n.02
#         └─ symbol.n.01
#           └─ signal.n.01
#             └─ communication.n.02
#               └─ abstraction.n.06
#                 └─ entity.n.01
#
# WORD: 'key'
#   Definition: metal device shaped in such a way that when it is inserted into the appropriate lock the lock's mechanism can be rotated
#   Example: No example
#
#   HYPERNYMS (more general): 1 found
#     → device.n.01
#       Definition: an instrumentality invented for a particular purpose
#         ↑ instrumentality.n.03: an artifact (or system of artifacts) that is instrumental in accomplishing some end
#
#   HYPONYMS (more specific): 3 found
#     → ignition_key.n.01
#       Definition: a key that operates the ignition switch of an automotive engine
#     → latchkey.n.01
#       Definition: key for raising or drawing back a latch or opening an outside door
#     → passkey.n.01
#       Definition: key that secures entrance everywhere
#
#   HIERARCHY PATH (up to root):
#     └─ key.n.01
#       └─ device.n.01
#         └─ instrumentality.n.03
#           └─ artifact.n.01
#             └─ whole.n.02
#               └─ object.n.01
#                 └─ physical_entity.n.01
#                   └─ entity.n.01
#
# WORD: 'hired'
#   Definition: engage or hire for work
#   Example: ['They hired two new secretaries in the department', 'How many people has she employed?']
#
#   HYPERNYMS: None found
#
#   HYPONYMS (more specific): 7 found
#     → subcontract.v.01
#       Definition: arranged for contracted work to be done by others
#     → rat.v.02
#       Definition: employ scabs or strike breakers in
#     → ship.v.02
#       Definition: hire for work on a ship
#     → featherbed.v.02
#       Definition: hire more workers than are necessary
#     → sign.v.04
#       Definition: engage by written agreement
#     → fill.v.06
#       Definition: appoint someone to (a position or a job)
#     → engage.v.04
#       Definition: ask to represent; of legal counsel
#
#   HIERARCHY PATH (up to root):
#     └─ hire.v.01
#
# WORD: 'revenue'
#   Definition: the entire amount of income before any deductions are made
#   Example: No example
#
#   HYPERNYMS (more general): 1 found
#     → sum.n.01
#       Definition: a quantity of money
#         ↑ assets.n.01: anything of material value or usefulness that is owned by a person or company
#
#   HYPONYMS (more specific): 2 found
#     → box_office.n.01
#       Definition: total admission receipts for an entertainment
#     → gate.n.03
#       Definition: total admission receipts at a sports event
#
#   HIERARCHY PATH (up to root):
#     └─ gross.n.02
#       └─ sum.n.01
#         └─ assets.n.01
#           └─ possession.n.02
#             └─ relation.n.01
#               └─ abstraction.n.06
#                 └─ entity.n.01
#
# WORD: 'jennifer'
#   No synsets found for 'jennifer'
#
# WORD: 'eu'
#   Definition: a bivalent and trivalent metallic element of the rare earth group
#   Example: No example
#
#   HYPERNYMS (more general): 1 found
#     → metallic_element.n.01
#       Definition: any of several chemical elements that are usually shiny solids that conduct heat or electricity and can be formed into sheets etc.
#         ↑ chemical_element.n.01: any of the more than 100 known substances (of which 92 occur naturally) that cannot be separated into simpler substances and that singly or in combination constitute all matter
#
#   HYPONYMS: None found
#
#   HIERARCHY PATH (up to root):
#     └─ europium.n.01
#       └─ metallic_element.n.01
#         └─ chemical_element.n.01
#           └─ substance.n.01
#             └─ part.n.01
#               └─ relation.n.01
#                 └─ abstraction.n.06
#                   └─ entity.n.01
#             └─ matter.n.03
#               └─ physical_entity.n.01
#                 └─ entity.n.01
#
# WORD: 'raising'
#   Definition: the event of something being raised upward
#   Example: ['an elevation of the temperature in the afternoon', 'a raising of the land resulting from volcanic activity']
#
#   HYPERNYMS (more general): 1 found
#     → rise.n.04
#       Definition: a movement upward
#         ↑ change_of_location.n.01: a movement through space that changes the location of something
#
#   HYPONYMS: None found
#
#   HIERARCHY PATH (up to root):
#     └─ elevation.n.01
#       └─ rise.n.04
#         └─ change_of_location.n.01
#           └─ movement.n.03
#             └─ happening.n.01
#               └─ event.n.01
#                 └─ psychological_feature.n.01
#                   └─ abstraction.n.06
#                     └─ entity.n.01
#
# WORD: 'b'
#   Definition: aerobic rod-shaped spore-producing bacterium; often occurring in chainlike formations; found primarily in soil
#   Example: No example
#
#   HYPERNYMS (more general): 1 found
#     → eubacteria.n.01
#       Definition: a large group of bacteria having rigid cell walls; motile types have flagella
#         ↑ moneran.n.01: organisms that typically reproduce by asexual budding or fission and whose nutritional mode is absorption or photosynthesis or chemosynthesis
#         ↑ bacteria.n.01: (microbiology) single-celled or noncellular spherical or spiral or rod-shaped organisms lacking chlorophyll that reproduce by fission; important as pathogens and for biochemical properties; taxonomy is difficult; often considered to be plants
#
#   HYPONYMS (more specific): 3 found
#     → bacillus_anthracis.n.01
#       Definition: a species of bacillus that causes anthrax in humans and in animals (cattle and swine and sheep and rabbits and mice and guinea pigs); can be used a bioweapon
#     → bacillus_subtilis.n.01
#       Definition: a species of bacillus found in soil and decomposing organic matter; some strains produce antibiotics
#     → yersinia_pestis.n.01
#       Definition: a bacillus bacterium that causes the plague; aerosolized bacteria can be used as a bioweapon
#
#   HIERARCHY PATH (up to root):
#     └─ bacillus.n.01
#       └─ eubacteria.n.01
#         └─ moneran.n.01
#           └─ microorganism.n.01
#             └─ organism.n.01
#               └─ living_thing.n.01
#                 └─ whole.n.02
#                   └─ object.n.01
#                     └─ physical_entity.n.01
#                       └─ entity.n.01
#         └─ bacteria.n.01
#           └─ microorganism.n.01
#             └─ organism.n.01
#               └─ living_thing.n.01
#                 └─ whole.n.02
#                   └─ object.n.01
#                     └─ physical_entity.n.01
#                       └─ entity.n.01
#
# WORD: 'france'
#   Definition: a republic in western Europe; the largest country wholly in Europe
#   Example: No example
#
#   HYPERNYMS: None found
#
#   HYPONYMS: None found
#
#   HIERARCHY PATH (up to root):
#     └─ france.n.01
#
# WORD: 'call'
#   Definition: a telephone connection
#   Example: ['she reported several anonymous calls', 'he placed a phone call to London', "he heard the phone ringing but didn't want to take the call"]
#
#   HYPERNYMS (more general): 1 found
#     → telephone.n.02
#       Definition: transmitting speech at a distance
#         ↑ telecommunication.n.01: (often plural) systems used in transmitting messages over a distance electronically
#
#   HYPONYMS (more specific): 8 found
#     → local_call.n.01
#       Definition: a telephone call made within a local calling area
#     → call-in.n.01
#       Definition: a telephone call to a radio station or a television station in which the caller participates in the on-going program
#     → conference_call.n.01
#       Definition: a telephone call in which more than two people participate
#     → collect_call.n.01
#       Definition: a telephone call that the receiving party is asked to pay for
#     → call-back.n.01
#       Definition: a return call
#     → crank_call.n.01
#       Definition: a hostile telephone call (from a crank)
#     → wake-up_call.n.02
#       Definition: a telephone call that you request be made a specific time in order to wake you up at that time (especially in hotels)
#     → long_distance.n.01
#       Definition: a telephone call made outside the local calling area
#
#   HIERARCHY PATH (up to root):
#     └─ call.n.01
#       └─ telephone.n.02
#         └─ telecommunication.n.01
#           └─ medium.n.01
#             └─ instrumentality.n.03
#               └─ artifact.n.01
#                 └─ whole.n.02
#                   └─ object.n.01
#                     └─ physical_entity.n.01
#                       └─ entity.n.01
#
# WORD: 'k'
#   Definition: the basic unit of thermodynamic temperature adopted under the Systeme International d'Unites
#   Example: No example
#
#   HYPERNYMS (more general): 1 found
#     → temperature_unit.n.01
#       Definition: a unit of measurement for temperature
#         ↑ unit_of_measurement.n.01: any division of quantity accepted as a standard of measurement or exchange
#
#   HYPONYMS: None found
#
#   HIERARCHY PATH (up to root):
#     └─ kelvin.n.01
#       └─ temperature_unit.n.01
#         └─ unit_of_measurement.n.01
#           └─ definite_quantity.n.01
#             └─ measure.n.02
#               └─ abstraction.n.06
#                 └─ entity.n.01
#
# WORD: 'people'
#   Definition: (plural) any group of human beings (men or women or children) collectively
#   Example: ['old people', 'there were at least 200 people in the audience']
#
#   HYPERNYMS (more general): 1 found
#     → group.n.01
#       Definition: any number of entities (members) considered as a unit
#         ↑ abstraction.n.06: a general concept formed by extracting common features from specific examples
#
#   HYPONYMS (more specific): 48 found
#     → mentally_retarded.n.01
#       Definition: people collectively who are mentally retarded
#     → damned.n.01
#       Definition: people who are condemned to eternal punishment
#     → populace.n.01
#       Definition: people in general considered as a whole
#     → retreated.n.01
#       Definition: people who have retreated
#     → nation.n.02
#       Definition: the people who live in a nation or country
#     → network_army.n.01
#       Definition: a group of like-minded people united by the internet; a new kind of social or political of business group that may exert broad influence on a shared concern
#     → free.n.01
#       Definition: people who are free
#     → baffled.n.01
#       Definition: people who are frustrated and perplexed
#     → wounded.n.01
#       Definition: people who are wounded
#     → uninitiate.n.01
#       Definition: people who have not been introduced to the mysteries of some field or activity
#     → chosen_people.n.01
#       Definition: any people believing themselves to be chosen by God
#     → tradespeople.n.01
#       Definition: people engaged in trade
#     → coevals.n.01
#       Definition: all the people living at the same time or of approximately the same age
#     → episcopacy.n.01
#       Definition: the collective body of bishops
#     → dead.n.01
#       Definition: people who are no longer living
#     → pocket.n.07
#       Definition: a small isolated group of people
#     → brave.n.02
#       Definition: people who are brave
#     → homebound.n.01
#       Definition: people who are confined to their homes
#     → migration.n.02
#       Definition: a group of people migrating together (especially in some given time period)
#     → doomed.n.01
#       Definition: people who are destined to die soon
#     → business_people.n.01
#       Definition: people who transact business (especially business executives)
#     → rank_and_file.n.02
#       Definition: people who constitute the main body of any group
#     → timid.n.01
#       Definition: people who are fearful and cautious
#     → ancients.n.01
#       Definition: people who lived in times long past (especially during the historical period before the fall of the Roman Empire in western Europe)
#     → womankind.n.01
#       Definition: women as distinguished from men
#     → disabled.n.01
#       Definition: people collectively who are crippled or otherwise physically handicapped
#     → smart_money.n.03
#       Definition: people who are highly experienced or who have inside information
#     → living.n.02
#       Definition: people who are still living
#     → initiate.n.03
#       Definition: people who have been introduced to the mysteries of some field or activity
#     → folk.n.01
#       Definition: people in general (often used in the plural)
#     → deaf.n.01
#       Definition: people who have severe hearing impairments
#     → defeated.n.01
#       Definition: people who are defeated
#     → peanut_gallery.n.01
#       Definition: (figurative) people whose criticisms are regarded as irrelevant or insignificant (resembling uneducated people who throw peanuts on the stage to express displeasure with a performance)
#     → unconfessed.n.01
#       Definition: people who have not confessed
#     → poor_people.n.01
#       Definition: people without possessions or wealth (considered as a group)
#     → lobby.n.02
#       Definition: the people who support some common cause or business or principle or sectional interest
#     → blind.n.01
#       Definition: people who have severe visual impairments, considered as a group
#     → sick.n.01
#       Definition: people who are sick
#     → rich_people.n.01
#       Definition: people who have possessions and wealth (considered as a group)
#     → nationality.n.01
#       Definition: people having common origins or traditions and often comprising a nation
#     → population.n.01
#       Definition: the people who inhabit a territory or state
#     → unemployed_people.n.01
#       Definition: people who are involuntarily out of work (considered as a group)
#     → peoples.n.01
#       Definition: the human beings of a particular nation or community or ethnic group
#     → age_group.n.01
#       Definition: a group of people having approximately the same age
#     → blood.n.05
#       Definition: people viewed as members of a group
#     → clientele.n.01
#       Definition: customers collectively
#     → class.n.03
#       Definition: people having the same social, economic, or educational status
#     → enemy.n.03
#       Definition: any hostile group of people
#
#   HIERARCHY PATH (up to root):
#     └─ people.n.01
#       └─ group.n.01
#         └─ abstraction.n.06
#           └─ entity.n.01
#
# WORD: 'deck'
#   Definition: any of various platforms built into a vessel
#   Example: No example
#
#   HYPERNYMS (more general): 1 found
#     → platform.n.01
#       Definition: a raised horizontal surface
#         ↑ horizontal_surface.n.01: a flat surface at right angles to a plumb line
#
#   HYPONYMS (more specific): 11 found
#     → orlop_deck.n.01
#       Definition: the fourth or lowest deck
#     → flight_deck.n.01
#       Definition: the upper deck of an aircraft carrier; used as a runway
#     → gun_deck.n.01
#       Definition: formerly any deck other than the weather deck having cannons from end to end
#     → main_deck.n.01
#       Definition: the uppermost sheltered deck that runs the entire length of a large vessel
#     → quarterdeck.n.01
#       Definition: the stern area of a ship's upper deck
#     → lower_deck.n.01
#       Definition: the deck below the main deck
#     → upper_deck.n.01
#       Definition: a higher deck
#     → hurricane_deck.n.01
#       Definition: a deck at the top of a passenger ship
#     → afterdeck.n.01
#       Definition: a deck abaft of midships
#     → foredeck.n.01
#       Definition: the deck between the bridge and the forecastle
#     → lido_deck.n.01
#       Definition: an open deck including a swimming pool
#
#   HIERARCHY PATH (up to root):
#     └─ deck.n.01
#       └─ platform.n.01
#         └─ horizontal_surface.n.01
#           └─ surface.n.01
#             └─ artifact.n.01
#               └─ whole.n.02
#                 └─ object.n.01
#                   └─ physical_entity.n.01
#                     └─ entity.n.01
#
# WORD: 'q'
#   Definition: the 17th letter of the Roman alphabet
#   Example: No example
#
#   HYPERNYMS (more general): 1 found
#     → letter.n.02
#       Definition: the conventional characters of the alphabet used to represent speech
#         ↑ character.n.08: a written symbol that is used to represent speech
#
#   HYPONYMS: None found
#
#   HIERARCHY PATH (up to root):
#     └─ q.n.01
#       └─ letter.n.02
#         └─ character.n.08
#           └─ written_symbol.n.01
#             └─ symbol.n.01
#               └─ signal.n.01
#                 └─ communication.n.02
#                   └─ abstraction.n.06
#                     └─ entity.n.01
#
# WORD: 'calendlycomstartupceomin'
#   No synsets found for 'calendlycomstartupceomin'
#
# WORD: 'app'
#   No synsets found for 'app'
#
# WORD: 'launched'
#   Definition: set up or found
#   Example: ['She set up a literacy program']
#
#   HYPERNYMS (more general): 1 found
#     → open.v.02
#       Definition: start to operate or function or cause to start operating or functioning
#
#   HYPONYMS: None found
#
#   HIERARCHY PATH (up to root):
#     └─ establish.v.01
#       └─ open.v.02
#
# WORD: 'expanded'
#   Definition: extend in one or more directions
#   Example: ['The dough expands']
#
#   HYPERNYMS (more general): 1 found
#     → grow.v.02
#       Definition: become larger, greater, or bigger; expand or gain
#         ↑ increase.v.01: become bigger or greater in amount
#
#   HYPONYMS (more specific): 2 found
#     → bush_out.v.01
#       Definition: grow outward
#     → dispread.v.01
#       Definition: spread abroad or out
#
#   HIERARCHY PATH (up to root):
#     └─ expand.v.01
#       └─ grow.v.02
#         └─ increase.v.01
#           └─ change_magnitude.v.01
#             └─ change.v.02
#
# WORD: 'growth'
#   Definition: (biology) the process of an individual organism growing organically; a purely biological unfolding of events involved in an organism changing gradually from a simple to a more complex level
#   Example: ['he proposed an indicator of osseous development in children']
#
#   HYPERNYMS (more general): 1 found
#     → organic_process.n.01
#       Definition: a process occurring in living organisms
#         ↑ process.n.06: a sustained phenomenon or one marked by gradual changes through a series of states
#
#   HYPONYMS (more specific): 34 found
#     → infructescence.n.01
#       Definition: the fruiting stage of the inflorescence
#     → intussusception.n.02
#       Definition: (biology) growth in the surface area of a cell by the deposit of new particles between existing particles in the cell wall
#     → apposition.n.02
#       Definition: (biology) growth in the thickness of a cell wall by the deposit of successive layers of material
#     → cytogenesis.n.01
#       Definition: the origin and development and variation of cells
#     → cenogenesis.n.01
#       Definition: introduction during embryonic development of characters or structure not present in the earlier evolutionary history of the strain or species (such as the addition of the placenta in mammalian evolution)
#     → myelinization.n.01
#       Definition: the development of a myelin sheath around a nerve fiber
#     → angiogenesis.n.01
#       Definition: the formation of new blood vessels
#     → amelogenesis.n.01
#       Definition: the developmental process of forming tooth enamel
#     → cultivation.n.04
#       Definition: the process of fostering the growth of something
#     → teething.n.01
#       Definition: the eruption through the gums of baby teeth
#     → culture.n.04
#       Definition: (biology) the growing of microorganisms in a nutrient medium (such as gelatin or agar)
#     → life_cycle.n.02
#       Definition: the course of developmental changes in an organism from fertilized zygote to maturity when another zygote can be produced
#     → morphogenesis.n.01
#       Definition: differentiation and growth of the structure of an organism (or a part of an organism)
#     → blossoming.n.01
#       Definition: the time and process of budding and unfolding of blossoms
#     → proliferation.n.01
#       Definition: growth by the rapid multiplication of parts
#     → cohesion.n.02
#       Definition: (botany) the process in some plants of parts growing together that are usually separate (such as petals)
#     → psychomotor_development.n.01
#       Definition: progressive acquisition of skills involving both mental and motor activities
#     → vegetation.n.02
#       Definition: the process of growth in plants
#     → psychosexual_development.n.01
#       Definition: (psychoanalysis) the process during which personality and sexual behavior mature through a series of stages: first oral stage and then anal stage and then phallic stage and then latency stage and finally genital stage
#     → juvenescence.n.01
#       Definition: the process of growing into a youth
#     → habit.n.04
#       Definition: the general form or mode of growth (especially of a plant or crystal)
#     → teratogenesis.n.01
#       Definition: the development of defects in an embryo
#     → psychogenesis.n.01
#       Definition: the development in the life of an individual of some disorder that is caused by psychological rather than physiological factors
#     → foliation.n.01
#       Definition: (botany) the process of forming leaves
#     → fructification.n.01
#       Definition: the bearing of fruit
#     → neurogenesis.n.01
#       Definition: the development of nerve tissues
#     → rooting.n.01
#       Definition: the process of putting forth roots and beginning to grow
#     → masculinization.n.01
#       Definition: the abnormal development of male sexual characteristics in a female (usually as the result of hormone therapies or adrenal malfunction)
#     → suppression.n.01
#       Definition: the failure to develop some part or organ
#     → psychogenesis.n.02
#       Definition: a general term for the origin and development of almost any aspect of the mind
#     → auxesis.n.01
#       Definition: growth from increase in cell size without cell division
#     → gametogenesis.n.01
#       Definition: the development and maturation of sex cells through meiosis
#     → germination.n.01
#       Definition: the process whereby seeds or spores sprout and begin to grow
#     → palingenesis.n.01
#       Definition: emergence during embryonic development of various characters or structures that appeared during the evolutionary history of the strain or species
#
#   HIERARCHY PATH (up to root):
#     └─ growth.n.01
#       └─ organic_process.n.01
#         └─ process.n.06
#           └─ physical_entity.n.01
#             └─ entity.n.01
#
# WORD: 'valuation'
#   Definition: an appraisal of the value of something
#   Example: ['he set a high valuation on friendship']
#
#   HYPERNYMS (more general): 1 found
#     → appraisal.n.01
#       Definition: the classification of someone or something with respect to its worth
#         ↑ classification.n.03: the basic cognitive process of arranging into classes or categories
#
#   HYPONYMS (more specific): 6 found
#     → pricing.n.01
#       Definition: the evaluation of something in terms of its price
#     → reevaluation.n.01
#       Definition: the evaluation of something a second time (or more)
#     → bond_rating.n.01
#       Definition: an evaluation by a rating company of the probability that a particular bond issue will default
#     → mark.n.01
#       Definition: a number or letter indicating quality (especially of a student's performance)
#     → overvaluation.n.02
#       Definition: too high a value or price assigned to something
#     → undervaluation.n.01
#       Definition: too low a value or price assigned to something
#
#   HIERARCHY PATH (up to root):
#     └─ evaluation.n.02
#       └─ appraisal.n.01
#         └─ classification.n.03
#           └─ basic_cognitive_process.n.01
#             └─ process.n.02
#               └─ cognition.n.01
#                 └─ psychological_feature.n.01
#                   └─ abstraction.n.06
#                     └─ entity.n.01
#
# DETAILED EXAMPLE FOR KEY WORDS FROM TEXT
#
# DEEP ANALYSIS FOR: 'apple'
#   Definition: fruit with red or yellow or green skin and sweet to tart crisp whitish flesh
#   Lemmas: ['apple']
#
#   All Hypernym Paths:
#     Path 1: entity -> physical_entity -> object -> whole -> natural_object -> plant_part -> plant_organ -> reproductive_structure -> fruit -> pome -> apple
#     Path 2: entity -> physical_entity -> object -> whole -> natural_object -> plant_part -> plant_organ -> reproductive_structure -> fruit -> edible_fruit -> apple
#     Path 3: entity -> physical_entity -> matter -> solid -> food -> produce -> edible_fruit -> apple
#
#   Total hyponyms found: 3
#   All hyponyms:
#     - cooking_apple.n.01: an apple used primarily in cooking for pies and applesauce etc
#     - eating_apple.n.01: an apple used primarily for eating raw without cooking
#     - crab_apple.n.03: small sour apple; suitable for preserving
#
# DEEP ANALYSIS FOR: 'computer'
#   Definition: a machine for performing calculations automatically
#   Lemmas: ['computer', 'computing_machine', 'computing_device', 'data_processor', 'electronic_computer', 'information_processing_system']
#
#   All Hypernym Paths:
#     Path 1: entity -> physical_entity -> object -> whole -> artifact -> instrumentality -> device -> machine -> computer
#
#   Total hyponyms found: 10
#   All hyponyms:
#     - home_computer.n.01: a computer intended for use in the home
#     - pari-mutuel_machine.n.01: computer that registers bets and divides the total amount bet among those who won
#     - node.n.08: (computer science) any computer that is hooked up to a computer network
#     - digital_computer.n.01: a computer that represents information by numerical (binary) digits
#     - web_site.n.01: a computer connected to the internet that maintains a series of web pages on the World Wide Web
#     - turing_machine.n.01: a hypothetical computer with an infinitely long memory tape
#     - number_cruncher.n.02: a computer capable of performing a large number of mathematical operations per second
#     - predictor.n.03: a computer for controlling antiaircraft fire that computes the position of an aircraft at the instant of a shell's arrival
#     - server.n.03: (computer science) a computer that provides client stations with access to files and printers as shared resources to a computer network
#     - analog_computer.n.01: a computer that represents information by variable quantities (e.g., positions or voltages)
#
# DEEP ANALYSIS FOR: 'company'
#   Definition: an institution created to conduct business
#   Lemmas: ['company']
#
#   All Hypernym Paths:
#     Path 1: entity -> abstraction -> group -> social_group -> organization -> institution -> company
#
#   Total hyponyms found: 36
#   All hyponyms:
#     - shipper.n.02: a company in the business of shipping freight
#     - service.n.04: a company or agency that performs a public service; subject to government regulation
#     - limited_company.n.01: a company that is organized to give its owners limited liability
#     - livery_company.n.01: one of the chartered companies of London originating with the craft guilds
#     - record_company.n.01: a company that makes and sells musical recordings
#     - electronics_company.n.01: a company that makes and sells electronic instruments
#     - subsidiary_company.n.01: a company that is completely controlled by another company
#     - corporate_investor.n.01: a company that invests in (acquires control of) other companies
#     - car_company.n.01: a company that makes and sells automobiles
#     - packaging_company.n.01: a company that packages goods for sale or shipment or storage
#     - holding_company.n.01: a company with controlling shares in other companies
#     - target_company.n.01: a company that has been chosen as attractive for takeover by a potential acquirer
#     - east_india_company.n.01: an English company formed in 1600 to develop trade with the new British colonies in India and southeastern Asia; in the 18th century it assumed administrative control of Bengal and held it until the British army took over in 1858 after the Indian Mutiny
#     - oil_company.n.01: a company that sells oil
#     - bureau_de_change.n.01: (French) an establishment where you can exchange foreign money
#     - broadcasting_company.n.01: a company that manages tv or radio stations
#     - furniture_company.n.01: a company that sells furniture
#     - dot-com.n.01: a company that operates its business primarily on the internet using a URL that ends in `.com'
#     - closed_shop.n.01: a company that hires only union members
#     - think_tank.n.01: a company that does research for hire and issues reports on the implications
#     - shipping_company.n.01: a company that provides shipping services
#     - steel_company.n.01: a company that makes and sells steel
#     - transportation_company.n.01: a company providing transportation
#     - food_company.n.01: a company that processes and sells food
#     - mover.n.04: a company that moves the possessions of a family or business from one site to another
#     - open_shop.n.01: a company whose workers are hired without regard to their membership in a labor union
#     - union_shop.n.01: a company allowed to hire nonunion workers on the condition that they will join the union within a specified time
#     - pipeline_company.n.01: a company that operates oil pipelines for the oil industry
#     - joint-stock_company.n.01: a company (usually unincorporated) which has the capital of its members pooled in a common fund; transferable shares represent ownership interest; shareholders are legally liable for all debts of the company
#     - mining_company.n.01: a company that owns and manages mines
#     - white_knight.n.01: a company that is a friendly acquirer in a takeover
#     - printing_concern.n.01: a company that does commercial printing
#     - stock_company.n.01: a company whose capital is represented by stock
#     - film_company.n.01: a company that makes, advertises, and distributes movies
#     - distributor.n.03: a company that markets merchandise
#     - drug_company.n.01: a company that makes and sells pharmaceuticals
#
# DEEP ANALYSIS FOR: 'inventor'
#   Definition: someone who is the first to think of or make something
#   Lemmas: ['inventor', 'discoverer', 'artificer']
#
#   All Hypernym Paths:
#     Path 1: entity -> physical_entity -> causal_agent -> person -> creator -> inventor
#     Path 2: entity -> physical_entity -> object -> whole -> living_thing -> organism -> person -> creator -> inventor
#
#   Total hyponyms found: 1
#   All hyponyms:
#     - patentee.n.01: the inventor to whom a patent is issued
#
# DEEP ANALYSIS FOR: 'founder'
#   Definition: inflammation of the laminated tissue that attaches the hoof to the foot of a horse
#   Lemmas: ['laminitis', 'founder']
#
#   All Hypernym Paths:
#     Path 1: entity -> abstraction -> psychological_feature -> cognition -> information -> evidence -> symptom -> inflammation -> laminitis
#
#   Total hyponyms found: 0
#
# DEEP ANALYSIS FOR: 'ceo'
#   Definition: the corporate executive responsible for the operations of the firm; reports to a board of directors; may appoint other managers (including a president)
#   Lemmas: ['chief_executive_officer', 'CEO', 'chief_operating_officer']
#
#   All Hypernym Paths:
#     Path 1: entity -> physical_entity -> causal_agent -> person -> leader -> head -> administrator -> executive -> corporate_executive -> chief_executive_officer
#     Path 2: entity -> physical_entity -> object -> whole -> living_thing -> organism -> person -> leader -> head -> administrator -> executive -> corporate_executive -> chief_executive_officer
#
#   Total hyponyms found: 0
#
# DEEP ANALYSIS FOR: 'pixar'
#
# DEEP ANALYSIS FOR: 'next'
#   Definition: immediately following in time or order
#   Lemmas: ['following', 'next']
#
#   All Hypernym Paths:
#     Path 1: following
#
#   Total hyponyms found: 0

# %% [markdown]
# # Summary of All Operations

# %%
# Cell 15: Summary of All Operations
print("SUMMARY OF ALL OPERATIONS PERFORMED")

print(f"1. CLEANING:")
print(f"   - Original text length: {len(raw_text)} characters")
print(f"   - Cleaned text length: {len(text_cleaned)} characters")
print(f"   - Characters removed: {len(raw_text) - len(text_cleaned)}")

print(f"\n2. LOWERCASING:")
print(f"   - Original text length: {len(text_cleaned)} characters")
print(f"   - Lowercased text length: {len(text_lower)} characters")

print(f"\n3. PUNCTUATION REMOVAL:")
print(f"   - Before removal: {len(text_lower)} characters")
print(f"   - After removal: {len(text_no_punct)} characters")
print(f"   - Punctuation removed: {len(text_lower) - len(text_no_punct)}")

print(f"\n4. STOPWORD REMOVAL:")
print(f"   - Tokens before: {len(tokens)}")
print(f"   - Tokens after: {len(filtered_tokens)}")
print(f"   - Stopwords removed: {len(tokens) - len(filtered_tokens)}")

print(f"\n5. TOKENIZATION:")
print(f"   - Number of sentences: {len(sentences)}")
print(f"   - Number of words: {len(words)}")
print(f"   - Number of characters (no spaces): {len(chars)}")

print(f"\n6. STEMMING:")
print(f"   - Original tokens: {len(filtered_tokens)}")
print(f"   - Porter stemmed tokens: {len(porter_stemmed_tokens)}")
print(f"   - Snowball stemmed tokens: {len(snowball_stemmed_tokens)}")

print(f"\n7. LEMMATIZATION:")
print(f"   - Original tokens: {len(filtered_tokens)}")
print(f"   - Lemmatized tokens: {len(lemmatized_tokens)}")

print(f"\n8. POS TAGGING:")
print(f"   - Number of words tagged: {len(pos_tagged)}")

print(f"\n9. CHUNKING:")
print(f"   - Processed all sentences: {len(all_sentences)} sentences")

print(f"\n10. PARSING:")
print(f"    - Dependency parsing: Complete text processed (Full output shown)")
print(f"    - Tree parsing: All sentences processed (Full output shown)")

print(f"\n11. HYPERNYMS & HYPONYMS:")
print(f"    - Unique words analyzed: {len(unique_words)} words")
print(f"    - Key words analyzed: {len(key_words)} words")
# Out:
# SUMMARY OF ALL OPERATIONS PERFORMED
# 1. CLEANING:
#    - Original text length: 539 characters
#    - Cleaned text length: 456 characters
#    - Characters removed: 83
#
# 2. LOWERCASING:
#    - Original text length: 456 characters
#    - Lowercased text length: 456 characters
#
# 3. PUNCTUATION REMOVAL:
#    - Before removal: 456 characters
#    - After removal: 440 characters
#    - Punctuation removed: 16
#
# 4. STOPWORD REMOVAL:
#    - Tokens before: 17
#    - Tokens after: 47
#    - Stopwords removed: -30
#
# 5. TOKENIZATION:
#    - Number of sentences: 2
#    - Number of words: 69
#    - Number of characters (no spaces): 380
#
# 6. STEMMING:
#    - Original tokens: 47
#    - Porter stemmed tokens: 47
#    - Snowball stemmed tokens: 47
#
# 7. LEMMATIZATION:
#    - Original tokens: 47
#    - Lemmatized tokens: 47
#
# 8. POS TAGGING:
#    - Number of words tagged: 47
#
# 9. CHUNKING:
#    - Processed all sentences: 2 sentences
#
# 10. PARSING:
#     - Dependency parsing: Complete text processed (Full output shown)
#     - Tree parsing: All sentences processed (Full output shown)
#
# 11. HYPERNYMS & HYPONYMS:
#     - Unique words analyzed: 47 words
#     - Key words analyzed: 8 words
