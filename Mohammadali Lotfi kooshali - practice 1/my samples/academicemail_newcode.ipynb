# %% [markdown]
# # practice one

# %% [markdown]
# # mabahese vizhe

# %% [markdown]
# # Mohammadali Lotfi kooshali      -        404198471

# %% [markdown]
# # install , download and import libraries

# %%
# !pip install spacy nltk
# !python -m spacy download en_core_web_sm

import re
import spacy
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize, sent_tokenize
from nltk.stem import PorterStemmer, WordNetLemmatizer, SnowballStemmer
from nltk import pos_tag
from nltk.corpus import wordnet as wn
from string import punctuation
from nltk.chunk import RegexpParser
from nltk import Tree
import time

# Download required NLTK data
nltk.download('punkt')
nltk.download('stopwords')
nltk.download('wordnet')
nltk.download('averaged_perceptron_tagger')
nltk.download('omw-1.4')

# Load spaCy model
nlp = spacy.load("en_core_web_sm")
# Out:
# Requirement already satisfied: spacy in D:\.venv\Lib\site-packages (3.8.14)
# Requirement already satisfied: nltk in D:\.venv\Lib\site-packages (3.9.4)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in D:\.venv\Lib\site-packages (from spacy) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in D:\.venv\Lib\site-packages (from spacy) (1.0.0)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in D:\.venv\Lib\site-packages (from spacy) (1.0.10)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in D:\.venv\Lib\site-packages (from spacy) (2.0.13)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in D:\.venv\Lib\site-packages (from spacy) (3.0.13)
# Requirement already satisfied: thinc<8.4.0,>=8.3.12 in D:\.venv\Lib\site-packages (from spacy) (8.3.13)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in D:\.venv\Lib\site-packages (from spacy) (0.10.1)
# Requirement already satisfied: srsly<3.0.0,>=2.5.3 in D:\.venv\Lib\site-packages (from spacy) (2.5.3)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in D:\.venv\Lib\site-packages (from spacy) (2.0.10)
# Requirement already satisfied: weasel<2.0.0,>=1.0.0 in D:\.venv\Lib\site-packages (from spacy) (1.0.0)
# Requirement already satisfied: confection<2.0.0,>=1.3.2 in D:\.venv\Lib\site-packages (from spacy) (1.3.3)
# Requirement already satisfied: typer<1.0.0,>=0.3.0 in D:\.venv\Lib\site-packages (from spacy) (0.23.1)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in D:\.venv\Lib\site-packages (from spacy) (4.67.3)
# Requirement already satisfied: numpy>=1.19.0 in D:\.venv\Lib\site-packages (from spacy) (2.3.5)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in D:\.venv\Lib\site-packages (from spacy) (2.32.5)
# Requirement already satisfied: pydantic<3.0.0,>=2.0.0 in D:\.venv\Lib\site-packages (from spacy) (2.12.5)
# Requirement already satisfied: jinja2 in D:\.venv\Lib\site-packages (from spacy) (3.1.6)
# Requirement already satisfied: setuptools in D:\.venv\Lib\site-packages (from spacy) (81.0.0)
# Requirement already satisfied: packaging>=20.0 in D:\.venv\Lib\site-packages (from spacy) (25.0)
# Requirement already satisfied: annotated-types>=0.6.0 in D:\.venv\Lib\site-packages (from pydantic<3.0.0,>=2.0.0->spacy) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in D:\.venv\Lib\site-packages (from pydantic<3.0.0,>=2.0.0->spacy) (2.41.5)
# Requirement already satisfied: typing-extensions>=4.14.1 in D:\.venv\Lib\site-packages (from pydantic<3.0.0,>=2.0.0->spacy) (4.15.0)
# Requirement already satisfied: typing-inspection>=0.4.2 in D:\.venv\Lib\site-packages (from pydantic<3.0.0,>=2.0.0->spacy) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in D:\.venv\Lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in D:\.venv\Lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in D:\.venv\Lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (2.6.3)
# Requirement already satisfied: certifi>=2017.4.17 in D:\.venv\Lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (2026.1.4)
# Requirement already satisfied: blis<1.4.0,>=1.3.0 in D:\.venv\Lib\site-packages (from thinc<8.4.0,>=8.3.12->spacy) (1.3.3)
# Requirement already satisfied: colorama in D:\.venv\Lib\site-packages (from tqdm<5.0.0,>=4.38.0->spacy) (0.4.6)
# Requirement already satisfied: click>=8.0.0 in D:\.venv\Lib\site-packages (from typer<1.0.0,>=0.3.0->spacy) (8.3.1)
# Requirement already satisfied: shellingham>=1.3.0 in D:\.venv\Lib\site-packages (from typer<1.0.0,>=0.3.0->spacy) (1.5.4)
# Requirement already satisfied: rich>=10.11.0 in D:\.venv\Lib\site-packages (from typer<1.0.0,>=0.3.0->spacy) (14.3.2)
# Requirement already satisfied: annotated-doc>=0.0.2 in D:\.venv\Lib\site-packages (from typer<1.0.0,>=0.3.0->spacy) (0.0.4)
# Requirement already satisfied: cloudpathlib>=0.7.0 in D:\.venv\Lib\site-packages (from weasel<2.0.0,>=1.0.0->spacy) (0.23.0)
# Requirement already satisfied: smart-open>=5.2.1 in D:\.venv\Lib\site-packages (from weasel<2.0.0,>=1.0.0->spacy) (7.6.0)
# Requirement already satisfied: httpx>=0.24.0 in D:\.venv\Lib\site-packages (from weasel<2.0.0,>=1.0.0->spacy) (0.28.1)
# Requirement already satisfied: joblib in D:\.venv\Lib\site-packages (from nltk) (1.5.3)
# Requirement already satisfied: regex>=2021.8.3 in D:\.venv\Lib\site-packages (from nltk) (2026.1.15)
# Requirement already satisfied: anyio in D:\.venv\Lib\site-packages (from httpx>=0.24.0->weasel<2.0.0,>=1.0.0->spacy) (4.12.1)
# Requirement already satisfied: httpcore==1.* in D:\.venv\Lib\site-packages (from httpx>=0.24.0->weasel<2.0.0,>=1.0.0->spacy) (1.0.9)
# Requirement already satisfied: h11>=0.16 in D:\.venv\Lib\site-packages (from httpcore==1.*->httpx>=0.24.0->weasel<2.0.0,>=1.0.0->spacy) (0.16.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in D:\.venv\Lib\site-packages (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in D:\.venv\Lib\site-packages (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in D:\.venv\Lib\site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy) (0.1.2)
# Requirement already satisfied: wrapt in D:\.venv\Lib\site-packages (from smart-open>=5.2.1->weasel<2.0.0,>=1.0.0->spacy) (2.1.2)
# Requirement already satisfied: MarkupSafe>=2.0 in D:\.venv\Lib\site-packages (from jinja2->spacy) (3.0.3)
#   WARNING: Retrying (Retry(total=4, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ProtocolError('Connection aborted.', ConnectionResetError(10054, 'An existing connection was forcibly closed by the remote host', None, 10054, None))': /github-production-release-asset/84940268/15132ab6-4050-4914-8fe8-ac2c2fdcb9cf?sp=r&sv=2018-11-09&sr=b&spr=https&se=2026-04-27T22%3A10%3A32Z&rscd=attachment%3B+filename%3Den_core_web_sm-3.8.0-py3-none-any.whl&rsct=application%2Foctet-stream&skoid=96c2d410-5711-43a1-aedd-ab1947aa7ab0&sktid=398a6654-997b-47e9-b12b-9515b896b4de&skt=2026-04-27T21%3A09%3A40Z&ske=2026-04-27T22%3A10%3A32Z&sks=b&skv=2018-11-09&sig=%2BaEUtnICkX9qtZ6miK%2B%2BJCUHR%2FX6MGCuWEd75UkmxcE%3D&jwt=eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9.eyJpc3MiOiJnaXRodWIuY29tIiwiYXVkIjoicmVsZWFzZS1hc3NldHMuZ2l0aHVidXNlcmNvbnRlbnQuY29tIiwia2V5Ijoia2V5MSIsImV4cCI6MTc3NzMyNjgzMiwibmJmIjoxNzc3MzI1MDMyLCJwYXRoIjoicmVsZWFzZWFzc2V0cHJvZHVjdGlvbi5ibG9iLmNvcmUud2luZG93cy5uZXQifQ.b9zCC-gE8jq_-Fl5Ngg-6seo9jcMZrLpn8v_lxeNPkk&response-content-disposition=attachment%3B%20filename%3Den_core_web_sm-3.8.0-py3-none-any.whl&response-content-type=application%2Foctet-stream
#   WARNING: Retrying (Retry(total=3, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ProtocolError('Connection aborted.', ConnectionResetError(10054, 'An existing connection was forcibly closed by the remote host', None, 10054, None))': /github-production-release-asset/84940268/15132ab6-4050-4914-8fe8-ac2c2fdcb9cf?sp=r&sv=2018-11-09&sr=b&spr=https&se=2026-04-27T22%3A10%3A32Z&rscd=attachment%3B+filename%3Den_core_web_sm-3.8.0-py3-none-any.whl&rsct=application%2Foctet-stream&skoid=96c2d410-5711-43a1-aedd-ab1947aa7ab0&sktid=398a6654-997b-47e9-b12b-9515b896b4de&skt=2026-04-27T21%3A09%3A40Z&ske=2026-04-27T22%3A10%3A32Z&sks=b&skv=2018-11-09&sig=%2BaEUtnICkX9qtZ6miK%2B%2BJCUHR%2FX6MGCuWEd75UkmxcE%3D&jwt=eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9.eyJpc3MiOiJnaXRodWIuY29tIiwiYXVkIjoicmVsZWFzZS1hc3NldHMuZ2l0aHVidXNlcmNvbnRlbnQuY29tIiwia2V5Ijoia2V5MSIsImV4cCI6MTc3NzMyNjgzMiwibmJmIjoxNzc3MzI1MDMyLCJwYXRoIjoicmVsZWFzZWFzc2V0cHJvZHVjdGlvbi5ibG9iLmNvcmUud2luZG93cy5uZXQifQ.b9zCC-gE8jq_-Fl5Ngg-6seo9jcMZrLpn8v_lxeNPkk&response-content-disposition=attachment%3B%20filename%3Den_core_web_sm-3.8.0-py3-none-any.whl&response-content-type=application%2Foctet-stream
#   WARNING: Retrying (Retry(total=2, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ProtocolError('Connection aborted.', ConnectionResetError(10054, 'An existing connection was forcibly closed by the remote host', None, 10054, None))': /github-production-release-asset/84940268/15132ab6-4050-4914-8fe8-ac2c2fdcb9cf?sp=r&sv=2018-11-09&sr=b&spr=https&se=2026-04-27T22%3A10%3A32Z&rscd=attachment%3B+filename%3Den_core_web_sm-3.8.0-py3-none-any.whl&rsct=application%2Foctet-stream&skoid=96c2d410-5711-43a1-aedd-ab1947aa7ab0&sktid=398a6654-997b-47e9-b12b-9515b896b4de&skt=2026-04-27T21%3A09%3A40Z&ske=2026-04-27T22%3A10%3A32Z&sks=b&skv=2018-11-09&sig=%2BaEUtnICkX9qtZ6miK%2B%2BJCUHR%2FX6MGCuWEd75UkmxcE%3D&jwt=eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9.eyJpc3MiOiJnaXRodWIuY29tIiwiYXVkIjoicmVsZWFzZS1hc3NldHMuZ2l0aHVidXNlcmNvbnRlbnQuY29tIiwia2V5Ijoia2V5MSIsImV4cCI6MTc3NzMyNjgzMiwibmJmIjoxNzc3MzI1MDMyLCJwYXRoIjoicmVsZWFzZWFzc2V0cHJvZHVjdGlvbi5ibG9iLmNvcmUud2luZG93cy5uZXQifQ.b9zCC-gE8jq_-Fl5Ngg-6seo9jcMZrLpn8v_lxeNPkk&response-content-disposition=attachment%3B%20filename%3Den_core_web_sm-3.8.0-py3-none-any.whl&response-content-type=application%2Foctet-stream
#   WARNING: Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ProtocolError('Connection aborted.', ConnectionResetError(10054, 'An existing connection was forcibly closed by the remote host', None, 10054, None))': /github-production-release-asset/84940268/15132ab6-4050-4914-8fe8-ac2c2fdcb9cf?sp=r&sv=2018-11-09&sr=b&spr=https&se=2026-04-27T22%3A10%3A32Z&rscd=attachment%3B+filename%3Den_core_web_sm-3.8.0-py3-none-any.whl&rsct=application%2Foctet-stream&skoid=96c2d410-5711-43a1-aedd-ab1947aa7ab0&sktid=398a6654-997b-47e9-b12b-9515b896b4de&skt=2026-04-27T21%3A09%3A40Z&ske=2026-04-27T22%3A10%3A32Z&sks=b&skv=2018-11-09&sig=%2BaEUtnICkX9qtZ6miK%2B%2BJCUHR%2FX6MGCuWEd75UkmxcE%3D&jwt=eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9.eyJpc3MiOiJnaXRodWIuY29tIiwiYXVkIjoicmVsZWFzZS1hc3NldHMuZ2l0aHVidXNlcmNvbnRlbnQuY29tIiwia2V5Ijoia2V5MSIsImV4cCI6MTc3NzMyNjgzMiwibmJmIjoxNzc3MzI1MDMyLCJwYXRoIjoicmVsZWFzZWFzc2V0cHJvZHVjdGlvbi5ibG9iLmNvcmUud2luZG93cy5uZXQifQ.b9zCC-gE8jq_-Fl5Ngg-6seo9jcMZrLpn8v_lxeNPkk&response-content-disposition=attachment%3B%20filename%3Den_core_web_sm-3.8.0-py3-none-any.whl&response-content-type=application%2Foctet-stream
#   WARNING: Retrying (Retry(total=0, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ProtocolError('Connection aborted.', ConnectionResetError(10054, 'An existing connection was forcibly closed by the remote host', None, 10054, None))': /github-production-release-asset/84940268/15132ab6-4050-4914-8fe8-ac2c2fdcb9cf?sp=r&sv=2018-11-09&sr=b&spr=https&se=2026-04-27T22%3A10%3A32Z&rscd=attachment%3B+filename%3Den_core_web_sm-3.8.0-py3-none-any.whl&rsct=application%2Foctet-stream&skoid=96c2d410-5711-43a1-aedd-ab1947aa7ab0&sktid=398a6654-997b-47e9-b12b-9515b896b4de&skt=2026-04-27T21%3A09%3A40Z&ske=2026-04-27T22%3A10%3A32Z&sks=b&skv=2018-11-09&sig=%2BaEUtnICkX9qtZ6miK%2B%2BJCUHR%2FX6MGCuWEd75UkmxcE%3D&jwt=eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9.eyJpc3MiOiJnaXRodWIuY29tIiwiYXVkIjoicmVsZWFzZS1hc3NldHMuZ2l0aHVidXNlcmNvbnRlbnQuY29tIiwia2V5Ijoia2V5MSIsImV4cCI6MTc3NzMyNjgzMiwibmJmIjoxNzc3MzI1MDMyLCJwYXRoIjoicmVsZWFzZWFzc2V0cHJvZHVjdGlvbi5ibG9iLmNvcmUud2luZG93cy5uZXQifQ.b9zCC-gE8jq_-Fl5Ngg-6seo9jcMZrLpn8v_lxeNPkk&response-content-disposition=attachment%3B%20filename%3Den_core_web_sm-3.8.0-py3-none-any.whl&response-content-type=application%2Foctet-stream
# ERROR: Could not install packages due to an OSError: HTTPSConnectionPool(host='release-assets.githubusercontent.com', port=443): Max retries exceeded with url: /github-production-release-asset/84940268/15132ab6-4050-4914-8fe8-ac2c2fdcb9cf?sp=r&sv=2018-11-09&sr=b&spr=https&se=2026-04-27T22%3A10%3A32Z&rscd=attachment%3B+filename%3Den_core_web_sm-3.8.0-py3-none-any.whl&rsct=application%2Foctet-stream&skoid=96c2d410-5711-43a1-aedd-ab1947aa7ab0&sktid=398a6654-997b-47e9-b12b-9515b896b4de&skt=2026-04-27T21%3A09%3A40Z&ske=2026-04-27T22%3A10%3A32Z&sks=b&skv=2018-11-09&sig=%2BaEUtnICkX9qtZ6miK%2B%2BJCUHR%2FX6MGCuWEd75UkmxcE%3D&jwt=eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9.eyJpc3MiOiJnaXRodWIuY29tIiwiYXVkIjoicmVsZWFzZS1hc3NldHMuZ2l0aHVidXNlcmNvbnRlbnQuY29tIiwia2V5Ijoia2V5MSIsImV4cCI6MTc3NzMyNjgzMiwibmJmIjoxNzc3MzI1MDMyLCJwYXRoIjoicmVsZWFzZWFzc2V0cHJvZHVjdGlvbi5ibG9iLmNvcmUud2luZG93cy5uZXQifQ.b9zCC-gE8jq_-Fl5Ngg-6seo9jcMZrLpn8v_lxeNPkk&response-content-disposition=attachment%3B%20filename%3Den_core_web_sm-3.8.0-py3-none-any.whl&response-content-type=application%2Foctet-stream (Caused by ProtocolError('Connection aborted.', ConnectionResetError(10054, 'An existing connection was forcibly closed by the remote host', None, 10054, None)))
# Collecting en-core-web-sm==3.8.0
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\ASUS\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\ASUS\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\ASUS\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     C:\Users\ASUS\AppData\Roaming\nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package omw-1.4 to
# [nltk_data]     C:\Users\ASUS\AppData\Roaming\nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!

# %% [markdown]
# # reading text file

# %%
with open('academic_email.txt', 'r', encoding='utf-8') as file:
    raw_text = file.read()

print("original text:")
print(raw_text)
print(f"Total characters: {len(raw_text)}")
# Out:
# original text:
# Dear Professor Williams,
#
# I hope this email finds you well. I am writing to request an extension for the NLP assignment (CS-534) due on December 10th.
#
# Due to unexpected technical issues with my local environment (PyCharm + Python 3.11), I couldn't complete the implementation of the transformer model.
#
# Could you please grant me an extension until December 13th? I have attached my current progress (file: transformer_implementation_v2.py).
#
# Thank you for your understanding.
#
# Sincerely,
# Michael Chen
# Student ID: 2024CS101
# michael.chen@university.edu
# Total characters: 552

# %% [markdown]
# # 1. Cleaning Text with re.sub

# %%
# Remove numbers
text_no_numbers = re.sub(r'\d+', '', raw_text)
print("After removing numbers:")
print(text_no_numbers)
print("-" * 80)

# Remove extra whitespaces
text_cleaned = re.sub(r'\s+', ' ', text_no_numbers)
print("After removing extra whitespaces:")
print(text_cleaned)
print("-" * 80)

# Remove special characters (keep letters, spaces, dots, commas)
text_cleaned = re.sub(r'[^\w\s\.\,]', '', text_cleaned)
print("After removing special characters:")
print(text_cleaned)
print(f"Cleaned text length: {len(text_cleaned)} characters")
# Out:
# After removing numbers:
# Dear Professor Williams,
#
# I hope this email finds you well. I am writing to request an extension for the NLP assignment (CS-) due on December th.
#
# Due to unexpected technical issues with my local environment (PyCharm + Python .), I couldn't complete the implementation of the transformer model.
#
# Could you please grant me an extension until December th? I have attached my current progress (file: transformer_implementation_v.py).
#
# Thank you for your understanding.
#
# Sincerely,
# Michael Chen
# Student ID: CS
# michael.chen@university.edu
# --------------------------------------------------------------------------------
# After removing extra whitespaces:
# Dear Professor Williams, I hope this email finds you well. I am writing to request an extension for the NLP assignment (CS-) due on December th. Due to unexpected technical issues with my local environment (PyCharm + Python .), I couldn't complete the implementation of the transformer model. Could you please grant me an extension until December th? I have attached my current progress (file: transformer_implementation_v.py). Thank you for your understanding. Sincerely, Michael Chen Student ID: CS michael.chen@university.edu
# --------------------------------------------------------------------------------
# After removing special characters:
# Dear Professor Williams, I hope this email finds you well. I am writing to request an extension for the NLP assignment CS due on December th. Due to unexpected technical issues with my local environment PyCharm  Python ., I couldnt complete the implementation of the transformer model. Could you please grant me an extension until December th I have attached my current progress file transformer_implementation_v.py. Thank you for your understanding. Sincerely, Michael Chen Student ID CS michael.chenuniversity.edu
# Cleaned text length: 515 characters

# %% [markdown]
# # 2. Lowercasing

# %%
text_lower = text_cleaned.lower()
print("Text after lowercasing:")
print(text_lower)
# Out:
# Text after lowercasing:
# dear professor williams, i hope this email finds you well. i am writing to request an extension for the nlp assignment cs due on december th. due to unexpected technical issues with my local environment pycharm  python ., i couldnt complete the implementation of the transformer model. could you please grant me an extension until december th i have attached my current progress file transformer_implementation_v.py. thank you for your understanding. sincerely, michael chen student id cs michael.chenuniversity.edu

# %% [markdown]
# # 3. Punctuation Removal

# %%
print("Punctuation removed:", punctuation)
text_no_punct = ''.join([char for char in text_lower if char not in punctuation])
print("Text after punctuation removal:")
print(text_no_punct)
# Out:
# Punctuation removed: !"#$%&'()*+,-./:;<=>?@[\]^_`{|}~
# Text after punctuation removal:
# dear professor williams i hope this email finds you well i am writing to request an extension for the nlp assignment cs due on december th due to unexpected technical issues with my local environment pycharm  python  i couldnt complete the implementation of the transformer model could you please grant me an extension until december th i have attached my current progress file transformerimplementationvpy thank you for your understanding sincerely michael chen student id cs michaelchenuniversityedu

# %% [markdown]
# # 4. Stopword Removal

# %%
# Get English stopwords
stop_words = set(stopwords.words('english'))
print("English stopwords :")
print(list(stop_words))

# Tokenize first
tokens = word_tokenize(text_no_punct)
print(f"Total tokens before stopword removal: {len(tokens)}")
print("tokens before removal:")
print(tokens)

# Remove stopwords
filtered_tokens = [word for word in tokens if word not in stop_words]
print(f"Total tokens after stopword removal: {len(filtered_tokens)}")
print("tokens after removal:")
print(filtered_tokens)

# Convert back to text
text_no_stopwords = ' '.join(filtered_tokens)
print("Complete text after stopword removal:")
print(text_no_stopwords)
# Out:
# English stopwords :
# ['about', "shouldn't", 'can', 'itself', 'own', 'why', 'during', 'wasn', 'myself', "hasn't", 'while', "she'd", 'there', 'against', 'not', 'as', 'at', 'she', "she'll", "wouldn't", "it'll", 'until', 'of', 'now', 're', 'both', 'yours', 'further', 'all', 'weren', "didn't", 'won', 'himself', 'having', 'than', 'her', "isn't", 'their', 'them', 'up', 'who', "it'd", "it's", "that'll", 'herself', 'being', 'that', 'yourselves', 'out', 'below', 'mustn', 'what', 'is', 'in', 'from', "won't", 'had', 'he', 'mightn', "we've", 'some', 'those', "i'd", 'it', 'couldn', 'themselves', 'haven', 'through', 'my', 'our', 'should', 'here', 'a', 'shouldn', "i'll", 'theirs', "hadn't", 'they', "she's", 'between', 'which', "they'll", "couldn't", 'his', 'same', 'am', 'very', 'whom', 'needn', 'do', 'doing', 'm', "we're", 'and', "you'd", 'an', 'if', 'was', 'don', 'after', 'how', "mightn't", 'you', 'into', 'once', 'for', 'me', 'only', 'any', 'under', 'to', "we'd", 'will', 'these', "wasn't", 'y', "i'm", 'has', "doesn't", 'over', 'doesn', 'with', 'no', 'where', 'down', 'so', "you'll", 'does', "he'll", "needn't", "you're", "should've", "weren't", 'd', 'ain', 'this', 'the', 'on', "haven't", 'been', 'did', 'just', 'aren', 'again', 'ours', 'your', 'ourselves', "they've", 'more', 've', "i've", "they're", "they'd", 'hadn', 'isn', 's', 'nor', 'other', "we'll", 'wouldn', "aren't", "don't", 'or', "shan't", 'then', 'we', 't', 'o', 'few', 'too', 'yourself', 'are', 'have', 'by', 'hasn', 'were', 'him', "mustn't", 'ma', 'hers', 'i', 'each', 'most', "he'd", 'because', 'but', 'above', 'shan', 'll', 'be', "he's", 'when', 'such', 'off', 'didn', "you've", 'before', 'its']
# Total tokens before stopword removal: 76
# tokens before removal:
# ['dear', 'professor', 'williams', 'i', 'hope', 'this', 'email', 'finds', 'you', 'well', 'i', 'am', 'writing', 'to', 'request', 'an', 'extension', 'for', 'the', 'nlp', 'assignment', 'cs', 'due', 'on', 'december', 'th', 'due', 'to', 'unexpected', 'technical', 'issues', 'with', 'my', 'local', 'environment', 'pycharm', 'python', 'i', 'couldnt', 'complete', 'the', 'implementation', 'of', 'the', 'transformer', 'model', 'could', 'you', 'please', 'grant', 'me', 'an', 'extension', 'until', 'december', 'th', 'i', 'have', 'attached', 'my', 'current', 'progress', 'file', 'transformerimplementationvpy', 'thank', 'you', 'for', 'your', 'understanding', 'sincerely', 'michael', 'chen', 'student', 'id', 'cs', 'michaelchenuniversityedu']
# Total tokens after stopword removal: 49
# tokens after removal:
# ['dear', 'professor', 'williams', 'hope', 'email', 'finds', 'well', 'writing', 'request', 'extension', 'nlp', 'assignment', 'cs', 'due', 'december', 'th', 'due', 'unexpected', 'technical', 'issues', 'local', 'environment', 'pycharm', 'python', 'couldnt', 'complete', 'implementation', 'transformer', 'model', 'could', 'please', 'grant', 'extension', 'december', 'th', 'attached', 'current', 'progress', 'file', 'transformerimplementationvpy', 'thank', 'understanding', 'sincerely', 'michael', 'chen', 'student', 'id', 'cs', 'michaelchenuniversityedu']
# Complete text after stopword removal:
# dear professor williams hope email finds well writing request extension nlp assignment cs due december th due unexpected technical issues local environment pycharm python couldnt complete implementation transformer model could please grant extension december th attached current progress file transformerimplementationvpy thank understanding sincerely michael chen student id cs michaelchenuniversityedu

# %% [markdown]
# # 5. Tokenization (Sentence, Word, Character)

# %%
# Sentence Tokenization
sentences = sent_tokenize(text_lower)
print("Sentence Tokenization:")
print(f"Total number of sentences: {len(sentences)}")
print("All sentences:")
for i, sent in enumerate(sentences, 1):
    print(f"{i}. {sent}")

# Word Tokenization
words = word_tokenize(text_lower)
print("Word Tokenization:")
print(f"Total number of words: {len(words)}")
print("All words:")
print(words)

# Character Tokenization
chars = [char for char in text_lower if char != ' ']
print("Character Tokenization:")
print(f"Total number of characters (without spaces): {len(chars)}")
print("All characters:")
print(chars)
# Out:
# Sentence Tokenization:
# Total number of sentences: 6
# All sentences:
# 1. dear professor williams, i hope this email finds you well.
# 2. i am writing to request an extension for the nlp assignment cs due on december th.
# 3. due to unexpected technical issues with my local environment pycharm  python ., i couldnt complete the implementation of the transformer model.
# 4. could you please grant me an extension until december th i have attached my current progress file transformer_implementation_v.py.
# 5. thank you for your understanding.
# 6. sincerely, michael chen student id cs michael.chenuniversity.edu
# Word Tokenization:
# Total number of words: 85
# All words:
# ['dear', 'professor', 'williams', ',', 'i', 'hope', 'this', 'email', 'finds', 'you', 'well', '.', 'i', 'am', 'writing', 'to', 'request', 'an', 'extension', 'for', 'the', 'nlp', 'assignment', 'cs', 'due', 'on', 'december', 'th', '.', 'due', 'to', 'unexpected', 'technical', 'issues', 'with', 'my', 'local', 'environment', 'pycharm', 'python', '.', ',', 'i', 'couldnt', 'complete', 'the', 'implementation', 'of', 'the', 'transformer', 'model', '.', 'could', 'you', 'please', 'grant', 'me', 'an', 'extension', 'until', 'december', 'th', 'i', 'have', 'attached', 'my', 'current', 'progress', 'file', 'transformer_implementation_v.py', '.', 'thank', 'you', 'for', 'your', 'understanding', '.', 'sincerely', ',', 'michael', 'chen', 'student', 'id', 'cs', 'michael.chenuniversity.edu']
# Character Tokenization:
# Total number of characters (without spaces): 438
# All characters:
# ['d', 'e', 'a', 'r', 'p', 'r', 'o', 'f', 'e', 's', 's', 'o', 'r', 'w', 'i', 'l', 'l', 'i', 'a', 'm', 's', ',', 'i', 'h', 'o', 'p', 'e', 't', 'h', 'i', 's', 'e', 'm', 'a', 'i', 'l', 'f', 'i', 'n', 'd', 's', 'y', 'o', 'u', 'w', 'e', 'l', 'l', '.', 'i', 'a', 'm', 'w', 'r', 'i', 't', 'i', 'n', 'g', 't', 'o', 'r', 'e', 'q', 'u', 'e', 's', 't', 'a', 'n', 'e', 'x', 't', 'e', 'n', 's', 'i', 'o', 'n', 'f', 'o', 'r', 't', 'h', 'e', 'n', 'l', 'p', 'a', 's', 's', 'i', 'g', 'n', 'm', 'e', 'n', 't', 'c', 's', 'd', 'u', 'e', 'o', 'n', 'd', 'e', 'c', 'e', 'm', 'b', 'e', 'r', 't', 'h', '.', 'd', 'u', 'e', 't', 'o', 'u', 'n', 'e', 'x', 'p', 'e', 'c', 't', 'e', 'd', 't', 'e', 'c', 'h', 'n', 'i', 'c', 'a', 'l', 'i', 's', 's', 'u', 'e', 's', 'w', 'i', 't', 'h', 'm', 'y', 'l', 'o', 'c', 'a', 'l', 'e', 'n', 'v', 'i', 'r', 'o', 'n', 'm', 'e', 'n', 't', 'p', 'y', 'c', 'h', 'a', 'r', 'm', 'p', 'y', 't', 'h', 'o', 'n', '.', ',', 'i', 'c', 'o', 'u', 'l', 'd', 'n', 't', 'c', 'o', 'm', 'p', 'l', 'e', 't', 'e', 't', 'h', 'e', 'i', 'm', 'p', 'l', 'e', 'm', 'e', 'n', 't', 'a', 't', 'i', 'o', 'n', 'o', 'f', 't', 'h', 'e', 't', 'r', 'a', 'n', 's', 'f', 'o', 'r', 'm', 'e', 'r', 'm', 'o', 'd', 'e', 'l', '.', 'c', 'o', 'u', 'l', 'd', 'y', 'o', 'u', 'p', 'l', 'e', 'a', 's', 'e', 'g', 'r', 'a', 'n', 't', 'm', 'e', 'a', 'n', 'e', 'x', 't', 'e', 'n', 's', 'i', 'o', 'n', 'u', 'n', 't', 'i', 'l', 'd', 'e', 'c', 'e', 'm', 'b', 'e', 'r', 't', 'h', 'i', 'h', 'a', 'v', 'e', 'a', 't', 't', 'a', 'c', 'h', 'e', 'd', 'm', 'y', 'c', 'u', 'r', 'r', 'e', 'n', 't', 'p', 'r', 'o', 'g', 'r', 'e', 's', 's', 'f', 'i', 'l', 'e', 't', 'r', 'a', 'n', 's', 'f', 'o', 'r', 'm', 'e', 'r', '_', 'i', 'm', 'p', 'l', 'e', 'm', 'e', 'n', 't', 'a', 't', 'i', 'o', 'n', '_', 'v', '.', 'p', 'y', '.', 't', 'h', 'a', 'n', 'k', 'y', 'o', 'u', 'f', 'o', 'r', 'y', 'o', 'u', 'r', 'u', 'n', 'd', 'e', 'r', 's', 't', 'a', 'n', 'd', 'i', 'n', 'g', '.', 's', 'i', 'n', 'c', 'e', 'r', 'e', 'l', 'y', ',', 'm', 'i', 'c', 'h', 'a', 'e', 'l', 'c', 'h', 'e', 'n', 's', 't', 'u', 'd', 'e', 'n', 't', 'i', 'd', 'c', 's', 'm', 'i', 'c', 'h', 'a', 'e', 'l', '.', 'c', 'h', 'e', 'n', 'u', 'n', 'i', 'v', 'e', 'r', 's', 'i', 't', 'y', '.', 'e', 'd', 'u']

# %% [markdown]
# # 6. Stemming (PorterStemmer and SnowballStemmer)

# %%
# Initialize both stemmers
porter_stemmer = PorterStemmer()
snowball_stemmer = SnowballStemmer("english")

# Apply both stemmers
porter_stemmed_tokens = [porter_stemmer.stem(word) for word in filtered_tokens]
snowball_stemmed_tokens = [snowball_stemmer.stem(word) for word in filtered_tokens]

print("COMPLETE COMPARISON (Original vs Porter vs Snowball):")
print(f"{'#':<5} | {'Original Word':<25} | {'Porter Stemmer':<20} | {'Snowball Stemmer':<20} | {'Difference'}")

difference_count = 0
for i, (original, porter, snowball) in enumerate(zip(filtered_tokens, porter_stemmed_tokens, snowball_stemmed_tokens), 1):
    difference = "DIFFERENT" if porter != snowball else "SAME"
    if porter != snowball:
        difference_count += 1
    print(f"{i:<5} | {original:<25} | {porter:<20} | {snowball:<20} | {difference}")

print(f"\nTotal words with different stemming results: {difference_count} out of {len(filtered_tokens)}")
print(f"Percentage of differences: {(difference_count/len(filtered_tokens))*100:.2f}%")

# Show detailed comparison for words that differ
print("\nDETAILED COMPARISON FOR WORDS WITH DIFFERENT STEMMING RESULTS:")

different_words = []
for original, porter, snowball in zip(filtered_tokens, porter_stemmed_tokens, snowball_stemmed_tokens):
    if porter != snowball:
        different_words.append((original, porter, snowball))

if different_words:
    print(f"{'#':<5} | {'Original Word':<25} | {'Porter Result':<20} | {'Snowball Result':<20} | {'Analysis'}")
    for i, (original, porter, snowball) in enumerate(different_words, 1):
        analysis = ""
        if len(porter) < len(snowball):
            analysis = "Porter shorter"
        elif len(snowball) < len(porter):
            analysis = "Snowball shorter"
        elif porter.endswith('ing') and not snowball.endswith('ing'):
            analysis = "Porter keeps -ing"
        elif snowball.endswith('ing') and not porter.endswith('ing'):
            analysis = "Snowball keeps -ing"
        else:
            analysis = "Different algorithm"
        print(f"{i:<5} | {original:<25} | {porter:<20} | {snowball:<20} | {analysis}")
else:
    print("No differences found between Porter and Snowball stemmers for this text.")

# Show complete stemmed texts
print("\nCOMPLETE PORTER STEMMED TEXT:")
porter_stemmed_text = ' '.join(porter_stemmed_tokens)
print(porter_stemmed_text)

print("\nCOMPLETE SNOWBALL STEMMED TEXT:")
snowball_stemmed_text = ' '.join(snowball_stemmed_tokens)
print(snowball_stemmed_text)

# Performance comparison
print("\nPERFORMANCE COMPARISON:")

# Test Porter speed
start_time = time.time()
for word in filtered_tokens * 10:
    porter_stemmer.stem(word)
porter_time = time.time() - start_time

# Test Snowball speed
start_time = time.time()
for word in filtered_tokens * 10:
    snowball_stemmer.stem(word)
snowball_time = time.time() - start_time

print(f"PorterStemmer processing time (10 repetitions): {porter_time:.6f} seconds")
print(f"SnowballStemmer processing time (10 repetitions): {snowball_time:.6f} seconds")
# Out:
# COMPLETE COMPARISON (Original vs Porter vs Snowball):
# #     | Original Word             | Porter Stemmer       | Snowball Stemmer     | Difference
# 1     | dear                      | dear                 | dear                 | SAME
# 2     | professor                 | professor            | professor            | SAME
# 3     | williams                  | william              | william              | SAME
# 4     | hope                      | hope                 | hope                 | SAME
# 5     | email                     | email                | email                | SAME
# 6     | finds                     | find                 | find                 | SAME
# 7     | well                      | well                 | well                 | SAME
# 8     | writing                   | write                | write                | SAME
# 9     | request                   | request              | request              | SAME
# 10    | extension                 | extens               | extens               | SAME
# 11    | nlp                       | nlp                  | nlp                  | SAME
# 12    | assignment                | assign               | assign               | SAME
# 13    | cs                        | cs                   | cs                   | SAME
# 14    | due                       | due                  | due                  | SAME
# 15    | december                  | decemb               | decemb               | SAME
# 16    | th                        | th                   | th                   | SAME
# 17    | due                       | due                  | due                  | SAME
# 18    | unexpected                | unexpect             | unexpect             | SAME
# 19    | technical                 | technic              | technic              | SAME
# 20    | issues                    | issu                 | issu                 | SAME
# 21    | local                     | local                | local                | SAME
# 22    | environment               | environ              | environ              | SAME
# 23    | pycharm                   | pycharm              | pycharm              | SAME
# 24    | python                    | python               | python               | SAME
# 25    | couldnt                   | couldnt              | couldnt              | SAME
# 26    | complete                  | complet              | complet              | SAME
# 27    | implementation            | implement            | implement            | SAME
# 28    | transformer               | transform            | transform            | SAME
# 29    | model                     | model                | model                | SAME
# 30    | could                     | could                | could                | SAME
# 31    | please                    | pleas                | pleas                | SAME
# 32    | grant                     | grant                | grant                | SAME
# 33    | extension                 | extens               | extens               | SAME
# 34    | december                  | decemb               | decemb               | SAME
# 35    | th                        | th                   | th                   | SAME
# 36    | attached                  | attach               | attach               | SAME
# 37    | current                   | current              | current              | SAME
# 38    | progress                  | progress             | progress             | SAME
# 39    | file                      | file                 | file                 | SAME
# 40    | transformerimplementationvpy | transformerimplementationvpi | transformerimplementationvpi | SAME
# 41    | thank                     | thank                | thank                | SAME
# 42    | understanding             | understand           | understand           | SAME
# 43    | sincerely                 | sincer               | sincer               | SAME
# 44    | michael                   | michael              | michael              | SAME
# 45    | chen                      | chen                 | chen                 | SAME
# 46    | student                   | student              | student              | SAME
# 47    | id                        | id                   | id                   | SAME
# 48    | cs                        | cs                   | cs                   | SAME
# 49    | michaelchenuniversityedu  | michaelchenuniversityedu | michaelchenuniversityedu | SAME
#
# Total words with different stemming results: 0 out of 49
# Percentage of differences: 0.00%
#
# DETAILED COMPARISON FOR WORDS WITH DIFFERENT STEMMING RESULTS:
# No differences found between Porter and Snowball stemmers for this text.
#
# COMPLETE PORTER STEMMED TEXT:
# dear professor william hope email find well write request extens nlp assign cs due decemb th due unexpect technic issu local environ pycharm python couldnt complet implement transform model could pleas grant extens decemb th attach current progress file transformerimplementationvpi thank understand sincer michael chen student id cs michaelchenuniversityedu
#
# COMPLETE SNOWBALL STEMMED TEXT:
# dear professor william hope email find well write request extens nlp assign cs due decemb th due unexpect technic issu local environ pycharm python couldnt complet implement transform model could pleas grant extens decemb th attach current progress file transformerimplementationvpi thank understand sincer michael chen student id cs michaelchenuniversityedu
#
# PERFORMANCE COMPARISON:
# PorterStemmer processing time (10 repetitions): 0.005006 seconds
# SnowballStemmer processing time (10 repetitions): 0.003999 seconds

# %% [markdown]
# # 7. Lemmatization (WordNetLemmatizer)

# %%
lemmatizer = WordNetLemmatizer()
lemmatized_tokens = [lemmatizer.lemmatize(word) for word in filtered_tokens]

print("COMPLETE COMPARISON (Original vs Lemmatized):")
print(f"{'#':<5} | {'Original Word':<25} | {'Lemmatized':<25}")
for i, (original, lemmatized) in enumerate(zip(filtered_tokens, lemmatized_tokens), 1):
    print(f"{i:<5} | {original:<25} | {lemmatized:<25}")

lemmatized_text = ' '.join(lemmatized_tokens)
print("\nCOMPLETE LEMMATIZED TEXT:")
print(lemmatized_text)

print("\nSTEMMING vs LEMMATIZATION COMPARISON:")
print(f"{'#':<5} | {'Original Word':<25} | {'Porter Stemmer':<20} | {'Snowball Stemmer':<20} | {'Lemmatized':<25}")
for i, (original, porter, snowball, lemmatized) in enumerate(zip(filtered_tokens, porter_stemmed_tokens, snowball_stemmed_tokens, lemmatized_tokens), 1):
    print(f"{i:<5} | {original:<25} | {porter:<20} | {snowball:<20} | {lemmatized:<25}")

# Performance comparison for Lemmatizer
print("\nPERFORMANCE COMPARISON (Lemmatizer vs Stemmers):")

# Test Lemmatizer speed
start_time = time.time()
for word in filtered_tokens * 10:
    lemmatizer.lemmatize(word)
lemmatizer_time = time.time() - start_time

print(f"WordNetLemmatizer processing time (10 repetitions): {lemmatizer_time:.6f} seconds")
print(f"PorterStemmer processing time (10 repetitions): {porter_time:.6f} seconds")
print(f"SnowballStemmer processing time (10 repetitions): {snowball_time:.6f} seconds")
# Out:
# COMPLETE COMPARISON (Original vs Lemmatized):
# #     | Original Word             | Lemmatized
# 1     | dear                      | dear
# 2     | professor                 | professor
# 3     | williams                  | williams
# 4     | hope                      | hope
# 5     | email                     | email
# 6     | finds                     | find
# 7     | well                      | well
# 8     | writing                   | writing
# 9     | request                   | request
# 10    | extension                 | extension
# 11    | nlp                       | nlp
# 12    | assignment                | assignment
# 13    | cs                        | c
# 14    | due                       | due
# 15    | december                  | december
# 16    | th                        | th
# 17    | due                       | due
# 18    | unexpected                | unexpected
# 19    | technical                 | technical
# 20    | issues                    | issue
# 21    | local                     | local
# 22    | environment               | environment
# 23    | pycharm                   | pycharm
# 24    | python                    | python
# 25    | couldnt                   | couldnt
# 26    | complete                  | complete
# 27    | implementation            | implementation
# 28    | transformer               | transformer
# 29    | model                     | model
# 30    | could                     | could
# 31    | please                    | please
# 32    | grant                     | grant
# 33    | extension                 | extension
# 34    | december                  | december
# 35    | th                        | th
# 36    | attached                  | attached
# 37    | current                   | current
# 38    | progress                  | progress
# 39    | file                      | file
# 40    | transformerimplementationvpy | transformerimplementationvpy
# 41    | thank                     | thank
# 42    | understanding             | understanding
# 43    | sincerely                 | sincerely
# 44    | michael                   | michael
# 45    | chen                      | chen
# 46    | student                   | student
# 47    | id                        | id
# 48    | cs                        | c
# 49    | michaelchenuniversityedu  | michaelchenuniversityedu
#
# COMPLETE LEMMATIZED TEXT:
# dear professor williams hope email find well writing request extension nlp assignment c due december th due unexpected technical issue local environment pycharm python couldnt complete implementation transformer model could please grant extension december th attached current progress file transformerimplementationvpy thank understanding sincerely michael chen student id c michaelchenuniversityedu
#
# STEMMING vs LEMMATIZATION COMPARISON:
# #     | Original Word             | Porter Stemmer       | Snowball Stemmer     | Lemmatized
# 1     | dear                      | dear                 | dear                 | dear
# 2     | professor                 | professor            | professor            | professor
# 3     | williams                  | william              | william              | williams
# 4     | hope                      | hope                 | hope                 | hope
# 5     | email                     | email                | email                | email
# 6     | finds                     | find                 | find                 | find
# 7     | well                      | well                 | well                 | well
# 8     | writing                   | write                | write                | writing
# 9     | request                   | request              | request              | request
# 10    | extension                 | extens               | extens               | extension
# 11    | nlp                       | nlp                  | nlp                  | nlp
# 12    | assignment                | assign               | assign               | assignment
# 13    | cs                        | cs                   | cs                   | c
# 14    | due                       | due                  | due                  | due
# 15    | december                  | decemb               | decemb               | december
# 16    | th                        | th                   | th                   | th
# 17    | due                       | due                  | due                  | due
# 18    | unexpected                | unexpect             | unexpect             | unexpected
# 19    | technical                 | technic              | technic              | technical
# 20    | issues                    | issu                 | issu                 | issue
# 21    | local                     | local                | local                | local
# 22    | environment               | environ              | environ              | environment
# 23    | pycharm                   | pycharm              | pycharm              | pycharm
# 24    | python                    | python               | python               | python
# 25    | couldnt                   | couldnt              | couldnt              | couldnt
# 26    | complete                  | complet              | complet              | complete
# 27    | implementation            | implement            | implement            | implementation
# 28    | transformer               | transform            | transform            | transformer
# 29    | model                     | model                | model                | model
# 30    | could                     | could                | could                | could
# 31    | please                    | pleas                | pleas                | please
# 32    | grant                     | grant                | grant                | grant
# 33    | extension                 | extens               | extens               | extension
# 34    | december                  | decemb               | decemb               | december
# 35    | th                        | th                   | th                   | th
# 36    | attached                  | attach               | attach               | attached
# 37    | current                   | current              | current              | current
# 38    | progress                  | progress             | progress             | progress
# 39    | file                      | file                 | file                 | file
# 40    | transformerimplementationvpy | transformerimplementationvpi | transformerimplementationvpi | transformerimplementationvpy
# 41    | thank                     | thank                | thank                | thank
# 42    | understanding             | understand           | understand           | understanding
# 43    | sincerely                 | sincer               | sincer               | sincerely
# 44    | michael                   | michael              | michael              | michael
# 45    | chen                      | chen                 | chen                 | chen
# 46    | student                   | student              | student              | student
# 47    | id                        | id                   | id                   | id
# 48    | cs                        | cs                   | cs                   | c
# 49    | michaelchenuniversityedu  | michaelchenuniversityedu | michaelchenuniversityedu | michaelchenuniversityedu
#
# PERFORMANCE COMPARISON (Lemmatizer vs Stemmers):
# WordNetLemmatizer processing time (10 repetitions): 0.000000 seconds
# PorterStemmer processing time (10 repetitions): 0.005006 seconds
# SnowballStemmer processing time (10 repetitions): 0.003999 seconds

# %% [markdown]
# # 8. Part-of-Speech (POS) Tagging

# %%
# Cell 10: 8. POS Tagging (Part-of-Speech Tagging)
print("8. PART-OF-SPEECH (POS) TAGGING")

# Perform POS tagging on all filtered tokens
pos_tagged = pos_tag(filtered_tokens)

print("COMPLETE POS TAGGING RESULTS:")
print(f"{'#':<4} | {'Word':<20} | {'POS Tag':<10} | {'Description'}")

pos_descriptions = {
    'NN': 'Noun, singular', 'NNS': 'Noun, plural',
    'NNP': 'Proper noun, singular', 'NNPS': 'Proper noun, plural',
    'VB': 'Verb, base form', 'VBD': 'Verb, past tense',
    'VBG': 'Verb, gerund/present participle', 'VBN': 'Verb, past participle',
    'VBP': 'Verb, non-3rd person singular present', 'VBZ': 'Verb, 3rd person singular present',
    'JJ': 'Adjective', 'JJR': 'Adjective, comparative', 'JJS': 'Adjective, superlative',
    'RB': 'Adverb', 'RBR': 'Adverb, comparative', 'RBS': 'Adverb, superlative',
    'IN': 'Preposition/subordinating conjunction', 'DT': 'Determiner',
    'CC': 'Coordinating conjunction', 'PRP': 'Personal pronoun', 'PRP$': 'Possessive pronoun',
    'MD': 'Modal auxiliary', 'TO': 'to', 'UH': 'Interjection',
    'CD': 'Cardinal number', 'EX': 'Existential there', 'FW': 'Foreign word',
    'LS': 'List item marker', 'POS': 'Possessive ending', 'RP': 'Particle',
    'SYM': 'Symbol', 'WDT': 'Wh-determiner', 'WP': 'Wh-pronoun',
    'WP$': 'Possessive wh-pronoun', 'WRB': 'Wh-adverb'
}

for i, (word, tag) in enumerate(pos_tagged, 1):
    desc = pos_descriptions.get(tag, 'Other')
    print(f"{i:<4} | {word:<20} | {tag:<10} | {desc}")
# Out:
# 8. PART-OF-SPEECH (POS) TAGGING
# COMPLETE POS TAGGING RESULTS:
# #    | Word                 | POS Tag    | Description
# 1    | dear                 | NN         | Noun, singular
# 2    | professor            | NN         | Noun, singular
# 3    | williams             | NNS        | Noun, plural
# 4    | hope                 | VBP        | Verb, non-3rd person singular present
# 5    | email                | JJ         | Adjective
# 6    | finds                | NNS        | Noun, plural
# 7    | well                 | RB         | Adverb
# 8    | writing              | VBG        | Verb, gerund/present participle
# 9    | request              | JJS        | Adjective, superlative
# 10   | extension            | NN         | Noun, singular
# 11   | nlp                  | FW         | Foreign word
# 12   | assignment           | NN         | Noun, singular
# 13   | cs                   | NN         | Noun, singular
# 14   | due                  | JJ         | Adjective
# 15   | december             | NN         | Noun, singular
# 16   | th                   | NN         | Noun, singular
# 17   | due                  | JJ         | Adjective
# 18   | unexpected           | JJ         | Adjective
# 19   | technical            | JJ         | Adjective
# 20   | issues               | NNS        | Noun, plural
# 21   | local                | JJ         | Adjective
# 22   | environment          | NN         | Noun, singular
# 23   | pycharm              | NN         | Noun, singular
# 24   | python               | NN         | Noun, singular
# 25   | couldnt              | VBD        | Verb, past tense
# 26   | complete             | JJ         | Adjective
# 27   | implementation       | NN         | Noun, singular
# 28   | transformer          | NN         | Noun, singular
# 29   | model                | NN         | Noun, singular
# 30   | could                | MD         | Modal auxiliary
# 31   | please               | VB         | Verb, base form
# 32   | grant                | JJ         | Adjective
# 33   | extension            | NN         | Noun, singular
# 34   | december             | NN         | Noun, singular
# 35   | th                   | NN         | Noun, singular
# 36   | attached             | VBD        | Verb, past tense
# 37   | current              | JJ         | Adjective
# 38   | progress             | NN         | Noun, singular
# 39   | file                 | NN         | Noun, singular
# 40   | transformerimplementationvpy | NN         | Noun, singular
# 41   | thank                | NN         | Noun, singular
# 42   | understanding        | VBG        | Verb, gerund/present participle
# 43   | sincerely            | RB         | Adverb
# 44   | michael              | JJ         | Adjective
# 45   | chen                 | VBP        | Verb, non-3rd person singular present
# 46   | student              | NN         | Noun, singular
# 47   | id                   | NN         | Noun, singular
# 48   | cs                   | NN         | Noun, singular
# 49   | michaelchenuniversityedu | NN         | Noun, singular

# %% [markdown]
# # 9. Chunking

# %%
# Define chunk grammar
chunk_grammar = r"""
    NP: {<DT>?<JJ>*<NN.*>+}
    NP: {<NNP>+}
    NP: {<NNP><POS>?<NNP>*}
    VP: {<VB.*><NP|PP|CLAUSE>+$}
    PP: {<IN><NP>}
"""
chunk_parser = RegexpParser(chunk_grammar)

# Process ALL sentences for chunking
all_sentences = sent_tokenize(text_lower)

for sent_idx, sentence in enumerate(all_sentences, 1):
    print(f"\nSentence {sent_idx}: {sentence}")

    # Tokenize and tag
    tokens = word_tokenize(sentence)
    pos_tags = pos_tag(tokens)

    # Parse chunks
    chunk_tree = chunk_parser.parse(pos_tags)

    print("Chunk Tree Structure:")
    print(chunk_tree)

    print("Chunks extracted:")
    for subtree in chunk_tree.subtrees():
        if subtree.label() in ['NP', 'VP', 'PP']:
            chunk_words = ' '.join(word for word, tag in subtree.leaves())
            print(f"  {subtree.label()}: {chunk_words}")
# Out:
# Sentence 1: dear professor williams, i hope this email finds you well.
# Chunk Tree Structure:
# (S
#   (NP dear/NN professor/NN williams/NN)
#   ,/,
#   i/JJ
#   hope/VBP
#   (NP this/DT email/NN)
#   finds/VBZ
#   you/PRP
#   well/RB
#   ./.)
# Chunks extracted:
#   NP: dear professor williams
#   NP: this email
#
# Sentence 2: i am writing to request an extension for the nlp assignment cs due on december th.
# Chunk Tree Structure:
# (S
#   (NP i/NN)
#   am/VBP
#   writing/VBG
#   to/TO
#   request/VB
#   (NP an/DT extension/NN)
#   (PP for/IN (NP the/DT nlp/JJ assignment/NN cs/NN))
#   due/JJ
#   (PP on/IN (NP december/JJ th/NN))
#   ./.)
# Chunks extracted:
#   NP: i
#   NP: an extension
#   PP: for the nlp assignment cs
#   NP: the nlp assignment cs
#   PP: on december th
#   NP: december th
#
# Sentence 3: due to unexpected technical issues with my local environment pycharm  python ., i couldnt complete the implementation of the transformer model.
# Chunk Tree Structure:
# (S
#   due/JJ
#   to/TO
#   (NP unexpected/JJ technical/JJ issues/NNS)
#   with/IN
#   my/PRP$
#   (NP local/JJ environment/NN pycharm/NN python/NN)
#   ./.
#   ,/,
#   i/JJ
#   couldnt/VBP
#   complete/JJ
#   (NP the/DT implementation/NN)
#   (PP of/IN (NP the/DT transformer/NN model/NN))
#   ./.)
# Chunks extracted:
#   NP: unexpected technical issues
#   NP: local environment pycharm python
#   NP: the implementation
#   PP: of the transformer model
#   NP: the transformer model
#
# Sentence 4: could you please grant me an extension until december th i have attached my current progress file transformer_implementation_v.py.
# Chunk Tree Structure:
# (S
#   could/MD
#   you/PRP
#   please/VB
#   grant/VB
#   me/PRP
#   (NP an/DT extension/NN)
#   (PP until/IN (NP december/NNP th/NN i/NN))
#   have/VBP
#   attached/VBN
#   my/PRP$
#   (NP
#     current/JJ
#     progress/NN
#     file/NN
#     transformer_implementation_v.py/NN)
#   ./.)
# Chunks extracted:
#   NP: an extension
#   PP: until december th i
#   NP: december th i
#   NP: current progress file transformer_implementation_v.py
#
# Sentence 5: thank you for your understanding.
# Chunk Tree Structure:
# (S (NP thank/NN) you/PRP for/IN your/PRP$ (NP understanding/NN) ./.)
# Chunks extracted:
#   NP: thank
#   NP: understanding
#
# Sentence 6: sincerely, michael chen student id cs michael.chenuniversity.edu
# Chunk Tree Structure:
# (S
#   sincerely/RB
#   ,/,
#   michael/PRP
#   (VP
#     chen/VBP
#     (NP student/JJ id/NN cs/NN michael.chenuniversity.edu/NN)))
# Chunks extracted:
#   VP: chen student id cs michael.chenuniversity.edu
#   NP: student id cs michael.chenuniversity.edu

# %% [markdown]
# # 10. Parsing ( Dependency Parsing and Tree Structure Parsing )

# %%
# Process entire text with spaCy
doc = nlp(text_lower)

print("DEPENDENCY RELATIONS FOR ENTIRE TEXT:")

for token in doc:
    print(f"Word: '{token.text}'")
    print(f"  Head word: '{token.head.text}'")
    print(f"  Dependency relation: {token.dep_}")
    print(f"  Explanation: {spacy.explain(token.dep_)}")
    print(f"  Children: {[child.text for child in token.children]}")
# Out:
# DEPENDENCY RELATIONS FOR ENTIRE TEXT:
# Word: 'dear'
#   Head word: 'williams'
#   Dependency relation: amod
#   Explanation: adjectival modifier
#   Children: []
# Word: 'professor'
#   Head word: 'williams'
#   Dependency relation: compound
#   Explanation: compound
#   Children: []
# Word: 'williams'
#   Head word: 'hope'
#   Dependency relation: npadvmod
#   Explanation: noun phrase as adverbial modifier
#   Children: ['dear', 'professor']
# Word: ','
#   Head word: 'hope'
#   Dependency relation: punct
#   Explanation: punctuation
#   Children: []
# Word: 'i'
#   Head word: 'hope'
#   Dependency relation: nsubj
#   Explanation: nominal subject
#   Children: []
# Word: 'hope'
#   Head word: 'hope'
#   Dependency relation: ROOT
#   Explanation: root
#   Children: ['williams', ',', 'i', 'finds', '.']
# Word: 'this'
#   Head word: 'email'
#   Dependency relation: det
#   Explanation: determiner
#   Children: []
# Word: 'email'
#   Head word: 'finds'
#   Dependency relation: nsubj
#   Explanation: nominal subject
#   Children: ['this']
# Word: 'finds'
#   Head word: 'hope'
#   Dependency relation: ccomp
#   Explanation: clausal complement
#   Children: ['email', 'well']
# Word: 'you'
#   Head word: 'well'
#   Dependency relation: nsubj
#   Explanation: nominal subject
#   Children: []
# Word: 'well'
#   Head word: 'finds'
#   Dependency relation: ccomp
#   Explanation: clausal complement
#   Children: ['you']
# Word: '.'
#   Head word: 'hope'
#   Dependency relation: punct
#   Explanation: punctuation
#   Children: []
# Word: 'i'
#   Head word: 'writing'
#   Dependency relation: nsubj
#   Explanation: nominal subject
#   Children: []
# Word: 'am'
#   Head word: 'writing'
#   Dependency relation: aux
#   Explanation: auxiliary
#   Children: []
# Word: 'writing'
#   Head word: 'writing'
#   Dependency relation: ROOT
#   Explanation: root
#   Children: ['i', 'am', 'request', 'due', 'on', '.']
# Word: 'to'
#   Head word: 'request'
#   Dependency relation: aux
#   Explanation: auxiliary
#   Children: []
# Word: 'request'
#   Head word: 'writing'
#   Dependency relation: xcomp
#   Explanation: open clausal complement
#   Children: ['to', 'extension']
# Word: 'an'
#   Head word: 'extension'
#   Dependency relation: det
#   Explanation: determiner
#   Children: []
# Word: 'extension'
#   Head word: 'request'
#   Dependency relation: dobj
#   Explanation: direct object
#   Children: ['an', 'for']
# Word: 'for'
#   Head word: 'extension'
#   Dependency relation: prep
#   Explanation: prepositional modifier
#   Children: ['cs']
# Word: 'the'
#   Head word: 'cs'
#   Dependency relation: det
#   Explanation: determiner
#   Children: []
# Word: 'nlp'
#   Head word: 'assignment'
#   Dependency relation: compound
#   Explanation: compound
#   Children: []
# Word: 'assignment'
#   Head word: 'cs'
#   Dependency relation: compound
#   Explanation: compound
#   Children: ['nlp']
# Word: 'cs'
#   Head word: 'for'
#   Dependency relation: pobj
#   Explanation: object of preposition
#   Children: ['the', 'assignment']
# Word: 'due'
#   Head word: 'writing'
#   Dependency relation: prep
#   Explanation: prepositional modifier
#   Children: []
# Word: 'on'
#   Head word: 'writing'
#   Dependency relation: prep
#   Explanation: prepositional modifier
#   Children: ['december']
# Word: 'december'
#   Head word: 'on'
#   Dependency relation: pobj
#   Explanation: object of preposition
#   Children: ['th']
# Word: 'th'
#   Head word: 'december'
#   Dependency relation: nummod
#   Explanation: numeric modifier
#   Children: []
# Word: '.'
#   Head word: 'writing'
#   Dependency relation: punct
#   Explanation: punctuation
#   Children: []
# Word: 'due'
#   Head word: 'pycharm'
#   Dependency relation: prep
#   Explanation: prepositional modifier
#   Children: ['to', 'issues']
# Word: 'to'
#   Head word: 'due'
#   Dependency relation: pcomp
#   Explanation: complement of preposition
#   Children: []
# Word: 'unexpected'
#   Head word: 'issues'
#   Dependency relation: amod
#   Explanation: adjectival modifier
#   Children: []
# Word: 'technical'
#   Head word: 'issues'
#   Dependency relation: amod
#   Explanation: adjectival modifier
#   Children: []
# Word: 'issues'
#   Head word: 'due'
#   Dependency relation: pobj
#   Explanation: object of preposition
#   Children: ['unexpected', 'technical', 'with']
# Word: 'with'
#   Head word: 'issues'
#   Dependency relation: prep
#   Explanation: prepositional modifier
#   Children: ['environment']
# Word: 'my'
#   Head word: 'environment'
#   Dependency relation: poss
#   Explanation: possession modifier
#   Children: []
# Word: 'local'
#   Head word: 'environment'
#   Dependency relation: amod
#   Explanation: adjectival modifier
#   Children: []
# Word: 'environment'
#   Head word: 'with'
#   Dependency relation: pobj
#   Explanation: object of preposition
#   Children: ['my', 'local']
# Word: 'pycharm'
#   Head word: 'pycharm'
#   Dependency relation: ROOT
#   Explanation: root
#   Children: ['due', ' ', 'python', '.']
# Word: ' '
#   Head word: 'pycharm'
#   Dependency relation: dep
#   Explanation: unclassified dependent
#   Children: []
# Word: 'python'
#   Head word: 'pycharm'
#   Dependency relation: dobj
#   Explanation: direct object
#   Children: []
# Word: '.'
#   Head word: 'pycharm'
#   Dependency relation: punct
#   Explanation: punctuation
#   Children: []
# Word: ','
#   Head word: 'complete'
#   Dependency relation: punct
#   Explanation: punctuation
#   Children: []
# Word: 'i'
#   Head word: 'complete'
#   Dependency relation: nsubj
#   Explanation: nominal subject
#   Children: []
# Word: 'could'
#   Head word: 'complete'
#   Dependency relation: aux
#   Explanation: auxiliary
#   Children: []
# Word: 'nt'
#   Head word: 'complete'
#   Dependency relation: neg
#   Explanation: negation modifier
#   Children: []
# Word: 'complete'
#   Head word: 'complete'
#   Dependency relation: ROOT
#   Explanation: root
#   Children: [',', 'i', 'could', 'nt', 'implementation', '.']
# Word: 'the'
#   Head word: 'implementation'
#   Dependency relation: det
#   Explanation: determiner
#   Children: []
# Word: 'implementation'
#   Head word: 'complete'
#   Dependency relation: dobj
#   Explanation: direct object
#   Children: ['the', 'of']
# Word: 'of'
#   Head word: 'implementation'
#   Dependency relation: prep
#   Explanation: prepositional modifier
#   Children: ['model']
# Word: 'the'
#   Head word: 'model'
#   Dependency relation: det
#   Explanation: determiner
#   Children: []
# Word: 'transformer'
#   Head word: 'model'
#   Dependency relation: compound
#   Explanation: compound
#   Children: []
# Word: 'model'
#   Head word: 'of'
#   Dependency relation: pobj
#   Explanation: object of preposition
#   Children: ['the', 'transformer']
# Word: '.'
#   Head word: 'complete'
#   Dependency relation: punct
#   Explanation: punctuation
#   Children: []
# Word: 'could'
#   Head word: 'grant'
#   Dependency relation: aux
#   Explanation: auxiliary
#   Children: []
# Word: 'you'
#   Head word: 'grant'
#   Dependency relation: nsubj
#   Explanation: nominal subject
#   Children: []
# Word: 'please'
#   Head word: 'grant'
#   Dependency relation: intj
#   Explanation: interjection
#   Children: []
# Word: 'grant'
#   Head word: 'grant'
#   Dependency relation: ROOT
#   Explanation: root
#   Children: ['could', 'you', 'please', 'me', 'extension', 'until', 'th', 'attached', '.']
# Word: 'me'
#   Head word: 'grant'
#   Dependency relation: dative
#   Explanation: dative
#   Children: []
# Word: 'an'
#   Head word: 'extension'
#   Dependency relation: det
#   Explanation: determiner
#   Children: []
# Word: 'extension'
#   Head word: 'grant'
#   Dependency relation: dobj
#   Explanation: direct object
#   Children: ['an']
# Word: 'until'
#   Head word: 'grant'
#   Dependency relation: prep
#   Explanation: prepositional modifier
#   Children: ['december']
# Word: 'december'
#   Head word: 'until'
#   Dependency relation: pobj
#   Explanation: object of preposition
#   Children: []
# Word: 'th'
#   Head word: 'grant'
#   Dependency relation: dep
#   Explanation: unclassified dependent
#   Children: []
# Word: 'i'
#   Head word: 'attached'
#   Dependency relation: nsubj
#   Explanation: nominal subject
#   Children: []
# Word: 'have'
#   Head word: 'attached'
#   Dependency relation: aux
#   Explanation: auxiliary
#   Children: []
# Word: 'attached'
#   Head word: 'grant'
#   Dependency relation: ccomp
#   Explanation: clausal complement
#   Children: ['i', 'have', 'file', 'transformer_implementation_v.py']
# Word: 'my'
#   Head word: 'file'
#   Dependency relation: poss
#   Explanation: possession modifier
#   Children: []
# Word: 'current'
#   Head word: 'file'
#   Dependency relation: amod
#   Explanation: adjectival modifier
#   Children: []
# Word: 'progress'
#   Head word: 'file'
#   Dependency relation: compound
#   Explanation: compound
#   Children: []
# Word: 'file'
#   Head word: 'attached'
#   Dependency relation: dobj
#   Explanation: direct object
#   Children: ['my', 'current', 'progress']
# Word: 'transformer_implementation_v.py'
#   Head word: 'attached'
#   Dependency relation: npadvmod
#   Explanation: noun phrase as adverbial modifier
#   Children: []
# Word: '.'
#   Head word: 'grant'
#   Dependency relation: punct
#   Explanation: punctuation
#   Children: []
# Word: 'thank'
#   Head word: 'thank'
#   Dependency relation: ROOT
#   Explanation: root
#   Children: ['you', 'for', '.']
# Word: 'you'
#   Head word: 'thank'
#   Dependency relation: dobj
#   Explanation: direct object
#   Children: []
# Word: 'for'
#   Head word: 'thank'
#   Dependency relation: prep
#   Explanation: prepositional modifier
#   Children: ['understanding']
# Word: 'your'
#   Head word: 'understanding'
#   Dependency relation: poss
#   Explanation: possession modifier
#   Children: []
# Word: 'understanding'
#   Head word: 'for'
#   Dependency relation: pobj
#   Explanation: object of preposition
#   Children: ['your']
# Word: '.'
#   Head word: 'thank'
#   Dependency relation: punct
#   Explanation: punctuation
#   Children: []
# Word: 'sincerely'
#   Head word: 'michael.chenuniversity.edu'
#   Dependency relation: advmod
#   Explanation: adverbial modifier
#   Children: []
# Word: ','
#   Head word: 'michael.chenuniversity.edu'
#   Dependency relation: punct
#   Explanation: punctuation
#   Children: []
# Word: 'michael'
#   Head word: 'student'
#   Dependency relation: compound
#   Explanation: compound
#   Children: []
# Word: 'chen'
#   Head word: 'student'
#   Dependency relation: compound
#   Explanation: compound
#   Children: []
# Word: 'student'
#   Head word: 'michael.chenuniversity.edu'
#   Dependency relation: nmod
#   Explanation: modifier of nominal
#   Children: ['michael', 'chen', 'i']
# Word: 'i'
#   Head word: 'student'
#   Dependency relation: appos
#   Explanation: appositional modifier
#   Children: []
# Word: 'd'
#   Head word: 'michael.chenuniversity.edu'
#   Dependency relation: nmod
#   Explanation: modifier of nominal
#   Children: []
# Word: 'cs'
#   Head word: 'michael.chenuniversity.edu'
#   Dependency relation: nmod
#   Explanation: modifier of nominal
#   Children: []
# Word: 'michael.chenuniversity.edu'
#   Head word: 'michael.chenuniversity.edu'
#   Dependency relation: ROOT
#   Explanation: root
#   Children: ['sincerely', ',', 'student', 'd', 'cs']

# %%
all_sentences = sent_tokenize(text_lower)

for sent_idx, sentence in enumerate(all_sentences, 1):
    print(f"\nSentence {sent_idx}: {sentence}")

    # Tokenize and tag
    tokens = word_tokenize(sentence)
    pos_tags = pos_tag(tokens)

    # Create a simple binary tree structure for visualization
    def create_simple_tree(tokens, pos_tags):
        """Create a simple constituency-like tree structure"""
        if len(tokens) == 1:
            return Tree(pos_tags[0][1], [tokens[0]])
        else:
            mid = len(tokens) // 2
            left_tree = create_simple_tree(tokens[:mid], pos_tags[:mid])
            right_tree = create_simple_tree(tokens[mid:], pos_tags[mid:])
            return Tree('S', [left_tree, right_tree])

    try:
        constituency_tree = create_simple_tree(tokens, pos_tags)
        print("Constituency Tree:")
        constituency_tree.pretty_print()

        print("Tree in bracketed notation:")
        print(constituency_tree)
    except Exception as e:
        print(f"Error creating tree: {e}")

print("\nALTERNATIVE TREE VISUALIZATION (ALL SENTENCES - Detailed NP chunks):")

# More detailed tree structure for ALL sentences
for sent_idx, sentence in enumerate(all_sentences, 1):
    print(f"\nSentence {sent_idx}: {sentence}")

    tokens = word_tokenize(sentence)
    pos_tags = pos_tag(tokens)

    # Manual tree building
    tree = Tree('S', [])
    current_np = []

    for word, tag in pos_tags:
        if tag.startswith('NN') or tag.startswith('JJ') or tag == 'DT':
            current_np.append((word, tag))
        else:
            if current_np:
                np_tree = Tree('NP', [f"{w}/{t}" for w, t in current_np])
                tree.append(np_tree)
                current_np = []
            tree.append(f"{word}/{tag}")

    if current_np:
        np_tree = Tree('NP', [f"{w}/{t}" for w, t in current_np])
        tree.append(np_tree)

    print("Detailed Constituency Tree (NP chunks):")
    tree.pretty_print()
    print("\nTree as string:")
    print(tree)
# Out:
# Sentence 1: dear professor williams, i hope this email finds you well.
# Constituency Tree:
#                                          S
#                        __________________|____________________
#                       S                                       S
#           ____________|__________                    _________|________
#          S                       S                  S                  S
#   _______|______              ___|___          _____|____           ___|____
#  |              S            |       S        |          S         |        S
#  |        ______|_____       |    ___|___     |      ____|____     |    ____|___
#  NN      NN           NN     ,   JJ     VBP   DT    NN       VBZ  PRP  RB       .
#  |       |            |      |   |       |    |     |         |    |   |        |
# dear professor     williams  ,   i      hope this email     finds you well      .
#
# Tree in bracketed notation:
# (S
#   (S
#     (S (NN dear) (S (NN professor) (NN williams)))
#     (S (, ,) (S (JJ i) (VBP hope))))
#   (S
#     (S (DT this) (S (NN email) (VBZ finds)))
#     (S (PRP you) (S (RB well) (. .)))))
#
# Sentence 2: i am writing to request an extension for the nlp assignment cs due on december th.
# Constituency Tree:
#                                                                        S
#                               _________________________________________|__________________________________
#                              |                                                                            S
#                              |                                                      ______________________|_____________
#                              S                                                     |                                    S
#               _______________|___________________                                  |                           _________|______
#              S                                   S                                 S                          |                S
#       _______|___________                 _______|_____________             _______|______________            |          ______|___
#      S                   S               S                     S           S                      S           S         |          S
#   ___|___           _____|___       _____|___            ______|___     ___|___            _______|___     ___|___      |       ___|___
#  NN     VBP       VBG        TO    VB        DT         NN         IN  DT      JJ         NN          NN  JJ      IN    JJ     NN      .
#  |       |         |         |     |         |          |          |   |       |          |           |   |       |     |      |       |
#  i       am     writing      to request      an     extension     for the     nlp     assignment      cs due      on december  th      .
#
# Tree in bracketed notation:
# (S
#   (S
#     (S (S (NN i) (VBP am)) (S (VBG writing) (TO to)))
#     (S (S (VB request) (DT an)) (S (NN extension) (IN for))))
#   (S
#     (S (S (DT the) (JJ nlp)) (S (NN assignment) (NN cs)))
#     (S (S (JJ due) (IN on)) (S (JJ december) (S (NN th) (. .))))))
#
# Sentence 3: due to unexpected technical issues with my local environment pycharm  python ., i couldnt complete the implementation of the transformer model.
# Constituency Tree:
#                                                                                                 S
#                                               __________________________________________________|____________________________________
#                                              S                                                                                       S
#                  ____________________________|______________                                                 ________________________|__________________________
#                 S                                           S                                               S                                                   S
#       __________|__________                        _________|__________________                      _______|_____________                               _______|________________
#      |                     S                      S                            S                    S                     S                             S                        S
#      |           __________|______            ____|____               _________|_____            ___|___           _______|______              _________|___             ________|____
#      S          |                 S          |         S             |               S          |       S         |              S            |             S           |             S
#   ___|___       |           ______|____      |     ____|____         |          _____|____      |    ___|___      |        ______|___         |          ___|___        |         ____|___
#  JJ      TO     JJ         JJ         NNS    IN  PRP$       JJ       NN        NN         NN    .   ,       JJ   VBP      JJ         DT       NN        IN      DT      NN       NN       .
#  |       |      |          |           |     |    |         |        |         |          |     |   |       |     |       |          |        |         |       |       |        |        |
# due      to unexpected technical     issues with  my      local environment pycharm     python  .   ,       i  couldnt complete     the implementation  of     the transformer model      .
#
# Tree in bracketed notation:
# (S
#   (S
#     (S
#       (S (JJ due) (TO to))
#       (S (JJ unexpected) (S (JJ technical) (NNS issues))))
#     (S
#       (S (IN with) (S (PRP$ my) (JJ local)))
#       (S (NN environment) (S (NN pycharm) (NN python)))))
#   (S
#     (S
#       (S (. .) (S (, ,) (JJ i)))
#       (S (VBP couldnt) (S (JJ complete) (DT the))))
#     (S
#       (S (NN implementation) (S (IN of) (DT the)))
#       (S (NN transformer) (S (NN model) (. .))))))
#
# Sentence 4: could you please grant me an extension until december th i have attached my current progress file transformer_implementation_v.py.
# Constituency Tree:
#                                                                              S
#                                      ________________________________________|_____________________________
#                                     S                                                                      S
#                 ____________________|______________                                       _________________|_________________________
#                |                                   S                                     S                                           S
#                |                         __________|_______                       _______|______                         ____________|__________
#                S                        |                  S                     |              S                       |                       S
#         _______|__________              |           _______|____                 |        ______|______                 |             __________|__________
#        S                  S             S          |            S                S       |             S                S            |                     S
#    ____|___          _____|____      ___|___       |        ____|_____        ___|___    |       ______|___        _____|_____       |           __________|___
#   MD      PRP       VB         VB  PRP      DT     NN      IN        NNP     NN      NN VBP    VBN        PRP$    JJ          NN     NN         NN             .
#   |        |        |          |    |       |      |       |          |      |       |   |      |          |      |           |      |          |              |
# could     you     please     grant  me      an extension until     december  th      i  have attached      my  current     progress file transformer_impl      .
#                                                                                                                                          ementation_v.py
#
# Tree in bracketed notation:
# (S
#   (S
#     (S (S (MD could) (PRP you)) (S (VB please) (VB grant)))
#     (S
#       (S (PRP me) (DT an))
#       (S (NN extension) (S (IN until) (NNP december)))))
#   (S
#     (S
#       (S (NN th) (NN i))
#       (S (VBP have) (S (VBN attached) (PRP$ my))))
#     (S
#       (S (JJ current) (NN progress))
#       (S (NN file) (S (NN transformer_implementation_v.py) (. .))))))
#
# Sentence 5: thank you for your understanding.
# Constituency Tree:
#                S
#         _______|_____________
#        S                     S
#    ____|___         _________|________
#   |        S       |                  S
#   |     ___|___    |          ________|___
#   NN  PRP      IN PRP$       NN           .
#   |    |       |   |         |            |
# thank you     for your understanding      .
#
# Tree in bracketed notation:
# (S
#   (S (NN thank) (S (PRP you) (IN for)))
#   (S (PRP$ your) (S (NN understanding) (. .))))
#
# Sentence 6: sincerely, michael chen student id cs michael.chenuniversity.edu
# Constituency Tree:
#                                    S
#                     _______________|____________________
#                    S                                    S
#             _______|___________                  _______|_______
#            S                   S                S               S
#      ______|___           _____|___        _____|___         ___|_________
#     RB         ,        PRP       VBP     JJ        NN      NN            NN
#     |          |         |         |      |         |       |             |
# sincerely      ,      michael     chen student      id      cs     michael.chenuniv
#                                                                       ersity.edu
#
# Tree in bracketed notation:
# (S
#   (S (S (RB sincerely) (, ,)) (S (PRP michael) (VBP chen)))
#   (S
#     (S (JJ student) (NN id))
#     (S (NN cs) (NN michael.chenuniversity.edu))))
#
# ALTERNATIVE TREE VISUALIZATION (ALL SENTENCES - Detailed NP chunks):
#
# Sentence 1: dear professor williams, i hope this email finds you well.
# Detailed Constituency Tree (NP chunks):
#                                         S
#   ______________________________________|_________________________________________________
#  |     |         |        |       |     |               NP                   NP           NP
#  |     |         |        |       |     |      _________|____________        |       _____|_____
# ,/, hope/VBP finds/VBZ you/PRP well/RB ./. dear/NN professor/NN williams/NN i/JJ this/DT     email/NN
#
#
# Tree as string:
# (S
#   (NP dear/NN professor/NN williams/NN)
#   ,/,
#   (NP i/JJ)
#   hope/VBP
#   (NP this/DT email/NN)
#   finds/VBZ
#   you/PRP
#   well/RB
#   ./.)
#
# Sentence 2: i am writing to request an extension for the nlp assignment cs due on december th.
# Detailed Constituency Tree (NP chunks):
#                                                             S
#    _________________________________________________________|__________________________________________________________________________
#   |         |        |       |        |      |    |   NP         NP                                  NP                                NP
#   |         |        |       |        |      |    |   |      ____|_______           _________________|_______________           _______|____
# am/VBP writing/VBG to/TO request/VB for/IN on/IN ./. i/NN an/DT     extension/NN the/DT nlp/JJ assignment/NN cs/NN due/JJ december/JJ     th/NN
#
#
# Tree as string:
# (S
#   (NP i/NN)
#   am/VBP
#   writing/VBG
#   to/TO
#   request/VB
#   (NP an/DT extension/NN)
#   for/IN
#   (NP the/DT nlp/JJ assignment/NN cs/NN due/JJ)
#   on/IN
#   (NP december/JJ th/NN)
#   ./.)
#
# Sentence 3: due to unexpected technical issues with my local environment pycharm  python ., i couldnt complete the implementation of the transformer model.
# Detailed Constituency Tree (NP chunks):
#                                                                                           S
#    _______________________________________________________________________________________|________________________________________________________________________________________________________
#   |      |       |     |   |       |        |    |    NP                      NP                                NP                             NP                NP                                NP
#   |      |       |     |   |       |        |    |    |           ____________|___________           ___________|_______________________       |         ________|___________            __________|___________
# to/TO with/IN my/PRP$ ./. ,/, couldnt/VBP of/IN ./. due/JJ unexpected/JJ technical/JJ issues/NNS local/JJ environment/NN pycharm/NN python/NN i/JJ complete/JJ the/DT implementation/ the/DT transformer/NN model/NN
#                                                                                                                                                                              NN
#
#
# Tree as string:
# (S
#   (NP due/JJ)
#   to/TO
#   (NP unexpected/JJ technical/JJ issues/NNS)
#   with/IN
#   my/PRP$
#   (NP local/JJ environment/NN pycharm/NN python/NN)
#   ./.
#   ,/,
#   (NP i/JJ)
#   couldnt/VBP
#   (NP complete/JJ the/DT implementation/NN)
#   of/IN
#   (NP the/DT transformer/NN model/NN)
#   ./.)
#
# Sentence 4: could you please grant me an extension until december th i have attached my current progress file transformer_implementation_v.py.
# Detailed Constituency Tree (NP chunks):
#                                                                                    S
#     _______________________________________________________________________________|_________________________________________________________________
#    |        |        |        |       |       |        |          |          |     |         NP                             NP                       NP
#    |        |        |        |       |       |        |          |          |     |     ____|_______              _________|____         ___________|_____________________
# could/MD you/PRP please/VB grant/VB me/PRP until/IN have/VBP attached/VBN my/PRP$ ./. an/DT     extension/NN december/NNP th/NN i/NN current/JJ progress/NN file/NN transformer_impl
#                                                                                                                                                                     ementation_v.py/
#                                                                                                                                                                            NN
#
#
# Tree as string:
# (S
#   could/MD
#   you/PRP
#   please/VB
#   grant/VB
#   me/PRP
#   (NP an/DT extension/NN)
#   until/IN
#   (NP december/NNP th/NN i/NN)
#   have/VBP
#   attached/VBN
#   my/PRP$
#   (NP
#     current/JJ
#     progress/NN
#     file/NN
#     transformer_implementation_v.py/NN)
#   ./.)
#
# Sentence 5: thank you for your understanding.
# Detailed Constituency Tree (NP chunks):
#                    S
#     _______________|_________________________
#    |      |        |      |     NP           NP
#    |      |        |      |     |            |
# you/PRP for/IN your/PRP$ ./. thank/NN understanding/NN
#
#
# Tree as string:
# (S (NP thank/NN) you/PRP for/IN your/PRP$ (NP understanding/NN) ./.)
#
# Sentence 6: sincerely, michael chen student id cs michael.chenuniversity.edu
# Detailed Constituency Tree (NP chunks):
#                                 S
#       __________________________|__________________
#      |        |       |         |                  NP
#      |        |       |         |          ________|________________
# sincerely/RB ,/, michael/PRP chen/VBP student/JJ id/NN cs/NN michael.chenuniv
#                                                               ersity.edu/NN
#
#
# Tree as string:
# (S
#   sincerely/RB
#   ,/,
#   michael/PRP
#   chen/VBP
#   (NP student/JJ id/NN cs/NN michael.chenuniversity.edu/NN))

# %% [markdown]
# # 11. Hypernyms and Hyponyms (WordNet)

# %%
# Extract ALL unique words from filtered tokens
unique_words = list(set(filtered_tokens))

for word in unique_words:
    print(f"\nWORD: '{word}'")

    # Get synsets for the word
    synsets = wn.synsets(word)

    if not synsets:
        print(f"  No synsets found for '{word}'")
        continue

    # Take first synset
    synset = synsets[0]
    print(f"  Definition: {synset.definition()}")
    print(f"  Example: {synset.examples() if synset.examples() else 'No example'}")

    # Hypernyms (more general concepts)
    hypernyms = synset.hypernyms()
    if hypernyms:
        print(f"\n  HYPERNYMS (more general): {len(hypernyms)} found")
        for hyp in hypernyms:
            print(f"    → {hyp.name()}")
            print(f"      Definition: {hyp.definition()}")
            # Get path hypernyms (higher level)
            hyper_paths = hyp.hypernyms()
            if hyper_paths:
                for path_hyp in hyper_paths:
                    print(f"        ↑ {path_hyp.name()}: {path_hyp.definition()}")
    else:
        print(f"\n  HYPERNYMS: None found")

    # Hyponyms (more specific concepts)
    hyponyms = synset.hyponyms()
    if hyponyms:
        print(f"\n  HYPONYMS (more specific): {len(hyponyms)} found")
        for hyp in hyponyms:
            print(f"    → {hyp.name()}")
            print(f"      Definition: {hyp.definition()}")
    else:
        print(f"\n  HYPONYMS: None found")

    # Full hierarchy path (no depth limit)
    print(f"\n  HIERARCHY PATH (up to root):")
    def show_path(s, level=0):
        print(f"    {'  ' * level}└─ {s.name()}")
        for hyp in s.hypernyms():
            show_path(hyp, level + 1)

    show_path(synset)

# Detailed example for ALL specific words from the text
print("\nDETAILED EXAMPLE FOR KEY WORDS FROM TEXT")

key_words = ['apple', 'computer', 'company', 'inventor', 'founder', 'ceo', 'pixar', 'next']

for word in key_words:
    print(f"\nDEEP ANALYSIS FOR: '{word}'")

    synsets = wn.synsets(word)
    if synsets:
        primary_synset = synsets[0]

        print(f"  Definition: {primary_synset.definition()}")
        print(f"  Lemmas: {primary_synset.lemma_names()}")

        # Get all hypernym paths (no limit)
        print("\n  All Hypernym Paths:")
        hypernym_paths = primary_synset.hypernym_paths()
        for i, path in enumerate(hypernym_paths, 1):
            print(f"    Path {i}: {' -> '.join([s.name().split('.')[0] for s in path])}")

        # Get all hyponyms (no limit on display)
        all_hyponyms = primary_synset.hyponyms()
        print(f"\n  Total hyponyms found: {len(all_hyponyms)}")
        if all_hyponyms:
            print("  All hyponyms:")
            for hyp in all_hyponyms:
                print(f"    - {hyp.name()}: {hyp.definition()}")
# Out:
# WORD: 'writing'
#   Definition: the act of creating written works
#   Example: ['writing was a form of therapy for him', 'it was a matter of disputed authorship']
#
#   HYPERNYMS (more general): 1 found
#     → verbal_creation.n.01
#       Definition: creating something by the use of speech and language
#         ↑ creating_by_mental_acts.n.01: the act of creating something by thinking
#
#   HYPONYMS (more specific): 10 found
#     → dramatization.n.01
#       Definition: conversion into dramatic form
#     → novelization.n.01
#       Definition: converting something into the form of a novel
#     → drafting.n.01
#       Definition: writing a first version to be filled out and polished later
#     → versification.n.03
#       Definition: the art or practice of writing verse
#     → adoxography.n.01
#       Definition: fine writing in praise of trivial or base subjects
#     → fabrication.n.02
#       Definition: writing in a fictional form
#     → lexicography.n.01
#       Definition: the act of writing dictionaries
#     → historiography.n.02
#       Definition: the writing of history
#     → redaction.n.02
#       Definition: the act of putting something in writing
#     → metrification.n.01
#       Definition: writing a metrical composition (or the metrical structure of a composition)
#
#   HIERARCHY PATH (up to root):
#     └─ writing.n.01
#       └─ verbal_creation.n.01
#         └─ creating_by_mental_acts.n.01
#           └─ creation.n.01
#             └─ activity.n.01
#               └─ act.n.02
#                 └─ event.n.01
#                   └─ psychological_feature.n.01
#                     └─ abstraction.n.06
#                       └─ entity.n.01
#
# WORD: 'assignment'
#   Definition: a duty that you are assigned to perform (especially in the armed forces)
#   Example: ['hazardous duty']
#
#   HYPERNYMS (more general): 1 found
#     → duty.n.02
#       Definition: work that you are obliged to perform for moral or legal reasons
#         ↑ work.n.01: activity directed toward making or doing something
#
#   HYPONYMS (more specific): 6 found
#     → guard_duty.n.01
#       Definition: the duty of serving as a sentry
#     → fatigue_duty.n.01
#       Definition: labor of a nonmilitary kind done by soldiers (cleaning or digging or draining or so on)
#     → shore_duty.n.01
#       Definition: naval service at land bases
#     → mission.n.03
#       Definition: a special assignment that is given to a person or group
#     → sea-duty.n.01
#       Definition: naval service aboard a ship at sea
#     → reassignment.n.01
#       Definition: assignment to a different duty
#
#   HIERARCHY PATH (up to root):
#     └─ assignment.n.01
#       └─ duty.n.02
#         └─ work.n.01
#           └─ activity.n.01
#             └─ act.n.02
#               └─ event.n.01
#                 └─ psychological_feature.n.01
#                   └─ abstraction.n.06
#                     └─ entity.n.01
#
# WORD: 'michaelchenuniversityedu'
#   No synsets found for 'michaelchenuniversityedu'
#
# WORD: 'attached'
#   Definition: cause to be attached
#   Example: No example
#
#   HYPERNYMS (more general): 1 found
#     → connect.v.01
#       Definition: connect, fasten, or put together two or more pieces
#
#   HYPONYMS (more specific): 29 found
#     → fasten.v.03
#       Definition: attach to
#     → append.v.01
#       Definition: add to the very end
#     → fixate.v.03
#       Definition: make fixed, stable or stationary
#     → peg.v.03
#       Definition: fasten or secure with a wooden pin
#     → harness.v.01
#       Definition: put a harness
#     → affix.v.01
#       Definition: attach to
#     → hinge.v.01
#       Definition: attach with a hinge
#     → nail.v.01
#       Definition: attach something somewhere by means of nails
#     → bind.v.03
#       Definition: make fast; tie or secure, with or as if with a rope
#     → yoke.v.03
#       Definition: put a yoke on or join with a yoke
#     → limber.v.01
#       Definition: attach the limber
#     → bell.v.01
#       Definition: attach a bell to
#     → saddle.v.01
#       Definition: put a saddle on
#     → hitch.v.01
#       Definition: to hook or entangle
#     → hook_up.v.01
#       Definition: connect or link
#     → tag.v.01
#       Definition: attach a tag or label to
#     → mount.v.01
#       Definition: attach to a support
#     → affix.v.03
#       Definition: attach or become attached to a stem word
#     → yoke.v.02
#       Definition: link with or as with a yoke
#     → tape.v.01
#       Definition: fasten or attach with tape
#     → couple.v.02
#       Definition: link together
#     → tether.v.01
#       Definition: tie with a tether
#     → ring.v.06
#       Definition: attach a ring to the foot of, in order to identify
#     → glue.v.01
#       Definition: join or attach with or as if with glue
#     → fasten.v.01
#       Definition: cause to be firmly attached
#     → clip.v.03
#       Definition: attach with a clip
#     → pin_down.v.03
#       Definition: attach with or as if with a pin
#     → append.v.02
#       Definition: fix to; attach
#     → insert.v.01
#       Definition: put or introduce into something
#
#   HIERARCHY PATH (up to root):
#     └─ attach.v.01
#       └─ connect.v.01
#
# WORD: 'request'
#   Definition: a formal message requesting something that is submitted to an authority
#   Example: No example
#
#   HYPERNYMS (more general): 1 found
#     → message.n.02
#       Definition: what a communication that is about something is about
#         ↑ communication.n.02: something that is communicated by or to or between people or groups
#
#   HYPONYMS (more specific): 3 found
#     → solicitation.n.02
#       Definition: request for a sum of money
#     → application.n.02
#       Definition: a verbal or written request for assistance or employment or admission to a school
#     → demand.n.01
#       Definition: an urgent or peremptory request
#
#   HIERARCHY PATH (up to root):
#     └─ request.n.01
#       └─ message.n.02
#         └─ communication.n.02
#           └─ abstraction.n.06
#             └─ entity.n.01
#
# WORD: 'extension'
#   Definition: a mutually agreed delay in the date set for the completion of a job or payment of a debt
#   Example: ['they applied for an extension of the loan']
#
#   HYPERNYMS (more general): 1 found
#     → delay.n.01
#       Definition: time during which some action is awaited
#         ↑ pause.n.01: a time interval during which there is a temporary cessation of something
#
#   HYPONYMS: None found
#
#   HIERARCHY PATH (up to root):
#     └─ extension.n.01
#       └─ delay.n.01
#         └─ pause.n.01
#           └─ time_interval.n.01
#             └─ measure.n.02
#               └─ abstraction.n.06
#                 └─ entity.n.01
#
# WORD: 'december'
#   Definition: the last (12th) month of the year
#   Example: No example
#
#   HYPERNYMS (more general): 1 found
#     → gregorian_calendar_month.n.01
#       Definition: a month in the Gregorian calendar
#         ↑ calendar_month.n.01: one of the twelve divisions of the calendar year
#
#   HYPONYMS: None found
#
#   HIERARCHY PATH (up to root):
#     └─ december.n.01
#       └─ gregorian_calendar_month.n.01
#         └─ calendar_month.n.01
#           └─ time_period.n.01
#             └─ fundamental_quantity.n.01
#               └─ measure.n.02
#                 └─ abstraction.n.06
#                   └─ entity.n.01
#
# WORD: 'th'
#   Definition: the fifth day of the week; the fourth working day
#   Example: No example
#
#   HYPERNYMS (more general): 1 found
#     → weekday.n.01
#       Definition: any day except Sunday (and sometimes except Saturday)
#         ↑ day_of_the_week.n.01: any one of the seven days in a week
#
#   HYPONYMS: None found
#
#   HIERARCHY PATH (up to root):
#     └─ thursday.n.01
#       └─ weekday.n.01
#         └─ day_of_the_week.n.01
#           └─ calendar_day.n.01
#             └─ time_period.n.01
#               └─ fundamental_quantity.n.01
#                 └─ measure.n.02
#                   └─ abstraction.n.06
#                     └─ entity.n.01
#
# WORD: 'issues'
#   Definition: an important question that is in dispute and must be settled
#   Example: ['the issue could be settled by requiring public education for everyone', 'politicians never discuss the real issues']
#
#   HYPERNYMS (more general): 1 found
#     → content.n.05
#       Definition: the sum or range of what has been perceived, discovered, or learned
#         ↑ cognition.n.01: the psychological result of perception and learning and reasoning
#
#   HYPONYMS (more specific): 4 found
#     → quodlibet.n.01
#       Definition: an issue that is presented for formal disputation
#     → paramount_issue.n.01
#       Definition: an issue whose settlement is more important than anything else; and issue that must be settled before anything else can be settled
#     → gut_issue.n.01
#       Definition: an issue that elicits strong emotional reactions
#     → pocketbook_issue.n.01
#       Definition: an issue whose settlement will affect financial resources
#
#   HIERARCHY PATH (up to root):
#     └─ issue.n.01
#       └─ content.n.05
#         └─ cognition.n.01
#           └─ psychological_feature.n.01
#             └─ abstraction.n.06
#               └─ entity.n.01
#
# WORD: 'email'
#   Definition: (computer science) a system of world-wide electronic communication in which a computer user can compose a message at one terminal that can be regenerated at the recipient's terminal when the recipient logs in
#   Example: ['you cannot send packages by electronic mail']
#
#   HYPERNYMS (more general): 1 found
#     → electronic_communication.n.01
#       Definition: communication by computer
#         ↑ transmission.n.02: communication by means of transmitted signals
#
#   HYPONYMS (more specific): 2 found
#     → spam.n.02
#       Definition: unwanted e-mail (usually of a commercial nature sent out in bulk)
#     → freemail.n.01
#       Definition: a service providing free email delivery in exchange for exposure to advertising
#
#   HIERARCHY PATH (up to root):
#     └─ electronic_mail.n.01
#       └─ electronic_communication.n.01
#         └─ transmission.n.02
#           └─ communication.n.01
#             └─ act.n.02
#               └─ event.n.01
#                 └─ psychological_feature.n.01
#                   └─ abstraction.n.06
#                     └─ entity.n.01
#
# WORD: 'cs'
#   Definition: a soft silver-white ductile metallic element (liquid at normal temperatures); the most electropositive and alkaline metal
#   Example: No example
#
#   HYPERNYMS (more general): 1 found
#     → metallic_element.n.01
#       Definition: any of several chemical elements that are usually shiny solids that conduct heat or electricity and can be formed into sheets etc.
#         ↑ chemical_element.n.01: any of the more than 100 known substances (of which 92 occur naturally) that cannot be separated into simpler substances and that singly or in combination constitute all matter
#
#   HYPONYMS (more specific): 1 found
#     → cesium_137.n.01
#       Definition: a radioactive isotope of cesium used in radiation therapy
#
#   HIERARCHY PATH (up to root):
#     └─ cesium.n.01
#       └─ metallic_element.n.01
#         └─ chemical_element.n.01
#           └─ substance.n.01
#             └─ matter.n.03
#               └─ physical_entity.n.01
#                 └─ entity.n.01
#             └─ part.n.01
#               └─ relation.n.01
#                 └─ abstraction.n.06
#                   └─ entity.n.01
#
# WORD: 'python'
#   Definition: large Old World boas
#   Example: No example
#
#   HYPERNYMS (more general): 1 found
#     → boa.n.02
#       Definition: any of several chiefly tropical constrictors with vestigial hind limbs
#         ↑ constrictor.n.01: any of various large nonvenomous snakes that kill their prey by crushing it in its coils
#
#   HYPONYMS (more specific): 5 found
#     → carpet_snake.n.01
#       Definition: Australian python with a variegated pattern on its back
#     → indian_python.n.01
#       Definition: very large python of southeast Asia
#     → rock_python.n.01
#       Definition: very large python of tropical and southern Africa
#     → amethystine_python.n.01
#       Definition: a python having the color of amethyst
#     → reticulated_python.n.01
#       Definition: of southeast Asia and East Indies; the largest snake in the world
#
#   HIERARCHY PATH (up to root):
#     └─ python.n.01
#       └─ boa.n.02
#         └─ constrictor.n.01
#           └─ snake.n.01
#             └─ diapsid.n.01
#               └─ reptile.n.01
#                 └─ vertebrate.n.01
#                   └─ chordate.n.01
#                     └─ animal.n.01
#                       └─ organism.n.01
#                         └─ living_thing.n.01
#                           └─ whole.n.02
#                             └─ object.n.01
#                               └─ physical_entity.n.01
#                                 └─ entity.n.01
#
# WORD: 'michael'
#   Definition: (Old Testament) the guardian archangel of the Jews
#   Example: No example
#
#   HYPERNYMS (more general): 1 found
#     → archangel.n.01
#       Definition: an angel ranked above the highest rank in the celestial hierarchy
#         ↑ angel.n.01: spiritual being attendant upon God
#
#   HYPONYMS: None found
#
#   HIERARCHY PATH (up to root):
#     └─ michael.n.01
#       └─ archangel.n.01
#         └─ angel.n.01
#           └─ spiritual_being.n.01
#             └─ belief.n.01
#               └─ content.n.05
#                 └─ cognition.n.01
#                   └─ psychological_feature.n.01
#                     └─ abstraction.n.06
#                       └─ entity.n.01
#
# WORD: 'professor'
#   Definition: someone who is a member of the faculty at a college or university
#   Example: No example
#
#   HYPERNYMS (more general): 1 found
#     → academician.n.03
#       Definition: an educator who works at a college or university
#         ↑ educator.n.01: someone who educates young people
#
#   HYPONYMS (more specific): 5 found
#     → full_professor.n.01
#       Definition: a professor of the highest rank
#     → assistant_professor.n.01
#       Definition: a teacher or lower rank than an associate professor
#     → associate_professor.n.01
#       Definition: a teacher lower in rank than a full professor but higher than an assistant professor
#     → visiting_professor.n.01
#       Definition: a professor visiting another college or university to teach for a limited time
#     → regius_professor.n.01
#       Definition: holder of a British professorship created by a royal patron
#
#   HIERARCHY PATH (up to root):
#     └─ professor.n.01
#       └─ academician.n.03
#         └─ educator.n.01
#           └─ professional.n.01
#             └─ adult.n.01
#               └─ person.n.01
#                 └─ organism.n.01
#                   └─ living_thing.n.01
#                     └─ whole.n.02
#                       └─ object.n.01
#                         └─ physical_entity.n.01
#                           └─ entity.n.01
#                 └─ causal_agent.n.01
#                   └─ physical_entity.n.01
#                     └─ entity.n.01
#
# WORD: 'dear'
#   Definition: a beloved person; used as terms of endearment
#   Example: No example
#
#   HYPERNYMS (more general): 1 found
#     → lover.n.01
#       Definition: a person who loves someone or is loved by someone
#         ↑ person.n.01: a human being
#
#   HYPONYMS: None found
#
#   HIERARCHY PATH (up to root):
#     └─ beloved.n.01
#       └─ lover.n.01
#         └─ person.n.01
#           └─ organism.n.01
#             └─ living_thing.n.01
#               └─ whole.n.02
#                 └─ object.n.01
#                   └─ physical_entity.n.01
#                     └─ entity.n.01
#           └─ causal_agent.n.01
#             └─ physical_entity.n.01
#               └─ entity.n.01
#
# WORD: 'due'
#   Definition: that which is deserved or owed
#   Example: ['give the devil his due']
#
#   HYPERNYMS (more general): 1 found
#     → right.n.01
#       Definition: an abstract idea of that which is due to a person or governmental body by law or tradition or nature; ; - Eleanor Roosevelt
#         ↑ abstraction.n.01: a concept or idea not associated with any specific instance
#
#   HYPONYMS: None found
#
#   HIERARCHY PATH (up to root):
#     └─ due.n.01
#       └─ right.n.01
#         └─ abstraction.n.01
#           └─ concept.n.01
#             └─ idea.n.01
#               └─ content.n.05
#                 └─ cognition.n.01
#                   └─ psychological_feature.n.01
#                     └─ abstraction.n.06
#                       └─ entity.n.01
#
# WORD: 'transformerimplementationvpy'
#   No synsets found for 'transformerimplementationvpy'
#
# WORD: 'transformer'
#   Definition: an electrical device by which alternating current of one voltage is changed to another voltage
#   Example: No example
#
#   HYPERNYMS (more general): 1 found
#     → electrical_device.n.01
#       Definition: a device that produces or is powered by electricity
#         ↑ device.n.01: an instrumentality invented for a particular purpose
#
#   HYPONYMS (more specific): 5 found
#     → voltage_regulator.n.01
#       Definition: a transformer whose voltage ratio of transformation can be adjusted
#     → step-up_transformer.n.01
#       Definition: a transformer that increases voltage
#     → tesla_coil.n.01
#       Definition: a step-up transformer with an air core; used to produce high voltages at high frequencies
#     → coil.n.03
#       Definition: a transformer that supplies high voltage to spark plugs in a gasoline engine
#     → step-down_transformer.n.01
#       Definition: a transformer that reduces voltage
#
#   HIERARCHY PATH (up to root):
#     └─ transformer.n.01
#       └─ electrical_device.n.01
#         └─ device.n.01
#           └─ instrumentality.n.03
#             └─ artifact.n.01
#               └─ whole.n.02
#                 └─ object.n.01
#                   └─ physical_entity.n.01
#                     └─ entity.n.01
#
# WORD: 'unexpected'
#   Definition: not expected or anticipated
#   Example: ['unexpected guests', 'unexpected news']
#
#   HYPERNYMS: None found
#
#   HYPONYMS: None found
#
#   HIERARCHY PATH (up to root):
#     └─ unexpected.a.01
#
# WORD: 'progress'
#   Definition: gradual improvement or growth or development
#   Example: ['advancement of knowledge', 'great progress in the arts']
#
#   HYPERNYMS (more general): 1 found
#     → development.n.01
#       Definition: act of improving by expanding or enlarging or refining
#         ↑ improvement.n.02: the act of improving something
#
#   HYPONYMS (more specific): 3 found
#     → stride.n.03
#       Definition: significant progress (especially in the phrase )
#     → forwarding.n.02
#       Definition: the advancement of some enterprise
#     → work_flow.n.01
#       Definition: progress (or rate of progress) in work being done
#
#   HIERARCHY PATH (up to root):
#     └─ advancement.n.03
#       └─ development.n.01
#         └─ improvement.n.02
#           └─ change_of_state.n.01
#             └─ change.n.03
#               └─ action.n.01
#                 └─ act.n.02
#                   └─ event.n.01
#                     └─ psychological_feature.n.01
#                       └─ abstraction.n.06
#                         └─ entity.n.01
#
# WORD: 'understanding'
#   Definition: the cognitive condition of someone who understands
#   Example: ['he has virtually no understanding of social cause and effect']
#
#   HYPERNYMS (more general): 1 found
#     → knowing.n.01
#       Definition: a clear and certain mental apprehension
#         ↑ higher_cognitive_process.n.01: cognitive processes that presuppose the availability of knowledge and put it to use
#
#   HYPONYMS (more specific): 8 found
#     → insight.n.03
#       Definition: the clear (and often sudden) understanding of a complex situation
#     → self-knowledge.n.01
#       Definition: an understanding of yourself and your goals and abilities
#     → realization.n.01
#       Definition: coming to understand something clearly and distinctly
#     → grasping.n.01
#       Definition: understanding with difficulty
#     → smattering.n.02
#       Definition: a slight or superficial understanding of a subject
#     → appreciation.n.01
#       Definition: understanding of the nature or meaning or quality or magnitude of something
#     → hindsight.n.01
#       Definition: understanding the nature of an event after it has happened
#     → comprehension.n.01
#       Definition: an ability to understand the meaning or importance of something (or the knowledge acquired as a result)
#
#   HIERARCHY PATH (up to root):
#     └─ understanding.n.01
#       └─ knowing.n.01
#         └─ higher_cognitive_process.n.01
#           └─ process.n.02
#             └─ cognition.n.01
#               └─ psychological_feature.n.01
#                 └─ abstraction.n.06
#                   └─ entity.n.01
#
# WORD: 'pycharm'
#   No synsets found for 'pycharm'
#
# WORD: 'hope'
#   Definition: a specific instance of feeling hopeful
#   Example: ['it revived their hope of winning the pennant']
#
#   HYPERNYMS (more general): 1 found
#     → anticipation.n.01
#       Definition: an expectation
#         ↑ expectation.n.03: the feeling that something is about to happen
#
#   HYPONYMS: None found
#
#   HIERARCHY PATH (up to root):
#     └─ hope.n.01
#       └─ anticipation.n.01
#         └─ expectation.n.03
#           └─ feeling.n.01
#             └─ state.n.02
#               └─ attribute.n.02
#                 └─ abstraction.n.06
#                   └─ entity.n.01
#
# WORD: 'thank'
#   Definition: express gratitude or show appreciation to
#   Example: No example
#
#   HYPERNYMS (more general): 1 found
#     → convey.v.01
#       Definition: make known; pass on, of information
#         ↑ impart.v.01: transmit (knowledge or skills)
#
#   HYPONYMS (more specific): 1 found
#     → acknowledge.v.04
#       Definition: express obligation, thanks, or gratitude for
#
#   HIERARCHY PATH (up to root):
#     └─ thank.v.01
#       └─ convey.v.01
#         └─ impart.v.01
#           └─ tell.v.02
#             └─ inform.v.01
#               └─ communicate.v.02
#                 └─ interact.v.01
#                   └─ act.v.01
#
# WORD: 'sincerely'
#   Definition: with sincerity; without pretense
#   Example: ['she praised him sincerely for his victory', 'was unfeignedly glad to see his old teacher', 'we are truly sorry for the inconvenience']
#
#   HYPERNYMS: None found
#
#   HYPONYMS: None found
#
#   HIERARCHY PATH (up to root):
#     └─ sincerely.r.01
#
# WORD: 'environment'
#   Definition: the totality of surrounding conditions
#   Example: ['he longed for the comfortable environment of his living room']
#
#   HYPERNYMS (more general): 1 found
#     → situation.n.01
#       Definition: the general state of things; the combination of circumstances at a given time; ; ; - Franklin D.Roosevelt
#         ↑ state.n.02: the way something is with respect to its main attributes
#
#   HYPONYMS (more specific): 7 found
#     → context.n.02
#       Definition: the set of facts or circumstances that surround a situation or event
#     → street.n.03
#       Definition: the streets of a city viewed as a depressed environment in which there is poverty and crime and prostitution and dereliction
#     → home.n.07
#       Definition: an environment offering affection and security
#     → milieu.n.01
#       Definition: the environmental condition
#     → setting.n.02
#       Definition: the state of the environment in which a situation exists
#     → sphere.n.01
#       Definition: a particular environment or walk of life
#     → ecology.n.01
#       Definition: the environment as it relates to living organisms
#
#   HIERARCHY PATH (up to root):
#     └─ environment.n.01
#       └─ situation.n.01
#         └─ state.n.02
#           └─ attribute.n.02
#             └─ abstraction.n.06
#               └─ entity.n.01
#
# WORD: 'file'
#   Definition: a set of related records (either written or electronic) kept together
#   Example: No example
#
#   HYPERNYMS (more general): 1 found
#     → record.n.01
#       Definition: anything (such as a document or a phonograph record or a photograph) providing permanent evidence of or information about past events
#         ↑ evidence.n.02: an indication that makes something evident
#
#   HYPONYMS (more specific): 3 found
#     → tickler.n.01
#       Definition: a file of memoranda or notices that remind of things to be done
#     → mug_file.n.01
#       Definition: a file of mug shots (pictures of criminals that are kept on file by the police)
#     → computer_file.n.01
#       Definition: (computer science) a file maintained in computer-readable form
#
#   HIERARCHY PATH (up to root):
#     └─ file.n.01
#       └─ record.n.01
#         └─ evidence.n.02
#           └─ indication.n.01
#             └─ communication.n.02
#               └─ abstraction.n.06
#                 └─ entity.n.01
#
# WORD: 'local'
#   Definition: public transport consisting of a bus or train that stops at all stations or stops
#   Example: ['the local seemed to take forever to get to New York']
#
#   HYPERNYMS (more general): 1 found
#     → public_transport.n.01
#       Definition: conveyance for passengers or mail or freight
#         ↑ conveyance.n.03: something that serves as a means of transportation
#
#   HYPONYMS: None found
#
#   HIERARCHY PATH (up to root):
#     └─ local.n.01
#       └─ public_transport.n.01
#         └─ conveyance.n.03
#           └─ instrumentality.n.03
#             └─ artifact.n.01
#               └─ whole.n.02
#                 └─ object.n.01
#                   └─ physical_entity.n.01
#                     └─ entity.n.01
#
# WORD: 'current'
#   Definition: a flow of electricity through a conductor
#   Example: ['the current was measured in amperes']
#
#   HYPERNYMS (more general): 1 found
#     → electrical_phenomenon.n.01
#       Definition: a physical phenomenon involving electricity
#         ↑ physical_phenomenon.n.01: a natural phenomenon involving the physical properties of matter and energy
#
#   HYPONYMS (more specific): 2 found
#     → juice.n.03
#       Definition: electric current
#     → thermionic_current.n.01
#       Definition: an electric current produced between two electrodes as a result of electrons emitted by thermionic emission
#
#   HIERARCHY PATH (up to root):
#     └─ current.n.01
#       └─ electrical_phenomenon.n.01
#         └─ physical_phenomenon.n.01
#           └─ natural_phenomenon.n.01
#             └─ phenomenon.n.01
#               └─ process.n.06
#                 └─ physical_entity.n.01
#                   └─ entity.n.01
#
# WORD: 'grant'
#   Definition: any monetary aid
#   Example: No example
#
#   HYPERNYMS (more general): 1 found
#     → aid.n.03
#       Definition: money to support a worthy person or cause
#         ↑ gift.n.01: something acquired without compensation
#
#   HYPONYMS (more specific): 2 found
#     → subsidy.n.01
#       Definition: a grant paid by a government to an enterprise that benefits the public
#     → grant-in-aid.n.02
#       Definition: a grant to a person or school for some educational project
#
#   HIERARCHY PATH (up to root):
#     └─ grant.n.01
#       └─ aid.n.03
#         └─ gift.n.01
#           └─ acquisition.n.02
#             └─ transferred_property.n.01
#               └─ possession.n.02
#                 └─ relation.n.01
#                   └─ abstraction.n.06
#                     └─ entity.n.01
#
# WORD: 'complete'
#   Definition: come or bring to a finish or an end
#   Example: ['He finished the dishes', "She completed the requirements for her Master's Degree", 'The fastest runner finished the race in just over 2 hours; others finished in over 4 hours']
#
#   HYPERNYMS (more general): 1 found
#     → end.v.02
#       Definition: bring to an end or halt
#         ↑ change.v.01: cause to change; make different; cause a transformation
#
#   HYPONYMS (more specific): 7 found
#     → follow_through.v.02
#       Definition: pursue to a conclusion or bring to a successful issue
#     → top.v.10
#       Definition: finish up or conclude
#     → get_through.v.01
#       Definition: finish a task completely
#     → close.v.17
#       Definition: finish a game in baseball by protecting a lead
#     → round_out.v.01
#       Definition: fill out
#     → see_through.v.03
#       Definition: remain with until completion
#     → carry_through.v.01
#       Definition: put in effect
#
#   HIERARCHY PATH (up to root):
#     └─ complete.v.01
#       └─ end.v.02
#         └─ change.v.01
#
# WORD: 'id'
#   Definition: a state in the Rocky Mountains
#   Example: No example
#
#   HYPERNYMS: None found
#
#   HYPONYMS: None found
#
#   HIERARCHY PATH (up to root):
#     └─ idaho.n.01
#
# WORD: 'implementation'
#   Definition: the act of accomplishing some aim or executing some order
#   Example: ['the agency was created for the implementation of the policy']
#
#   HYPERNYMS (more general): 1 found
#     → enforcement.n.01
#       Definition: the act of enforcing; ensuring observance of or obedience to
#         ↑ social_control.n.01: control exerted (actively or passively) by group action
#
#   HYPONYMS: None found
#
#   HIERARCHY PATH (up to root):
#     └─ execution.n.06
#       └─ enforcement.n.01
#         └─ social_control.n.01
#           └─ group_action.n.01
#             └─ event.n.01
#               └─ psychological_feature.n.01
#                 └─ abstraction.n.06
#                   └─ entity.n.01
#             └─ act.n.02
#               └─ event.n.01
#                 └─ psychological_feature.n.01
#                   └─ abstraction.n.06
#                     └─ entity.n.01
#
# WORD: 'could'
#   No synsets found for 'could'
#
# WORD: 'student'
#   Definition: a learner who is enrolled in an educational institution
#   Example: No example
#
#   HYPERNYMS (more general): 1 found
#     → enrollee.n.01
#       Definition: a person who enrolls in (or is enrolled in) a class or course of study
#         ↑ person.n.01: a human being
#
#   HYPONYMS (more specific): 20 found
#     → sixth-former.n.01
#       Definition: a student in the sixth form
#     → law_student.n.01
#       Definition: a student in law school
#     → withdrawer.n.05
#       Definition: a student who withdraws from the educational institution in which he or she was enrolled
#     → wykehamist.n.01
#       Definition: a student enrolled in (or graduated from) Winchester College
#     → seminarian.n.01
#       Definition: a student at a seminary (especially a Roman Catholic seminary)
#     → medical_student.n.01
#       Definition: a student in medical school
#     → underachiever.n.01
#       Definition: a student who does not perform as well as expected or as well as the IQ indicates
#     → scholar.n.03
#       Definition: a student who holds a scholarship
#     → art_student.n.01
#       Definition: someone studying to be an artist
#     → major.n.03
#       Definition: a university student who is studying a particular field as the principal subject
#     → etonian.n.01
#       Definition: a student enrolled in (or graduated from) Eton College
#     → nonreader.n.01
#       Definition: a student who is very slow in learning to read
#     → auditor.n.02
#       Definition: a student who attends a course but does not take it for credit
#     → catechumen.n.01
#       Definition: a new convert being taught the principles of Christianity by a catechist
#     → overachiever.n.01
#       Definition: a student who attains higher standards than the IQ indicated
#     → skipper.n.01
#       Definition: a student who fails to attend classes
#     → ivy_leaguer.n.01
#       Definition: a student or graduate at an Ivy League school
#     → passer.n.03
#       Definition: a student who passes an examination
#     → collegian.n.01
#       Definition: a student (or former student) at a college or university
#     → crammer.n.01
#       Definition: a student who crams
#
#   HIERARCHY PATH (up to root):
#     └─ student.n.01
#       └─ enrollee.n.01
#         └─ person.n.01
#           └─ organism.n.01
#             └─ living_thing.n.01
#               └─ whole.n.02
#                 └─ object.n.01
#                   └─ physical_entity.n.01
#                     └─ entity.n.01
#           └─ causal_agent.n.01
#             └─ physical_entity.n.01
#               └─ entity.n.01
#
# WORD: 'technical'
#   Definition: a pickup truck with a gun mounted on it
#   Example: No example
#
#   HYPERNYMS (more general): 2 found
#     → pickup.n.01
#       Definition: a light truck with an open body and low sides and a tailboard
#         ↑ truck.n.01: an automotive vehicle suitable for hauling
#     → military_vehicle.n.01
#       Definition: vehicle used by the armed forces
#         ↑ vehicle.n.01: a conveyance that transports people or objects
#
#   HYPONYMS: None found
#
#   HIERARCHY PATH (up to root):
#     └─ technical.n.01
#       └─ pickup.n.01
#         └─ truck.n.01
#           └─ motor_vehicle.n.01
#             └─ self-propelled_vehicle.n.01
#               └─ wheeled_vehicle.n.01
#                 └─ container.n.01
#                   └─ instrumentality.n.03
#                     └─ artifact.n.01
#                       └─ whole.n.02
#                         └─ object.n.01
#                           └─ physical_entity.n.01
#                             └─ entity.n.01
#                 └─ vehicle.n.01
#                   └─ conveyance.n.03
#                     └─ instrumentality.n.03
#                       └─ artifact.n.01
#                         └─ whole.n.02
#                           └─ object.n.01
#                             └─ physical_entity.n.01
#                               └─ entity.n.01
#       └─ military_vehicle.n.01
#         └─ vehicle.n.01
#           └─ conveyance.n.03
#             └─ instrumentality.n.03
#               └─ artifact.n.01
#                 └─ whole.n.02
#                   └─ object.n.01
#                     └─ physical_entity.n.01
#                       └─ entity.n.01
#
# WORD: 'williams'
#   Definition: United States country singer and songwriter (1923-1953)
#   Example: No example
#
#   HYPERNYMS: None found
#
#   HYPONYMS: None found
#
#   HIERARCHY PATH (up to root):
#     └─ williams.n.01
#
# WORD: 'nlp'
#   Definition: the branch of information science that deals with natural language information
#   Example: No example
#
#   HYPERNYMS (more general): 1 found
#     → information_science.n.01
#       Definition: the sciences concerned with gathering, manipulating, storing, retrieving, and classifying recorded information
#         ↑ science.n.01: a particular branch of scientific knowledge
#
#   HYPONYMS: None found
#
#   HIERARCHY PATH (up to root):
#     └─ natural_language_processing.n.01
#       └─ information_science.n.01
#         └─ science.n.01
#           └─ discipline.n.01
#             └─ knowledge_domain.n.01
#               └─ content.n.05
#                 └─ cognition.n.01
#                   └─ psychological_feature.n.01
#                     └─ abstraction.n.06
#                       └─ entity.n.01
#
# WORD: 'finds'
#   Definition: a productive insight
#   Example: No example
#
#   HYPERNYMS (more general): 1 found
#     → insight.n.03
#       Definition: the clear (and often sudden) understanding of a complex situation
#         ↑ understanding.n.01: the cognitive condition of someone who understands
#
#   HYPONYMS: None found
#
#   HIERARCHY PATH (up to root):
#     └─ discovery.n.03
#       └─ insight.n.03
#         └─ understanding.n.01
#           └─ knowing.n.01
#             └─ higher_cognitive_process.n.01
#               └─ process.n.02
#                 └─ cognition.n.01
#                   └─ psychological_feature.n.01
#                     └─ abstraction.n.06
#                       └─ entity.n.01
#
# WORD: 'couldnt'
#   No synsets found for 'couldnt'
#
# WORD: 'well'
#   Definition: a deep hole or shaft dug or drilled to obtain water or oil or gas or brine
#   Example: No example
#
#   HYPERNYMS (more general): 1 found
#     → excavation.n.03
#       Definition: a hole in the ground made by excavating
#         ↑ artifact.n.01: a man-made object taken as a whole
#
#   HYPONYMS (more specific): 5 found
#     → gas_well.n.01
#       Definition: a well that yields or has yielded natural gas
#     → oil_well.n.01
#       Definition: a well that yields or has yielded oil
#     → sump.n.02
#       Definition: a well or other hole in which water has collected
#     → driven_well.n.01
#       Definition: a well made by driving a tube into the earth to a stratum that bears water
#     → artesian_well.n.01
#       Definition: a well drilled through impermeable strata into strata that receive water from a higher altitude so there is pressure to force the water to flow upward
#
#   HIERARCHY PATH (up to root):
#     └─ well.n.01
#       └─ excavation.n.03
#         └─ artifact.n.01
#           └─ whole.n.02
#             └─ object.n.01
#               └─ physical_entity.n.01
#                 └─ entity.n.01
#
# WORD: 'model'
#   Definition: a hypothetical description of a complex entity or process
#   Example: ['the computer program was based on a model of the circulatory and respiratory systems']
#
#   HYPERNYMS (more general): 1 found
#     → hypothesis.n.02
#       Definition: a tentative insight into the natural world; a concept that is not yet verified but that if true would explain certain facts or phenomena
#         ↑ concept.n.01: an abstract or general idea inferred or derived from specific instances
#
#   HYPONYMS (more specific): 7 found
#     → string_theory.n.01
#       Definition: (particle physics) a theory that postulates that subatomic particles are one-dimensional strings
#     → ptolemaic_system.n.01
#       Definition: (astronomy) Ptolemy's model of the universe with the Earth at the center
#     → stochastic_process.n.01
#       Definition: a statistical process involving a number of random variables depending on a variable parameter (which is usually time)
#     → simulation.n.02
#       Definition: (computer science) the technique of representing the real world by a computer program
#     → copernican_system.n.01
#       Definition: (astronomy) Copernicus' astronomical model in which the Earth rotates around the sun
#     → mean_sun.n.01
#       Definition: a theoretical sun that moves along the celestial equator at a constant speed and completes its annual course in the same amount of time the real sun takes at variable speeds
#     → m-theory.n.01
#       Definition: (particle physics) a theory that involves an eleven-dimensional universe in which the weak and strong forces and gravity are unified and to which all the string theories belong
#
#   HIERARCHY PATH (up to root):
#     └─ model.n.01
#       └─ hypothesis.n.02
#         └─ concept.n.01
#           └─ idea.n.01
#             └─ content.n.05
#               └─ cognition.n.01
#                 └─ psychological_feature.n.01
#                   └─ abstraction.n.06
#                     └─ entity.n.01
#
# WORD: 'chen'
#   Definition: wild goose having white adult plumage
#   Example: No example
#
#   HYPERNYMS (more general): 1 found
#     → bird_genus.n.01
#       Definition: a genus of birds
#         ↑ genus.n.02: (biology) taxonomic group containing one or more species
#
#   HYPONYMS: None found
#
#   HIERARCHY PATH (up to root):
#     └─ chen.n.01
#       └─ bird_genus.n.01
#         └─ genus.n.02
#           └─ taxonomic_group.n.01
#             └─ biological_group.n.01
#               └─ group.n.01
#                 └─ abstraction.n.06
#                   └─ entity.n.01
#
# WORD: 'please'
#   Definition: give pleasure to or be pleasing to
#   Example: ['These colors please the senses', 'a pleasing sensation']
#
#   HYPERNYMS (more general): 1 found
#     → satisfy.v.02
#       Definition: make happy or satisfied
#
#   HYPONYMS (more specific): 2 found
#     → endear.v.01
#       Definition: make attractive or lovable
#     → enchant.v.01
#       Definition: hold spellbound
#
#   HIERARCHY PATH (up to root):
#     └─ please.v.01
#       └─ satisfy.v.02
#
# DETAILED EXAMPLE FOR KEY WORDS FROM TEXT
#
# DEEP ANALYSIS FOR: 'apple'
#   Definition: fruit with red or yellow or green skin and sweet to tart crisp whitish flesh
#   Lemmas: ['apple']
#
#   All Hypernym Paths:
#     Path 1: entity -> physical_entity -> matter -> solid -> food -> produce -> edible_fruit -> apple
#     Path 2: entity -> physical_entity -> object -> whole -> natural_object -> plant_part -> plant_organ -> reproductive_structure -> fruit -> edible_fruit -> apple
#     Path 3: entity -> physical_entity -> object -> whole -> natural_object -> plant_part -> plant_organ -> reproductive_structure -> fruit -> pome -> apple
#
#   Total hyponyms found: 3
#   All hyponyms:
#     - crab_apple.n.03: small sour apple; suitable for preserving
#     - cooking_apple.n.01: an apple used primarily in cooking for pies and applesauce etc
#     - eating_apple.n.01: an apple used primarily for eating raw without cooking
#
# DEEP ANALYSIS FOR: 'computer'
#   Definition: a machine for performing calculations automatically
#   Lemmas: ['computer', 'computing_machine', 'computing_device', 'data_processor', 'electronic_computer', 'information_processing_system']
#
#   All Hypernym Paths:
#     Path 1: entity -> physical_entity -> object -> whole -> artifact -> instrumentality -> device -> machine -> computer
#
#   Total hyponyms found: 10
#   All hyponyms:
#     - predictor.n.03: a computer for controlling antiaircraft fire that computes the position of an aircraft at the instant of a shell's arrival
#     - web_site.n.01: a computer connected to the internet that maintains a series of web pages on the World Wide Web
#     - server.n.03: (computer science) a computer that provides client stations with access to files and printers as shared resources to a computer network
#     - turing_machine.n.01: a hypothetical computer with an infinitely long memory tape
#     - number_cruncher.n.02: a computer capable of performing a large number of mathematical operations per second
#     - analog_computer.n.01: a computer that represents information by variable quantities (e.g., positions or voltages)
#     - home_computer.n.01: a computer intended for use in the home
#     - pari-mutuel_machine.n.01: computer that registers bets and divides the total amount bet among those who won
#     - node.n.08: (computer science) any computer that is hooked up to a computer network
#     - digital_computer.n.01: a computer that represents information by numerical (binary) digits
#
# DEEP ANALYSIS FOR: 'company'
#   Definition: an institution created to conduct business
#   Lemmas: ['company']
#
#   All Hypernym Paths:
#     Path 1: entity -> abstraction -> group -> social_group -> organization -> institution -> company
#
#   Total hyponyms found: 36
#   All hyponyms:
#     - limited_company.n.01: a company that is organized to give its owners limited liability
#     - livery_company.n.01: one of the chartered companies of London originating with the craft guilds
#     - record_company.n.01: a company that makes and sells musical recordings
#     - electronics_company.n.01: a company that makes and sells electronic instruments
#     - subsidiary_company.n.01: a company that is completely controlled by another company
#     - corporate_investor.n.01: a company that invests in (acquires control of) other companies
#     - car_company.n.01: a company that makes and sells automobiles
#     - packaging_company.n.01: a company that packages goods for sale or shipment or storage
#     - holding_company.n.01: a company with controlling shares in other companies
#     - target_company.n.01: a company that has been chosen as attractive for takeover by a potential acquirer
#     - east_india_company.n.01: an English company formed in 1600 to develop trade with the new British colonies in India and southeastern Asia; in the 18th century it assumed administrative control of Bengal and held it until the British army took over in 1858 after the Indian Mutiny
#     - oil_company.n.01: a company that sells oil
#     - bureau_de_change.n.01: (French) an establishment where you can exchange foreign money
#     - closed_shop.n.01: a company that hires only union members
#     - broadcasting_company.n.01: a company that manages tv or radio stations
#     - furniture_company.n.01: a company that sells furniture
#     - dot-com.n.01: a company that operates its business primarily on the internet using a URL that ends in `.com'
#     - think_tank.n.01: a company that does research for hire and issues reports on the implications
#     - shipping_company.n.01: a company that provides shipping services
#     - food_company.n.01: a company that processes and sells food
#     - steel_company.n.01: a company that makes and sells steel
#     - transportation_company.n.01: a company providing transportation
#     - union_shop.n.01: a company allowed to hire nonunion workers on the condition that they will join the union within a specified time
#     - mover.n.04: a company that moves the possessions of a family or business from one site to another
#     - mining_company.n.01: a company that owns and manages mines
#     - open_shop.n.01: a company whose workers are hired without regard to their membership in a labor union
#     - pipeline_company.n.01: a company that operates oil pipelines for the oil industry
#     - joint-stock_company.n.01: a company (usually unincorporated) which has the capital of its members pooled in a common fund; transferable shares represent ownership interest; shareholders are legally liable for all debts of the company
#     - stock_company.n.01: a company whose capital is represented by stock
#     - white_knight.n.01: a company that is a friendly acquirer in a takeover
#     - printing_concern.n.01: a company that does commercial printing
#     - film_company.n.01: a company that makes, advertises, and distributes movies
#     - distributor.n.03: a company that markets merchandise
#     - drug_company.n.01: a company that makes and sells pharmaceuticals
#     - shipper.n.02: a company in the business of shipping freight
#     - service.n.04: a company or agency that performs a public service; subject to government regulation
#
# DEEP ANALYSIS FOR: 'inventor'
#   Definition: someone who is the first to think of or make something
#   Lemmas: ['inventor', 'discoverer', 'artificer']
#
#   All Hypernym Paths:
#     Path 1: entity -> physical_entity -> object -> whole -> living_thing -> organism -> person -> creator -> inventor
#     Path 2: entity -> physical_entity -> causal_agent -> person -> creator -> inventor
#
#   Total hyponyms found: 1
#   All hyponyms:
#     - patentee.n.01: the inventor to whom a patent is issued
#
# DEEP ANALYSIS FOR: 'founder'
#   Definition: inflammation of the laminated tissue that attaches the hoof to the foot of a horse
#   Lemmas: ['laminitis', 'founder']
#
#   All Hypernym Paths:
#     Path 1: entity -> abstraction -> psychological_feature -> cognition -> information -> evidence -> symptom -> inflammation -> laminitis
#
#   Total hyponyms found: 0
#
# DEEP ANALYSIS FOR: 'ceo'
#   Definition: the corporate executive responsible for the operations of the firm; reports to a board of directors; may appoint other managers (including a president)
#   Lemmas: ['chief_executive_officer', 'CEO', 'chief_operating_officer']
#
#   All Hypernym Paths:
#     Path 1: entity -> physical_entity -> object -> whole -> living_thing -> organism -> person -> leader -> head -> administrator -> executive -> corporate_executive -> chief_executive_officer
#     Path 2: entity -> physical_entity -> causal_agent -> person -> leader -> head -> administrator -> executive -> corporate_executive -> chief_executive_officer
#
#   Total hyponyms found: 0
#
# DEEP ANALYSIS FOR: 'pixar'
#
# DEEP ANALYSIS FOR: 'next'
#   Definition: immediately following in time or order
#   Lemmas: ['following', 'next']
#
#   All Hypernym Paths:
#     Path 1: following
#
#   Total hyponyms found: 0

# %% [markdown]
# # Summary of All Operations

# %%
# Cell 15: Summary of All Operations
print("SUMMARY OF ALL OPERATIONS PERFORMED")

print(f"1. CLEANING:")
print(f"   - Original text length: {len(raw_text)} characters")
print(f"   - Cleaned text length: {len(text_cleaned)} characters")
print(f"   - Characters removed: {len(raw_text) - len(text_cleaned)}")

print(f"\n2. LOWERCASING:")
print(f"   - Original text length: {len(text_cleaned)} characters")
print(f"   - Lowercased text length: {len(text_lower)} characters")

print(f"\n3. PUNCTUATION REMOVAL:")
print(f"   - Before removal: {len(text_lower)} characters")
print(f"   - After removal: {len(text_no_punct)} characters")
print(f"   - Punctuation removed: {len(text_lower) - len(text_no_punct)}")

print(f"\n4. STOPWORD REMOVAL:")
print(f"   - Tokens before: {len(tokens)}")
print(f"   - Tokens after: {len(filtered_tokens)}")
print(f"   - Stopwords removed: {len(tokens) - len(filtered_tokens)}")

print(f"\n5. TOKENIZATION:")
print(f"   - Number of sentences: {len(sentences)}")
print(f"   - Number of words: {len(words)}")
print(f"   - Number of characters (no spaces): {len(chars)}")

print(f"\n6. STEMMING:")
print(f"   - Original tokens: {len(filtered_tokens)}")
print(f"   - Porter stemmed tokens: {len(porter_stemmed_tokens)}")
print(f"   - Snowball stemmed tokens: {len(snowball_stemmed_tokens)}")

print(f"\n7. LEMMATIZATION:")
print(f"   - Original tokens: {len(filtered_tokens)}")
print(f"   - Lemmatized tokens: {len(lemmatized_tokens)}")

print(f"\n8. POS TAGGING:")
print(f"   - Number of words tagged: {len(pos_tagged)}")

print(f"\n9. CHUNKING:")
print(f"   - Processed all sentences: {len(all_sentences)} sentences")

print(f"\n10. PARSING:")
print(f"    - Dependency parsing: Complete text processed (Full output shown)")
print(f"    - Tree parsing: All sentences processed (Full output shown)")

print(f"\n11. HYPERNYMS & HYPONYMS:")
print(f"    - Unique words analyzed: {len(unique_words)} words")
print(f"    - Key words analyzed: {len(key_words)} words")
# Out:
# SUMMARY OF ALL OPERATIONS PERFORMED
# 1. CLEANING:
#    - Original text length: 552 characters
#    - Cleaned text length: 515 characters
#    - Characters removed: 37
#
# 2. LOWERCASING:
#    - Original text length: 515 characters
#    - Lowercased text length: 515 characters
#
# 3. PUNCTUATION REMOVAL:
#    - Before removal: 515 characters
#    - After removal: 501 characters
#    - Punctuation removed: 14
#
# 4. STOPWORD REMOVAL:
#    - Tokens before: 8
#    - Tokens after: 49
#    - Stopwords removed: -41
#
# 5. TOKENIZATION:
#    - Number of sentences: 6
#    - Number of words: 85
#    - Number of characters (no spaces): 438
#
# 6. STEMMING:
#    - Original tokens: 49
#    - Porter stemmed tokens: 49
#    - Snowball stemmed tokens: 49
#
# 7. LEMMATIZATION:
#    - Original tokens: 49
#    - Lemmatized tokens: 49
#
# 8. POS TAGGING:
#    - Number of words tagged: 49
#
# 9. CHUNKING:
#    - Processed all sentences: 6 sentences
#
# 10. PARSING:
#     - Dependency parsing: Complete text processed (Full output shown)
#     - Tree parsing: All sentences processed (Full output shown)
#
# 11. HYPERNYMS & HYPONYMS:
#     - Unique words analyzed: 44 words
#     - Key words analyzed: 8 words
