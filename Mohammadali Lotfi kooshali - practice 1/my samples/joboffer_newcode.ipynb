# %% [markdown]
# # practice one

# %% [markdown]
# # mabahese vizhe

# %% [markdown]
# # Mohammadali Lotfi kooshali      -        404198471

# %% [markdown]
# # install , download and import libraries

# %%
# !pip install spacy nltk
# !python -m spacy download en_core_web_sm

import re
import spacy
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize, sent_tokenize
from nltk.stem import PorterStemmer, WordNetLemmatizer, SnowballStemmer
from nltk import pos_tag
from nltk.corpus import wordnet as wn
from string import punctuation
from nltk.chunk import RegexpParser
from nltk import Tree
import time

# Download required NLTK data
nltk.download('punkt')
nltk.download('stopwords')
nltk.download('wordnet')
nltk.download('averaged_perceptron_tagger')
nltk.download('omw-1.4')

# Load spaCy model
nlp = spacy.load("en_core_web_sm")
# Out:
# Requirement already satisfied: spacy in D:\.venv\Lib\site-packages (3.8.14)
# Requirement already satisfied: nltk in D:\.venv\Lib\site-packages (3.9.4)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in D:\.venv\Lib\site-packages (from spacy) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in D:\.venv\Lib\site-packages (from spacy) (1.0.0)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in D:\.venv\Lib\site-packages (from spacy) (1.0.10)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in D:\.venv\Lib\site-packages (from spacy) (2.0.13)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in D:\.venv\Lib\site-packages (from spacy) (3.0.13)
# Requirement already satisfied: thinc<8.4.0,>=8.3.12 in D:\.venv\Lib\site-packages (from spacy) (8.3.13)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in D:\.venv\Lib\site-packages (from spacy) (0.10.1)
# Requirement already satisfied: srsly<3.0.0,>=2.5.3 in D:\.venv\Lib\site-packages (from spacy) (2.5.3)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in D:\.venv\Lib\site-packages (from spacy) (2.0.10)
# Requirement already satisfied: weasel<2.0.0,>=1.0.0 in D:\.venv\Lib\site-packages (from spacy) (1.0.0)
# Requirement already satisfied: confection<2.0.0,>=1.3.2 in D:\.venv\Lib\site-packages (from spacy) (1.3.3)
# Requirement already satisfied: typer<1.0.0,>=0.3.0 in D:\.venv\Lib\site-packages (from spacy) (0.23.1)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in D:\.venv\Lib\site-packages (from spacy) (4.67.3)
# Requirement already satisfied: numpy>=1.19.0 in D:\.venv\Lib\site-packages (from spacy) (2.3.5)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in D:\.venv\Lib\site-packages (from spacy) (2.32.5)
# Requirement already satisfied: pydantic<3.0.0,>=2.0.0 in D:\.venv\Lib\site-packages (from spacy) (2.12.5)
# Requirement already satisfied: jinja2 in D:\.venv\Lib\site-packages (from spacy) (3.1.6)
# Requirement already satisfied: setuptools in D:\.venv\Lib\site-packages (from spacy) (81.0.0)
# Requirement already satisfied: packaging>=20.0 in D:\.venv\Lib\site-packages (from spacy) (25.0)
# Requirement already satisfied: annotated-types>=0.6.0 in D:\.venv\Lib\site-packages (from pydantic<3.0.0,>=2.0.0->spacy) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in D:\.venv\Lib\site-packages (from pydantic<3.0.0,>=2.0.0->spacy) (2.41.5)
# Requirement already satisfied: typing-extensions>=4.14.1 in D:\.venv\Lib\site-packages (from pydantic<3.0.0,>=2.0.0->spacy) (4.15.0)
# Requirement already satisfied: typing-inspection>=0.4.2 in D:\.venv\Lib\site-packages (from pydantic<3.0.0,>=2.0.0->spacy) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in D:\.venv\Lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in D:\.venv\Lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in D:\.venv\Lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (2.6.3)
# Requirement already satisfied: certifi>=2017.4.17 in D:\.venv\Lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (2026.1.4)
# Requirement already satisfied: blis<1.4.0,>=1.3.0 in D:\.venv\Lib\site-packages (from thinc<8.4.0,>=8.3.12->spacy) (1.3.3)
# Requirement already satisfied: colorama in D:\.venv\Lib\site-packages (from tqdm<5.0.0,>=4.38.0->spacy) (0.4.6)
# Requirement already satisfied: click>=8.0.0 in D:\.venv\Lib\site-packages (from typer<1.0.0,>=0.3.0->spacy) (8.3.1)
# Requirement already satisfied: shellingham>=1.3.0 in D:\.venv\Lib\site-packages (from typer<1.0.0,>=0.3.0->spacy) (1.5.4)
# Requirement already satisfied: rich>=10.11.0 in D:\.venv\Lib\site-packages (from typer<1.0.0,>=0.3.0->spacy) (14.3.2)
# Requirement already satisfied: annotated-doc>=0.0.2 in D:\.venv\Lib\site-packages (from typer<1.0.0,>=0.3.0->spacy) (0.0.4)
# Requirement already satisfied: cloudpathlib>=0.7.0 in D:\.venv\Lib\site-packages (from weasel<2.0.0,>=1.0.0->spacy) (0.23.0)
# Requirement already satisfied: smart-open>=5.2.1 in D:\.venv\Lib\site-packages (from weasel<2.0.0,>=1.0.0->spacy) (7.6.0)
# Requirement already satisfied: httpx>=0.24.0 in D:\.venv\Lib\site-packages (from weasel<2.0.0,>=1.0.0->spacy) (0.28.1)
# Requirement already satisfied: joblib in D:\.venv\Lib\site-packages (from nltk) (1.5.3)
# Requirement already satisfied: regex>=2021.8.3 in D:\.venv\Lib\site-packages (from nltk) (2026.1.15)
# Requirement already satisfied: anyio in D:\.venv\Lib\site-packages (from httpx>=0.24.0->weasel<2.0.0,>=1.0.0->spacy) (4.12.1)
# Requirement already satisfied: httpcore==1.* in D:\.venv\Lib\site-packages (from httpx>=0.24.0->weasel<2.0.0,>=1.0.0->spacy) (1.0.9)
# Requirement already satisfied: h11>=0.16 in D:\.venv\Lib\site-packages (from httpcore==1.*->httpx>=0.24.0->weasel<2.0.0,>=1.0.0->spacy) (0.16.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in D:\.venv\Lib\site-packages (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in D:\.venv\Lib\site-packages (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in D:\.venv\Lib\site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy) (0.1.2)
# Requirement already satisfied: wrapt in D:\.venv\Lib\site-packages (from smart-open>=5.2.1->weasel<2.0.0,>=1.0.0->spacy) (2.1.2)
# Requirement already satisfied: MarkupSafe>=2.0 in D:\.venv\Lib\site-packages (from jinja2->spacy) (3.0.3)
# Collecting en-core-web-sm==3.8.0
#   WARNING: Retrying (Retry(total=4, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ProtocolError('Connection aborted.', ConnectionResetError(10054, 'An existing connection was forcibly closed by the remote host', None, 10054, None))': /github-production-release-asset/84940268/15132ab6-4050-4914-8fe8-ac2c2fdcb9cf?sp=r&sv=2018-11-09&sr=b&spr=https&se=2026-04-27T22%3A02%3A13Z&rscd=attachment%3B+filename%3Den_core_web_sm-3.8.0-py3-none-any.whl&rsct=application%2Foctet-stream&skoid=96c2d410-5711-43a1-aedd-ab1947aa7ab0&sktid=398a6654-997b-47e9-b12b-9515b896b4de&skt=2026-04-27T21%3A01%3A30Z&ske=2026-04-27T22%3A02%3A13Z&sks=b&skv=2018-11-09&sig=VdYOBeB%2Bn1%2BidLL896FH2Nd5uVqk3y0JQbibHhUieGg%3D&jwt=eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9.eyJpc3MiOiJnaXRodWIuY29tIiwiYXVkIjoicmVsZWFzZS1hc3NldHMuZ2l0aHVidXNlcmNvbnRlbnQuY29tIiwia2V5Ijoia2V5MSIsImV4cCI6MTc3NzMyNjU3NSwibmJmIjoxNzc3MzI0Nzc1LCJwYXRoIjoicmVsZWFzZWFzc2V0cHJvZHVjdGlvbi5ibG9iLmNvcmUud2luZG93cy5uZXQifQ.D53r6RASxUqW8FLtvrG2qo_rx5RjglpGG1ALVjgNYiE&response-content-disposition=attachment%3B%20filename%3Den_core_web_sm-3.8.0-py3-none-any.whl&response-content-type=application%2Foctet-stream
#   WARNING: Retrying (Retry(total=3, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ProtocolError('Connection aborted.', ConnectionResetError(10054, 'An existing connection was forcibly closed by the remote host', None, 10054, None))': /github-production-release-asset/84940268/15132ab6-4050-4914-8fe8-ac2c2fdcb9cf?sp=r&sv=2018-11-09&sr=b&spr=https&se=2026-04-27T22%3A02%3A13Z&rscd=attachment%3B+filename%3Den_core_web_sm-3.8.0-py3-none-any.whl&rsct=application%2Foctet-stream&skoid=96c2d410-5711-43a1-aedd-ab1947aa7ab0&sktid=398a6654-997b-47e9-b12b-9515b896b4de&skt=2026-04-27T21%3A01%3A30Z&ske=2026-04-27T22%3A02%3A13Z&sks=b&skv=2018-11-09&sig=VdYOBeB%2Bn1%2BidLL896FH2Nd5uVqk3y0JQbibHhUieGg%3D&jwt=eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9.eyJpc3MiOiJnaXRodWIuY29tIiwiYXVkIjoicmVsZWFzZS1hc3NldHMuZ2l0aHVidXNlcmNvbnRlbnQuY29tIiwia2V5Ijoia2V5MSIsImV4cCI6MTc3NzMyNjU3NSwibmJmIjoxNzc3MzI0Nzc1LCJwYXRoIjoicmVsZWFzZWFzc2V0cHJvZHVjdGlvbi5ibG9iLmNvcmUud2luZG93cy5uZXQifQ.D53r6RASxUqW8FLtvrG2qo_rx5RjglpGG1ALVjgNYiE&response-content-disposition=attachment%3B%20filename%3Den_core_web_sm-3.8.0-py3-none-any.whl&response-content-type=application%2Foctet-stream
#   WARNING: Retrying (Retry(total=2, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ProtocolError('Connection aborted.', ConnectionResetError(10054, 'An existing connection was forcibly closed by the remote host', None, 10054, None))': /github-production-release-asset/84940268/15132ab6-4050-4914-8fe8-ac2c2fdcb9cf?sp=r&sv=2018-11-09&sr=b&spr=https&se=2026-04-27T22%3A02%3A13Z&rscd=attachment%3B+filename%3Den_core_web_sm-3.8.0-py3-none-any.whl&rsct=application%2Foctet-stream&skoid=96c2d410-5711-43a1-aedd-ab1947aa7ab0&sktid=398a6654-997b-47e9-b12b-9515b896b4de&skt=2026-04-27T21%3A01%3A30Z&ske=2026-04-27T22%3A02%3A13Z&sks=b&skv=2018-11-09&sig=VdYOBeB%2Bn1%2BidLL896FH2Nd5uVqk3y0JQbibHhUieGg%3D&jwt=eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9.eyJpc3MiOiJnaXRodWIuY29tIiwiYXVkIjoicmVsZWFzZS1hc3NldHMuZ2l0aHVidXNlcmNvbnRlbnQuY29tIiwia2V5Ijoia2V5MSIsImV4cCI6MTc3NzMyNjU3NSwibmJmIjoxNzc3MzI0Nzc1LCJwYXRoIjoicmVsZWFzZWFzc2V0cHJvZHVjdGlvbi5ibG9iLmNvcmUud2luZG93cy5uZXQifQ.D53r6RASxUqW8FLtvrG2qo_rx5RjglpGG1ALVjgNYiE&response-content-disposition=attachment%3B%20filename%3Den_core_web_sm-3.8.0-py3-none-any.whl&response-content-type=application%2Foctet-stream
#   WARNING: Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ProtocolError('Connection aborted.', ConnectionResetError(10054, 'An existing connection was forcibly closed by the remote host', None, 10054, None))': /github-production-release-asset/84940268/15132ab6-4050-4914-8fe8-ac2c2fdcb9cf?sp=r&sv=2018-11-09&sr=b&spr=https&se=2026-04-27T22%3A02%3A13Z&rscd=attachment%3B+filename%3Den_core_web_sm-3.8.0-py3-none-any.whl&rsct=application%2Foctet-stream&skoid=96c2d410-5711-43a1-aedd-ab1947aa7ab0&sktid=398a6654-997b-47e9-b12b-9515b896b4de&skt=2026-04-27T21%3A01%3A30Z&ske=2026-04-27T22%3A02%3A13Z&sks=b&skv=2018-11-09&sig=VdYOBeB%2Bn1%2BidLL896FH2Nd5uVqk3y0JQbibHhUieGg%3D&jwt=eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9.eyJpc3MiOiJnaXRodWIuY29tIiwiYXVkIjoicmVsZWFzZS1hc3NldHMuZ2l0aHVidXNlcmNvbnRlbnQuY29tIiwia2V5Ijoia2V5MSIsImV4cCI6MTc3NzMyNjU3NSwibmJmIjoxNzc3MzI0Nzc1LCJwYXRoIjoicmVsZWFzZWFzc2V0cHJvZHVjdGlvbi5ibG9iLmNvcmUud2luZG93cy5uZXQifQ.D53r6RASxUqW8FLtvrG2qo_rx5RjglpGG1ALVjgNYiE&response-content-disposition=attachment%3B%20filename%3Den_core_web_sm-3.8.0-py3-none-any.whl&response-content-type=application%2Foctet-stream
#   WARNING: Retrying (Retry(total=0, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ProtocolError('Connection aborted.', ConnectionResetError(10054, 'An existing connection was forcibly closed by the remote host', None, 10054, None))': /github-production-release-asset/84940268/15132ab6-4050-4914-8fe8-ac2c2fdcb9cf?sp=r&sv=2018-11-09&sr=b&spr=https&se=2026-04-27T22%3A02%3A13Z&rscd=attachment%3B+filename%3Den_core_web_sm-3.8.0-py3-none-any.whl&rsct=application%2Foctet-stream&skoid=96c2d410-5711-43a1-aedd-ab1947aa7ab0&sktid=398a6654-997b-47e9-b12b-9515b896b4de&skt=2026-04-27T21%3A01%3A30Z&ske=2026-04-27T22%3A02%3A13Z&sks=b&skv=2018-11-09&sig=VdYOBeB%2Bn1%2BidLL896FH2Nd5uVqk3y0JQbibHhUieGg%3D&jwt=eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9.eyJpc3MiOiJnaXRodWIuY29tIiwiYXVkIjoicmVsZWFzZS1hc3NldHMuZ2l0aHVidXNlcmNvbnRlbnQuY29tIiwia2V5Ijoia2V5MSIsImV4cCI6MTc3NzMyNjU3NSwibmJmIjoxNzc3MzI0Nzc1LCJwYXRoIjoicmVsZWFzZWFzc2V0cHJvZHVjdGlvbi5ibG9iLmNvcmUud2luZG93cy5uZXQifQ.D53r6RASxUqW8FLtvrG2qo_rx5RjglpGG1ALVjgNYiE&response-content-disposition=attachment%3B%20filename%3Den_core_web_sm-3.8.0-py3-none-any.whl&response-content-type=application%2Foctet-stream
# ERROR: Could not install packages due to an OSError: HTTPSConnectionPool(host='release-assets.githubusercontent.com', port=443): Max retries exceeded with url: /github-production-release-asset/84940268/15132ab6-4050-4914-8fe8-ac2c2fdcb9cf?sp=r&sv=2018-11-09&sr=b&spr=https&se=2026-04-27T22%3A02%3A13Z&rscd=attachment%3B+filename%3Den_core_web_sm-3.8.0-py3-none-any.whl&rsct=application%2Foctet-stream&skoid=96c2d410-5711-43a1-aedd-ab1947aa7ab0&sktid=398a6654-997b-47e9-b12b-9515b896b4de&skt=2026-04-27T21%3A01%3A30Z&ske=2026-04-27T22%3A02%3A13Z&sks=b&skv=2018-11-09&sig=VdYOBeB%2Bn1%2BidLL896FH2Nd5uVqk3y0JQbibHhUieGg%3D&jwt=eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9.eyJpc3MiOiJnaXRodWIuY29tIiwiYXVkIjoicmVsZWFzZS1hc3NldHMuZ2l0aHVidXNlcmNvbnRlbnQuY29tIiwia2V5Ijoia2V5MSIsImV4cCI6MTc3NzMyNjU3NSwibmJmIjoxNzc3MzI0Nzc1LCJwYXRoIjoicmVsZWFzZWFzc2V0cHJvZHVjdGlvbi5ibG9iLmNvcmUud2luZG93cy5uZXQifQ.D53r6RASxUqW8FLtvrG2qo_rx5RjglpGG1ALVjgNYiE&response-content-disposition=attachment%3B%20filename%3Den_core_web_sm-3.8.0-py3-none-any.whl&response-content-type=application%2Foctet-stream (Caused by ProtocolError('Connection aborted.', ConnectionResetError(10054, 'An existing connection was forcibly closed by the remote host', None, 10054, None)))
#
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\ASUS\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\ASUS\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\ASUS\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     C:\Users\ASUS\AppData\Roaming\nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package omw-1.4 to
# [nltk_data]     C:\Users\ASUS\AppData\Roaming\nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!

# %% [markdown]
# # reading text file

# %%
with open('job_offer.txt', 'r', encoding='utf-8') as file:
    raw_text = file.read()

print("original text:")
print(raw_text)
print(f"Total characters: {len(raw_text)}")
# Out:
# original text:
# Subject: Job Offer - Senior Data Scientist Position
#
# Dear Mr. Thompson,
#
# Congratulations! 🎉 We are pleased to offer you the position of Senior Data Scientist at DataMind Corp.
#
# Offer Details:
# - Start Date: January 15th, 2025
# - Base Salary: $145,000/year
# - Equity: 5,000 stock options
# - Bonus: 15% annual performance bonus
# - Location: San Francisco, CA (remote options available)
#
# Please review the attached offer letter (PDF) and sign by December 20th.
#
# Onboarding documents: https://datamind.corp/onboarding/MT2024
#
# If you have questions, contact HR at hr@datamind.com or call (415) 555-7890.
#
# We look forward to having you on the team! 🚀
#
# Best regards,
# Lisa Wong
# Talent Acquisition Lead
# DataMind Corporation
# Total characters: 709

# %% [markdown]
# # 1. Cleaning Text with re.sub

# %%
# Remove numbers
text_no_numbers = re.sub(r'\d+', '', raw_text)
print("After removing numbers:")
print(text_no_numbers)
print("-" * 80)

# Remove extra whitespaces
text_cleaned = re.sub(r'\s+', ' ', text_no_numbers)
print("After removing extra whitespaces:")
print(text_cleaned)
print("-" * 80)

# Remove special characters (keep letters, spaces, dots, commas)
text_cleaned = re.sub(r'[^\w\s\.\,]', '', text_cleaned)
print("After removing special characters:")
print(text_cleaned)
print(f"Cleaned text length: {len(text_cleaned)} characters")
# Out:
# After removing numbers:
# Subject: Job Offer - Senior Data Scientist Position
#
# Dear Mr. Thompson,
#
# Congratulations! 🎉 We are pleased to offer you the position of Senior Data Scientist at DataMind Corp.
#
# Offer Details:
# - Start Date: January th,
# - Base Salary: $,/year
# - Equity: , stock options
# - Bonus: % annual performance bonus
# - Location: San Francisco, CA (remote options available)
#
# Please review the attached offer letter (PDF) and sign by December th.
#
# Onboarding documents: https://datamind.corp/onboarding/MT
#
# If you have questions, contact HR at hr@datamind.com or call () -.
#
# We look forward to having you on the team! 🚀
#
# Best regards,
# Lisa Wong
# Talent Acquisition Lead
# DataMind Corporation
# --------------------------------------------------------------------------------
# After removing extra whitespaces:
# Subject: Job Offer - Senior Data Scientist Position Dear Mr. Thompson, Congratulations! 🎉 We are pleased to offer you the position of Senior Data Scientist at DataMind Corp. Offer Details: - Start Date: January th, - Base Salary: $,/year - Equity: , stock options - Bonus: % annual performance bonus - Location: San Francisco, CA (remote options available) Please review the attached offer letter (PDF) and sign by December th. Onboarding documents: https://datamind.corp/onboarding/MT If you have questions, contact HR at hr@datamind.com or call () -. We look forward to having you on the team! 🚀 Best regards, Lisa Wong Talent Acquisition Lead DataMind Corporation
# --------------------------------------------------------------------------------
# After removing special characters:
# Subject Job Offer  Senior Data Scientist Position Dear Mr. Thompson, Congratulations  We are pleased to offer you the position of Senior Data Scientist at DataMind Corp. Offer Details  Start Date January th,  Base Salary ,year  Equity , stock options  Bonus  annual performance bonus  Location San Francisco, CA remote options available Please review the attached offer letter PDF and sign by December th. Onboarding documents httpsdatamind.corponboardingMT If you have questions, contact HR at hrdatamind.com or call  . We look forward to having you on the team  Best regards, Lisa Wong Talent Acquisition Lead DataMind Corporation
# Cleaned text length: 632 characters

# %% [markdown]
# # 2. Lowercasing

# %%
text_lower = text_cleaned.lower()
print("Text after lowercasing:")
print(text_lower)
# Out:
# Text after lowercasing:
# subject job offer  senior data scientist position dear mr. thompson, congratulations  we are pleased to offer you the position of senior data scientist at datamind corp. offer details  start date january th,  base salary ,year  equity , stock options  bonus  annual performance bonus  location san francisco, ca remote options available please review the attached offer letter pdf and sign by december th. onboarding documents httpsdatamind.corponboardingmt if you have questions, contact hr at hrdatamind.com or call  . we look forward to having you on the team  best regards, lisa wong talent acquisition lead datamind corporation

# %% [markdown]
# # 3. Punctuation Removal

# %%
print("Punctuation removed:", punctuation)
text_no_punct = ''.join([char for char in text_lower if char not in punctuation])
print("Text after punctuation removal:")
print(text_no_punct)
# Out:
# Punctuation removed: !"#$%&'()*+,-./:;<=>?@[\]^_`{|}~
# Text after punctuation removal:
# subject job offer  senior data scientist position dear mr thompson congratulations  we are pleased to offer you the position of senior data scientist at datamind corp offer details  start date january th  base salary year  equity  stock options  bonus  annual performance bonus  location san francisco ca remote options available please review the attached offer letter pdf and sign by december th onboarding documents httpsdatamindcorponboardingmt if you have questions contact hr at hrdatamindcom or call   we look forward to having you on the team  best regards lisa wong talent acquisition lead datamind corporation

# %% [markdown]
# # 4. Stopword Removal

# %%
# Get English stopwords
stop_words = set(stopwords.words('english'))
print("English stopwords :")
print(list(stop_words))

# Tokenize first
tokens = word_tokenize(text_no_punct)
print(f"Total tokens before stopword removal: {len(tokens)}")
print("tokens before removal:")
print(tokens)

# Remove stopwords
filtered_tokens = [word for word in tokens if word not in stop_words]
print(f"Total tokens after stopword removal: {len(filtered_tokens)}")
print("tokens after removal:")
print(filtered_tokens)

# Convert back to text
text_no_stopwords = ' '.join(filtered_tokens)
print("Complete text after stopword removal:")
print(text_no_stopwords)
# Out:
# English stopwords :
# ['some', 'a', 'my', 'has', 'who', 'than', 'was', 'few', "didn't", 'll', 'were', "hadn't", 'just', "they'd", 'we', 'at', "you'd", 'all', 'don', "should've", 'herself', 'ain', 'couldn', "they'll", 'aren', 'up', "doesn't", 'y', "you're", 'in', 'those', 'is', 'itself', 'am', "we're", 'been', "they've", 'are', 'own', "we'll", "shouldn't", 'hasn', 'this', 'ours', 'himself', "it's", 'she', 'through', 'me', "that'll", 'being', "isn't", "i'd", "mightn't", 'what', 'them', 'off', 'of', 't', 'mightn', 'until', 'their', 'under', 'doesn', 'but', 'theirs', 'an', 'here', 'how', "she'd", 'there', 'on', 'will', 'wasn', 'it', 'o', 'above', 'these', 'and', 'ourselves', "i'll", 'between', 'for', 'then', 'while', 'yourselves', 'no', "it'd", 'had', "he'll", 'do', "wasn't", 'any', 'him', 'isn', 'myself', 'needn', 'have', "we've", "couldn't", 'again', 'having', "we'd", 'from', "wouldn't", "he's", "you'll", 'yours', 'now', 'only', "needn't", 'the', 'each', 'its', 'to', 'where', 'further', 'can', "it'll", "shan't", 'shouldn', 'when', 'did', 'he', 'that', 'won', 'her', 'weren', 'your', 'doing', 's', 'by', 'why', 'didn', "won't", 'below', 'wouldn', 'more', "mustn't", 'be', 'does', 'down', 'nor', 'they', 'with', 'you', "weren't", 'should', 'i', 'over', 'themselves', "don't", 'both', 'or', 'as', 'hers', 'hadn', 'which', 'ma', 'about', "she'll", 'mustn', 'before', 'shan', 'so', 'most', 'very', "i'm", "haven't", 'such', 'because', 'into', 'm', 'out', "you've", "i've", 'not', "they're", 've', 'once', 'other', 'his', 'same', 'against', "hasn't", 'whom', 'd', 'too', 'after', "he'd", 'our', "she's", 'if', 'during', "aren't", 're', 'yourself', 'haven']
# Total tokens before stopword removal: 92
# tokens before removal:
# ['subject', 'job', 'offer', 'senior', 'data', 'scientist', 'position', 'dear', 'mr', 'thompson', 'congratulations', 'we', 'are', 'pleased', 'to', 'offer', 'you', 'the', 'position', 'of', 'senior', 'data', 'scientist', 'at', 'datamind', 'corp', 'offer', 'details', 'start', 'date', 'january', 'th', 'base', 'salary', 'year', 'equity', 'stock', 'options', 'bonus', 'annual', 'performance', 'bonus', 'location', 'san', 'francisco', 'ca', 'remote', 'options', 'available', 'please', 'review', 'the', 'attached', 'offer', 'letter', 'pdf', 'and', 'sign', 'by', 'december', 'th', 'onboarding', 'documents', 'httpsdatamindcorponboardingmt', 'if', 'you', 'have', 'questions', 'contact', 'hr', 'at', 'hrdatamindcom', 'or', 'call', 'we', 'look', 'forward', 'to', 'having', 'you', 'on', 'the', 'team', 'best', 'regards', 'lisa', 'wong', 'talent', 'acquisition', 'lead', 'datamind', 'corporation']
# Total tokens after stopword removal: 71
# tokens after removal:
# ['subject', 'job', 'offer', 'senior', 'data', 'scientist', 'position', 'dear', 'mr', 'thompson', 'congratulations', 'pleased', 'offer', 'position', 'senior', 'data', 'scientist', 'datamind', 'corp', 'offer', 'details', 'start', 'date', 'january', 'th', 'base', 'salary', 'year', 'equity', 'stock', 'options', 'bonus', 'annual', 'performance', 'bonus', 'location', 'san', 'francisco', 'ca', 'remote', 'options', 'available', 'please', 'review', 'attached', 'offer', 'letter', 'pdf', 'sign', 'december', 'th', 'onboarding', 'documents', 'httpsdatamindcorponboardingmt', 'questions', 'contact', 'hr', 'hrdatamindcom', 'call', 'look', 'forward', 'team', 'best', 'regards', 'lisa', 'wong', 'talent', 'acquisition', 'lead', 'datamind', 'corporation']
# Complete text after stopword removal:
# subject job offer senior data scientist position dear mr thompson congratulations pleased offer position senior data scientist datamind corp offer details start date january th base salary year equity stock options bonus annual performance bonus location san francisco ca remote options available please review attached offer letter pdf sign december th onboarding documents httpsdatamindcorponboardingmt questions contact hr hrdatamindcom call look forward team best regards lisa wong talent acquisition lead datamind corporation

# %% [markdown]
# # 5. Tokenization (Sentence, Word, Character)

# %%
# Sentence Tokenization
sentences = sent_tokenize(text_lower)
print("Sentence Tokenization:")
print(f"Total number of sentences: {len(sentences)}")
print("All sentences:")
for i, sent in enumerate(sentences, 1):
    print(f"{i}. {sent}")

# Word Tokenization
words = word_tokenize(text_lower)
print("Word Tokenization:")
print(f"Total number of words: {len(words)}")
print("All words:")
print(words)

# Character Tokenization
chars = [char for char in text_lower if char != ' ']
print("Character Tokenization:")
print(f"Total number of characters (without spaces): {len(chars)}")
print("All characters:")
print(chars)
# Out:
# Sentence Tokenization:
# Total number of sentences: 3
# All sentences:
# 1. subject job offer  senior data scientist position dear mr. thompson, congratulations  we are pleased to offer you the position of senior data scientist at datamind corp. offer details  start date january th,  base salary ,year  equity , stock options  bonus  annual performance bonus  location san francisco, ca remote options available please review the attached offer letter pdf and sign by december th.
# 2. onboarding documents httpsdatamind.corponboardingmt if you have questions, contact hr at hrdatamind.com or call  .
# 3. we look forward to having you on the team  best regards, lisa wong talent acquisition lead datamind corporation
# Word Tokenization:
# Total number of words: 101
# All words:
# ['subject', 'job', 'offer', 'senior', 'data', 'scientist', 'position', 'dear', 'mr.', 'thompson', ',', 'congratulations', 'we', 'are', 'pleased', 'to', 'offer', 'you', 'the', 'position', 'of', 'senior', 'data', 'scientist', 'at', 'datamind', 'corp.', 'offer', 'details', 'start', 'date', 'january', 'th', ',', 'base', 'salary', ',', 'year', 'equity', ',', 'stock', 'options', 'bonus', 'annual', 'performance', 'bonus', 'location', 'san', 'francisco', ',', 'ca', 'remote', 'options', 'available', 'please', 'review', 'the', 'attached', 'offer', 'letter', 'pdf', 'and', 'sign', 'by', 'december', 'th', '.', 'onboarding', 'documents', 'httpsdatamind.corponboardingmt', 'if', 'you', 'have', 'questions', ',', 'contact', 'hr', 'at', 'hrdatamind.com', 'or', 'call', '.', 'we', 'look', 'forward', 'to', 'having', 'you', 'on', 'the', 'team', 'best', 'regards', ',', 'lisa', 'wong', 'talent', 'acquisition', 'lead', 'datamind', 'corporation']
# Character Tokenization:
# Total number of characters (without spaces): 529
# All characters:
# ['s', 'u', 'b', 'j', 'e', 'c', 't', 'j', 'o', 'b', 'o', 'f', 'f', 'e', 'r', 's', 'e', 'n', 'i', 'o', 'r', 'd', 'a', 't', 'a', 's', 'c', 'i', 'e', 'n', 't', 'i', 's', 't', 'p', 'o', 's', 'i', 't', 'i', 'o', 'n', 'd', 'e', 'a', 'r', 'm', 'r', '.', 't', 'h', 'o', 'm', 'p', 's', 'o', 'n', ',', 'c', 'o', 'n', 'g', 'r', 'a', 't', 'u', 'l', 'a', 't', 'i', 'o', 'n', 's', 'w', 'e', 'a', 'r', 'e', 'p', 'l', 'e', 'a', 's', 'e', 'd', 't', 'o', 'o', 'f', 'f', 'e', 'r', 'y', 'o', 'u', 't', 'h', 'e', 'p', 'o', 's', 'i', 't', 'i', 'o', 'n', 'o', 'f', 's', 'e', 'n', 'i', 'o', 'r', 'd', 'a', 't', 'a', 's', 'c', 'i', 'e', 'n', 't', 'i', 's', 't', 'a', 't', 'd', 'a', 't', 'a', 'm', 'i', 'n', 'd', 'c', 'o', 'r', 'p', '.', 'o', 'f', 'f', 'e', 'r', 'd', 'e', 't', 'a', 'i', 'l', 's', 's', 't', 'a', 'r', 't', 'd', 'a', 't', 'e', 'j', 'a', 'n', 'u', 'a', 'r', 'y', 't', 'h', ',', 'b', 'a', 's', 'e', 's', 'a', 'l', 'a', 'r', 'y', ',', 'y', 'e', 'a', 'r', 'e', 'q', 'u', 'i', 't', 'y', ',', 's', 't', 'o', 'c', 'k', 'o', 'p', 't', 'i', 'o', 'n', 's', 'b', 'o', 'n', 'u', 's', 'a', 'n', 'n', 'u', 'a', 'l', 'p', 'e', 'r', 'f', 'o', 'r', 'm', 'a', 'n', 'c', 'e', 'b', 'o', 'n', 'u', 's', 'l', 'o', 'c', 'a', 't', 'i', 'o', 'n', 's', 'a', 'n', 'f', 'r', 'a', 'n', 'c', 'i', 's', 'c', 'o', ',', 'c', 'a', 'r', 'e', 'm', 'o', 't', 'e', 'o', 'p', 't', 'i', 'o', 'n', 's', 'a', 'v', 'a', 'i', 'l', 'a', 'b', 'l', 'e', 'p', 'l', 'e', 'a', 's', 'e', 'r', 'e', 'v', 'i', 'e', 'w', 't', 'h', 'e', 'a', 't', 't', 'a', 'c', 'h', 'e', 'd', 'o', 'f', 'f', 'e', 'r', 'l', 'e', 't', 't', 'e', 'r', 'p', 'd', 'f', 'a', 'n', 'd', 's', 'i', 'g', 'n', 'b', 'y', 'd', 'e', 'c', 'e', 'm', 'b', 'e', 'r', 't', 'h', '.', 'o', 'n', 'b', 'o', 'a', 'r', 'd', 'i', 'n', 'g', 'd', 'o', 'c', 'u', 'm', 'e', 'n', 't', 's', 'h', 't', 't', 'p', 's', 'd', 'a', 't', 'a', 'm', 'i', 'n', 'd', '.', 'c', 'o', 'r', 'p', 'o', 'n', 'b', 'o', 'a', 'r', 'd', 'i', 'n', 'g', 'm', 't', 'i', 'f', 'y', 'o', 'u', 'h', 'a', 'v', 'e', 'q', 'u', 'e', 's', 't', 'i', 'o', 'n', 's', ',', 'c', 'o', 'n', 't', 'a', 'c', 't', 'h', 'r', 'a', 't', 'h', 'r', 'd', 'a', 't', 'a', 'm', 'i', 'n', 'd', '.', 'c', 'o', 'm', 'o', 'r', 'c', 'a', 'l', 'l', '.', 'w', 'e', 'l', 'o', 'o', 'k', 'f', 'o', 'r', 'w', 'a', 'r', 'd', 't', 'o', 'h', 'a', 'v', 'i', 'n', 'g', 'y', 'o', 'u', 'o', 'n', 't', 'h', 'e', 't', 'e', 'a', 'm', 'b', 'e', 's', 't', 'r', 'e', 'g', 'a', 'r', 'd', 's', ',', 'l', 'i', 's', 'a', 'w', 'o', 'n', 'g', 't', 'a', 'l', 'e', 'n', 't', 'a', 'c', 'q', 'u', 'i', 's', 'i', 't', 'i', 'o', 'n', 'l', 'e', 'a', 'd', 'd', 'a', 't', 'a', 'm', 'i', 'n', 'd', 'c', 'o', 'r', 'p', 'o', 'r', 'a', 't', 'i', 'o', 'n']

# %% [markdown]
# # 6. Stemming (PorterStemmer and SnowballStemmer)

# %%
# Initialize both stemmers
porter_stemmer = PorterStemmer()
snowball_stemmer = SnowballStemmer("english")

# Apply both stemmers
porter_stemmed_tokens = [porter_stemmer.stem(word) for word in filtered_tokens]
snowball_stemmed_tokens = [snowball_stemmer.stem(word) for word in filtered_tokens]

print("COMPLETE COMPARISON (Original vs Porter vs Snowball):")
print(f"{'#':<5} | {'Original Word':<25} | {'Porter Stemmer':<20} | {'Snowball Stemmer':<20} | {'Difference'}")

difference_count = 0
for i, (original, porter, snowball) in enumerate(zip(filtered_tokens, porter_stemmed_tokens, snowball_stemmed_tokens), 1):
    difference = "DIFFERENT" if porter != snowball else "SAME"
    if porter != snowball:
        difference_count += 1
    print(f"{i:<5} | {original:<25} | {porter:<20} | {snowball:<20} | {difference}")

print(f"\nTotal words with different stemming results: {difference_count} out of {len(filtered_tokens)}")
print(f"Percentage of differences: {(difference_count/len(filtered_tokens))*100:.2f}%")

# Show detailed comparison for words that differ
print("\nDETAILED COMPARISON FOR WORDS WITH DIFFERENT STEMMING RESULTS:")

different_words = []
for original, porter, snowball in zip(filtered_tokens, porter_stemmed_tokens, snowball_stemmed_tokens):
    if porter != snowball:
        different_words.append((original, porter, snowball))

if different_words:
    print(f"{'#':<5} | {'Original Word':<25} | {'Porter Result':<20} | {'Snowball Result':<20} | {'Analysis'}")
    for i, (original, porter, snowball) in enumerate(different_words, 1):
        analysis = ""
        if len(porter) < len(snowball):
            analysis = "Porter shorter"
        elif len(snowball) < len(porter):
            analysis = "Snowball shorter"
        elif porter.endswith('ing') and not snowball.endswith('ing'):
            analysis = "Porter keeps -ing"
        elif snowball.endswith('ing') and not porter.endswith('ing'):
            analysis = "Snowball keeps -ing"
        else:
            analysis = "Different algorithm"
        print(f"{i:<5} | {original:<25} | {porter:<20} | {snowball:<20} | {analysis}")
else:
    print("No differences found between Porter and Snowball stemmers for this text.")

# Show complete stemmed texts
print("\nCOMPLETE PORTER STEMMED TEXT:")
porter_stemmed_text = ' '.join(porter_stemmed_tokens)
print(porter_stemmed_text)

print("\nCOMPLETE SNOWBALL STEMMED TEXT:")
snowball_stemmed_text = ' '.join(snowball_stemmed_tokens)
print(snowball_stemmed_text)

# Performance comparison
print("\nPERFORMANCE COMPARISON:")

# Test Porter speed
start_time = time.time()
for word in filtered_tokens * 10:
    porter_stemmer.stem(word)
porter_time = time.time() - start_time

# Test Snowball speed
start_time = time.time()
for word in filtered_tokens * 10:
    snowball_stemmer.stem(word)
snowball_time = time.time() - start_time

print(f"PorterStemmer processing time (10 repetitions): {porter_time:.6f} seconds")
print(f"SnowballStemmer processing time (10 repetitions): {snowball_time:.6f} seconds")
# Out:
# COMPLETE COMPARISON (Original vs Porter vs Snowball):
# #     | Original Word             | Porter Stemmer       | Snowball Stemmer     | Difference
# 1     | subject                   | subject              | subject              | SAME
# 2     | job                       | job                  | job                  | SAME
# 3     | offer                     | offer                | offer                | SAME
# 4     | senior                    | senior               | senior               | SAME
# 5     | data                      | data                 | data                 | SAME
# 6     | scientist                 | scientist            | scientist            | SAME
# 7     | position                  | posit                | posit                | SAME
# 8     | dear                      | dear                 | dear                 | SAME
# 9     | mr                        | mr                   | mr                   | SAME
# 10    | thompson                  | thompson             | thompson             | SAME
# 11    | congratulations           | congratul            | congratul            | SAME
# 12    | pleased                   | pleas                | pleas                | SAME
# 13    | offer                     | offer                | offer                | SAME
# 14    | position                  | posit                | posit                | SAME
# 15    | senior                    | senior               | senior               | SAME
# 16    | data                      | data                 | data                 | SAME
# 17    | scientist                 | scientist            | scientist            | SAME
# 18    | datamind                  | datamind             | datamind             | SAME
# 19    | corp                      | corp                 | corp                 | SAME
# 20    | offer                     | offer                | offer                | SAME
# 21    | details                   | detail               | detail               | SAME
# 22    | start                     | start                | start                | SAME
# 23    | date                      | date                 | date                 | SAME
# 24    | january                   | januari              | januari              | SAME
# 25    | th                        | th                   | th                   | SAME
# 26    | base                      | base                 | base                 | SAME
# 27    | salary                    | salari               | salari               | SAME
# 28    | year                      | year                 | year                 | SAME
# 29    | equity                    | equiti               | equiti               | SAME
# 30    | stock                     | stock                | stock                | SAME
# 31    | options                   | option               | option               | SAME
# 32    | bonus                     | bonu                 | bonus                | DIFFERENT
# 33    | annual                    | annual               | annual               | SAME
# 34    | performance               | perform              | perform              | SAME
# 35    | bonus                     | bonu                 | bonus                | DIFFERENT
# 36    | location                  | locat                | locat                | SAME
# 37    | san                       | san                  | san                  | SAME
# 38    | francisco                 | francisco            | francisco            | SAME
# 39    | ca                        | ca                   | ca                   | SAME
# 40    | remote                    | remot                | remot                | SAME
# 41    | options                   | option               | option               | SAME
# 42    | available                 | avail                | avail                | SAME
# 43    | please                    | pleas                | pleas                | SAME
# 44    | review                    | review               | review               | SAME
# 45    | attached                  | attach               | attach               | SAME
# 46    | offer                     | offer                | offer                | SAME
# 47    | letter                    | letter               | letter               | SAME
# 48    | pdf                       | pdf                  | pdf                  | SAME
# 49    | sign                      | sign                 | sign                 | SAME
# 50    | december                  | decemb               | decemb               | SAME
# 51    | th                        | th                   | th                   | SAME
# 52    | onboarding                | onboard              | onboard              | SAME
# 53    | documents                 | document             | document             | SAME
# 54    | httpsdatamindcorponboardingmt | httpsdatamindcorponboardingmt | httpsdatamindcorponboardingmt | SAME
# 55    | questions                 | question             | question             | SAME
# 56    | contact                   | contact              | contact              | SAME
# 57    | hr                        | hr                   | hr                   | SAME
# 58    | hrdatamindcom             | hrdatamindcom        | hrdatamindcom        | SAME
# 59    | call                      | call                 | call                 | SAME
# 60    | look                      | look                 | look                 | SAME
# 61    | forward                   | forward              | forward              | SAME
# 62    | team                      | team                 | team                 | SAME
# 63    | best                      | best                 | best                 | SAME
# 64    | regards                   | regard               | regard               | SAME
# 65    | lisa                      | lisa                 | lisa                 | SAME
# 66    | wong                      | wong                 | wong                 | SAME
# 67    | talent                    | talent               | talent               | SAME
# 68    | acquisition               | acquisit             | acquisit             | SAME
# 69    | lead                      | lead                 | lead                 | SAME
# 70    | datamind                  | datamind             | datamind             | SAME
# 71    | corporation               | corpor               | corpor               | SAME
#
# Total words with different stemming results: 2 out of 71
# Percentage of differences: 2.82%
#
# DETAILED COMPARISON FOR WORDS WITH DIFFERENT STEMMING RESULTS:
# #     | Original Word             | Porter Result        | Snowball Result      | Analysis
# 1     | bonus                     | bonu                 | bonus                | Porter shorter
# 2     | bonus                     | bonu                 | bonus                | Porter shorter
#
# COMPLETE PORTER STEMMED TEXT:
# subject job offer senior data scientist posit dear mr thompson congratul pleas offer posit senior data scientist datamind corp offer detail start date januari th base salari year equiti stock option bonu annual perform bonu locat san francisco ca remot option avail pleas review attach offer letter pdf sign decemb th onboard document httpsdatamindcorponboardingmt question contact hr hrdatamindcom call look forward team best regard lisa wong talent acquisit lead datamind corpor
#
# COMPLETE SNOWBALL STEMMED TEXT:
# subject job offer senior data scientist posit dear mr thompson congratul pleas offer posit senior data scientist datamind corp offer detail start date januari th base salari year equiti stock option bonus annual perform bonus locat san francisco ca remot option avail pleas review attach offer letter pdf sign decemb th onboard document httpsdatamindcorponboardingmt question contact hr hrdatamindcom call look forward team best regard lisa wong talent acquisit lead datamind corpor
#
# PERFORMANCE COMPARISON:
# PorterStemmer processing time (10 repetitions): 0.006997 seconds
# SnowballStemmer processing time (10 repetitions): 0.004509 seconds

# %% [markdown]
# # 7. Lemmatization (WordNetLemmatizer)

# %%
lemmatizer = WordNetLemmatizer()
lemmatized_tokens = [lemmatizer.lemmatize(word) for word in filtered_tokens]

print("COMPLETE COMPARISON (Original vs Lemmatized):")
print(f"{'#':<5} | {'Original Word':<25} | {'Lemmatized':<25}")
for i, (original, lemmatized) in enumerate(zip(filtered_tokens, lemmatized_tokens), 1):
    print(f"{i:<5} | {original:<25} | {lemmatized:<25}")

lemmatized_text = ' '.join(lemmatized_tokens)
print("\nCOMPLETE LEMMATIZED TEXT:")
print(lemmatized_text)

print("\nSTEMMING vs LEMMATIZATION COMPARISON:")
print(f"{'#':<5} | {'Original Word':<25} | {'Porter Stemmer':<20} | {'Snowball Stemmer':<20} | {'Lemmatized':<25}")
for i, (original, porter, snowball, lemmatized) in enumerate(zip(filtered_tokens, porter_stemmed_tokens, snowball_stemmed_tokens, lemmatized_tokens), 1):
    print(f"{i:<5} | {original:<25} | {porter:<20} | {snowball:<20} | {lemmatized:<25}")

# Performance comparison for Lemmatizer
print("\nPERFORMANCE COMPARISON (Lemmatizer vs Stemmers):")

# Test Lemmatizer speed
start_time = time.time()
for word in filtered_tokens * 10:
    lemmatizer.lemmatize(word)
lemmatizer_time = time.time() - start_time

print(f"WordNetLemmatizer processing time (10 repetitions): {lemmatizer_time:.6f} seconds")
print(f"PorterStemmer processing time (10 repetitions): {porter_time:.6f} seconds")
print(f"SnowballStemmer processing time (10 repetitions): {snowball_time:.6f} seconds")
# Out:
# COMPLETE COMPARISON (Original vs Lemmatized):
# #     | Original Word             | Lemmatized
# 1     | subject                   | subject
# 2     | job                       | job
# 3     | offer                     | offer
# 4     | senior                    | senior
# 5     | data                      | data
# 6     | scientist                 | scientist
# 7     | position                  | position
# 8     | dear                      | dear
# 9     | mr                        | mr
# 10    | thompson                  | thompson
# 11    | congratulations           | congratulation
# 12    | pleased                   | pleased
# 13    | offer                     | offer
# 14    | position                  | position
# 15    | senior                    | senior
# 16    | data                      | data
# 17    | scientist                 | scientist
# 18    | datamind                  | datamind
# 19    | corp                      | corp
# 20    | offer                     | offer
# 21    | details                   | detail
# 22    | start                     | start
# 23    | date                      | date
# 24    | january                   | january
# 25    | th                        | th
# 26    | base                      | base
# 27    | salary                    | salary
# 28    | year                      | year
# 29    | equity                    | equity
# 30    | stock                     | stock
# 31    | options                   | option
# 32    | bonus                     | bonus
# 33    | annual                    | annual
# 34    | performance               | performance
# 35    | bonus                     | bonus
# 36    | location                  | location
# 37    | san                       | san
# 38    | francisco                 | francisco
# 39    | ca                        | ca
# 40    | remote                    | remote
# 41    | options                   | option
# 42    | available                 | available
# 43    | please                    | please
# 44    | review                    | review
# 45    | attached                  | attached
# 46    | offer                     | offer
# 47    | letter                    | letter
# 48    | pdf                       | pdf
# 49    | sign                      | sign
# 50    | december                  | december
# 51    | th                        | th
# 52    | onboarding                | onboarding
# 53    | documents                 | document
# 54    | httpsdatamindcorponboardingmt | httpsdatamindcorponboardingmt
# 55    | questions                 | question
# 56    | contact                   | contact
# 57    | hr                        | hr
# 58    | hrdatamindcom             | hrdatamindcom
# 59    | call                      | call
# 60    | look                      | look
# 61    | forward                   | forward
# 62    | team                      | team
# 63    | best                      | best
# 64    | regards                   | regard
# 65    | lisa                      | lisa
# 66    | wong                      | wong
# 67    | talent                    | talent
# 68    | acquisition               | acquisition
# 69    | lead                      | lead
# 70    | datamind                  | datamind
# 71    | corporation               | corporation
#
# COMPLETE LEMMATIZED TEXT:
# subject job offer senior data scientist position dear mr thompson congratulation pleased offer position senior data scientist datamind corp offer detail start date january th base salary year equity stock option bonus annual performance bonus location san francisco ca remote option available please review attached offer letter pdf sign december th onboarding document httpsdatamindcorponboardingmt question contact hr hrdatamindcom call look forward team best regard lisa wong talent acquisition lead datamind corporation
#
# STEMMING vs LEMMATIZATION COMPARISON:
# #     | Original Word             | Porter Stemmer       | Snowball Stemmer     | Lemmatized
# 1     | subject                   | subject              | subject              | subject
# 2     | job                       | job                  | job                  | job
# 3     | offer                     | offer                | offer                | offer
# 4     | senior                    | senior               | senior               | senior
# 5     | data                      | data                 | data                 | data
# 6     | scientist                 | scientist            | scientist            | scientist
# 7     | position                  | posit                | posit                | position
# 8     | dear                      | dear                 | dear                 | dear
# 9     | mr                        | mr                   | mr                   | mr
# 10    | thompson                  | thompson             | thompson             | thompson
# 11    | congratulations           | congratul            | congratul            | congratulation
# 12    | pleased                   | pleas                | pleas                | pleased
# 13    | offer                     | offer                | offer                | offer
# 14    | position                  | posit                | posit                | position
# 15    | senior                    | senior               | senior               | senior
# 16    | data                      | data                 | data                 | data
# 17    | scientist                 | scientist            | scientist            | scientist
# 18    | datamind                  | datamind             | datamind             | datamind
# 19    | corp                      | corp                 | corp                 | corp
# 20    | offer                     | offer                | offer                | offer
# 21    | details                   | detail               | detail               | detail
# 22    | start                     | start                | start                | start
# 23    | date                      | date                 | date                 | date
# 24    | january                   | januari              | januari              | january
# 25    | th                        | th                   | th                   | th
# 26    | base                      | base                 | base                 | base
# 27    | salary                    | salari               | salari               | salary
# 28    | year                      | year                 | year                 | year
# 29    | equity                    | equiti               | equiti               | equity
# 30    | stock                     | stock                | stock                | stock
# 31    | options                   | option               | option               | option
# 32    | bonus                     | bonu                 | bonus                | bonus
# 33    | annual                    | annual               | annual               | annual
# 34    | performance               | perform              | perform              | performance
# 35    | bonus                     | bonu                 | bonus                | bonus
# 36    | location                  | locat                | locat                | location
# 37    | san                       | san                  | san                  | san
# 38    | francisco                 | francisco            | francisco            | francisco
# 39    | ca                        | ca                   | ca                   | ca
# 40    | remote                    | remot                | remot                | remote
# 41    | options                   | option               | option               | option
# 42    | available                 | avail                | avail                | available
# 43    | please                    | pleas                | pleas                | please
# 44    | review                    | review               | review               | review
# 45    | attached                  | attach               | attach               | attached
# 46    | offer                     | offer                | offer                | offer
# 47    | letter                    | letter               | letter               | letter
# 48    | pdf                       | pdf                  | pdf                  | pdf
# 49    | sign                      | sign                 | sign                 | sign
# 50    | december                  | decemb               | decemb               | december
# 51    | th                        | th                   | th                   | th
# 52    | onboarding                | onboard              | onboard              | onboarding
# 53    | documents                 | document             | document             | document
# 54    | httpsdatamindcorponboardingmt | httpsdatamindcorponboardingmt | httpsdatamindcorponboardingmt | httpsdatamindcorponboardingmt
# 55    | questions                 | question             | question             | question
# 56    | contact                   | contact              | contact              | contact
# 57    | hr                        | hr                   | hr                   | hr
# 58    | hrdatamindcom             | hrdatamindcom        | hrdatamindcom        | hrdatamindcom
# 59    | call                      | call                 | call                 | call
# 60    | look                      | look                 | look                 | look
# 61    | forward                   | forward              | forward              | forward
# 62    | team                      | team                 | team                 | team
# 63    | best                      | best                 | best                 | best
# 64    | regards                   | regard               | regard               | regard
# 65    | lisa                      | lisa                 | lisa                 | lisa
# 66    | wong                      | wong                 | wong                 | wong
# 67    | talent                    | talent               | talent               | talent
# 68    | acquisition               | acquisit             | acquisit             | acquisition
# 69    | lead                      | lead                 | lead                 | lead
# 70    | datamind                  | datamind             | datamind             | datamind
# 71    | corporation               | corpor               | corpor               | corporation
#
# PERFORMANCE COMPARISON (Lemmatizer vs Stemmers):
# WordNetLemmatizer processing time (10 repetitions): 0.000000 seconds
# PorterStemmer processing time (10 repetitions): 0.006997 seconds
# SnowballStemmer processing time (10 repetitions): 0.004509 seconds

# %% [markdown]
# # 8. Part-of-Speech (POS) Tagging

# %%
# Cell 10: 8. POS Tagging (Part-of-Speech Tagging)
print("8. PART-OF-SPEECH (POS) TAGGING")

# Perform POS tagging on all filtered tokens
pos_tagged = pos_tag(filtered_tokens)

print("COMPLETE POS TAGGING RESULTS:")
print(f"{'#':<4} | {'Word':<20} | {'POS Tag':<10} | {'Description'}")

pos_descriptions = {
    'NN': 'Noun, singular', 'NNS': 'Noun, plural',
    'NNP': 'Proper noun, singular', 'NNPS': 'Proper noun, plural',
    'VB': 'Verb, base form', 'VBD': 'Verb, past tense',
    'VBG': 'Verb, gerund/present participle', 'VBN': 'Verb, past participle',
    'VBP': 'Verb, non-3rd person singular present', 'VBZ': 'Verb, 3rd person singular present',
    'JJ': 'Adjective', 'JJR': 'Adjective, comparative', 'JJS': 'Adjective, superlative',
    'RB': 'Adverb', 'RBR': 'Adverb, comparative', 'RBS': 'Adverb, superlative',
    'IN': 'Preposition/subordinating conjunction', 'DT': 'Determiner',
    'CC': 'Coordinating conjunction', 'PRP': 'Personal pronoun', 'PRP$': 'Possessive pronoun',
    'MD': 'Modal auxiliary', 'TO': 'to', 'UH': 'Interjection',
    'CD': 'Cardinal number', 'EX': 'Existential there', 'FW': 'Foreign word',
    'LS': 'List item marker', 'POS': 'Possessive ending', 'RP': 'Particle',
    'SYM': 'Symbol', 'WDT': 'Wh-determiner', 'WP': 'Wh-pronoun',
    'WP$': 'Possessive wh-pronoun', 'WRB': 'Wh-adverb'
}

for i, (word, tag) in enumerate(pos_tagged, 1):
    desc = pos_descriptions.get(tag, 'Other')
    print(f"{i:<4} | {word:<20} | {tag:<10} | {desc}")
# Out:
# 8. PART-OF-SPEECH (POS) TAGGING
# COMPLETE POS TAGGING RESULTS:
# #    | Word                 | POS Tag    | Description
# 1    | subject              | JJ         | Adjective
# 2    | job                  | NN         | Noun, singular
# 3    | offer                | NN         | Noun, singular
# 4    | senior               | JJ         | Adjective
# 5    | data                 | NNS        | Noun, plural
# 6    | scientist            | NN         | Noun, singular
# 7    | position             | NN         | Noun, singular
# 8    | dear                 | IN         | Preposition/subordinating conjunction
# 9    | mr                   | JJ         | Adjective
# 10   | thompson             | NN         | Noun, singular
# 11   | congratulations      | NNS        | Noun, plural
# 12   | pleased              | VBD        | Verb, past tense
# 13   | offer                | NN         | Noun, singular
# 14   | position             | NN         | Noun, singular
# 15   | senior               | JJ         | Adjective
# 16   | data                 | NNS        | Noun, plural
# 17   | scientist            | NN         | Noun, singular
# 18   | datamind             | IN         | Preposition/subordinating conjunction
# 19   | corp                 | NN         | Noun, singular
# 20   | offer                | NN         | Noun, singular
# 21   | details              | NNS        | Noun, plural
# 22   | start                | VBP        | Verb, non-3rd person singular present
# 23   | date                 | NN         | Noun, singular
# 24   | january              | JJ         | Adjective
# 25   | th                   | NN         | Noun, singular
# 26   | base                 | NN         | Noun, singular
# 27   | salary               | JJ         | Adjective
# 28   | year                 | NN         | Noun, singular
# 29   | equity               | NN         | Noun, singular
# 30   | stock                | NN         | Noun, singular
# 31   | options              | NNS        | Noun, plural
# 32   | bonus                | VBP        | Verb, non-3rd person singular present
# 33   | annual               | JJ         | Adjective
# 34   | performance          | NN         | Noun, singular
# 35   | bonus                | NN         | Noun, singular
# 36   | location             | NN         | Noun, singular
# 37   | san                  | NN         | Noun, singular
# 38   | francisco            | NN         | Noun, singular
# 39   | ca                   | MD         | Modal auxiliary
# 40   | remote               | VB         | Verb, base form
# 41   | options              | NNS        | Noun, plural
# 42   | available            | JJ         | Adjective
# 43   | please               | JJ         | Adjective
# 44   | review               | NN         | Noun, singular
# 45   | attached             | VBD        | Verb, past tense
# 46   | offer                | VBP        | Verb, non-3rd person singular present
# 47   | letter               | NN         | Noun, singular
# 48   | pdf                  | NN         | Noun, singular
# 49   | sign                 | NN         | Noun, singular
# 50   | december             | NNP        | Proper noun, singular
# 51   | th                   | NN         | Noun, singular
# 52   | onboarding           | VBG        | Verb, gerund/present participle
# 53   | documents            | NNS        | Noun, plural
# 54   | httpsdatamindcorponboardingmt | JJ         | Adjective
# 55   | questions            | NNS        | Noun, plural
# 56   | contact              | VBP        | Verb, non-3rd person singular present
# 57   | hr                   | JJ         | Adjective
# 58   | hrdatamindcom        | NN         | Noun, singular
# 59   | call                 | NN         | Noun, singular
# 60   | look                 | NN         | Noun, singular
# 61   | forward              | RB         | Adverb
# 62   | team                 | NN         | Noun, singular
# 63   | best                 | JJS        | Adjective, superlative
# 64   | regards              | NNS        | Noun, plural
# 65   | lisa                 | VBP        | Verb, non-3rd person singular present
# 66   | wong                 | JJ         | Adjective
# 67   | talent               | JJ         | Adjective
# 68   | acquisition          | NN         | Noun, singular
# 69   | lead                 | NN         | Noun, singular
# 70   | datamind             | NN         | Noun, singular
# 71   | corporation          | NN         | Noun, singular

# %% [markdown]
# # 9. Chunking

# %%
# Define chunk grammar
chunk_grammar = r"""
    NP: {<DT>?<JJ>*<NN.*>+}
    NP: {<NNP>+}
    NP: {<NNP><POS>?<NNP>*}
    VP: {<VB.*><NP|PP|CLAUSE>+$}
    PP: {<IN><NP>}
"""
chunk_parser = RegexpParser(chunk_grammar)

# Process ALL sentences for chunking
all_sentences = sent_tokenize(text_lower)

for sent_idx, sentence in enumerate(all_sentences, 1):
    print(f"\nSentence {sent_idx}: {sentence}")

    # Tokenize and tag
    tokens = word_tokenize(sentence)
    pos_tags = pos_tag(tokens)

    # Parse chunks
    chunk_tree = chunk_parser.parse(pos_tags)

    print("Chunk Tree Structure:")
    print(chunk_tree)

    print("Chunks extracted:")
    for subtree in chunk_tree.subtrees():
        if subtree.label() in ['NP', 'VP', 'PP']:
            chunk_words = ' '.join(word for word, tag in subtree.leaves())
            print(f"  {subtree.label()}: {chunk_words}")
# Out:
# Sentence 1: subject job offer  senior data scientist position dear mr. thompson, congratulations  we are pleased to offer you the position of senior data scientist at datamind corp. offer details  start date january th,  base salary ,year  equity , stock options  bonus  annual performance bonus  location san francisco, ca remote options available please review the attached offer letter pdf and sign by december th.
# Chunk Tree Structure:
# (S
#   (NP subject/JJ job/NN offer/NN)
#   (NP senior/JJ data/NNS scientist/NN position/NN)
#   (PP dear/IN (NP mr./JJ thompson/NNP))
#   ,/,
#   (NP congratulations/NNS)
#   we/PRP
#   are/VBP
#   pleased/JJ
#   to/TO
#   offer/VB
#   you/PRP
#   (NP the/DT position/NN)
#   (PP of/IN (NP senior/JJ data/NNS scientist/NN))
#   (PP at/IN (NP datamind/NNP corp./NN offer/NN details/NNS))
#   start/VBP
#   (NP date/NN)
#   (NP january/JJ th/NN)
#   ,/,
#   (NP base/NN salary/NN)
#   ,/,
#   (NP year/NN equity/NN)
#   ,/,
#   (NP stock/NN options/NNS)
#   bonus/VBP
#   (NP
#     annual/JJ
#     performance/NN
#     bonus/NN
#     location/NN
#     san/NN
#     francisco/NN)
#   ,/,
#   ca/MD
#   remote/VB
#   (NP options/NNS)
#   (NP available/JJ please/NN)
#   review/VB
#   (NP the/DT attached/JJ offer/NN letter/NN pdf/NN)
#   and/CC
#   (NP sign/NN)
#   (PP by/IN (NP december/NN th/NN))
#   ./.)
# Chunks extracted:
#   NP: subject job offer
#   NP: senior data scientist position
#   PP: dear mr. thompson
#   NP: mr. thompson
#   NP: congratulations
#   NP: the position
#   PP: of senior data scientist
#   NP: senior data scientist
#   PP: at datamind corp. offer details
#   NP: datamind corp. offer details
#   NP: date
#   NP: january th
#   NP: base salary
#   NP: year equity
#   NP: stock options
#   NP: annual performance bonus location san francisco
#   NP: options
#   NP: available please
#   NP: the attached offer letter pdf
#   NP: sign
#   PP: by december th
#   NP: december th
#
# Sentence 2: onboarding documents httpsdatamind.corponboardingmt if you have questions, contact hr at hrdatamind.com or call  .
# Chunk Tree Structure:
# (S
#   onboarding/VBG
#   (NP documents/NNS)
#   httpsdatamind.corponboardingmt/VB
#   if/IN
#   you/PRP
#   have/VBP
#   (NP questions/NNS)
#   ,/,
#   (NP contact/NN hr/NN)
#   (PP at/IN (NP hrdatamind.com/NN))
#   or/CC
#   (NP call/NN)
#   ./.)
# Chunks extracted:
#   NP: documents
#   NP: questions
#   NP: contact hr
#   PP: at hrdatamind.com
#   NP: hrdatamind.com
#   NP: call
#
# Sentence 3: we look forward to having you on the team  best regards, lisa wong talent acquisition lead datamind corporation
# Chunk Tree Structure:
# (S
#   we/PRP
#   look/VBP
#   forward/RB
#   to/TO
#   having/VBG
#   you/PRP
#   (PP on/IN (NP the/DT team/NN))
#   best/JJS
#   (NP regards/NNS)
#   ,/,
#   (VP
#     lisa/VBP
#     (NP
#       wong/JJ
#       talent/JJ
#       acquisition/NN
#       lead/NN
#       datamind/NN
#       corporation/NN)))
# Chunks extracted:
#   PP: on the team
#   NP: the team
#   NP: regards
#   VP: lisa wong talent acquisition lead datamind corporation
#   NP: wong talent acquisition lead datamind corporation

# %% [markdown]
# # 10. Parsing ( Dependency Parsing and Tree Structure Parsing )

# %%
# Process entire text with spaCy
doc = nlp(text_lower)

print("DEPENDENCY RELATIONS FOR ENTIRE TEXT:")

for token in doc:
    print(f"Word: '{token.text}'")
    print(f"  Head word: '{token.head.text}'")
    print(f"  Dependency relation: {token.dep_}")
    print(f"  Explanation: {spacy.explain(token.dep_)}")
    print(f"  Children: {[child.text for child in token.children]}")
# Out:
# DEPENDENCY RELATIONS FOR ENTIRE TEXT:
# Word: 'subject'
#   Head word: 'job'
#   Dependency relation: amod
#   Explanation: adjectival modifier
#   Children: []
# Word: 'job'
#   Head word: 'offer'
#   Dependency relation: nsubj
#   Explanation: nominal subject
#   Children: ['subject']
# Word: 'offer'
#   Head word: 'offer'
#   Dependency relation: nsubj
#   Explanation: nominal subject
#   Children: ['job', ' ', 'position', 'thompson', ',', 'congratulations']
# Word: ' '
#   Head word: 'offer'
#   Dependency relation: dep
#   Explanation: unclassified dependent
#   Children: []
# Word: 'senior'
#   Head word: 'position'
#   Dependency relation: amod
#   Explanation: adjectival modifier
#   Children: []
# Word: 'data'
#   Head word: 'scientist'
#   Dependency relation: compound
#   Explanation: compound
#   Children: []
# Word: 'scientist'
#   Head word: 'position'
#   Dependency relation: compound
#   Explanation: compound
#   Children: ['data']
# Word: 'position'
#   Head word: 'offer'
#   Dependency relation: dobj
#   Explanation: direct object
#   Children: ['senior', 'scientist']
# Word: 'dear'
#   Head word: 'thompson'
#   Dependency relation: compound
#   Explanation: compound
#   Children: []
# Word: 'mr'
#   Head word: 'thompson'
#   Dependency relation: compound
#   Explanation: compound
#   Children: []
# Word: '.'
#   Head word: 'thompson'
#   Dependency relation: compound
#   Explanation: compound
#   Children: []
# Word: 'thompson'
#   Head word: 'offer'
#   Dependency relation: npadvmod
#   Explanation: noun phrase as adverbial modifier
#   Children: ['dear', 'mr', '.']
# Word: ','
#   Head word: 'offer'
#   Dependency relation: punct
#   Explanation: punctuation
#   Children: []
# Word: 'congratulations'
#   Head word: 'offer'
#   Dependency relation: appos
#   Explanation: appositional modifier
#   Children: [' ', 'are']
# Word: ' '
#   Head word: 'congratulations'
#   Dependency relation: dep
#   Explanation: unclassified dependent
#   Children: []
# Word: 'we'
#   Head word: 'are'
#   Dependency relation: nsubj
#   Explanation: nominal subject
#   Children: []
# Word: 'are'
#   Head word: 'congratulations'
#   Dependency relation: relcl
#   Explanation: relative clause modifier
#   Children: ['we', 'pleased']
# Word: 'pleased'
#   Head word: 'are'
#   Dependency relation: acomp
#   Explanation: adjectival complement
#   Children: ['offer']
# Word: 'to'
#   Head word: 'offer'
#   Dependency relation: aux
#   Explanation: auxiliary
#   Children: []
# Word: 'offer'
#   Head word: 'pleased'
#   Dependency relation: xcomp
#   Explanation: open clausal complement
#   Children: ['to', 'you', 'position']
# Word: 'you'
#   Head word: 'offer'
#   Dependency relation: dative
#   Explanation: dative
#   Children: []
# Word: 'the'
#   Head word: 'position'
#   Dependency relation: det
#   Explanation: determiner
#   Children: []
# Word: 'position'
#   Head word: 'offer'
#   Dependency relation: dobj
#   Explanation: direct object
#   Children: ['the', 'of', 'at']
# Word: 'of'
#   Head word: 'position'
#   Dependency relation: prep
#   Explanation: prepositional modifier
#   Children: ['scientist']
# Word: 'senior'
#   Head word: 'scientist'
#   Dependency relation: amod
#   Explanation: adjectival modifier
#   Children: []
# Word: 'data'
#   Head word: 'scientist'
#   Dependency relation: compound
#   Explanation: compound
#   Children: []
# Word: 'scientist'
#   Head word: 'of'
#   Dependency relation: pobj
#   Explanation: object of preposition
#   Children: ['senior', 'data']
# Word: 'at'
#   Head word: 'position'
#   Dependency relation: prep
#   Explanation: prepositional modifier
#   Children: ['corp', '.']
# Word: 'datamind'
#   Head word: 'corp'
#   Dependency relation: compound
#   Explanation: compound
#   Children: []
# Word: 'corp'
#   Head word: 'at'
#   Dependency relation: pobj
#   Explanation: object of preposition
#   Children: ['datamind']
# Word: '.'
#   Head word: 'at'
#   Dependency relation: pobj
#   Explanation: object of preposition
#   Children: []
# Word: 'offer'
#   Head word: 'offer'
#   Dependency relation: ROOT
#   Explanation: root
#   Children: ['offer', 'details', 'start', 'th', ',', 'options', 'review', '.']
# Word: 'details'
#   Head word: 'offer'
#   Dependency relation: dobj
#   Explanation: direct object
#   Children: [' ']
# Word: ' '
#   Head word: 'details'
#   Dependency relation: dep
#   Explanation: unclassified dependent
#   Children: []
# Word: 'start'
#   Head word: 'offer'
#   Dependency relation: dative
#   Explanation: dative
#   Children: ['date', 'january']
# Word: 'date'
#   Head word: 'start'
#   Dependency relation: dobj
#   Explanation: direct object
#   Children: []
# Word: 'january'
#   Head word: 'start'
#   Dependency relation: npadvmod
#   Explanation: noun phrase as adverbial modifier
#   Children: []
# Word: 'th'
#   Head word: 'offer'
#   Dependency relation: dative
#   Explanation: dative
#   Children: []
# Word: ','
#   Head word: 'offer'
#   Dependency relation: punct
#   Explanation: punctuation
#   Children: [' ']
# Word: ' '
#   Head word: ','
#   Dependency relation: dep
#   Explanation: unclassified dependent
#   Children: []
# Word: 'base'
#   Head word: 'salary'
#   Dependency relation: compound
#   Explanation: compound
#   Children: []
# Word: 'salary'
#   Head word: 'remote'
#   Dependency relation: nsubj
#   Explanation: nominal subject
#   Children: ['base', ',', 'equity', ',']
# Word: ','
#   Head word: 'salary'
#   Dependency relation: punct
#   Explanation: punctuation
#   Children: []
# Word: 'year'
#   Head word: 'equity'
#   Dependency relation: compound
#   Explanation: compound
#   Children: [' ']
# Word: ' '
#   Head word: 'year'
#   Dependency relation: dep
#   Explanation: unclassified dependent
#   Children: []
# Word: 'equity'
#   Head word: 'salary'
#   Dependency relation: conj
#   Explanation: conjunct
#   Children: ['year', ',', 'francisco']
# Word: ','
#   Head word: 'equity'
#   Dependency relation: punct
#   Explanation: punctuation
#   Children: []
# Word: 'stock'
#   Head word: 'options'
#   Dependency relation: compound
#   Explanation: compound
#   Children: []
# Word: 'options'
#   Head word: 'bonus'
#   Dependency relation: compound
#   Explanation: compound
#   Children: ['stock', ' ']
# Word: ' '
#   Head word: 'options'
#   Dependency relation: dep
#   Explanation: unclassified dependent
#   Children: []
# Word: 'bonus'
#   Head word: 'location'
#   Dependency relation: compound
#   Explanation: compound
#   Children: ['options', ' ']
# Word: ' '
#   Head word: 'bonus'
#   Dependency relation: dep
#   Explanation: unclassified dependent
#   Children: []
# Word: 'annual'
#   Head word: 'performance'
#   Dependency relation: amod
#   Explanation: adjectival modifier
#   Children: []
# Word: 'performance'
#   Head word: 'location'
#   Dependency relation: compound
#   Explanation: compound
#   Children: ['annual']
# Word: 'bonus'
#   Head word: 'location'
#   Dependency relation: compound
#   Explanation: compound
#   Children: [' ']
# Word: ' '
#   Head word: 'bonus'
#   Dependency relation: dep
#   Explanation: unclassified dependent
#   Children: []
# Word: 'location'
#   Head word: 'francisco'
#   Dependency relation: compound
#   Explanation: compound
#   Children: ['bonus', 'performance', 'bonus']
# Word: 'san'
#   Head word: 'francisco'
#   Dependency relation: compound
#   Explanation: compound
#   Children: []
# Word: 'francisco'
#   Head word: 'equity'
#   Dependency relation: conj
#   Explanation: conjunct
#   Children: ['location', 'san']
# Word: ','
#   Head word: 'salary'
#   Dependency relation: punct
#   Explanation: punctuation
#   Children: []
# Word: 'ca'
#   Head word: 'remote'
#   Dependency relation: aux
#   Explanation: auxiliary
#   Children: []
# Word: 'remote'
#   Head word: 'options'
#   Dependency relation: amod
#   Explanation: adjectival modifier
#   Children: ['salary', 'ca']
# Word: 'options'
#   Head word: 'offer'
#   Dependency relation: dobj
#   Explanation: direct object
#   Children: ['remote', 'available']
# Word: 'available'
#   Head word: 'options'
#   Dependency relation: amod
#   Explanation: adjectival modifier
#   Children: []
# Word: 'please'
#   Head word: 'review'
#   Dependency relation: intj
#   Explanation: interjection
#   Children: []
# Word: 'review'
#   Head word: 'offer'
#   Dependency relation: dep
#   Explanation: unclassified dependent
#   Children: ['please', 'pdf', 'by']
# Word: 'the'
#   Head word: 'pdf'
#   Dependency relation: det
#   Explanation: determiner
#   Children: []
# Word: 'attached'
#   Head word: 'pdf'
#   Dependency relation: amod
#   Explanation: adjectival modifier
#   Children: []
# Word: 'offer'
#   Head word: 'pdf'
#   Dependency relation: compound
#   Explanation: compound
#   Children: []
# Word: 'letter'
#   Head word: 'pdf'
#   Dependency relation: compound
#   Explanation: compound
#   Children: []
# Word: 'pdf'
#   Head word: 'review'
#   Dependency relation: dobj
#   Explanation: direct object
#   Children: ['the', 'attached', 'offer', 'letter', 'and', 'sign']
# Word: 'and'
#   Head word: 'pdf'
#   Dependency relation: cc
#   Explanation: coordinating conjunction
#   Children: []
# Word: 'sign'
#   Head word: 'pdf'
#   Dependency relation: conj
#   Explanation: conjunct
#   Children: []
# Word: 'by'
#   Head word: 'review'
#   Dependency relation: prep
#   Explanation: prepositional modifier
#   Children: ['december']
# Word: 'december'
#   Head word: 'by'
#   Dependency relation: pobj
#   Explanation: object of preposition
#   Children: ['th']
# Word: 'th'
#   Head word: 'december'
#   Dependency relation: nummod
#   Explanation: numeric modifier
#   Children: []
# Word: '.'
#   Head word: 'offer'
#   Dependency relation: punct
#   Explanation: punctuation
#   Children: []
# Word: 'onboarding'
#   Head word: 'documents'
#   Dependency relation: amod
#   Explanation: adjectival modifier
#   Children: []
# Word: 'documents'
#   Head word: 'documents'
#   Dependency relation: ROOT
#   Explanation: root
#   Children: ['onboarding', 'httpsdatamind.corponboardingmt', 'have', ',', 'hr', '.']
# Word: 'httpsdatamind.corponboardingmt'
#   Head word: 'documents'
#   Dependency relation: prep
#   Explanation: prepositional modifier
#   Children: []
# Word: 'if'
#   Head word: 'have'
#   Dependency relation: mark
#   Explanation: marker
#   Children: []
# Word: 'you'
#   Head word: 'have'
#   Dependency relation: nsubj
#   Explanation: nominal subject
#   Children: []
# Word: 'have'
#   Head word: 'documents'
#   Dependency relation: advcl
#   Explanation: adverbial clause modifier
#   Children: ['if', 'you', 'questions']
# Word: 'questions'
#   Head word: 'have'
#   Dependency relation: dobj
#   Explanation: direct object
#   Children: []
# Word: ','
#   Head word: 'documents'
#   Dependency relation: punct
#   Explanation: punctuation
#   Children: []
# Word: 'contact'
#   Head word: 'hr'
#   Dependency relation: compound
#   Explanation: compound
#   Children: []
# Word: 'hr'
#   Head word: 'documents'
#   Dependency relation: appos
#   Explanation: appositional modifier
#   Children: ['contact', 'at', 'or', 'call']
# Word: 'at'
#   Head word: 'hr'
#   Dependency relation: prep
#   Explanation: prepositional modifier
#   Children: ['hrdatamind.com']
# Word: 'hrdatamind.com'
#   Head word: 'at'
#   Dependency relation: pobj
#   Explanation: object of preposition
#   Children: []
# Word: 'or'
#   Head word: 'hr'
#   Dependency relation: cc
#   Explanation: coordinating conjunction
#   Children: []
# Word: 'call'
#   Head word: 'hr'
#   Dependency relation: conj
#   Explanation: conjunct
#   Children: [' ']
# Word: ' '
#   Head word: 'call'
#   Dependency relation: dep
#   Explanation: unclassified dependent
#   Children: []
# Word: '.'
#   Head word: 'documents'
#   Dependency relation: punct
#   Explanation: punctuation
#   Children: []
# Word: 'we'
#   Head word: 'look'
#   Dependency relation: nsubj
#   Explanation: nominal subject
#   Children: []
# Word: 'look'
#   Head word: 'look'
#   Dependency relation: ROOT
#   Explanation: root
#   Children: ['we', 'forward', 'to', ',', 'corporation']
# Word: 'forward'
#   Head word: 'look'
#   Dependency relation: advmod
#   Explanation: adverbial modifier
#   Children: []
# Word: 'to'
#   Head word: 'look'
#   Dependency relation: prep
#   Explanation: prepositional modifier
#   Children: ['having']
# Word: 'having'
#   Head word: 'to'
#   Dependency relation: pcomp
#   Explanation: complement of preposition
#   Children: ['you', 'on', 'regards']
# Word: 'you'
#   Head word: 'having'
#   Dependency relation: dobj
#   Explanation: direct object
#   Children: []
# Word: 'on'
#   Head word: 'having'
#   Dependency relation: prep
#   Explanation: prepositional modifier
#   Children: ['team']
# Word: 'the'
#   Head word: 'team'
#   Dependency relation: det
#   Explanation: determiner
#   Children: []
# Word: 'team'
#   Head word: 'on'
#   Dependency relation: pobj
#   Explanation: object of preposition
#   Children: ['the', ' ']
# Word: ' '
#   Head word: 'team'
#   Dependency relation: dep
#   Explanation: unclassified dependent
#   Children: []
# Word: 'best'
#   Head word: 'regards'
#   Dependency relation: amod
#   Explanation: adjectival modifier
#   Children: []
# Word: 'regards'
#   Head word: 'having'
#   Dependency relation: dobj
#   Explanation: direct object
#   Children: ['best']
# Word: ','
#   Head word: 'look'
#   Dependency relation: punct
#   Explanation: punctuation
#   Children: []
# Word: 'lisa'
#   Head word: 'acquisition'
#   Dependency relation: compound
#   Explanation: compound
#   Children: []
# Word: 'wong'
#   Head word: 'acquisition'
#   Dependency relation: compound
#   Explanation: compound
#   Children: []
# Word: 'talent'
#   Head word: 'acquisition'
#   Dependency relation: compound
#   Explanation: compound
#   Children: []
# Word: 'acquisition'
#   Head word: 'lead'
#   Dependency relation: nsubj
#   Explanation: nominal subject
#   Children: ['lisa', 'wong', 'talent']
# Word: 'lead'
#   Head word: 'corporation'
#   Dependency relation: compound
#   Explanation: compound
#   Children: ['acquisition']
# Word: 'datamind'
#   Head word: 'corporation'
#   Dependency relation: compound
#   Explanation: compound
#   Children: []
# Word: 'corporation'
#   Head word: 'look'
#   Dependency relation: npadvmod
#   Explanation: noun phrase as adverbial modifier
#   Children: ['lead', 'datamind']

# %%
all_sentences = sent_tokenize(text_lower)

for sent_idx, sentence in enumerate(all_sentences, 1):
    print(f"\nSentence {sent_idx}: {sentence}")

    # Tokenize and tag
    tokens = word_tokenize(sentence)
    pos_tags = pos_tag(tokens)

    # Create a simple binary tree structure for visualization
    def create_simple_tree(tokens, pos_tags):
        """Create a simple constituency-like tree structure"""
        if len(tokens) == 1:
            return Tree(pos_tags[0][1], [tokens[0]])
        else:
            mid = len(tokens) // 2
            left_tree = create_simple_tree(tokens[:mid], pos_tags[:mid])
            right_tree = create_simple_tree(tokens[mid:], pos_tags[mid:])
            return Tree('S', [left_tree, right_tree])

    try:
        constituency_tree = create_simple_tree(tokens, pos_tags)
        print("Constituency Tree:")
        constituency_tree.pretty_print()

        print("Tree in bracketed notation:")
        print(constituency_tree)
    except Exception as e:
        print(f"Error creating tree: {e}")

print("\nALTERNATIVE TREE VISUALIZATION (ALL SENTENCES - Detailed NP chunks):")

# More detailed tree structure for ALL sentences
for sent_idx, sentence in enumerate(all_sentences, 1):
    print(f"\nSentence {sent_idx}: {sentence}")

    tokens = word_tokenize(sentence)
    pos_tags = pos_tag(tokens)

    # Manual tree building
    tree = Tree('S', [])
    current_np = []

    for word, tag in pos_tags:
        if tag.startswith('NN') or tag.startswith('JJ') or tag == 'DT':
            current_np.append((word, tag))
        else:
            if current_np:
                np_tree = Tree('NP', [f"{w}/{t}" for w, t in current_np])
                tree.append(np_tree)
                current_np = []
            tree.append(f"{word}/{tag}")

    if current_np:
        np_tree = Tree('NP', [f"{w}/{t}" for w, t in current_np])
        tree.append(np_tree)

    print("Detailed Constituency Tree (NP chunks):")
    tree.pretty_print()
    print("\nTree as string:")
    print(tree)
# Out:
# Sentence 1: subject job offer  senior data scientist position dear mr. thompson, congratulations  we are pleased to offer you the position of senior data scientist at datamind corp. offer details  start date january th,  base salary ,year  equity , stock options  bonus  annual performance bonus  location san francisco, ca remote options available please review the attached offer letter pdf and sign by december th.
# Constituency Tree:
#                                                                                                                                                                                                                                                                                                                  S
#                                                                                                                                                               ___________________________________________________________________________________________________________________________________________________|___________________________________________________________________________________________________________________________________________________
#                                                                                                                                                              S                                                                                                                                                                                                                                                                                                       S
#                                                                            __________________________________________________________________________________|_______________________________________________________________________                                                                                                                                                 _______________________________________________________________________________|____________________________________________________________________________________
#                                                                           |                                                                                                                                                          S                                                                                                                                               S                                                                                                                                                                    S
#                                                                           |                                                                                                              ____________________________________________|______________________________________                                                                  _______________________________________|___________________________________________                                                                           ______________________________________________|_______________________________
#                                                                           S                                                                                                             |                                                                                   S                                                                |                                                                                   S                                                                         |                                                                              S
#                                  _________________________________________|_______________________________________                                                                      |                                                              _____________________|_______________                                                 |                                                        ___________________________|_________________                                                        |                                                               _______________|______________
#                                 S                                                                                 S                                                                     S                                                             |                                     S                                                S                                                       |                                             S                                                       S                                                              |                              S
#                   ______________|________________________                                        _________________|_____________________                                   _____________|_____________________                                        |                            _________|______                            ______________|___________________                                    |                                 ____________|______                               __________________|________________________                                      |                     _________|______
#                  S                                       S                                      S                                       S                                 S                                   S                                       S                           |                S                          S                                  S                                   S                                |                   S                             S                                           S                                     S                    |                S
#           _______|_________                 _____________|____________              ____________|_______                         _______|___________               _______|_______                  __________|________                   ____________|_________                  |          ______|_____             ________|__________              __________|_______                   _________|__________                      |             ______|______             __________|___________                      __________|_______                    __________|_______             |          ______|___
#          S                 S               S                          S            S                    S                       S                   S             S               S                S                   S                 S                      S                 S         |            S           S                   S            S                  S                 S                    S                     S            |             S           S                      S                    S                  S                  S                  S            S         |          S
#     _____|___          ____|____       ____|______              ______|___      ___|_____            ___|_________           ___|___           _____|___      ____|___         ___|_____        ___|____           ____|______        ___|_____             ____|____        _____|____     |       _____|___     ___|___           _____|___     ____|____           ___|____        _____|____           _____|_______          ____|_____       |       ______|___     ___|____             _____|______         _____|____           ___|_____         ____|____           ___|___     ____|___      |       ___|___
#    JJ        NN       NN        JJ   NNS          NN           NN         IN   JJ       NNP         ,            NNS       PRP     VBP        JJ        TO   VB      PRP      DT        NN     IN       JJ       NNS          NN     IN       NNP          NN        NN    NNS        VBP   NN     JJ        NN  ,       NN        NN        ,   NN        NN        ,        NN    NNS        VBP        JJ            NN       NN         NN     NN     NN         ,   MD       VB         NNS           JJ      NN         VB        DT        JJ      NN        NN        NN      CC  NN       IN    NN     NN      .
#    |         |        |         |     |           |            |          |    |         |          |             |         |       |         |         |    |        |       |         |      |        |         |           |      |         |           |         |      |          |    |      |         |   |       |         |         |   |         |         |        |      |          |         |             |        |          |      |      |          |   |        |           |            |       |          |         |         |       |         |         |       |   |        |     |      |       |
# subject     job     offer     senior data     scientist     position     dear mr.     thompson      ,      congratulations  we     are     pleased      to offer     you     the     position  of     senior     data     scientist  at     datamind     corp.     offer details     start date january      th  ,      base     salary      ,  year     equity      ,      stock options     bonus     annual     performance bonus     location san francisco      ,   ca     remote     options     available please     review     the     attached offer     letter     pdf     and sign      by december  th      .
#
# Tree in bracketed notation:
# (S
#   (S
#     (S
#       (S
#         (S (S (JJ subject) (NN job)) (S (NN offer) (JJ senior)))
#         (S (S (NNS data) (NN scientist)) (S (NN position) (IN dear))))
#       (S
#         (S
#           (S (JJ mr.) (NNP thompson))
#           (S (, ,) (NNS congratulations)))
#         (S (S (PRP we) (VBP are)) (S (JJ pleased) (TO to)))))
#     (S
#       (S
#         (S (S (VB offer) (PRP you)) (S (DT the) (NN position)))
#         (S (S (IN of) (JJ senior)) (S (NNS data) (NN scientist))))
#       (S
#         (S (S (IN at) (NNP datamind)) (S (NN corp.) (NN offer)))
#         (S
#           (S (NNS details) (VBP start))
#           (S (NN date) (S (JJ january) (NN th)))))))
#   (S
#     (S
#       (S
#         (S (S (, ,) (NN base)) (S (NN salary) (, ,)))
#         (S (S (NN year) (NN equity)) (S (, ,) (NN stock))))
#       (S
#         (S
#           (S (NNS options) (VBP bonus))
#           (S (JJ annual) (NN performance)))
#         (S
#           (S (NN bonus) (NN location))
#           (S (NN san) (S (NN francisco) (, ,))))))
#     (S
#       (S
#         (S (S (MD ca) (VB remote)) (S (NNS options) (JJ available)))
#         (S (S (NN please) (VB review)) (S (DT the) (JJ attached))))
#       (S
#         (S (S (NN offer) (NN letter)) (S (NN pdf) (CC and)))
#         (S (S (NN sign) (IN by)) (S (NN december) (S (NN th) (. .))))))))
#
# Sentence 2: onboarding documents httpsdatamind.corponboardingmt if you have questions, contact hr at hrdatamind.com or call  .
# Constituency Tree:
#                                                                               S
#                                             __________________________________|___________________________
#                                            S                                                              S
#                 ___________________________|___________                                        ___________|__________________________
#                S                                       S                                      S                                      S
#      __________|______                          _______|________                   ___________|_______                        _______|________
#     |                 S                        S                S                 S                   S                      S                S
#     |           ______|_________            ___|___         ____|______        ___|_____           ___|___          _________|___         ____|___
#    VBG        NNS               VB         IN     PRP     VBP         NNS     ,         NN        NN      IN       NN            CC      NN       .
#     |          |                |          |       |       |           |      |         |         |       |        |             |       |        |
# onboarding documents      httpsdatamind.   if     you     have     questions  ,      contact      hr      at hrdatamind.com      or     call      .
#                          corponboardingmt
#
# Tree in bracketed notation:
# (S
#   (S
#     (S
#       (VBG onboarding)
#       (S (NNS documents) (VB httpsdatamind.corponboardingmt)))
#     (S (S (IN if) (PRP you)) (S (VBP have) (NNS questions))))
#   (S
#     (S (S (, ,) (NN contact)) (S (NN hr) (IN at)))
#     (S (S (NN hrdatamind.com) (CC or)) (S (NN call) (. .)))))
#
# Sentence 3: we look forward to having you on the team  best regards, lisa wong talent acquisition lead datamind corporation
# Constituency Tree:
#                                                                   S
#                                     ______________________________|_____________________________
#                                    S                                                            S
#                ____________________|_____________                                   ____________|___________________________
#               |                                  S                                 S                                        S
#               |                           _______|___                   ___________|___                      _______________|______
#               S                          |           S                 |               S                    |                      S
#       ________|___________               |        ___|___              |            ___|____                |                ______|______
#      S                    S              S       |       S             S           |        S               S               |             S
#   ___|___            _____|___      _____|___    |    ___|___      ____|_____      |    ____|___       _____|_______        |       ______|_______
# PRP     VBP         RB        TO  VBG       PRP  IN  DT      NN  JJS        NNS    ,  VBP       JJ    JJ            NN      NN     NN             NN
#  |       |          |         |    |         |   |   |       |    |          |     |   |        |     |             |       |      |              |
#  we     look     forward      to having     you  on the     team best     regards  ,  lisa     wong talent     acquisition lead datamind     corporation
#
# Tree in bracketed notation:
# (S
#   (S
#     (S (S (PRP we) (VBP look)) (S (RB forward) (TO to)))
#     (S (S (VBG having) (PRP you)) (S (IN on) (S (DT the) (NN team)))))
#   (S
#     (S
#       (S (JJS best) (NNS regards))
#       (S (, ,) (S (VBP lisa) (JJ wong))))
#     (S
#       (S (JJ talent) (NN acquisition))
#       (S (NN lead) (S (NN datamind) (NN corporation))))))
#
# ALTERNATIVE TREE VISUALIZATION (ALL SENTENCES - Detailed NP chunks):
#
# Sentence 1: subject job offer  senior data scientist position dear mr. thompson, congratulations  we are pleased to offer you the position of senior data scientist at datamind corp. offer details  start date january th,  base salary ,year  equity , stock options  bonus  annual performance bonus  location san francisco, ca remote options available please review the attached offer letter pdf and sign by december th.
# Detailed Constituency Tree (NP chunks):
#                                                                                                                                                                                                                                                                                         S
#     ____________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________|______________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________
#    |     |    |       |      |      |        |      |     |       |      |   |   |      |      |    |       |         |       |      |    |                                 NP                                              NP                     NP            NP             NP                          NP                                 NP                                     NP                    NP                    NP                     NP                                         NP                                                     NP                                      NP                        NP                NP
#    |     |    |       |      |      |        |      |     |       |      |   |   |      |      |    |       |         |       |      |    |       __________________________|________________________________          _____|_______               |             |         _____|_______            ________|__________              __________|___________________           ________|________        _____|______          _____|______          ______|_______            _______________________|_____________________________              ___________|___________         ___________________|_________________        |          _______|____
# dear/IN ,/, we/PRP are/VBP to/TO offer/VB you/PRP of/IN at/IN start/VBP ,/, ,/, ,/, bonus/VBP ,/, ca/MD remote/VB review/VB and/CC by/IN ./. subject/JJ job/NN offer/NN senior/JJ data/NNS scientist/NN position/NN mr./JJ     thompson/NNP congratulations/ pleased/JJ the/DT     position/NN senior/JJ data/NNS scientist/NN datamind/NNP corp./NN offer/NN details/NNS date/NN january/JJ th/NN base/NN     salary/NN year/NN     equity/NN stock/NN     options/NNS annual/JJ performance/NN bonus/NN location/NN san/NN francisco/NN options/NNS available/JJ please/NN the/DT attached/JJ offer/NN letter/NN pdf/NN sign/NN december/NN     th/NN
#                                                                                                                                                                                                                                                   NNS
#
#
# Tree as string:
# (S
#   (NP
#     subject/JJ
#     job/NN
#     offer/NN
#     senior/JJ
#     data/NNS
#     scientist/NN
#     position/NN)
#   dear/IN
#   (NP mr./JJ thompson/NNP)
#   ,/,
#   (NP congratulations/NNS)
#   we/PRP
#   are/VBP
#   (NP pleased/JJ)
#   to/TO
#   offer/VB
#   you/PRP
#   (NP the/DT position/NN)
#   of/IN
#   (NP senior/JJ data/NNS scientist/NN)
#   at/IN
#   (NP datamind/NNP corp./NN offer/NN details/NNS)
#   start/VBP
#   (NP date/NN january/JJ th/NN)
#   ,/,
#   (NP base/NN salary/NN)
#   ,/,
#   (NP year/NN equity/NN)
#   ,/,
#   (NP stock/NN options/NNS)
#   bonus/VBP
#   (NP
#     annual/JJ
#     performance/NN
#     bonus/NN
#     location/NN
#     san/NN
#     francisco/NN)
#   ,/,
#   ca/MD
#   remote/VB
#   (NP options/NNS available/JJ please/NN)
#   review/VB
#   (NP the/DT attached/JJ offer/NN letter/NN pdf/NN)
#   and/CC
#   (NP sign/NN)
#   by/IN
#   (NP december/NN th/NN)
#   ./.)
#
# Sentence 2: onboarding documents httpsdatamind.corponboardingmt if you have questions, contact hr at hrdatamind.com or call  .
# Detailed Constituency Tree (NP chunks):
#                                                                     S
#        _____________________________________________________________|___________________________________________________________________________
#       |                |           |      |       |      |    |     |    |        NP            NP                  NP              NP          NP
#       |                |           |      |       |      |    |     |    |        |             |            _______|____           |           |
# onboarding/VBG   httpsdatamind.  if/IN you/PRP have/VBP ,/, at/IN or/CC ./. documents/NNS questions/NNS contact/NN     hr/NN hrdatamind.com/ call/NN
#                corponboardingmt/                                                                                                    NN
#                        VB
#
#
# Tree as string:
# (S
#   onboarding/VBG
#   (NP documents/NNS)
#   httpsdatamind.corponboardingmt/VB
#   if/IN
#   you/PRP
#   have/VBP
#   (NP questions/NNS)
#   ,/,
#   (NP contact/NN hr/NN)
#   at/IN
#   (NP hrdatamind.com/NN)
#   or/CC
#   (NP call/NN)
#   ./.)
#
# Sentence 3: we look forward to having you on the team  best regards, lisa wong talent acquisition lead datamind corporation
# Detailed Constituency Tree (NP chunks):
#                                                                          S
#    ______________________________________________________________________|_________________________________________________________
#   |       |         |        |       |         |      |    |     |               NP                                                NP
#   |       |         |        |       |         |      |    |     |        _______|__________________           ____________________|__________________________________
# we/PRP look/VBP forward/RB to/TO having/VBG you/PRP on/IN ,/, lisa/VBP the/DT team/NN best/JJS regards/NNS wong/JJ talent/JJ acquisition/NN lead/NN datamind/NN corporation/NN
#
#
# Tree as string:
# (S
#   we/PRP
#   look/VBP
#   forward/RB
#   to/TO
#   having/VBG
#   you/PRP
#   on/IN
#   (NP the/DT team/NN best/JJS regards/NNS)
#   ,/,
#   lisa/VBP
#   (NP
#     wong/JJ
#     talent/JJ
#     acquisition/NN
#     lead/NN
#     datamind/NN
#     corporation/NN))

# %% [markdown]
# # 11. Hypernyms and Hyponyms (WordNet)

# %%
# Extract ALL unique words from filtered tokens
unique_words = list(set(filtered_tokens))

for word in unique_words:
    print(f"\nWORD: '{word}'")

    # Get synsets for the word
    synsets = wn.synsets(word)

    if not synsets:
        print(f"  No synsets found for '{word}'")
        continue

    # Take first synset
    synset = synsets[0]
    print(f"  Definition: {synset.definition()}")
    print(f"  Example: {synset.examples() if synset.examples() else 'No example'}")

    # Hypernyms (more general concepts)
    hypernyms = synset.hypernyms()
    if hypernyms:
        print(f"\n  HYPERNYMS (more general): {len(hypernyms)} found")
        for hyp in hypernyms:
            print(f"    → {hyp.name()}")
            print(f"      Definition: {hyp.definition()}")
            # Get path hypernyms (higher level)
            hyper_paths = hyp.hypernyms()
            if hyper_paths:
                for path_hyp in hyper_paths:
                    print(f"        ↑ {path_hyp.name()}: {path_hyp.definition()}")
    else:
        print(f"\n  HYPERNYMS: None found")

    # Hyponyms (more specific concepts)
    hyponyms = synset.hyponyms()
    if hyponyms:
        print(f"\n  HYPONYMS (more specific): {len(hyponyms)} found")
        for hyp in hyponyms:
            print(f"    → {hyp.name()}")
            print(f"      Definition: {hyp.definition()}")
    else:
        print(f"\n  HYPONYMS: None found")

    # Full hierarchy path (no depth limit)
    print(f"\n  HIERARCHY PATH (up to root):")
    def show_path(s, level=0):
        print(f"    {'  ' * level}└─ {s.name()}")
        for hyp in s.hypernyms():
            show_path(hyp, level + 1)

    show_path(synset)

# Detailed example for ALL specific words from the text
print("\nDETAILED EXAMPLE FOR KEY WORDS FROM TEXT")

key_words = ['apple', 'computer', 'company', 'inventor', 'founder', 'ceo', 'pixar', 'next']

for word in key_words:
    print(f"\nDEEP ANALYSIS FOR: '{word}'")

    synsets = wn.synsets(word)
    if synsets:
        primary_synset = synsets[0]

        print(f"  Definition: {primary_synset.definition()}")
        print(f"  Lemmas: {primary_synset.lemma_names()}")

        # Get all hypernym paths (no limit)
        print("\n  All Hypernym Paths:")
        hypernym_paths = primary_synset.hypernym_paths()
        for i, path in enumerate(hypernym_paths, 1):
            print(f"    Path {i}: {' -> '.join([s.name().split('.')[0] for s in path])}")

        # Get all hyponyms (no limit on display)
        all_hyponyms = primary_synset.hyponyms()
        print(f"\n  Total hyponyms found: {len(all_hyponyms)}")
        if all_hyponyms:
            print("  All hyponyms:")
            for hyp in all_hyponyms:
                print(f"    - {hyp.name()}: {hyp.definition()}")
# Out:
# WORD: 'team'
#   Definition: a cooperative unit (especially in sports)
#   Example: No example
#
#   HYPERNYMS (more general): 1 found
#     → unit.n.03
#       Definition: an organization regarded as part of a larger social group
#         ↑ organization.n.01: a group of people who work together
#
#   HYPONYMS (more specific): 20 found
#     → powerhouse.n.02
#       Definition: a team considered to be the best of its class
#     → football_team.n.01
#       Definition: a team that plays football
#     → crew.n.04
#       Definition: the team of men manning a racing shell
#     → junior_varsity.n.01
#       Definition: a college or university team that competes at a level below the varsity team
#     → a-team.n.01
#       Definition: a group of elite soldiers or a leadership group of advisors or workers in an organization
#     → hit_squad.n.01
#       Definition: a team of assassins
#     → major-league_team.n.01
#       Definition: a team that plays in a major league
#     → defense.n.03
#       Definition: (sports) the team that is trying to prevent the other team from scoring
#     → second_string.n.01
#       Definition: a squad of players that are available either individually or as a team to relieve or replace the players who started the game
#     → section.n.05
#       Definition: a small team of policemen working as part of a police platoon
#     → baseball_team.n.01
#       Definition: a team that plays baseball
#     → offense.n.04
#       Definition: the team that has the ball (or puck) and is trying to score
#     → varsity.n.02
#       Definition: a team representing a college or university
#     → battery.n.04
#       Definition: a unit composed of the pitcher and catcher
#     → hockey_team.n.01
#       Definition: a team that plays ice hockey
#     → flying_squad.n.01
#       Definition: a mobile group of trained people (police or executives or officials) able to move quickly in the case of emergencies
#     → little-league_team.n.01
#       Definition: a team that plays in a little league
#     → basketball_team.n.01
#       Definition: a team that plays basketball
#     → police_squad.n.01
#       Definition: a small squad of policemen trained to deal with a particular kind of crime
#     → minor-league_team.n.01
#       Definition: a team that plays in a minor league
#
#   HIERARCHY PATH (up to root):
#     └─ team.n.01
#       └─ unit.n.03
#         └─ organization.n.01
#           └─ social_group.n.01
#             └─ group.n.01
#               └─ abstraction.n.06
#                 └─ entity.n.01
#
# WORD: 'congratulations'
#   Definition: an expression of approval and commendation
#   Example: ['he always appreciated praise for his work']
#
#   HYPERNYMS (more general): 1 found
#     → approval.n.04
#       Definition: a message expressing a favorable opinion
#         ↑ message.n.02: what a communication that is about something is about
#
#   HYPONYMS (more specific): 5 found
#     → eulogy.n.01
#       Definition: a formal expression of praise for someone who has died recently
#     → superlative.n.01
#       Definition: an exaggerated expression (usually of praise)
#     → encomium.n.01
#       Definition: a formal expression of praise
#     → recommendation.n.02
#       Definition: something that recommends (or expresses commendation of) a person or thing as worthy or desirable
#     → compliment.n.01
#       Definition: a remark (or act) expressing praise and admiration
#
#   HIERARCHY PATH (up to root):
#     └─ praise.n.01
#       └─ approval.n.04
#         └─ message.n.02
#           └─ communication.n.02
#             └─ abstraction.n.06
#               └─ entity.n.01
#
# WORD: 'bonus'
#   Definition: anything that tends to arouse
#   Example: ['his approval was an added fillip']
#
#   HYPERNYMS (more general): 1 found
#     → positive_stimulus.n.01
#       Definition: a stimulus with desirable consequences
#         ↑ stimulation.n.02: any stimulating information or event; acts to arouse action
#
#   HYPONYMS: None found
#
#   HIERARCHY PATH (up to root):
#     └─ bonus.n.01
#       └─ positive_stimulus.n.01
#         └─ stimulation.n.02
#           └─ information.n.02
#             └─ cognition.n.01
#               └─ psychological_feature.n.01
#                 └─ abstraction.n.06
#                   └─ entity.n.01
#
# WORD: 'available'
#   Definition: obtainable or accessible and ready for use or service
#   Example: ['kept a fire extinguisher available', 'much information is available through computers', 'available in many colors', 'the list of available candidates is unusually long']
#
#   HYPERNYMS: None found
#
#   HYPONYMS: None found
#
#   HIERARCHY PATH (up to root):
#     └─ available.a.01
#
# WORD: 'onboarding'
#   No synsets found for 'onboarding'
#
# WORD: 'documents'
#   Definition: writing that provides information (especially information of an official nature)
#   Example: No example
#
#   HYPERNYMS (more general): 1 found
#     → writing.n.02
#       Definition: the work of a writer; anything expressed in letters of the alphabet (especially when considered from the point of view of style and effect)
#         ↑ written_communication.n.01: communication by means of written symbols (either printed or handwritten)
#
#   HYPONYMS (more specific): 20 found
#     → certificate.n.01
#       Definition: a document attesting to the truth of certain stated facts
#     → form.n.08
#       Definition: a printed document with spaces in which to write
#     → confession.n.02
#       Definition: a written document acknowledging an offense and signed by the guilty party
#     → commercial_document.n.01
#       Definition: a document of or relating to commerce
#     → voucher.n.02
#       Definition: a document that serves as evidence of some expenditure
#     → resignation.n.03
#       Definition: a formal document giving notice of your intention to resign
#     → brevet.n.01
#       Definition: a document entitling a commissioned officer to hold a higher rank temporarily (but without higher pay)
#     → copyright.n.01
#       Definition: a document granting exclusive right to publish and sell literary or musical or artistic work
#     → charter.n.01
#       Definition: a document incorporating an institution and specifying its rights; includes the articles of incorporation and the certificate of incorporation
#     → patent.n.01
#       Definition: a document granting an inventor sole rights to an invention
#     → resolution.n.01
#       Definition: a formal expression by a meeting; agreed to by a vote
#     → source.n.02
#       Definition: a document (or organization) from which information is obtained
#     → ballot.n.01
#       Definition: a document listing the alternatives that is used in voting
#     → enclosure.n.04
#       Definition: something (usually a supporting document) that is enclosed in an envelope with a covering letter
#     → report.n.01
#       Definition: a written document describing the findings of some individual or group
#     → capitulation.n.01
#       Definition: a document containing the terms of surrender
#     → platform.n.02
#       Definition: a document stating the aims and principles of a political party
#     → specification.n.03
#       Definition: (patent law) a document drawn up by the applicant for a patent of invention that provides an explicit and detailed description of the nature and use of an invention
#     → papyrus.n.03
#       Definition: a document written on papyrus
#     → legal_document.n.01
#       Definition: (law) a document that states some contractual relationship or grants some right
#
#   HIERARCHY PATH (up to root):
#     └─ document.n.01
#       └─ writing.n.02
#         └─ written_communication.n.01
#           └─ communication.n.02
#             └─ abstraction.n.06
#               └─ entity.n.01
#
# WORD: 'senior'
#   Definition: an undergraduate student during the year preceding graduation
#   Example: No example
#
#   HYPERNYMS (more general): 1 found
#     → undergraduate.n.01
#       Definition: a university student who has not yet received a first degree
#         ↑ collegian.n.01: a student (or former student) at a college or university
#
#   HYPONYMS: None found
#
#   HIERARCHY PATH (up to root):
#     └─ senior.n.01
#       └─ undergraduate.n.01
#         └─ collegian.n.01
#           └─ student.n.01
#             └─ enrollee.n.01
#               └─ person.n.01
#                 └─ organism.n.01
#                   └─ living_thing.n.01
#                     └─ whole.n.02
#                       └─ object.n.01
#                         └─ physical_entity.n.01
#                           └─ entity.n.01
#                 └─ causal_agent.n.01
#                   └─ physical_entity.n.01
#                     └─ entity.n.01
#
# WORD: 'january'
#   Definition: the first month of the year; begins 10 days after the winter solstice
#   Example: No example
#
#   HYPERNYMS (more general): 1 found
#     → gregorian_calendar_month.n.01
#       Definition: a month in the Gregorian calendar
#         ↑ calendar_month.n.01: one of the twelve divisions of the calendar year
#
#   HYPONYMS: None found
#
#   HIERARCHY PATH (up to root):
#     └─ january.n.01
#       └─ gregorian_calendar_month.n.01
#         └─ calendar_month.n.01
#           └─ time_period.n.01
#             └─ fundamental_quantity.n.01
#               └─ measure.n.02
#                 └─ abstraction.n.06
#                   └─ entity.n.01
#
# WORD: 'details'
#   Definition: true confidential information
#   Example: ['after the trial he gave us the real details']
#
#   HYPERNYMS (more general): 1 found
#     → information.n.01
#       Definition: a message received and understood
#         ↑ message.n.02: what a communication that is about something is about
#
#   HYPONYMS (more specific): 1 found
#     → dope.n.04
#       Definition: slang terms for inside information
#
#   HIERARCHY PATH (up to root):
#     └─ details.n.01
#       └─ information.n.01
#         └─ message.n.02
#           └─ communication.n.02
#             └─ abstraction.n.06
#               └─ entity.n.01
#
# WORD: 'offer'
#   Definition: the verbal act of offering
#   Example: ['a generous offer of assistance']
#
#   HYPERNYMS (more general): 1 found
#     → speech_act.n.01
#       Definition: the use of language to perform some act
#         ↑ act.n.02: something that people do or cause to happen
#
#   HYPONYMS: None found
#
#   HIERARCHY PATH (up to root):
#     └─ offer.n.01
#       └─ speech_act.n.01
#         └─ act.n.02
#           └─ event.n.01
#             └─ psychological_feature.n.01
#               └─ abstraction.n.06
#                 └─ entity.n.01
#
# WORD: 'san'
#   No synsets found for 'san'
#
# WORD: 'please'
#   Definition: give pleasure to or be pleasing to
#   Example: ['These colors please the senses', 'a pleasing sensation']
#
#   HYPERNYMS (more general): 1 found
#     → satisfy.v.02
#       Definition: make happy or satisfied
#
#   HYPONYMS (more specific): 2 found
#     → endear.v.01
#       Definition: make attractive or lovable
#     → enchant.v.01
#       Definition: hold spellbound
#
#   HIERARCHY PATH (up to root):
#     └─ please.v.01
#       └─ satisfy.v.02
#
# WORD: 'base'
#   Definition: installation from which a military force initiates operations
#   Example: ['the attack wiped out our forward bases']
#
#   HYPERNYMS (more general): 1 found
#     → military_installation.n.01
#       Definition: any facility servicing military forces
#         ↑ facility.n.01: a building or place that provides a particular service or is used for a particular industry
#
#   HYPONYMS (more specific): 5 found
#     → army_base.n.01
#       Definition: a large base of operations for an army
#     → firebase.n.01
#       Definition: an artillery base to support advancing troops
#     → rocket_base.n.01
#       Definition: a military base for rocket missiles
#     → navy_base.n.01
#       Definition: base of operations for a naval fleet
#     → air_base.n.01
#       Definition: a base for military aircraft
#
#   HIERARCHY PATH (up to root):
#     └─ base.n.01
#       └─ military_installation.n.01
#         └─ facility.n.01
#           └─ artifact.n.01
#             └─ whole.n.02
#               └─ object.n.01
#                 └─ physical_entity.n.01
#                   └─ entity.n.01
#
# WORD: 'contact'
#   Definition: close interaction
#   Example: ['they kept in daily contact', 'they claimed that they had been in contact with extraterrestrial beings']
#
#   HYPERNYMS (more general): 1 found
#     → interaction.n.01
#       Definition: a mutual or reciprocal action; interacting
#         ↑ action.n.01: something done (usually as opposed to something said)
#
#   HYPONYMS (more specific): 3 found
#     → eye_contact.n.02
#       Definition: contact that occurs when two people look directly at each other
#     → brush.n.09
#       Definition: contact with something dangerous or undesirable
#     → placement.n.02
#       Definition: contact established between applicants and prospective employees
#
#   HIERARCHY PATH (up to root):
#     └─ contact.n.01
#       └─ interaction.n.01
#         └─ action.n.01
#           └─ act.n.02
#             └─ event.n.01
#               └─ psychological_feature.n.01
#                 └─ abstraction.n.06
#                   └─ entity.n.01
#
# WORD: 'forward'
#   Definition: the person who plays the position of forward in certain games, such as basketball, soccer, or hockey
#   Example: No example
#
#   HYPERNYMS (more general): 1 found
#     → basketball_player.n.01
#       Definition: an athlete who plays basketball
#         ↑ athlete.n.01: a person trained to compete in sports
#
#   HYPONYMS: None found
#
#   HIERARCHY PATH (up to root):
#     └─ forward.n.01
#       └─ basketball_player.n.01
#         └─ athlete.n.01
#           └─ contestant.n.01
#             └─ person.n.01
#               └─ organism.n.01
#                 └─ living_thing.n.01
#                   └─ whole.n.02
#                     └─ object.n.01
#                       └─ physical_entity.n.01
#                         └─ entity.n.01
#               └─ causal_agent.n.01
#                 └─ physical_entity.n.01
#                   └─ entity.n.01
#
# WORD: 'francisco'
#   No synsets found for 'francisco'
#
# WORD: 'hr'
#   Definition: a period of time equal to 1/24th of a day
#   Example: ['the job will take more than an hour']
#
#   HYPERNYMS (more general): 1 found
#     → time_unit.n.01
#       Definition: a unit for measuring time periods
#         ↑ measure.n.02: how much there is or how many there are of something that you can quantify
#
#   HYPONYMS (more specific): 2 found
#     → man_hour.n.01
#       Definition: a time unit used in industry for measuring work
#     → sidereal_hour.n.01
#       Definition: 1/24 of a sidereal day
#
#   HIERARCHY PATH (up to root):
#     └─ hour.n.01
#       └─ time_unit.n.01
#         └─ measure.n.02
#           └─ abstraction.n.06
#             └─ entity.n.01
#
# WORD: 'year'
#   Definition: a period of time containing 365 (or 366) days
#   Example: ['she is 4 years old', 'in the year 1920']
#
#   HYPERNYMS (more general): 1 found
#     → time_period.n.01
#       Definition: an amount of time
#         ↑ fundamental_quantity.n.01: one of the four quantities that are the basis of systems of measurement
#
#   HYPONYMS (more specific): 12 found
#     → church_year.n.01
#       Definition: the year in the ecclesiastical calendar; especially feast days and special seasons
#     → common_year.n.01
#       Definition: a year that is not a leap year
#     → off_year.n.02
#       Definition: a year in which no major political elections are held
#     → holy_year.n.01
#       Definition: (Roman Catholic Church) a period of remission from sin (usually granted every 25 years)
#     → annum.n.01
#       Definition: (Latin) year
#     → leap_year.n.01
#       Definition: in the Gregorian calendar: any year divisible by 4 except centenary years divisible by 400
#     → y2k.n.01
#       Definition: the year 2000 in the Gregorian calendar
#     → off_year.n.01
#       Definition: a year in which productivity is low or inferior
#     → year_of_grace.n.01
#       Definition: any year of the Christian era
#     → fiscal_year.n.01
#       Definition: any accounting period of 12 months
#     → calendar_year.n.01
#       Definition: the year (reckoned from January 1 to December 31) according to Gregorian calendar
#     → new_year.n.01
#       Definition: the calendar year just begun
#
#   HIERARCHY PATH (up to root):
#     └─ year.n.01
#       └─ time_period.n.01
#         └─ fundamental_quantity.n.01
#           └─ measure.n.02
#             └─ abstraction.n.06
#               └─ entity.n.01
#
# WORD: 'scientist'
#   Definition: a person with advanced knowledge of one or more sciences
#   Example: No example
#
#   HYPERNYMS (more general): 1 found
#     → person.n.01
#       Definition: a human being
#         ↑ organism.n.01: a living thing that has (or can develop) the ability to act or function independently
#         ↑ causal_agent.n.01: any entity that produces an effect or is responsible for events or results
#
#   HYPONYMS (more specific): 20 found
#     → microscopist.n.01
#       Definition: a scientist who specializes in research with the use of microscopes
#     → bibliotist.n.01
#       Definition: someone who engages in bibliotics
#     → computer_scientist.n.01
#       Definition: a scientist who specializes in the theory of computation and the design of computers
#     → biologist.n.01
#       Definition: (biology) a scientist who studies living organisms
#     → cognitive_scientist.n.01
#       Definition: a scientist who studies cognitive processes
#     → physicist.n.01
#       Definition: a scientist trained in physics
#     → cosmographer.n.01
#       Definition: a scientist knowledgeable about cosmography
#     → paleontologist.n.01
#       Definition: a specialist in paleontology
#     → psychologist.n.01
#       Definition: a scientist trained in psychology
#     → geologist.n.01
#       Definition: a specialist in geology
#     → chemist.n.01
#       Definition: a scientist who specializes in chemistry
#     → oceanographer.n.01
#       Definition: a scientist who studies physical and biological aspects of the seas
#     → principal_investigator.n.01
#       Definition: the scientist in charge of an experiment or research project
#     → mathematician.n.01
#       Definition: a person skilled in mathematics
#     → linguist.n.01
#       Definition: a specialist in linguistics
#     → social_scientist.n.01
#       Definition: someone expert in the study of human society and its personal relationships
#     → mineralogist.n.01
#       Definition: a scientist trained in mineralogy
#     → research_worker.n.01
#       Definition: a scientist who devotes himself to doing research
#     → radiologic_technologist.n.01
#       Definition: a scientist trained in radiological technology
#     → medical_scientist.n.01
#       Definition: a scientist who studies disease processes
#
#   HIERARCHY PATH (up to root):
#     └─ scientist.n.01
#       └─ person.n.01
#         └─ organism.n.01
#           └─ living_thing.n.01
#             └─ whole.n.02
#               └─ object.n.01
#                 └─ physical_entity.n.01
#                   └─ entity.n.01
#         └─ causal_agent.n.01
#           └─ physical_entity.n.01
#             └─ entity.n.01
#
# WORD: 'lead'
#   Definition: an advantage held by a competitor in a race
#   Example: ['he took the lead at the last turn']
#
#   HYPERNYMS (more general): 1 found
#     → advantage.n.01
#       Definition: the quality of having a superior or more favorable position
#         ↑ asset.n.01: a useful or valuable quality
#
#   HYPONYMS: None found
#
#   HIERARCHY PATH (up to root):
#     └─ lead.n.01
#       └─ advantage.n.01
#         └─ asset.n.01
#           └─ quality.n.01
#             └─ attribute.n.02
#               └─ abstraction.n.06
#                 └─ entity.n.01
#
# WORD: 'options'
#   Definition: the right to buy or sell property at an agreed price; the right is purchased and if it is not exercised by a stated date the money is forfeited
#   Example: No example
#
#   HYPERNYMS (more general): 1 found
#     → derivative_instrument.n.01
#       Definition: a financial instrument whose value is based on another security
#         ↑ legal_document.n.01: (law) a document that states some contractual relationship or grants some right
#
#   HYPONYMS (more specific): 8 found
#     → lock-up_option.n.01
#       Definition: an option to buy the crown jewels offered to a white knight in order to forestall a hostile takeover
#     → covered_option.n.01
#       Definition: a put or call option backed by the shares underlying the option
#     → naked_option.n.01
#       Definition: a put or call option for which the seller or buyer has no underlying security position
#     → stock_option.n.01
#       Definition: the right to buy or sell a stock at a specified price within a stated period
#     → straddle.n.04
#       Definition: the option to buy or sell a given stock (or stock index or commodity future) at a given price before a given date; consists of an equal number of put and call options
#     → call_option.n.02
#       Definition: the option to buy a given stock (or stock index or commodity future) at a given price before a given date
#     → put_option.n.02
#       Definition: the option to sell a given stock (or stock index or commodity future) at a given price before a given date
#     → incentive_option.n.01
#       Definition: an option granted to corporate executives if the company achieves certain financial goals
#
#   HIERARCHY PATH (up to root):
#     └─ option.n.01
#       └─ derivative_instrument.n.01
#         └─ legal_document.n.01
#           └─ document.n.01
#             └─ writing.n.02
#               └─ written_communication.n.01
#                 └─ communication.n.02
#                   └─ abstraction.n.06
#                     └─ entity.n.01
#
# WORD: 'review'
#   Definition: a new appraisal or evaluation
#   Example: No example
#
#   HYPERNYMS (more general): 1 found
#     → appraisal.n.01
#       Definition: the classification of someone or something with respect to its worth
#         ↑ classification.n.03: the basic cognitive process of arranging into classes or categories
#
#   HYPONYMS (more specific): 1 found
#     → stocktaking.n.01
#       Definition: reappraisal of a situation or position or outlook
#
#   HIERARCHY PATH (up to root):
#     └─ reappraisal.n.01
#       └─ appraisal.n.01
#         └─ classification.n.03
#           └─ basic_cognitive_process.n.01
#             └─ process.n.02
#               └─ cognition.n.01
#                 └─ psychological_feature.n.01
#                   └─ abstraction.n.06
#                     └─ entity.n.01
#
# WORD: 'sign'
#   Definition: a perceptible indication of something not immediately apparent (as a visible clue that something has happened)
#   Example: ['he showed signs of strain', 'they welcomed the signs of spring']
#
#   HYPERNYMS (more general): 1 found
#     → clue.n.02
#       Definition: evidence that helps to solve a problem
#         ↑ evidence.n.02: an indication that makes something evident
#
#   HYPONYMS (more specific): 1 found
#     → token.n.02
#       Definition: something serving as a sign of something else
#
#   HIERARCHY PATH (up to root):
#     └─ sign.n.01
#       └─ clue.n.02
#         └─ evidence.n.02
#           └─ indication.n.01
#             └─ communication.n.02
#               └─ abstraction.n.06
#                 └─ entity.n.01
#
# WORD: 'httpsdatamindcorponboardingmt'
#   No synsets found for 'httpsdatamindcorponboardingmt'
#
# WORD: 'acquisition'
#   Definition: the act of contracting or assuming or acquiring possession of something
#   Example: ['the acquisition of wealth', 'the acquisition of one company by another']
#
#   HYPERNYMS (more general): 1 found
#     → acquiring.n.01
#       Definition: the act of acquiring something
#         ↑ act.n.02: something that people do or cause to happen
#
#   HYPONYMS (more specific): 12 found
#     → succession.n.05
#       Definition: acquisition of property by descent or by will
#     → purchase.n.01
#       Definition: the acquisition of something for payment
#     → annexation.n.02
#       Definition: the formal act of acquiring something (especially territory) by conquest or occupation
#     → acceptance.n.07
#       Definition: the act of taking something that is offered
#     → incurring.n.01
#       Definition: acquiring or coming into something (usually undesirable)
#     → inheritance.n.01
#       Definition: hereditary succession to a title or an office or property
#     → pork-barreling.n.01
#       Definition: acquisition of government money for benefits to a specific locale
#     → procurement.n.01
#       Definition: the act of getting possession of something
#     → moneymaking.n.01
#       Definition: the act of making money (and accumulating wealth)
#     → buyout.n.01
#       Definition: acquisition of a company by purchasing a controlling percentage of its stock
#     → restitution.n.03
#       Definition: getting something back again
#     → assumption.n.03
#       Definition: the act of taking possession of or power over something
#
#   HIERARCHY PATH (up to root):
#     └─ acquisition.n.01
#       └─ acquiring.n.01
#         └─ act.n.02
#           └─ event.n.01
#             └─ psychological_feature.n.01
#               └─ abstraction.n.06
#                 └─ entity.n.01
#
# WORD: 'stock'
#   Definition: the capital raised by a corporation through the issue of shares entitling holders to an ownership interest (equity)
#   Example: ["he owns a controlling share of the company's stock"]
#
#   HYPERNYMS (more general): 1 found
#     → capital.n.01
#       Definition: assets available for use in the production of further assets
#         ↑ assets.n.01: anything of material value or usefulness that is owned by a person or company
#
#   HYPONYMS (more specific): 13 found
#     → watered_stock.n.01
#       Definition: stock representing ownership of overvalued assets; stock of a corporation whose total worth is less than its invested capital
#     → float.n.02
#       Definition: the number of shares outstanding and available for trading by the public
#     → authorized_shares.n.01
#       Definition: the maximum number of shares authorized under the terms of a corporation's articles of incorporation
#     → common_stock.n.01
#       Definition: stock other than preferred stock; entitles the owner to a share of the corporation's profits and a share of the voting power in shareholder elections
#     → growth_stock.n.01
#       Definition: stock of a corporation that has had faster than average gains in earnings and is expected to continue to
#     → quarter_stock.n.01
#       Definition: stock with a par value of $25/share
#     → voting_stock.n.01
#       Definition: shares in a corporation that entitle the shareholder to voting and proxy rights
#     → control_stock.n.01
#       Definition: shares owned by shareholders who have a controlling interest
#     → no-par-value_stock.n.01
#       Definition: stock with no par value specified in the corporate charter or on the stock certificate
#     → hot_stock.n.01
#       Definition: newly issued stock that is in great public demand
#     → common_stock_equivalent.n.01
#       Definition: preferred stock or convertible bonds or warrants that can be converted into common stock
#     → preferred_stock.n.01
#       Definition: stock whose holders are guaranteed priority in the payment of dividends but whose holders have no voting rights
#     → treasury_stock.n.01
#       Definition: stock that has been bought back by the issuing corporation and is available for retirement or resale; it is issued but not outstanding; it cannot vote and pays no dividends
#
#   HIERARCHY PATH (up to root):
#     └─ stock.n.01
#       └─ capital.n.01
#         └─ assets.n.01
#           └─ possession.n.02
#             └─ relation.n.01
#               └─ abstraction.n.06
#                 └─ entity.n.01
#
# WORD: 'mr'
#   Definition: a form of address for a man
#   Example: No example
#
#   HYPERNYMS (more general): 1 found
#     → title.n.06
#       Definition: an identifying appellation signifying status or function: e.g. `Mr.' or `General'
#         ↑ appellation.n.01: identifying word or words by which someone or something is called and classified or distinguished from others
#
#   HYPONYMS: None found
#
#   HIERARCHY PATH (up to root):
#     └─ mister.n.01
#       └─ title.n.06
#         └─ appellation.n.01
#           └─ name.n.01
#             └─ language_unit.n.01
#               └─ part.n.01
#                 └─ relation.n.01
#                   └─ abstraction.n.06
#                     └─ entity.n.01
#
# WORD: 'datamind'
#   No synsets found for 'datamind'
#
# WORD: 'december'
#   Definition: the last (12th) month of the year
#   Example: No example
#
#   HYPERNYMS (more general): 1 found
#     → gregorian_calendar_month.n.01
#       Definition: a month in the Gregorian calendar
#         ↑ calendar_month.n.01: one of the twelve divisions of the calendar year
#
#   HYPONYMS: None found
#
#   HIERARCHY PATH (up to root):
#     └─ december.n.01
#       └─ gregorian_calendar_month.n.01
#         └─ calendar_month.n.01
#           └─ time_period.n.01
#             └─ fundamental_quantity.n.01
#               └─ measure.n.02
#                 └─ abstraction.n.06
#                   └─ entity.n.01
#
# WORD: 'call'
#   Definition: a telephone connection
#   Example: ['she reported several anonymous calls', 'he placed a phone call to London', "he heard the phone ringing but didn't want to take the call"]
#
#   HYPERNYMS (more general): 1 found
#     → telephone.n.02
#       Definition: transmitting speech at a distance
#         ↑ telecommunication.n.01: (often plural) systems used in transmitting messages over a distance electronically
#
#   HYPONYMS (more specific): 8 found
#     → long_distance.n.01
#       Definition: a telephone call made outside the local calling area
#     → local_call.n.01
#       Definition: a telephone call made within a local calling area
#     → call-in.n.01
#       Definition: a telephone call to a radio station or a television station in which the caller participates in the on-going program
#     → conference_call.n.01
#       Definition: a telephone call in which more than two people participate
#     → collect_call.n.01
#       Definition: a telephone call that the receiving party is asked to pay for
#     → call-back.n.01
#       Definition: a return call
#     → wake-up_call.n.02
#       Definition: a telephone call that you request be made a specific time in order to wake you up at that time (especially in hotels)
#     → crank_call.n.01
#       Definition: a hostile telephone call (from a crank)
#
#   HIERARCHY PATH (up to root):
#     └─ call.n.01
#       └─ telephone.n.02
#         └─ telecommunication.n.01
#           └─ medium.n.01
#             └─ instrumentality.n.03
#               └─ artifact.n.01
#                 └─ whole.n.02
#                   └─ object.n.01
#                     └─ physical_entity.n.01
#                       └─ entity.n.01
#
# WORD: 'job'
#   Definition: the principal activity in your life that you do to earn money
#   Example: ["he's not in my line of business"]
#
#   HYPERNYMS (more general): 1 found
#     → activity.n.01
#       Definition: any specific behavior
#         ↑ act.n.02: something that people do or cause to happen
#
#   HYPONYMS (more specific): 15 found
#     → metier.n.02
#       Definition: an occupation for which you are especially well suited
#     → appointment.n.05
#       Definition: the job to which you are (or hope to be) appointed
#     → position.n.06
#       Definition: a job in an organization
#     → trade.n.02
#       Definition: the skilled practice of a practical occupation
#     → game.n.10
#       Definition: your occupation or line of work
#     → career.n.01
#       Definition: the particular occupation for which you are trained
#     → treadmill.n.03
#       Definition: a job involving drudgery and confinement
#     → farming.n.02
#       Definition: agriculture considered as an occupation or way of life
#     → catering.n.01
#       Definition: providing food and services
#     → profession.n.02
#       Definition: an occupation requiring special education (especially in the liberal arts or sciences)
#     → employment.n.02
#       Definition: the occupation for which you are paid
#     → photography.n.03
#       Definition: the occupation of taking and printing photographs or making movies
#     → accountancy.n.01
#       Definition: the occupation of maintaining and auditing records and preparing financial reports for a business
#     → confectionery.n.03
#       Definition: the occupation and skills of a confectioner
#     → sport.n.02
#       Definition: the occupation of athletes who compete for pay
#
#   HIERARCHY PATH (up to root):
#     └─ occupation.n.01
#       └─ activity.n.01
#         └─ act.n.02
#           └─ event.n.01
#             └─ psychological_feature.n.01
#               └─ abstraction.n.06
#                 └─ entity.n.01
#
# WORD: 'ca'
#   Definition: a white metallic element that burns with a brilliant light; the fifth most abundant element in the earth's crust; an important component of most plants and animals
#   Example: No example
#
#   HYPERNYMS (more general): 1 found
#     → metallic_element.n.01
#       Definition: any of several chemical elements that are usually shiny solids that conduct heat or electricity and can be formed into sheets etc.
#         ↑ chemical_element.n.01: any of the more than 100 known substances (of which 92 occur naturally) that cannot be separated into simpler substances and that singly or in combination constitute all matter
#
#   HYPONYMS (more specific): 1 found
#     → calcium_ion.n.01
#       Definition: ion of calcium; a factor in the clotting of blood
#
#   HIERARCHY PATH (up to root):
#     └─ calcium.n.01
#       └─ metallic_element.n.01
#         └─ chemical_element.n.01
#           └─ substance.n.01
#             └─ matter.n.03
#               └─ physical_entity.n.01
#                 └─ entity.n.01
#             └─ part.n.01
#               └─ relation.n.01
#                 └─ abstraction.n.06
#                   └─ entity.n.01
#
# WORD: 'remote'
#   Definition: a device that can be used to control a machine or apparatus from a distance
#   Example: ['he lost the remote for his TV']
#
#   HYPERNYMS (more general): 1 found
#     → device.n.01
#       Definition: an instrumentality invented for a particular purpose
#         ↑ instrumentality.n.03: an artifact (or system of artifacts) that is instrumental in accomplishing some end
#
#   HYPONYMS: None found
#
#   HIERARCHY PATH (up to root):
#     └─ remote_control.n.01
#       └─ device.n.01
#         └─ instrumentality.n.03
#           └─ artifact.n.01
#             └─ whole.n.02
#               └─ object.n.01
#                 └─ physical_entity.n.01
#                   └─ entity.n.01
#
# WORD: 'questions'
#   Definition: an instance of questioning
#   Example: ['there was a question about my training', 'we made inquiries of all those who were present']
#
#   HYPERNYMS (more general): 1 found
#     → questioning.n.01
#       Definition: a request for information
#         ↑ request.n.02: the verbal act of requesting
#
#   HYPONYMS: None found
#
#   HIERARCHY PATH (up to root):
#     └─ question.n.01
#       └─ questioning.n.01
#         └─ request.n.02
#           └─ speech_act.n.01
#             └─ act.n.02
#               └─ event.n.01
#                 └─ psychological_feature.n.01
#                   └─ abstraction.n.06
#                     └─ entity.n.01
#
# WORD: 'equity'
#   Definition: the difference between the market value of a property and the claims held against it
#   Example: No example
#
#   HYPERNYMS (more general): 1 found
#     → assets.n.01
#       Definition: anything of material value or usefulness that is owned by a person or company
#         ↑ possession.n.02: anything owned or possessed
#
#   HYPONYMS: None found
#
#   HIERARCHY PATH (up to root):
#     └─ equity.n.01
#       └─ assets.n.01
#         └─ possession.n.02
#           └─ relation.n.01
#             └─ abstraction.n.06
#               └─ entity.n.01
#
# WORD: 'location'
#   Definition: a point or extent in space
#   Example: No example
#
#   HYPERNYMS (more general): 1 found
#     → object.n.01
#       Definition: a tangible and visible entity; an entity that can cast a shadow
#         ↑ physical_entity.n.01: an entity that has physical existence
#
#   HYPONYMS (more specific): 26 found
#     → earth.n.04
#       Definition: the abode of mortals (as contrasted with Heaven or Hell)
#     → west.n.08
#       Definition: a location in the western part of a country, region, or city
#     → seat.n.06
#       Definition: the location (metaphorically speaking) where something is based
#     → base.n.14
#       Definition: the place where you are stationed and from which missions start and end
#     → there.n.01
#       Definition: a location other than here; that place
#     → north.n.04
#       Definition: a location in the northern part of a country, region, or city
#     → outer_space.n.01
#       Definition: any location outside the Earth's atmosphere
#     → region.n.03
#       Definition: a large indefinite location on the surface of the Earth
#     → southeast.n.04
#       Definition: a location in the southeastern part of a country, region, or city
#     → northeast.n.04
#       Definition: a location in the northeastern part of a country, region, or city
#     → region.n.01
#       Definition: the extended spatial location of something
#     → whereabouts.n.01
#       Definition: the general location where something is
#     → sodom.n.01
#       Definition: any location known for vice and corruption
#     → south.n.04
#       Definition: a location in the southern part of a country, region, or city
#     → northwest.n.04
#       Definition: a location in the northwestern part of a country, region, or city
#     → home.n.03
#       Definition: the country or state or city where you live
#     → east.n.05
#       Definition: a location in the eastern part of a country, region, or city
#     → southwest.n.04
#       Definition: a location in the southwestern part of a country, region, or city
#     → jungle.n.01
#       Definition: a location marked by an intense competition and struggle for survival
#     → here.n.01
#       Definition: the present location; this place
#     → point.n.02
#       Definition: the precise location of something; a spatially limited location
#     → somewhere.n.01
#       Definition: an indefinite or unknown location
#     → bilocation.n.01
#       Definition: the ability (said of certain Roman Catholic saints) to exist simultaneously in two locations
#     → pass.n.04
#       Definition: the location in a range of mountains of a geological formation that is lower than the surrounding peaks
#     → space.n.02
#       Definition: an empty area (usually bounded in some way between things)
#     → line.n.11
#       Definition: a spatial location defined by a real or imaginary unidimensional extent
#
#   HIERARCHY PATH (up to root):
#     └─ location.n.01
#       └─ object.n.01
#         └─ physical_entity.n.01
#           └─ entity.n.01
#
# WORD: 'regards'
#   Definition: (usually preceded by `in') a detail or point
#   Example: ['it differs in that respect']
#
#   HYPERNYMS (more general): 1 found
#     → detail.n.01
#       Definition: an isolated fact that is considered separately from the whole
#         ↑ fact.n.01: a piece of information about circumstances that exist or events that have occurred
#
#   HYPONYMS: None found
#
#   HIERARCHY PATH (up to root):
#     └─ respect.n.01
#       └─ detail.n.01
#         └─ fact.n.01
#           └─ information.n.02
#             └─ cognition.n.01
#               └─ psychological_feature.n.01
#                 └─ abstraction.n.06
#                   └─ entity.n.01
#
# WORD: 'wong'
#   No synsets found for 'wong'
#
# WORD: 'date'
#   Definition: the specified day of the month
#   Example: ['what is the date today?']
#
#   HYPERNYMS (more general): 1 found
#     → day.n.01
#       Definition: time for Earth to make a complete rotation on its axis
#         ↑ time_unit.n.01: a unit for measuring time periods
#
#   HYPONYMS (more specific): 2 found
#     → birthday.n.02
#       Definition: the date on which a person was born
#     → maturity.n.03
#       Definition: the date on which an obligation must be repaid
#
#   HIERARCHY PATH (up to root):
#     └─ date.n.01
#       └─ day.n.01
#         └─ time_unit.n.01
#           └─ measure.n.02
#             └─ abstraction.n.06
#               └─ entity.n.01
#
# WORD: 'pleased'
#   Definition: give pleasure to or be pleasing to
#   Example: ['These colors please the senses', 'a pleasing sensation']
#
#   HYPERNYMS (more general): 1 found
#     → satisfy.v.02
#       Definition: make happy or satisfied
#
#   HYPONYMS (more specific): 2 found
#     → endear.v.01
#       Definition: make attractive or lovable
#     → enchant.v.01
#       Definition: hold spellbound
#
#   HIERARCHY PATH (up to root):
#     └─ please.v.01
#       └─ satisfy.v.02
#
# WORD: 'pdf'
#   No synsets found for 'pdf'
#
# WORD: 'annual'
#   Definition: (botany) a plant that completes its entire life cycle within the space of a year
#   Example: No example
#
#   HYPERNYMS (more general): 1 found
#     → plant.n.02
#       Definition: (botany) a living organism lacking the power of locomotion
#         ↑ organism.n.01: a living thing that has (or can develop) the ability to act or function independently
#
#   HYPONYMS: None found
#
#   HIERARCHY PATH (up to root):
#     └─ annual.n.01
#       └─ plant.n.02
#         └─ organism.n.01
#           └─ living_thing.n.01
#             └─ whole.n.02
#               └─ object.n.01
#                 └─ physical_entity.n.01
#                   └─ entity.n.01
#
# WORD: 'look'
#   Definition: the feelings expressed on a person's face
#   Example: ['a sad expression', 'a look of triumph', 'an angry face']
#
#   HYPERNYMS (more general): 1 found
#     → countenance.n.01
#       Definition: the appearance conveyed by a person's face
#         ↑ appearance.n.01: outward or visible aspect of a person or thing
#
#   HYPONYMS (more specific): 2 found
#     → sparkle.n.01
#       Definition: merriment expressed by a brightness or gleam or animation of countenance
#     → leer.n.02
#       Definition: a suggestive or sneering look or grin
#
#   HIERARCHY PATH (up to root):
#     └─ expression.n.01
#       └─ countenance.n.01
#         └─ appearance.n.01
#           └─ quality.n.01
#             └─ attribute.n.02
#               └─ abstraction.n.06
#                 └─ entity.n.01
#
# WORD: 'subject'
#   Definition: the subject matter of a conversation or discussion
#   Example: ["he didn't want to discuss that subject", 'it was a very sensitive topic', 'his letters were always on the theme of love']
#
#   HYPERNYMS (more general): 1 found
#     → message.n.02
#       Definition: what a communication that is about something is about
#         ↑ communication.n.02: something that is communicated by or to or between people or groups
#
#   HYPONYMS (more specific): 4 found
#     → question.n.02
#       Definition: the subject matter at issue
#     → keynote.n.01
#       Definition: the principal theme in a speech or literary work
#     → bone_of_contention.n.01
#       Definition: the subject of a dispute
#     → precedent.n.04
#       Definition: a subject mentioned earlier (preceding in time)
#
#   HIERARCHY PATH (up to root):
#     └─ subject.n.01
#       └─ message.n.02
#         └─ communication.n.02
#           └─ abstraction.n.06
#             └─ entity.n.01
#
# WORD: 'start'
#   Definition: the beginning of anything
#   Example: ['it was off to a good start']
#
#   HYPERNYMS (more general): 1 found
#     → beginning.n.01
#       Definition: the event consisting of the start of something
#         ↑ happening.n.01: an event that happens
#
#   HYPONYMS (more specific): 11 found
#     → kickoff.n.03
#       Definition: a start given to contestants
#     → menarche.n.01
#       Definition: the first occurrence of menstruation in a woman
#     → onset.n.01
#       Definition: the beginning or early stages
#     → alpha.n.02
#       Definition: the beginning of a series or sequence; --Revelations
#     → opener.n.01
#       Definition: the first event in a series
#     → adrenarche.n.01
#       Definition: the increase in activity of the adrenal glands just before puberty
#     → thelarche.n.01
#       Definition: the start of breast development in a woman at the beginning of puberty
#     → dawn.n.02
#       Definition: the earliest period
#     → racing_start.n.01
#       Definition: the start of a race
#     → flying_start.n.02
#       Definition: a quick and auspicious beginning
#     → opening.n.04
#       Definition: the first performance (as of a theatrical production)
#
#   HIERARCHY PATH (up to root):
#     └─ start.n.01
#       └─ beginning.n.01
#         └─ happening.n.01
#           └─ event.n.01
#             └─ psychological_feature.n.01
#               └─ abstraction.n.06
#                 └─ entity.n.01
#
# WORD: 'lisa'
#   No synsets found for 'lisa'
#
# WORD: 'position'
#   Definition: the particular portion of space occupied by something
#   Example: ['he put the lamp back in its place']
#
#   HYPERNYMS (more general): 1 found
#     → point.n.02
#       Definition: the precise location of something; a spatially limited location
#         ↑ location.n.01: a point or extent in space
#
#   HYPONYMS (more specific): 21 found
#     → front.n.09
#       Definition: the part of something that is nearest to the normal viewer
#     → vantage.n.01
#       Definition: place or situation affording some advantage (especially a comprehensive view or commanding perspective)
#     → right.n.02
#       Definition: location near or direction toward the right side; i.e. the side to the south when a person or object faces east
#     → wing.n.07
#       Definition: (in flight formation) a position to the side and just to the rear of another aircraft
#     → anomaly.n.03
#       Definition: (astronomy) position of a planet as defined by its angular distance from its perihelion (as observed from the sun)
#     → polls.n.01
#       Definition: the place where people vote
#     → pole_position.n.01
#       Definition: the most favorable position at the start of a race
#     → pride_of_place.n.01
#       Definition: the first or highest or most important or most ostentatious place
#     → lead.n.09
#       Definition: (baseball) the position taken by a base runner preparing to advance to the next base
#     → half-mast.n.01
#       Definition: a position some distance below the top of a mast to which a flag is lowered in mourning or to signal distress
#     → lie.n.03
#       Definition: position or manner in which something is situated
#     → left.n.01
#       Definition: location near or direction toward the left side; i.e. the side to the north when a person or object faces east
#     → station.n.03
#       Definition: (nautical) the location to which a ship or fleet is assigned for duty
#     → post.n.01
#       Definition: the position where someone (as a guard or sentry) stands or is assigned to stand
#     → juxtaposition.n.02
#       Definition: a side-by-side position
#     → setting.n.05
#       Definition: the physical position of something
#     → back.n.03
#       Definition: the part of something that is furthest from the normal viewer
#     → landmark.n.01
#       Definition: the position of a prominent or well-known object in a particular landscape
#     → pitch.n.03
#       Definition: a vendor's position (especially on the sidewalk)
#     → stand.n.02
#       Definition: the position where a thing or person stands
#     → site.n.02
#       Definition: physical position in relation to the surroundings
#
#   HIERARCHY PATH (up to root):
#     └─ position.n.01
#       └─ point.n.02
#         └─ location.n.01
#           └─ object.n.01
#             └─ physical_entity.n.01
#               └─ entity.n.01
#
# WORD: 'thompson'
#   Definition: United States classical archaeologist (born in Canada) noted for leading the excavation of the Athenian agora (1906-2000)
#   Example: No example
#
#   HYPERNYMS: None found
#
#   HYPONYMS: None found
#
#   HIERARCHY PATH (up to root):
#     └─ thompson.n.01
#
# WORD: 'best'
#   Definition: the supreme effort one can make
#   Example: ['they did their best']
#
#   HYPERNYMS (more general): 1 found
#     → attempt.n.01
#       Definition: earnest and conscientious activity intended to do or accomplish something
#         ↑ activity.n.01: any specific behavior
#
#   HYPONYMS: None found
#
#   HIERARCHY PATH (up to root):
#     └─ best.n.01
#       └─ attempt.n.01
#         └─ activity.n.01
#           └─ act.n.02
#             └─ event.n.01
#               └─ psychological_feature.n.01
#                 └─ abstraction.n.06
#                   └─ entity.n.01
#
# WORD: 'dear'
#   Definition: a beloved person; used as terms of endearment
#   Example: No example
#
#   HYPERNYMS (more general): 1 found
#     → lover.n.01
#       Definition: a person who loves someone or is loved by someone
#         ↑ person.n.01: a human being
#
#   HYPONYMS: None found
#
#   HIERARCHY PATH (up to root):
#     └─ beloved.n.01
#       └─ lover.n.01
#         └─ person.n.01
#           └─ organism.n.01
#             └─ living_thing.n.01
#               └─ whole.n.02
#                 └─ object.n.01
#                   └─ physical_entity.n.01
#                     └─ entity.n.01
#           └─ causal_agent.n.01
#             └─ physical_entity.n.01
#               └─ entity.n.01
#
# WORD: 'th'
#   Definition: the fifth day of the week; the fourth working day
#   Example: No example
#
#   HYPERNYMS (more general): 1 found
#     → weekday.n.01
# ...
#     → closed_corporation.n.01
#       Definition: a corporation owned by a few people; shares have no public market
#     → shell_corporation.n.01
#       Definition: a company that is incorporated but has no assets or operations
#     → federal_home_loan_mortgage_corporation.n.01
#       Definition: a corporation authorized by Congress to provide a secondary market for residential mortgages
#     → federal_national_mortgage_association.n.01
#       Definition: a federally chartered corporation that purchases mortgages
#     → federal_deposit_insurance_corporation.n.01
#       Definition: a federally sponsored corporation that insures accounts in national banks and other qualified institutions
#     → large_cap.n.01
#       Definition: a corporation with a large capitalization
#     → small_cap.n.01
#       Definition: a corporation with a small capitalization
#     → boy_scouts_of_america.n.01
#       Definition: a corporation that operates through a national council that charters local councils all over the United States; the purpose is character building and citizenship training
#
#   HIERARCHY PATH (up to root):
#     └─ corporation.n.01
#       └─ firm.n.01
#         └─ business.n.01
#           └─ enterprise.n.02
#             └─ organization.n.01
#               └─ social_group.n.01
#                 └─ group.n.01
#                   └─ abstraction.n.06
#                     └─ entity.n.01
#
# WORD: 'performance'
#   Definition: a dramatic or musical entertainment
#   Example: ['they listened to ten different performances', 'the play ran for 100 performances', 'the frequent performances of the symphony testify to its popularity']
#
#   HYPERNYMS (more general): 1 found
#     → show.n.03
#       Definition: a social event involving a public performance or entertainment
#         ↑ social_event.n.01: an event characteristic of persons forming groups
#
#   HYPONYMS (more specific): 12 found
#     → theatrical_performance.n.01
#       Definition: a performance of a play
#     → pianism.n.01
#       Definition: performance by or technique of a pianist
#     → song_and_dance.n.01
#       Definition: theatrical performance combining singing and dancing
#     → recital.n.02
#       Definition: performance of music or dance especially by soloists
#     → concert.n.01
#       Definition: a performance of music by players or singers not involving theatrical staging
#     → act.n.04
#       Definition: a short theatrical performance that is part of a longer program
#     → benefit.n.03
#       Definition: a performance to raise money for a charitable cause
#     → play_reading.n.01
#       Definition: performance of a play by a group of readers
#     → rendition.n.01
#       Definition: a performance of a musical composition or a dramatic role etc.
#     → spectacular.n.01
#       Definition: a lavishly produced performance
#     → premiere.n.01
#       Definition: the first public performance of a play or movie
#     → world_premiere.n.01
#       Definition: (music) the first public performance (as of a dramatic or musical work) anywhere in the world
#
#   HIERARCHY PATH (up to root):
#     └─ performance.n.01
#       └─ show.n.03
#         └─ social_event.n.01
#           └─ event.n.01
#             └─ psychological_feature.n.01
#               └─ abstraction.n.06
#                 └─ entity.n.01
#
# WORD: 'hrdatamindcom'
#   No synsets found for 'hrdatamindcom'
#
# WORD: 'talent'
#   Definition: natural abilities or qualities
#   Example: No example
#
#   HYPERNYMS (more general): 1 found
#     → natural_ability.n.01
#       Definition: ability that is inherited
#         ↑ aptitude.n.01: inherent ability
#
#   HYPONYMS (more specific): 3 found
#     → bent.n.04
#       Definition: a special way of doing something
#     → raw_talent.n.01
#       Definition: powerfully impressive talent
#     → flair.n.01
#       Definition: a natural talent
#
#   HIERARCHY PATH (up to root):
#     └─ endowment.n.01
#       └─ natural_ability.n.01
#         └─ aptitude.n.01
#           └─ ability.n.02
#             └─ cognition.n.01
#               └─ psychological_feature.n.01
#                 └─ abstraction.n.06
#                   └─ entity.n.01
#
# WORD: 'attached'
#   Definition: cause to be attached
#   Example: No example
#
#   HYPERNYMS (more general): 1 found
#     → connect.v.01
#       Definition: connect, fasten, or put together two or more pieces
#
#   HYPONYMS (more specific): 29 found
#     → fasten.v.01
#       Definition: cause to be firmly attached
#     → clip.v.03
#       Definition: attach with a clip
#     → pin_down.v.03
#       Definition: attach with or as if with a pin
#     → append.v.02
#       Definition: fix to; attach
#     → hook_up.v.01
#       Definition: connect or link
#     → insert.v.01
#       Definition: put or introduce into something
#     → fasten.v.03
#       Definition: attach to
#     → append.v.01
#       Definition: add to the very end
#     → fixate.v.03
#       Definition: make fixed, stable or stationary
#     → peg.v.03
#       Definition: fasten or secure with a wooden pin
#     → harness.v.01
#       Definition: put a harness
#     → affix.v.01
#       Definition: attach to
#     → hinge.v.01
#       Definition: attach with a hinge
#     → nail.v.01
#       Definition: attach something somewhere by means of nails
#     → bind.v.03
#       Definition: make fast; tie or secure, with or as if with a rope
#     → yoke.v.03
#       Definition: put a yoke on or join with a yoke
#     → limber.v.01
#       Definition: attach the limber
#     → bell.v.01
#       Definition: attach a bell to
#     → saddle.v.01
#       Definition: put a saddle on
#     → hitch.v.01
#       Definition: to hook or entangle
#     → tag.v.01
#       Definition: attach a tag or label to
#     → mount.v.01
#       Definition: attach to a support
#     → affix.v.03
#       Definition: attach or become attached to a stem word
#     → yoke.v.02
#       Definition: link with or as with a yoke
#     → tape.v.01
#       Definition: fasten or attach with tape
#     → couple.v.02
#       Definition: link together
#     → tether.v.01
#       Definition: tie with a tether
#     → ring.v.06
#       Definition: attach a ring to the foot of, in order to identify
#     → glue.v.01
#       Definition: join or attach with or as if with glue
#
#   HIERARCHY PATH (up to root):
#     └─ attach.v.01
#       └─ connect.v.01
#
# WORD: 'corporation'
#   Definition: a business firm whose articles of incorporation have been approved in some state
#   Example: No example
#
#   HYPERNYMS (more general): 1 found
#     → firm.n.01
#       Definition: the members of a business organization that owns or operates one or more establishments
#         ↑ business.n.01: a commercial or industrial enterprise and the people who constitute it
#
#   HYPONYMS (more specific): 10 found
#     → closely_held_corporation.n.01
#       Definition: stock is publicly traded but most is held by a few shareholders who have no plans to sell
#     → conglomerate.n.02
#       Definition: a group of diverse companies under common ownership and run as a single organization
#     → closed_corporation.n.01
#       Definition: a corporation owned by a few people; shares have no public market
#     → shell_corporation.n.01
#       Definition: a company that is incorporated but has no assets or operations
#     → federal_home_loan_mortgage_corporation.n.01
#       Definition: a corporation authorized by Congress to provide a secondary market for residential mortgages
#     → federal_national_mortgage_association.n.01
#       Definition: a federally chartered corporation that purchases mortgages
#     → federal_deposit_insurance_corporation.n.01
#       Definition: a federally sponsored corporation that insures accounts in national banks and other qualified institutions
#     → large_cap.n.01
#       Definition: a corporation with a large capitalization
#     → small_cap.n.01
#       Definition: a corporation with a small capitalization
#     → boy_scouts_of_america.n.01
#       Definition: a corporation that operates through a national council that charters local councils all over the United States; the purpose is character building and citizenship training
#
#   HIERARCHY PATH (up to root):
#     └─ corporation.n.01
#       └─ firm.n.01
#         └─ business.n.01
#           └─ enterprise.n.02
#             └─ organization.n.01
#               └─ social_group.n.01
#                 └─ group.n.01
#                   └─ abstraction.n.06
#                     └─ entity.n.01
#
# DETAILED EXAMPLE FOR KEY WORDS FROM TEXT
#
# DEEP ANALYSIS FOR: 'apple'
#   Definition: fruit with red or yellow or green skin and sweet to tart crisp whitish flesh
#   Lemmas: ['apple']
#
#   All Hypernym Paths:
#     Path 1: entity -> physical_entity -> matter -> solid -> food -> produce -> edible_fruit -> apple
#     Path 2: entity -> physical_entity -> object -> whole -> natural_object -> plant_part -> plant_organ -> reproductive_structure -> fruit -> edible_fruit -> apple
#     Path 3: entity -> physical_entity -> object -> whole -> natural_object -> plant_part -> plant_organ -> reproductive_structure -> fruit -> pome -> apple
#
#   Total hyponyms found: 3
#   All hyponyms:
#     - crab_apple.n.03: small sour apple; suitable for preserving
#     - cooking_apple.n.01: an apple used primarily in cooking for pies and applesauce etc
#     - eating_apple.n.01: an apple used primarily for eating raw without cooking
#
# DEEP ANALYSIS FOR: 'computer'
#   Definition: a machine for performing calculations automatically
#   Lemmas: ['computer', 'computing_machine', 'computing_device', 'data_processor', 'electronic_computer', 'information_processing_system']
#
#   All Hypernym Paths:
#     Path 1: entity -> physical_entity -> object -> whole -> artifact -> instrumentality -> device -> machine -> computer
#
#   Total hyponyms found: 10
#   All hyponyms:
#     - turing_machine.n.01: a hypothetical computer with an infinitely long memory tape
#     - pari-mutuel_machine.n.01: computer that registers bets and divides the total amount bet among those who won
#     - node.n.08: (computer science) any computer that is hooked up to a computer network
#     - digital_computer.n.01: a computer that represents information by numerical (binary) digits
#     - web_site.n.01: a computer connected to the internet that maintains a series of web pages on the World Wide Web
#     - server.n.03: (computer science) a computer that provides client stations with access to files and printers as shared resources to a computer network
#     - number_cruncher.n.02: a computer capable of performing a large number of mathematical operations per second
#     - predictor.n.03: a computer for controlling antiaircraft fire that computes the position of an aircraft at the instant of a shell's arrival
#     - analog_computer.n.01: a computer that represents information by variable quantities (e.g., positions or voltages)
#     - home_computer.n.01: a computer intended for use in the home
#
# DEEP ANALYSIS FOR: 'company'
#   Definition: an institution created to conduct business
#   Lemmas: ['company']
#
#   All Hypernym Paths:
#     Path 1: entity -> abstraction -> group -> social_group -> organization -> institution -> company
#
#   Total hyponyms found: 36
#   All hyponyms:
#     - closed_shop.n.01: a company that hires only union members
#     - broadcasting_company.n.01: a company that manages tv or radio stations
#     - furniture_company.n.01: a company that sells furniture
#     - dot-com.n.01: a company that operates its business primarily on the internet using a URL that ends in `.com'
#     - think_tank.n.01: a company that does research for hire and issues reports on the implications
#     - shipping_company.n.01: a company that provides shipping services
#     - steel_company.n.01: a company that makes and sells steel
#     - transportation_company.n.01: a company providing transportation
#     - food_company.n.01: a company that processes and sells food
#     - mover.n.04: a company that moves the possessions of a family or business from one site to another
#     - mining_company.n.01: a company that owns and manages mines
#     - open_shop.n.01: a company whose workers are hired without regard to their membership in a labor union
#     - union_shop.n.01: a company allowed to hire nonunion workers on the condition that they will join the union within a specified time
#     - pipeline_company.n.01: a company that operates oil pipelines for the oil industry
#     - joint-stock_company.n.01: a company (usually unincorporated) which has the capital of its members pooled in a common fund; transferable shares represent ownership interest; shareholders are legally liable for all debts of the company
#     - white_knight.n.01: a company that is a friendly acquirer in a takeover
#     - printing_concern.n.01: a company that does commercial printing
#     - stock_company.n.01: a company whose capital is represented by stock
#     - film_company.n.01: a company that makes, advertises, and distributes movies
#     - distributor.n.03: a company that markets merchandise
#     - drug_company.n.01: a company that makes and sells pharmaceuticals
#     - shipper.n.02: a company in the business of shipping freight
#     - service.n.04: a company or agency that performs a public service; subject to government regulation
#     - limited_company.n.01: a company that is organized to give its owners limited liability
#     - livery_company.n.01: one of the chartered companies of London originating with the craft guilds
#     - record_company.n.01: a company that makes and sells musical recordings
#     - subsidiary_company.n.01: a company that is completely controlled by another company
#     - electronics_company.n.01: a company that makes and sells electronic instruments
#     - corporate_investor.n.01: a company that invests in (acquires control of) other companies
#     - car_company.n.01: a company that makes and sells automobiles
#     - packaging_company.n.01: a company that packages goods for sale or shipment or storage
#     - holding_company.n.01: a company with controlling shares in other companies
#     - target_company.n.01: a company that has been chosen as attractive for takeover by a potential acquirer
#     - east_india_company.n.01: an English company formed in 1600 to develop trade with the new British colonies in India and southeastern Asia; in the 18th century it assumed administrative control of Bengal and held it until the British army took over in 1858 after the Indian Mutiny
#     - oil_company.n.01: a company that sells oil
#     - bureau_de_change.n.01: (French) an establishment where you can exchange foreign money
#
# DEEP ANALYSIS FOR: 'inventor'
#   Definition: someone who is the first to think of or make something
#   Lemmas: ['inventor', 'discoverer', 'artificer']
#
#   All Hypernym Paths:
#     Path 1: entity -> physical_entity -> object -> whole -> living_thing -> organism -> person -> creator -> inventor
#     Path 2: entity -> physical_entity -> causal_agent -> person -> creator -> inventor
#
#   Total hyponyms found: 1
#   All hyponyms:
#     - patentee.n.01: the inventor to whom a patent is issued
#
# DEEP ANALYSIS FOR: 'founder'
#   Definition: inflammation of the laminated tissue that attaches the hoof to the foot of a horse
#   Lemmas: ['laminitis', 'founder']
#
#   All Hypernym Paths:
#     Path 1: entity -> abstraction -> psychological_feature -> cognition -> information -> evidence -> symptom -> inflammation -> laminitis
#
#   Total hyponyms found: 0
#
# DEEP ANALYSIS FOR: 'ceo'
#   Definition: the corporate executive responsible for the operations of the firm; reports to a board of directors; may appoint other managers (including a president)
#   Lemmas: ['chief_executive_officer', 'CEO', 'chief_operating_officer']
#
#   All Hypernym Paths:
#     Path 1: entity -> physical_entity -> object -> whole -> living_thing -> organism -> person -> leader -> head -> administrator -> executive -> corporate_executive -> chief_executive_officer
#     Path 2: entity -> physical_entity -> causal_agent -> person -> leader -> head -> administrator -> executive -> corporate_executive -> chief_executive_officer
#
#   Total hyponyms found: 0
#
# DEEP ANALYSIS FOR: 'pixar'
#
# DEEP ANALYSIS FOR: 'next'
#   Definition: immediately following in time or order
#   Lemmas: ['following', 'next']
#
#   All Hypernym Paths:
#     Path 1: following
#
#   Total hyponyms found: 0

# %% [markdown]
# # Summary of All Operations

# %%
# Cell 15: Summary of All Operations
print("SUMMARY OF ALL OPERATIONS PERFORMED")

print(f"1. CLEANING:")
print(f"   - Original text length: {len(raw_text)} characters")
print(f"   - Cleaned text length: {len(text_cleaned)} characters")
print(f"   - Characters removed: {len(raw_text) - len(text_cleaned)}")

print(f"\n2. LOWERCASING:")
print(f"   - Original text length: {len(text_cleaned)} characters")
print(f"   - Lowercased text length: {len(text_lower)} characters")

print(f"\n3. PUNCTUATION REMOVAL:")
print(f"   - Before removal: {len(text_lower)} characters")
print(f"   - After removal: {len(text_no_punct)} characters")
print(f"   - Punctuation removed: {len(text_lower) - len(text_no_punct)}")

print(f"\n4. STOPWORD REMOVAL:")
print(f"   - Tokens before: {len(tokens)}")
print(f"   - Tokens after: {len(filtered_tokens)}")
print(f"   - Stopwords removed: {len(tokens) - len(filtered_tokens)}")

print(f"\n5. TOKENIZATION:")
print(f"   - Number of sentences: {len(sentences)}")
print(f"   - Number of words: {len(words)}")
print(f"   - Number of characters (no spaces): {len(chars)}")

print(f"\n6. STEMMING:")
print(f"   - Original tokens: {len(filtered_tokens)}")
print(f"   - Porter stemmed tokens: {len(porter_stemmed_tokens)}")
print(f"   - Snowball stemmed tokens: {len(snowball_stemmed_tokens)}")

print(f"\n7. LEMMATIZATION:")
print(f"   - Original tokens: {len(filtered_tokens)}")
print(f"   - Lemmatized tokens: {len(lemmatized_tokens)}")

print(f"\n8. POS TAGGING:")
print(f"   - Number of words tagged: {len(pos_tagged)}")

print(f"\n9. CHUNKING:")
print(f"   - Processed all sentences: {len(all_sentences)} sentences")

print(f"\n10. PARSING:")
print(f"    - Dependency parsing: Complete text processed (Full output shown)")
print(f"    - Tree parsing: All sentences processed (Full output shown)")

print(f"\n11. HYPERNYMS & HYPONYMS:")
print(f"    - Unique words analyzed: {len(unique_words)} words")
print(f"    - Key words analyzed: {len(key_words)} words")
# Out:
# SUMMARY OF ALL OPERATIONS PERFORMED
# 1. CLEANING:
#    - Original text length: 709 characters
#    - Cleaned text length: 632 characters
#    - Characters removed: 77
#
# 2. LOWERCASING:
#    - Original text length: 632 characters
#    - Lowercased text length: 632 characters
#
# 3. PUNCTUATION REMOVAL:
#    - Before removal: 632 characters
#    - After removal: 619 characters
#    - Punctuation removed: 13
#
# 4. STOPWORD REMOVAL:
#    - Tokens before: 19
#    - Tokens after: 71
#    - Stopwords removed: -52
#
# 5. TOKENIZATION:
#    - Number of sentences: 3
#    - Number of words: 101
#    - Number of characters (no spaces): 529
#
# 6. STEMMING:
#    - Original tokens: 71
#    - Porter stemmed tokens: 71
#    - Snowball stemmed tokens: 71
#
# 7. LEMMATIZATION:
#    - Original tokens: 71
#    - Lemmatized tokens: 71
#
# 8. POS TAGGING:
#    - Number of words tagged: 71
#
# 9. CHUNKING:
#    - Processed all sentences: 3 sentences
#
# 10. PARSING:
#     - Dependency parsing: Complete text processed (Full output shown)
#     - Tree parsing: All sentences processed (Full output shown)
#
# 11. HYPERNYMS & HYPONYMS:
#     - Unique words analyzed: 60 words
#     - Key words analyzed: 8 words
