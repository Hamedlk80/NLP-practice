# %% [markdown]
# # practice one

# %% [markdown]
# # mabahese vizhe

# %% [markdown]
# # Mohammadali Lotfi kooshali      -        404198471

# %% [markdown]
# # install , download and import libraries

# %%
# !pip install spacy nltk
# !python -m spacy download en_core_web_sm

import re
import spacy
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize, sent_tokenize
from nltk.stem import PorterStemmer, WordNetLemmatizer, SnowballStemmer
from nltk import pos_tag
from nltk.corpus import wordnet as wn
from string import punctuation
from nltk.chunk import RegexpParser
from nltk import Tree
import time

# Download required NLTK data
nltk.download('punkt')
nltk.download('stopwords')
nltk.download('wordnet')
nltk.download('averaged_perceptron_tagger')
nltk.download('omw-1.4')

# Load spaCy model
nlp = spacy.load("en_core_web_sm")
# Out:
# Requirement already satisfied: spacy in D:\.venv\Lib\site-packages (3.8.14)
# Requirement already satisfied: nltk in D:\.venv\Lib\site-packages (3.9.4)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in D:\.venv\Lib\site-packages (from spacy) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in D:\.venv\Lib\site-packages (from spacy) (1.0.0)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in D:\.venv\Lib\site-packages (from spacy) (1.0.10)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in D:\.venv\Lib\site-packages (from spacy) (2.0.13)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in D:\.venv\Lib\site-packages (from spacy) (3.0.13)
# Requirement already satisfied: thinc<8.4.0,>=8.3.12 in D:\.venv\Lib\site-packages (from spacy) (8.3.13)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in D:\.venv\Lib\site-packages (from spacy) (0.10.1)
# Requirement already satisfied: srsly<3.0.0,>=2.5.3 in D:\.venv\Lib\site-packages (from spacy) (2.5.3)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in D:\.venv\Lib\site-packages (from spacy) (2.0.10)
# Requirement already satisfied: weasel<2.0.0,>=1.0.0 in D:\.venv\Lib\site-packages (from spacy) (1.0.0)
# Requirement already satisfied: confection<2.0.0,>=1.3.2 in D:\.venv\Lib\site-packages (from spacy) (1.3.3)
# Requirement already satisfied: typer<1.0.0,>=0.3.0 in D:\.venv\Lib\site-packages (from spacy) (0.23.1)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in D:\.venv\Lib\site-packages (from spacy) (4.67.3)
# Requirement already satisfied: numpy>=1.19.0 in D:\.venv\Lib\site-packages (from spacy) (2.3.5)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in D:\.venv\Lib\site-packages (from spacy) (2.32.5)
# Requirement already satisfied: pydantic<3.0.0,>=2.0.0 in D:\.venv\Lib\site-packages (from spacy) (2.12.5)
# Requirement already satisfied: jinja2 in D:\.venv\Lib\site-packages (from spacy) (3.1.6)
# Requirement already satisfied: setuptools in D:\.venv\Lib\site-packages (from spacy) (81.0.0)
# Requirement already satisfied: packaging>=20.0 in D:\.venv\Lib\site-packages (from spacy) (25.0)
# Requirement already satisfied: annotated-types>=0.6.0 in D:\.venv\Lib\site-packages (from pydantic<3.0.0,>=2.0.0->spacy) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in D:\.venv\Lib\site-packages (from pydantic<3.0.0,>=2.0.0->spacy) (2.41.5)
# Requirement already satisfied: typing-extensions>=4.14.1 in D:\.venv\Lib\site-packages (from pydantic<3.0.0,>=2.0.0->spacy) (4.15.0)
# Requirement already satisfied: typing-inspection>=0.4.2 in D:\.venv\Lib\site-packages (from pydantic<3.0.0,>=2.0.0->spacy) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in D:\.venv\Lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in D:\.venv\Lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in D:\.venv\Lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (2.6.3)
# Requirement already satisfied: certifi>=2017.4.17 in D:\.venv\Lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (2026.1.4)
# Requirement already satisfied: blis<1.4.0,>=1.3.0 in D:\.venv\Lib\site-packages (from thinc<8.4.0,>=8.3.12->spacy) (1.3.3)
# Requirement already satisfied: colorama in D:\.venv\Lib\site-packages (from tqdm<5.0.0,>=4.38.0->spacy) (0.4.6)
# Requirement already satisfied: click>=8.0.0 in D:\.venv\Lib\site-packages (from typer<1.0.0,>=0.3.0->spacy) (8.3.1)
# Requirement already satisfied: shellingham>=1.3.0 in D:\.venv\Lib\site-packages (from typer<1.0.0,>=0.3.0->spacy) (1.5.4)
# Requirement already satisfied: rich>=10.11.0 in D:\.venv\Lib\site-packages (from typer<1.0.0,>=0.3.0->spacy) (14.3.2)
# Requirement already satisfied: annotated-doc>=0.0.2 in D:\.venv\Lib\site-packages (from typer<1.0.0,>=0.3.0->spacy) (0.0.4)
# Requirement already satisfied: cloudpathlib>=0.7.0 in D:\.venv\Lib\site-packages (from weasel<2.0.0,>=1.0.0->spacy) (0.23.0)
# Requirement already satisfied: smart-open>=5.2.1 in D:\.venv\Lib\site-packages (from weasel<2.0.0,>=1.0.0->spacy) (7.6.0)
# Requirement already satisfied: httpx>=0.24.0 in D:\.venv\Lib\site-packages (from weasel<2.0.0,>=1.0.0->spacy) (0.28.1)
# Requirement already satisfied: joblib in D:\.venv\Lib\site-packages (from nltk) (1.5.3)
# Requirement already satisfied: regex>=2021.8.3 in D:\.venv\Lib\site-packages (from nltk) (2026.1.15)
# Requirement already satisfied: anyio in D:\.venv\Lib\site-packages (from httpx>=0.24.0->weasel<2.0.0,>=1.0.0->spacy) (4.12.1)
# Requirement already satisfied: httpcore==1.* in D:\.venv\Lib\site-packages (from httpx>=0.24.0->weasel<2.0.0,>=1.0.0->spacy) (1.0.9)
# Requirement already satisfied: h11>=0.16 in D:\.venv\Lib\site-packages (from httpcore==1.*->httpx>=0.24.0->weasel<2.0.0,>=1.0.0->spacy) (0.16.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in D:\.venv\Lib\site-packages (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in D:\.venv\Lib\site-packages (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in D:\.venv\Lib\site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy) (0.1.2)
# Requirement already satisfied: wrapt in D:\.venv\Lib\site-packages (from smart-open>=5.2.1->weasel<2.0.0,>=1.0.0->spacy) (2.1.2)
# Requirement already satisfied: MarkupSafe>=2.0 in D:\.venv\Lib\site-packages (from jinja2->spacy) (3.0.3)
#   WARNING: Retrying (Retry(total=4, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ProtocolError('Connection aborted.', ConnectionResetError(10054, 'An existing connection was forcibly closed by the remote host', None, 10054, None))': /github-production-release-asset/84940268/15132ab6-4050-4914-8fe8-ac2c2fdcb9cf?sp=r&sv=2018-11-09&sr=b&spr=https&se=2026-04-27T22%3A02%3A31Z&rscd=attachment%3B+filename%3Den_core_web_sm-3.8.0-py3-none-any.whl&rsct=application%2Foctet-stream&skoid=96c2d410-5711-43a1-aedd-ab1947aa7ab0&sktid=398a6654-997b-47e9-b12b-9515b896b4de&skt=2026-04-27T21%3A01%3A54Z&ske=2026-04-27T22%3A02%3A31Z&sks=b&skv=2018-11-09&sig=gz2UBGD1mVxC0TJT6mTRtDM5dwU0L6Bl0hLYE5S9RCw%3D&jwt=eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9.eyJpc3MiOiJnaXRodWIuY29tIiwiYXVkIjoicmVsZWFzZS1hc3NldHMuZ2l0aHVidXNlcmNvbnRlbnQuY29tIiwia2V5Ijoia2V5MSIsImV4cCI6MTc3NzMyNjIzMiwibmJmIjoxNzc3MzI0NDMyLCJwYXRoIjoicmVsZWFzZWFzc2V0cHJvZHVjdGlvbi5ibG9iLmNvcmUud2luZG93cy5uZXQifQ.MjMrBwA80nIVJJV6_Chxaq9SHtJwlaEleKr2uhsnxmg&response-content-disposition=attachment%3B%20filename%3Den_core_web_sm-3.8.0-py3-none-any.whl&response-content-type=application%2Foctet-stream
#   WARNING: Retrying (Retry(total=3, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ProtocolError('Connection aborted.', ConnectionResetError(10054, 'An existing connection was forcibly closed by the remote host', None, 10054, None))': /github-production-release-asset/84940268/15132ab6-4050-4914-8fe8-ac2c2fdcb9cf?sp=r&sv=2018-11-09&sr=b&spr=https&se=2026-04-27T22%3A02%3A31Z&rscd=attachment%3B+filename%3Den_core_web_sm-3.8.0-py3-none-any.whl&rsct=application%2Foctet-stream&skoid=96c2d410-5711-43a1-aedd-ab1947aa7ab0&sktid=398a6654-997b-47e9-b12b-9515b896b4de&skt=2026-04-27T21%3A01%3A54Z&ske=2026-04-27T22%3A02%3A31Z&sks=b&skv=2018-11-09&sig=gz2UBGD1mVxC0TJT6mTRtDM5dwU0L6Bl0hLYE5S9RCw%3D&jwt=eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9.eyJpc3MiOiJnaXRodWIuY29tIiwiYXVkIjoicmVsZWFzZS1hc3NldHMuZ2l0aHVidXNlcmNvbnRlbnQuY29tIiwia2V5Ijoia2V5MSIsImV4cCI6MTc3NzMyNjIzMiwibmJmIjoxNzc3MzI0NDMyLCJwYXRoIjoicmVsZWFzZWFzc2V0cHJvZHVjdGlvbi5ibG9iLmNvcmUud2luZG93cy5uZXQifQ.MjMrBwA80nIVJJV6_Chxaq9SHtJwlaEleKr2uhsnxmg&response-content-disposition=attachment%3B%20filename%3Den_core_web_sm-3.8.0-py3-none-any.whl&response-content-type=application%2Foctet-stream
#   WARNING: Retrying (Retry(total=2, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ProtocolError('Connection aborted.', ConnectionResetError(10054, 'An existing connection was forcibly closed by the remote host', None, 10054, None))': /github-production-release-asset/84940268/15132ab6-4050-4914-8fe8-ac2c2fdcb9cf?sp=r&sv=2018-11-09&sr=b&spr=https&se=2026-04-27T22%3A02%3A31Z&rscd=attachment%3B+filename%3Den_core_web_sm-3.8.0-py3-none-any.whl&rsct=application%2Foctet-stream&skoid=96c2d410-5711-43a1-aedd-ab1947aa7ab0&sktid=398a6654-997b-47e9-b12b-9515b896b4de&skt=2026-04-27T21%3A01%3A54Z&ske=2026-04-27T22%3A02%3A31Z&sks=b&skv=2018-11-09&sig=gz2UBGD1mVxC0TJT6mTRtDM5dwU0L6Bl0hLYE5S9RCw%3D&jwt=eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9.eyJpc3MiOiJnaXRodWIuY29tIiwiYXVkIjoicmVsZWFzZS1hc3NldHMuZ2l0aHVidXNlcmNvbnRlbnQuY29tIiwia2V5Ijoia2V5MSIsImV4cCI6MTc3NzMyNjIzMiwibmJmIjoxNzc3MzI0NDMyLCJwYXRoIjoicmVsZWFzZWFzc2V0cHJvZHVjdGlvbi5ibG9iLmNvcmUud2luZG93cy5uZXQifQ.MjMrBwA80nIVJJV6_Chxaq9SHtJwlaEleKr2uhsnxmg&response-content-disposition=attachment%3B%20filename%3Den_core_web_sm-3.8.0-py3-none-any.whl&response-content-type=application%2Foctet-stream
#   WARNING: Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ProtocolError('Connection aborted.', ConnectionResetError(10054, 'An existing connection was forcibly closed by the remote host', None, 10054, None))': /github-production-release-asset/84940268/15132ab6-4050-4914-8fe8-ac2c2fdcb9cf?sp=r&sv=2018-11-09&sr=b&spr=https&se=2026-04-27T22%3A02%3A31Z&rscd=attachment%3B+filename%3Den_core_web_sm-3.8.0-py3-none-any.whl&rsct=application%2Foctet-stream&skoid=96c2d410-5711-43a1-aedd-ab1947aa7ab0&sktid=398a6654-997b-47e9-b12b-9515b896b4de&skt=2026-04-27T21%3A01%3A54Z&ske=2026-04-27T22%3A02%3A31Z&sks=b&skv=2018-11-09&sig=gz2UBGD1mVxC0TJT6mTRtDM5dwU0L6Bl0hLYE5S9RCw%3D&jwt=eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9.eyJpc3MiOiJnaXRodWIuY29tIiwiYXVkIjoicmVsZWFzZS1hc3NldHMuZ2l0aHVidXNlcmNvbnRlbnQuY29tIiwia2V5Ijoia2V5MSIsImV4cCI6MTc3NzMyNjIzMiwibmJmIjoxNzc3MzI0NDMyLCJwYXRoIjoicmVsZWFzZWFzc2V0cHJvZHVjdGlvbi5ibG9iLmNvcmUud2luZG93cy5uZXQifQ.MjMrBwA80nIVJJV6_Chxaq9SHtJwlaEleKr2uhsnxmg&response-content-disposition=attachment%3B%20filename%3Den_core_web_sm-3.8.0-py3-none-any.whl&response-content-type=application%2Foctet-stream
#   WARNING: Retrying (Retry(total=0, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ProtocolError('Connection aborted.', ConnectionResetError(10054, 'An existing connection was forcibly closed by the remote host', None, 10054, None))': /github-production-release-asset/84940268/15132ab6-4050-4914-8fe8-ac2c2fdcb9cf?sp=r&sv=2018-11-09&sr=b&spr=https&se=2026-04-27T22%3A02%3A31Z&rscd=attachment%3B+filename%3Den_core_web_sm-3.8.0-py3-none-any.whl&rsct=application%2Foctet-stream&skoid=96c2d410-5711-43a1-aedd-ab1947aa7ab0&sktid=398a6654-997b-47e9-b12b-9515b896b4de&skt=2026-04-27T21%3A01%3A54Z&ske=2026-04-27T22%3A02%3A31Z&sks=b&skv=2018-11-09&sig=gz2UBGD1mVxC0TJT6mTRtDM5dwU0L6Bl0hLYE5S9RCw%3D&jwt=eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9.eyJpc3MiOiJnaXRodWIuY29tIiwiYXVkIjoicmVsZWFzZS1hc3NldHMuZ2l0aHVidXNlcmNvbnRlbnQuY29tIiwia2V5Ijoia2V5MSIsImV4cCI6MTc3NzMyNjIzMiwibmJmIjoxNzc3MzI0NDMyLCJwYXRoIjoicmVsZWFzZWFzc2V0cHJvZHVjdGlvbi5ibG9iLmNvcmUud2luZG93cy5uZXQifQ.MjMrBwA80nIVJJV6_Chxaq9SHtJwlaEleKr2uhsnxmg&response-content-disposition=attachment%3B%20filename%3Den_core_web_sm-3.8.0-py3-none-any.whl&response-content-type=application%2Foctet-stream
# ERROR: Could not install packages due to an OSError: HTTPSConnectionPool(host='release-assets.githubusercontent.com', port=443): Max retries exceeded with url: /github-production-release-asset/84940268/15132ab6-4050-4914-8fe8-ac2c2fdcb9cf?sp=r&sv=2018-11-09&sr=b&spr=https&se=2026-04-27T22%3A02%3A31Z&rscd=attachment%3B+filename%3Den_core_web_sm-3.8.0-py3-none-any.whl&rsct=application%2Foctet-stream&skoid=96c2d410-5711-43a1-aedd-ab1947aa7ab0&sktid=398a6654-997b-47e9-b12b-9515b896b4de&skt=2026-04-27T21%3A01%3A54Z&ske=2026-04-27T22%3A02%3A31Z&sks=b&skv=2018-11-09&sig=gz2UBGD1mVxC0TJT6mTRtDM5dwU0L6Bl0hLYE5S9RCw%3D&jwt=eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9.eyJpc3MiOiJnaXRodWIuY29tIiwiYXVkIjoicmVsZWFzZS1hc3NldHMuZ2l0aHVidXNlcmNvbnRlbnQuY29tIiwia2V5Ijoia2V5MSIsImV4cCI6MTc3NzMyNjIzMiwibmJmIjoxNzc3MzI0NDMyLCJwYXRoIjoicmVsZWFzZWFzc2V0cHJvZHVjdGlvbi5ibG9iLmNvcmUud2luZG93cy5uZXQifQ.MjMrBwA80nIVJJV6_Chxaq9SHtJwlaEleKr2uhsnxmg&response-content-disposition=attachment%3B%20filename%3Den_core_web_sm-3.8.0-py3-none-any.whl&response-content-type=application%2Foctet-stream (Caused by ProtocolError('Connection aborted.', ConnectionResetError(10054, 'An existing connection was forcibly closed by the remote host', None, 10054, None)))
#
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\ASUS\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\ASUS\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\ASUS\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     C:\Users\ASUS\AppData\Roaming\nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package omw-1.4 to
# [nltk_data]     C:\Users\ASUS\AppData\Roaming\nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# Collecting en-core-web-sm==3.8.0

# %% [markdown]
# # reading text file

# %%
with open('scifi_story.txt', 'r', encoding='utf-8') as file:
    raw_text = file.read()

print("original text:")
print(raw_text)
print(f"Total characters: {len(raw_text)}")
# Out:
# original text:
# In the year 2147, humanity had finally achieved interstellar travel.
#
# The starship "Odyssey-9" was preparing for its maiden voyage to Proxima Centauri b (distance: 4.24 light years).
#
# Chief Engineer Dr. Elena Vasquez ran the final diagnostics:
# - Hyperdrive status: ONLINE ✅
# - Life support systems: OPERATIONAL ✅
# - Quantum AI core: ACTIVATED 🤖⚡
#
# "Launch sequence initiated," announced Commander James Webb. "T-minus 10... 9... 8..."
#
# Suddenly, an alarm blared: "ERROR: Unidentified signal detected from Sector 7-Gamma!"
#
# The crew exchanged worried glances. What was out there? 👽🛸
#
# To be continued...
# Total characters: 600

# %% [markdown]
# # 1. Cleaning Text with re.sub

# %%
# Remove numbers
text_no_numbers = re.sub(r'\d+', '', raw_text)
print("After removing numbers:")
print(text_no_numbers)
print("-" * 80)

# Remove extra whitespaces
text_cleaned = re.sub(r'\s+', ' ', text_no_numbers)
print("After removing extra whitespaces:")
print(text_cleaned)
print("-" * 80)

# Remove special characters (keep letters, spaces, dots, commas)
text_cleaned = re.sub(r'[^\w\s\.\,]', '', text_cleaned)
print("After removing special characters:")
print(text_cleaned)
print(f"Cleaned text length: {len(text_cleaned)} characters")
# Out:
# After removing numbers:
# In the year , humanity had finally achieved interstellar travel.
#
# The starship "Odyssey-" was preparing for its maiden voyage to Proxima Centauri b (distance: . light years).
#
# Chief Engineer Dr. Elena Vasquez ran the final diagnostics:
# - Hyperdrive status: ONLINE ✅
# - Life support systems: OPERATIONAL ✅
# - Quantum AI core: ACTIVATED 🤖⚡
#
# "Launch sequence initiated," announced Commander James Webb. "T-minus ... ... ..."
#
# Suddenly, an alarm blared: "ERROR: Unidentified signal detected from Sector -Gamma!"
#
# The crew exchanged worried glances. What was out there? 👽🛸
#
# To be continued...
# --------------------------------------------------------------------------------
# After removing extra whitespaces:
# In the year , humanity had finally achieved interstellar travel. The starship "Odyssey-" was preparing for its maiden voyage to Proxima Centauri b (distance: . light years). Chief Engineer Dr. Elena Vasquez ran the final diagnostics: - Hyperdrive status: ONLINE ✅ - Life support systems: OPERATIONAL ✅ - Quantum AI core: ACTIVATED 🤖⚡ "Launch sequence initiated," announced Commander James Webb. "T-minus ... ... ..." Suddenly, an alarm blared: "ERROR: Unidentified signal detected from Sector -Gamma!" The crew exchanged worried glances. What was out there? 👽🛸 To be continued...
# --------------------------------------------------------------------------------
# After removing special characters:
# In the year , humanity had finally achieved interstellar travel. The starship Odyssey was preparing for its maiden voyage to Proxima Centauri b distance . light years. Chief Engineer Dr. Elena Vasquez ran the final diagnostics  Hyperdrive status ONLINE   Life support systems OPERATIONAL   Quantum AI core ACTIVATED  Launch sequence initiated, announced Commander James Webb. Tminus ... ... ... Suddenly, an alarm blared ERROR Unidentified signal detected from Sector Gamma The crew exchanged worried glances. What was out there  To be continued...
# Cleaned text length: 548 characters

# %% [markdown]
# # 2. Lowercasing

# %%
text_lower = text_cleaned.lower()
print("Text after lowercasing:")
print(text_lower)
# Out:
# Text after lowercasing:
# in the year , humanity had finally achieved interstellar travel. the starship odyssey was preparing for its maiden voyage to proxima centauri b distance . light years. chief engineer dr. elena vasquez ran the final diagnostics  hyperdrive status online   life support systems operational   quantum ai core activated  launch sequence initiated, announced commander james webb. tminus ... ... ... suddenly, an alarm blared error unidentified signal detected from sector gamma the crew exchanged worried glances. what was out there  to be continued...

# %% [markdown]
# # 3. Punctuation Removal

# %%
print("Punctuation removed:", punctuation)
text_no_punct = ''.join([char for char in text_lower if char not in punctuation])
print("Text after punctuation removal:")
print(text_no_punct)
# Out:
# Punctuation removed: !"#$%&'()*+,-./:;<=>?@[\]^_`{|}~
# Text after punctuation removal:
# in the year  humanity had finally achieved interstellar travel the starship odyssey was preparing for its maiden voyage to proxima centauri b distance  light years chief engineer dr elena vasquez ran the final diagnostics  hyperdrive status online   life support systems operational   quantum ai core activated  launch sequence initiated announced commander james webb tminus    suddenly an alarm blared error unidentified signal detected from sector gamma the crew exchanged worried glances what was out there  to be continued

# %% [markdown]
# # 4. Stopword Removal

# %%
# Get English stopwords
stop_words = set(stopwords.words('english'))
print("English stopwords :")
print(list(stop_words))

# Tokenize first
tokens = word_tokenize(text_no_punct)
print(f"Total tokens before stopword removal: {len(tokens)}")
print("tokens before removal:")
print(tokens)

# Remove stopwords
filtered_tokens = [word for word in tokens if word not in stop_words]
print(f"Total tokens after stopword removal: {len(filtered_tokens)}")
print("tokens after removal:")
print(filtered_tokens)

# Convert back to text
text_no_stopwords = ' '.join(filtered_tokens)
print("Complete text after stopword removal:")
print(text_no_stopwords)
# Out:
# English stopwords :
# ["i've", 'had', 'ours', 'm', 'are', 'any', "we've", 'from', "hasn't", "weren't", 'aren', 'all', "shouldn't", "mightn't", 'nor', 'only', 'they', 'wouldn', "we'll", 'having', 'out', 'them', 'a', 've', 'my', 'doing', 'most', 'the', "you'd", 'where', 'has', 'hasn', 'if', 'after', 're', 'not', 'don', 'you', 'because', 'when', "she'll", 'shouldn', "that'll", 'before', "shan't", 'it', 'how', 'at', 'once', 'few', 'below', 'him', 'yourselves', 'of', 'just', "he'd", 'is', 'her', 'be', 'or', 'between', 'into', 'their', 'yourself', 'haven', 'hadn', 'for', 'what', 'there', 'do', 'myself', 'mightn', 'about', 'off', 'himself', 'but', 'down', 'during', "he'll", "isn't", 'over', 'who', 'didn', 'wasn', 'couldn', 'as', 'to', 'above', 'such', 'so', 'am', 'does', "hadn't", 'which', 'shan', 'theirs', 'needn', 'y', 'themselves', 'was', 'being', 'won', 'here', 'can', "haven't", "won't", "they're", 'weren', 'an', 'he', "needn't", 'and', 'isn', 'your', 'again', 'more', 'than', 'these', 'we', 'those', 'some', 'd', "he's", 'this', "aren't", 'then', "we'd", 'll', "i'll", 'until', 'doesn', 'whom', 'hers', "should've", 'why', "mustn't", "she'd", 'been', 'did', 'o', 'other', 'while', 'ourselves', "didn't", 'each', "it'd", 'were', 't', "it'll", 'his', 'that', 'ma', 'its', 'have', 'in', "she's", 'very', 'too', "you're", 'me', "wouldn't", "we're", 'by', "couldn't", "don't", 'under', 'she', 'itself', 'on', 'with', "wasn't", 'both', "i'd", 'up', "doesn't", "you'll", "i'm", 'herself', "it's", 'ain', 'will', 's', 'further', "they'll", 'should', 'our', 'same', 'mustn', "they've", 'no', 'now', "you've", 'own', 'yours', "they'd", 'through', 'against', 'i']
# Total tokens before stopword removal: 76
# tokens before removal:
# ['in', 'the', 'year', 'humanity', 'had', 'finally', 'achieved', 'interstellar', 'travel', 'the', 'starship', 'odyssey', 'was', 'preparing', 'for', 'its', 'maiden', 'voyage', 'to', 'proxima', 'centauri', 'b', 'distance', 'light', 'years', 'chief', 'engineer', 'dr', 'elena', 'vasquez', 'ran', 'the', 'final', 'diagnostics', 'hyperdrive', 'status', 'online', 'life', 'support', 'systems', 'operational', 'quantum', 'ai', 'core', 'activated', 'launch', 'sequence', 'initiated', 'announced', 'commander', 'james', 'webb', 'tminus', 'suddenly', 'an', 'alarm', 'blared', 'error', 'unidentified', 'signal', 'detected', 'from', 'sector', 'gamma', 'the', 'crew', 'exchanged', 'worried', 'glances', 'what', 'was', 'out', 'there', 'to', 'be', 'continued']
# Total tokens after stopword removal: 58
# tokens after removal:
# ['year', 'humanity', 'finally', 'achieved', 'interstellar', 'travel', 'starship', 'odyssey', 'preparing', 'maiden', 'voyage', 'proxima', 'centauri', 'b', 'distance', 'light', 'years', 'chief', 'engineer', 'dr', 'elena', 'vasquez', 'ran', 'final', 'diagnostics', 'hyperdrive', 'status', 'online', 'life', 'support', 'systems', 'operational', 'quantum', 'ai', 'core', 'activated', 'launch', 'sequence', 'initiated', 'announced', 'commander', 'james', 'webb', 'tminus', 'suddenly', 'alarm', 'blared', 'error', 'unidentified', 'signal', 'detected', 'sector', 'gamma', 'crew', 'exchanged', 'worried', 'glances', 'continued']
# Complete text after stopword removal:
# year humanity finally achieved interstellar travel starship odyssey preparing maiden voyage proxima centauri b distance light years chief engineer dr elena vasquez ran final diagnostics hyperdrive status online life support systems operational quantum ai core activated launch sequence initiated announced commander james webb tminus suddenly alarm blared error unidentified signal detected sector gamma crew exchanged worried glances continued

# %% [markdown]
# # 5. Tokenization (Sentence, Word, Character)

# %%
# Sentence Tokenization
sentences = sent_tokenize(text_lower)
print("Sentence Tokenization:")
print(f"Total number of sentences: {len(sentences)}")
print("All sentences:")
for i, sent in enumerate(sentences, 1):
    print(f"{i}. {sent}")

# Word Tokenization
words = word_tokenize(text_lower)
print("Word Tokenization:")
print(f"Total number of words: {len(words)}")
print("All words:")
print(words)

# Character Tokenization
chars = [char for char in text_lower if char != ' ']
print("Character Tokenization:")
print(f"Total number of characters (without spaces): {len(chars)}")
print("All characters:")
print(chars)
# Out:
# Sentence Tokenization:
# Total number of sentences: 6
# All sentences:
# 1. in the year , humanity had finally achieved interstellar travel.
# 2. the starship odyssey was preparing for its maiden voyage to proxima centauri b distance .
# 3. light years.
# 4. chief engineer dr. elena vasquez ran the final diagnostics  hyperdrive status online   life support systems operational   quantum ai core activated  launch sequence initiated, announced commander james webb.
# 5. tminus ... ... ... suddenly, an alarm blared error unidentified signal detected from sector gamma the crew exchanged worried glances.
# 6. what was out there  to be continued...
# Word Tokenization:
# Total number of words: 88
# All words:
# ['in', 'the', 'year', ',', 'humanity', 'had', 'finally', 'achieved', 'interstellar', 'travel', '.', 'the', 'starship', 'odyssey', 'was', 'preparing', 'for', 'its', 'maiden', 'voyage', 'to', 'proxima', 'centauri', 'b', 'distance', '.', 'light', 'years', '.', 'chief', 'engineer', 'dr.', 'elena', 'vasquez', 'ran', 'the', 'final', 'diagnostics', 'hyperdrive', 'status', 'online', 'life', 'support', 'systems', 'operational', 'quantum', 'ai', 'core', 'activated', 'launch', 'sequence', 'initiated', ',', 'announced', 'commander', 'james', 'webb', '.', 'tminus', '...', '...', '...', 'suddenly', ',', 'an', 'alarm', 'blared', 'error', 'unidentified', 'signal', 'detected', 'from', 'sector', 'gamma', 'the', 'crew', 'exchanged', 'worried', 'glances', '.', 'what', 'was', 'out', 'there', 'to', 'be', 'continued', '...']
# Character Tokenization:
# Total number of characters (without spaces): 461
# All characters:
# ['i', 'n', 't', 'h', 'e', 'y', 'e', 'a', 'r', ',', 'h', 'u', 'm', 'a', 'n', 'i', 't', 'y', 'h', 'a', 'd', 'f', 'i', 'n', 'a', 'l', 'l', 'y', 'a', 'c', 'h', 'i', 'e', 'v', 'e', 'd', 'i', 'n', 't', 'e', 'r', 's', 't', 'e', 'l', 'l', 'a', 'r', 't', 'r', 'a', 'v', 'e', 'l', '.', 't', 'h', 'e', 's', 't', 'a', 'r', 's', 'h', 'i', 'p', 'o', 'd', 'y', 's', 's', 'e', 'y', 'w', 'a', 's', 'p', 'r', 'e', 'p', 'a', 'r', 'i', 'n', 'g', 'f', 'o', 'r', 'i', 't', 's', 'm', 'a', 'i', 'd', 'e', 'n', 'v', 'o', 'y', 'a', 'g', 'e', 't', 'o', 'p', 'r', 'o', 'x', 'i', 'm', 'a', 'c', 'e', 'n', 't', 'a', 'u', 'r', 'i', 'b', 'd', 'i', 's', 't', 'a', 'n', 'c', 'e', '.', 'l', 'i', 'g', 'h', 't', 'y', 'e', 'a', 'r', 's', '.', 'c', 'h', 'i', 'e', 'f', 'e', 'n', 'g', 'i', 'n', 'e', 'e', 'r', 'd', 'r', '.', 'e', 'l', 'e', 'n', 'a', 'v', 'a', 's', 'q', 'u', 'e', 'z', 'r', 'a', 'n', 't', 'h', 'e', 'f', 'i', 'n', 'a', 'l', 'd', 'i', 'a', 'g', 'n', 'o', 's', 't', 'i', 'c', 's', 'h', 'y', 'p', 'e', 'r', 'd', 'r', 'i', 'v', 'e', 's', 't', 'a', 't', 'u', 's', 'o', 'n', 'l', 'i', 'n', 'e', 'l', 'i', 'f', 'e', 's', 'u', 'p', 'p', 'o', 'r', 't', 's', 'y', 's', 't', 'e', 'm', 's', 'o', 'p', 'e', 'r', 'a', 't', 'i', 'o', 'n', 'a', 'l', 'q', 'u', 'a', 'n', 't', 'u', 'm', 'a', 'i', 'c', 'o', 'r', 'e', 'a', 'c', 't', 'i', 'v', 'a', 't', 'e', 'd', 'l', 'a', 'u', 'n', 'c', 'h', 's', 'e', 'q', 'u', 'e', 'n', 'c', 'e', 'i', 'n', 'i', 't', 'i', 'a', 't', 'e', 'd', ',', 'a', 'n', 'n', 'o', 'u', 'n', 'c', 'e', 'd', 'c', 'o', 'm', 'm', 'a', 'n', 'd', 'e', 'r', 'j', 'a', 'm', 'e', 's', 'w', 'e', 'b', 'b', '.', 't', 'm', 'i', 'n', 'u', 's', '.', '.', '.', '.', '.', '.', '.', '.', '.', 's', 'u', 'd', 'd', 'e', 'n', 'l', 'y', ',', 'a', 'n', 'a', 'l', 'a', 'r', 'm', 'b', 'l', 'a', 'r', 'e', 'd', 'e', 'r', 'r', 'o', 'r', 'u', 'n', 'i', 'd', 'e', 'n', 't', 'i', 'f', 'i', 'e', 'd', 's', 'i', 'g', 'n', 'a', 'l', 'd', 'e', 't', 'e', 'c', 't', 'e', 'd', 'f', 'r', 'o', 'm', 's', 'e', 'c', 't', 'o', 'r', 'g', 'a', 'm', 'm', 'a', 't', 'h', 'e', 'c', 'r', 'e', 'w', 'e', 'x', 'c', 'h', 'a', 'n', 'g', 'e', 'd', 'w', 'o', 'r', 'r', 'i', 'e', 'd', 'g', 'l', 'a', 'n', 'c', 'e', 's', '.', 'w', 'h', 'a', 't', 'w', 'a', 's', 'o', 'u', 't', 't', 'h', 'e', 'r', 'e', 't', 'o', 'b', 'e', 'c', 'o', 'n', 't', 'i', 'n', 'u', 'e', 'd', '.', '.', '.']

# %% [markdown]
# # 6. Stemming (PorterStemmer and SnowballStemmer)

# %%
# Initialize both stemmers
porter_stemmer = PorterStemmer()
snowball_stemmer = SnowballStemmer("english")

# Apply both stemmers
porter_stemmed_tokens = [porter_stemmer.stem(word) for word in filtered_tokens]
snowball_stemmed_tokens = [snowball_stemmer.stem(word) for word in filtered_tokens]

print("COMPLETE COMPARISON (Original vs Porter vs Snowball):")
print(f"{'#':<5} | {'Original Word':<25} | {'Porter Stemmer':<20} | {'Snowball Stemmer':<20} | {'Difference'}")

difference_count = 0
for i, (original, porter, snowball) in enumerate(zip(filtered_tokens, porter_stemmed_tokens, snowball_stemmed_tokens), 1):
    difference = "DIFFERENT" if porter != snowball else "SAME"
    if porter != snowball:
        difference_count += 1
    print(f"{i:<5} | {original:<25} | {porter:<20} | {snowball:<20} | {difference}")

print(f"\nTotal words with different stemming results: {difference_count} out of {len(filtered_tokens)}")
print(f"Percentage of differences: {(difference_count/len(filtered_tokens))*100:.2f}%")

# Show detailed comparison for words that differ
print("\nDETAILED COMPARISON FOR WORDS WITH DIFFERENT STEMMING RESULTS:")

different_words = []
for original, porter, snowball in zip(filtered_tokens, porter_stemmed_tokens, snowball_stemmed_tokens):
    if porter != snowball:
        different_words.append((original, porter, snowball))

if different_words:
    print(f"{'#':<5} | {'Original Word':<25} | {'Porter Result':<20} | {'Snowball Result':<20} | {'Analysis'}")
    for i, (original, porter, snowball) in enumerate(different_words, 1):
        analysis = ""
        if len(porter) < len(snowball):
            analysis = "Porter shorter"
        elif len(snowball) < len(porter):
            analysis = "Snowball shorter"
        elif porter.endswith('ing') and not snowball.endswith('ing'):
            analysis = "Porter keeps -ing"
        elif snowball.endswith('ing') and not porter.endswith('ing'):
            analysis = "Snowball keeps -ing"
        else:
            analysis = "Different algorithm"
        print(f"{i:<5} | {original:<25} | {porter:<20} | {snowball:<20} | {analysis}")
else:
    print("No differences found between Porter and Snowball stemmers for this text.")

# Show complete stemmed texts
print("\nCOMPLETE PORTER STEMMED TEXT:")
porter_stemmed_text = ' '.join(porter_stemmed_tokens)
print(porter_stemmed_text)

print("\nCOMPLETE SNOWBALL STEMMED TEXT:")
snowball_stemmed_text = ' '.join(snowball_stemmed_tokens)
print(snowball_stemmed_text)

# Performance comparison
print("\nPERFORMANCE COMPARISON:")

# Test Porter speed
start_time = time.time()
for word in filtered_tokens * 10:
    porter_stemmer.stem(word)
porter_time = time.time() - start_time

# Test Snowball speed
start_time = time.time()
for word in filtered_tokens * 10:
    snowball_stemmer.stem(word)
snowball_time = time.time() - start_time

print(f"PorterStemmer processing time (10 repetitions): {porter_time:.6f} seconds")
print(f"SnowballStemmer processing time (10 repetitions): {snowball_time:.6f} seconds")
# Out:
# COMPLETE COMPARISON (Original vs Porter vs Snowball):
# #     | Original Word             | Porter Stemmer       | Snowball Stemmer     | Difference
# 1     | year                      | year                 | year                 | SAME
# 2     | humanity                  | human                | human                | SAME
# 3     | finally                   | final                | final                | SAME
# 4     | achieved                  | achiev               | achiev               | SAME
# 5     | interstellar              | interstellar         | interstellar         | SAME
# 6     | travel                    | travel               | travel               | SAME
# 7     | starship                  | starship             | starship             | SAME
# 8     | odyssey                   | odyssey              | odyssey              | SAME
# 9     | preparing                 | prepar               | prepar               | SAME
# 10    | maiden                    | maiden               | maiden               | SAME
# 11    | voyage                    | voyag                | voyag                | SAME
# 12    | proxima                   | proxima              | proxima              | SAME
# 13    | centauri                  | centauri             | centauri             | SAME
# 14    | b                         | b                    | b                    | SAME
# 15    | distance                  | distanc              | distanc              | SAME
# 16    | light                     | light                | light                | SAME
# 17    | years                     | year                 | year                 | SAME
# 18    | chief                     | chief                | chief                | SAME
# 19    | engineer                  | engin                | engin                | SAME
# 20    | dr                        | dr                   | dr                   | SAME
# 21    | elena                     | elena                | elena                | SAME
# 22    | vasquez                   | vasquez              | vasquez              | SAME
# 23    | ran                       | ran                  | ran                  | SAME
# 24    | final                     | final                | final                | SAME
# 25    | diagnostics               | diagnost             | diagnost             | SAME
# 26    | hyperdrive                | hyperdr              | hyperdr              | SAME
# 27    | status                    | statu                | status               | DIFFERENT
# 28    | online                    | onlin                | onlin                | SAME
# 29    | life                      | life                 | life                 | SAME
# 30    | support                   | support              | support              | SAME
# 31    | systems                   | system               | system               | SAME
# 32    | operational               | oper                 | oper                 | SAME
# 33    | quantum                   | quantum              | quantum              | SAME
# 34    | ai                        | ai                   | ai                   | SAME
# 35    | core                      | core                 | core                 | SAME
# 36    | activated                 | activ                | activ                | SAME
# 37    | launch                    | launch               | launch               | SAME
# 38    | sequence                  | sequenc              | sequenc              | SAME
# 39    | initiated                 | initi                | initi                | SAME
# 40    | announced                 | announc              | announc              | SAME
# 41    | commander                 | command              | command              | SAME
# 42    | james                     | jame                 | jame                 | SAME
# 43    | webb                      | webb                 | webb                 | SAME
# 44    | tminus                    | tminu                | tminus               | DIFFERENT
# 45    | suddenly                  | suddenli             | sudden               | DIFFERENT
# 46    | alarm                     | alarm                | alarm                | SAME
# 47    | blared                    | blare                | blare                | SAME
# 48    | error                     | error                | error                | SAME
# 49    | unidentified              | unidentifi           | unidentifi           | SAME
# 50    | signal                    | signal               | signal               | SAME
# 51    | detected                  | detect               | detect               | SAME
# 52    | sector                    | sector               | sector               | SAME
# 53    | gamma                     | gamma                | gamma                | SAME
# 54    | crew                      | crew                 | crew                 | SAME
# 55    | exchanged                 | exchang              | exchang              | SAME
# 56    | worried                   | worri                | worri                | SAME
# 57    | glances                   | glanc                | glanc                | SAME
# 58    | continued                 | continu              | continu              | SAME
#
# Total words with different stemming results: 3 out of 58
# Percentage of differences: 5.17%
#
# DETAILED COMPARISON FOR WORDS WITH DIFFERENT STEMMING RESULTS:
# #     | Original Word             | Porter Result        | Snowball Result      | Analysis
# 1     | status                    | statu                | status               | Porter shorter
# 2     | tminus                    | tminu                | tminus               | Porter shorter
# 3     | suddenly                  | suddenli             | sudden               | Snowball shorter
#
# COMPLETE PORTER STEMMED TEXT:
# year human final achiev interstellar travel starship odyssey prepar maiden voyag proxima centauri b distanc light year chief engin dr elena vasquez ran final diagnost hyperdr statu onlin life support system oper quantum ai core activ launch sequenc initi announc command jame webb tminu suddenli alarm blare error unidentifi signal detect sector gamma crew exchang worri glanc continu
#
# COMPLETE SNOWBALL STEMMED TEXT:
# year human final achiev interstellar travel starship odyssey prepar maiden voyag proxima centauri b distanc light year chief engin dr elena vasquez ran final diagnost hyperdr status onlin life support system oper quantum ai core activ launch sequenc initi announc command jame webb tminus sudden alarm blare error unidentifi signal detect sector gamma crew exchang worri glanc continu
#
# PERFORMANCE COMPARISON:
# PorterStemmer processing time (10 repetitions): 0.000000 seconds
# SnowballStemmer processing time (10 repetitions): 0.000000 seconds

# %% [markdown]
# # 7. Lemmatization (WordNetLemmatizer)

# %%
lemmatizer = WordNetLemmatizer()
lemmatized_tokens = [lemmatizer.lemmatize(word) for word in filtered_tokens]

print("COMPLETE COMPARISON (Original vs Lemmatized):")
print(f"{'#':<5} | {'Original Word':<25} | {'Lemmatized':<25}")
for i, (original, lemmatized) in enumerate(zip(filtered_tokens, lemmatized_tokens), 1):
    print(f"{i:<5} | {original:<25} | {lemmatized:<25}")

lemmatized_text = ' '.join(lemmatized_tokens)
print("\nCOMPLETE LEMMATIZED TEXT:")
print(lemmatized_text)

print("\nSTEMMING vs LEMMATIZATION COMPARISON:")
print(f"{'#':<5} | {'Original Word':<25} | {'Porter Stemmer':<20} | {'Snowball Stemmer':<20} | {'Lemmatized':<25}")
for i, (original, porter, snowball, lemmatized) in enumerate(zip(filtered_tokens, porter_stemmed_tokens, snowball_stemmed_tokens, lemmatized_tokens), 1):
    print(f"{i:<5} | {original:<25} | {porter:<20} | {snowball:<20} | {lemmatized:<25}")

# Performance comparison for Lemmatizer
print("\nPERFORMANCE COMPARISON (Lemmatizer vs Stemmers):")

# Test Lemmatizer speed
start_time = time.time()
for word in filtered_tokens * 10:
    lemmatizer.lemmatize(word)
lemmatizer_time = time.time() - start_time

print(f"WordNetLemmatizer processing time (10 repetitions): {lemmatizer_time:.6f} seconds")
print(f"PorterStemmer processing time (10 repetitions): {porter_time:.6f} seconds")
print(f"SnowballStemmer processing time (10 repetitions): {snowball_time:.6f} seconds")
# Out:
# COMPLETE COMPARISON (Original vs Lemmatized):
# #     | Original Word             | Lemmatized
# 1     | year                      | year
# 2     | humanity                  | humanity
# 3     | finally                   | finally
# 4     | achieved                  | achieved
# 5     | interstellar              | interstellar
# 6     | travel                    | travel
# 7     | starship                  | starship
# 8     | odyssey                   | odyssey
# 9     | preparing                 | preparing
# 10    | maiden                    | maiden
# 11    | voyage                    | voyage
# 12    | proxima                   | proxima
# 13    | centauri                  | centauri
# 14    | b                         | b
# 15    | distance                  | distance
# 16    | light                     | light
# 17    | years                     | year
# 18    | chief                     | chief
# 19    | engineer                  | engineer
# 20    | dr                        | dr
# 21    | elena                     | elena
# 22    | vasquez                   | vasquez
# 23    | ran                       | ran
# 24    | final                     | final
# 25    | diagnostics               | diagnostics
# 26    | hyperdrive                | hyperdrive
# 27    | status                    | status
# 28    | online                    | online
# 29    | life                      | life
# 30    | support                   | support
# 31    | systems                   | system
# 32    | operational               | operational
# 33    | quantum                   | quantum
# 34    | ai                        | ai
# 35    | core                      | core
# 36    | activated                 | activated
# 37    | launch                    | launch
# 38    | sequence                  | sequence
# 39    | initiated                 | initiated
# 40    | announced                 | announced
# 41    | commander                 | commander
# 42    | james                     | james
# 43    | webb                      | webb
# 44    | tminus                    | tminus
# 45    | suddenly                  | suddenly
# 46    | alarm                     | alarm
# 47    | blared                    | blared
# 48    | error                     | error
# 49    | unidentified              | unidentified
# 50    | signal                    | signal
# 51    | detected                  | detected
# 52    | sector                    | sector
# 53    | gamma                     | gamma
# 54    | crew                      | crew
# 55    | exchanged                 | exchanged
# 56    | worried                   | worried
# 57    | glances                   | glance
# 58    | continued                 | continued
#
# COMPLETE LEMMATIZED TEXT:
# year humanity finally achieved interstellar travel starship odyssey preparing maiden voyage proxima centauri b distance light year chief engineer dr elena vasquez ran final diagnostics hyperdrive status online life support system operational quantum ai core activated launch sequence initiated announced commander james webb tminus suddenly alarm blared error unidentified signal detected sector gamma crew exchanged worried glance continued
#
# STEMMING vs LEMMATIZATION COMPARISON:
# #     | Original Word             | Porter Stemmer       | Snowball Stemmer     | Lemmatized
# 1     | year                      | year                 | year                 | year
# 2     | humanity                  | human                | human                | humanity
# 3     | finally                   | final                | final                | finally
# 4     | achieved                  | achiev               | achiev               | achieved
# 5     | interstellar              | interstellar         | interstellar         | interstellar
# 6     | travel                    | travel               | travel               | travel
# 7     | starship                  | starship             | starship             | starship
# 8     | odyssey                   | odyssey              | odyssey              | odyssey
# 9     | preparing                 | prepar               | prepar               | preparing
# 10    | maiden                    | maiden               | maiden               | maiden
# 11    | voyage                    | voyag                | voyag                | voyage
# 12    | proxima                   | proxima              | proxima              | proxima
# 13    | centauri                  | centauri             | centauri             | centauri
# 14    | b                         | b                    | b                    | b
# 15    | distance                  | distanc              | distanc              | distance
# 16    | light                     | light                | light                | light
# 17    | years                     | year                 | year                 | year
# 18    | chief                     | chief                | chief                | chief
# 19    | engineer                  | engin                | engin                | engineer
# 20    | dr                        | dr                   | dr                   | dr
# 21    | elena                     | elena                | elena                | elena
# 22    | vasquez                   | vasquez              | vasquez              | vasquez
# 23    | ran                       | ran                  | ran                  | ran
# 24    | final                     | final                | final                | final
# 25    | diagnostics               | diagnost             | diagnost             | diagnostics
# 26    | hyperdrive                | hyperdr              | hyperdr              | hyperdrive
# 27    | status                    | statu                | status               | status
# 28    | online                    | onlin                | onlin                | online
# 29    | life                      | life                 | life                 | life
# 30    | support                   | support              | support              | support
# 31    | systems                   | system               | system               | system
# 32    | operational               | oper                 | oper                 | operational
# 33    | quantum                   | quantum              | quantum              | quantum
# 34    | ai                        | ai                   | ai                   | ai
# 35    | core                      | core                 | core                 | core
# 36    | activated                 | activ                | activ                | activated
# 37    | launch                    | launch               | launch               | launch
# 38    | sequence                  | sequenc              | sequenc              | sequence
# 39    | initiated                 | initi                | initi                | initiated
# 40    | announced                 | announc              | announc              | announced
# 41    | commander                 | command              | command              | commander
# 42    | james                     | jame                 | jame                 | james
# 43    | webb                      | webb                 | webb                 | webb
# 44    | tminus                    | tminu                | tminus               | tminus
# 45    | suddenly                  | suddenli             | sudden               | suddenly
# 46    | alarm                     | alarm                | alarm                | alarm
# 47    | blared                    | blare                | blare                | blared
# 48    | error                     | error                | error                | error
# 49    | unidentified              | unidentifi           | unidentifi           | unidentified
# 50    | signal                    | signal               | signal               | signal
# 51    | detected                  | detect               | detect               | detected
# 52    | sector                    | sector               | sector               | sector
# 53    | gamma                     | gamma                | gamma                | gamma
# 54    | crew                      | crew                 | crew                 | crew
# 55    | exchanged                 | exchang              | exchang              | exchanged
# 56    | worried                   | worri                | worri                | worried
# 57    | glances                   | glanc                | glanc                | glance
# 58    | continued                 | continu              | continu              | continued
#
# PERFORMANCE COMPARISON (Lemmatizer vs Stemmers):
# WordNetLemmatizer processing time (10 repetitions): 0.000000 seconds
# PorterStemmer processing time (10 repetitions): 0.000000 seconds
# SnowballStemmer processing time (10 repetitions): 0.000000 seconds

# %% [markdown]
# # 8. Part-of-Speech (POS) Tagging

# %%
# Cell 10: 8. POS Tagging (Part-of-Speech Tagging)
print("8. PART-OF-SPEECH (POS) TAGGING")

# Perform POS tagging on all filtered tokens
pos_tagged = pos_tag(filtered_tokens)

print("COMPLETE POS TAGGING RESULTS:")
print(f"{'#':<4} | {'Word':<20} | {'POS Tag':<10} | {'Description'}")

pos_descriptions = {
    'NN': 'Noun, singular', 'NNS': 'Noun, plural',
    'NNP': 'Proper noun, singular', 'NNPS': 'Proper noun, plural',
    'VB': 'Verb, base form', 'VBD': 'Verb, past tense',
    'VBG': 'Verb, gerund/present participle', 'VBN': 'Verb, past participle',
    'VBP': 'Verb, non-3rd person singular present', 'VBZ': 'Verb, 3rd person singular present',
    'JJ': 'Adjective', 'JJR': 'Adjective, comparative', 'JJS': 'Adjective, superlative',
    'RB': 'Adverb', 'RBR': 'Adverb, comparative', 'RBS': 'Adverb, superlative',
    'IN': 'Preposition/subordinating conjunction', 'DT': 'Determiner',
    'CC': 'Coordinating conjunction', 'PRP': 'Personal pronoun', 'PRP$': 'Possessive pronoun',
    'MD': 'Modal auxiliary', 'TO': 'to', 'UH': 'Interjection',
    'CD': 'Cardinal number', 'EX': 'Existential there', 'FW': 'Foreign word',
    'LS': 'List item marker', 'POS': 'Possessive ending', 'RP': 'Particle',
    'SYM': 'Symbol', 'WDT': 'Wh-determiner', 'WP': 'Wh-pronoun',
    'WP$': 'Possessive wh-pronoun', 'WRB': 'Wh-adverb'
}

for i, (word, tag) in enumerate(pos_tagged, 1):
    desc = pos_descriptions.get(tag, 'Other')
    print(f"{i:<4} | {word:<20} | {tag:<10} | {desc}")
# Out:
# 8. PART-OF-SPEECH (POS) TAGGING
# COMPLETE POS TAGGING RESULTS:
# #    | Word                 | POS Tag    | Description
# 1    | year                 | NN         | Noun, singular
# 2    | humanity             | NN         | Noun, singular
# 3    | finally              | RB         | Adverb
# 4    | achieved             | VBD        | Verb, past tense
# 5    | interstellar         | JJ         | Adjective
# 6    | travel               | NN         | Noun, singular
# 7    | starship             | NN         | Noun, singular
# 8    | odyssey              | IN         | Preposition/subordinating conjunction
# 9    | preparing            | VBG        | Verb, gerund/present participle
# 10   | maiden               | JJ         | Adjective
# 11   | voyage               | NN         | Noun, singular
# 12   | proxima              | NN         | Noun, singular
# 13   | centauri             | NN         | Noun, singular
# 14   | b                    | NN         | Noun, singular
# 15   | distance             | NN         | Noun, singular
# 16   | light                | JJ         | Adjective
# 17   | years                | NNS        | Noun, plural
# 18   | chief                | JJ         | Adjective
# 19   | engineer             | NN         | Noun, singular
# 20   | dr                   | NN         | Noun, singular
# 21   | elena                | NN         | Noun, singular
# 22   | vasquez              | NN         | Noun, singular
# 23   | ran                  | VBD        | Verb, past tense
# 24   | final                | JJ         | Adjective
# 25   | diagnostics          | NNS        | Noun, plural
# 26   | hyperdrive           | JJ         | Adjective
# 27   | status               | NN         | Noun, singular
# 28   | online               | JJ         | Adjective
# 29   | life                 | NN         | Noun, singular
# 30   | support              | NN         | Noun, singular
# 31   | systems              | NNS        | Noun, plural
# 32   | operational          | JJ         | Adjective
# 33   | quantum              | JJ         | Adjective
# 34   | ai                   | NN         | Noun, singular
# 35   | core                 | NN         | Noun, singular
# 36   | activated            | VBD        | Verb, past tense
# 37   | launch               | JJ         | Adjective
# 38   | sequence             | NN         | Noun, singular
# 39   | initiated            | VBD        | Verb, past tense
# 40   | announced            | JJ         | Adjective
# 41   | commander            | NN         | Noun, singular
# 42   | james                | NNS        | Noun, plural
# 43   | webb                 | VBP        | Verb, non-3rd person singular present
# 44   | tminus               | IN         | Preposition/subordinating conjunction
# 45   | suddenly             | RB         | Adverb
# 46   | alarm                | NN         | Noun, singular
# 47   | blared               | VBD        | Verb, past tense
# 48   | error                | RB         | Adverb
# 49   | unidentified         | JJ         | Adjective
# 50   | signal               | NN         | Noun, singular
# 51   | detected             | VBD        | Verb, past tense
# 52   | sector               | NN         | Noun, singular
# 53   | gamma                | NN         | Noun, singular
# 54   | crew                 | VBD        | Verb, past tense
# 55   | exchanged            | VBN        | Verb, past participle
# 56   | worried              | JJ         | Adjective
# 57   | glances              | NNS        | Noun, plural
# 58   | continued            | VBD        | Verb, past tense

# %% [markdown]
# # 9. Chunking

# %%
# Define chunk grammar
chunk_grammar = r"""
    NP: {<DT>?<JJ>*<NN.*>+}
    NP: {<NNP>+}
    NP: {<NNP><POS>?<NNP>*}
    VP: {<VB.*><NP|PP|CLAUSE>+$}
    PP: {<IN><NP>}
"""
chunk_parser = RegexpParser(chunk_grammar)

# Process ALL sentences for chunking
all_sentences = sent_tokenize(text_lower)

for sent_idx, sentence in enumerate(all_sentences, 1):
    print(f"\nSentence {sent_idx}: {sentence}")

    # Tokenize and tag
    tokens = word_tokenize(sentence)
    pos_tags = pos_tag(tokens)

    # Parse chunks
    chunk_tree = chunk_parser.parse(pos_tags)

    print("Chunk Tree Structure:")
    print(chunk_tree)

    print("Chunks extracted:")
    for subtree in chunk_tree.subtrees():
        if subtree.label() in ['NP', 'VP', 'PP']:
            chunk_words = ' '.join(word for word, tag in subtree.leaves())
            print(f"  {subtree.label()}: {chunk_words}")
# Out:
# Sentence 1: in the year , humanity had finally achieved interstellar travel.
# Chunk Tree Structure:
# (S
#   (PP in/IN (NP the/DT year/NN))
#   ,/,
#   (NP humanity/NN)
#   had/VBD
#   finally/RB
#   achieved/VBN
#   (NP interstellar/JJ travel/NN)
#   ./.)
# Chunks extracted:
#   PP: in the year
#   NP: the year
#   NP: humanity
#   NP: interstellar travel
#
# Sentence 2: the starship odyssey was preparing for its maiden voyage to proxima centauri b distance .
# Chunk Tree Structure:
# (S
#   (NP the/DT starship/NN odyssey/NN)
#   was/VBD
#   preparing/VBG
#   for/IN
#   its/PRP$
#   (NP maiden/JJ voyage/NN)
#   to/TO
#   proxima/VB
#   (NP centauri/NN b/NN distance/NN)
#   ./.)
# Chunks extracted:
#   NP: the starship odyssey
#   NP: maiden voyage
#   NP: centauri b distance
#
# Sentence 3: light years.
# Chunk Tree Structure:
# (S (NP light/JJ years/NNS) ./.)
# Chunks extracted:
#   NP: light years
#
# Sentence 4: chief engineer dr. elena vasquez ran the final diagnostics  hyperdrive status online   life support systems operational   quantum ai core activated  launch sequence initiated, announced commander james webb.
# Chunk Tree Structure:
# (S
#   (NP chief/JJ engineer/NN dr./NN elena/NN vasquez/NN)
#   ran/VBD
#   (NP the/DT final/JJ diagnostics/NNS)
#   (NP hyperdrive/JJ status/NN)
#   (NP online/JJ life/NN support/NN systems/NNS)
#   (NP operational/JJ quantum/JJ ai/NN core/NN)
#   activated/VBD
#   (NP launch/JJ sequence/NN)
#   initiated/VBN
#   ,/,
#   announced/VBD
#   (NP commander/NN james/NNS)
#   webb/VBP
#   ./.)
# Chunks extracted:
#   NP: chief engineer dr. elena vasquez
#   NP: the final diagnostics
#   NP: hyperdrive status
#   NP: online life support systems
#   NP: operational quantum ai core
#   NP: launch sequence
#   NP: commander james
#
# Sentence 5: tminus ... ... ... suddenly, an alarm blared error unidentified signal detected from sector gamma the crew exchanged worried glances.
# Chunk Tree Structure:
# (S
#   (NP tminus/NN)
#   .../:
#   .../:
#   .../:
#   suddenly/RB
#   ,/,
#   (NP an/DT alarm/NN)
#   blared/VBD
#   error/RB
#   (NP unidentified/JJ signal/NN)
#   detected/VBN
#   (PP from/IN (NP sector/NN))
#   gamma/VBD
#   (NP the/DT crew/NN)
#   exchanged/VBD
#   (NP worried/JJ glances/NNS)
#   ./.)
# Chunks extracted:
#   NP: tminus
#   NP: an alarm
#   NP: unidentified signal
#   PP: from sector
#   NP: sector
#   NP: the crew
#   NP: worried glances
#
# Sentence 6: what was out there  to be continued...
# Chunk Tree Structure:
# (S what/WDT was/VBD out/RB there/RB to/TO be/VB continued/VBN .../:)
# Chunks extracted:

# %% [markdown]
# # 10. Parsing ( Dependency Parsing and Tree Structure Parsing )

# %%
# Process entire text with spaCy
doc = nlp(text_lower)

print("DEPENDENCY RELATIONS FOR ENTIRE TEXT:")

for token in doc:
    print(f"Word: '{token.text}'")
    print(f"  Head word: '{token.head.text}'")
    print(f"  Dependency relation: {token.dep_}")
    print(f"  Explanation: {spacy.explain(token.dep_)}")
    print(f"  Children: {[child.text for child in token.children]}")
# Out:
# DEPENDENCY RELATIONS FOR ENTIRE TEXT:
# Word: 'in'
#   Head word: 'achieved'
#   Dependency relation: prep
#   Explanation: prepositional modifier
#   Children: ['year']
# Word: 'the'
#   Head word: 'year'
#   Dependency relation: det
#   Explanation: determiner
#   Children: []
# Word: 'year'
#   Head word: 'in'
#   Dependency relation: pobj
#   Explanation: object of preposition
#   Children: ['the']
# Word: ','
#   Head word: 'achieved'
#   Dependency relation: punct
#   Explanation: punctuation
#   Children: []
# Word: 'humanity'
#   Head word: 'achieved'
#   Dependency relation: nsubj
#   Explanation: nominal subject
#   Children: []
# Word: 'had'
#   Head word: 'achieved'
#   Dependency relation: aux
#   Explanation: auxiliary
#   Children: []
# Word: 'finally'
#   Head word: 'achieved'
#   Dependency relation: advmod
#   Explanation: adverbial modifier
#   Children: []
# Word: 'achieved'
#   Head word: 'achieved'
#   Dependency relation: ROOT
#   Explanation: root
#   Children: ['in', ',', 'humanity', 'had', 'finally', 'travel', '.']
# Word: 'interstellar'
#   Head word: 'travel'
#   Dependency relation: amod
#   Explanation: adjectival modifier
#   Children: []
# Word: 'travel'
#   Head word: 'achieved'
#   Dependency relation: dobj
#   Explanation: direct object
#   Children: ['interstellar']
# Word: '.'
#   Head word: 'achieved'
#   Dependency relation: punct
#   Explanation: punctuation
#   Children: []
# Word: 'the'
#   Head word: 'odyssey'
#   Dependency relation: det
#   Explanation: determiner
#   Children: []
# Word: 'starship'
#   Head word: 'odyssey'
#   Dependency relation: compound
#   Explanation: compound
#   Children: []
# Word: 'odyssey'
#   Head word: 'preparing'
#   Dependency relation: nsubj
#   Explanation: nominal subject
#   Children: ['the', 'starship']
# Word: 'was'
#   Head word: 'preparing'
#   Dependency relation: aux
#   Explanation: auxiliary
#   Children: []
# Word: 'preparing'
#   Head word: 'preparing'
#   Dependency relation: ROOT
#   Explanation: root
#   Children: ['odyssey', 'was', 'for', 'to', '.']
# Word: 'for'
#   Head word: 'preparing'
#   Dependency relation: prep
#   Explanation: prepositional modifier
#   Children: ['voyage']
# Word: 'its'
#   Head word: 'voyage'
#   Dependency relation: poss
#   Explanation: possession modifier
#   Children: []
# Word: 'maiden'
#   Head word: 'voyage'
#   Dependency relation: amod
#   Explanation: adjectival modifier
#   Children: []
# Word: 'voyage'
#   Head word: 'for'
#   Dependency relation: pobj
#   Explanation: object of preposition
#   Children: ['its', 'maiden']
# Word: 'to'
#   Head word: 'preparing'
#   Dependency relation: prep
#   Explanation: prepositional modifier
#   Children: ['centauri', 'distance']
# Word: 'proxima'
#   Head word: 'centauri'
#   Dependency relation: compound
#   Explanation: compound
#   Children: []
# Word: 'centauri'
#   Head word: 'to'
#   Dependency relation: pobj
#   Explanation: object of preposition
#   Children: ['proxima']
# Word: 'b'
#   Head word: 'distance'
#   Dependency relation: compound
#   Explanation: compound
#   Children: []
# Word: 'distance'
#   Head word: 'to'
#   Dependency relation: pobj
#   Explanation: object of preposition
#   Children: ['b']
# Word: '.'
#   Head word: 'preparing'
#   Dependency relation: punct
#   Explanation: punctuation
#   Children: []
# Word: 'light'
#   Head word: 'years'
#   Dependency relation: amod
#   Explanation: adjectival modifier
#   Children: []
# Word: 'years'
#   Head word: 'years'
#   Dependency relation: ROOT
#   Explanation: root
#   Children: ['light', '.']
# Word: '.'
#   Head word: 'years'
#   Dependency relation: punct
#   Explanation: punctuation
#   Children: []
# Word: 'chief'
#   Head word: 'engineer'
#   Dependency relation: amod
#   Explanation: adjectival modifier
#   Children: []
# Word: 'engineer'
#   Head word: 'dr'
#   Dependency relation: compound
#   Explanation: compound
#   Children: ['chief']
# Word: 'dr'
#   Head word: 'vasquez'
#   Dependency relation: compound
#   Explanation: compound
#   Children: ['engineer']
# Word: '.'
#   Head word: 'vasquez'
#   Dependency relation: compound
#   Explanation: compound
#   Children: []
# Word: 'elena'
#   Head word: 'vasquez'
#   Dependency relation: compound
#   Explanation: compound
#   Children: []
# Word: 'vasquez'
#   Head word: 'ran'
#   Dependency relation: nsubj
#   Explanation: nominal subject
#   Children: ['dr', '.', 'elena']
# Word: 'ran'
#   Head word: 'ran'
#   Dependency relation: ROOT
#   Explanation: root
#   Children: ['vasquez', 'quantum', 'activated', 'announced', '.']
# Word: 'the'
#   Head word: 'diagnostics'
#   Dependency relation: det
#   Explanation: determiner
#   Children: []
# Word: 'final'
#   Head word: 'diagnostics'
#   Dependency relation: amod
#   Explanation: adjectival modifier
#   Children: []
# Word: 'diagnostics'
#   Head word: 'systems'
#   Dependency relation: nmod
#   Explanation: modifier of nominal
#   Children: ['the', 'final', ' ']
# Word: ' '
#   Head word: 'diagnostics'
#   Dependency relation: dep
#   Explanation: unclassified dependent
#   Children: []
# Word: 'hyperdrive'
#   Head word: 'status'
#   Dependency relation: amod
#   Explanation: adjectival modifier
#   Children: []
# Word: 'status'
#   Head word: 'systems'
#   Dependency relation: nmod
#   Explanation: modifier of nominal
#   Children: ['hyperdrive']
# Word: 'online'
#   Head word: 'life'
#   Dependency relation: amod
#   Explanation: adjectival modifier
#   Children: ['  ']
# Word: '  '
#   Head word: 'online'
#   Dependency relation: dep
#   Explanation: unclassified dependent
#   Children: []
# Word: 'life'
#   Head word: 'support'
#   Dependency relation: compound
#   Explanation: compound
#   Children: ['online']
# Word: 'support'
#   Head word: 'systems'
#   Dependency relation: compound
#   Explanation: compound
#   Children: ['life']
# Word: 'systems'
#   Head word: 'quantum'
#   Dependency relation: nmod
#   Explanation: modifier of nominal
#   Children: ['diagnostics', 'status', 'support']
# Word: 'operational'
#   Head word: 'quantum'
#   Dependency relation: amod
#   Explanation: adjectival modifier
#   Children: ['  ']
# Word: '  '
#   Head word: 'operational'
#   Dependency relation: dep
#   Explanation: unclassified dependent
#   Children: []
# Word: 'quantum'
#   Head word: 'ran'
#   Dependency relation: dobj
#   Explanation: direct object
#   Children: ['systems', 'operational']
# Word: 'ai'
#   Head word: 'activated'
#   Dependency relation: auxpass
#   Explanation: auxiliary (passive)
#   Children: []
# Word: 'core'
#   Head word: 'activated'
#   Dependency relation: nsubj
#   Explanation: nominal subject
#   Children: []
# Word: 'activated'
#   Head word: 'ran'
#   Dependency relation: conj
#   Explanation: conjunct
#   Children: ['ai', 'core', ' ', 'sequence', 'initiated', ',']
# Word: ' '
#   Head word: 'activated'
#   Dependency relation: dep
#   Explanation: unclassified dependent
#   Children: []
# Word: 'launch'
#   Head word: 'sequence'
#   Dependency relation: compound
#   Explanation: compound
#   Children: []
# Word: 'sequence'
#   Head word: 'activated'
#   Dependency relation: dobj
#   Explanation: direct object
#   Children: ['launch']
# Word: 'initiated'
#   Head word: 'activated'
#   Dependency relation: advcl
#   Explanation: adverbial clause modifier
#   Children: []
# Word: ','
#   Head word: 'activated'
#   Dependency relation: punct
#   Explanation: punctuation
#   Children: []
# Word: 'announced'
#   Head word: 'ran'
#   Dependency relation: conj
#   Explanation: conjunct
#   Children: ['webb']
# Word: 'commander'
#   Head word: 'webb'
#   Dependency relation: compound
#   Explanation: compound
#   Children: []
# Word: 'james'
#   Head word: 'webb'
#   Dependency relation: compound
#   Explanation: compound
#   Children: []
# Word: 'webb'
#   Head word: 'announced'
#   Dependency relation: dobj
#   Explanation: direct object
#   Children: ['commander', 'james']
# Word: '.'
#   Head word: 'ran'
#   Dependency relation: punct
#   Explanation: punctuation
#   Children: []
# Word: 'tminus'
#   Head word: 'tminus'
#   Dependency relation: ROOT
#   Explanation: root
#   Children: ['...', '...', '...']
# Word: '...'
#   Head word: 'tminus'
#   Dependency relation: punct
#   Explanation: punctuation
#   Children: []
# Word: '...'
#   Head word: 'tminus'
#   Dependency relation: punct
#   Explanation: punctuation
#   Children: []
# Word: '...'
#   Head word: 'tminus'
#   Dependency relation: punct
#   Explanation: punctuation
#   Children: []
# Word: 'suddenly'
#   Head word: 'exchanged'
#   Dependency relation: advmod
#   Explanation: adverbial modifier
#   Children: []
# Word: ','
#   Head word: 'exchanged'
#   Dependency relation: punct
#   Explanation: punctuation
#   Children: []
# Word: 'an'
#   Head word: 'error'
#   Dependency relation: det
#   Explanation: determiner
#   Children: []
# Word: 'alarm'
#   Head word: 'error'
#   Dependency relation: nmod
#   Explanation: modifier of nominal
#   Children: []
# Word: 'blared'
#   Head word: 'error'
#   Dependency relation: amod
#   Explanation: adjectival modifier
#   Children: []
# Word: 'error'
#   Head word: 'signal'
#   Dependency relation: nmod
#   Explanation: modifier of nominal
#   Children: ['an', 'alarm', 'blared']
# Word: 'unidentified'
#   Head word: 'signal'
#   Dependency relation: amod
#   Explanation: adjectival modifier
#   Children: []
# Word: 'signal'
#   Head word: 'exchanged'
#   Dependency relation: nsubj
#   Explanation: nominal subject
#   Children: ['error', 'unidentified', 'detected']
# Word: 'detected'
#   Head word: 'signal'
#   Dependency relation: acl
#   Explanation: clausal modifier of noun (adjectival clause)
#   Children: ['from']
# Word: 'from'
#   Head word: 'detected'
#   Dependency relation: prep
#   Explanation: prepositional modifier
#   Children: ['gamma']
# Word: 'sector'
#   Head word: 'gamma'
#   Dependency relation: compound
#   Explanation: compound
#   Children: []
# Word: 'gamma'
#   Head word: 'from'
#   Dependency relation: pobj
#   Explanation: object of preposition
#   Children: ['sector']
# Word: 'the'
#   Head word: 'crew'
#   Dependency relation: det
#   Explanation: determiner
#   Children: []
# Word: 'crew'
#   Head word: 'exchanged'
#   Dependency relation: nsubj
#   Explanation: nominal subject
#   Children: ['the']
# Word: 'exchanged'
#   Head word: 'exchanged'
#   Dependency relation: ROOT
#   Explanation: root
#   Children: ['suddenly', ',', 'signal', 'crew', 'glances', '.']
# Word: 'worried'
#   Head word: 'glances'
#   Dependency relation: amod
#   Explanation: adjectival modifier
#   Children: []
# Word: 'glances'
#   Head word: 'exchanged'
#   Dependency relation: dobj
#   Explanation: direct object
#   Children: ['worried']
# Word: '.'
#   Head word: 'exchanged'
#   Dependency relation: punct
#   Explanation: punctuation
#   Children: []
# Word: 'what'
#   Head word: 'was'
#   Dependency relation: nsubj
#   Explanation: nominal subject
#   Children: []
# Word: 'was'
#   Head word: 'was'
#   Dependency relation: ROOT
#   Explanation: root
#   Children: ['what', 'there', 'continued', '...']
# Word: 'out'
#   Head word: 'there'
#   Dependency relation: advmod
#   Explanation: adverbial modifier
#   Children: []
# Word: 'there'
#   Head word: 'was'
#   Dependency relation: advmod
#   Explanation: adverbial modifier
#   Children: ['out', ' ']
# Word: ' '
#   Head word: 'there'
#   Dependency relation: dep
#   Explanation: unclassified dependent
#   Children: []
# Word: 'to'
#   Head word: 'continued'
#   Dependency relation: aux
#   Explanation: auxiliary
#   Children: []
# Word: 'be'
#   Head word: 'continued'
#   Dependency relation: auxpass
#   Explanation: auxiliary (passive)
#   Children: []
# Word: 'continued'
#   Head word: 'was'
#   Dependency relation: advcl
#   Explanation: adverbial clause modifier
#   Children: ['to', 'be']
# Word: '...'
#   Head word: 'was'
#   Dependency relation: punct
#   Explanation: punctuation
#   Children: []

# %%
all_sentences = sent_tokenize(text_lower)

for sent_idx, sentence in enumerate(all_sentences, 1):
    print(f"\nSentence {sent_idx}: {sentence}")

    # Tokenize and tag
    tokens = word_tokenize(sentence)
    pos_tags = pos_tag(tokens)

    # Create a simple binary tree structure for visualization
    def create_simple_tree(tokens, pos_tags):
        """Create a simple constituency-like tree structure"""
        if len(tokens) == 1:
            return Tree(pos_tags[0][1], [tokens[0]])
        else:
            mid = len(tokens) // 2
            left_tree = create_simple_tree(tokens[:mid], pos_tags[:mid])
            right_tree = create_simple_tree(tokens[mid:], pos_tags[mid:])
            return Tree('S', [left_tree, right_tree])

    try:
        constituency_tree = create_simple_tree(tokens, pos_tags)
        print("Constituency Tree:")
        constituency_tree.pretty_print()

        print("Tree in bracketed notation:")
        print(constituency_tree)
    except Exception as e:
        print(f"Error creating tree: {e}")

print("\nALTERNATIVE TREE VISUALIZATION (ALL SENTENCES - Detailed NP chunks):")

# More detailed tree structure for ALL sentences
for sent_idx, sentence in enumerate(all_sentences, 1):
    print(f"\nSentence {sent_idx}: {sentence}")

    tokens = word_tokenize(sentence)
    pos_tags = pos_tag(tokens)

    # Manual tree building
    tree = Tree('S', [])
    current_np = []

    for word, tag in pos_tags:
        if tag.startswith('NN') or tag.startswith('JJ') or tag == 'DT':
            current_np.append((word, tag))
        else:
            if current_np:
                np_tree = Tree('NP', [f"{w}/{t}" for w, t in current_np])
                tree.append(np_tree)
                current_np = []
            tree.append(f"{word}/{tag}")

    if current_np:
        np_tree = Tree('NP', [f"{w}/{t}" for w, t in current_np])
        tree.append(np_tree)

    print("Detailed Constituency Tree (NP chunks):")
    tree.pretty_print()
    print("\nTree as string:")
    print(tree)
# Out:
# Sentence 1: in the year , humanity had finally achieved interstellar travel.
# Constituency Tree:
#                                    S
#               _____________________|_________________
#              S                                       S
#       _______|____                        ___________|____________________
#      |            S                      S                                S
#      |        ____|___              _____|_____                  _________|_____
#      S       |        S            |           S                |               S
#   ___|___    |     ___|_____       |      _____|_____           |          _____|___
#  IN      DT  NN   ,         NN    VBD    RB         VBN         JJ        NN        .
#  |       |   |    |         |      |     |           |          |         |         |
#  in     the year  ,      humanity had finally     achieved interstellar travel      .
#
# Tree in bracketed notation:
# (S
#   (S (S (IN in) (DT the)) (S (NN year) (S (, ,) (NN humanity))))
#   (S
#     (S (VBD had) (S (RB finally) (VBN achieved)))
#     (S (JJ interstellar) (S (NN travel) (. .)))))
#
# Sentence 2: the starship odyssey was preparing for its maiden voyage to proxima centauri b distance .
# Constituency Tree:
#                                                               S
#                            ___________________________________|______________________________
#                           S                                                                  S
#         __________________|_________________                                    _____________|______________________
#        S                                    S                                  S                                    S
#   _____|______                 _____________|_______                 __________|_______                      _______|____________
#  |            S               S                     S               S                  S                    S                    S
#  |      ______|_____       ___|______            ___|___       _____|____           ___|_____         ______|___           ______|___
#  DT    NN           NN   VBD        VBG         IN     PRP$   JJ         NN        TO        VB      NN         NN        NN         .
#  |     |            |     |          |          |       |     |          |         |         |       |          |         |          |
# the starship     odyssey was     preparing     for     its  maiden     voyage      to     proxima centauri      b      distance      .
#
# Tree in bracketed notation:
# (S
#   (S
#     (S (DT the) (S (NN starship) (NN odyssey)))
#     (S (S (VBD was) (VBG preparing)) (S (IN for) (PRP$ its))))
#   (S
#     (S (S (JJ maiden) (NN voyage)) (S (TO to) (VB proxima)))
#     (S (S (NN centauri) (NN b)) (S (NN distance) (. .)))))
#
# Sentence 3: light years.
# Constituency Tree:
#         S
#    _____|____
#   |          S
#   |      ____|___
#   JJ   NNS       .
#   |     |        |
# light years      .
#
# Tree in bracketed notation:
# (S (JJ light) (S (NNS years) (. .)))
#
# Sentence 4: chief engineer dr. elena vasquez ran the final diagnostics  hyperdrive status online   life support systems operational   quantum ai core activated  launch sequence initiated, announced commander james webb.
# Constituency Tree:
#                                                                                                                                     S
#                                                        _____________________________________________________________________________|_____________________________________________________________________
#                                                       S                                                                                                                                                   S
#                           ____________________________|_____________________________________                                                                       _______________________________________|___________________________________
#                          S                                                                  S                                                                     S                                                                           S
#           _______________|________________                           _______________________|________________                                  ___________________|____________                                                 ______________|__________________________
#          S                                S                         S                                        S                                S                                S                                               S                                         S
#    ______|______               ___________|_______          ________|_______                       __________|________               _________|_______                 ________|_____________                     _____________|_______                         _________|________
#   |             S             S                   S        |                S                     S                   S             |                 S               S                      S                   S                     S                       S                  S
#   |       ______|___      ____|_____           ___|___     |         _______|______          _____|____           ____|_____        |          _______|_____       ___|___             ______|____         ______|______            ___|______           ______|____          ____|___
#   JJ     NN         NN   NN         NN       VBD      DT   JJ      NNS             JJ       NN         JJ        NN         NN     NNS        JJ            JJ    NN      NN         VBD          JJ      NN           VBN         ,         VBD        NN         NNS      VBP       .
#   |      |          |    |          |         |       |    |        |              |        |          |         |          |       |         |             |     |       |           |           |       |             |          |          |         |           |        |        |
# chief engineer     dr. elena     vasquez     ran     the final diagnostics     hyperdrive status     online     life     support systems operational     quantum  ai     core     activated     launch sequence     initiated      ,      announced commander     james     webb      .
#
# Tree in bracketed notation:
# (S
#   (S
#     (S
#       (S (JJ chief) (S (NN engineer) (NN dr.)))
#       (S (S (NN elena) (NN vasquez)) (S (VBD ran) (DT the))))
#     (S
#       (S (JJ final) (S (NNS diagnostics) (JJ hyperdrive)))
#       (S (S (NN status) (JJ online)) (S (NN life) (NN support)))))
#   (S
#     (S
#       (S (NNS systems) (S (JJ operational) (JJ quantum)))
#       (S (S (NN ai) (NN core)) (S (VBD activated) (JJ launch))))
#     (S
#       (S (S (NN sequence) (VBN initiated)) (S (, ,) (VBD announced)))
#       (S (S (NN commander) (NNS james)) (S (VBP webb) (. .))))))
#
# Sentence 5: tminus ... ... ... suddenly, an alarm blared error unidentified signal detected from sector gamma the crew exchanged worried glances.
# Constituency Tree:
#                                                                             S
#                                       ______________________________________|__________________________________________________
#                                      S                                                                                         S
#                  ____________________|____________                                                        _____________________|_______________
#                 S                                 S                                                      S                                     S
#          _______|___                      ________|____________                              ____________|_____                     ___________|________________
#         |           S                    S                     S                            |                  S                   S                            S
#         |        ___|___              ___|___            ______|____                        |             _____|_____           ___|____                 _______|_____
#         S       |       S            |       S          |           S                       S            |           S         |        S               |             S
#    _____|___    |    ___|_____       |    ___|____      |       ____|_______           _____|_____       |      _____|____     |    ____|______         |        _____|___
#   NN        :   :   :         RB     ,   DT       NN   VBD     RB           JJ        NN         VBN     IN    NN        VBD   DT  NN         VBD       JJ     NNS        .
#   |         |   |   |         |      |   |        |     |      |            |         |           |      |     |          |    |   |           |        |       |         |
# tminus     ... ... ...     suddenly  ,   an     alarm blared error     unidentified signal     detected from sector     gamma the crew     exchanged worried glances      .
#
# Tree in bracketed notation:
# (S
#   (S
#     (S (S (NN tminus) (: ...)) (S (: ...) (S (: ...) (RB suddenly))))
#     (S
#       (S (, ,) (S (DT an) (NN alarm)))
#       (S (VBD blared) (S (RB error) (JJ unidentified)))))
#   (S
#     (S
#       (S (NN signal) (VBN detected))
#       (S (IN from) (S (NN sector) (VBD gamma))))
#     (S
#       (S (DT the) (S (NN crew) (VBD exchanged)))
#       (S (JJ worried) (S (NNS glances) (. .))))))
#
# Sentence 6: what was out there  to be continued...
# Constituency Tree:
#                            S
#                ____________|________________
#               S                             S
#        _______|_______               _______|_____________
#       S               S             S                     S
#   ____|___         ___|____      ___|___            ______|___
# WDT      VBD      RB       RB   TO      VB        VBN         :
#  |        |       |        |    |       |          |          |
# what     was     out     there  to      be     continued     ...
#
# Tree in bracketed notation:
# (S
#   (S (S (WDT what) (VBD was)) (S (RB out) (RB there)))
#   (S (S (TO to) (VB be)) (S (VBN continued) (: ...))))
#
# ALTERNATIVE TREE VISUALIZATION (ALL SENTENCES - Detailed NP chunks):
#
# Sentence 1: in the year , humanity had finally achieved interstellar travel.
# Detailed Constituency Tree (NP chunks):
#                                            S
#    ________________________________________|__________________________________________________
#   |    |     |        |           |        |          NP              NP                      NP
#   |    |     |        |           |        |     _____|_____          |              _________|______
# in/IN ,/, had/VBD finally/RB achieved/VBN ./. the/DT     year/NN humanity/NN interstellar/JJ     travel/NN
#
#
# Tree as string:
# (S
#   in/IN
#   (NP the/DT year/NN)
#   ,/,
#   (NP humanity/NN)
#   had/VBD
#   finally/RB
#   achieved/VBN
#   (NP interstellar/JJ travel/NN)
#   ./.)
#
# Sentence 2: the starship odyssey was preparing for its maiden voyage to proxima centauri b distance .
# Detailed Constituency Tree (NP chunks):
#                                                              S
#     _________________________________________________________|________________________________________________________________
#    |          |         |       |       |       |       |              NP                           NP                        NP
#    |          |         |       |       |       |       |     _________|__________            ______|______            _______|________
# was/VBD preparing/VBG for/IN its/PRP$ to/TO proxima/VB ./. the/DT starship/NN odyssey/NN maiden/JJ     voyage/NN centauri/NN b/NN distance/NN
#
#
# Tree as string:
# (S
#   (NP the/DT starship/NN odyssey/NN)
#   was/VBD
#   preparing/VBG
#   for/IN
#   its/PRP$
#   (NP maiden/JJ voyage/NN)
#   to/TO
#   proxima/VB
#   (NP centauri/NN b/NN distance/NN)
#   ./.)
#
# Sentence 3: light years.
# Detailed Constituency Tree (NP chunks):
#        S
#   _____|______
#  |            NP
#  |      ______|______
# ./. light/JJ     years/NNS
#
#
# Tree as string:
# (S (NP light/JJ years/NNS) ./.)
#
# Sentence 4: chief engineer dr. elena vasquez ran the final diagnostics  hyperdrive status online   life support systems operational   quantum ai core activated  launch sequence initiated, announced commander james webb.
# Detailed Constituency Tree (NP chunks):
#                                                                                                                                           S
#     ______________________________________________________________________________________________________________________________________|_________________________________________________________________________________________________________________________________________________________
#    |          |             |        |        |          |      |                         NP                                                                                            NP                                                                             NP                           NP
#    |          |             |        |        |          |      |      ___________________|_________________          __________________________________________________________________|______________________________________________________________          ______|_______             ________|______
# ran/VBD activated/VBD initiated/VBN ,/, announced/VBD webb/VBP ./. chief/JJ engineer/NN dr./NN elena/NN vasquez/NN the/DT final/JJ diagnostics/NNS hyperdrive/JJ status/NN online/JJ life/NN support/NN systems/NNS operational/JJ quantum/JJ ai/NN core/NN launch/JJ     sequence/NN commander/NN     james/NNS
#
#
# Tree as string:
# (S
#   (NP chief/JJ engineer/NN dr./NN elena/NN vasquez/NN)
#   ran/VBD
#   (NP
#     the/DT
#     final/JJ
#     diagnostics/NNS
#     hyperdrive/JJ
#     status/NN
#     online/JJ
#     life/NN
#     support/NN
#     systems/NNS
#     operational/JJ
#     quantum/JJ
#     ai/NN
#     core/NN)
#   activated/VBD
#   (NP launch/JJ sequence/NN)
#   initiated/VBN
#   ,/,
#   announced/VBD
#   (NP commander/NN james/NNS)
#   webb/VBP
#   ./.)
#
# Sentence 5: tminus ... ... ... suddenly, an alarm blared error unidentified signal detected from sector gamma the crew exchanged worried glances.
# Detailed Constituency Tree (NP chunks):
#                                                                                            S
#    ________________________________________________________________________________________|_______________________________________________________________________________________________________________
#   |     |     |        |       |      |         |          |          |        |           |        |      NP           NP                           NP               NP            NP                     NP
#   |     |     |        |       |      |         |          |          |        |           |        |      |        ____|_____              _________|______          |        _____|_____          _______|_______
# .../: .../: .../: suddenly/RB ,/, blared/VBD error/RB detected/VBN from/IN gamma/VBD exchanged/VBD ./. tminus/NN an/DT     alarm/NN unidentified/JJ     signal/NN sector/NN the/DT     crew/NN worried/JJ     glances/NNS
#
#
# Tree as string:
# (S
#   (NP tminus/NN)
#   .../:
#   .../:
#   .../:
#   suddenly/RB
#   ,/,
#   (NP an/DT alarm/NN)
#   blared/VBD
#   error/RB
#   (NP unidentified/JJ signal/NN)
#   detected/VBN
#   from/IN
#   (NP sector/NN)
#   gamma/VBD
#   (NP the/DT crew/NN)
#   exchanged/VBD
#   (NP worried/JJ glances/NNS)
#   ./.)
#
# Sentence 6: what was out there  to be continued...
# Detailed Constituency Tree (NP chunks):
#                            S
#     _______________________|_________________________________
# what/WDT was/VBD out/RB there/RB to/TO be/VB continued/VBN .../:
#
#
# Tree as string:
# (S what/WDT was/VBD out/RB there/RB to/TO be/VB continued/VBN .../:)

# %% [markdown]
# # 11. Hypernyms and Hyponyms (WordNet)

# %%
# Extract ALL unique words from filtered tokens
unique_words = list(set(filtered_tokens))

for word in unique_words:
    print(f"\nWORD: '{word}'")

    # Get synsets for the word
    synsets = wn.synsets(word)

    if not synsets:
        print(f"  No synsets found for '{word}'")
        continue

    # Take first synset
    synset = synsets[0]
    print(f"  Definition: {synset.definition()}")
    print(f"  Example: {synset.examples() if synset.examples() else 'No example'}")

    # Hypernyms (more general concepts)
    hypernyms = synset.hypernyms()
    if hypernyms:
        print(f"\n  HYPERNYMS (more general): {len(hypernyms)} found")
        for hyp in hypernyms:
            print(f"    → {hyp.name()}")
            print(f"      Definition: {hyp.definition()}")
            # Get path hypernyms (higher level)
            hyper_paths = hyp.hypernyms()
            if hyper_paths:
                for path_hyp in hyper_paths:
                    print(f"        ↑ {path_hyp.name()}: {path_hyp.definition()}")
    else:
        print(f"\n  HYPERNYMS: None found")

    # Hyponyms (more specific concepts)
    hyponyms = synset.hyponyms()
    if hyponyms:
        print(f"\n  HYPONYMS (more specific): {len(hyponyms)} found")
        for hyp in hyponyms:
            print(f"    → {hyp.name()}")
            print(f"      Definition: {hyp.definition()}")
    else:
        print(f"\n  HYPONYMS: None found")

    # Full hierarchy path (no depth limit)
    print(f"\n  HIERARCHY PATH (up to root):")
    def show_path(s, level=0):
        print(f"    {'  ' * level}└─ {s.name()}")
        for hyp in s.hypernyms():
            show_path(hyp, level + 1)

    show_path(synset)

# Detailed example for ALL specific words from the text
print("\nDETAILED EXAMPLE FOR KEY WORDS FROM TEXT")

key_words = ['apple', 'computer', 'company', 'inventor', 'founder', 'ceo', 'pixar', 'next']

for word in key_words:
    print(f"\nDEEP ANALYSIS FOR: '{word}'")

    synsets = wn.synsets(word)
    if synsets:
        primary_synset = synsets[0]

        print(f"  Definition: {primary_synset.definition()}")
        print(f"  Lemmas: {primary_synset.lemma_names()}")

        # Get all hypernym paths (no limit)
        print("\n  All Hypernym Paths:")
        hypernym_paths = primary_synset.hypernym_paths()
        for i, path in enumerate(hypernym_paths, 1):
            print(f"    Path {i}: {' -> '.join([s.name().split('.')[0] for s in path])}")

        # Get all hyponyms (no limit on display)
        all_hyponyms = primary_synset.hyponyms()
        print(f"\n  Total hyponyms found: {len(all_hyponyms)}")
        if all_hyponyms:
            print("  All hyponyms:")
            for hyp in all_hyponyms:
                print(f"    - {hyp.name()}: {hyp.definition()}")
# Out:
# WORD: 'ran'
#   Definition: move fast by using one's feet, with one foot off the ground at any given time
#   Example: ["Don't run--you'll be out of breath", 'The children ran to the store']
#
#   HYPERNYMS (more general): 1 found
#     → travel_rapidly.v.01
#       Definition: move very fast
#         ↑ travel.v.01: change location; move, travel, or proceed, also metaphorically
#
#   HYPONYMS (more specific): 12 found
#     → sprint.v.01
#       Definition: run very fast, usually for a short distance
#     → outrun.v.01
#       Definition: run faster than
#     → romp.v.02
#       Definition: run easily and fairly fast
#     → run.v.33
#       Definition: run with the ball; in such sports as football
#     → hare.v.01
#       Definition: run quickly, like a hare
#     → rush.v.05
#       Definition: run with the ball, in football
#     → run_bases.v.01
#       Definition: run around the bases, in baseball
#     → streak.v.02
#       Definition: run naked in a public place
#     → jog.v.03
#       Definition: run for exercise
#     → scurry.v.01
#       Definition: to move about or proceed hurriedly
#     → trot.v.01
#       Definition: run at a moderately swift pace
#     → lope.v.01
#       Definition: run easily
#
#   HIERARCHY PATH (up to root):
#     └─ run.v.01
#       └─ travel_rapidly.v.01
#         └─ travel.v.01
#
# WORD: 'preparing'
#   Definition: make ready or suitable or equip in advance for a particular purpose or for some use, event, etc
#   Example: ['Get the children ready for school!', 'prepare for war', 'I was fixing to leave town after I paid the hotel bill']
#
#   HYPERNYMS (more general): 1 found
#     → change.v.01
#       Definition: cause to change; make different; cause a transformation
#
#   HYPONYMS (more specific): 12 found
#     → mount.v.03
#       Definition: fix onto a backing, setting, or support
#     → set_up.v.04
#       Definition: get ready for a particular purpose or event
#     → winterize.v.01
#       Definition: prepare for winter
#     → brace.v.01
#       Definition: prepare (oneself) for something unpleasant or difficult
#     → cultivate.v.02
#       Definition: prepare for crops
#     → cram.v.04
#       Definition: prepare (students) hastily for an impending exam
#     → provide.v.07
#       Definition: take measures in preparation for
#     → fix.v.07
#       Definition: kill, preserve, and harden (tissue) in order to prepare for microscopic study
#     → socialize.v.03
#       Definition: prepare for social life
#     → summerize.v.01
#       Definition: prepare for summer
#     → prime.v.01
#       Definition: insert a primer into (a gun, mine, or charge) preparatory to detonation or firing
#     → precondition.v.01
#       Definition: put into the required condition beforehand
#
#   HIERARCHY PATH (up to root):
#     └─ fix.v.12
#       └─ change.v.01
#
# WORD: 'tminus'
#   No synsets found for 'tminus'
#
# WORD: 'operational'
#   Definition: pertaining to a process or series of actions for achieving a result
#   Example: ['operational difficulties', 'they assumed their operational positions']
#
#   HYPERNYMS: None found
#
#   HYPONYMS: None found
#
#   HIERARCHY PATH (up to root):
#     └─ operational.a.01
#
# WORD: 'systems'
#   Definition: instrumentality that combines interrelated interacting artifacts designed to work as a coherent entity
#   Example: ['he bought a new stereo system', 'the system consists of a motor and a small computer']
#
#   HYPERNYMS (more general): 1 found
#     → instrumentality.n.03
#       Definition: an artifact (or system of artifacts) that is instrumental in accomplishing some end
#         ↑ artifact.n.01: a man-made object taken as a whole
#
#   HYPONYMS (more specific): 28 found
#     → resonator.n.03
#       Definition: any system that resonates
#     → sprinkler_system.n.01
#       Definition: a system for extinguishing fires; water from a network of overhead pipes is released through nozzles that open automatically with the rise in temperature
#     → data_system.n.01
#       Definition: system consisting of the network of all communication channels used within an organization
#     → solar_thermal_system.n.01
#       Definition: a system that converts sunlight into heat
#     → security_system.n.01
#       Definition: (computing) a system that enforces boundaries between computer networks
#     → containment.n.02
#       Definition: (physics) a system designed to prevent the accidental release of radioactive material from a reactor
#     → exhaust.n.02
#       Definition: system consisting of the parts of an engine through which burned gases or steam are discharged
#     → synchromesh.n.01
#       Definition: an automotive system for shifting gears in which the gears revolve at the same speed and so shift smoothly
#     → inertial_guidance_system.n.01
#       Definition: a system to control a plane or spacecraft; uses inertial forces
#     → computer_system.n.01
#       Definition: a system of one or more computers and associated software with common storage
#     → drainage_system.n.01
#       Definition: a system of watercourses or drains for carrying off excess water
#     → communication_system.n.01
#       Definition: a system for communicating
#     → audio_system.n.01
#       Definition: a system of electronic equipment for recording or reproducing sound
#     → scaffolding.n.01
#       Definition: a system of scaffolds
#     → network.n.05
#       Definition: (electronics) a system of interconnected electronic components or circuits
#     → propulsion_system.n.01
#       Definition: a system that provides a propelling or driving force
#     → navigational_system.n.01
#       Definition: a system that provides information useful in determining the position and course of a ship or aircraft
#     → maze.n.01
#       Definition: complex system of paths or tunnels in which it is easy to get lost
#     → network.n.04
#       Definition: a system of intersecting lines or channels
#     → lockage.n.02
#       Definition: a system of locks in a canal or waterway
#     → guidance_system.n.01
#       Definition: a system of equipment for automatically guiding the path of a vehicle (especially a missile)
#     → control_system.n.01
#       Definition: a system for controlling the operation of another system
#     → hookup.n.02
#       Definition: a system of components assembled together for a particular purpose
#     → selsyn.n.01
#       Definition: a system consisting of a generator and a motor so connected that the motor will assume the same relative position as the generator; the generator and the motor are synchronized
#     → explosive_trace_detection.n.01
#       Definition: a system for screening luggage in airports; an agent passes a swab around or inside luggage and then runs the swab through a machine that can detect trace amounts of explosives
#     → mechanical_system.n.01
#       Definition: a system of elements that interact on mechanical principles
#     → shipboard_system.n.01
#       Definition: a system designed to work as a coherent entity on board a naval ship
#     → explosive_detection_system.n.01
#       Definition: a rapid automatic system to detect plastic explosives in passengers' luggage using X-ray technology and computers; designed for use in airports
#
#   HIERARCHY PATH (up to root):
#     └─ system.n.01
#       └─ instrumentality.n.03
#         └─ artifact.n.01
#           └─ whole.n.02
#             └─ object.n.01
#               └─ physical_entity.n.01
#                 └─ entity.n.01
#
# WORD: 'commander'
#   Definition: an officer in command of a military unit
#   Example: No example
#
#   HYPERNYMS (more general): 1 found
#     → military_officer.n.01
#       Definition: any person in the armed services who holds a position of authority or command
#         ↑ serviceman.n.01: someone who serves in the armed forces; a member of a military force
#
#   HYPONYMS (more specific): 4 found
#     → supreme_allied_commander_europe.n.01
#       Definition: commanding officer of ACE; NATO's senior military commander in Europe
#     → commander_in_chief.n.01
#       Definition: the officer who holds the supreme command
#     → supreme_allied_commander_atlantic.n.01
#       Definition: commanding officer of ACLANT; a general of the United States Army nominated by the President of the United States and approved by the North Atlantic Council
#     → wing_commander.n.01
#       Definition: (RAF rank) one who is next below a group captain
#
#   HIERARCHY PATH (up to root):
#     └─ commanding_officer.n.01
#       └─ military_officer.n.01
#         └─ serviceman.n.01
#           └─ skilled_worker.n.01
#             └─ worker.n.01
#               └─ person.n.01
#                 └─ organism.n.01
#                   └─ living_thing.n.01
#                     └─ whole.n.02
#                       └─ object.n.01
#                         └─ physical_entity.n.01
#                           └─ entity.n.01
#                 └─ causal_agent.n.01
#                   └─ physical_entity.n.01
#                     └─ entity.n.01
#
# WORD: 'support'
#   Definition: the activity of providing for or maintaining by supplying with money or necessities
#   Example: ['his support kept the family together', 'they gave him emotional support during difficult times']
#
#   HYPERNYMS (more general): 1 found
#     → activity.n.01
#       Definition: any specific behavior
#         ↑ act.n.02: something that people do or cause to happen
#
#   HYPONYMS (more specific): 2 found
#     → logistic_support.n.01
#       Definition: assistance between and within military commands
#     → sustenance.n.03
#       Definition: the act of sustaining life by food or providing a means of subsistence
#
#   HIERARCHY PATH (up to root):
#     └─ support.n.01
#       └─ activity.n.01
#         └─ act.n.02
#           └─ event.n.01
#             └─ psychological_feature.n.01
#               └─ abstraction.n.06
#                 └─ entity.n.01
#
# WORD: 'elena'
#   No synsets found for 'elena'
#
# WORD: 'glances'
#   Definition: a quick look
#   Example: No example
#
#   HYPERNYMS (more general): 1 found
#     → look.n.02
#       Definition: the act of directing the eyes toward something and perceiving it visually
#         ↑ sensing.n.02: becoming aware of something via the senses
#
#   HYPONYMS (more specific): 2 found
#     → eye-beaming.n.01
#       Definition: a radiant glance of the eye
#     → side-glance.n.01
#       Definition: a glance sideways
#
#   HIERARCHY PATH (up to root):
#     └─ glance.n.01
#       └─ look.n.02
#         └─ sensing.n.02
#           └─ sensory_activity.n.01
#             └─ activity.n.01
#               └─ act.n.02
#                 └─ event.n.01
#                   └─ psychological_feature.n.01
#                     └─ abstraction.n.06
#                       └─ entity.n.01
#
# WORD: 'initiated'
#   Definition: bring into being
#   Example: ['He initiated a new program', 'Start a foundation']
#
#   HYPERNYMS (more general): 1 found
#     → make.v.03
#       Definition: make or cause to be or to become
#
#   HYPONYMS (more specific): 3 found
#     → lead_up.v.01
#       Definition: set in motion, start an event or prepare the way for
#     → set.v.13
#       Definition: apply or start
#     → go_back.v.01
#       Definition: belong to an earlier time
#
#   HIERARCHY PATH (up to root):
#     └─ originate.v.02
#       └─ make.v.03
#
# WORD: 'year'
#   Definition: a period of time containing 365 (or 366) days
#   Example: ['she is 4 years old', 'in the year 1920']
#
#   HYPERNYMS (more general): 1 found
#     → time_period.n.01
#       Definition: an amount of time
#         ↑ fundamental_quantity.n.01: one of the four quantities that are the basis of systems of measurement
#
#   HYPONYMS (more specific): 12 found
#     → year_of_grace.n.01
#       Definition: any year of the Christian era
#     → calendar_year.n.01
#       Definition: the year (reckoned from January 1 to December 31) according to Gregorian calendar
#     → y2k.n.01
#       Definition: the year 2000 in the Gregorian calendar
#     → new_year.n.01
#       Definition: the calendar year just begun
#     → off_year.n.02
#       Definition: a year in which no major political elections are held
#     → church_year.n.01
#       Definition: the year in the ecclesiastical calendar; especially feast days and special seasons
#     → common_year.n.01
#       Definition: a year that is not a leap year
#     → annum.n.01
#       Definition: (Latin) year
#     → holy_year.n.01
#       Definition: (Roman Catholic Church) a period of remission from sin (usually granted every 25 years)
#     → leap_year.n.01
#       Definition: in the Gregorian calendar: any year divisible by 4 except centenary years divisible by 400
#     → fiscal_year.n.01
#       Definition: any accounting period of 12 months
#     → off_year.n.01
#       Definition: a year in which productivity is low or inferior
#
#   HIERARCHY PATH (up to root):
#     └─ year.n.01
#       └─ time_period.n.01
#         └─ fundamental_quantity.n.01
#           └─ measure.n.02
#             └─ abstraction.n.06
#               └─ entity.n.01
#
# WORD: 'online'
#   Definition: on a regular route of a railroad or bus or airline system
#   Example: ['on-line industries']
#
#   HYPERNYMS: None found
#
#   HYPONYMS: None found
#
#   HIERARCHY PATH (up to root):
#     └─ on-line.a.01
#
# WORD: 'activated'
#   Definition: put in motion or move to act
#   Example: ['trigger a reaction', 'actuate the circuits']
#
#   HYPERNYMS (more general): 1 found
#     → initiate.v.02
#       Definition: take the lead or initiative in; participate in the development of
#         ↑ cause.v.01: give rise to; cause to happen or occur, not always intentionally
#
#   HYPONYMS: None found
#
#   HIERARCHY PATH (up to root):
#     └─ trip.v.04
#       └─ initiate.v.02
#         └─ cause.v.01
#           └─ make.v.03
#
# WORD: 'odyssey'
#   Definition: a long wandering and eventful journey
#   Example: No example
#
#   HYPERNYMS (more general): 1 found
#     → journey.n.01
#       Definition: the act of traveling from one place to another
#         ↑ travel.n.01: the act of going from one place to another
#
#   HYPONYMS: None found
#
#   HIERARCHY PATH (up to root):
#     └─ odyssey.n.01
#       └─ journey.n.01
#         └─ travel.n.01
#           └─ motion.n.06
#             └─ change.n.03
#               └─ action.n.01
#                 └─ act.n.02
#                   └─ event.n.01
#                     └─ psychological_feature.n.01
#                       └─ abstraction.n.06
#                         └─ entity.n.01
#
# WORD: 'maiden'
#   Definition: an unmarried girl (especially a virgin)
#   Example: No example
#
#   HYPERNYMS (more general): 1 found
#     → girl.n.01
#       Definition: a young woman
#         ↑ woman.n.01: an adult female person (as opposed to a man)
#
#   HYPONYMS (more specific): 1 found
#     → damsel.n.01
#       Definition: a young unmarried woman
#
#   HIERARCHY PATH (up to root):
#     └─ maid.n.02
#       └─ girl.n.01
#         └─ woman.n.01
#           └─ adult.n.01
#             └─ person.n.01
#               └─ organism.n.01
#                 └─ living_thing.n.01
#                   └─ whole.n.02
#                     └─ object.n.01
#                       └─ physical_entity.n.01
#                         └─ entity.n.01
#               └─ causal_agent.n.01
#                 └─ physical_entity.n.01
#                   └─ entity.n.01
#           └─ female.n.02
#             └─ person.n.01
#               └─ organism.n.01
#                 └─ living_thing.n.01
#                   └─ whole.n.02
#                     └─ object.n.01
#                       └─ physical_entity.n.01
#                         └─ entity.n.01
#               └─ causal_agent.n.01
#                 └─ physical_entity.n.01
#                   └─ entity.n.01
#
# WORD: 'dr'
#   No synsets found for 'dr'
#
# WORD: 'hyperdrive'
#   No synsets found for 'hyperdrive'
#
# WORD: 'core'
#   Definition: a small group of indispensable persons or things
#   Example: ['five periodicals make up the core of their publishing program']
#
#   HYPERNYMS (more general): 1 found
#     → set.n.01
#       Definition: a group of things of the same kind that belong together and are so used
#         ↑ collection.n.01: several things grouped together or considered as a whole
#
#   HYPONYMS (more specific): 1 found
#     → cadre.n.02
#       Definition: a nucleus of military personnel capable of expansion
#
#   HIERARCHY PATH (up to root):
#     └─ core.n.01
#       └─ set.n.01
#         └─ collection.n.01
#           └─ group.n.01
#             └─ abstraction.n.06
#               └─ entity.n.01
#
# WORD: 'james'
#   Definition: a Stuart king of Scotland who married a daughter of Henry VII; when England and France went to war in 1513 he invaded England and died in defeat at Flodden (1473-1513)
#   Example: No example
#
#   HYPERNYMS: None found
#
#   HYPONYMS: None found
#
#   HIERARCHY PATH (up to root):
#     └─ james.n.01
#
# WORD: 'detected'
#   Definition: discover or determine the existence, presence, or fact of
#   Example: ['She detected high levels of lead in her drinking water', 'We found traces of lead in the paint']
#
#   HYPERNYMS (more general): 1 found
#     → spy.v.03
#       Definition: catch sight of; to perceive with the eyes
#         ↑ perceive.v.01: to become aware of through the senses
#
#   HYPONYMS (more specific): 5 found
#     → trace.v.05
#       Definition: discover traces of
#     → instantiate.v.02
#       Definition: find an instance of (a word or particular usage of a word)
#     → sense.v.02
#       Definition: detect some circumstance or entity automatically
#     → see.v.19
#       Definition: observe as if with an eye
#     → find_out.v.04
#       Definition: trap; especially in an error or in a reprehensible act
#
#   HIERARCHY PATH (up to root):
#     └─ detect.v.01
#       └─ spy.v.03
#         └─ perceive.v.01
#
# WORD: 'sector'
#   Definition: a plane figure bounded by two radii and the included arc of a circle
#   Example: No example
#
#   HYPERNYMS (more general): 1 found
#     → plane_figure.n.01
#       Definition: a two-dimensional shape
#         ↑ figure.n.06: a combination of points and lines and planes that form a visible palpable shape
#
#   HYPONYMS: None found
#
#   HIERARCHY PATH (up to root):
#     └─ sector.n.01
#       └─ plane_figure.n.01
#         └─ figure.n.06
#           └─ shape.n.02
#             └─ attribute.n.02
#               └─ abstraction.n.06
#                 └─ entity.n.01
#
# WORD: 'continued'
#   Definition: continue a certain state, condition, or activity
#   Example: ['Keep on working!', 'We continued to work into the night', 'Keep smiling', 'We went on working until well past midnight']
#
#   HYPERNYMS (more general): 1 found
#     → act.v.01
#       Definition: perform an action, or work out or perform (an action)
#
#   HYPONYMS (more specific): 3 found
#     → ride.v.03
#       Definition: continue undisturbed and without interference
#     → hold.v.13
#       Definition: remain in a certain state, position, or condition
#     → run_on.v.02
#       Definition: continue uninterrupted
#
#   HIERARCHY PATH (up to root):
#     └─ continue.v.01
#       └─ act.v.01
#
# WORD: 'final'
#   Definition: the final match between the winners of all previous matches in an elimination tournament
#   Example: No example
#
#   HYPERNYMS (more general): 1 found
#     → match.n.02
#       Definition: a formal contest in which two or more persons or teams compete
#         ↑ contest.n.01: an occasion on which a winner is selected from among two or more contestants
#
#   HYPONYMS (more specific): 1 found
#     → cup_final.n.01
#       Definition: the final match of any cup competition (such as the annual final of the English soccer competition at Wembley)
#
#   HIERARCHY PATH (up to root):
#     └─ final.n.01
#       └─ match.n.02
#         └─ contest.n.01
#           └─ social_event.n.01
#             └─ event.n.01
#               └─ psychological_feature.n.01
#                 └─ abstraction.n.06
#                   └─ entity.n.01
#
# WORD: 'status'
#   Definition: the relative position or standing of things or especially persons in a society
#   Example: ['he had the status of a minor', 'the novel attained the status of a classic', 'atheists do not enjoy a favorable position in American life']
#
#   HYPERNYMS (more general): 1 found
#     → state.n.02
#       Definition: the way something is with respect to its main attributes
#         ↑ attribute.n.02: an abstraction belonging to or characteristic of an entity
#
#   HYPONYMS (more specific): 26 found
#     → legal_status.n.01
#       Definition: a status defined by law
#     → leadership.n.03
#       Definition: the status of a leader
#     → caste.n.01
#       Definition: social status or position conferred by a system based on class
#     → high_profile.n.01
#       Definition: a position attracting much attention and publicity
#     → nationality.n.02
#       Definition: the status of belonging to a particular nation by birth or naturalization
#     → dignity.n.03
#       Definition: high office or rank or station
#     → low_status.n.01
#       Definition: a position of inferior status; low in station or rank or fortune or estimation
#     → election.n.03
#       Definition: the status or fact of being elected
#     → holy_order.n.01
#       Definition: (usually plural) the status or rank or office of a Christian clergyman in an ecclesiastical hierarchy
#     → footing.n.01
#       Definition: status with respect to the relations between people or groups
#     → ordination.n.01
#       Definition: the status of being ordained to a sacred office
#     → face.n.11
#       Definition: status in the eyes of others
#     → standing.n.01
#       Definition: social or financial or professional status or reputation
#     → left-handedness.n.01
#       Definition: the status of being born of a morganatic marriage
#     → high_status.n.01
#       Definition: a position of superior status
#     → equality.n.02
#       Definition: a state of being essentially equal or equivalent; equally balanced
#     → high_ground.n.01
#       Definition: a position of superiority over opponents or competitors
#     → rank.n.02
#       Definition: relative status
#     → pedestal.n.02
#       Definition: a position of great esteem (and supposed superiority)
#     → nobility.n.03
#       Definition: the state of being of noble birth
#     → bastardy.n.01
#       Definition: the status of being born to parents who were not married
#     → slot.n.04
#       Definition: a position in a hierarchy or organization
#     → retirement.n.01
#       Definition: the state of being retired from one's business or occupation
#     → social_station.n.01
#       Definition: position in a social hierarchy
#     → toehold.n.01
#       Definition: a relatively insignificant position from which future progress might be made
#     → command.n.05
#       Definition: a position of highest authority
#
#   HIERARCHY PATH (up to root):
#     └─ status.n.01
#       └─ state.n.02
#         └─ attribute.n.02
#           └─ abstraction.n.06
#             └─ entity.n.01
#
# WORD: 'proxima'
#   Definition: the nearest star to the sun; distance: 4.3 light years
#   Example: No example
#
#   HYPERNYMS: None found
#
#   HYPONYMS: None found
#
#   HIERARCHY PATH (up to root):
#     └─ proxima.n.01
#
# WORD: 'signal'
#   Definition: any nonverbal action or gesture that encodes a message
#   Example: ['signals from the boat suddenly stopped']
#
#   HYPERNYMS (more general): 1 found
#     → communication.n.02
#       Definition: something that is communicated by or to or between people or groups
#         ↑ abstraction.n.06: a general concept formed by extracting common features from specific examples
#
#   HYPONYMS (more specific): 26 found
#     → symbol.n.01
#       Definition: an arbitrary sign (written or printed) that has acquired a conventional significance
#     → starting_signal.n.01
#       Definition: a signal to begin (as in a race)
#     → time_signal.n.01
#       Definition: a signal (especially electronic or by radio) indicating the precisely correct time
#     → bugle_call.n.01
#       Definition: a signal broadcast by the sound of a bugle
#     → radio_beam.n.01
#       Definition: a signal transmitted along a narrow path; guides airplane pilots in darkness or bad weather
#     → input_signal.n.01
#       Definition: signal going into an electronic system
#     → ticktack.n.01
#       Definition: system of signalling by hand signs used by bookmakers at racetracks
#     → dog-ear.n.01
#       Definition: a corner of a page turned down to mark your place
#     → storm_signal.n.01
#       Definition: a signal announcing the approach of a storm (particularly a storm of marked violence)
#     → retreat.n.03
#       Definition: (military) a signal to begin a withdrawal from a dangerous position
#     → high_sign.n.01
#       Definition: a silent signal of warning or recognition
#     → all_clear.n.01
#       Definition: a signal (usually a siren) that danger is over
#     → phone_number.n.01
#       Definition: the number is used in calling a particular telephone
#     → drumbeat.n.02
#       Definition: (military) the beating of a drum as a signal for lowering the flag at sundown
#     → telegraphic_signal.n.01
#       Definition: a signal transmitted by telegraphy
#     → visual_signal.n.01
#       Definition: a signal that involves visual communication
#     → distress_signal.n.01
#       Definition: an internationally recognized signal sent out by a ship or plane indicating that help is needed
#     → whistle.n.02
#       Definition: the act of signalling (e.g., summoning) by whistling or blowing a whistle
#     → alarm.n.03
#       Definition: an automatic signal (usually a sound) warning of danger
#     → electronic_signal.n.01
#       Definition: a signal generated by electronic means
#     → curfew.n.02
#       Definition: a signal (usually a bell) announcing the start of curfew restrictions
#     → animal_communication.n.01
#       Definition: communication between animals (of the same species)
#     → recording.n.01
#       Definition: a signal that encodes something (e.g., picture or sound) that has been recorded
#     → indicator.n.02
#       Definition: a signal for attracting attention
#     → output_signal.n.01
#       Definition: signal that comes out of an electronic system
#     → radio_beacon.n.01
#       Definition: a characteristic signal emitted by a transmitter used for navigation
#
#   HIERARCHY PATH (up to root):
#     └─ signal.n.01
#       └─ communication.n.02
#         └─ abstraction.n.06
#           └─ entity.n.01
#
# WORD: 'life'
#   Definition: a characteristic state or mode of living
#   Example: ['social life', 'city life', 'real life']
#
#   HYPERNYMS (more general): 1 found
#     → being.n.01
#       Definition: the state or fact of existing
#         ↑ state.n.02: the way something is with respect to its main attributes
#
#   HYPONYMS (more specific): 1 found
#     → ghetto.n.02
#       Definition: any segregated mode of living or working that results from bias or stereotyping
#
#   HIERARCHY PATH (up to root):
#     └─ life.n.01
#       └─ being.n.01
#         └─ state.n.02
#           └─ attribute.n.02
#             └─ abstraction.n.06
#               └─ entity.n.01
#
# WORD: 'diagnostics'
#   Definition: the branch of medical science dealing with the classification of disease
#   Example: No example
#
#   HYPERNYMS (more general): 1 found
#     → medicine.n.01
#       Definition: the branches of medical science that deal with nonsurgical techniques
#         ↑ medical_science.n.01: the science of dealing with the maintenance of health and the prevention and treatment of disease
#
#   HYPONYMS: None found
#
#   HIERARCHY PATH (up to root):
#     └─ nosology.n.01
#       └─ medicine.n.01
#         └─ medical_science.n.01
#           └─ life_science.n.01
#             └─ natural_science.n.01
#               └─ science.n.01
#                 └─ discipline.n.01
#                   └─ knowledge_domain.n.01
#                     └─ content.n.05
#                       └─ cognition.n.01
#                         └─ psychological_feature.n.01
#                           └─ abstraction.n.06
#                             └─ entity.n.01
#
# WORD: 'announced'
#   Definition: make known; make an announcement
#   Example: ['She denoted her feelings clearly']
#
#   HYPERNYMS (more general): 1 found
#     → inform.v.01
#       Definition: impart knowledge of some fact, state or affairs, or event to
#         ↑ communicate.v.02: transmit thoughts or feelings
#
#   HYPONYMS (more specific): 11 found
#     → blare_out.v.01
#       Definition: announce loudly
#     → report.v.02
#       Definition: announce as the result of an investigation or experience or finding
#     → trump.v.04
#       Definition: proclaim or announce with or as if with a fanfare
#     → report.v.03
#       Definition: announce one's presence
#     → advertise.v.01
#       Definition: call attention to
#     → sound.v.04
#       Definition: announce by means of a sound
#     → call_out.v.02
#       Definition: call out loudly, as of names or numbers
#     → cry.v.04
#       Definition: proclaim or announce in public
#     → meld.v.01
#       Definition: announce for a score; of cards in a card game
#     → denounce.v.03
#       Definition: announce the termination of, as of treaties
#     → post.v.02
#       Definition: publicize with, or as if with, a poster
#
#   HIERARCHY PATH (up to root):
#     └─ announce.v.01
#       └─ inform.v.01
#         └─ communicate.v.02
#           └─ interact.v.01
#             └─ act.v.01
#
# WORD: 'finally'
#   Definition: after an unspecified period of time or an especially long delay
#   Example: No example
#
#   HYPERNYMS: None found
#
#   HYPONYMS: None found
#
#   HIERARCHY PATH (up to root):
#     └─ finally.r.01
#
# WORD: 'light'
#   Definition: (physics) electromagnetic radiation that can produce a visual sensation
#   Example: ['the light was filtered through a soft glass window']
#
#   HYPERNYMS (more general): 1 found
#     → actinic_radiation.n.01
#       Definition: electromagnetic radiation that can produce photochemical reactions
#         ↑ electromagnetic_radiation.n.01: radiation consisting of waves of energy associated with electric and magnetic fields resulting from the acceleration of an electric charge
#
#   HYPONYMS (more specific): 23 found
#     → sunlight.n.01
#       Definition: the rays of the sun
#     → counterglow.n.01
#       Definition: a faint spot of light in the night sky that appears directly opposite the position of the sun; a reflection of sunlight by micrometeoric material in space
#     → beam.n.04
#       Definition: a column of light (as from a beacon)
#     → glow.n.05
#       Definition: a steady even light without flames
#     → candlelight.n.01
#       Definition: the light provided by a burning candle
#     → starlight.n.01
#       Definition: the light of the stars
#     → luminescence.n.01
#       Definition: light not due to incandescence; occurs at low temperatures
#     → meteor.n.02
#       Definition: a streak of light in the sky at night that results when a meteoroid hits the earth's atmosphere and air friction causes the meteoroid to melt or vaporize or explode
#     → firelight.n.01
#       Definition: the light of a fire (especially in a fireplace)
#     → streamer.n.01
#       Definition: light that streams
#     → moonlight.n.01
#       Definition: the light of the Moon
#     → twilight.n.02
#       Definition: the diffused light from the sky when the sun is below the horizon but its rays are refracted by the atmosphere of the earth
#     → gaslight.n.01
#       Definition: light yielded by the combustion of illuminating gas
#     → friar's_lantern.n.01
#       Definition: a pale light sometimes seen at night over marshy ground
#     → scintillation.n.01
#       Definition: (physics) a flash of light that is produced in a phosphor when it absorbs a photon or ionizing particle
#     → incandescence.n.01
#       Definition: the phenomenon of light emission by a body as its temperature is raised
#     → daylight.n.02
#       Definition: light during the daytime
#     → torchlight.n.01
#       Definition: light from a torch or torches
#     → lamplight.n.01
#       Definition: light from a lamp
#     → corona.n.04
#       Definition: one or more circles of light seen around a luminous object
#     → radiance.n.01
#       Definition: the amount of electromagnetic radiation leaving or arriving at a point on a surface
#     → half-light.n.01
#       Definition: a greyish light (as at dawn or dusk or in dim interiors)
#     → fluorescence.n.01
#       Definition: light emitted during absorption of radiation of some other (invisible) wavelength
#
#   HIERARCHY PATH (up to root):
#     └─ light.n.01
#       └─ actinic_radiation.n.01
#         └─ electromagnetic_radiation.n.01
#           └─ radiation.n.01
#             └─ energy.n.01
#               └─ physical_phenomenon.n.01
#                 └─ natural_phenomenon.n.01
#                   └─ phenomenon.n.01
#                     └─ process.n.06
#                       └─ physical_entity.n.01
#                         └─ entity.n.01
#
# WORD: 'vasquez'
#   No synsets found for 'vasquez'
#
# WORD: 'error'
#   Definition: a wrong action attributable to bad judgment or ignorance or inattention
#   Example: ['he made a bad mistake', 'she was quick to point out my errors', 'I could understand his English in spite of his grammatical faults']
#
#   HYPERNYMS (more general): 1 found
#     → nonaccomplishment.n.01
#       Definition: an act that does not achieve its intended goal
#         ↑ act.n.02: something that people do or cause to happen
#
#   HYPONYMS (more specific): 13 found
#     → incursion.n.03
#       Definition: the mistake of incurring liability or blame
#     → blunder.n.01
#       Definition: an embarrassing mistake
#     → offside.n.01
#       Definition: (sport) the mistake of occupying an illegal position on the playing field (in football, soccer, ice hockey, field hockey, etc.)
#     → distortion.n.06
#       Definition: the mistake of misrepresenting the facts
#     → slip.n.02
#       Definition: a minor inadvertent mistake usually observed in speech or writing or in small accidents or memory lapses etc.
#     → revoke.n.01
#       Definition: the mistake of not following suit when able to do so
#     → ballup.n.01
#       Definition: something badly botched or muddled
#     → omission.n.01
#       Definition: a mistake resulting from neglect
#     → miscalculation.n.01
#       Definition: a mistake in calculating
#     → oversight.n.03
#       Definition: a mistake resulting from inattention
#     → confusion.n.05
#       Definition: a mistake that results from taking one thing to be another
#     → stupidity.n.02
#       Definition: a stupid mistake
#     → blot.n.02
#       Definition: an act that brings discredit to the person who does it
#
#   HIERARCHY PATH (up to root):
#     └─ mistake.n.01
#       └─ nonaccomplishment.n.01
#         └─ act.n.02
#           └─ event.n.01
#             └─ psychological_feature.n.01
#               └─ abstraction.n.06
#                 └─ entity.n.01
#
# WORD: 'unidentified'
#   Definition: not yet identified
#   Example: ['an unidentified species', 'an unidentified witness']
#
#   HYPERNYMS: None found
#
#   HYPONYMS: None found
#
#   HIERARCHY PATH (up to root):
#     └─ unidentified.s.01
#
# WORD: 'crew'
#   Definition: the men and women who man a vehicle (ship, aircraft, etc.)
#   Example: No example
#
#   HYPERNYMS (more general): 1 found
#     → unit.n.03
#       Definition: an organization regarded as part of a larger social group
#         ↑ organization.n.01: a group of people who work together
#
#   HYPONYMS (more specific): 2 found
#     → aircrew.n.01
#       Definition: the crew of an aircraft
#     → merchant_marine.n.01
#       Definition: the crew of a merchant vessel
#
#   HIERARCHY PATH (up to root):
#     └─ crew.n.01
#       └─ unit.n.03
#         └─ organization.n.01
#           └─ social_group.n.01
#             └─ group.n.01
#               └─ abstraction.n.06
#                 └─ entity.n.01
#
# WORD: 'engineer'
#   Definition: a person who uses scientific knowledge to solve practical problems
#   Example: No example
#
#   HYPERNYMS (more general): 1 found
#     → person.n.01
#       Definition: a human being
#         ↑ organism.n.01: a living thing that has (or can develop) the ability to act or function independently
#         ↑ causal_agent.n.01: any entity that produces an effect or is responsible for events or results
#
#   HYPONYMS (more specific): 13 found
#     → surveyor.n.01
#       Definition: an engineer who determines the boundaries and elevations of land or structures
#     → rocket_engineer.n.01
#       Definition: an engineer who builds and tests rockets
#     → aeronautical_engineer.n.01
#       Definition: an engineer concerned with the design and construction of aircraft
#     → civil_engineer.n.01
#       Definition: an engineer trained to design and construct and maintain public works (roads or bridges or harbors etc.)
#     → mining_engineer.n.01
#       Definition: an engineer concerned with the construction and operation of mines
#     → mechanical_engineer.n.01
#       Definition: a person trained to design and construct machines
#     → army_engineer.n.01
#       Definition: a member of the military who is trained in engineering and construction work
#     → programmer.n.01
#       Definition: a person who designs and writes and tests computer programs
#     → aerospace_engineer.n.01
#       Definition: an engineer of aircraft and space vehicles
#     → marine_engineer.n.01
#       Definition: a naval officer responsible for the operation and maintenance of the ship's engines
#     → electrical_engineer.n.01
#       Definition: a person trained in practical applications of the theory of electricity
#     → automotive_engineer.n.01
#       Definition: an engineer concerned with the design and construction of automobiles
#     → metallurgist.n.01
#       Definition: an engineer trained in the extraction and refining and alloying and fabrication of metals
#
#   HIERARCHY PATH (up to root):
#     └─ engineer.n.01
#       └─ person.n.01
#         └─ organism.n.01
#           └─ living_thing.n.01
#             └─ whole.n.02
#               └─ object.n.01
#                 └─ physical_entity.n.01
#                   └─ entity.n.01
#         └─ causal_agent.n.01
#           └─ physical_entity.n.01
#             └─ entity.n.01
#
# WORD: 'sequence'
#   Definition: serial arrangement in which things follow in logical order or a recurrent pattern
#   Example: ['the sequence of names was alphabetical', 'he invented a technique to determine the sequence of base pairs in DNA']
#
#   HYPERNYMS (more general): 1 found
#     → series.n.01
#       Definition: similar things placed in order or happening one after another
#         ↑ ordering.n.01: logical or comprehensible arrangement of separate elements
#
#   HYPONYMS (more specific): 6 found
#     → codon.n.01
#       Definition: a specific sequence of three adjacent nucleotides on a strand of DNA or RNA that specifies the genetic code information for synthesizing a particular amino acid
#     → combination.n.03
#       Definition: a sequence of numbers or letters that opens a combination lock
#     → string.n.05
#       Definition: a linear sequence of symbols (characters or words or phrases)
#     → combination.n.02
#       Definition: a coordinated sequence of chess moves
#     → gene.n.01
#       Definition: (genetics) a segment of DNA that is involved in producing a polypeptide chain; it can include regions preceding and following the coding DNA as well as introns between the exons; it is considered a unit of heredity
#     → fibonacci_sequence.n.01
#       Definition: a sequence of numbers in which each number equals the sum of the two preceding numbers
#
#   HIERARCHY PATH (up to root):
#     └─ sequence.n.01
#       └─ series.n.01
#         └─ ordering.n.01
#           └─ arrangement.n.02
#             └─ group.n.01
#               └─ abstraction.n.06
#                 └─ entity.n.01
#
# WORD: 'gamma'
#   Definition: the 3rd letter of the Greek alphabet
#   Example: No example
#
#   HYPERNYMS (more general): 1 found
#     → letter.n.02
#       Definition: the conventional characters of the alphabet used to represent speech
#         ↑ character.n.08: a written symbol that is used to represent speech
#
#   HYPONYMS: None found
#
#   HIERARCHY PATH (up to root):
#     └─ gamma.n.01
#       └─ letter.n.02
#         └─ character.n.08
#           └─ written_symbol.n.01
#             └─ symbol.n.01
#               └─ signal.n.01
#                 └─ communication.n.02
#                   └─ abstraction.n.06
#                     └─ entity.n.01
#
# WORD: 'voyage'
#   Definition: an act of traveling by water
#   Example: No example
#
#   HYPERNYMS (more general): 1 found
#     → water_travel.n.01
#       Definition: travel by water
#         ↑ travel.n.01: the act of going from one place to another
#
#   HYPONYMS (more specific): 2 found
#     → cruise.n.01
#       Definition: an ocean trip taken for pleasure
#     → maiden_voyage.n.01
#       Definition: the first voyage of its kind
#
#   HIERARCHY PATH (up to root):
#     └─ ocean_trip.n.01
#       └─ water_travel.n.01
#         └─ travel.n.01
#           └─ motion.n.06
#             └─ change.n.03
#               └─ action.n.01
#                 └─ act.n.02
#                   └─ event.n.01
#                     └─ psychological_feature.n.01
#                       └─ abstraction.n.06
#                         └─ entity.n.01
#
# WORD: 'starship'
#   Definition: a spacecraft designed to carry a crew into interstellar space (especially in science fiction)
#   Example: No example
#
#   HYPERNYMS (more general): 1 found
#     → spacecraft.n.01
#       Definition: a craft capable of traveling in outer space; technically, a satellite around the sun
#         ↑ craft.n.02: a vehicle designed for navigation in or on water or air or through outer space
#         ↑ satellite.n.01: man-made equipment that orbits around the earth or the moon
#
#   HYPONYMS: None found
#
#   HIERARCHY PATH (up to root):
#     └─ starship.n.01
#       └─ spacecraft.n.01
#         └─ craft.n.02
#           └─ vehicle.n.01
#             └─ conveyance.n.03
#               └─ instrumentality.n.03
#                 └─ artifact.n.01
#                   └─ whole.n.02
#                     └─ object.n.01
#                       └─ physical_entity.n.01
#                         └─ entity.n.01
#         └─ satellite.n.01
#           └─ equipment.n.01
#             └─ instrumentality.n.03
#               └─ artifact.n.01
#                 └─ whole.n.02
#                   └─ object.n.01
#                     └─ physical_entity.n.01
#                       └─ entity.n.01
#
# WORD: 'b'
#   Definition: aerobic rod-shaped spore-producing bacterium; often occurring in chainlike formations; found primarily in soil
#   Example: No example
#
#   HYPERNYMS (more general): 1 found
#     → eubacteria.n.01
#       Definition: a large group of bacteria having rigid cell walls; motile types have flagella
#         ↑ moneran.n.01: organisms that typically reproduce by asexual budding or fission and whose nutritional mode is absorption or photosynthesis or chemosynthesis
#         ↑ bacteria.n.01: (microbiology) single-celled or noncellular spherical or spiral or rod-shaped organisms lacking chlorophyll that reproduce by fission; important as pathogens and for biochemical properties; taxonomy is difficult; often considered to be plants
#
#   HYPONYMS (more specific): 3 found
#     → yersinia_pestis.n.01
#       Definition: a bacillus bacterium that causes the plague; aerosolized bacteria can be used as a bioweapon
#     → bacillus_subtilis.n.01
#       Definition: a species of bacillus found in soil and decomposing organic matter; some strains produce antibiotics
#     → bacillus_anthracis.n.01
#       Definition: a species of bacillus that causes anthrax in humans and in animals (cattle and swine and sheep and rabbits and mice and guinea pigs); can be used a bioweapon
#
#   HIERARCHY PATH (up to root):
#     └─ bacillus.n.01
#       └─ eubacteria.n.01
#         └─ moneran.n.01
#           └─ microorganism.n.01
#             └─ organism.n.01
#               └─ living_thing.n.01
#                 └─ whole.n.02
#                   └─ object.n.01
#                     └─ physical_entity.n.01
#                       └─ entity.n.01
#         └─ bacteria.n.01
#           └─ microorganism.n.01
#             └─ organism.n.01
#               └─ living_thing.n.01
#                 └─ whole.n.02
#                   └─ object.n.01
#                     └─ physical_entity.n.01
#                       └─ entity.n.01
#
# WORD: 'webb'
#   Definition: English writer and a central member of the Fabian Society (1858-1943)
#   Example: No example
#
#   HYPERNYMS: None found
#
#   HYPONYMS: None found
#
#   HIERARCHY PATH (up to root):
#     └─ webb.n.01
#
# WORD: 'achieved'
#   Definition: to gain with effort
#   Example: ['she achieved her goal despite setbacks']
#
#   HYPERNYMS (more general): 1 found
#     → succeed.v.01
#       Definition: attain success or reach a desired goal
#
#   HYPONYMS (more specific): 8 found
#     → score.v.06
#       Definition: get a certain number or letter indicating quality or performance
#     → compass.v.01
#       Definition: bring about; accomplish
#     → culminate.v.03
#       Definition: reach the highest or most decisive point
#     → average.v.02
#       Definition: achieve or reach on average
#     → begin.v.09
#       Definition: achieve or accomplish in the least degree, usually used in the negative
#     → reach.v.07
#       Definition: reach a goal, e.g.,
#     → come_to.v.03
#       Definition: attain
#     → wangle.v.01
#       Definition: achieve something by means of trickery or devious methods
#
#   HIERARCHY PATH (up to root):
#     └─ achieve.v.01
#       └─ succeed.v.01
#
# WORD: 'centauri'
#   No synsets found for 'centauri'
#
# WORD: 'distance'
#   Definition: the property created by the space between two objects or points
#   Example: No example
#
#   HYPERNYMS (more general): 1 found
#     → spacing.n.02
#       Definition: the property possessed by an array of things that have space between them
#         ↑ placement.n.01: the spatial property of the way in which something is placed
#
#   HYPONYMS (more specific): 18 found
#     → piece.n.09
#       Definition: a distance
#     → farness.n.01
#       Definition: the property of being remote
#     → leap.n.04
#       Definition: the distance leaped (or to be leaped)
#     → hyperfocal_distance.n.01
#       Definition: the distance in front of a lens that is focused at infinity beyond which all objects are well defined and clear
#     → mileage.n.01
#       Definition: distance measured in miles
#     → span.n.02
#       Definition: the distance or interval between two points
#     → wheelbase.n.01
#       Definition: the distance from the center of a car's front wheel to the rear axle
#     → interval.n.03
#       Definition: the distance between things
#     → nearness.n.01
#       Definition: the spatial property resulting from a relatively small distance
#     → focal_distance.n.01
#       Definition: the distance from a lens to its focus
#     → yardage.n.01
#       Definition: distance measured in the aggregate number of yards
#     → hour.n.04
#       Definition: distance measured by the time taken to cover it
#     → remove.n.01
#       Definition: degree of figurative distance or separation;  or
#     → elevation.n.05
#       Definition: distance of something above a reference point (such as sea level)
#     → way.n.09
#       Definition: the property of distance in general
#     → wavelength.n.01
#       Definition: the distance (measured in the direction of propagation) between two points in the same phase in consecutive cycles of a wave
#     → hour_angle.n.01
#       Definition: the angular distance along the celestial equator from the observer's meridian to the hour circle of a given celestial body
#     → mean_distance.n.01
#       Definition: the arithmetic mean of the maximum and minimum distances of a celestial body (satellite or secondary star) from its primary
#
#   HIERARCHY PATH (up to root):
#     └─ distance.n.01
#       └─ spacing.n.02
#         └─ placement.n.01
#           └─ position.n.07
#             └─ relation.n.01
#               └─ abstraction.n.06
#                 └─ entity.n.01
#
# WORD: 'exchanged'
#   Definition: give to, and receive from, one another
#   Example: ['Would you change places with me?', 'We have been exchanging letters for a year']
#
#   HYPERNYMS (more general): 1 found
#     → transfer.v.05
#       Definition: cause to change ownership
#
#   HYPONYMS (more specific): 8 found
#     → sell.v.01
#       Definition: exchange or deliver for money or its equivalent
#     → trade.v.04
#       Definition: exchange or give (something) in exchange for
#     → trade.v.02
#       Definition: turn in as payment or part payment for a purchase
#     → ransom.v.01
#       Definition: exchange or buy back for money; under threat
#     → redeem.v.03
#       Definition: to turn in (vouchers or coupons) and receive something in exchange
#     → barter.v.01
#       Definition: exchange goods without involving money
#     → substitute.v.02
#       Definition: be a substitute
#     → cash.v.01
#       Definition: exchange for cash
#
#   HIERARCHY PATH (up to root):
#     └─ exchange.v.01
#       └─ transfer.v.05
#
# WORD: 'ai'
#   Definition: an agency of the United States Army responsible for providing timely and relevant and accurate and synchronized intelligence to tactical and operational and strategic level commanders
#   Example: No example
#
#   HYPERNYMS (more general): 1 found
#     → agency.n.01
# ...
#   Example: No example
#
#   HYPERNYMS (more general): 1 found
#     → humaneness.n.01
#       Definition: the quality of compassion or consideration for others (people or animals)
#         ↑ quality.n.01: an essential and distinguishing attribute of something or someone; --Shakespeare
#
#   HYPONYMS: None found
#
#   HIERARCHY PATH (up to root):
#     └─ humanity.n.01
#       └─ humaneness.n.01
#         └─ quality.n.01
#           └─ attribute.n.02
#             └─ abstraction.n.06
#               └─ entity.n.01
#
# WORD: 'chief'
#   Definition: a person who is in charge
#   Example: ['the head of the whole operation']
#
#   HYPERNYMS (more general): 1 found
#     → leader.n.01
#       Definition: a person who rules or guides or inspires others
#         ↑ person.n.01: a human being
#
#   HYPONYMS (more specific): 10 found
#     → general_manager.n.01
#       Definition: the highest ranking manager
#     → general.n.02
#       Definition: the head of a religious order or congregation
#     → capo.n.01
#       Definition: the head of a branch of an organized crime syndicate
#     → secretary.n.01
#       Definition: a person who is head of an administrative department of government
#     → department_head.n.01
#       Definition: the head of a department
#     → head_of_household.n.01
#       Definition: the head of a household or family or tribe
#     → administrator.n.01
#       Definition: someone who administers a business
#     → don.n.03
#       Definition: the head of an organized crime family
#     → grand_dragon.n.01
#       Definition: a high ranking person in the Ku Klux Klan
#     → administrator.n.03
#       Definition: someone who manages a government agency or department
#
#   HIERARCHY PATH (up to root):
#     └─ head.n.04
#       └─ leader.n.01
#         └─ person.n.01
#           └─ organism.n.01
#             └─ living_thing.n.01
#               └─ whole.n.02
#                 └─ object.n.01
#                   └─ physical_entity.n.01
#                     └─ entity.n.01
#           └─ causal_agent.n.01
#             └─ physical_entity.n.01
#               └─ entity.n.01
#
# WORD: 'suddenly'
#   Definition: happening unexpectedly
#   Example: ['suddenly she felt a sharp pain in her side']
#
#   HYPERNYMS: None found
#
#   HYPONYMS: None found
#
#   HIERARCHY PATH (up to root):
#     └─ suddenly.r.01
#
# WORD: 'launch'
#   Definition: a motorboat with an open deck or a half deck
#   Example: No example
#
#   HYPERNYMS (more general): 1 found
#     → motorboat.n.01
#       Definition: a boat propelled by an internal-combustion engine
#         ↑ boat.n.01: a small vessel for travel on water
#
#   HYPONYMS: None found
#
#   HIERARCHY PATH (up to root):
#     └─ launch.n.01
#       └─ motorboat.n.01
#         └─ boat.n.01
#           └─ vessel.n.02
#             └─ craft.n.02
#               └─ vehicle.n.01
#                 └─ conveyance.n.03
#                   └─ instrumentality.n.03
#                     └─ artifact.n.01
#                       └─ whole.n.02
#                         └─ object.n.01
#                           └─ physical_entity.n.01
#                             └─ entity.n.01
#
# WORD: 'travel'
#   Definition: the act of going from one place to another
#   Example: ['he enjoyed selling but he hated the travel']
#
#   HYPERNYMS (more general): 1 found
#     → motion.n.06
#       Definition: the act of changing location from one place to another
#         ↑ change.n.03: the action of changing something
#
#   HYPONYMS (more specific): 17 found
#     → water_travel.n.01
#       Definition: travel by water
#     → wayfaring.n.01
#       Definition: traveling (especially on foot)
#     → walk.n.04
#       Definition: the act of walking somewhere
#     → staging.n.03
#       Definition: travel by stagecoach
#     → circumnavigation.n.01
#       Definition: traveling around something (by ship or plane)
#     → driving.n.02
#       Definition: the act of controlling and steering the movement of a vehicle or animal
#     → peregrination.n.01
#       Definition: traveling or wandering around
#     → riding.n.02
#       Definition: travel by being carried on horseback
#     → on_the_road.n.01
#       Definition: travelling about
#     → crossing.n.01
#       Definition: traveling across
#     → air_travel.n.01
#       Definition: travel via aircraft
#     → journey.n.01
#       Definition: the act of traveling from one place to another
#     → commutation.n.01
#       Definition: the travel of a commuter
#     → junketing.n.01
#       Definition: taking an excursion for pleasure
#     → wandering.n.01
#       Definition: travelling about without any clear destination
#     → traversal.n.02
#       Definition: travel across
#     → stage.n.06
#       Definition: a section or portion of a journey or course
#
#   HIERARCHY PATH (up to root):
#     └─ travel.n.01
#       └─ motion.n.06
#         └─ change.n.03
#           └─ action.n.01
#             └─ act.n.02
#               └─ event.n.01
#                 └─ psychological_feature.n.01
#                   └─ abstraction.n.06
#                     └─ entity.n.01
#
# WORD: 'alarm'
#   Definition: fear resulting from the awareness of danger
#   Example: No example
#
#   HYPERNYMS (more general): 1 found
#     → fear.n.01
#       Definition: an emotion experienced in anticipation of some specific pain or danger (usually accompanied by a desire to flee or fight)
#         ↑ emotion.n.01: any strong feeling
#
#   HYPONYMS: None found
#
#   HIERARCHY PATH (up to root):
#     └─ alarm.n.01
#       └─ fear.n.01
#         └─ emotion.n.01
#           └─ feeling.n.01
#             └─ state.n.02
#               └─ attribute.n.02
#                 └─ abstraction.n.06
#                   └─ entity.n.01
#
# WORD: 'years'
#   Definition: a late time of life
#   Example: ['old age is not for sissies', "he's showing his years", "age hasn't slowed him down at all", 'a beard white with eld', 'on the brink of geezerhood']
#
#   HYPERNYMS (more general): 1 found
#     → time_of_life.n.01
#       Definition: a period of time during which a person is normally in a particular life state
#         ↑ time_period.n.01: an amount of time
#
#   HYPONYMS (more specific): 1 found
#     → dotage.n.01
#       Definition: mental infirmity as a consequence of old age; sometimes shown by foolish infatuations
#
#   HIERARCHY PATH (up to root):
#     └─ old_age.n.01
#       └─ time_of_life.n.01
#         └─ time_period.n.01
#           └─ fundamental_quantity.n.01
#             └─ measure.n.02
#               └─ abstraction.n.06
#                 └─ entity.n.01
#
# WORD: 'interstellar'
#   Definition: between or among stars
#   Example: ['the density of hydrogen in interplanetary and interstellar space']
#
#   HYPERNYMS: None found
#
#   HYPONYMS: None found
#
#   HIERARCHY PATH (up to root):
#     └─ interstellar.a.01
#
# WORD: 'quantum'
#   Definition: a discrete amount of something that is analogous to the quantities in quantum theory
#   Example: No example
#
#   HYPERNYMS (more general): 1 found
#     → quantity.n.03
#       Definition: the concept that something has a magnitude and can be represented in mathematical expressions by a constant or a variable
#         ↑ concept.n.01: an abstract or general idea inferred or derived from specific instances
#
#   HYPONYMS: None found
#
#   HIERARCHY PATH (up to root):
#     └─ quantum.n.01
#       └─ quantity.n.03
#         └─ concept.n.01
#           └─ idea.n.01
#             └─ content.n.05
#               └─ cognition.n.01
#                 └─ psychological_feature.n.01
#                   └─ abstraction.n.06
#                     └─ entity.n.01
#
# WORD: 'worried'
#   Definition: be worried, concerned, anxious, troubled, or uneasy
#   Example: ['I worry about my job']
#
#   HYPERNYMS: None found
#
#   HYPONYMS (more specific): 4 found
#     → fear.v.01
#       Definition: be afraid or feel anxious or apprehensive about a possible or probable situation or event
#     → fret.v.02
#       Definition: be agitated or irritated
#     → obsess.v.02
#       Definition: be preoccupied with something
#     → fuss.v.01
#       Definition: worry unnecessarily or excessively
#
#   HIERARCHY PATH (up to root):
#     └─ worry.v.01
#
# WORD: 'blared'
#   Definition: make a strident sound
#   Example: ['She tended to blast when speaking into a microphone']
#
#   HYPERNYMS (more general): 1 found
#     → make_noise.v.01
#       Definition: emit a noise
#         ↑ sound.v.02: make a certain noise or sound
#
#   HYPONYMS: None found
#
#   HIERARCHY PATH (up to root):
#     └─ blast.v.01
#       └─ make_noise.v.01
#         └─ sound.v.02
#           └─ cause_to_be_perceived.v.01
#
# DETAILED EXAMPLE FOR KEY WORDS FROM TEXT
#
# DEEP ANALYSIS FOR: 'apple'
#   Definition: fruit with red or yellow or green skin and sweet to tart crisp whitish flesh
#   Lemmas: ['apple']
#
#   All Hypernym Paths:
#     Path 1: entity -> physical_entity -> object -> whole -> natural_object -> plant_part -> plant_organ -> reproductive_structure -> fruit -> edible_fruit -> apple
#     Path 2: entity -> physical_entity -> matter -> solid -> food -> produce -> edible_fruit -> apple
#     Path 3: entity -> physical_entity -> object -> whole -> natural_object -> plant_part -> plant_organ -> reproductive_structure -> fruit -> pome -> apple
#
#   Total hyponyms found: 3
#   All hyponyms:
#     - crab_apple.n.03: small sour apple; suitable for preserving
#     - cooking_apple.n.01: an apple used primarily in cooking for pies and applesauce etc
#     - eating_apple.n.01: an apple used primarily for eating raw without cooking
#
# DEEP ANALYSIS FOR: 'computer'
#   Definition: a machine for performing calculations automatically
#   Lemmas: ['computer', 'computing_machine', 'computing_device', 'data_processor', 'electronic_computer', 'information_processing_system']
#
#   All Hypernym Paths:
#     Path 1: entity -> physical_entity -> object -> whole -> artifact -> instrumentality -> device -> machine -> computer
#
#   Total hyponyms found: 10
#   All hyponyms:
#     - predictor.n.03: a computer for controlling antiaircraft fire that computes the position of an aircraft at the instant of a shell's arrival
#     - web_site.n.01: a computer connected to the internet that maintains a series of web pages on the World Wide Web
#     - server.n.03: (computer science) a computer that provides client stations with access to files and printers as shared resources to a computer network
#     - analog_computer.n.01: a computer that represents information by variable quantities (e.g., positions or voltages)
#     - turing_machine.n.01: a hypothetical computer with an infinitely long memory tape
#     - number_cruncher.n.02: a computer capable of performing a large number of mathematical operations per second
#     - home_computer.n.01: a computer intended for use in the home
#     - pari-mutuel_machine.n.01: computer that registers bets and divides the total amount bet among those who won
#     - node.n.08: (computer science) any computer that is hooked up to a computer network
#     - digital_computer.n.01: a computer that represents information by numerical (binary) digits
#
# DEEP ANALYSIS FOR: 'company'
#   Definition: an institution created to conduct business
#   Lemmas: ['company']
#
#   All Hypernym Paths:
#     Path 1: entity -> abstraction -> group -> social_group -> organization -> institution -> company
#
#   Total hyponyms found: 36
#   All hyponyms:
#     - shipping_company.n.01: a company that provides shipping services
#     - food_company.n.01: a company that processes and sells food
#     - mover.n.04: a company that moves the possessions of a family or business from one site to another
#     - transportation_company.n.01: a company providing transportation
#     - union_shop.n.01: a company allowed to hire nonunion workers on the condition that they will join the union within a specified time
#     - pipeline_company.n.01: a company that operates oil pipelines for the oil industry
#     - mining_company.n.01: a company that owns and manages mines
#     - open_shop.n.01: a company whose workers are hired without regard to their membership in a labor union
#     - joint-stock_company.n.01: a company (usually unincorporated) which has the capital of its members pooled in a common fund; transferable shares represent ownership interest; shareholders are legally liable for all debts of the company
#     - printing_concern.n.01: a company that does commercial printing
#     - stock_company.n.01: a company whose capital is represented by stock
#     - white_knight.n.01: a company that is a friendly acquirer in a takeover
#     - film_company.n.01: a company that makes, advertises, and distributes movies
#     - distributor.n.03: a company that markets merchandise
#     - drug_company.n.01: a company that makes and sells pharmaceuticals
#     - shipper.n.02: a company in the business of shipping freight
#     - service.n.04: a company or agency that performs a public service; subject to government regulation
#     - limited_company.n.01: a company that is organized to give its owners limited liability
#     - livery_company.n.01: one of the chartered companies of London originating with the craft guilds
#     - record_company.n.01: a company that makes and sells musical recordings
#     - electronics_company.n.01: a company that makes and sells electronic instruments
#     - subsidiary_company.n.01: a company that is completely controlled by another company
#     - corporate_investor.n.01: a company that invests in (acquires control of) other companies
#     - car_company.n.01: a company that makes and sells automobiles
#     - packaging_company.n.01: a company that packages goods for sale or shipment or storage
#     - holding_company.n.01: a company with controlling shares in other companies
#     - target_company.n.01: a company that has been chosen as attractive for takeover by a potential acquirer
#     - oil_company.n.01: a company that sells oil
#     - east_india_company.n.01: an English company formed in 1600 to develop trade with the new British colonies in India and southeastern Asia; in the 18th century it assumed administrative control of Bengal and held it until the British army took over in 1858 after the Indian Mutiny
#     - bureau_de_change.n.01: (French) an establishment where you can exchange foreign money
#     - broadcasting_company.n.01: a company that manages tv or radio stations
#     - closed_shop.n.01: a company that hires only union members
#     - think_tank.n.01: a company that does research for hire and issues reports on the implications
#     - furniture_company.n.01: a company that sells furniture
#     - dot-com.n.01: a company that operates its business primarily on the internet using a URL that ends in `.com'
#     - steel_company.n.01: a company that makes and sells steel
#
# DEEP ANALYSIS FOR: 'inventor'
#   Definition: someone who is the first to think of or make something
#   Lemmas: ['inventor', 'discoverer', 'artificer']
#
#   All Hypernym Paths:
#     Path 1: entity -> physical_entity -> object -> whole -> living_thing -> organism -> person -> creator -> inventor
#     Path 2: entity -> physical_entity -> causal_agent -> person -> creator -> inventor
#
#   Total hyponyms found: 1
#   All hyponyms:
#     - patentee.n.01: the inventor to whom a patent is issued
#
# DEEP ANALYSIS FOR: 'founder'
#   Definition: inflammation of the laminated tissue that attaches the hoof to the foot of a horse
#   Lemmas: ['laminitis', 'founder']
#
#   All Hypernym Paths:
#     Path 1: entity -> abstraction -> psychological_feature -> cognition -> information -> evidence -> symptom -> inflammation -> laminitis
#
#   Total hyponyms found: 0
#
# DEEP ANALYSIS FOR: 'ceo'
#   Definition: the corporate executive responsible for the operations of the firm; reports to a board of directors; may appoint other managers (including a president)
#   Lemmas: ['chief_executive_officer', 'CEO', 'chief_operating_officer']
#
#   All Hypernym Paths:
#     Path 1: entity -> physical_entity -> object -> whole -> living_thing -> organism -> person -> leader -> head -> administrator -> executive -> corporate_executive -> chief_executive_officer
#     Path 2: entity -> physical_entity -> causal_agent -> person -> leader -> head -> administrator -> executive -> corporate_executive -> chief_executive_officer
#
#   Total hyponyms found: 0
#
# DEEP ANALYSIS FOR: 'pixar'
#
# DEEP ANALYSIS FOR: 'next'
#   Definition: immediately following in time or order
#   Lemmas: ['following', 'next']
#
#   All Hypernym Paths:
#     Path 1: following
#
#   Total hyponyms found: 0

# %% [markdown]
# # Summary of All Operations

# %%
# Cell 15: Summary of All Operations
print("SUMMARY OF ALL OPERATIONS PERFORMED")

print(f"1. CLEANING:")
print(f"   - Original text length: {len(raw_text)} characters")
print(f"   - Cleaned text length: {len(text_cleaned)} characters")
print(f"   - Characters removed: {len(raw_text) - len(text_cleaned)}")

print(f"\n2. LOWERCASING:")
print(f"   - Original text length: {len(text_cleaned)} characters")
print(f"   - Lowercased text length: {len(text_lower)} characters")

print(f"\n3. PUNCTUATION REMOVAL:")
print(f"   - Before removal: {len(text_lower)} characters")
print(f"   - After removal: {len(text_no_punct)} characters")
print(f"   - Punctuation removed: {len(text_lower) - len(text_no_punct)}")

print(f"\n4. STOPWORD REMOVAL:")
print(f"   - Tokens before: {len(tokens)}")
print(f"   - Tokens after: {len(filtered_tokens)}")
print(f"   - Stopwords removed: {len(tokens) - len(filtered_tokens)}")

print(f"\n5. TOKENIZATION:")
print(f"   - Number of sentences: {len(sentences)}")
print(f"   - Number of words: {len(words)}")
print(f"   - Number of characters (no spaces): {len(chars)}")

print(f"\n6. STEMMING:")
print(f"   - Original tokens: {len(filtered_tokens)}")
print(f"   - Porter stemmed tokens: {len(porter_stemmed_tokens)}")
print(f"   - Snowball stemmed tokens: {len(snowball_stemmed_tokens)}")

print(f"\n7. LEMMATIZATION:")
print(f"   - Original tokens: {len(filtered_tokens)}")
print(f"   - Lemmatized tokens: {len(lemmatized_tokens)}")

print(f"\n8. POS TAGGING:")
print(f"   - Number of words tagged: {len(pos_tagged)}")

print(f"\n9. CHUNKING:")
print(f"   - Processed all sentences: {len(all_sentences)} sentences")

print(f"\n10. PARSING:")
print(f"    - Dependency parsing: Complete text processed (Full output shown)")
print(f"    - Tree parsing: All sentences processed (Full output shown)")

print(f"\n11. HYPERNYMS & HYPONYMS:")
print(f"    - Unique words analyzed: {len(unique_words)} words")
print(f"    - Key words analyzed: {len(key_words)} words")
# Out:
# SUMMARY OF ALL OPERATIONS PERFORMED
# 1. CLEANING:
#    - Original text length: 600 characters
#    - Cleaned text length: 548 characters
#    - Characters removed: 52
#
# 2. LOWERCASING:
#    - Original text length: 548 characters
#    - Lowercased text length: 548 characters
#
# 3. PUNCTUATION REMOVAL:
#    - Before removal: 548 characters
#    - After removal: 527 characters
#    - Punctuation removed: 21
#
# 4. STOPWORD REMOVAL:
#    - Tokens before: 8
#    - Tokens after: 58
#    - Stopwords removed: -50
#
# 5. TOKENIZATION:
#    - Number of sentences: 6
#    - Number of words: 88
#    - Number of characters (no spaces): 461
#
# 6. STEMMING:
#    - Original tokens: 58
#    - Porter stemmed tokens: 58
#    - Snowball stemmed tokens: 58
#
# 7. LEMMATIZATION:
#    - Original tokens: 58
#    - Lemmatized tokens: 58
#
# 8. POS TAGGING:
#    - Number of words tagged: 58
#
# 9. CHUNKING:
#    - Processed all sentences: 6 sentences
#
# 10. PARSING:
#     - Dependency parsing: Complete text processed (Full output shown)
#     - Tree parsing: All sentences processed (Full output shown)
#
# 11. HYPERNYMS & HYPONYMS:
#     - Unique words analyzed: 58 words
#     - Key words analyzed: 8 words
