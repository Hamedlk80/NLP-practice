# %% [markdown]
# # practice one

# %% [markdown]
# # mabahese vizhe

# %% [markdown]
# # Mohammadali Lotfi kooshali      -        404198471

# %% [markdown]
# # install , download and import libraries

# %%
# !pip install spacy nltk
# !python -m spacy download en_core_web_sm

import re
import spacy
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize, sent_tokenize
from nltk.stem import PorterStemmer, WordNetLemmatizer, SnowballStemmer
from nltk import pos_tag
from nltk.corpus import wordnet as wn
from string import punctuation
from nltk.chunk import RegexpParser
from nltk import Tree
import time

# Download required NLTK data
nltk.download('punkt')
nltk.download('stopwords')
nltk.download('wordnet')
nltk.download('averaged_perceptron_tagger')
nltk.download('omw-1.4')

# Load spaCy model
nlp = spacy.load("en_core_web_sm")
# Out:
# Requirement already satisfied: spacy in D:\.venv\Lib\site-packages (3.8.14)
# Requirement already satisfied: nltk in D:\.venv\Lib\site-packages (3.9.4)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in D:\.venv\Lib\site-packages (from spacy) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in D:\.venv\Lib\site-packages (from spacy) (1.0.0)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in D:\.venv\Lib\site-packages (from spacy) (1.0.10)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in D:\.venv\Lib\site-packages (from spacy) (2.0.13)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in D:\.venv\Lib\site-packages (from spacy) (3.0.13)
# Requirement already satisfied: thinc<8.4.0,>=8.3.12 in D:\.venv\Lib\site-packages (from spacy) (8.3.13)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in D:\.venv\Lib\site-packages (from spacy) (0.10.1)
# Requirement already satisfied: srsly<3.0.0,>=2.5.3 in D:\.venv\Lib\site-packages (from spacy) (2.5.3)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in D:\.venv\Lib\site-packages (from spacy) (2.0.10)
# Requirement already satisfied: weasel<2.0.0,>=1.0.0 in D:\.venv\Lib\site-packages (from spacy) (1.0.0)
# Requirement already satisfied: confection<2.0.0,>=1.3.2 in D:\.venv\Lib\site-packages (from spacy) (1.3.3)
# Requirement already satisfied: typer<1.0.0,>=0.3.0 in D:\.venv\Lib\site-packages (from spacy) (0.23.1)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in D:\.venv\Lib\site-packages (from spacy) (4.67.3)
# Requirement already satisfied: numpy>=1.19.0 in D:\.venv\Lib\site-packages (from spacy) (2.3.5)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in D:\.venv\Lib\site-packages (from spacy) (2.32.5)
# Requirement already satisfied: pydantic<3.0.0,>=2.0.0 in D:\.venv\Lib\site-packages (from spacy) (2.12.5)
# Requirement already satisfied: jinja2 in D:\.venv\Lib\site-packages (from spacy) (3.1.6)
# Requirement already satisfied: setuptools in D:\.venv\Lib\site-packages (from spacy) (81.0.0)
# Requirement already satisfied: packaging>=20.0 in D:\.venv\Lib\site-packages (from spacy) (25.0)
# Requirement already satisfied: annotated-types>=0.6.0 in D:\.venv\Lib\site-packages (from pydantic<3.0.0,>=2.0.0->spacy) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in D:\.venv\Lib\site-packages (from pydantic<3.0.0,>=2.0.0->spacy) (2.41.5)
# Requirement already satisfied: typing-extensions>=4.14.1 in D:\.venv\Lib\site-packages (from pydantic<3.0.0,>=2.0.0->spacy) (4.15.0)
# Requirement already satisfied: typing-inspection>=0.4.2 in D:\.venv\Lib\site-packages (from pydantic<3.0.0,>=2.0.0->spacy) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in D:\.venv\Lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in D:\.venv\Lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in D:\.venv\Lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (2.6.3)
# Requirement already satisfied: certifi>=2017.4.17 in D:\.venv\Lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (2026.1.4)
# Requirement already satisfied: blis<1.4.0,>=1.3.0 in D:\.venv\Lib\site-packages (from thinc<8.4.0,>=8.3.12->spacy) (1.3.3)
# Requirement already satisfied: colorama in D:\.venv\Lib\site-packages (from tqdm<5.0.0,>=4.38.0->spacy) (0.4.6)
# Requirement already satisfied: click>=8.0.0 in D:\.venv\Lib\site-packages (from typer<1.0.0,>=0.3.0->spacy) (8.3.1)
# Requirement already satisfied: shellingham>=1.3.0 in D:\.venv\Lib\site-packages (from typer<1.0.0,>=0.3.0->spacy) (1.5.4)
# Requirement already satisfied: rich>=10.11.0 in D:\.venv\Lib\site-packages (from typer<1.0.0,>=0.3.0->spacy) (14.3.2)
# Requirement already satisfied: annotated-doc>=0.0.2 in D:\.venv\Lib\site-packages (from typer<1.0.0,>=0.3.0->spacy) (0.0.4)
# Requirement already satisfied: cloudpathlib>=0.7.0 in D:\.venv\Lib\site-packages (from weasel<2.0.0,>=1.0.0->spacy) (0.23.0)
# Requirement already satisfied: smart-open>=5.2.1 in D:\.venv\Lib\site-packages (from weasel<2.0.0,>=1.0.0->spacy) (7.6.0)
# Requirement already satisfied: httpx>=0.24.0 in D:\.venv\Lib\site-packages (from weasel<2.0.0,>=1.0.0->spacy) (0.28.1)
# Requirement already satisfied: joblib in D:\.venv\Lib\site-packages (from nltk) (1.5.3)
# Requirement already satisfied: regex>=2021.8.3 in D:\.venv\Lib\site-packages (from nltk) (2026.1.15)
# Requirement already satisfied: anyio in D:\.venv\Lib\site-packages (from httpx>=0.24.0->weasel<2.0.0,>=1.0.0->spacy) (4.12.1)
# Requirement already satisfied: httpcore==1.* in D:\.venv\Lib\site-packages (from httpx>=0.24.0->weasel<2.0.0,>=1.0.0->spacy) (1.0.9)
# Requirement already satisfied: h11>=0.16 in D:\.venv\Lib\site-packages (from httpcore==1.*->httpx>=0.24.0->weasel<2.0.0,>=1.0.0->spacy) (0.16.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in D:\.venv\Lib\site-packages (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in D:\.venv\Lib\site-packages (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in D:\.venv\Lib\site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy) (0.1.2)
# Requirement already satisfied: wrapt in D:\.venv\Lib\site-packages (from smart-open>=5.2.1->weasel<2.0.0,>=1.0.0->spacy) (2.1.2)
# Requirement already satisfied: MarkupSafe>=2.0 in D:\.venv\Lib\site-packages (from jinja2->spacy) (3.0.3)
#   WARNING: Retrying (Retry(total=4, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ProtocolError('Connection aborted.', ConnectionResetError(10054, 'An existing connection was forcibly closed by the remote host', None, 10054, None))': /github-production-release-asset/84940268/15132ab6-4050-4914-8fe8-ac2c2fdcb9cf?sp=r&sv=2018-11-09&sr=b&spr=https&se=2026-04-27T22%3A09%3A20Z&rscd=attachment%3B+filename%3Den_core_web_sm-3.8.0-py3-none-any.whl&rsct=application%2Foctet-stream&skoid=96c2d410-5711-43a1-aedd-ab1947aa7ab0&sktid=398a6654-997b-47e9-b12b-9515b896b4de&skt=2026-04-27T21%3A08%3A22Z&ske=2026-04-27T22%3A09%3A20Z&sks=b&skv=2018-11-09&sig=J0Gr6KtrqJzvo%2B5M2chIwZu%2BoXn5g%2BqVZPFFGDWrSvI%3D&jwt=eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9.eyJpc3MiOiJnaXRodWIuY29tIiwiYXVkIjoicmVsZWFzZS1hc3NldHMuZ2l0aHVidXNlcmNvbnRlbnQuY29tIiwia2V5Ijoia2V5MSIsImV4cCI6MTc3NzMyNjc3OCwibmJmIjoxNzc3MzI0OTc4LCJwYXRoIjoicmVsZWFzZWFzc2V0cHJvZHVjdGlvbi5ibG9iLmNvcmUud2luZG93cy5uZXQifQ.4dGYTgx8awPpf351N13ZTtckCAZpMLp-KtB81uc0NUo&response-content-disposition=attachment%3B%20filename%3Den_core_web_sm-3.8.0-py3-none-any.whl&response-content-type=application%2Foctet-stream
#   WARNING: Retrying (Retry(total=3, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ProtocolError('Connection aborted.', ConnectionResetError(10054, 'An existing connection was forcibly closed by the remote host', None, 10054, None))': /github-production-release-asset/84940268/15132ab6-4050-4914-8fe8-ac2c2fdcb9cf?sp=r&sv=2018-11-09&sr=b&spr=https&se=2026-04-27T22%3A09%3A20Z&rscd=attachment%3B+filename%3Den_core_web_sm-3.8.0-py3-none-any.whl&rsct=application%2Foctet-stream&skoid=96c2d410-5711-43a1-aedd-ab1947aa7ab0&sktid=398a6654-997b-47e9-b12b-9515b896b4de&skt=2026-04-27T21%3A08%3A22Z&ske=2026-04-27T22%3A09%3A20Z&sks=b&skv=2018-11-09&sig=J0Gr6KtrqJzvo%2B5M2chIwZu%2BoXn5g%2BqVZPFFGDWrSvI%3D&jwt=eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9.eyJpc3MiOiJnaXRodWIuY29tIiwiYXVkIjoicmVsZWFzZS1hc3NldHMuZ2l0aHVidXNlcmNvbnRlbnQuY29tIiwia2V5Ijoia2V5MSIsImV4cCI6MTc3NzMyNjc3OCwibmJmIjoxNzc3MzI0OTc4LCJwYXRoIjoicmVsZWFzZWFzc2V0cHJvZHVjdGlvbi5ibG9iLmNvcmUud2luZG93cy5uZXQifQ.4dGYTgx8awPpf351N13ZTtckCAZpMLp-KtB81uc0NUo&response-content-disposition=attachment%3B%20filename%3Den_core_web_sm-3.8.0-py3-none-any.whl&response-content-type=application%2Foctet-stream
#   WARNING: Retrying (Retry(total=2, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ProtocolError('Connection aborted.', ConnectionResetError(10054, 'An existing connection was forcibly closed by the remote host', None, 10054, None))': /github-production-release-asset/84940268/15132ab6-4050-4914-8fe8-ac2c2fdcb9cf?sp=r&sv=2018-11-09&sr=b&spr=https&se=2026-04-27T22%3A09%3A20Z&rscd=attachment%3B+filename%3Den_core_web_sm-3.8.0-py3-none-any.whl&rsct=application%2Foctet-stream&skoid=96c2d410-5711-43a1-aedd-ab1947aa7ab0&sktid=398a6654-997b-47e9-b12b-9515b896b4de&skt=2026-04-27T21%3A08%3A22Z&ske=2026-04-27T22%3A09%3A20Z&sks=b&skv=2018-11-09&sig=J0Gr6KtrqJzvo%2B5M2chIwZu%2BoXn5g%2BqVZPFFGDWrSvI%3D&jwt=eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9.eyJpc3MiOiJnaXRodWIuY29tIiwiYXVkIjoicmVsZWFzZS1hc3NldHMuZ2l0aHVidXNlcmNvbnRlbnQuY29tIiwia2V5Ijoia2V5MSIsImV4cCI6MTc3NzMyNjc3OCwibmJmIjoxNzc3MzI0OTc4LCJwYXRoIjoicmVsZWFzZWFzc2V0cHJvZHVjdGlvbi5ibG9iLmNvcmUud2luZG93cy5uZXQifQ.4dGYTgx8awPpf351N13ZTtckCAZpMLp-KtB81uc0NUo&response-content-disposition=attachment%3B%20filename%3Den_core_web_sm-3.8.0-py3-none-any.whl&response-content-type=application%2Foctet-stream
#   WARNING: Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ProtocolError('Connection aborted.', ConnectionResetError(10054, 'An existing connection was forcibly closed by the remote host', None, 10054, None))': /github-production-release-asset/84940268/15132ab6-4050-4914-8fe8-ac2c2fdcb9cf?sp=r&sv=2018-11-09&sr=b&spr=https&se=2026-04-27T22%3A09%3A20Z&rscd=attachment%3B+filename%3Den_core_web_sm-3.8.0-py3-none-any.whl&rsct=application%2Foctet-stream&skoid=96c2d410-5711-43a1-aedd-ab1947aa7ab0&sktid=398a6654-997b-47e9-b12b-9515b896b4de&skt=2026-04-27T21%3A08%3A22Z&ske=2026-04-27T22%3A09%3A20Z&sks=b&skv=2018-11-09&sig=J0Gr6KtrqJzvo%2B5M2chIwZu%2BoXn5g%2BqVZPFFGDWrSvI%3D&jwt=eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9.eyJpc3MiOiJnaXRodWIuY29tIiwiYXVkIjoicmVsZWFzZS1hc3NldHMuZ2l0aHVidXNlcmNvbnRlbnQuY29tIiwia2V5Ijoia2V5MSIsImV4cCI6MTc3NzMyNjc3OCwibmJmIjoxNzc3MzI0OTc4LCJwYXRoIjoicmVsZWFzZWFzc2V0cHJvZHVjdGlvbi5ibG9iLmNvcmUud2luZG93cy5uZXQifQ.4dGYTgx8awPpf351N13ZTtckCAZpMLp-KtB81uc0NUo&response-content-disposition=attachment%3B%20filename%3Den_core_web_sm-3.8.0-py3-none-any.whl&response-content-type=application%2Foctet-stream
#   WARNING: Retrying (Retry(total=0, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ProtocolError('Connection aborted.', ConnectionResetError(10054, 'An existing connection was forcibly closed by the remote host', None, 10054, None))': /github-production-release-asset/84940268/15132ab6-4050-4914-8fe8-ac2c2fdcb9cf?sp=r&sv=2018-11-09&sr=b&spr=https&se=2026-04-27T22%3A09%3A20Z&rscd=attachment%3B+filename%3Den_core_web_sm-3.8.0-py3-none-any.whl&rsct=application%2Foctet-stream&skoid=96c2d410-5711-43a1-aedd-ab1947aa7ab0&sktid=398a6654-997b-47e9-b12b-9515b896b4de&skt=2026-04-27T21%3A08%3A22Z&ske=2026-04-27T22%3A09%3A20Z&sks=b&skv=2018-11-09&sig=J0Gr6KtrqJzvo%2B5M2chIwZu%2BoXn5g%2BqVZPFFGDWrSvI%3D&jwt=eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9.eyJpc3MiOiJnaXRodWIuY29tIiwiYXVkIjoicmVsZWFzZS1hc3NldHMuZ2l0aHVidXNlcmNvbnRlbnQuY29tIiwia2V5Ijoia2V5MSIsImV4cCI6MTc3NzMyNjc3OCwibmJmIjoxNzc3MzI0OTc4LCJwYXRoIjoicmVsZWFzZWFzc2V0cHJvZHVjdGlvbi5ibG9iLmNvcmUud2luZG93cy5uZXQifQ.4dGYTgx8awPpf351N13ZTtckCAZpMLp-KtB81uc0NUo&response-content-disposition=attachment%3B%20filename%3Den_core_web_sm-3.8.0-py3-none-any.whl&response-content-type=application%2Foctet-stream
# ERROR: Could not install packages due to an OSError: HTTPSConnectionPool(host='release-assets.githubusercontent.com', port=443): Max retries exceeded with url: /github-production-release-asset/84940268/15132ab6-4050-4914-8fe8-ac2c2fdcb9cf?sp=r&sv=2018-11-09&sr=b&spr=https&se=2026-04-27T22%3A09%3A20Z&rscd=attachment%3B+filename%3Den_core_web_sm-3.8.0-py3-none-any.whl&rsct=application%2Foctet-stream&skoid=96c2d410-5711-43a1-aedd-ab1947aa7ab0&sktid=398a6654-997b-47e9-b12b-9515b896b4de&skt=2026-04-27T21%3A08%3A22Z&ske=2026-04-27T22%3A09%3A20Z&sks=b&skv=2018-11-09&sig=J0Gr6KtrqJzvo%2B5M2chIwZu%2BoXn5g%2BqVZPFFGDWrSvI%3D&jwt=eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9.eyJpc3MiOiJnaXRodWIuY29tIiwiYXVkIjoicmVsZWFzZS1hc3NldHMuZ2l0aHVidXNlcmNvbnRlbnQuY29tIiwia2V5Ijoia2V5MSIsImV4cCI6MTc3NzMyNjc3OCwibmJmIjoxNzc3MzI0OTc4LCJwYXRoIjoicmVsZWFzZWFzc2V0cHJvZHVjdGlvbi5ibG9iLmNvcmUud2luZG93cy5uZXQifQ.4dGYTgx8awPpf351N13ZTtckCAZpMLp-KtB81uc0NUo&response-content-disposition=attachment%3B%20filename%3Den_core_web_sm-3.8.0-py3-none-any.whl&response-content-type=application%2Foctet-stream (Caused by ProtocolError('Connection aborted.', ConnectionResetError(10054, 'An existing connection was forcibly closed by the remote host', None, 10054, None)))
# Collecting en-core-web-sm==3.8.0
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\ASUS\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\ASUS\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\ASUS\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     C:\Users\ASUS\AppData\Roaming\nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package omw-1.4 to
# [nltk_data]     C:\Users\ASUS\AppData\Roaming\nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!

# %% [markdown]
# # reading text file

# %%
with open('amazon_review.txt', 'r', encoding='utf-8') as file:
    raw_text = file.read()

print("original text:")
print(raw_text)
print(f"Total characters: {len(raw_text)}")
# Out:
# original text:
# ⭐️⭐️⭐️⭐️☆ (4/5 stars)
#
# Title: "Great product but has minor issues"
#
# I bought the SmartHome Hub X200 ($149.99) last month.
#
# Pros:
# - Easy setup (took 5 minutes) ✅
# - Voice control works perfectly 🎤
# - Compatible with Alexa and Google Home 🤖
#
# Cons:
# - Mobile app crashes sometimes 🐛
# - Customer service responded after 48 hours (too slow!) ⏰
#
# Overall, I recommend it. 4 stars!
#
# Check my video review: https://youtu.be/smarthome_x200_review
#
# #SmartHome #TechReview #HonestOpinion
# Total characters: 473

# %% [markdown]
# # 1. Cleaning Text with re.sub

# %%
# Remove numbers
text_no_numbers = re.sub(r'\d+', '', raw_text)
print("After removing numbers:")
print(text_no_numbers)
print("-" * 80)

# Remove extra whitespaces
text_cleaned = re.sub(r'\s+', ' ', text_no_numbers)
print("After removing extra whitespaces:")
print(text_cleaned)
print("-" * 80)

# Remove special characters (keep letters, spaces, dots, commas)
text_cleaned = re.sub(r'[^\w\s\.\,]', '', text_cleaned)
print("After removing special characters:")
print(text_cleaned)
print(f"Cleaned text length: {len(text_cleaned)} characters")
# Out:
# After removing numbers:
# ⭐️⭐️⭐️⭐️☆ (/ stars)
#
# Title: "Great product but has minor issues"
#
# I bought the SmartHome Hub X ($.) last month.
#
# Pros:
# - Easy setup (took  minutes) ✅
# - Voice control works perfectly 🎤
# - Compatible with Alexa and Google Home 🤖
#
# Cons:
# - Mobile app crashes sometimes 🐛
# - Customer service responded after  hours (too slow!) ⏰
#
# Overall, I recommend it.  stars!
#
# Check my video review: https://youtu.be/smarthome_x_review
#
# #SmartHome #TechReview #HonestOpinion
# --------------------------------------------------------------------------------
# After removing extra whitespaces:
# ⭐️⭐️⭐️⭐️☆ (/ stars) Title: "Great product but has minor issues" I bought the SmartHome Hub X ($.) last month. Pros: - Easy setup (took minutes) ✅ - Voice control works perfectly 🎤 - Compatible with Alexa and Google Home 🤖 Cons: - Mobile app crashes sometimes 🐛 - Customer service responded after hours (too slow!) ⏰ Overall, I recommend it. stars! Check my video review: https://youtu.be/smarthome_x_review #SmartHome #TechReview #HonestOpinion
# --------------------------------------------------------------------------------
# After removing special characters:
#   stars Title Great product but has minor issues I bought the SmartHome Hub X . last month. Pros  Easy setup took minutes   Voice control works perfectly   Compatible with Alexa and Google Home  Cons  Mobile app crashes sometimes   Customer service responded after hours too slow  Overall, I recommend it. stars Check my video review httpsyoutu.besmarthome_x_review SmartHome TechReview HonestOpinion
# Cleaned text length: 400 characters

# %% [markdown]
# # 2. Lowercasing

# %%
text_lower = text_cleaned.lower()
print("Text after lowercasing:")
print(text_lower)
# Out:
# Text after lowercasing:
#   stars title great product but has minor issues i bought the smarthome hub x . last month. pros  easy setup took minutes   voice control works perfectly   compatible with alexa and google home  cons  mobile app crashes sometimes   customer service responded after hours too slow  overall, i recommend it. stars check my video review httpsyoutu.besmarthome_x_review smarthome techreview honestopinion

# %% [markdown]
# # 3. Punctuation Removal

# %%
print("Punctuation removed:", punctuation)
text_no_punct = ''.join([char for char in text_lower if char not in punctuation])
print("Text after punctuation removal:")
print(text_no_punct)
# Out:
# Punctuation removed: !"#$%&'()*+,-./:;<=>?@[\]^_`{|}~
# Text after punctuation removal:
#   stars title great product but has minor issues i bought the smarthome hub x  last month pros  easy setup took minutes   voice control works perfectly   compatible with alexa and google home  cons  mobile app crashes sometimes   customer service responded after hours too slow  overall i recommend it stars check my video review httpsyoutubesmarthomexreview smarthome techreview honestopinion

# %% [markdown]
# # 4. Stopword Removal

# %%
# Get English stopwords
stop_words = set(stopwords.words('english'))
print("English stopwords :")
print(list(stop_words))

# Tokenize first
tokens = word_tokenize(text_no_punct)
print(f"Total tokens before stopword removal: {len(tokens)}")
print("tokens before removal:")
print(tokens)

# Remove stopwords
filtered_tokens = [word for word in tokens if word not in stop_words]
print(f"Total tokens after stopword removal: {len(filtered_tokens)}")
print("tokens after removal:")
print(filtered_tokens)

# Convert back to text
text_no_stopwords = ' '.join(filtered_tokens)
print("Complete text after stopword removal:")
print(text_no_stopwords)
# Out:
# English stopwords :
# ['won', 'wasn', 'why', 'me', 'not', "isn't", "i'll", 'more', 'd', 'she', 'her', 'don', 'shan', "it'll", 'too', 'until', 'only', 'his', 'own', 'who', 'out', 'm', "he'll", "weren't", 'no', 'because', 'further', "he's", 'its', 'as', 'both', 'weren', 'ma', 'against', "needn't", 'at', 'himself', 'into', 'they', 'here', 'same', 'being', 'my', 'myself', 'there', 'few', 'so', 'y', "you'll", 'can', 'during', 'do', 'a', "mustn't", "they'd", 'with', 'on', 'him', "mightn't", "you'd", 'while', 'is', 'very', 'o', "you're", 'if', 'but', 'doing', 'shouldn', 'was', "we're", "we've", 'mustn', "we'll", 'what', 'up', 'ourselves', "it's", 'that', 'nor', 'off', "she'll", 'all', 'them', 'you', 'or', 'been', 'once', "she's", "it'd", 'the', "shouldn't", 'before', 'mightn', 'yourself', 'needn', 'to', 'and', "don't", 'under', "wouldn't", 'then', 'ain', 'yourselves', 'our', "shan't", 'should', 'll', 'by', 'hers', 'were', 'down', 'which', 'wouldn', 'had', 'hasn', "couldn't", "that'll", 'those', 'i', 'themselves', "he'd", 'doesn', 're', 'such', 'will', 'between', "they'll", 'didn', 'be', 'about', 'above', 'below', 'how', 'of', "wasn't", 'does', 'other', 'in', "they've", 've', 'through', 'have', 'has', 'hadn', "she'd", "haven't", 'over', "aren't", "didn't", 'your', 'herself', 'these', 'from', 'after', 'ours', 'aren', "won't", "hasn't", 'their', 'just', 't', 'am', 's', 'haven', 'some', 'did', "you've", 'having', 'isn', 'whom', 'an', 'each', 'we', 'now', 'most', 'again', "i've", "they're", 'are', 'any', 'he', "i'd", 'for', 'theirs', 'itself', 'this', "should've", "doesn't", 'it', 'when', 'couldn', 'than', 'yours', "we'd", "i'm", 'where', "hadn't"]
# Total tokens before stopword removal: 56
# tokens before removal:
# ['stars', 'title', 'great', 'product', 'but', 'has', 'minor', 'issues', 'i', 'bought', 'the', 'smarthome', 'hub', 'x', 'last', 'month', 'pros', 'easy', 'setup', 'took', 'minutes', 'voice', 'control', 'works', 'perfectly', 'compatible', 'with', 'alexa', 'and', 'google', 'home', 'cons', 'mobile', 'app', 'crashes', 'sometimes', 'customer', 'service', 'responded', 'after', 'hours', 'too', 'slow', 'overall', 'i', 'recommend', 'it', 'stars', 'check', 'my', 'video', 'review', 'httpsyoutubesmarthomexreview', 'smarthome', 'techreview', 'honestopinion']
# Total tokens after stopword removal: 45
# tokens after removal:
# ['stars', 'title', 'great', 'product', 'minor', 'issues', 'bought', 'smarthome', 'hub', 'x', 'last', 'month', 'pros', 'easy', 'setup', 'took', 'minutes', 'voice', 'control', 'works', 'perfectly', 'compatible', 'alexa', 'google', 'home', 'cons', 'mobile', 'app', 'crashes', 'sometimes', 'customer', 'service', 'responded', 'hours', 'slow', 'overall', 'recommend', 'stars', 'check', 'video', 'review', 'httpsyoutubesmarthomexreview', 'smarthome', 'techreview', 'honestopinion']
# Complete text after stopword removal:
# stars title great product minor issues bought smarthome hub x last month pros easy setup took minutes voice control works perfectly compatible alexa google home cons mobile app crashes sometimes customer service responded hours slow overall recommend stars check video review httpsyoutubesmarthomexreview smarthome techreview honestopinion

# %% [markdown]
# # 5. Tokenization (Sentence, Word, Character)

# %%
# Sentence Tokenization
sentences = sent_tokenize(text_lower)
print("Sentence Tokenization:")
print(f"Total number of sentences: {len(sentences)}")
print("All sentences:")
for i, sent in enumerate(sentences, 1):
    print(f"{i}. {sent}")

# Word Tokenization
words = word_tokenize(text_lower)
print("Word Tokenization:")
print(f"Total number of words: {len(words)}")
print("All words:")
print(words)

# Character Tokenization
chars = [char for char in text_lower if char != ' ']
print("Character Tokenization:")
print(f"Total number of characters (without spaces): {len(chars)}")
print("All characters:")
print(chars)
# Out:
# Sentence Tokenization:
# Total number of sentences: 4
# All sentences:
# 1.   stars title great product but has minor issues i bought the smarthome hub x .
# 2. last month.
# 3. pros  easy setup took minutes   voice control works perfectly   compatible with alexa and google home  cons  mobile app crashes sometimes   customer service responded after hours too slow  overall, i recommend it.
# 4. stars check my video review httpsyoutu.besmarthome_x_review smarthome techreview honestopinion
# Word Tokenization:
# Total number of words: 60
# All words:
# ['stars', 'title', 'great', 'product', 'but', 'has', 'minor', 'issues', 'i', 'bought', 'the', 'smarthome', 'hub', 'x', '.', 'last', 'month', '.', 'pros', 'easy', 'setup', 'took', 'minutes', 'voice', 'control', 'works', 'perfectly', 'compatible', 'with', 'alexa', 'and', 'google', 'home', 'cons', 'mobile', 'app', 'crashes', 'sometimes', 'customer', 'service', 'responded', 'after', 'hours', 'too', 'slow', 'overall', ',', 'i', 'recommend', 'it', '.', 'stars', 'check', 'my', 'video', 'review', 'httpsyoutu.besmarthome_x_review', 'smarthome', 'techreview', 'honestopinion']
# Character Tokenization:
# Total number of characters (without spaces): 332
# All characters:
# ['s', 't', 'a', 'r', 's', 't', 'i', 't', 'l', 'e', 'g', 'r', 'e', 'a', 't', 'p', 'r', 'o', 'd', 'u', 'c', 't', 'b', 'u', 't', 'h', 'a', 's', 'm', 'i', 'n', 'o', 'r', 'i', 's', 's', 'u', 'e', 's', 'i', 'b', 'o', 'u', 'g', 'h', 't', 't', 'h', 'e', 's', 'm', 'a', 'r', 't', 'h', 'o', 'm', 'e', 'h', 'u', 'b', 'x', '.', 'l', 'a', 's', 't', 'm', 'o', 'n', 't', 'h', '.', 'p', 'r', 'o', 's', 'e', 'a', 's', 'y', 's', 'e', 't', 'u', 'p', 't', 'o', 'o', 'k', 'm', 'i', 'n', 'u', 't', 'e', 's', 'v', 'o', 'i', 'c', 'e', 'c', 'o', 'n', 't', 'r', 'o', 'l', 'w', 'o', 'r', 'k', 's', 'p', 'e', 'r', 'f', 'e', 'c', 't', 'l', 'y', 'c', 'o', 'm', 'p', 'a', 't', 'i', 'b', 'l', 'e', 'w', 'i', 't', 'h', 'a', 'l', 'e', 'x', 'a', 'a', 'n', 'd', 'g', 'o', 'o', 'g', 'l', 'e', 'h', 'o', 'm', 'e', 'c', 'o', 'n', 's', 'm', 'o', 'b', 'i', 'l', 'e', 'a', 'p', 'p', 'c', 'r', 'a', 's', 'h', 'e', 's', 's', 'o', 'm', 'e', 't', 'i', 'm', 'e', 's', 'c', 'u', 's', 't', 'o', 'm', 'e', 'r', 's', 'e', 'r', 'v', 'i', 'c', 'e', 'r', 'e', 's', 'p', 'o', 'n', 'd', 'e', 'd', 'a', 'f', 't', 'e', 'r', 'h', 'o', 'u', 'r', 's', 't', 'o', 'o', 's', 'l', 'o', 'w', 'o', 'v', 'e', 'r', 'a', 'l', 'l', ',', 'i', 'r', 'e', 'c', 'o', 'm', 'm', 'e', 'n', 'd', 'i', 't', '.', 's', 't', 'a', 'r', 's', 'c', 'h', 'e', 'c', 'k', 'm', 'y', 'v', 'i', 'd', 'e', 'o', 'r', 'e', 'v', 'i', 'e', 'w', 'h', 't', 't', 'p', 's', 'y', 'o', 'u', 't', 'u', '.', 'b', 'e', 's', 'm', 'a', 'r', 't', 'h', 'o', 'm', 'e', '_', 'x', '_', 'r', 'e', 'v', 'i', 'e', 'w', 's', 'm', 'a', 'r', 't', 'h', 'o', 'm', 'e', 't', 'e', 'c', 'h', 'r', 'e', 'v', 'i', 'e', 'w', 'h', 'o', 'n', 'e', 's', 't', 'o', 'p', 'i', 'n', 'i', 'o', 'n']

# %% [markdown]
# # 6. Stemming (PorterStemmer and SnowballStemmer)

# %%
# Initialize both stemmers
porter_stemmer = PorterStemmer()
snowball_stemmer = SnowballStemmer("english")

# Apply both stemmers
porter_stemmed_tokens = [porter_stemmer.stem(word) for word in filtered_tokens]
snowball_stemmed_tokens = [snowball_stemmer.stem(word) for word in filtered_tokens]

print("COMPLETE COMPARISON (Original vs Porter vs Snowball):")
print(f"{'#':<5} | {'Original Word':<25} | {'Porter Stemmer':<20} | {'Snowball Stemmer':<20} | {'Difference'}")

difference_count = 0
for i, (original, porter, snowball) in enumerate(zip(filtered_tokens, porter_stemmed_tokens, snowball_stemmed_tokens), 1):
    difference = "DIFFERENT" if porter != snowball else "SAME"
    if porter != snowball:
        difference_count += 1
    print(f"{i:<5} | {original:<25} | {porter:<20} | {snowball:<20} | {difference}")

print(f"\nTotal words with different stemming results: {difference_count} out of {len(filtered_tokens)}")
print(f"Percentage of differences: {(difference_count/len(filtered_tokens))*100:.2f}%")

# Show detailed comparison for words that differ
print("\nDETAILED COMPARISON FOR WORDS WITH DIFFERENT STEMMING RESULTS:")

different_words = []
for original, porter, snowball in zip(filtered_tokens, porter_stemmed_tokens, snowball_stemmed_tokens):
    if porter != snowball:
        different_words.append((original, porter, snowball))

if different_words:
    print(f"{'#':<5} | {'Original Word':<25} | {'Porter Result':<20} | {'Snowball Result':<20} | {'Analysis'}")
    for i, (original, porter, snowball) in enumerate(different_words, 1):
        analysis = ""
        if len(porter) < len(snowball):
            analysis = "Porter shorter"
        elif len(snowball) < len(porter):
            analysis = "Snowball shorter"
        elif porter.endswith('ing') and not snowball.endswith('ing'):
            analysis = "Porter keeps -ing"
        elif snowball.endswith('ing') and not porter.endswith('ing'):
            analysis = "Snowball keeps -ing"
        else:
            analysis = "Different algorithm"
        print(f"{i:<5} | {original:<25} | {porter:<20} | {snowball:<20} | {analysis}")
else:
    print("No differences found between Porter and Snowball stemmers for this text.")

# Show complete stemmed texts
print("\nCOMPLETE PORTER STEMMED TEXT:")
porter_stemmed_text = ' '.join(porter_stemmed_tokens)
print(porter_stemmed_text)

print("\nCOMPLETE SNOWBALL STEMMED TEXT:")
snowball_stemmed_text = ' '.join(snowball_stemmed_tokens)
print(snowball_stemmed_text)

# Performance comparison
print("\nPERFORMANCE COMPARISON:")

# Test Porter speed
start_time = time.time()
for word in filtered_tokens * 10:
    porter_stemmer.stem(word)
porter_time = time.time() - start_time

# Test Snowball speed
start_time = time.time()
for word in filtered_tokens * 10:
    snowball_stemmer.stem(word)
snowball_time = time.time() - start_time

print(f"PorterStemmer processing time (10 repetitions): {porter_time:.6f} seconds")
print(f"SnowballStemmer processing time (10 repetitions): {snowball_time:.6f} seconds")
# Out:
# COMPLETE COMPARISON (Original vs Porter vs Snowball):
# #     | Original Word             | Porter Stemmer       | Snowball Stemmer     | Difference
# 1     | stars                     | star                 | star                 | SAME
# 2     | title                     | titl                 | titl                 | SAME
# 3     | great                     | great                | great                | SAME
# 4     | product                   | product              | product              | SAME
# 5     | minor                     | minor                | minor                | SAME
# 6     | issues                    | issu                 | issu                 | SAME
# 7     | bought                    | bought               | bought               | SAME
# 8     | smarthome                 | smarthom             | smarthom             | SAME
# 9     | hub                       | hub                  | hub                  | SAME
# 10    | x                         | x                    | x                    | SAME
# 11    | last                      | last                 | last                 | SAME
# 12    | month                     | month                | month                | SAME
# 13    | pros                      | pro                  | pros                 | DIFFERENT
# 14    | easy                      | easi                 | easi                 | SAME
# 15    | setup                     | setup                | setup                | SAME
# 16    | took                      | took                 | took                 | SAME
# 17    | minutes                   | minut                | minut                | SAME
# 18    | voice                     | voic                 | voic                 | SAME
# 19    | control                   | control              | control              | SAME
# 20    | works                     | work                 | work                 | SAME
# 21    | perfectly                 | perfectli            | perfect              | DIFFERENT
# 22    | compatible                | compat               | compat               | SAME
# 23    | alexa                     | alexa                | alexa                | SAME
# 24    | google                    | googl                | googl                | SAME
# 25    | home                      | home                 | home                 | SAME
# 26    | cons                      | con                  | con                  | SAME
# 27    | mobile                    | mobil                | mobil                | SAME
# 28    | app                       | app                  | app                  | SAME
# 29    | crashes                   | crash                | crash                | SAME
# 30    | sometimes                 | sometim              | sometim              | SAME
# 31    | customer                  | custom               | custom               | SAME
# 32    | service                   | servic               | servic               | SAME
# 33    | responded                 | respond              | respond              | SAME
# 34    | hours                     | hour                 | hour                 | SAME
# 35    | slow                      | slow                 | slow                 | SAME
# 36    | overall                   | overal               | overal               | SAME
# 37    | recommend                 | recommend            | recommend            | SAME
# 38    | stars                     | star                 | star                 | SAME
# 39    | check                     | check                | check                | SAME
# 40    | video                     | video                | video                | SAME
# 41    | review                    | review               | review               | SAME
# 42    | httpsyoutubesmarthomexreview | httpsyoutubesmarthomexreview | httpsyoutubesmarthomexreview | SAME
# 43    | smarthome                 | smarthom             | smarthom             | SAME
# 44    | techreview                | techreview           | techreview           | SAME
# 45    | honestopinion             | honestopinion        | honestopinion        | SAME
#
# Total words with different stemming results: 2 out of 45
# Percentage of differences: 4.44%
#
# DETAILED COMPARISON FOR WORDS WITH DIFFERENT STEMMING RESULTS:
# #     | Original Word             | Porter Result        | Snowball Result      | Analysis
# 1     | pros                      | pro                  | pros                 | Porter shorter
# 2     | perfectly                 | perfectli            | perfect              | Snowball shorter
#
# COMPLETE PORTER STEMMED TEXT:
# star titl great product minor issu bought smarthom hub x last month pro easi setup took minut voic control work perfectli compat alexa googl home con mobil app crash sometim custom servic respond hour slow overal recommend star check video review httpsyoutubesmarthomexreview smarthom techreview honestopinion
#
# COMPLETE SNOWBALL STEMMED TEXT:
# star titl great product minor issu bought smarthom hub x last month pros easi setup took minut voic control work perfect compat alexa googl home con mobil app crash sometim custom servic respond hour slow overal recommend star check video review httpsyoutubesmarthomexreview smarthom techreview honestopinion
#
# PERFORMANCE COMPARISON:
# PorterStemmer processing time (10 repetitions): 0.000000 seconds
# SnowballStemmer processing time (10 repetitions): 0.000000 seconds

# %% [markdown]
# # 7. Lemmatization (WordNetLemmatizer)

# %%
lemmatizer = WordNetLemmatizer()
lemmatized_tokens = [lemmatizer.lemmatize(word) for word in filtered_tokens]

print("COMPLETE COMPARISON (Original vs Lemmatized):")
print(f"{'#':<5} | {'Original Word':<25} | {'Lemmatized':<25}")
for i, (original, lemmatized) in enumerate(zip(filtered_tokens, lemmatized_tokens), 1):
    print(f"{i:<5} | {original:<25} | {lemmatized:<25}")

lemmatized_text = ' '.join(lemmatized_tokens)
print("\nCOMPLETE LEMMATIZED TEXT:")
print(lemmatized_text)

print("\nSTEMMING vs LEMMATIZATION COMPARISON:")
print(f"{'#':<5} | {'Original Word':<25} | {'Porter Stemmer':<20} | {'Snowball Stemmer':<20} | {'Lemmatized':<25}")
for i, (original, porter, snowball, lemmatized) in enumerate(zip(filtered_tokens, porter_stemmed_tokens, snowball_stemmed_tokens, lemmatized_tokens), 1):
    print(f"{i:<5} | {original:<25} | {porter:<20} | {snowball:<20} | {lemmatized:<25}")

# Performance comparison for Lemmatizer
print("\nPERFORMANCE COMPARISON (Lemmatizer vs Stemmers):")

# Test Lemmatizer speed
start_time = time.time()
for word in filtered_tokens * 10:
    lemmatizer.lemmatize(word)
lemmatizer_time = time.time() - start_time

print(f"WordNetLemmatizer processing time (10 repetitions): {lemmatizer_time:.6f} seconds")
print(f"PorterStemmer processing time (10 repetitions): {porter_time:.6f} seconds")
print(f"SnowballStemmer processing time (10 repetitions): {snowball_time:.6f} seconds")
# Out:
# COMPLETE COMPARISON (Original vs Lemmatized):
# #     | Original Word             | Lemmatized
# 1     | stars                     | star
# 2     | title                     | title
# 3     | great                     | great
# 4     | product                   | product
# 5     | minor                     | minor
# 6     | issues                    | issue
# 7     | bought                    | bought
# 8     | smarthome                 | smarthome
# 9     | hub                       | hub
# 10    | x                         | x
# 11    | last                      | last
# 12    | month                     | month
# 13    | pros                      | pro
# 14    | easy                      | easy
# 15    | setup                     | setup
# 16    | took                      | took
# 17    | minutes                   | minute
# 18    | voice                     | voice
# 19    | control                   | control
# 20    | works                     | work
# 21    | perfectly                 | perfectly
# 22    | compatible                | compatible
# 23    | alexa                     | alexa
# 24    | google                    | google
# 25    | home                      | home
# 26    | cons                      | con
# 27    | mobile                    | mobile
# 28    | app                       | app
# 29    | crashes                   | crash
# 30    | sometimes                 | sometimes
# 31    | customer                  | customer
# 32    | service                   | service
# 33    | responded                 | responded
# 34    | hours                     | hour
# 35    | slow                      | slow
# 36    | overall                   | overall
# 37    | recommend                 | recommend
# 38    | stars                     | star
# 39    | check                     | check
# 40    | video                     | video
# 41    | review                    | review
# 42    | httpsyoutubesmarthomexreview | httpsyoutubesmarthomexreview
# 43    | smarthome                 | smarthome
# 44    | techreview                | techreview
# 45    | honestopinion             | honestopinion
#
# COMPLETE LEMMATIZED TEXT:
# star title great product minor issue bought smarthome hub x last month pro easy setup took minute voice control work perfectly compatible alexa google home con mobile app crash sometimes customer service responded hour slow overall recommend star check video review httpsyoutubesmarthomexreview smarthome techreview honestopinion
#
# STEMMING vs LEMMATIZATION COMPARISON:
# #     | Original Word             | Porter Stemmer       | Snowball Stemmer     | Lemmatized
# 1     | stars                     | star                 | star                 | star
# 2     | title                     | titl                 | titl                 | title
# 3     | great                     | great                | great                | great
# 4     | product                   | product              | product              | product
# 5     | minor                     | minor                | minor                | minor
# 6     | issues                    | issu                 | issu                 | issue
# 7     | bought                    | bought               | bought               | bought
# 8     | smarthome                 | smarthom             | smarthom             | smarthome
# 9     | hub                       | hub                  | hub                  | hub
# 10    | x                         | x                    | x                    | x
# 11    | last                      | last                 | last                 | last
# 12    | month                     | month                | month                | month
# 13    | pros                      | pro                  | pros                 | pro
# 14    | easy                      | easi                 | easi                 | easy
# 15    | setup                     | setup                | setup                | setup
# 16    | took                      | took                 | took                 | took
# 17    | minutes                   | minut                | minut                | minute
# 18    | voice                     | voic                 | voic                 | voice
# 19    | control                   | control              | control              | control
# 20    | works                     | work                 | work                 | work
# 21    | perfectly                 | perfectli            | perfect              | perfectly
# 22    | compatible                | compat               | compat               | compatible
# 23    | alexa                     | alexa                | alexa                | alexa
# 24    | google                    | googl                | googl                | google
# 25    | home                      | home                 | home                 | home
# 26    | cons                      | con                  | con                  | con
# 27    | mobile                    | mobil                | mobil                | mobile
# 28    | app                       | app                  | app                  | app
# 29    | crashes                   | crash                | crash                | crash
# 30    | sometimes                 | sometim              | sometim              | sometimes
# 31    | customer                  | custom               | custom               | customer
# 32    | service                   | servic               | servic               | service
# 33    | responded                 | respond              | respond              | responded
# 34    | hours                     | hour                 | hour                 | hour
# 35    | slow                      | slow                 | slow                 | slow
# 36    | overall                   | overal               | overal               | overall
# 37    | recommend                 | recommend            | recommend            | recommend
# 38    | stars                     | star                 | star                 | star
# 39    | check                     | check                | check                | check
# 40    | video                     | video                | video                | video
# 41    | review                    | review               | review               | review
# 42    | httpsyoutubesmarthomexreview | httpsyoutubesmarthomexreview | httpsyoutubesmarthomexreview | httpsyoutubesmarthomexreview
# 43    | smarthome                 | smarthom             | smarthom             | smarthome
# 44    | techreview                | techreview           | techreview           | techreview
# 45    | honestopinion             | honestopinion        | honestopinion        | honestopinion
#
# PERFORMANCE COMPARISON (Lemmatizer vs Stemmers):
# WordNetLemmatizer processing time (10 repetitions): 0.005477 seconds
# PorterStemmer processing time (10 repetitions): 0.000000 seconds
# SnowballStemmer processing time (10 repetitions): 0.000000 seconds

# %% [markdown]
# # 8. Part-of-Speech (POS) Tagging

# %%
# Cell 10: 8. POS Tagging (Part-of-Speech Tagging)
print("8. PART-OF-SPEECH (POS) TAGGING")

# Perform POS tagging on all filtered tokens
pos_tagged = pos_tag(filtered_tokens)

print("COMPLETE POS TAGGING RESULTS:")
print(f"{'#':<4} | {'Word':<20} | {'POS Tag':<10} | {'Description'}")

pos_descriptions = {
    'NN': 'Noun, singular', 'NNS': 'Noun, plural',
    'NNP': 'Proper noun, singular', 'NNPS': 'Proper noun, plural',
    'VB': 'Verb, base form', 'VBD': 'Verb, past tense',
    'VBG': 'Verb, gerund/present participle', 'VBN': 'Verb, past participle',
    'VBP': 'Verb, non-3rd person singular present', 'VBZ': 'Verb, 3rd person singular present',
    'JJ': 'Adjective', 'JJR': 'Adjective, comparative', 'JJS': 'Adjective, superlative',
    'RB': 'Adverb', 'RBR': 'Adverb, comparative', 'RBS': 'Adverb, superlative',
    'IN': 'Preposition/subordinating conjunction', 'DT': 'Determiner',
    'CC': 'Coordinating conjunction', 'PRP': 'Personal pronoun', 'PRP$': 'Possessive pronoun',
    'MD': 'Modal auxiliary', 'TO': 'to', 'UH': 'Interjection',
    'CD': 'Cardinal number', 'EX': 'Existential there', 'FW': 'Foreign word',
    'LS': 'List item marker', 'POS': 'Possessive ending', 'RP': 'Particle',
    'SYM': 'Symbol', 'WDT': 'Wh-determiner', 'WP': 'Wh-pronoun',
    'WP$': 'Possessive wh-pronoun', 'WRB': 'Wh-adverb'
}

for i, (word, tag) in enumerate(pos_tagged, 1):
    desc = pos_descriptions.get(tag, 'Other')
    print(f"{i:<4} | {word:<20} | {tag:<10} | {desc}")
# Out:
# 8. PART-OF-SPEECH (POS) TAGGING
# COMPLETE POS TAGGING RESULTS:
# #    | Word                 | POS Tag    | Description
# 1    | stars                | NNS        | Noun, plural
# 2    | title                | RB         | Adverb
# 3    | great                | JJ         | Adjective
# 4    | product              | NN         | Noun, singular
# 5    | minor                | JJ         | Adjective
# 6    | issues               | NNS        | Noun, plural
# 7    | bought               | VBD        | Verb, past tense
# 8    | smarthome            | JJ         | Adjective
# 9    | hub                  | NN         | Noun, singular
# 10   | x                    | NNP        | Proper noun, singular
# 11   | last                 | JJ         | Adjective
# 12   | month                | NN         | Noun, singular
# 13   | pros                 | VBD        | Verb, past tense
# 14   | easy                 | JJ         | Adjective
# 15   | setup                | NN         | Noun, singular
# 16   | took                 | VBD        | Verb, past tense
# 17   | minutes              | NNS        | Noun, plural
# 18   | voice                | NN         | Noun, singular
# 19   | control              | NN         | Noun, singular
# 20   | works                | VBZ        | Verb, 3rd person singular present
# 21   | perfectly            | RB         | Adverb
# 22   | compatible           | JJ         | Adjective
# 23   | alexa                | NN         | Noun, singular
# 24   | google               | NN         | Noun, singular
# 25   | home                 | NN         | Noun, singular
# 26   | cons                 | NNS        | Noun, plural
# 27   | mobile               | VBP        | Verb, non-3rd person singular present
# 28   | app                  | JJ         | Adjective
# 29   | crashes              | NNS        | Noun, plural
# 30   | sometimes            | RB         | Adverb
# 31   | customer             | NN         | Noun, singular
# 32   | service              | NN         | Noun, singular
# 33   | responded            | VBD        | Verb, past tense
# 34   | hours                | NNS        | Noun, plural
# 35   | slow                 | VB         | Verb, base form
# 36   | overall              | JJ         | Adjective
# 37   | recommend            | NN         | Noun, singular
# 38   | stars                | NNS        | Noun, plural
# 39   | check                | VBP        | Verb, non-3rd person singular present
# 40   | video                | NN         | Noun, singular
# 41   | review               | NN         | Noun, singular
# 42   | httpsyoutubesmarthomexreview | NN         | Noun, singular
# 43   | smarthome            | JJ         | Adjective
# 44   | techreview           | NN         | Noun, singular
# 45   | honestopinion        | NN         | Noun, singular

# %% [markdown]
# # 9. Chunking

# %%
# Define chunk grammar
chunk_grammar = r"""
    NP: {<DT>?<JJ>*<NN.*>+}
    NP: {<NNP>+}
    NP: {<NNP><POS>?<NNP>*}
    VP: {<VB.*><NP|PP|CLAUSE>+$}
    PP: {<IN><NP>}
"""
chunk_parser = RegexpParser(chunk_grammar)

# Process ALL sentences for chunking
all_sentences = sent_tokenize(text_lower)

for sent_idx, sentence in enumerate(all_sentences, 1):
    print(f"\nSentence {sent_idx}: {sentence}")

    # Tokenize and tag
    tokens = word_tokenize(sentence)
    pos_tags = pos_tag(tokens)

    # Parse chunks
    chunk_tree = chunk_parser.parse(pos_tags)

    print("Chunk Tree Structure:")
    print(chunk_tree)

    print("Chunks extracted:")
    for subtree in chunk_tree.subtrees():
        if subtree.label() in ['NP', 'VP', 'PP']:
            chunk_words = ' '.join(word for word, tag in subtree.leaves())
            print(f"  {subtree.label()}: {chunk_words}")
# Out:
# Sentence 1:   stars title great product but has minor issues i bought the smarthome hub x .
# Chunk Tree Structure:
# (S
#   (NP stars/NNS)
#   title/RB
#   (NP great/JJ product/NN)
#   but/CC
#   has/VBZ
#   (NP minor/JJ issues/NNS)
#   i/VBP
#   bought/VBD
#   (NP the/DT smarthome/JJ hub/NN x/NN)
#   ./.)
# Chunks extracted:
#   NP: stars
#   NP: great product
#   NP: minor issues
#   NP: the smarthome hub x
#
# Sentence 2: last month.
# Chunk Tree Structure:
# (S (NP last/JJ month/NN) ./.)
# Chunks extracted:
#   NP: last month
#
# Sentence 3: pros  easy setup took minutes   voice control works perfectly   compatible with alexa and google home  cons  mobile app crashes sometimes   customer service responded after hours too slow  overall, i recommend it.
# Chunk Tree Structure:
# (S
#   (NP pros/NNS)
#   easy/JJ
#   setup/JJ
#   took/VBD
#   (NP minutes/NNS voice/NN control/NN)
#   works/VBZ
#   perfectly/RB
#   compatible/JJ
#   (PP with/IN (NP alexa/NN))
#   and/CC
#   (NP google/NN home/NN cons/NNS)
#   mobile/VBP
#   (NP app/JJ crashes/NNS)
#   sometimes/RB
#   (NP customer/NN service/NN)
#   responded/VBD
#   (PP after/IN (NP hours/NNS))
#   too/RB
#   slow/JJ
#   overall/JJ
#   ,/,
#   i/JJ
#   recommend/VBP
#   it/PRP
#   ./.)
# Chunks extracted:
#   NP: pros
#   NP: minutes voice control
#   PP: with alexa
#   NP: alexa
#   NP: google home cons
#   NP: app crashes
#   NP: customer service
#   PP: after hours
#   NP: hours
#
# Sentence 4: stars check my video review httpsyoutu.besmarthome_x_review smarthome techreview honestopinion
# Chunk Tree Structure:
# (S
#   (NP stars/NNS)
#   check/VB
#   my/PRP$
#   (NP video/NN review/NN httpsyoutu.besmarthome_x_review/NN)
#   (NP smarthome/JJ techreview/NN honestopinion/NN))
# Chunks extracted:
#   NP: stars
#   NP: video review httpsyoutu.besmarthome_x_review
#   NP: smarthome techreview honestopinion

# %% [markdown]
# # 10. Parsing ( Dependency Parsing and Tree Structure Parsing )

# %%
# Process entire text with spaCy
doc = nlp(text_lower)

print("DEPENDENCY RELATIONS FOR ENTIRE TEXT:")

for token in doc:
    print(f"Word: '{token.text}'")
    print(f"  Head word: '{token.head.text}'")
    print(f"  Dependency relation: {token.dep_}")
    print(f"  Explanation: {spacy.explain(token.dep_)}")
    print(f"  Children: {[child.text for child in token.children]}")
# Out:
# DEPENDENCY RELATIONS FOR ENTIRE TEXT:
# Word: '  '
#   Head word: 'stars'
#   Dependency relation: dep
#   Explanation: unclassified dependent
#   Children: []
# Word: 'stars'
#   Head word: 'title'
#   Dependency relation: nsubj
#   Explanation: nominal subject
#   Children: ['  ']
# Word: 'title'
#   Head word: 'title'
#   Dependency relation: ROOT
#   Explanation: root
#   Children: ['stars', 'product', 'but', 'has', 'x', '.']
# Word: 'great'
#   Head word: 'product'
#   Dependency relation: amod
#   Explanation: adjectival modifier
#   Children: []
# Word: 'product'
#   Head word: 'title'
#   Dependency relation: dobj
#   Explanation: direct object
#   Children: ['great']
# Word: 'but'
#   Head word: 'title'
#   Dependency relation: cc
#   Explanation: coordinating conjunction
#   Children: []
# Word: 'has'
#   Head word: 'title'
#   Dependency relation: conj
#   Explanation: conjunct
#   Children: ['issues']
# Word: 'minor'
#   Head word: 'issues'
#   Dependency relation: amod
#   Explanation: adjectival modifier
#   Children: []
# Word: 'issues'
#   Head word: 'has'
#   Dependency relation: dobj
#   Explanation: direct object
#   Children: ['minor', 'bought']
# Word: 'i'
#   Head word: 'bought'
#   Dependency relation: nsubj
#   Explanation: nominal subject
#   Children: []
# Word: 'bought'
#   Head word: 'issues'
#   Dependency relation: relcl
#   Explanation: relative clause modifier
#   Children: ['i', 'hub']
# Word: 'the'
#   Head word: 'hub'
#   Dependency relation: det
#   Explanation: determiner
#   Children: []
# Word: 'smarthome'
#   Head word: 'hub'
#   Dependency relation: compound
#   Explanation: compound
#   Children: []
# Word: 'hub'
#   Head word: 'bought'
#   Dependency relation: dobj
#   Explanation: direct object
#   Children: ['the', 'smarthome']
# Word: 'x'
#   Head word: 'title'
#   Dependency relation: punct
#   Explanation: punctuation
#   Children: []
# Word: '.'
#   Head word: 'title'
#   Dependency relation: punct
#   Explanation: punctuation
#   Children: []
# Word: 'last'
#   Head word: 'month'
#   Dependency relation: amod
#   Explanation: adjectival modifier
#   Children: []
# Word: 'month'
#   Head word: 'month'
#   Dependency relation: ROOT
#   Explanation: root
#   Children: ['last', '.']
# Word: '.'
#   Head word: 'month'
#   Dependency relation: punct
#   Explanation: punctuation
#   Children: []
# Word: 'pros'
#   Head word: 'took'
#   Dependency relation: nsubj
#   Explanation: nominal subject
#   Children: [' ', 'setup']
# Word: ' '
#   Head word: 'pros'
#   Dependency relation: dep
#   Explanation: unclassified dependent
#   Children: []
# Word: 'easy'
#   Head word: 'setup'
#   Dependency relation: amod
#   Explanation: adjectival modifier
#   Children: []
# Word: 'setup'
#   Head word: 'pros'
#   Dependency relation: appos
#   Explanation: appositional modifier
#   Children: ['easy']
# Word: 'took'
#   Head word: 'recommend'
#   Dependency relation: ccomp
#   Explanation: clausal complement
#   Children: ['pros', 'control', 'works', 'crashes']
# Word: 'minutes'
#   Head word: 'control'
#   Dependency relation: compound
#   Explanation: compound
#   Children: ['  ']
# Word: '  '
#   Head word: 'minutes'
#   Dependency relation: dep
#   Explanation: unclassified dependent
#   Children: []
# Word: 'voice'
#   Head word: 'control'
#   Dependency relation: compound
#   Explanation: compound
#   Children: []
# Word: 'control'
#   Head word: 'took'
#   Dependency relation: dobj
#   Explanation: direct object
#   Children: ['minutes', 'voice']
# Word: 'works'
#   Head word: 'took'
#   Dependency relation: ccomp
#   Explanation: clausal complement
#   Children: ['compatible']
# Word: 'perfectly'
#   Head word: 'compatible'
#   Dependency relation: advmod
#   Explanation: adverbial modifier
#   Children: ['  ']
# Word: '  '
#   Head word: 'perfectly'
#   Dependency relation: dep
#   Explanation: unclassified dependent
#   Children: []
# Word: 'compatible'
#   Head word: 'works'
#   Dependency relation: acomp
#   Explanation: adjectival complement
#   Children: ['perfectly', 'with']
# Word: 'with'
#   Head word: 'compatible'
#   Dependency relation: prep
#   Explanation: prepositional modifier
#   Children: ['app']
# Word: 'alexa'
#   Head word: 'app'
#   Dependency relation: nmod
#   Explanation: modifier of nominal
#   Children: ['and', 'cons']
# Word: 'and'
#   Head word: 'alexa'
#   Dependency relation: cc
#   Explanation: coordinating conjunction
#   Children: []
# Word: 'google'
#   Head word: 'cons'
#   Dependency relation: compound
#   Explanation: compound
#   Children: []
# Word: 'home'
#   Head word: 'cons'
#   Dependency relation: compound
#   Explanation: compound
#   Children: [' ']
# Word: ' '
#   Head word: 'home'
#   Dependency relation: dep
#   Explanation: unclassified dependent
#   Children: []
# Word: 'cons'
#   Head word: 'alexa'
#   Dependency relation: conj
#   Explanation: conjunct
#   Children: ['google', 'home', ' ']
# Word: ' '
#   Head word: 'cons'
#   Dependency relation: dep
#   Explanation: unclassified dependent
#   Children: []
# Word: 'mobile'
#   Head word: 'app'
#   Dependency relation: amod
#   Explanation: adjectival modifier
#   Children: []
# Word: 'app'
#   Head word: 'with'
#   Dependency relation: pobj
#   Explanation: object of preposition
#   Children: ['alexa', 'mobile']
# Word: 'crashes'
#   Head word: 'took'
#   Dependency relation: conj
#   Explanation: conjunct
#   Children: ['service']
# Word: 'sometimes'
#   Head word: 'service'
#   Dependency relation: advmod
#   Explanation: adverbial modifier
#   Children: ['  ']
# Word: '  '
#   Head word: 'sometimes'
#   Dependency relation: dep
#   Explanation: unclassified dependent
#   Children: []
# Word: 'customer'
#   Head word: 'service'
#   Dependency relation: compound
#   Explanation: compound
#   Children: []
# Word: 'service'
#   Head word: 'crashes'
#   Dependency relation: dobj
#   Explanation: direct object
#   Children: ['sometimes', 'customer', 'responded']
# Word: 'responded'
#   Head word: 'service'
#   Dependency relation: acl
#   Explanation: clausal modifier of noun (adjectival clause)
#   Children: ['after']
# Word: 'after'
#   Head word: 'responded'
#   Dependency relation: prep
#   Explanation: prepositional modifier
#   Children: ['hours']
# Word: 'hours'
#   Head word: 'after'
#   Dependency relation: pobj
#   Explanation: object of preposition
#   Children: ['slow', 'overall']
# Word: 'too'
#   Head word: 'slow'
#   Dependency relation: advmod
#   Explanation: adverbial modifier
#   Children: []
# Word: 'slow'
#   Head word: 'hours'
#   Dependency relation: amod
#   Explanation: adjectival modifier
#   Children: ['too', ' ']
# Word: ' '
#   Head word: 'slow'
#   Dependency relation: dep
#   Explanation: unclassified dependent
#   Children: []
# Word: 'overall'
#   Head word: 'hours'
#   Dependency relation: advmod
#   Explanation: adverbial modifier
#   Children: []
# Word: ','
#   Head word: 'recommend'
#   Dependency relation: punct
#   Explanation: punctuation
#   Children: []
# Word: 'i'
#   Head word: 'recommend'
#   Dependency relation: nsubj
#   Explanation: nominal subject
#   Children: []
# Word: 'recommend'
#   Head word: 'recommend'
#   Dependency relation: ROOT
#   Explanation: root
#   Children: ['took', ',', 'i', 'it', '.']
# Word: 'it'
#   Head word: 'recommend'
#   Dependency relation: dobj
#   Explanation: direct object
#   Children: []
# Word: '.'
#   Head word: 'recommend'
#   Dependency relation: punct
#   Explanation: punctuation
#   Children: []
# Word: 'stars'
#   Head word: 'check'
#   Dependency relation: nsubj
#   Explanation: nominal subject
#   Children: []
# Word: 'check'
#   Head word: 'check'
#   Dependency relation: ROOT
#   Explanation: root
#   Children: ['stars', 'review', 'honestopinion']
# Word: 'my'
#   Head word: 'review'
#   Dependency relation: poss
#   Explanation: possession modifier
#   Children: []
# Word: 'video'
#   Head word: 'review'
#   Dependency relation: compound
#   Explanation: compound
#   Children: []
# Word: 'review'
#   Head word: 'check'
#   Dependency relation: dobj
#   Explanation: direct object
#   Children: ['my', 'video']
# Word: 'httpsyoutu.besmarthome_x_review'
#   Head word: 'honestopinion'
#   Dependency relation: nummod
#   Explanation: numeric modifier
#   Children: []
# Word: 'smarthome'
#   Head word: 'techreview'
#   Dependency relation: compound
#   Explanation: compound
#   Children: []
# Word: 'techreview'
#   Head word: 'honestopinion'
#   Dependency relation: compound
#   Explanation: compound
#   Children: ['smarthome']
# Word: 'honestopinion'
#   Head word: 'check'
#   Dependency relation: dobj
#   Explanation: direct object
#   Children: ['httpsyoutu.besmarthome_x_review', 'techreview']

# %%
all_sentences = sent_tokenize(text_lower)

for sent_idx, sentence in enumerate(all_sentences, 1):
    print(f"\nSentence {sent_idx}: {sentence}")

    # Tokenize and tag
    tokens = word_tokenize(sentence)
    pos_tags = pos_tag(tokens)

    # Create a simple binary tree structure for visualization
    def create_simple_tree(tokens, pos_tags):
        """Create a simple constituency-like tree structure"""
        if len(tokens) == 1:
            return Tree(pos_tags[0][1], [tokens[0]])
        else:
            mid = len(tokens) // 2
            left_tree = create_simple_tree(tokens[:mid], pos_tags[:mid])
            right_tree = create_simple_tree(tokens[mid:], pos_tags[mid:])
            return Tree('S', [left_tree, right_tree])

    try:
        constituency_tree = create_simple_tree(tokens, pos_tags)
        print("Constituency Tree:")
        constituency_tree.pretty_print()

        print("Tree in bracketed notation:")
        print(constituency_tree)
    except Exception as e:
        print(f"Error creating tree: {e}")

print("\nALTERNATIVE TREE VISUALIZATION (ALL SENTENCES - Detailed NP chunks):")

# More detailed tree structure for ALL sentences
for sent_idx, sentence in enumerate(all_sentences, 1):
    print(f"\nSentence {sent_idx}: {sentence}")

    tokens = word_tokenize(sentence)
    pos_tags = pos_tag(tokens)

    # Manual tree building
    tree = Tree('S', [])
    current_np = []

    for word, tag in pos_tags:
        if tag.startswith('NN') or tag.startswith('JJ') or tag == 'DT':
            current_np.append((word, tag))
        else:
            if current_np:
                np_tree = Tree('NP', [f"{w}/{t}" for w, t in current_np])
                tree.append(np_tree)
                current_np = []
            tree.append(f"{word}/{tag}")

    if current_np:
        np_tree = Tree('NP', [f"{w}/{t}" for w, t in current_np])
        tree.append(np_tree)

    print("Detailed Constituency Tree (NP chunks):")
    tree.pretty_print()
    print("\nTree as string:")
    print(tree)
# Out:
# Sentence 1:   stars title great product but has minor issues i bought the smarthome hub x .
# Constituency Tree:
#                                                           S
#                           ________________________________|____________________________
#                          S                                                             S
#          ________________|_____________                                  ______________|_____________________
#         S                              S                                S                                    S
#    _____|____                   _______|_______                  _______|__________                   _______|_______
#   |          S                 S               S                S                  S                 S               S
#   |      ____|____        _____|___         ___|____       _____|___          _____|___        ______|___         ___|___
#  NNS    RB        JJ     NN        CC     VBZ       JJ   NNS       VBP      VBD        DT     JJ         NN      NN      .
#   |     |         |      |         |       |        |     |         |        |         |      |          |       |       |
# stars title     great product     but     has     minor issues      i      bought     the smarthome     hub      x       .
#
# Tree in bracketed notation:
# (S
#   (S
#     (S (NNS stars) (S (RB title) (JJ great)))
#     (S (S (NN product) (CC but)) (S (VBZ has) (JJ minor))))
#   (S
#     (S (S (NNS issues) (VBP i)) (S (VBD bought) (DT the)))
#     (S (S (JJ smarthome) (NN hub)) (S (NN x) (. .)))))
#
# Sentence 2: last month.
# Constituency Tree:
#        S
#   _____|____
#  |          S
#  |      ____|___
#  JJ    NN       .
#  |     |        |
# last month      .
#
# Tree in bracketed notation:
# (S (JJ last) (S (NN month) (. .)))
#
# Sentence 3: pros  easy setup took minutes   voice control works perfectly   compatible with alexa and google home  cons  mobile app crashes sometimes   customer service responded after hours too slow  overall, i recommend it.
# Constituency Tree:
#                                                                                                                                                         S
#                                                                       __________________________________________________________________________________|_____________________________________________________________________________________
#                                                                      |                                                                                                                                                                        S
#                                                                      |                                                                                                                    ____________________________________________________|_________________________________
#                                                                      S                                                                                                                   |                                                                                      S
#                               _______________________________________|___________________________________________                                                                        |                                                                  ____________________|______________
#                              S                                                                                   S                                                                       S                                                                 |                                   S
#                 _____________|______________________                                                _____________|___________________                                  __________________|___________________________                                      |                         __________|______
#                S                                    S                                              S                                 S                                S                                              S                                     S                        |                 S
#        ________|_________                  _________|___________                     ______________|________               __________|________                 _______|___________                        ___________|_____________                 _______|________                |           ______|___
#       S                  S                S                     S                   S                       S             S                   S               S                   S                      S                         S               S                S               S          |          S
#   ____|___           ____|___        _____|____            _____|____         ______|______             ____|____      ___|____           ____|___       _____|___           _____|______          ______|_____              ______|____       ____|___         ____|_____       ___|___       |       ___|___
# NNS       JJ        JJ      VBD    NNS         NN         NN        VBZ      RB            JJ          IN        NN   CC       NN        NN      NNS   VBP        JJ       NNS           RB       NN           NN          VBD          IN   NNS       RB      JJ         JJ    ,       JJ    VBP    PRP      .
#  |        |         |        |      |          |          |          |       |             |           |         |    |        |         |        |     |         |         |            |        |            |            |           |     |        |       |          |     |       |      |      |       |
# pros     easy     setup     took minutes     voice     control     works perfectly     compatible     with     alexa and     google     home     cons mobile     app     crashes     sometimes customer     service     responded     after hours     too     slow     overall  ,       i  recommend  it      .
#
# Tree in bracketed notation:
# (S
#   (S
#     (S
#       (S (S (NNS pros) (JJ easy)) (S (JJ setup) (VBD took)))
#       (S (S (NNS minutes) (NN voice)) (S (NN control) (VBZ works))))
#     (S
#       (S (S (RB perfectly) (JJ compatible)) (S (IN with) (NN alexa)))
#       (S (S (CC and) (NN google)) (S (NN home) (NNS cons)))))
#   (S
#     (S
#       (S (S (VBP mobile) (JJ app)) (S (NNS crashes) (RB sometimes)))
#       (S
#         (S (NN customer) (NN service))
#         (S (VBD responded) (IN after))))
#     (S
#       (S (S (NNS hours) (RB too)) (S (JJ slow) (JJ overall)))
#       (S (S (, ,) (JJ i)) (S (VBP recommend) (S (PRP it) (. .)))))))
#
# Sentence 4: stars check my video review httpsyoutu.besmarthome_x_review smarthome techreview honestopinion
# Constituency Tree:
#                                      S
#                   ___________________|_____________________________
#                  |                                                 S
#                  |                          _______________________|_________
#                  S                         |                                 S
#         _________|________                 |                        _________|_______
#        S                  S                S                       |                 S
#    ____|____          ____|____       _____|_________              |          _______|________
#  NNS        VB      PRP$       NN    NN              NN            JJ        NN               NN
#   |         |        |         |     |               |             |         |                |
# stars     check      my      video review     httpsyoutu.besma smarthome techreview     honestopinion
#                                               rthome_x_review
#
# Tree in bracketed notation:
# (S
#   (S (S (NNS stars) (VB check)) (S (PRP$ my) (NN video)))
#   (S
#     (S (NN review) (NN httpsyoutu.besmarthome_x_review))
#     (S (JJ smarthome) (S (NN techreview) (NN honestopinion)))))
#
# ALTERNATIVE TREE VISUALIZATION (ALL SENTENCES - Detailed NP chunks):
#
# Sentence 1:   stars title great product but has minor issues i bought the smarthome hub x .
# Detailed Constituency Tree (NP chunks):
#                                                           S
#     ______________________________________________________|________________________________________________________
#    |       |       |      |       |       |      NP              NP                      NP                        NP
#    |       |       |      |       |       |      |         ______|______           ______|______          _________|_______________
# title/RB but/CC has/VBZ i/VBP bought/VBD ./. stars/NNS great/JJ     product/NN minor/JJ     issues/NNS the/DT smarthome/JJ hub/NN x/NN
#
#
# Tree as string:
# (S
#   (NP stars/NNS)
#   title/RB
#   (NP great/JJ product/NN)
#   but/CC
#   has/VBZ
#   (NP minor/JJ issues/NNS)
#   i/VBP
#   bought/VBD
#   (NP the/DT smarthome/JJ hub/NN x/NN)
#   ./.)
#
# Sentence 2: last month.
# Detailed Constituency Tree (NP chunks):
#        S
#   _____|_____
#  |           NP
#  |      _____|_____
# ./. last/JJ     month/NN
#
#
# Tree as string:
# (S (NP last/JJ month/NN) ./.)
#
# Sentence 3: pros  easy setup took minutes   voice control works perfectly   compatible with alexa and google home  cons  mobile app crashes sometimes   customer service responded after hours too slow  overall, i recommend it.
# Detailed Constituency Tree (NP chunks):
#                                                                                                                                                       S
#     __________________________________________________________________________________________________________________________________________________|___________________________________________________________________________________________________________________________________________________________________________
#    |         |          |          |      |        |           |             |          |       |     |        |         |     |              NP                           NP                     NP         NP                 NP                    NP                          NP                NP             NP             NP
#    |         |          |          |      |        |           |             |          |       |     |        |         |     |      ________|_______            _________|_________             |          |          ________|_______         _____|_______             _______|______           |         _____|______        |
# took/VBD works/VBZ perfectly/RB with/IN and/CC mobile/VBP sometimes/RB responded/VBD after/IN too/RB ,/, recommend/VBP it/PRP ./. pros/NNS easy/JJ setup/JJ minutes/NNS voice/NN control/NN compatible/JJ alexa/NN google/NN home/NN cons/NNS app/JJ     crashes/NNS customer/NN     service/NN hours/NNS slow/JJ     overall/JJ i/JJ
#
#
# Tree as string:
# (S
#   (NP pros/NNS easy/JJ setup/JJ)
#   took/VBD
#   (NP minutes/NNS voice/NN control/NN)
#   works/VBZ
#   perfectly/RB
#   (NP compatible/JJ)
#   with/IN
#   (NP alexa/NN)
#   and/CC
#   (NP google/NN home/NN cons/NNS)
#   mobile/VBP
#   (NP app/JJ crashes/NNS)
#   sometimes/RB
#   (NP customer/NN service/NN)
#   responded/VBD
#   after/IN
#   (NP hours/NNS)
#   too/RB
#   (NP slow/JJ overall/JJ)
#   ,/,
#   (NP i/JJ)
#   recommend/VBP
#   it/PRP
#   ./.)
#
# Sentence 4: stars check my video review httpsyoutu.besmarthome_x_review smarthome techreview honestopinion
# Detailed Constituency Tree (NP chunks):
#                                         S
#     ____________________________________|____________
#    |        |        NP                              NP
#    |        |        |         ______________________|___________________________________________
# check/VB my/PRP$ stars/NNS video/NN review/NN httpsyoutu.besma smarthome/JJ techreview/NN honestopinion/NN
#                                               rthome_x_review/
#                                                      NN
#
#
# Tree as string:
# (S
#   (NP stars/NNS)
#   check/VB
#   my/PRP$
#   (NP
#     video/NN
#     review/NN
#     httpsyoutu.besmarthome_x_review/NN
#     smarthome/JJ
#     techreview/NN
#     honestopinion/NN))

# %% [markdown]
# # 11. Hypernyms and Hyponyms (WordNet)

# %%
# Extract ALL unique words from filtered tokens
unique_words = list(set(filtered_tokens))

for word in unique_words:
    print(f"\nWORD: '{word}'")

    # Get synsets for the word
    synsets = wn.synsets(word)

    if not synsets:
        print(f"  No synsets found for '{word}'")
        continue

    # Take first synset
    synset = synsets[0]
    print(f"  Definition: {synset.definition()}")
    print(f"  Example: {synset.examples() if synset.examples() else 'No example'}")

    # Hypernyms (more general concepts)
    hypernyms = synset.hypernyms()
    if hypernyms:
        print(f"\n  HYPERNYMS (more general): {len(hypernyms)} found")
        for hyp in hypernyms:
            print(f"    → {hyp.name()}")
            print(f"      Definition: {hyp.definition()}")
            # Get path hypernyms (higher level)
            hyper_paths = hyp.hypernyms()
            if hyper_paths:
                for path_hyp in hyper_paths:
                    print(f"        ↑ {path_hyp.name()}: {path_hyp.definition()}")
    else:
        print(f"\n  HYPERNYMS: None found")

    # Hyponyms (more specific concepts)
    hyponyms = synset.hyponyms()
    if hyponyms:
        print(f"\n  HYPONYMS (more specific): {len(hyponyms)} found")
        for hyp in hyponyms:
            print(f"    → {hyp.name()}")
            print(f"      Definition: {hyp.definition()}")
    else:
        print(f"\n  HYPONYMS: None found")

    # Full hierarchy path (no depth limit)
    print(f"\n  HIERARCHY PATH (up to root):")
    def show_path(s, level=0):
        print(f"    {'  ' * level}└─ {s.name()}")
        for hyp in s.hypernyms():
            show_path(hyp, level + 1)

    show_path(synset)

# Detailed example for ALL specific words from the text
print("\nDETAILED EXAMPLE FOR KEY WORDS FROM TEXT")

key_words = ['apple', 'computer', 'company', 'inventor', 'founder', 'ceo', 'pixar', 'next']

for word in key_words:
    print(f"\nDEEP ANALYSIS FOR: '{word}'")

    synsets = wn.synsets(word)
    if synsets:
        primary_synset = synsets[0]

        print(f"  Definition: {primary_synset.definition()}")
        print(f"  Lemmas: {primary_synset.lemma_names()}")

        # Get all hypernym paths (no limit)
        print("\n  All Hypernym Paths:")
        hypernym_paths = primary_synset.hypernym_paths()
        for i, path in enumerate(hypernym_paths, 1):
            print(f"    Path {i}: {' -> '.join([s.name().split('.')[0] for s in path])}")

        # Get all hyponyms (no limit on display)
        all_hyponyms = primary_synset.hyponyms()
        print(f"\n  Total hyponyms found: {len(all_hyponyms)}")
        if all_hyponyms:
            print("  All hyponyms:")
            for hyp in all_hyponyms:
                print(f"    - {hyp.name()}: {hyp.definition()}")
# Out:
# WORD: 'issues'
#   Definition: an important question that is in dispute and must be settled
#   Example: ['the issue could be settled by requiring public education for everyone', 'politicians never discuss the real issues']
#
#   HYPERNYMS (more general): 1 found
#     → content.n.05
#       Definition: the sum or range of what has been perceived, discovered, or learned
#         ↑ cognition.n.01: the psychological result of perception and learning and reasoning
#
#   HYPONYMS (more specific): 4 found
#     → quodlibet.n.01
#       Definition: an issue that is presented for formal disputation
#     → paramount_issue.n.01
#       Definition: an issue whose settlement is more important than anything else; and issue that must be settled before anything else can be settled
#     → gut_issue.n.01
#       Definition: an issue that elicits strong emotional reactions
#     → pocketbook_issue.n.01
#       Definition: an issue whose settlement will affect financial resources
#
#   HIERARCHY PATH (up to root):
#     └─ issue.n.01
#       └─ content.n.05
#         └─ cognition.n.01
#           └─ psychological_feature.n.01
#             └─ abstraction.n.06
#               └─ entity.n.01
#
# WORD: 'review'
#   Definition: a new appraisal or evaluation
#   Example: No example
#
#   HYPERNYMS (more general): 1 found
#     → appraisal.n.01
#       Definition: the classification of someone or something with respect to its worth
#         ↑ classification.n.03: the basic cognitive process of arranging into classes or categories
#
#   HYPONYMS (more specific): 1 found
#     → stocktaking.n.01
#       Definition: reappraisal of a situation or position or outlook
#
#   HIERARCHY PATH (up to root):
#     └─ reappraisal.n.01
#       └─ appraisal.n.01
#         └─ classification.n.03
#           └─ basic_cognitive_process.n.01
#             └─ process.n.02
#               └─ cognition.n.01
#                 └─ psychological_feature.n.01
#                   └─ abstraction.n.06
#                     └─ entity.n.01
#
# WORD: 'video'
#   Definition: the visible part of a television transmission
#   Example: ['they could still receive the sound but the picture was gone']
#
#   HYPERNYMS (more general): 1 found
#     → visual_communication.n.01
#       Definition: communication that relies on vision
#         ↑ communication.n.02: something that is communicated by or to or between people or groups
#
#   HYPONYMS: None found
#
#   HIERARCHY PATH (up to root):
#     └─ video.n.01
#       └─ visual_communication.n.01
#         └─ communication.n.02
#           └─ abstraction.n.06
#             └─ entity.n.01
#
# WORD: 'service'
#   Definition: work done by one person or group that benefits another
#   Example: ['budget separately for goods and services']
#
#   HYPERNYMS (more general): 1 found
#     → work.n.01
#       Definition: activity directed toward making or doing something
#         ↑ activity.n.01: any specific behavior
#
#   HYPONYMS (more specific): 4 found
#     → consulting_service.n.01
#       Definition: service provided by a professional advisor (e.g., a lawyer or doctor or CPA etc.)
#     → national_service.n.01
#       Definition: compulsory service in the military during peacetime
#     → facility.n.05
#       Definition: a service that an organization or a piece of equipment offers you
#     → utility.n.03
#       Definition: the service (electric power or water or transportation) provided by a public utility
#
#   HIERARCHY PATH (up to root):
#     └─ service.n.01
#       └─ work.n.01
#         └─ activity.n.01
#           └─ act.n.02
#             └─ event.n.01
#               └─ psychological_feature.n.01
#                 └─ abstraction.n.06
#                   └─ entity.n.01
#
# WORD: 'hub'
#   Definition: the central part of a car wheel (or fan or propeller etc) through which the shaft or axle passes
#   Example: No example
#
#   HYPERNYMS (more general): 1 found
#     → part.n.02
#       Definition: something less than the whole of a human artifact
#         ↑ object.n.01: a tangible and visible entity; an entity that can cast a shadow
#
#   HYPONYMS: None found
#
#   HIERARCHY PATH (up to root):
#     └─ hub.n.01
#       └─ part.n.02
#         └─ object.n.01
#           └─ physical_entity.n.01
#             └─ entity.n.01
#
# WORD: 'took'
#   Definition: carry out
#   Example: ['take action', 'take steps', 'take vengeance']
#
#   HYPERNYMS (more general): 1 found
#     → act.v.01
#       Definition: perform an action, or work out or perform (an action)
#
#   HYPONYMS: None found
#
#   HIERARCHY PATH (up to root):
#     └─ take.v.01
#       └─ act.v.01
#
# WORD: 'bought'
#   Definition: obtain by purchase; acquire by means of a financial transaction
#   Example: ['The family purchased a new car', 'The conglomerate acquired a new company', 'She buys for the big department store']
#
#   HYPERNYMS (more general): 1 found
#     → get.v.01
#       Definition: come into the possession of something concrete or abstract
#
#   HYPONYMS (more specific): 8 found
#     → take.v.33
#       Definition: buy, select
#     → take_out.v.07
#       Definition: purchase prepared food to be eaten at home
#     → buy_back.v.01
#       Definition: buy what had previously been sold, lost, or given away
#     → impulse-buy.v.01
#       Definition: buy on impulse without proper reflection
#     → get.v.22
#       Definition: purchase
#     → take_over.v.05
#       Definition: take over ownership of; of corporations and companies
#     → pick_up.v.08
#       Definition: buy casually or spontaneously
#     → subscribe.v.05
#       Definition: receive or obtain regularly
#
#   HIERARCHY PATH (up to root):
#     └─ buy.v.01
#       └─ get.v.01
#
# WORD: 'month'
#   Definition: one of the twelve divisions of the calendar year
#   Example: ['he paid the bill last month']
#
#   HYPERNYMS (more general): 1 found
#     → time_period.n.01
#       Definition: an amount of time
#         ↑ fundamental_quantity.n.01: one of the four quantities that are the basis of systems of measurement
#
#   HYPONYMS (more specific): 6 found
#     → jewish_calendar_month.n.01
#       Definition: a month in the Jewish calendar
#     → gregorian_calendar_month.n.01
#       Definition: a month in the Gregorian calendar
#     → revolutionary_calendar_month.n.01
#       Definition: a month in the Revolutionary calendar
#     → islamic_calendar_month.n.01
#       Definition: any lunar month in the Muslim calendar
#     → hindu_calendar_month.n.01
#       Definition: any lunisolar month in the Hindu calendar
#     → date.n.06
#       Definition: the particular day, month, or year (usually according to the Gregorian calendar) that an event occurred
#
#   HIERARCHY PATH (up to root):
#     └─ calendar_month.n.01
#       └─ time_period.n.01
#         └─ fundamental_quantity.n.01
#           └─ measure.n.02
#             └─ abstraction.n.06
#               └─ entity.n.01
#
# WORD: 'techreview'
#   No synsets found for 'techreview'
#
# WORD: 'works'
#   Definition: buildings for carrying on industrial labor
#   Example: ['they built a large plant to manufacture automobiles']
#
#   HYPERNYMS (more general): 1 found
#     → building_complex.n.01
#       Definition: a whole structure (as a building) made up of interconnected or related structures
#         ↑ structure.n.01: a thing constructed; a complex entity constructed of many parts
#
#   HYPONYMS (more specific): 11 found
#     → brewery.n.01
#       Definition: a plant where beer is brewed by fermentation
#     → packinghouse.n.02
#       Definition: a plant where livestock are slaughtered and processed and packed as meat products
#     → recycling_plant.n.01
#       Definition: a plant for reprocessing used or abandoned materials
#     → refinery.n.01
#       Definition: an industrial plant for purifying a crude substance
#     → saltworks.n.01
#       Definition: a plant where salt is produced commercially
#     → bottling_plant.n.01
#       Definition: a plant where beverages are put into bottles with caps
#     → mint.n.06
#       Definition: a plant where money is coined by authority of the government
#     → factory.n.01
#       Definition: a plant consisting of one or more buildings with facilities for manufacturing
#     → sewage_disposal_plant.n.01
#       Definition: a plant for disposing of sewage
#     → distillery.n.01
#       Definition: a plant and works where alcoholic drinks are made by distillation
#     → smelter.n.01
#       Definition: an industrial plant for smelting
#
#   HIERARCHY PATH (up to root):
#     └─ plant.n.01
#       └─ building_complex.n.01
#         └─ structure.n.01
#           └─ artifact.n.01
#             └─ whole.n.02
#               └─ object.n.01
#                 └─ physical_entity.n.01
#                   └─ entity.n.01
#
# WORD: 'title'
#   Definition: a heading that names a statute or legislative bill; may give a brief summary of the matters it deals with
#   Example: ['Title 8 provided federal help for schools']
#
#   HYPERNYMS (more general): 1 found
#     → heading.n.01
#       Definition: a line of text serving to indicate what the passage below it is about
#         ↑ line.n.05: text consisting of a row of words written across a page or computer screen
#
#   HYPONYMS: None found
#
#   HIERARCHY PATH (up to root):
#     └─ title.n.01
#       └─ heading.n.01
#         └─ line.n.05
#           └─ text.n.01
#             └─ matter.n.06
#               └─ writing.n.02
#                 └─ written_communication.n.01
#                   └─ communication.n.02
#                     └─ abstraction.n.06
#                       └─ entity.n.01
#
# WORD: 'control'
#   Definition: power to direct or determine
#   Example: ['under control']
#
#   HYPERNYMS (more general): 1 found
#     → power.n.01
#       Definition: possession of controlling influence
#         ↑ quality.n.01: an essential and distinguishing attribute of something or someone; --Shakespeare
#
#   HYPONYMS (more specific): 5 found
#     → rein.n.02
#       Definition: any means of control
#     → corporatism.n.01
#       Definition: control of a state or organization by large interest groups
#     → hold.n.03
#       Definition: power by which something or someone is affected or dominated
#     → authority.n.01
#       Definition: the power or right to give orders or make decisions
#     → iron_fist.n.01
#       Definition: rigorous or ruthless control
#
#   HIERARCHY PATH (up to root):
#     └─ control.n.01
#       └─ power.n.01
#         └─ quality.n.01
#           └─ attribute.n.02
#             └─ abstraction.n.06
#               └─ entity.n.01
#
# WORD: 'google'
#   Definition: a widely used search engine that uses text-matching techniques to find web pages that are important and relevant to a user's search
#   Example: No example
#
#   HYPERNYMS: None found
#
#   HYPONYMS: None found
#
#   HIERARCHY PATH (up to root):
#     └─ google.n.01
#
# WORD: 'perfectly'
#   Definition: completely and without qualification; used informally as intensifiers
#   Example: ['an absolutely magnificent painting', 'a perfectly idiotic idea', "you're perfectly right", 'utterly miserable', 'you can be dead sure of my innocence', 'was dead tired', 'dead right']
#
#   HYPERNYMS: None found
#
#   HYPONYMS: None found
#
#   HIERARCHY PATH (up to root):
#     └─ absolutely.r.01
#
# WORD: 'slow'
#   Definition: lose velocity; move more slowly
#   Example: ['The car decelerated']
#
#   HYPERNYMS (more general): 1 found
#     → decrease.v.01
#       Definition: decrease in size, extent, or range
#         ↑ change_magnitude.v.01: change in size or magnitude
#
#   HYPONYMS (more specific): 2 found
#     → delay.v.01
#       Definition: cause to be slowed down or delayed
#     → slow.v.03
#       Definition: cause to proceed more slowly
#
#   HIERARCHY PATH (up to root):
#     └─ decelerate.v.01
#       └─ decrease.v.01
#         └─ change_magnitude.v.01
#           └─ change.v.02
#
# WORD: 'voice'
#   Definition: the distinctive quality or pitch or condition of a person's speech
#   Example: ['A shrill voice sounded behind us']
#
#   HYPERNYMS (more general): 1 found
#     → sound.n.01
#       Definition: the particular auditory effect produced by a given cause
#         ↑ sound_property.n.01: an attribute of sound
#
#   HYPONYMS (more specific): 1 found
#     → androglossia.n.01
#       Definition: a woman's voice with male qualities
#
#   HIERARCHY PATH (up to root):
#     └─ voice.n.01
#       └─ sound.n.01
#         └─ sound_property.n.01
#           └─ property.n.02
#             └─ attribute.n.02
#               └─ abstraction.n.06
#                 └─ entity.n.01
#
# WORD: 'cons'
#   Definition: an argument opposed to a proposal
#   Example: No example
#
#   HYPERNYMS (more general): 1 found
#     → argument.n.01
#       Definition: a fact or assertion offered as evidence that something is true
#         ↑ evidence.n.02: an indication that makes something evident
#
#   HYPONYMS: None found
#
#   HIERARCHY PATH (up to root):
#     └─ con.n.01
#       └─ argument.n.01
#         └─ evidence.n.02
#           └─ indication.n.01
#             └─ communication.n.02
#               └─ abstraction.n.06
#                 └─ entity.n.01
#
# WORD: 'compatible'
#   Definition: able to exist and perform in harmonious or agreeable combination
#   Example: ['a compatible married couple', 'her deeds were compatible with her ideology']
#
#   HYPERNYMS: None found
#
#   HYPONYMS: None found
#
#   HIERARCHY PATH (up to root):
#     └─ compatible.a.01
#
# WORD: 'minor'
#   Definition: a young person of either sex
#   Example: ['she writes books for children', "they're just kids", "`tiddler' is a British term for youngster"]
#
#   HYPERNYMS (more general): 1 found
#     → juvenile.n.01
#       Definition: a young person, not fully developed
#         ↑ person.n.01: a human being
#
#   HYPONYMS (more specific): 17 found
#     → bairn.n.01
#       Definition: a child: son or daughter
#     → foster-child.n.01
#       Definition: a child who is raised by foster parents
#     → poster_child.n.01
#       Definition: a child afflicted by some disease or deformity whose picture is used on posters to raise money for charitable purposes
#     → toddler.n.01
#       Definition: a young child
#     → imp.n.02
#       Definition: one who is playfully mischievous
#     → child_prodigy.n.01
#       Definition: a prodigy whose talents are recognized at an early age
#     → orphan.n.01
#       Definition: a child who has lost both parents
#     → sprog.n.02
#       Definition: a child
#     → waif.n.01
#       Definition: a homeless child especially one forsaken or orphaned
#     → changeling.n.02
#       Definition: a child secretly exchanged for another in infancy
#     → peanut.n.03
#       Definition: a young child who is small for his age
#     → buster.n.02
#       Definition: a robust child
#     → pickaninny.n.01
#       Definition: (ethnic slur) offensive term for a Black child
#     → kiddy.n.01
#       Definition: a young child
#     → preschooler.n.01
#       Definition: a child who attends a preschool or kindergarten
#     → silly.n.01
#       Definition: a word used for misbehaving children
#     → urchin.n.01
#       Definition: poor and often mischievous city child
#
#   HIERARCHY PATH (up to root):
#     └─ child.n.01
#       └─ juvenile.n.01
#         └─ person.n.01
#           └─ organism.n.01
#             └─ living_thing.n.01
#               └─ whole.n.02
#                 └─ object.n.01
#                   └─ physical_entity.n.01
#                     └─ entity.n.01
#           └─ causal_agent.n.01
#             └─ physical_entity.n.01
#               └─ entity.n.01
#
# WORD: 'alexa'
#   No synsets found for 'alexa'
#
# WORD: 'honestopinion'
#   No synsets found for 'honestopinion'
#
# WORD: 'customer'
#   Definition: someone who pays for goods or services
#   Example: No example
#
#   HYPERNYMS (more general): 1 found
#     → consumer.n.01
#       Definition: a person who uses goods or services
#         ↑ user.n.01: a person who makes use of a thing; someone who uses or employs something
#
#   HYPONYMS (more specific): 10 found
#     → warrantee.n.02
#       Definition: a customer to whom a warrant or guarantee is given
#     → guest.n.03
#       Definition: a customer of a hotel or restaurant etc.
#     → subscriber.n.02
#       Definition: someone who contracts to receive and pay for a service or a certain number of issues of a publication
#     → shopper.n.01
#       Definition: someone who visits stores in search of articles to buy
#     → whoremaster.n.01
#       Definition: a prostitute's customer
#     → buyer.n.01
#       Definition: a person who buys
#     → taker.n.01
#       Definition: one who accepts an offer
#     → policyholder.n.01
#       Definition: a person who holds an insurance policy; usually, the client in whose name an insurance policy is written
#     → spender.n.03
#       Definition: someone who spends money to purchase goods or services
#     → patron.n.01
#       Definition: a regular customer
#
#   HIERARCHY PATH (up to root):
#     └─ customer.n.01
#       └─ consumer.n.01
#         └─ user.n.01
#           └─ person.n.01
#             └─ organism.n.01
#               └─ living_thing.n.01
#                 └─ whole.n.02
#                   └─ object.n.01
#                     └─ physical_entity.n.01
#                       └─ entity.n.01
#             └─ causal_agent.n.01
#               └─ physical_entity.n.01
#                 └─ entity.n.01
#
# WORD: 'check'
#   Definition: a written order directing a bank to pay money
#   Example: ['he paid all his bills by check']
#
#   HYPERNYMS (more general): 1 found
#     → draft.n.01
#       Definition: a document ordering the payment of money; drawn by one person or bank on another
#         ↑ negotiable_instrument.n.01: an unconditional order or promise to pay an amount of money
#
#   HYPONYMS (more specific): 11 found
#     → paycheck.n.01
#       Definition: a check issued in payment of wages or salary
#     → blank_check.n.02
#       Definition: a check that has been signed but with the amount payable left blank
#     → kite.n.02
#       Definition: a bank check drawn on insufficient funds at another bank in order to take advantage of the float
#     → certified_check.n.01
#       Definition: a check containing certification that the person who issued the check has sufficient funds on deposit to cover payment
#     → counter_check.n.01
#       Definition: a blank check provided by a bank for the convenience of customers who are making withdrawals
#     → personal_check.n.01
#       Definition: a check drawn against funds deposited in your personal checking account
#     → medicare_check.n.01
#       Definition: a check reimbursing an aged person for the expenses of health care
#     → cashier's_check.n.01
#       Definition: a check issued by the officer of a bank on the banks own account (not that of a private person)
#     → bad_check.n.01
#       Definition: a check that is dishonored on presentation because of insufficient funds
#     → kite.n.01
#       Definition: a bank check that has been fraudulently altered to increase its face value
#     → giro.n.01
#       Definition: a check given by the British government to someone who is unemployed; it can be cashed either at a bank or at the post office
#
#   HIERARCHY PATH (up to root):
#     └─ check.n.01
#       └─ draft.n.01
#         └─ negotiable_instrument.n.01
#           └─ legal_document.n.01
#             └─ document.n.01
#               └─ writing.n.02
#                 └─ written_communication.n.01
#                   └─ communication.n.02
#                     └─ abstraction.n.06
#                       └─ entity.n.01
#
# WORD: 'httpsyoutubesmarthomexreview'
#   No synsets found for 'httpsyoutubesmarthomexreview'
#
# WORD: 'hours'
#   Definition: a period of time assigned for work
#   Example: ['they work long hours']
#
#   HYPERNYMS (more general): 1 found
#     → work_time.n.01
#       Definition: a time period when you are required to work
#         ↑ time_period.n.01: an amount of time
#
#   HYPONYMS (more specific): 1 found
#     → shift.n.03
#       Definition: the time period during which you are at work
#
#   HIERARCHY PATH (up to root):
#     └─ hours.n.01
#       └─ work_time.n.01
#         └─ time_period.n.01
#           └─ fundamental_quantity.n.01
#             └─ measure.n.02
#               └─ abstraction.n.06
#                 └─ entity.n.01
#
# WORD: 'responded'
#   Definition: show a response or a reaction to something
#   Example: No example
#
#   HYPERNYMS (more general): 1 found
#     → act.v.01
#       Definition: perform an action, or work out or perform (an action)
#
#   HYPONYMS (more specific): 17 found
#     → flip.v.09
#       Definition: react in an excited, delighted, or surprised way
#     → respond.v.03
#       Definition: respond favorably or as hoped
#     → explode.v.03
#       Definition: show a violent emotional reaction
#     → accept.v.03
#       Definition: give an affirmative reply to; respond favorably to
#     → refuse.v.01
#       Definition: show unwillingness towards
#     → accept.v.11
#       Definition: be sexually responsive to, used of a female domesticated mammal
#     → greet.v.03
#       Definition: react to in a certain way
#     → treat.v.08
#       Definition: regard or consider in a specific way
#     → accept.v.04
#       Definition: react favorably to; consider right and proper
#     → notice.v.04
#       Definition: express recognition of the presence or existence of, or acquaintance with
#     → answer.v.10
#       Definition: react to a stimulus or command
#     → stool.v.02
#       Definition: react to a decoy, of wildfowl
#     → answer.v.02
#       Definition: respond to a signal
#     → bristle.v.04
#       Definition: react in an offended or angry manner
#     → wonder.v.03
#       Definition: be amazed at
#     → resist.v.05
#       Definition: resist immunologically the introduction of some foreign tissue or organ
#     → overreact.v.01
#       Definition: show an exaggerated response to something
#
#   HIERARCHY PATH (up to root):
#     └─ react.v.01
#       └─ act.v.01
#
# WORD: 'last'
#   Definition: the temporal end; the concluding time
#   Example: ['the stopping point of each round was signaled by a bell', 'the market was up at the finish', 'they were playing better at the close of the season']
#
#   HYPERNYMS (more general): 1 found
#     → end.n.02
#       Definition: the point in time at which something ends
#         ↑ point.n.06: an instant of time
#
#   HYPONYMS: None found
#
#   HIERARCHY PATH (up to root):
#     └─ stopping_point.n.01
#       └─ end.n.02
#         └─ point.n.06
#           └─ measure.n.02
#             └─ abstraction.n.06
#               └─ entity.n.01
#
# WORD: 'mobile'
#   Definition: a river in southwestern Alabama; flows into Mobile Bay
#   Example: No example
#
#   HYPERNYMS: None found
#
#   HYPONYMS: None found
#
#   HIERARCHY PATH (up to root):
#     └─ mobile.n.01
#
# WORD: 'setup'
#   Definition: equipment designed to serve a specific function
#   Example: No example
#
#   HYPERNYMS (more general): 1 found
#     → equipment.n.01
#       Definition: an instrumentality needed for an undertaking or to perform a service
#         ↑ instrumentality.n.03: an artifact (or system of artifacts) that is instrumental in accomplishing some end
#
#   HYPONYMS (more specific): 28 found
#     → duplicator.n.01
#       Definition: apparatus that makes copies of typed, written or drawn material
#     → still.n.03
#       Definition: an apparatus used for the distillation of liquids; consists of a vessel in which a substance is vaporized by heat and a condenser where the vapor is condensed
#     → heat_pump.n.01
#       Definition: apparatus that extracts heat from a liquid that is at a higher temperature than its surroundings; can be used to transfer heat from a reservoir outside in order to heat a building
#     → sequencer.n.01
#       Definition: (chemistry) an apparatus that can determine the sequence of monomers in a polymer
#     → cascade_liquefier.n.01
#       Definition: an apparatus used to liquefy air or oxygen etc.
#     → pendulum.n.01
#       Definition: an apparatus consisting of an object mounted so that it swings freely under the influence of gravity
#     → aerator.n.01
#       Definition: an apparatus for exposing something to the air (as sewage)
#     → burner.n.01
#       Definition: an apparatus for burning fuel (or refuse)
#     → soda_fountain.n.02
#       Definition: an apparatus for dispensing soda water
#     → condenser.n.02
#       Definition: an apparatus that converts vapor into liquid
#     → purifier.n.01
#       Definition: an apparatus for removing impurities
#     → kipp's_apparatus.n.01
#       Definition: a laboratory apparatus for producing a gas (usually hydrogen sulfide) by the action of a liquid on a solid without heating
#     → titrator.n.01
#       Definition: an apparatus for performing a titration
#     → centrifuge.n.01
#       Definition: an apparatus that uses centrifugal force to separate particles from a suspension
#     → instillator.n.01
#       Definition: medical apparatus that puts a liquid into a cavity drop by drop
#     → x-ray_machine.n.01
#       Definition: an apparatus that provides a source of X rays
#     → electrograph.n.01
#       Definition: an apparatus for the electrical transmission of pictures
#     → lighting.n.02
#       Definition: apparatus for supplying artificial light effects for the stage or a film
#     → reformer.n.02
#       Definition: an apparatus that reforms the molecular structure of hydrocarbons to produce richer fuel
#     → chemical_reactor.n.01
#       Definition: an apparatus for holding substances that are undergoing a chemical reaction
#     → incubator.n.01
#       Definition: apparatus consisting of a box designed to maintain a constant temperature by the use of a thermostat; used for chicks or premature infants
#     → telegraph.n.01
#       Definition: apparatus used to communicate at a distance over a wire (usually in Morse code)
#     → nuclear_reactor.n.01
#       Definition: (physics) any of several kinds of apparatus that maintain and control a nuclear reaction for the production of energy or artificial elements
#     → heliograph.n.01
#       Definition: an apparatus for sending telegraphic messages by using a mirror to turn the sun's rays off and on
#     → optical_bench.n.01
#       Definition: apparatus for observation and measurement of optical phenomena
#     → semaphore.n.01
#       Definition: an apparatus for visual signaling with lights or mechanically moving arms
#     → submersible.n.01
#       Definition: an apparatus intended for use under water
#     → generator.n.01
#       Definition: an apparatus that produces a vapor or gas
#
#   HIERARCHY PATH (up to root):
#     └─ apparatus.n.01
#       └─ equipment.n.01
#         └─ instrumentality.n.03
#           └─ artifact.n.01
#             └─ whole.n.02
#               └─ object.n.01
#                 └─ physical_entity.n.01
#                   └─ entity.n.01
#
# WORD: 'crashes'
#   Definition: a loud resonant repeating noise
#   Example: ['he could hear the clang of distant bells']
#
#   HYPERNYMS (more general): 1 found
#     → noise.n.01
#       Definition: sound of any kind (especially unintelligible or dissonant sound)
#         ↑ sound.n.04: the sudden occurrence of an audible event
#
#   HYPONYMS: None found
#
#   HIERARCHY PATH (up to root):
#     └─ clang.n.01
#       └─ noise.n.01
#         └─ sound.n.04
#           └─ happening.n.01
#             └─ event.n.01
#               └─ psychological_feature.n.01
#                 └─ abstraction.n.06
#                   └─ entity.n.01
#
# WORD: 'overall'
#   Definition: (usually plural) work clothing consisting of denim trousers (usually with a bib and shoulder straps)
#   Example: No example
#
#   HYPERNYMS (more general): 1 found
#     → work-clothing.n.01
#       Definition: clothing worn for doing manual labor
#         ↑ clothing.n.01: a covering designed to be worn on a person's body
#
#   HYPONYMS: None found
#
#   HIERARCHY PATH (up to root):
#     └─ overall.n.01
#       └─ work-clothing.n.01
#         └─ clothing.n.01
#           └─ consumer_goods.n.01
#             └─ commodity.n.01
#               └─ artifact.n.01
#                 └─ whole.n.02
#                   └─ object.n.01
#                     └─ physical_entity.n.01
#                       └─ entity.n.01
#           └─ covering.n.02
#             └─ artifact.n.01
#               └─ whole.n.02
#                 └─ object.n.01
#                   └─ physical_entity.n.01
#                     └─ entity.n.01
#
# WORD: 'recommend'
#   Definition: push for something
#   Example: ['The travel agent recommended strongly that we not travel on Thanksgiving Day']
#
#   HYPERNYMS (more general): 1 found
#     → propose.v.01
#       Definition: make a proposal, declare a plan for something
#         ↑ declare.v.01: state emphatically and authoritatively
#
#   HYPONYMS: None found
#
#   HIERARCHY PATH (up to root):
#     └─ recommend.v.01
#       └─ propose.v.01
#         └─ declare.v.01
#           └─ state.v.01
#             └─ express.v.02
#
# WORD: 'sometimes'
#   Definition: on certain occasions or in certain cases but not always
#   Example: ['sometimes she wished she were back in England', 'sometimes her photography is breathtaking', 'sometimes they come for a month; at other times for six months']
#
#   HYPERNYMS: None found
#
#   HYPONYMS: None found
#
#   HIERARCHY PATH (up to root):
#     └─ sometimes.r.01
#
# WORD: 'pros'
#   Definition: an athlete who plays for pay
#   Example: No example
#
#   HYPERNYMS (more general): 1 found
#     → athlete.n.01
#       Definition: a person trained to compete in sports
#         ↑ contestant.n.01: a person who participates in competitions
#
#   HYPONYMS (more specific): 2 found
#     → semiprofessional.n.01
#       Definition: an athlete who plays for pay on a part-time basis
#     → free_agent.n.01
#       Definition: (sports) a professional athlete who is free to sign a contract to play for any team
#
#   HIERARCHY PATH (up to root):
#     └─ professional.n.02
#       └─ athlete.n.01
#         └─ contestant.n.01
#           └─ person.n.01
#             └─ organism.n.01
#               └─ living_thing.n.01
#                 └─ whole.n.02
#                   └─ object.n.01
#                     └─ physical_entity.n.01
#                       └─ entity.n.01
#             └─ causal_agent.n.01
#               └─ physical_entity.n.01
#                 └─ entity.n.01
#
# WORD: 'x'
#   Definition: the cardinal number that is the sum of nine and one; the base of the decimal system
#   Example: No example
#
#   HYPERNYMS (more general): 1 found
#     → large_integer.n.01
#       Definition: an integer equal to or greater than ten
#         ↑ integer.n.01: any of the natural numbers (positive or negative) or zero
#
#   HYPONYMS: None found
#
#   HIERARCHY PATH (up to root):
#     └─ ten.n.01
#       └─ large_integer.n.01
#         └─ integer.n.01
#           └─ number.n.02
#             └─ definite_quantity.n.01
#               └─ measure.n.02
#                 └─ abstraction.n.06
#                   └─ entity.n.01
#
# WORD: 'app'
#   No synsets found for 'app'
#
# WORD: 'easy'
#   Definition: posing no difficulty; requiring little effort
#   Example: ['an easy job', 'an easy problem', 'an easy victory', 'the house is easy to heat', 'satisfied with easy answers', 'took the easy way out of his dilemma']
#
#   HYPERNYMS: None found
#
#   HYPONYMS: None found
#
#   HIERARCHY PATH (up to root):
#     └─ easy.a.01
#
# WORD: 'stars'
#   Definition: (astronomy) a celestial body of hot gases that radiates energy derived from thermonuclear reactions in the interior
#   Example: No example
#
#   HYPERNYMS (more general): 1 found
#     → celestial_body.n.01
#       Definition: natural objects visible in the sky
#         ↑ natural_object.n.01: an object occurring naturally; not made by man
#
#   HYPONYMS (more specific): 14 found
#     → nova.n.01
#       Definition: a star that ejects some of its material in the form of a cloud and become more luminous in the process
#     → binary_star.n.01
#       Definition: a system of two stars that revolve around each other under their mutual gravitation
#     → sun.n.04
#       Definition: any star around which a planetary system revolves
#     → supergiant.n.01
#       Definition: an extremely bright star of very large diameter and low density
#     → variable_star.n.01
#       Definition: a star that varies noticeably in brightness
#     → white_dwarf.n.01
#       Definition: a faint star of enormous density
#     → supernova.n.01
#       Definition: a star that explodes and becomes extremely luminous in the process
#     → giant_star.n.01
#       Definition: a very bright star of large diameter and low density (relative to the Sun)
#     → red_dwarf.n.01
#       Definition: a small, old, relatively cool star; approximately 100 times the mass of Jupiter
#     → red_giant.n.01
#       Definition: a large, old, luminous star; has a relatively low surface temperature and a diameter large relative to the sun
#     → multiple_star.n.01
#       Definition: a system of three or more stars associated by gravity
#     → neutron_star.n.01
#       Definition: a star that has collapsed under its own gravity; it is composed of neutrons
#     → lodestar.n.01
#       Definition: guiding star; a star that is used as a reference point in navigation or astronomy
#     → fixed_star.n.01
#       Definition: any star in the Ptolemaic theory of planetary motion
#
#   HIERARCHY PATH (up to root):
#     └─ star.n.01
#       └─ celestial_body.n.01
#         └─ natural_object.n.01
#           └─ whole.n.02
#             └─ object.n.01
#               └─ physical_entity.n.01
#                 └─ entity.n.01
#
# WORD: 'home'
#   Definition: where you live at a particular time
#   Example: ['deliver the package to my home', "he doesn't have a home to go to", 'your place or mine?']
#
#   HYPERNYMS (more general): 1 found
#     → residence.n.01
#       Definition: any address at which you dwell more than temporarily
#         ↑ address.n.02: the place where a person or organization can be found or communicated with
#
#   HYPONYMS (more specific): 1 found
#     → home_away_from_home.n.01
#       Definition: a place where you are just as comfortable and content as if you were home
#
#   HIERARCHY PATH (up to root):
#     └─ home.n.01
#       └─ residence.n.01
#         └─ address.n.02
#           └─ geographic_point.n.01
#             └─ point.n.02
#               └─ location.n.01
#                 └─ object.n.01
#                   └─ physical_entity.n.01
#                     └─ entity.n.01
#
# WORD: 'smarthome'
#   No synsets found for 'smarthome'
#
# WORD: 'minutes'
#   Definition: a written account of what transpired at a meeting
#   Example: No example
#
#   HYPERNYMS (more general): 1 found
#     → written_record.n.01
#       Definition: a written document preserving knowledge of facts or events
#         ↑ record.n.01: anything (such as a document or a phonograph record or a photograph) providing permanent evidence of or information about past events
#
#   HYPONYMS (more specific): 2 found
#     → hansard.n.01
#       Definition: the official published verbatim report of the proceedings of a parliamentary body; originally of the British Parliament
#     → congressional_record.n.01
#       Definition: a published written account of the speeches and debates and votes of the United States Congress
#
#   HIERARCHY PATH (up to root):
#     └─ minutes.n.01
#       └─ written_record.n.01
#         └─ record.n.01
#           └─ evidence.n.02
#             └─ indication.n.01
#               └─ communication.n.02
#                 └─ abstraction.n.06
#                   └─ entity.n.01
#
# WORD: 'great'
#   Definition: a person who has achieved distinction and honor in some field
#   Example: ['he is one of the greats of American music']
#
#   HYPERNYMS (more general): 1 found
#     → achiever.n.01
#       Definition: a person with a record of successes
#         ↑ person.n.01: a human being
#
#   HYPONYMS: None found
#
#   HIERARCHY PATH (up to root):
#     └─ great.n.01
#       └─ achiever.n.01
#         └─ person.n.01
#           └─ organism.n.01
#             └─ living_thing.n.01
#               └─ whole.n.02
#                 └─ object.n.01
#                   └─ physical_entity.n.01
#                     └─ entity.n.01
#           └─ causal_agent.n.01
#             └─ physical_entity.n.01
#               └─ entity.n.01
#
# WORD: 'product'
#   Definition: commodities offered for sale
#   Example: ['good business depends on having good merchandise', 'that store offers a variety of products']
#
#   HYPERNYMS (more general): 1 found
#     → commodity.n.01
#       Definition: articles of commerce
#         ↑ artifact.n.01: a man-made object taken as a whole
#
#   HYPONYMS (more specific): 15 found
#     → generic.n.02
#       Definition: any product that can be sold without a brand name
#     → number.n.11
#       Definition: an item of merchandise offered for sale
#     → line.n.22
#       Definition: a particular kind of product or merchandise
#     → release.n.01
#       Definition: merchandise issued for sale or public showing (especially a record or film)
#     → stock.n.02
#       Definition: the merchandise that a shop has on hand
#     → yard_goods.n.01
#       Definition: merchandise in the form of fabrics sold by the yard
#     → software_package.n.02
#       Definition: merchandise consisting of a computer program that is offered for sale
#     → refill.n.02
#       Definition: a commercial product that refills a container with its appropriate contents
#     → irregular.n.02
#       Definition: merchandise that has imperfections; usually sold at a reduced price without the brand name
#     → top_of_the_line.n.01
#       Definition: the best (most expensive) in a given line of merchandise
#     → schlock.n.01
#       Definition: merchandise that is shoddy or inferior
#     → contraband.n.01
#       Definition: goods whose importation or exportation or possession is prohibited by law
#     → cargo.n.01
#       Definition: goods carried by a large vehicle
#     → ironmongery.n.01
#       Definition: the merchandise that is sold in an ironmonger's shop
#     → feature.n.06
#       Definition: an article of merchandise that is displayed or advertised more than other articles
#
#   HIERARCHY PATH (up to root):
#     └─ merchandise.n.01
#       └─ commodity.n.01
#         └─ artifact.n.01
#           └─ whole.n.02
#             └─ object.n.01
#               └─ physical_entity.n.01
#                 └─ entity.n.01
#
# DETAILED EXAMPLE FOR KEY WORDS FROM TEXT
#
# DEEP ANALYSIS FOR: 'apple'
#   Definition: fruit with red or yellow or green skin and sweet to tart crisp whitish flesh
#   Lemmas: ['apple']
#
#   All Hypernym Paths:
#     Path 1: entity -> physical_entity -> object -> whole -> natural_object -> plant_part -> plant_organ -> reproductive_structure -> fruit -> pome -> apple
#     Path 2: entity -> physical_entity -> object -> whole -> natural_object -> plant_part -> plant_organ -> reproductive_structure -> fruit -> edible_fruit -> apple
#     Path 3: entity -> physical_entity -> matter -> solid -> food -> produce -> edible_fruit -> apple
#
#   Total hyponyms found: 3
#   All hyponyms:
#     - cooking_apple.n.01: an apple used primarily in cooking for pies and applesauce etc
#     - eating_apple.n.01: an apple used primarily for eating raw without cooking
#     - crab_apple.n.03: small sour apple; suitable for preserving
#
# DEEP ANALYSIS FOR: 'computer'
#   Definition: a machine for performing calculations automatically
#   Lemmas: ['computer', 'computing_machine', 'computing_device', 'data_processor', 'electronic_computer', 'information_processing_system']
#
#   All Hypernym Paths:
#     Path 1: entity -> physical_entity -> object -> whole -> artifact -> instrumentality -> device -> machine -> computer
#
#   Total hyponyms found: 10
#   All hyponyms:
#     - node.n.08: (computer science) any computer that is hooked up to a computer network
#     - digital_computer.n.01: a computer that represents information by numerical (binary) digits
#     - predictor.n.03: a computer for controlling antiaircraft fire that computes the position of an aircraft at the instant of a shell's arrival
#     - web_site.n.01: a computer connected to the internet that maintains a series of web pages on the World Wide Web
#     - server.n.03: (computer science) a computer that provides client stations with access to files and printers as shared resources to a computer network
#     - analog_computer.n.01: a computer that represents information by variable quantities (e.g., positions or voltages)
#     - turing_machine.n.01: a hypothetical computer with an infinitely long memory tape
#     - number_cruncher.n.02: a computer capable of performing a large number of mathematical operations per second
#     - home_computer.n.01: a computer intended for use in the home
#     - pari-mutuel_machine.n.01: computer that registers bets and divides the total amount bet among those who won
#
# DEEP ANALYSIS FOR: 'company'
#   Definition: an institution created to conduct business
#   Lemmas: ['company']
#
#   All Hypernym Paths:
#     Path 1: entity -> abstraction -> group -> social_group -> organization -> institution -> company
#
#   Total hyponyms found: 36
#   All hyponyms:
#     - limited_company.n.01: a company that is organized to give its owners limited liability
#     - record_company.n.01: a company that makes and sells musical recordings
#     - livery_company.n.01: one of the chartered companies of London originating with the craft guilds
#     - electronics_company.n.01: a company that makes and sells electronic instruments
#     - subsidiary_company.n.01: a company that is completely controlled by another company
#     - corporate_investor.n.01: a company that invests in (acquires control of) other companies
#     - car_company.n.01: a company that makes and sells automobiles
#     - packaging_company.n.01: a company that packages goods for sale or shipment or storage
#     - holding_company.n.01: a company with controlling shares in other companies
#     - target_company.n.01: a company that has been chosen as attractive for takeover by a potential acquirer
#     - oil_company.n.01: a company that sells oil
#     - east_india_company.n.01: an English company formed in 1600 to develop trade with the new British colonies in India and southeastern Asia; in the 18th century it assumed administrative control of Bengal and held it until the British army took over in 1858 after the Indian Mutiny
#     - bureau_de_change.n.01: (French) an establishment where you can exchange foreign money
#     - broadcasting_company.n.01: a company that manages tv or radio stations
#     - closed_shop.n.01: a company that hires only union members
#     - dot-com.n.01: a company that operates its business primarily on the internet using a URL that ends in `.com'
#     - think_tank.n.01: a company that does research for hire and issues reports on the implications
#     - furniture_company.n.01: a company that sells furniture
#     - steel_company.n.01: a company that makes and sells steel
#     - shipping_company.n.01: a company that provides shipping services
#     - food_company.n.01: a company that processes and sells food
#     - mover.n.04: a company that moves the possessions of a family or business from one site to another
#     - transportation_company.n.01: a company providing transportation
#     - union_shop.n.01: a company allowed to hire nonunion workers on the condition that they will join the union within a specified time
#     - pipeline_company.n.01: a company that operates oil pipelines for the oil industry
#     - mining_company.n.01: a company that owns and manages mines
#     - open_shop.n.01: a company whose workers are hired without regard to their membership in a labor union
#     - joint-stock_company.n.01: a company (usually unincorporated) which has the capital of its members pooled in a common fund; transferable shares represent ownership interest; shareholders are legally liable for all debts of the company
#     - printing_concern.n.01: a company that does commercial printing
#     - stock_company.n.01: a company whose capital is represented by stock
#     - white_knight.n.01: a company that is a friendly acquirer in a takeover
#     - film_company.n.01: a company that makes, advertises, and distributes movies
#     - distributor.n.03: a company that markets merchandise
#     - drug_company.n.01: a company that makes and sells pharmaceuticals
#     - shipper.n.02: a company in the business of shipping freight
#     - service.n.04: a company or agency that performs a public service; subject to government regulation
#
# DEEP ANALYSIS FOR: 'inventor'
#   Definition: someone who is the first to think of or make something
#   Lemmas: ['inventor', 'discoverer', 'artificer']
#
#   All Hypernym Paths:
#     Path 1: entity -> physical_entity -> object -> whole -> living_thing -> organism -> person -> creator -> inventor
#     Path 2: entity -> physical_entity -> causal_agent -> person -> creator -> inventor
#
#   Total hyponyms found: 1
#   All hyponyms:
#     - patentee.n.01: the inventor to whom a patent is issued
#
# DEEP ANALYSIS FOR: 'founder'
#   Definition: inflammation of the laminated tissue that attaches the hoof to the foot of a horse
#   Lemmas: ['laminitis', 'founder']
#
#   All Hypernym Paths:
#     Path 1: entity -> abstraction -> psychological_feature -> cognition -> information -> evidence -> symptom -> inflammation -> laminitis
#
#   Total hyponyms found: 0
#
# DEEP ANALYSIS FOR: 'ceo'
#   Definition: the corporate executive responsible for the operations of the firm; reports to a board of directors; may appoint other managers (including a president)
#   Lemmas: ['chief_executive_officer', 'CEO', 'chief_operating_officer']
#
#   All Hypernym Paths:
#     Path 1: entity -> physical_entity -> object -> whole -> living_thing -> organism -> person -> leader -> head -> administrator -> executive -> corporate_executive -> chief_executive_officer
#     Path 2: entity -> physical_entity -> causal_agent -> person -> leader -> head -> administrator -> executive -> corporate_executive -> chief_executive_officer
#
#   Total hyponyms found: 0
#
# DEEP ANALYSIS FOR: 'pixar'
#
# DEEP ANALYSIS FOR: 'next'
#   Definition: immediately following in time or order
#   Lemmas: ['following', 'next']
#
#   All Hypernym Paths:
#     Path 1: following
#
#   Total hyponyms found: 0

# %% [markdown]
# # Summary of All Operations

# %%
# Cell 15: Summary of All Operations
print("SUMMARY OF ALL OPERATIONS PERFORMED")

print(f"1. CLEANING:")
print(f"   - Original text length: {len(raw_text)} characters")
print(f"   - Cleaned text length: {len(text_cleaned)} characters")
print(f"   - Characters removed: {len(raw_text) - len(text_cleaned)}")

print(f"\n2. LOWERCASING:")
print(f"   - Original text length: {len(text_cleaned)} characters")
print(f"   - Lowercased text length: {len(text_lower)} characters")

print(f"\n3. PUNCTUATION REMOVAL:")
print(f"   - Before removal: {len(text_lower)} characters")
print(f"   - After removal: {len(text_no_punct)} characters")
print(f"   - Punctuation removed: {len(text_lower) - len(text_no_punct)}")

print(f"\n4. STOPWORD REMOVAL:")
print(f"   - Tokens before: {len(tokens)}")
print(f"   - Tokens after: {len(filtered_tokens)}")
print(f"   - Stopwords removed: {len(tokens) - len(filtered_tokens)}")

print(f"\n5. TOKENIZATION:")
print(f"   - Number of sentences: {len(sentences)}")
print(f"   - Number of words: {len(words)}")
print(f"   - Number of characters (no spaces): {len(chars)}")

print(f"\n6. STEMMING:")
print(f"   - Original tokens: {len(filtered_tokens)}")
print(f"   - Porter stemmed tokens: {len(porter_stemmed_tokens)}")
print(f"   - Snowball stemmed tokens: {len(snowball_stemmed_tokens)}")

print(f"\n7. LEMMATIZATION:")
print(f"   - Original tokens: {len(filtered_tokens)}")
print(f"   - Lemmatized tokens: {len(lemmatized_tokens)}")

print(f"\n8. POS TAGGING:")
print(f"   - Number of words tagged: {len(pos_tagged)}")

print(f"\n9. CHUNKING:")
print(f"   - Processed all sentences: {len(all_sentences)} sentences")

print(f"\n10. PARSING:")
print(f"    - Dependency parsing: Complete text processed (Full output shown)")
print(f"    - Tree parsing: All sentences processed (Full output shown)")

print(f"\n11. HYPERNYMS & HYPONYMS:")
print(f"    - Unique words analyzed: {len(unique_words)} words")
print(f"    - Key words analyzed: {len(key_words)} words")
# Out:
# SUMMARY OF ALL OPERATIONS PERFORMED
# 1. CLEANING:
#    - Original text length: 473 characters
#    - Cleaned text length: 400 characters
#    - Characters removed: 73
#
# 2. LOWERCASING:
#    - Original text length: 400 characters
#    - Lowercased text length: 400 characters
#
# 3. PUNCTUATION REMOVAL:
#    - Before removal: 400 characters
#    - After removal: 393 characters
#    - Punctuation removed: 7
#
# 4. STOPWORD REMOVAL:
#    - Tokens before: 9
#    - Tokens after: 45
#    - Stopwords removed: -36
#
# 5. TOKENIZATION:
#    - Number of sentences: 4
#    - Number of words: 60
#    - Number of characters (no spaces): 332
#
# 6. STEMMING:
#    - Original tokens: 45
#    - Porter stemmed tokens: 45
#    - Snowball stemmed tokens: 45
#
# 7. LEMMATIZATION:
#    - Original tokens: 45
#    - Lemmatized tokens: 45
#
# 8. POS TAGGING:
#    - Number of words tagged: 45
#
# 9. CHUNKING:
#    - Processed all sentences: 4 sentences
#
# 10. PARSING:
#     - Dependency parsing: Complete text processed (Full output shown)
#     - Tree parsing: All sentences processed (Full output shown)
#
# 11. HYPERNYMS & HYPONYMS:
#     - Unique words analyzed: 43 words
#     - Key words analyzed: 8 words
