# %% [markdown]
# # practice one

# %% [markdown]
# # mabahese vizhe

# %% [markdown]
# # Mohammadali Lotfi kooshali      -        404198471

# %% [markdown]
# # install , download and import libraries

# %%
# !pip install spacy nltk
# !python -m spacy download en_core_web_sm

import re
import spacy
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize, sent_tokenize
from nltk.stem import PorterStemmer, WordNetLemmatizer, SnowballStemmer
from nltk import pos_tag
from nltk.corpus import wordnet as wn
from string import punctuation
from nltk.chunk import RegexpParser
from nltk import Tree
import time

# Download required NLTK data
nltk.download('punkt')
nltk.download('stopwords')
nltk.download('wordnet')
nltk.download('averaged_perceptron_tagger')
nltk.download('omw-1.4')

# Load spaCy model
nlp = spacy.load("en_core_web_sm")
# Out:
# Requirement already satisfied: spacy in D:\.venv\Lib\site-packages (3.8.14)
# Requirement already satisfied: nltk in D:\.venv\Lib\site-packages (3.9.4)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in D:\.venv\Lib\site-packages (from spacy) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in D:\.venv\Lib\site-packages (from spacy) (1.0.0)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in D:\.venv\Lib\site-packages (from spacy) (1.0.10)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in D:\.venv\Lib\site-packages (from spacy) (2.0.13)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in D:\.venv\Lib\site-packages (from spacy) (3.0.13)
# Requirement already satisfied: thinc<8.4.0,>=8.3.12 in D:\.venv\Lib\site-packages (from spacy) (8.3.13)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in D:\.venv\Lib\site-packages (from spacy) (0.10.1)
# Requirement already satisfied: srsly<3.0.0,>=2.5.3 in D:\.venv\Lib\site-packages (from spacy) (2.5.3)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in D:\.venv\Lib\site-packages (from spacy) (2.0.10)
# Requirement already satisfied: weasel<2.0.0,>=1.0.0 in D:\.venv\Lib\site-packages (from spacy) (1.0.0)
# Requirement already satisfied: confection<2.0.0,>=1.3.2 in D:\.venv\Lib\site-packages (from spacy) (1.3.3)
# Requirement already satisfied: typer<1.0.0,>=0.3.0 in D:\.venv\Lib\site-packages (from spacy) (0.23.1)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in D:\.venv\Lib\site-packages (from spacy) (4.67.3)
# Requirement already satisfied: numpy>=1.19.0 in D:\.venv\Lib\site-packages (from spacy) (2.3.5)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in D:\.venv\Lib\site-packages (from spacy) (2.32.5)
# Requirement already satisfied: pydantic<3.0.0,>=2.0.0 in D:\.venv\Lib\site-packages (from spacy) (2.12.5)
# Requirement already satisfied: jinja2 in D:\.venv\Lib\site-packages (from spacy) (3.1.6)
# Requirement already satisfied: setuptools in D:\.venv\Lib\site-packages (from spacy) (81.0.0)
# Requirement already satisfied: packaging>=20.0 in D:\.venv\Lib\site-packages (from spacy) (25.0)
# Requirement already satisfied: annotated-types>=0.6.0 in D:\.venv\Lib\site-packages (from pydantic<3.0.0,>=2.0.0->spacy) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in D:\.venv\Lib\site-packages (from pydantic<3.0.0,>=2.0.0->spacy) (2.41.5)
# Requirement already satisfied: typing-extensions>=4.14.1 in D:\.venv\Lib\site-packages (from pydantic<3.0.0,>=2.0.0->spacy) (4.15.0)
# Requirement already satisfied: typing-inspection>=0.4.2 in D:\.venv\Lib\site-packages (from pydantic<3.0.0,>=2.0.0->spacy) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in D:\.venv\Lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in D:\.venv\Lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in D:\.venv\Lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (2.6.3)
# Requirement already satisfied: certifi>=2017.4.17 in D:\.venv\Lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (2026.1.4)
# Requirement already satisfied: blis<1.4.0,>=1.3.0 in D:\.venv\Lib\site-packages (from thinc<8.4.0,>=8.3.12->spacy) (1.3.3)
# Requirement already satisfied: colorama in D:\.venv\Lib\site-packages (from tqdm<5.0.0,>=4.38.0->spacy) (0.4.6)
# Requirement already satisfied: click>=8.0.0 in D:\.venv\Lib\site-packages (from typer<1.0.0,>=0.3.0->spacy) (8.3.1)
# Requirement already satisfied: shellingham>=1.3.0 in D:\.venv\Lib\site-packages (from typer<1.0.0,>=0.3.0->spacy) (1.5.4)
# Requirement already satisfied: rich>=10.11.0 in D:\.venv\Lib\site-packages (from typer<1.0.0,>=0.3.0->spacy) (14.3.2)
# Requirement already satisfied: annotated-doc>=0.0.2 in D:\.venv\Lib\site-packages (from typer<1.0.0,>=0.3.0->spacy) (0.0.4)
# Requirement already satisfied: cloudpathlib>=0.7.0 in D:\.venv\Lib\site-packages (from weasel<2.0.0,>=1.0.0->spacy) (0.23.0)
# Requirement already satisfied: smart-open>=5.2.1 in D:\.venv\Lib\site-packages (from weasel<2.0.0,>=1.0.0->spacy) (7.6.0)
# Requirement already satisfied: httpx>=0.24.0 in D:\.venv\Lib\site-packages (from weasel<2.0.0,>=1.0.0->spacy) (0.28.1)
# Requirement already satisfied: joblib in D:\.venv\Lib\site-packages (from nltk) (1.5.3)
# Requirement already satisfied: regex>=2021.8.3 in D:\.venv\Lib\site-packages (from nltk) (2026.1.15)
# Requirement already satisfied: anyio in D:\.venv\Lib\site-packages (from httpx>=0.24.0->weasel<2.0.0,>=1.0.0->spacy) (4.12.1)
# Requirement already satisfied: httpcore==1.* in D:\.venv\Lib\site-packages (from httpx>=0.24.0->weasel<2.0.0,>=1.0.0->spacy) (1.0.9)
# Requirement already satisfied: h11>=0.16 in D:\.venv\Lib\site-packages (from httpcore==1.*->httpx>=0.24.0->weasel<2.0.0,>=1.0.0->spacy) (0.16.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in D:\.venv\Lib\site-packages (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in D:\.venv\Lib\site-packages (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in D:\.venv\Lib\site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy) (0.1.2)
# Requirement already satisfied: wrapt in D:\.venv\Lib\site-packages (from smart-open>=5.2.1->weasel<2.0.0,>=1.0.0->spacy) (2.1.2)
# Requirement already satisfied: MarkupSafe>=2.0 in D:\.venv\Lib\site-packages (from jinja2->spacy) (3.0.3)
# Collecting en-core-web-sm==3.8.0
#   WARNING: Retrying (Retry(total=4, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ProtocolError('Connection aborted.', ConnectionResetError(10054, 'An existing connection was forcibly closed by the remote host', None, 10054, None))': /github-production-release-asset/84940268/15132ab6-4050-4914-8fe8-ac2c2fdcb9cf?sp=r&sv=2018-11-09&sr=b&spr=https&se=2026-04-27T19%3A02%3A56Z&rscd=attachment%3B+filename%3Den_core_web_sm-3.8.0-py3-none-any.whl&rsct=application%2Foctet-stream&skoid=96c2d410-5711-43a1-aedd-ab1947aa7ab0&sktid=398a6654-997b-47e9-b12b-9515b896b4de&skt=2026-04-27T18%3A02%3A53Z&ske=2026-04-27T19%3A02%3A56Z&sks=b&skv=2018-11-09&sig=Db9IPg%2FZm%2BkLkUkNYVJ991uDaoFJUDK%2BZYH8eEBdIms%3D&jwt=eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9.eyJpc3MiOiJnaXRodWIuY29tIiwiYXVkIjoicmVsZWFzZS1hc3NldHMuZ2l0aHVidXNlcmNvbnRlbnQuY29tIiwia2V5Ijoia2V5MSIsImV4cCI6MTc3NzMxNTM3NywibmJmIjoxNzc3MzEzNTc3LCJwYXRoIjoicmVsZWFzZWFzc2V0cHJvZHVjdGlvbi5ibG9iLmNvcmUud2luZG93cy5uZXQifQ.DNkSt_VDzlphliIhBvVpPa8iW_31fCcuf2HZqufV1yg&response-content-disposition=attachment%3B%20filename%3Den_core_web_sm-3.8.0-py3-none-any.whl&response-content-type=application%2Foctet-stream
#   WARNING: Retrying (Retry(total=3, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ProtocolError('Connection aborted.', ConnectionResetError(10054, 'An existing connection was forcibly closed by the remote host', None, 10054, None))': /github-production-release-asset/84940268/15132ab6-4050-4914-8fe8-ac2c2fdcb9cf?sp=r&sv=2018-11-09&sr=b&spr=https&se=2026-04-27T19%3A02%3A56Z&rscd=attachment%3B+filename%3Den_core_web_sm-3.8.0-py3-none-any.whl&rsct=application%2Foctet-stream&skoid=96c2d410-5711-43a1-aedd-ab1947aa7ab0&sktid=398a6654-997b-47e9-b12b-9515b896b4de&skt=2026-04-27T18%3A02%3A53Z&ske=2026-04-27T19%3A02%3A56Z&sks=b&skv=2018-11-09&sig=Db9IPg%2FZm%2BkLkUkNYVJ991uDaoFJUDK%2BZYH8eEBdIms%3D&jwt=eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9.eyJpc3MiOiJnaXRodWIuY29tIiwiYXVkIjoicmVsZWFzZS1hc3NldHMuZ2l0aHVidXNlcmNvbnRlbnQuY29tIiwia2V5Ijoia2V5MSIsImV4cCI6MTc3NzMxNTM3NywibmJmIjoxNzc3MzEzNTc3LCJwYXRoIjoicmVsZWFzZWFzc2V0cHJvZHVjdGlvbi5ibG9iLmNvcmUud2luZG93cy5uZXQifQ.DNkSt_VDzlphliIhBvVpPa8iW_31fCcuf2HZqufV1yg&response-content-disposition=attachment%3B%20filename%3Den_core_web_sm-3.8.0-py3-none-any.whl&response-content-type=application%2Foctet-stream
#   WARNING: Retrying (Retry(total=2, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ProtocolError('Connection aborted.', ConnectionResetError(10054, 'An existing connection was forcibly closed by the remote host', None, 10054, None))': /github-production-release-asset/84940268/15132ab6-4050-4914-8fe8-ac2c2fdcb9cf?sp=r&sv=2018-11-09&sr=b&spr=https&se=2026-04-27T19%3A02%3A56Z&rscd=attachment%3B+filename%3Den_core_web_sm-3.8.0-py3-none-any.whl&rsct=application%2Foctet-stream&skoid=96c2d410-5711-43a1-aedd-ab1947aa7ab0&sktid=398a6654-997b-47e9-b12b-9515b896b4de&skt=2026-04-27T18%3A02%3A53Z&ske=2026-04-27T19%3A02%3A56Z&sks=b&skv=2018-11-09&sig=Db9IPg%2FZm%2BkLkUkNYVJ991uDaoFJUDK%2BZYH8eEBdIms%3D&jwt=eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9.eyJpc3MiOiJnaXRodWIuY29tIiwiYXVkIjoicmVsZWFzZS1hc3NldHMuZ2l0aHVidXNlcmNvbnRlbnQuY29tIiwia2V5Ijoia2V5MSIsImV4cCI6MTc3NzMxNTM3NywibmJmIjoxNzc3MzEzNTc3LCJwYXRoIjoicmVsZWFzZWFzc2V0cHJvZHVjdGlvbi5ibG9iLmNvcmUud2luZG93cy5uZXQifQ.DNkSt_VDzlphliIhBvVpPa8iW_31fCcuf2HZqufV1yg&response-content-disposition=attachment%3B%20filename%3Den_core_web_sm-3.8.0-py3-none-any.whl&response-content-type=application%2Foctet-stream
#   WARNING: Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ProtocolError('Connection aborted.', ConnectionResetError(10054, 'An existing connection was forcibly closed by the remote host', None, 10054, None))': /github-production-release-asset/84940268/15132ab6-4050-4914-8fe8-ac2c2fdcb9cf?sp=r&sv=2018-11-09&sr=b&spr=https&se=2026-04-27T19%3A02%3A56Z&rscd=attachment%3B+filename%3Den_core_web_sm-3.8.0-py3-none-any.whl&rsct=application%2Foctet-stream&skoid=96c2d410-5711-43a1-aedd-ab1947aa7ab0&sktid=398a6654-997b-47e9-b12b-9515b896b4de&skt=2026-04-27T18%3A02%3A53Z&ske=2026-04-27T19%3A02%3A56Z&sks=b&skv=2018-11-09&sig=Db9IPg%2FZm%2BkLkUkNYVJ991uDaoFJUDK%2BZYH8eEBdIms%3D&jwt=eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9.eyJpc3MiOiJnaXRodWIuY29tIiwiYXVkIjoicmVsZWFzZS1hc3NldHMuZ2l0aHVidXNlcmNvbnRlbnQuY29tIiwia2V5Ijoia2V5MSIsImV4cCI6MTc3NzMxNTM3NywibmJmIjoxNzc3MzEzNTc3LCJwYXRoIjoicmVsZWFzZWFzc2V0cHJvZHVjdGlvbi5ibG9iLmNvcmUud2luZG93cy5uZXQifQ.DNkSt_VDzlphliIhBvVpPa8iW_31fCcuf2HZqufV1yg&response-content-disposition=attachment%3B%20filename%3Den_core_web_sm-3.8.0-py3-none-any.whl&response-content-type=application%2Foctet-stream
#   WARNING: Retrying (Retry(total=0, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ProtocolError('Connection aborted.', ConnectionResetError(10054, 'An existing connection was forcibly closed by the remote host', None, 10054, None))': /github-production-release-asset/84940268/15132ab6-4050-4914-8fe8-ac2c2fdcb9cf?sp=r&sv=2018-11-09&sr=b&spr=https&se=2026-04-27T19%3A02%3A56Z&rscd=attachment%3B+filename%3Den_core_web_sm-3.8.0-py3-none-any.whl&rsct=application%2Foctet-stream&skoid=96c2d410-5711-43a1-aedd-ab1947aa7ab0&sktid=398a6654-997b-47e9-b12b-9515b896b4de&skt=2026-04-27T18%3A02%3A53Z&ske=2026-04-27T19%3A02%3A56Z&sks=b&skv=2018-11-09&sig=Db9IPg%2FZm%2BkLkUkNYVJ991uDaoFJUDK%2BZYH8eEBdIms%3D&jwt=eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9.eyJpc3MiOiJnaXRodWIuY29tIiwiYXVkIjoicmVsZWFzZS1hc3NldHMuZ2l0aHVidXNlcmNvbnRlbnQuY29tIiwia2V5Ijoia2V5MSIsImV4cCI6MTc3NzMxNTM3NywibmJmIjoxNzc3MzEzNTc3LCJwYXRoIjoicmVsZWFzZWFzc2V0cHJvZHVjdGlvbi5ibG9iLmNvcmUud2luZG93cy5uZXQifQ.DNkSt_VDzlphliIhBvVpPa8iW_31fCcuf2HZqufV1yg&response-content-disposition=attachment%3B%20filename%3Den_core_web_sm-3.8.0-py3-none-any.whl&response-content-type=application%2Foctet-stream
# ERROR: Could not install packages due to an OSError: HTTPSConnectionPool(host='release-assets.githubusercontent.com', port=443): Max retries exceeded with url: /github-production-release-asset/84940268/15132ab6-4050-4914-8fe8-ac2c2fdcb9cf?sp=r&sv=2018-11-09&sr=b&spr=https&se=2026-04-27T19%3A02%3A56Z&rscd=attachment%3B+filename%3Den_core_web_sm-3.8.0-py3-none-any.whl&rsct=application%2Foctet-stream&skoid=96c2d410-5711-43a1-aedd-ab1947aa7ab0&sktid=398a6654-997b-47e9-b12b-9515b896b4de&skt=2026-04-27T18%3A02%3A53Z&ske=2026-04-27T19%3A02%3A56Z&sks=b&skv=2018-11-09&sig=Db9IPg%2FZm%2BkLkUkNYVJ991uDaoFJUDK%2BZYH8eEBdIms%3D&jwt=eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9.eyJpc3MiOiJnaXRodWIuY29tIiwiYXVkIjoicmVsZWFzZS1hc3NldHMuZ2l0aHVidXNlcmNvbnRlbnQuY29tIiwia2V5Ijoia2V5MSIsImV4cCI6MTc3NzMxNTM3NywibmJmIjoxNzc3MzEzNTc3LCJwYXRoIjoicmVsZWFzZWFzc2V0cHJvZHVjdGlvbi5ibG9iLmNvcmUud2luZG93cy5uZXQifQ.DNkSt_VDzlphliIhBvVpPa8iW_31fCcuf2HZqufV1yg&response-content-disposition=attachment%3B%20filename%3Den_core_web_sm-3.8.0-py3-none-any.whl&response-content-type=application%2Foctet-stream (Caused by ProtocolError('Connection aborted.', ConnectionResetError(10054, 'An existing connection was forcibly closed by the remote host', None, 10054, None)))
#
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\ASUS\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\ASUS\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\ASUS\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     C:\Users\ASUS\AppData\Roaming\nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package omw-1.4 to
# [nltk_data]     C:\Users\ASUS\AppData\Roaming\nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!

# %% [markdown]
# # reading text file

# %%
with open('myText.txt', 'r', encoding='utf-8') as file:
    raw_text = file.read()

print("original text:")
print(raw_text)
print(f"Total characters: {len(raw_text)}")
# Out:
# original text:
# Steven Paul Jobs (February 24, 1955 – October 5, 2011) was an American business magnate, inventor, and investor. He was the co-founder, chairman, and CEO of Apple; the chairman and majority shareholder of Pixar; a member of The Walt Disney Company's board of directors following its acquisition of Pixar; and the founder, chairman, and CEO of NeXT. He was a pioneer of the personal computer revolution of the 1970s and 1980s, along with his early business partner and fellow Apple co-founder Steve Wozniak.
#
# Jobs was born in San Francisco to a Syrian father and German-American mother. He was adopted shortly after his birth. Jobs attended Reed College in 1972 before withdrawing that same year. In 1974, he traveled through India seeking enlightenment before later studying Zen Buddhism. He and Wozniak co-founded Apple in 1976 to sell Wozniak's Apple I personal computer. Together the duo gained fame and wealth a year later with production and sale of the Apple II, one of the first highly successful mass-produced microcomputers. Jobs saw the commercial potential of the Xerox Alto in 1979, which was mouse-driven and had a graphical user interface (GUI). This led to the development of the unsuccessful Apple Lisa in 1983, followed by the breakthrough Macintosh in 1984, the first mass-produced computer with a GUI. The Macintosh introduced the desktop publishing industry in 1985 with the addition of the Apple LaserWriter, the first laser printer to feature vector graphics.
#
# In 1985, Jobs was forced out of Apple after a long power struggle with the company's board and its then-CEO, John Sculley. That same year, Jobs took a few Apple employees with him to found NeXT, a computer platform development company that specialized in computers for higher-education and business markets. In addition, he helped to develop the visual effects industry when he funded the computer graphics division of George Lucas's Lucasfilm in 1986. The new company was Pixar, which produced the first 3D computer-animated feature film Toy Story (1995) and went on to become a major animation studio, producing over 25 films since.
#
# In 1997, Jobs returned to Apple as CEO after the company's acquisition of NeXT. He was largely responsible for reviving Apple, which was on the verge of bankruptcy. He worked closely with British designer Jony Ive to develop a line of products that had larger cultural ramifications, beginning with the "Think different" advertising campaign and leading to the Apple Store, App Store (iOS), iMac, iPad, iPod, iPhone, iTunes, and iTunes Store. In 2001, the original Mac OS was replaced with the completely new Mac OS X (later known as macOS), based on NeXT's NeXTSTEP platform, giving the operating system a modern Unix-based foundation for the first time. In 2003, Jobs was diagnosed with a pancreatic neuroendocrine tumor. He died of respiratory arrest related to the tumor in 2011, at the age of 56, with Tim Cook succeeding him as CEO of Apple. In 2022, he was posthumously awarded the Presidential Medal of Freedom.
# Total characters: 3038

# %% [markdown]
# # 1. Cleaning Text with re.sub

# %%
# Remove numbers
text_no_numbers = re.sub(r'\d+', '', raw_text)
print("After removing numbers:")
print(text_no_numbers)
print("-" * 80)

# Remove extra whitespaces
text_cleaned = re.sub(r'\s+', ' ', text_no_numbers)
print("After removing extra whitespaces:")
print(text_cleaned)
print("-" * 80)

# Remove special characters (keep letters, spaces, dots, commas)
text_cleaned = re.sub(r'[^\w\s\.\,]', '', text_cleaned)
print("After removing special characters:")
print(text_cleaned)
print(f"Cleaned text length: {len(text_cleaned)} characters")
# Out:
# After removing numbers:
# Steven Paul Jobs (February ,  – October , ) was an American business magnate, inventor, and investor. He was the co-founder, chairman, and CEO of Apple; the chairman and majority shareholder of Pixar; a member of The Walt Disney Company's board of directors following its acquisition of Pixar; and the founder, chairman, and CEO of NeXT. He was a pioneer of the personal computer revolution of the s and s, along with his early business partner and fellow Apple co-founder Steve Wozniak.
#
# Jobs was born in San Francisco to a Syrian father and German-American mother. He was adopted shortly after his birth. Jobs attended Reed College in  before withdrawing that same year. In , he traveled through India seeking enlightenment before later studying Zen Buddhism. He and Wozniak co-founded Apple in  to sell Wozniak's Apple I personal computer. Together the duo gained fame and wealth a year later with production and sale of the Apple II, one of the first highly successful mass-produced microcomputers. Jobs saw the commercial potential of the Xerox Alto in , which was mouse-driven and had a graphical user interface (GUI). This led to the development of the unsuccessful Apple Lisa in , followed by the breakthrough Macintosh in , the first mass-produced computer with a GUI. The Macintosh introduced the desktop publishing industry in  with the addition of the Apple LaserWriter, the first laser printer to feature vector graphics.
#
# In , Jobs was forced out of Apple after a long power struggle with the company's board and its then-CEO, John Sculley. That same year, Jobs took a few Apple employees with him to found NeXT, a computer platform development company that specialized in computers for higher-education and business markets. In addition, he helped to develop the visual effects industry when he funded the computer graphics division of George Lucas's Lucasfilm in . The new company was Pixar, which produced the first D computer-animated feature film Toy Story () and went on to become a major animation studio, producing over  films since.
#
# In , Jobs returned to Apple as CEO after the company's acquisition of NeXT. He was largely responsible for reviving Apple, which was on the verge of bankruptcy. He worked closely with British designer Jony Ive to develop a line of products that had larger cultural ramifications, beginning with the "Think different" advertising campaign and leading to the Apple Store, App Store (iOS), iMac, iPad, iPod, iPhone, iTunes, and iTunes Store. In , the original Mac OS was replaced with the completely new Mac OS X (later known as macOS), based on NeXT's NeXTSTEP platform, giving the operating system a modern Unix-based foundation for the first time. In , Jobs was diagnosed with a pancreatic neuroendocrine tumor. He died of respiratory arrest related to the tumor in , at the age of , with Tim Cook succeeding him as CEO of Apple. In , he was posthumously awarded the Presidential Medal of Freedom.
# --------------------------------------------------------------------------------
# After removing extra whitespaces:
# Steven Paul Jobs (February , – October , ) was an American business magnate, inventor, and investor. He was the co-founder, chairman, and CEO of Apple; the chairman and majority shareholder of Pixar; a member of The Walt Disney Company's board of directors following its acquisition of Pixar; and the founder, chairman, and CEO of NeXT. He was a pioneer of the personal computer revolution of the s and s, along with his early business partner and fellow Apple co-founder Steve Wozniak. Jobs was born in San Francisco to a Syrian father and German-American mother. He was adopted shortly after his birth. Jobs attended Reed College in before withdrawing that same year. In , he traveled through India seeking enlightenment before later studying Zen Buddhism. He and Wozniak co-founded Apple in to sell Wozniak's Apple I personal computer. Together the duo gained fame and wealth a year later with production and sale of the Apple II, one of the first highly successful mass-produced microcomputers. Jobs saw the commercial potential of the Xerox Alto in , which was mouse-driven and had a graphical user interface (GUI). This led to the development of the unsuccessful Apple Lisa in , followed by the breakthrough Macintosh in , the first mass-produced computer with a GUI. The Macintosh introduced the desktop publishing industry in with the addition of the Apple LaserWriter, the first laser printer to feature vector graphics. In , Jobs was forced out of Apple after a long power struggle with the company's board and its then-CEO, John Sculley. That same year, Jobs took a few Apple employees with him to found NeXT, a computer platform development company that specialized in computers for higher-education and business markets. In addition, he helped to develop the visual effects industry when he funded the computer graphics division of George Lucas's Lucasfilm in . The new company was Pixar, which produced the first D computer-animated feature film Toy Story () and went on to become a major animation studio, producing over films since. In , Jobs returned to Apple as CEO after the company's acquisition of NeXT. He was largely responsible for reviving Apple, which was on the verge of bankruptcy. He worked closely with British designer Jony Ive to develop a line of products that had larger cultural ramifications, beginning with the "Think different" advertising campaign and leading to the Apple Store, App Store (iOS), iMac, iPad, iPod, iPhone, iTunes, and iTunes Store. In , the original Mac OS was replaced with the completely new Mac OS X (later known as macOS), based on NeXT's NeXTSTEP platform, giving the operating system a modern Unix-based foundation for the first time. In , Jobs was diagnosed with a pancreatic neuroendocrine tumor. He died of respiratory arrest related to the tumor in , at the age of , with Tim Cook succeeding him as CEO of Apple. In , he was posthumously awarded the Presidential Medal of Freedom.
# --------------------------------------------------------------------------------
# After removing special characters:
# Steven Paul Jobs February ,  October ,  was an American business magnate, inventor, and investor. He was the cofounder, chairman, and CEO of Apple the chairman and majority shareholder of Pixar a member of The Walt Disney Companys board of directors following its acquisition of Pixar and the founder, chairman, and CEO of NeXT. He was a pioneer of the personal computer revolution of the s and s, along with his early business partner and fellow Apple cofounder Steve Wozniak. Jobs was born in San Francisco to a Syrian father and GermanAmerican mother. He was adopted shortly after his birth. Jobs attended Reed College in before withdrawing that same year. In , he traveled through India seeking enlightenment before later studying Zen Buddhism. He and Wozniak cofounded Apple in to sell Wozniaks Apple I personal computer. Together the duo gained fame and wealth a year later with production and sale of the Apple II, one of the first highly successful massproduced microcomputers. Jobs saw the commercial potential of the Xerox Alto in , which was mousedriven and had a graphical user interface GUI. This led to the development of the unsuccessful Apple Lisa in , followed by the breakthrough Macintosh in , the first massproduced computer with a GUI. The Macintosh introduced the desktop publishing industry in with the addition of the Apple LaserWriter, the first laser printer to feature vector graphics. In , Jobs was forced out of Apple after a long power struggle with the companys board and its thenCEO, John Sculley. That same year, Jobs took a few Apple employees with him to found NeXT, a computer platform development company that specialized in computers for highereducation and business markets. In addition, he helped to develop the visual effects industry when he funded the computer graphics division of George Lucass Lucasfilm in . The new company was Pixar, which produced the first D computeranimated feature film Toy Story  and went on to become a major animation studio, producing over films since. In , Jobs returned to Apple as CEO after the companys acquisition of NeXT. He was largely responsible for reviving Apple, which was on the verge of bankruptcy. He worked closely with British designer Jony Ive to develop a line of products that had larger cultural ramifications, beginning with the Think different advertising campaign and leading to the Apple Store, App Store iOS, iMac, iPad, iPod, iPhone, iTunes, and iTunes Store. In , the original Mac OS was replaced with the completely new Mac OS X later known as macOS, based on NeXTs NeXTSTEP platform, giving the operating system a modern Unixbased foundation for the first time. In , Jobs was diagnosed with a pancreatic neuroendocrine tumor. He died of respiratory arrest related to the tumor in , at the age of , with Tim Cook succeeding him as CEO of Apple. In , he was posthumously awarded the Presidential Medal of Freedom.
# Cleaned text length: 2913 characters

# %% [markdown]
# # 2. Lowercasing

# %%
text_lower = text_cleaned.lower()
print("Text after lowercasing:")
print(text_lower)
# Out:
# Text after lowercasing:
# steven paul jobs february ,  october ,  was an american business magnate, inventor, and investor. he was the cofounder, chairman, and ceo of apple the chairman and majority shareholder of pixar a member of the walt disney companys board of directors following its acquisition of pixar and the founder, chairman, and ceo of next. he was a pioneer of the personal computer revolution of the s and s, along with his early business partner and fellow apple cofounder steve wozniak. jobs was born in san francisco to a syrian father and germanamerican mother. he was adopted shortly after his birth. jobs attended reed college in before withdrawing that same year. in , he traveled through india seeking enlightenment before later studying zen buddhism. he and wozniak cofounded apple in to sell wozniaks apple i personal computer. together the duo gained fame and wealth a year later with production and sale of the apple ii, one of the first highly successful massproduced microcomputers. jobs saw the commercial potential of the xerox alto in , which was mousedriven and had a graphical user interface gui. this led to the development of the unsuccessful apple lisa in , followed by the breakthrough macintosh in , the first massproduced computer with a gui. the macintosh introduced the desktop publishing industry in with the addition of the apple laserwriter, the first laser printer to feature vector graphics. in , jobs was forced out of apple after a long power struggle with the companys board and its thenceo, john sculley. that same year, jobs took a few apple employees with him to found next, a computer platform development company that specialized in computers for highereducation and business markets. in addition, he helped to develop the visual effects industry when he funded the computer graphics division of george lucass lucasfilm in . the new company was pixar, which produced the first d computeranimated feature film toy story  and went on to become a major animation studio, producing over films since. in , jobs returned to apple as ceo after the companys acquisition of next. he was largely responsible for reviving apple, which was on the verge of bankruptcy. he worked closely with british designer jony ive to develop a line of products that had larger cultural ramifications, beginning with the think different advertising campaign and leading to the apple store, app store ios, imac, ipad, ipod, iphone, itunes, and itunes store. in , the original mac os was replaced with the completely new mac os x later known as macos, based on nexts nextstep platform, giving the operating system a modern unixbased foundation for the first time. in , jobs was diagnosed with a pancreatic neuroendocrine tumor. he died of respiratory arrest related to the tumor in , at the age of , with tim cook succeeding him as ceo of apple. in , he was posthumously awarded the presidential medal of freedom.

# %% [markdown]
# # 3. Punctuation Removal

# %%
print("Punctuation removed:", punctuation)
text_no_punct = ''.join([char for char in text_lower if char not in punctuation])
print("Text after punctuation removal:")
print(text_no_punct)
# Out:
# Punctuation removed: !"#$%&'()*+,-./:;<=>?@[\]^_`{|}~
# Text after punctuation removal:
# steven paul jobs february   october   was an american business magnate inventor and investor he was the cofounder chairman and ceo of apple the chairman and majority shareholder of pixar a member of the walt disney companys board of directors following its acquisition of pixar and the founder chairman and ceo of next he was a pioneer of the personal computer revolution of the s and s along with his early business partner and fellow apple cofounder steve wozniak jobs was born in san francisco to a syrian father and germanamerican mother he was adopted shortly after his birth jobs attended reed college in before withdrawing that same year in  he traveled through india seeking enlightenment before later studying zen buddhism he and wozniak cofounded apple in to sell wozniaks apple i personal computer together the duo gained fame and wealth a year later with production and sale of the apple ii one of the first highly successful massproduced microcomputers jobs saw the commercial potential of the xerox alto in  which was mousedriven and had a graphical user interface gui this led to the development of the unsuccessful apple lisa in  followed by the breakthrough macintosh in  the first massproduced computer with a gui the macintosh introduced the desktop publishing industry in with the addition of the apple laserwriter the first laser printer to feature vector graphics in  jobs was forced out of apple after a long power struggle with the companys board and its thenceo john sculley that same year jobs took a few apple employees with him to found next a computer platform development company that specialized in computers for highereducation and business markets in addition he helped to develop the visual effects industry when he funded the computer graphics division of george lucass lucasfilm in  the new company was pixar which produced the first d computeranimated feature film toy story  and went on to become a major animation studio producing over films since in  jobs returned to apple as ceo after the companys acquisition of next he was largely responsible for reviving apple which was on the verge of bankruptcy he worked closely with british designer jony ive to develop a line of products that had larger cultural ramifications beginning with the think different advertising campaign and leading to the apple store app store ios imac ipad ipod iphone itunes and itunes store in  the original mac os was replaced with the completely new mac os x later known as macos based on nexts nextstep platform giving the operating system a modern unixbased foundation for the first time in  jobs was diagnosed with a pancreatic neuroendocrine tumor he died of respiratory arrest related to the tumor in  at the age of  with tim cook succeeding him as ceo of apple in  he was posthumously awarded the presidential medal of freedom

# %% [markdown]
# # 4. Stopword Removal

# %%
# Get English stopwords
stop_words = set(stopwords.words('english'))
print("English stopwords :")
print(list(stop_words))

# Tokenize first
tokens = word_tokenize(text_no_punct)
print(f"Total tokens before stopword removal: {len(tokens)}")
print("tokens before removal:")
print(tokens)

# Remove stopwords
filtered_tokens = [word for word in tokens if word not in stop_words]
print(f"Total tokens after stopword removal: {len(filtered_tokens)}")
print("tokens after removal:")
print(filtered_tokens)

# Convert back to text
text_no_stopwords = ' '.join(filtered_tokens)
print("Complete text after stopword removal:")
print(text_no_stopwords)
# Out:
# English stopwords :
# ['whom', 'and', "you're", "shouldn't", 'd', 'there', 'hadn', 'they', 'll', 'into', "didn't", "i've", "doesn't", 'with', 'during', 'before', 'this', 'these', 'only', 'hasn', 'can', 'mustn', 'each', 't', "he'll", 'as', "they're", 'o', 'had', "don't", 'him', "weren't", 'from', 'she', 'very', 'no', 'off', 'once', "you've", "haven't", 'ours', 'his', "they'd", 'your', 'be', 'doing', 'were', 'has', 'over', "he's", 'how', 'then', 'now', 'all', 'by', 'above', 'don', 'will', "aren't", 'after', "should've", 'haven', 'its', 'was', "wouldn't", 'to', 'while', 'herself', 'hers', "i'll", 'a', 'me', 'themselves', 'itself', "you'll", 'or', "she'll", 'for', "it'll", 'why', 'other', 'any', 'of', 'won', 'wouldn', "shan't", 'own', 'such', 'just', "we're", "hadn't", "isn't", 'mightn', "that'll", "we've", 'have', 'few', 'doesn', 'weren', 'yourselves', 'more', 'below', 'down', 'shouldn', "she's", "won't", 'against', 'you', 'i', "hasn't", 'yours', 'being', 'until', 'what', 'not', 'some', 'didn', 'couldn', "i'd", 'than', 'theirs', "couldn't", "we'll", 'needn', 'here', "mightn't", 'does', 'should', 'those', 'myself', "we'd", 'her', "wasn't", 'about', 'an', 'ain', 'yourself', 's', 'through', 'between', 'my', 're', 'so', 'ma', 'it', "she'd", "they've", 'y', 'nor', "it's", 'shan', 'them', 'further', 'he', 'out', 'when', "he'd", 'do', 'we', 'on', 'because', 'our', 'who', 'did', 'up', "needn't", 'himself', 'if', 'been', 'am', "they'll", 'wasn', 'which', 'again', 'both', 'where', 'under', 'isn', 'the', 'in', 'are', 'is', 'aren', 'too', "i'm", "you'd", 'same', 'that', "it'd", 'ourselves', 'their', 'most', 'at', "mustn't", 'm', 'having', 've', 'but']
# Total tokens before stopword removal: 472
# tokens before removal:
# ['steven', 'paul', 'jobs', 'february', 'october', 'was', 'an', 'american', 'business', 'magnate', 'inventor', 'and', 'investor', 'he', 'was', 'the', 'cofounder', 'chairman', 'and', 'ceo', 'of', 'apple', 'the', 'chairman', 'and', 'majority', 'shareholder', 'of', 'pixar', 'a', 'member', 'of', 'the', 'walt', 'disney', 'companys', 'board', 'of', 'directors', 'following', 'its', 'acquisition', 'of', 'pixar', 'and', 'the', 'founder', 'chairman', 'and', 'ceo', 'of', 'next', 'he', 'was', 'a', 'pioneer', 'of', 'the', 'personal', 'computer', 'revolution', 'of', 'the', 's', 'and', 's', 'along', 'with', 'his', 'early', 'business', 'partner', 'and', 'fellow', 'apple', 'cofounder', 'steve', 'wozniak', 'jobs', 'was', 'born', 'in', 'san', 'francisco', 'to', 'a', 'syrian', 'father', 'and', 'germanamerican', 'mother', 'he', 'was', 'adopted', 'shortly', 'after', 'his', 'birth', 'jobs', 'attended', 'reed', 'college', 'in', 'before', 'withdrawing', 'that', 'same', 'year', 'in', 'he', 'traveled', 'through', 'india', 'seeking', 'enlightenment', 'before', 'later', 'studying', 'zen', 'buddhism', 'he', 'and', 'wozniak', 'cofounded', 'apple', 'in', 'to', 'sell', 'wozniaks', 'apple', 'i', 'personal', 'computer', 'together', 'the', 'duo', 'gained', 'fame', 'and', 'wealth', 'a', 'year', 'later', 'with', 'production', 'and', 'sale', 'of', 'the', 'apple', 'ii', 'one', 'of', 'the', 'first', 'highly', 'successful', 'massproduced', 'microcomputers', 'jobs', 'saw', 'the', 'commercial', 'potential', 'of', 'the', 'xerox', 'alto', 'in', 'which', 'was', 'mousedriven', 'and', 'had', 'a', 'graphical', 'user', 'interface', 'gui', 'this', 'led', 'to', 'the', 'development', 'of', 'the', 'unsuccessful', 'apple', 'lisa', 'in', 'followed', 'by', 'the', 'breakthrough', 'macintosh', 'in', 'the', 'first', 'massproduced', 'computer', 'with', 'a', 'gui', 'the', 'macintosh', 'introduced', 'the', 'desktop', 'publishing', 'industry', 'in', 'with', 'the', 'addition', 'of', 'the', 'apple', 'laserwriter', 'the', 'first', 'laser', 'printer', 'to', 'feature', 'vector', 'graphics', 'in', 'jobs', 'was', 'forced', 'out', 'of', 'apple', 'after', 'a', 'long', 'power', 'struggle', 'with', 'the', 'companys', 'board', 'and', 'its', 'thenceo', 'john', 'sculley', 'that', 'same', 'year', 'jobs', 'took', 'a', 'few', 'apple', 'employees', 'with', 'him', 'to', 'found', 'next', 'a', 'computer', 'platform', 'development', 'company', 'that', 'specialized', 'in', 'computers', 'for', 'highereducation', 'and', 'business', 'markets', 'in', 'addition', 'he', 'helped', 'to', 'develop', 'the', 'visual', 'effects', 'industry', 'when', 'he', 'funded', 'the', 'computer', 'graphics', 'division', 'of', 'george', 'lucass', 'lucasfilm', 'in', 'the', 'new', 'company', 'was', 'pixar', 'which', 'produced', 'the', 'first', 'd', 'computeranimated', 'feature', 'film', 'toy', 'story', 'and', 'went', 'on', 'to', 'become', 'a', 'major', 'animation', 'studio', 'producing', 'over', 'films', 'since', 'in', 'jobs', 'returned', 'to', 'apple', 'as', 'ceo', 'after', 'the', 'companys', 'acquisition', 'of', 'next', 'he', 'was', 'largely', 'responsible', 'for', 'reviving', 'apple', 'which', 'was', 'on', 'the', 'verge', 'of', 'bankruptcy', 'he', 'worked', 'closely', 'with', 'british', 'designer', 'jony', 'ive', 'to', 'develop', 'a', 'line', 'of', 'products', 'that', 'had', 'larger', 'cultural', 'ramifications', 'beginning', 'with', 'the', 'think', 'different', 'advertising', 'campaign', 'and', 'leading', 'to', 'the', 'apple', 'store', 'app', 'store', 'ios', 'imac', 'ipad', 'ipod', 'iphone', 'itunes', 'and', 'itunes', 'store', 'in', 'the', 'original', 'mac', 'os', 'was', 'replaced', 'with', 'the', 'completely', 'new', 'mac', 'os', 'x', 'later', 'known', 'as', 'macos', 'based', 'on', 'nexts', 'nextstep', 'platform', 'giving', 'the', 'operating', 'system', 'a', 'modern', 'unixbased', 'foundation', 'for', 'the', 'first', 'time', 'in', 'jobs', 'was', 'diagnosed', 'with', 'a', 'pancreatic', 'neuroendocrine', 'tumor', 'he', 'died', 'of', 'resp ...
# Total tokens after stopword removal: 277
# tokens after removal:
# ['steven', 'paul', 'jobs', 'february', 'october', 'american', 'business', 'magnate', 'inventor', 'investor', 'cofounder', 'chairman', 'ceo', 'apple', 'chairman', 'majority', 'shareholder', 'pixar', 'member', 'walt', 'disney', 'companys', 'board', 'directors', 'following', 'acquisition', 'pixar', 'founder', 'chairman', 'ceo', 'next', 'pioneer', 'personal', 'computer', 'revolution', 'along', 'early', 'business', 'partner', 'fellow', 'apple', 'cofounder', 'steve', 'wozniak', 'jobs', 'born', 'san', 'francisco', 'syrian', 'father', 'germanamerican', 'mother', 'adopted', 'shortly', 'birth', 'jobs', 'attended', 'reed', 'college', 'withdrawing', 'year', 'traveled', 'india', 'seeking', 'enlightenment', 'later', 'studying', 'zen', 'buddhism', 'wozniak', 'cofounded', 'apple', 'sell', 'wozniaks', 'apple', 'personal', 'computer', 'together', 'duo', 'gained', 'fame', 'wealth', 'year', 'later', 'production', 'sale', 'apple', 'ii', 'one', 'first', 'highly', 'successful', 'massproduced', 'microcomputers', 'jobs', 'saw', 'commercial', 'potential', 'xerox', 'alto', 'mousedriven', 'graphical', 'user', 'interface', 'gui', 'led', 'development', 'unsuccessful', 'apple', 'lisa', 'followed', 'breakthrough', 'macintosh', 'first', 'massproduced', 'computer', 'gui', 'macintosh', 'introduced', 'desktop', 'publishing', 'industry', 'addition', 'apple', 'laserwriter', 'first', 'laser', 'printer', 'feature', 'vector', 'graphics', 'jobs', 'forced', 'apple', 'long', 'power', 'struggle', 'companys', 'board', 'thenceo', 'john', 'sculley', 'year', 'jobs', 'took', 'apple', 'employees', 'found', 'next', 'computer', 'platform', 'development', 'company', 'specialized', 'computers', 'highereducation', 'business', 'markets', 'addition', 'helped', 'develop', 'visual', 'effects', 'industry', 'funded', 'computer', 'graphics', 'division', 'george', 'lucass', 'lucasfilm', 'new', 'company', 'pixar', 'produced', 'first', 'computeranimated', 'feature', 'film', 'toy', 'story', 'went', 'become', 'major', 'animation', 'studio', 'producing', 'films', 'since', 'jobs', 'returned', 'apple', 'ceo', 'companys', 'acquisition', 'next', 'largely', 'responsible', 'reviving', 'apple', 'verge', 'bankruptcy', 'worked', 'closely', 'british', 'designer', 'jony', 'ive', 'develop', 'line', 'products', 'larger', 'cultural', 'ramifications', 'beginning', 'think', 'different', 'advertising', 'campaign', 'leading', 'apple', 'store', 'app', 'store', 'ios', 'imac', 'ipad', 'ipod', 'iphone', 'itunes', 'itunes', 'store', 'original', 'mac', 'os', 'replaced', 'completely', 'new', 'mac', 'os', 'x', 'later', 'known', 'macos', 'based', 'nexts', 'nextstep', 'platform', 'giving', 'operating', 'system', 'modern', 'unixbased', 'foundation', 'first', 'time', 'jobs', 'diagnosed', 'pancreatic', 'neuroendocrine', 'tumor', 'died', 'respiratory', 'arrest', 'related', 'tumor', 'age', 'tim', 'cook', 'succeeding', 'ceo', 'apple', 'posthumously', 'awarded', 'presidential', 'medal', 'freedom']
# Complete text after stopword removal:
# steven paul jobs february october american business magnate inventor investor cofounder chairman ceo apple chairman majority shareholder pixar member walt disney companys board directors following acquisition pixar founder chairman ceo next pioneer personal computer revolution along early business partner fellow apple cofounder steve wozniak jobs born san francisco syrian father germanamerican mother adopted shortly birth jobs attended reed college withdrawing year traveled india seeking enlightenment later studying zen buddhism wozniak cofounded apple sell wozniaks apple personal computer together duo gained fame wealth year later production sale apple ii one first highly successful massproduced microcomputers jobs saw commercial potential xerox alto mousedriven graphical user interface gui led development unsuccessful apple lisa followed breakthrough macintosh first massproduced computer gui macintosh introduced desktop publishing industry addition apple laserwriter first laser printer feature vector graphics jobs forced apple long power struggle companys board thenceo john sculley year jobs took apple employees found next computer platform development company specialized computers highereducation business markets addition helped develop visual effects industry funded computer graphics division george lucass lucasfilm new company pixar produced first computeranimated feature film toy story went become major animation studio producing films since jobs returned apple ceo companys acquisition next largely responsible reviving apple verge bankruptcy worked closely british designer jony ive develop line products larger cultural ramifications beginning think different advertising campaign leading apple store app store ios imac ipad ipod iphone itunes itunes store original mac os replaced completely new mac os x later known macos based nexts nextstep platform giving operating system modern unixbased foundation first time jobs diagnosed pancreatic neuroendocrine tumor died respiratory arrest related tumor age tim cook succeeding ceo apple posthumously awarded presidential medal freedom

# %% [markdown]
# # 5. Tokenization (Sentence, Word, Character)

# %%
# Sentence Tokenization
sentences = sent_tokenize(text_lower)
print("Sentence Tokenization:")
print(f"Total number of sentences: {len(sentences)}")
print("All sentences:")
for i, sent in enumerate(sentences, 1):
    print(f"{i}. {sent}")

# Word Tokenization
words = word_tokenize(text_lower)
print("Word Tokenization:")
print(f"Total number of words: {len(words)}")
print("All words:")
print(words)

# Character Tokenization
chars = [char for char in text_lower if char != ' ']
print("Character Tokenization:")
print(f"Total number of characters (without spaces): {len(chars)}")
print("All characters:")
print(chars)
# Out:
# Sentence Tokenization:
# Total number of sentences: 23
# All sentences:
# 1. steven paul jobs february ,  october ,  was an american business magnate, inventor, and investor.
# 2. he was the cofounder, chairman, and ceo of apple the chairman and majority shareholder of pixar a member of the walt disney companys board of directors following its acquisition of pixar and the founder, chairman, and ceo of next.
# 3. he was a pioneer of the personal computer revolution of the s and s, along with his early business partner and fellow apple cofounder steve wozniak.
# 4. jobs was born in san francisco to a syrian father and germanamerican mother.
# 5. he was adopted shortly after his birth.
# 6. jobs attended reed college in before withdrawing that same year.
# 7. in , he traveled through india seeking enlightenment before later studying zen buddhism.
# 8. he and wozniak cofounded apple in to sell wozniaks apple i personal computer.
# 9. together the duo gained fame and wealth a year later with production and sale of the apple ii, one of the first highly successful massproduced microcomputers.
# 10. jobs saw the commercial potential of the xerox alto in , which was mousedriven and had a graphical user interface gui.
# 11. this led to the development of the unsuccessful apple lisa in , followed by the breakthrough macintosh in , the first massproduced computer with a gui.
# 12. the macintosh introduced the desktop publishing industry in with the addition of the apple laserwriter, the first laser printer to feature vector graphics.
# 13. in , jobs was forced out of apple after a long power struggle with the companys board and its thenceo, john sculley.
# 14. that same year, jobs took a few apple employees with him to found next, a computer platform development company that specialized in computers for highereducation and business markets.
# 15. in addition, he helped to develop the visual effects industry when he funded the computer graphics division of george lucass lucasfilm in .
# 16. the new company was pixar, which produced the first d computeranimated feature film toy story  and went on to become a major animation studio, producing over films since.
# 17. in , jobs returned to apple as ceo after the companys acquisition of next.
# 18. he was largely responsible for reviving apple, which was on the verge of bankruptcy.
# 19. he worked closely with british designer jony ive to develop a line of products that had larger cultural ramifications, beginning with the think different advertising campaign and leading to the apple store, app store ios, imac, ipad, ipod, iphone, itunes, and itunes store.
# 20. in , the original mac os was replaced with the completely new mac os x later known as macos, based on nexts nextstep platform, giving the operating system a modern unixbased foundation for the first time.
# 21. in , jobs was diagnosed with a pancreatic neuroendocrine tumor.
# 22. he died of respiratory arrest related to the tumor in , at the age of , with tim cook succeeding him as ceo of apple.
# 23. in , he was posthumously awarded the presidential medal of freedom.
# Word Tokenization:
# Total number of words: 534
# All words:
# ['steven', 'paul', 'jobs', 'february', ',', 'october', ',', 'was', 'an', 'american', 'business', 'magnate', ',', 'inventor', ',', 'and', 'investor', '.', 'he', 'was', 'the', 'cofounder', ',', 'chairman', ',', 'and', 'ceo', 'of', 'apple', 'the', 'chairman', 'and', 'majority', 'shareholder', 'of', 'pixar', 'a', 'member', 'of', 'the', 'walt', 'disney', 'companys', 'board', 'of', 'directors', 'following', 'its', 'acquisition', 'of', 'pixar', 'and', 'the', 'founder', ',', 'chairman', ',', 'and', 'ceo', 'of', 'next', '.', 'he', 'was', 'a', 'pioneer', 'of', 'the', 'personal', 'computer', 'revolution', 'of', 'the', 's', 'and', 's', ',', 'along', 'with', 'his', 'early', 'business', 'partner', 'and', 'fellow', 'apple', 'cofounder', 'steve', 'wozniak', '.', 'jobs', 'was', 'born', 'in', 'san', 'francisco', 'to', 'a', 'syrian', 'father', 'and', 'germanamerican', 'mother', '.', 'he', 'was', 'adopted', 'shortly', 'after', 'his', 'birth', '.', 'jobs', 'attended', 'reed', 'college', 'in', 'before', 'withdrawing', 'that', 'same', 'year', '.', 'in', ',', 'he', 'traveled', 'through', 'india', 'seeking', 'enlightenment', 'before', 'later', 'studying', 'zen', 'buddhism', '.', 'he', 'and', 'wozniak', 'cofounded', 'apple', 'in', 'to', 'sell', 'wozniaks', 'apple', 'i', 'personal', 'computer', '.', 'together', 'the', 'duo', 'gained', 'fame', 'and', 'wealth', 'a', 'year', 'later', 'with', 'production', 'and', 'sale', 'of', 'the', 'apple', 'ii', ',', 'one', 'of', 'the', 'first', 'highly', 'successful', 'massproduced', 'microcomputers', '.', 'jobs', 'saw', 'the', 'commercial', 'potential', 'of', 'the', 'xerox', 'alto', 'in', ',', 'which', 'was', 'mousedriven', 'and', 'had', 'a', 'graphical', 'user', 'interface', 'gui', '.', 'this', 'led', 'to', 'the', 'development', 'of', 'the', 'unsuccessful', 'apple', 'lisa', 'in', ',', 'followed', 'by', 'the', 'breakthrough', 'macintosh', 'in', ',', 'the', 'first', 'massproduced', 'computer', 'with', 'a', 'gui', '.', 'the', 'macintosh', 'introduced', 'the', 'desktop', 'publishing', 'industry', 'in', 'with', 'the', 'addition', 'of', 'the', 'apple', 'laserwriter', ',', 'the', 'first', 'laser', 'printer', 'to', 'feature', 'vector', 'graphics', '.', 'in', ',', 'jobs', 'was', 'forced', 'out', 'of', 'apple', 'after', 'a', 'long', 'power', 'struggle', 'with', 'the', 'companys', 'board', 'and', 'its', 'thenceo', ',', 'john', 'sculley', '.', 'that', 'same', 'year', ',', 'jobs', 'took', 'a', 'few', 'apple', 'employees', 'with', 'him', 'to', 'found', 'next', ',', 'a', 'computer', 'platform', 'development', 'company', 'that', 'specialized', 'in', 'computers', 'for', 'highereducation', 'and', 'business', 'markets', '.', 'in', 'addition', ',', 'he', 'helped', 'to', 'develop', 'the', 'visual', 'effects', 'industry', 'when', 'he', 'funded', 'the', 'computer', 'graphics', 'division', 'of', 'george', 'lucass', 'lucasfilm', 'in', '.', 'the', 'new', 'company', 'was', 'pixar', ',', 'which', 'produced', 'the', 'first', 'd', 'computeranimated', 'feature', 'film', 'toy', 'story', 'and', 'went', 'on', 'to', 'become', 'a', 'major', 'animation', 'studio', ',', 'producing', 'over', 'films', 'since', '.', 'in', ',', 'jobs', 'returned', 'to', 'apple', 'as', 'ceo', 'after', 'the', 'companys', 'acquisition', 'of', 'next', '.', 'he', 'was', 'largely', 'responsible', 'for', 'reviving', 'apple', ',', 'which', 'was', 'on', 'the', 'verge', 'of', 'bankruptcy', '.', 'he', 'worked', 'closely', 'with', 'british', 'designer', 'jony', 'ive', 'to', 'develop', 'a', 'line', 'of', 'products', 'that', 'had', 'larger', 'cultural', 'ramifications', ',', 'beginning', 'with', 'the', 'think', 'different', 'advertising', 'campaign', 'and', 'leading', 'to', 'the', 'apple', 'store', ',', 'app', 'store', 'ios', ',', 'imac', ',', 'ipad', ',', 'ipod', ',', 'iphone', ',', 'itunes', ',', 'and', 'itunes', 'store', '.', 'in', ',', 'the', 'original', 'mac', 'os', 'was', 'replaced', 'with', 'the', 'completely', 'new', 'mac', 'os', 'x', 'later', 'known', 'as', 'macos', ',', 'based',  ...
# Character Tokenization:
# Total number of characters (without spaces): 2425
# All characters:
# ['s', 't', 'e', 'v', 'e', 'n', 'p', 'a', 'u', 'l', 'j', 'o', 'b', 's', 'f', 'e', 'b', 'r', 'u', 'a', 'r', 'y', ',', 'o', 'c', 't', 'o', 'b', 'e', 'r', ',', 'w', 'a', 's', 'a', 'n', 'a', 'm', 'e', 'r', 'i', 'c', 'a', 'n', 'b', 'u', 's', 'i', 'n', 'e', 's', 's', 'm', 'a', 'g', 'n', 'a', 't', 'e', ',', 'i', 'n', 'v', 'e', 'n', 't', 'o', 'r', ',', 'a', 'n', 'd', 'i', 'n', 'v', 'e', 's', 't', 'o', 'r', '.', 'h', 'e', 'w', 'a', 's', 't', 'h', 'e', 'c', 'o', 'f', 'o', 'u', 'n', 'd', 'e', 'r', ',', 'c', 'h', 'a', 'i', 'r', 'm', 'a', 'n', ',', 'a', 'n', 'd', 'c', 'e', 'o', 'o', 'f', 'a', 'p', 'p', 'l', 'e', 't', 'h', 'e', 'c', 'h', 'a', 'i', 'r', 'm', 'a', 'n', 'a', 'n', 'd', 'm', 'a', 'j', 'o', 'r', 'i', 't', 'y', 's', 'h', 'a', 'r', 'e', 'h', 'o', 'l', 'd', 'e', 'r', 'o', 'f', 'p', 'i', 'x', 'a', 'r', 'a', 'm', 'e', 'm', 'b', 'e', 'r', 'o', 'f', 't', 'h', 'e', 'w', 'a', 'l', 't', 'd', 'i', 's', 'n', 'e', 'y', 'c', 'o', 'm', 'p', 'a', 'n', 'y', 's', 'b', 'o', 'a', 'r', 'd', 'o', 'f', 'd', 'i', 'r', 'e', 'c', 't', 'o', 'r', 's', 'f', 'o', 'l', 'l', 'o', 'w', 'i', 'n', 'g', 'i', 't', 's', 'a', 'c', 'q', 'u', 'i', 's', 'i', 't', 'i', 'o', 'n', 'o', 'f', 'p', 'i', 'x', 'a', 'r', 'a', 'n', 'd', 't', 'h', 'e', 'f', 'o', 'u', 'n', 'd', 'e', 'r', ',', 'c', 'h', 'a', 'i', 'r', 'm', 'a', 'n', ',', 'a', 'n', 'd', 'c', 'e', 'o', 'o', 'f', 'n', 'e', 'x', 't', '.', 'h', 'e', 'w', 'a', 's', 'a', 'p', 'i', 'o', 'n', 'e', 'e', 'r', 'o', 'f', 't', 'h', 'e', 'p', 'e', 'r', 's', 'o', 'n', 'a', 'l', 'c', 'o', 'm', 'p', 'u', 't', 'e', 'r', 'r', 'e', 'v', 'o', 'l', 'u', 't', 'i', 'o', 'n', 'o', 'f', 't', 'h', 'e', 's', 'a', 'n', 'd', 's', ',', 'a', 'l', 'o', 'n', 'g', 'w', 'i', 't', 'h', 'h', 'i', 's', 'e', 'a', 'r', 'l', 'y', 'b', 'u', 's', 'i', 'n', 'e', 's', 's', 'p', 'a', 'r', 't', 'n', 'e', 'r', 'a', 'n', 'd', 'f', 'e', 'l', 'l', 'o', 'w', 'a', 'p', 'p', 'l', 'e', 'c', 'o', 'f', 'o', 'u', 'n', 'd', 'e', 'r', 's', 't', 'e', 'v', 'e', 'w', 'o', 'z', 'n', 'i', 'a', 'k', '.', 'j', 'o', 'b', 's', 'w', 'a', 's', 'b', 'o', 'r', 'n', 'i', 'n', 's', 'a', 'n', 'f', 'r', 'a', 'n', 'c', 'i', 's', 'c', 'o', 't', 'o', 'a', 's', 'y', 'r', 'i', 'a', 'n', 'f', 'a', 't', 'h', 'e', 'r', 'a', 'n', 'd', 'g', 'e', 'r', 'm', 'a', 'n', 'a', 'm', 'e', 'r', 'i', 'c', 'a', 'n', 'm', 'o', 't', 'h', 'e', 'r', '.', 'h', 'e', 'w', 'a', 's', 'a', 'd', 'o', 'p', 't', 'e', 'd', 's', 'h', 'o', 'r', 't', 'l', 'y', 'a', 'f', 't', 'e', 'r', 'h', 'i', 's', 'b', 'i', 'r', 't', 'h', '.', 'j', 'o', 'b', 's', 'a', 't', 't', 'e', 'n', 'd', 'e', 'd', 'r', 'e', 'e', 'd', 'c', 'o', 'l', 'l', 'e', 'g', 'e', 'i', 'n', 'b', 'e', 'f', 'o', 'r', 'e', 'w', 'i', 't', 'h', 'd', 'r', 'a', 'w', 'i', 'n', 'g', 't', 'h', 'a', 't', 's', 'a', 'm', 'e', 'y', 'e', 'a', 'r', '.', 'i', 'n', ',', 'h', 'e', 't', 'r', 'a', 'v', 'e', 'l', 'e', 'd', 't', 'h', 'r', 'o', 'u', 'g', 'h', 'i', 'n', 'd', 'i', 'a', 's', 'e', 'e', 'k', 'i', 'n', 'g', 'e', 'n', 'l', 'i', 'g', 'h', 't', 'e', 'n', 'm', 'e', 'n', 't', 'b', 'e', 'f', 'o', 'r', 'e', 'l', 'a', 't', 'e', 'r', 's', 't', 'u', 'd', 'y', 'i', 'n', 'g', 'z', 'e', 'n', 'b', 'u', 'd', 'd', 'h', 'i', 's', 'm', '.', 'h', 'e', 'a', 'n', 'd', 'w', 'o', 'z', 'n', 'i', 'a', 'k', 'c', 'o', 'f', 'o', 'u', 'n', 'd', 'e', 'd', 'a', 'p', 'p', 'l', 'e', 'i', 'n', 't', 'o', 's', 'e', 'l', 'l', 'w', 'o', 'z', 'n', 'i', 'a', 'k', 's', 'a', 'p', 'p', 'l', 'e', 'i', 'p', 'e', 'r', 's', 'o', 'n', 'a', 'l', 'c', 'o', 'm', 'p', 'u', 't', 'e', 'r', '.', 't', 'o', 'g', 'e', 't', 'h', 'e', 'r', 't', 'h', 'e', 'd', 'u', 'o', 'g', 'a', 'i', 'n', 'e', 'd', 'f', 'a', 'm', 'e', 'a', 'n', 'd', 'w', 'e', 'a', 'l', 't', 'h', 'a', 'y', 'e', 'a', 'r', 'l', 'a', 't', 'e', 'r', 'w', 'i', 't', 'h', 'p', 'r', 'o', 'd', 'u', 'c', 't', 'i', 'o', 'n', 'a', 'n', 'd', 's', 'a', 'l', 'e', 'o', 'f', 't', 'h', 'e', 'a', 'p', 'p', 'l', 'e', 'i', 'i', ',', 'o', 'n', 'e', 'o', 'f', 't', 'h', 'e', 'f', 'i', 'r', 's', 't', 'h', 'i', 'g', 'h', 'l', 'y', 's', 'u', 'c', 'c', 'e', 's', 's', 'f', 'u', 'l', 'm', 'a', 's', 's', 'p', ...

# %% [markdown]
# # 6. Stemming (PorterStemmer and SnowballStemmer)

# %%
# Initialize both stemmers
porter_stemmer = PorterStemmer()
snowball_stemmer = SnowballStemmer("english")

# Apply both stemmers
porter_stemmed_tokens = [porter_stemmer.stem(word) for word in filtered_tokens]
snowball_stemmed_tokens = [snowball_stemmer.stem(word) for word in filtered_tokens]

print("COMPLETE COMPARISON (Original vs Porter vs Snowball):")
print(f"{'#':<5} | {'Original Word':<25} | {'Porter Stemmer':<20} | {'Snowball Stemmer':<20} | {'Difference'}")

difference_count = 0
for i, (original, porter, snowball) in enumerate(zip(filtered_tokens, porter_stemmed_tokens, snowball_stemmed_tokens), 1):
    difference = "DIFFERENT" if porter != snowball else "SAME"
    if porter != snowball:
        difference_count += 1
    print(f"{i:<5} | {original:<25} | {porter:<20} | {snowball:<20} | {difference}")

print(f"\nTotal words with different stemming results: {difference_count} out of {len(filtered_tokens)}")
print(f"Percentage of differences: {(difference_count/len(filtered_tokens))*100:.2f}%")

# Show detailed comparison for words that differ
print("\nDETAILED COMPARISON FOR WORDS WITH DIFFERENT STEMMING RESULTS:")

different_words = []
for original, porter, snowball in zip(filtered_tokens, porter_stemmed_tokens, snowball_stemmed_tokens):
    if porter != snowball:
        different_words.append((original, porter, snowball))

if different_words:
    print(f"{'#':<5} | {'Original Word':<25} | {'Porter Result':<20} | {'Snowball Result':<20} | {'Analysis'}")
    for i, (original, porter, snowball) in enumerate(different_words, 1):
        analysis = ""
        if len(porter) < len(snowball):
            analysis = "Porter shorter"
        elif len(snowball) < len(porter):
            analysis = "Snowball shorter"
        elif porter.endswith('ing') and not snowball.endswith('ing'):
            analysis = "Porter keeps -ing"
        elif snowball.endswith('ing') and not porter.endswith('ing'):
            analysis = "Snowball keeps -ing"
        else:
            analysis = "Different algorithm"
        print(f"{i:<5} | {original:<25} | {porter:<20} | {snowball:<20} | {analysis}")
else:
    print("No differences found between Porter and Snowball stemmers for this text.")

# Show complete stemmed texts
print("\nCOMPLETE PORTER STEMMED TEXT:")
porter_stemmed_text = ' '.join(porter_stemmed_tokens)
print(porter_stemmed_text)

print("\nCOMPLETE SNOWBALL STEMMED TEXT:")
snowball_stemmed_text = ' '.join(snowball_stemmed_tokens)
print(snowball_stemmed_text)

# Performance comparison
print("\nPERFORMANCE COMPARISON:")

# Test Porter speed
start_time = time.time()
for word in filtered_tokens * 10:
    porter_stemmer.stem(word)
porter_time = time.time() - start_time

# Test Snowball speed
start_time = time.time()
for word in filtered_tokens * 10:
    snowball_stemmer.stem(word)
snowball_time = time.time() - start_time

print(f"PorterStemmer processing time (10 repetitions): {porter_time:.6f} seconds")
print(f"SnowballStemmer processing time (10 repetitions): {snowball_time:.6f} seconds")
if porter_time > snowball_time:
    print(f"SnowballStemmer is {porter_time/snowball_time:.2f}x faster than PorterStemmer")
else:
    print(f"PorterStemmer is {snowball_time/porter_time:.2f}x faster than SnowballStemmer")
# Out:
# COMPLETE COMPARISON (Original vs Porter vs Snowball):
# #     | Original Word             | Porter Stemmer       | Snowball Stemmer     | Difference
# 1     | steven                    | steven               | steven               | SAME
# 2     | paul                      | paul                 | paul                 | SAME
# 3     | jobs                      | job                  | job                  | SAME
# 4     | february                  | februari             | februari             | SAME
# 5     | october                   | octob                | octob                | SAME
# 6     | american                  | american             | american             | SAME
# 7     | business                  | busi                 | busi                 | SAME
# 8     | magnate                   | magnat               | magnat               | SAME
# 9     | inventor                  | inventor             | inventor             | SAME
# 10    | investor                  | investor             | investor             | SAME
# 11    | cofounder                 | cofound              | cofound              | SAME
# 12    | chairman                  | chairman             | chairman             | SAME
# 13    | ceo                       | ceo                  | ceo                  | SAME
# 14    | apple                     | appl                 | appl                 | SAME
# 15    | chairman                  | chairman             | chairman             | SAME
# 16    | majority                  | major                | major                | SAME
# 17    | shareholder               | sharehold            | sharehold            | SAME
# 18    | pixar                     | pixar                | pixar                | SAME
# 19    | member                    | member               | member               | SAME
# 20    | walt                      | walt                 | walt                 | SAME
# 21    | disney                    | disney               | disney               | SAME
# 22    | companys                  | compani              | compani              | SAME
# 23    | board                     | board                | board                | SAME
# 24    | directors                 | director             | director             | SAME
# 25    | following                 | follow               | follow               | SAME
# 26    | acquisition               | acquisit             | acquisit             | SAME
# 27    | pixar                     | pixar                | pixar                | SAME
# 28    | founder                   | founder              | founder              | SAME
# 29    | chairman                  | chairman             | chairman             | SAME
# 30    | ceo                       | ceo                  | ceo                  | SAME
# 31    | next                      | next                 | next                 | SAME
# 32    | pioneer                   | pioneer              | pioneer              | SAME
# 33    | personal                  | person               | person               | SAME
# 34    | computer                  | comput               | comput               | SAME
# 35    | revolution                | revolut              | revolut              | SAME
# 36    | along                     | along                | along                | SAME
# 37    | early                     | earli                | earli                | SAME
# 38    | business                  | busi                 | busi                 | SAME
# 39    | partner                   | partner              | partner              | SAME
# 40    | fellow                    | fellow               | fellow               | SAME
# 41    | apple                     | appl                 | appl                 | SAME
# 42    | cofounder                 | cofound              | cofound              | SAME
# 43    | steve                     | steve                | steve                | SAME
# 44    | wozniak                   | wozniak              | wozniak              | SAME
# 45    | jobs                      | job                  | job                  | SAME
# 46    | born                      | born                 | born                 | SAME
# 47    | san                       | san                  | san                  | SAME
# 48    | francisco                 | francisco            | francisco            | SAME
# 49    | syrian                    | syrian               | syrian               | SAME
# 50    | father                    | father               | father               | SAME
# 51    | germanamerican            | germanamerican       | germanamerican       | SAME
# 52    | mother                    | mother               | mother               | SAME
# 53    | adopted                   | adopt                | adopt                | SAME
# 54    | shortly                   | shortli              | short                | DIFFERENT
# 55    | birth                     | birth                | birth                | SAME
# 56    | jobs                      | job                  | job                  | SAME
# 57    | attended                  | attend               | attend               | SAME
# 58    | reed                      | reed                 | reed                 | SAME
# 59    | college                   | colleg               | colleg               | SAME
# 60    | withdrawing               | withdraw             | withdraw             | SAME
# 61    | year                      | year                 | year                 | SAME
# 62    | traveled                  | travel               | travel               | SAME
# 63    | india                     | india                | india                | SAME
# 64    | seeking                   | seek                 | seek                 | SAME
# 65    | enlightenment             | enlighten            | enlighten            | SAME
# 66    | later                     | later                | later                | SAME
# 67    | studying                  | studi                | studi                | SAME
# 68    | zen                       | zen                  | zen                  | SAME
# 69    | buddhism                  | buddhism             | buddhism             | SAME
# 70    | wozniak                   | wozniak              | wozniak              | SAME
# 71    | cofounded                 | cofound              | cofound              | SAME
# 72    | apple                     | appl                 | appl                 | SAME
# 73    | sell                      | sell                 | sell                 | SAME
# 74    | wozniaks                  | wozniak              | wozniak              | SAME
# 75    | apple                     | appl                 | appl                 | SAME
# 76    | personal                  | person               | person               | SAME
# 77    | computer                  | comput               | comput               | SAME
# 78    | together                  | togeth               | togeth               | SAME
# 79    | duo                       | duo                  | duo                  | SAME
# 80    | gained                    | gain                 | gain                 | SAME
# 81    | fame                      | fame                 | fame                 | SAME
# 82    | wealth                    | wealth               | wealth               | SAME
# 83    | year                      | year                 | year                 | SAME
# 84    | later                     | later                | later                | SAME
# 85    | production                | product              | product              | SAME
# 86    | sale                      | sale                 | sale                 | SAME
# 87    | apple                     | appl                 | appl                 | SAME
# 88    | ii                        | ii                   | ii                   | SAME
# 89    | one                       | one                  | one                  | SAME
# 90    | first                     | first                | first                | SAME
# 91    | highly                    | highli               | high                 | DIFFERENT
# 92    | successful                | success              | success              | SAME
# 93    | massproduced              | massproduc           | massproduc           | SAME
# 94    | microcomputers            | microcomput          | microcomput          | SAME
# 95    | jobs                      | job                  | job                  | SAME
# 96    | saw                       | saw                  | saw                  | SAME
# 97    | commercial                | commerci             | commerci             | SAME
# 98    | potential                 | potenti              | potenti              | SAME
# 99    | xerox                     | xerox                | xerox                | SAME
# 100   | alto                      | alto                 | alto                 | SAME
# 101   | mousedriven               | mousedriven          | mousedriven          | SAME
# 102   | graphical                 | graphic              | graphic              | SAME
# 103   | user                      | user                 | user                 | SAME
# 104   | interface                 | interfac             | interfac             | SAME
# 105   | gui                       | gui                  | gui                  | SAME
# 106   | led                       | led                  | led                  | SAME
# 107   | development               | develop              | develop              | SAME
# 108   | unsuccessful              | unsuccess            | unsuccess            | SAME
# 109   | apple                     | appl                 | appl                 | SAME
# 110   | lisa                      | lisa                 | lisa                 | SAME
# 111   | followed                  | follow               | follow               | SAME
# 112   | breakthrough              | breakthrough         | breakthrough         | SAME
# 113   | macintosh                 | macintosh            | macintosh            | SAME
# 114   | first                     | first                | first                | SAME
# 115   | massproduced              | massproduc           | massproduc           | SAME
# 116   | computer                  | comput               | comput               | SAME
# 117   | gui                       | gui                  | gui                  | SAME
# 118   | macintosh                 | macintosh            | macintosh            | SAME
# 119   | introduced                | introduc             | introduc             | SAME
# 120   | desktop                   | desktop              | desktop              | SAME
# 121   | publishing                | publish              | publish              | SAME
# 122   | industry                  | industri             | industri             | SAME
# 123   | addition                  | addit                | addit                | SAME
# 124   | apple                     | appl                 | appl                 | SAME
# 125   | laserwriter               | laserwrit            | laserwrit            | SAME
# 126   | first                     | first                | first                | SAME
# 127   | laser                     | laser                | laser                | SAME
# 128   | printer                   | printer              | printer              | SAME
# 129   | feature                   | featur               | featur               | SAME
# 130   | vector                    | vector               | vector               | SAME
# 131   | graphics                  | graphic              | graphic              | SAME
# 132   | jobs                      | job                  | job                  | SAME
# 133   | forced                    | forc                 | forc                 | SAME
# 134   | apple                     | appl                 | appl                 | SAME
# 135   | long                      | long                 | long                 | SAME
# 136   | power                     | power                | power                | SAME
# 137   | struggle                  | struggl              | struggl              | SAME
# 138   | companys                  | compani              | compani              | SAME
# 139   | board                     | board                | board                | SAME
# 140   | thenceo                   | thenceo              | thenceo              | SAME
# 141   | john                      | john                 | john                 | SAME
# 142   | sculley                   | sculley              | sculley              | SAME
# 143   | year                      | year                 | year                 | SAME
# 144   | jobs                      | job                  | job                  | SAME
# 145   | took                      | took                 | took                 | SAME
# 146   | apple                     | appl                 | appl                 | SAME
# 147   | employees                 | employe              | employe              | SAME
# 148   | found                     | found                | found                | SAME
# 149   | next                      | next                 | next                 | SAME
# 150   | computer                  | comput               | comput               | SAME
# 151   | platform                  | platform             | platform             | SAME
# 152   | development               | develop              | develop              | SAME
# 153   | company                   | compani              | compani              | SAME
# 154   | specialized               | special              | special              | SAME
# 155   | computers                 | comput               | comput               | SAME
# 156   | highereducation           | highereduc           | highereduc           | SAME
# 157   | business                  | busi                 | busi                 | SAME
# 158   | markets                   | market               | market               | SAME
# 159   | addition                  | addit                | addit                | SAME
# 160   | helped                    | help                 | help                 | SAME
# 161   | develop                   | develop              | develop              | SAME
# 162   | visual                    | visual               | visual               | SAME
# 163   | effects                   | effect               | effect               | SAME
# 164   | industry                  | industri             | industri             | SAME
# 165   | funded                    | fund                 | fund                 | SAME
# 166   | computer                  | comput               | comput               | SAME
# 167   | graphics                  | graphic              | graphic              | SAME
# 168   | division                  | divis                | divis                | SAME
# 169   | george                    | georg                | georg                | SAME
# 170   | lucass                    | lucass               | lucass               | SAME
# 171   | lucasfilm                 | lucasfilm            | lucasfilm            | SAME
# 172   | new                       | new                  | new                  | SAME
# 173   | company                   | compani              | compani              | SAME
# 174   | pixar                     | pixar                | pixar                | SAME
# 175   | produced                  | produc               | produc               | SAME
# 176   | first                     | first                | first                | SAME
# 177   | computeranimated          | computeranim         | computeranim         | SAME
# 178   | feature                   | featur               | featur               | SAME
# 179   | film                      | film                 | film                 | SAME
# 180   | toy                       | toy                  | toy                  | SAME
# 181   | story                     | stori                | stori                | SAME
# 182   | went                      | went                 | went                 | SAME
# 183   | become                    | becom                | becom                | SAME
# 184   | major                     | major                | major                | SAME
# 185   | animation                 | anim                 | anim                 | SAME
# 186   | studio                    | studio               | studio               | SAME
# 187   | producing                 | produc               | produc               | SAME
# 188   | films                     | film                 | film                 | SAME
# 189   | since                     | sinc                 | sinc                 | SAME
# 190   | jobs                      | job                  | job                  | SAME
# 191   | returned                  | return               | return               | SAME
# 192   | apple                     | appl                 | appl                 | SAME
# 193   | ceo                       | ceo                  | ceo                  | SAME
# 194   | companys                  | compani              | compani              | SAME
# 195   | acquisition               | acquisit             | acquisit             | SAME
# 196   | next                      | next                 | next                 | SAME
# 197   | largely                   | larg                 | larg                 | SAME
# 198   | responsible               | respons              | respons              | SAME
# 199   | reviving                  | reviv                | reviv                | SAME
# 200   | apple                     | appl                 | appl                 | SAME
# 201   | verge                     | verg                 | verg                 | SAME
# 202   | bankruptcy                | bankruptci           | bankruptci           | SAME
# 203   | worked                    | work                 | work                 | SAME
# 204   | closely                   | close                | close                | SAME
# 205   | british                   | british              | british              | SAME
# 206   | designer                  | design               | design               | SAME
# 207   | jony                      | joni                 | joni                 | SAME
# 208   | ive                       | ive                  | ive                  | SAME
# 209   | develop                   | develop              | develop              | SAME
# 210   | line                      | line                 | line                 | SAME
# 211   | products                  | product              | product              | SAME
# 212   | larger                    | larger               | larger               | SAME
# 213   | cultural                  | cultur               | cultur               | SAME
# 214   | ramifications             | ramif                | ramif                | SAME
# 215   | beginning                 | begin                | begin                | SAME
# 216   | think                     | think                | think                | SAME
# 217   | different                 | differ               | differ               | SAME
# 218   | advertising               | advertis             | advertis             | SAME
# 219   | campaign                  | campaign             | campaign             | SAME
# 220   | leading                   | lead                 | lead                 | SAME
# 221   | apple                     | appl                 | appl                 | SAME
# 222   | store                     | store                | store                | SAME
# 223   | app                       | app                  | app                  | SAME
# 224   | store                     | store                | store                | SAME
# 225   | ios                       | io                   | io                   | SAME
# 226   | imac                      | imac                 | imac                 | SAME
# 227   | ipad                      | ipad                 | ipad                 | SAME
# 228   | ipod                      | ipod                 | ipod                 | SAME
# 229   | iphone                    | iphon                | iphon                | SAME
# 230   | itunes                    | itun                 | itun                 | SAME
# 231   | itunes                    | itun                 | itun                 | SAME
# 232   | store                     | store                | store                | SAME
# 233   | original                  | origin               | origin               | SAME
# 234   | mac                       | mac                  | mac                  | SAME
# 235   | os                        | os                   | os                   | SAME
# 236   | replaced                  | replac               | replac               | SAME
# 237   | completely                | complet              | complet              | SAME
# 238   | new                       | new                  | new                  | SAME
# 239   | mac                       | mac                  | mac                  | SAME
# 240   | os                        | os                   | os                   | SAME
# 241   | x                         | x                    | x                    | SAME
# 242   | later                     | later                | later                | SAME
# 243   | known                     | known                | known                | SAME
# 244   | macos                     | maco                 | maco                 | SAME
# 245   | based                     | base                 | base                 | SAME
# 246   | nexts                     | next                 | next                 | SAME
# 247   | nextstep                  | nextstep             | nextstep             | SAME
# 248   | platform                  | platform             | platform             | SAME
# 249   | giving                    | give                 | give                 | SAME
# 250   | operating                 | oper                 | oper                 | SAME
# 251   | system                    | system               | system               | SAME
# 252   | modern                    | modern               | modern               | SAME
# 253   | unixbased                 | unixbas              | unixbas              | SAME
# 254   | foundation                | foundat              | foundat              | SAME
# 255   | first                     | first                | first                | SAME
# 256   | time                      | time                 | time                 | SAME
# 257   | jobs                      | job                  | job                  | SAME
# 258   | diagnosed                 | diagnos              | diagnos              | SAME
# 259   | pancreatic                | pancreat             | pancreat             | SAME
# 260   | neuroendocrine            | neuroendocrin        | neuroendocrin        | SAME
# 261   | tumor                     | tumor                | tumor                | SAME
# 262   | died                      | die                  | die                  | SAME
# 263   | respiratory               | respiratori          | respiratori          | SAME
# 264   | arrest                    | arrest               | arrest               | SAME
# 265   | related                   | relat                | relat                | SAME
# 266   | tumor                     | tumor                | tumor                | SAME
# 267   | age                       | age                  | age                  | SAME
# 268   | tim                       | tim                  | tim                  | SAME
# 269   | cook                      | cook                 | cook                 | SAME
# 270   | succeeding                | succeed              | succeed              | SAME
# 271   | ceo                       | ceo                  | ceo                  | SAME
# 272   | apple                     | appl                 | appl                 | SAME
# 273   | posthumously              | posthum              | posthum              | SAME
# 274   | awarded                   | award                | award                | SAME
# 275   | presidential              | presidenti           | presidenti           | SAME
# 276   | medal                     | medal                | medal                | SAME
# 277   | freedom                   | freedom              | freedom              | SAME
#
# Total words with different stemming results: 2 out of 277
# Percentage of differences: 0.72%
#
# DETAILED COMPARISON FOR WORDS WITH DIFFERENT STEMMING RESULTS:
# #     | Original Word             | Porter Result        | Snowball Result      | Analysis
# 1     | shortly                   | shortli              | short                | Snowball shorter
# 2     | highly                    | highli               | high                 | Snowball shorter
#
# COMPLETE PORTER STEMMED TEXT:
# steven paul job februari octob american busi magnat inventor investor cofound chairman ceo appl chairman major sharehold pixar member walt disney compani board director follow acquisit pixar founder chairman ceo next pioneer person comput revolut along earli busi partner fellow appl cofound steve wozniak job born san francisco syrian father germanamerican mother adopt shortli birth job attend reed colleg withdraw year travel india seek enlighten later studi zen buddhism wozniak cofound appl sell wozniak appl person comput togeth duo gain fame wealth year later product sale appl ii one first highli success massproduc microcomput job saw commerci potenti xerox alto mousedriven graphic user interfac gui led develop unsuccess appl lisa follow breakthrough macintosh first massproduc comput gui macintosh introduc desktop publish industri addit appl laserwrit first laser printer featur vector graphic job forc appl long power struggl compani board thenceo john sculley year job took appl employe found next comput platform develop compani special comput highereduc busi market addit help develop visual effect industri fund comput graphic divis georg lucass lucasfilm new compani pixar produc first computeranim featur film toy stori went becom major anim studio produc film sinc job return appl ceo compani acquisit next larg respons reviv appl verg bankruptci work close british design joni ive develop line product larger cultur ramif begin think differ advertis campaign lead appl store app store io imac ipad ipod iphon itun itun store origin mac os replac complet new mac os x later known maco base next nextstep platform give oper system modern unixbas foundat first time job diagnos pancreat neuroendocrin tumor die respiratori arrest relat tumor age tim cook succeed ceo appl posthum award presidenti medal freedom
#
# COMPLETE SNOWBALL STEMMED TEXT:
# steven paul job februari octob american busi magnat inventor investor cofound chairman ceo appl chairman major sharehold pixar member walt disney compani board director follow acquisit pixar founder chairman ceo next pioneer person comput revolut along earli busi partner fellow appl cofound steve wozniak job born san francisco syrian father germanamerican mother adopt short birth job attend reed colleg withdraw year travel india seek enlighten later studi zen buddhism wozniak cofound appl sell wozniak appl person comput togeth duo gain fame wealth year later product sale appl ii one first high success massproduc microcomput job saw commerci potenti xerox alto mousedriven graphic user interfac gui led develop unsuccess appl lisa follow breakthrough macintosh first massproduc comput gui macintosh introduc desktop publish industri addit appl laserwrit first laser printer featur vector graphic job forc appl long power struggl compani board thenceo john sculley year job took appl employe found next comput platform develop compani special comput highereduc busi market addit help develop visual effect industri fund comput graphic divis georg lucass lucasfilm new compani pixar produc first computeranim featur film toy stori went becom major anim studio produc film sinc job return appl ceo compani acquisit next larg respons reviv appl verg bankruptci work close british design joni ive develop line product larger cultur ramif begin think differ advertis campaign lead appl store app store io imac ipad ipod iphon itun itun store origin mac os replac complet new mac os x later known maco base next nextstep platform give oper system modern unixbas foundat first time job diagnos pancreat neuroendocrin tumor die respiratori arrest relat tumor age tim cook succeed ceo appl posthum award presidenti medal freedom
#
# PERFORMANCE COMPARISON:
# PorterStemmer processing time (10 repetitions): 0.032572 seconds
# SnowballStemmer processing time (10 repetitions): 0.015790 seconds
# SnowballStemmer is 2.06x faster than PorterStemmer

# %% [markdown]
# # 7. Lemmatization (WordNetLemmatizer)

# %%
lemmatizer = WordNetLemmatizer()
lemmatized_tokens = [lemmatizer.lemmatize(word) for word in filtered_tokens]

print("COMPLETE COMPARISON (Original vs Lemmatized):")
print(f"{'#':<5} | {'Original Word':<25} | {'Lemmatized':<25}")
for i, (original, lemmatized) in enumerate(zip(filtered_tokens, lemmatized_tokens), 1):
    print(f"{i:<5} | {original:<25} | {lemmatized:<25}")

lemmatized_text = ' '.join(lemmatized_tokens)
print("\nCOMPLETE LEMMATIZED TEXT:")
print(lemmatized_text)

print("\nSTEMMING vs LEMMATIZATION COMPARISON:")
print(f"{'#':<5} | {'Original Word':<25} | {'Porter Stemmer':<20} | {'Snowball Stemmer':<20} | {'Lemmatized':<25}")
for i, (original, porter, snowball, lemmatized) in enumerate(zip(filtered_tokens, porter_stemmed_tokens, snowball_stemmed_tokens, lemmatized_tokens), 1):
    print(f"{i:<5} | {original:<25} | {porter:<20} | {snowball:<20} | {lemmatized:<25}")

# Performance comparison for Lemmatizer
print("\nPERFORMANCE COMPARISON (Lemmatizer vs Stemmers):")

# Test Lemmatizer speed
start_time = time.time()
for word in filtered_tokens * 10:
    lemmatizer.lemmatize(word)
lemmatizer_time = time.time() - start_time

print(f"WordNetLemmatizer processing time (10 repetitions): {lemmatizer_time:.6f} seconds")
print(f"PorterStemmer processing time (10 repetitions): {porter_time:.6f} seconds")
print(f"SnowballStemmer processing time (10 repetitions): {snowball_time:.6f} seconds")

# Find fastest
fastest_time = min(porter_time, snowball_time, lemmatizer_time)
if porter_time == fastest_time:
    fastest = "PorterStemmer"
    print(f"\nFastest: {fastest} is {snowball_time/fastest_time:.2f}x faster than Snowball and {lemmatizer_time/fastest_time:.2f}x faster than Lemmatizer")
elif snowball_time == fastest_time:
    fastest = "SnowballStemmer"
    print(f"\nFastest: {fastest} is {porter_time/fastest_time:.2f}x faster than Porter and {lemmatizer_time/fastest_time:.2f}x faster than Lemmatizer")
else:
    fastest = "WordNetLemmatizer"
    print(f"\nFastest: {fastest} is {porter_time/fastest_time:.2f}x faster than Porter and {snowball_time/fastest_time:.2f}x faster than Snowball")
# Out:
# COMPLETE COMPARISON (Original vs Lemmatized):
# #     | Original Word             | Lemmatized
# 1     | steven                    | steven
# 2     | paul                      | paul
# 3     | jobs                      | job
# 4     | february                  | february
# 5     | october                   | october
# 6     | american                  | american
# 7     | business                  | business
# 8     | magnate                   | magnate
# 9     | inventor                  | inventor
# 10    | investor                  | investor
# 11    | cofounder                 | cofounder
# 12    | chairman                  | chairman
# 13    | ceo                       | ceo
# 14    | apple                     | apple
# 15    | chairman                  | chairman
# 16    | majority                  | majority
# 17    | shareholder               | shareholder
# 18    | pixar                     | pixar
# 19    | member                    | member
# 20    | walt                      | walt
# 21    | disney                    | disney
# 22    | companys                  | company
# 23    | board                     | board
# 24    | directors                 | director
# 25    | following                 | following
# 26    | acquisition               | acquisition
# 27    | pixar                     | pixar
# 28    | founder                   | founder
# 29    | chairman                  | chairman
# 30    | ceo                       | ceo
# 31    | next                      | next
# 32    | pioneer                   | pioneer
# 33    | personal                  | personal
# 34    | computer                  | computer
# 35    | revolution                | revolution
# 36    | along                     | along
# 37    | early                     | early
# 38    | business                  | business
# 39    | partner                   | partner
# 40    | fellow                    | fellow
# 41    | apple                     | apple
# 42    | cofounder                 | cofounder
# 43    | steve                     | steve
# 44    | wozniak                   | wozniak
# 45    | jobs                      | job
# 46    | born                      | born
# 47    | san                       | san
# 48    | francisco                 | francisco
# 49    | syrian                    | syrian
# 50    | father                    | father
# 51    | germanamerican            | germanamerican
# 52    | mother                    | mother
# 53    | adopted                   | adopted
# 54    | shortly                   | shortly
# 55    | birth                     | birth
# 56    | jobs                      | job
# 57    | attended                  | attended
# 58    | reed                      | reed
# 59    | college                   | college
# 60    | withdrawing               | withdrawing
# 61    | year                      | year
# 62    | traveled                  | traveled
# 63    | india                     | india
# 64    | seeking                   | seeking
# 65    | enlightenment             | enlightenment
# 66    | later                     | later
# 67    | studying                  | studying
# 68    | zen                       | zen
# 69    | buddhism                  | buddhism
# 70    | wozniak                   | wozniak
# 71    | cofounded                 | cofounded
# 72    | apple                     | apple
# 73    | sell                      | sell
# 74    | wozniaks                  | wozniaks
# 75    | apple                     | apple
# 76    | personal                  | personal
# 77    | computer                  | computer
# 78    | together                  | together
# 79    | duo                       | duo
# 80    | gained                    | gained
# 81    | fame                      | fame
# 82    | wealth                    | wealth
# 83    | year                      | year
# 84    | later                     | later
# 85    | production                | production
# 86    | sale                      | sale
# 87    | apple                     | apple
# 88    | ii                        | ii
# 89    | one                       | one
# 90    | first                     | first
# 91    | highly                    | highly
# 92    | successful                | successful
# 93    | massproduced              | massproduced
# 94    | microcomputers            | microcomputer
# 95    | jobs                      | job
# 96    | saw                       | saw
# 97    | commercial                | commercial
# 98    | potential                 | potential
# 99    | xerox                     | xerox
# 100   | alto                      | alto
# 101   | mousedriven               | mousedriven
# 102   | graphical                 | graphical
# 103   | user                      | user
# 104   | interface                 | interface
# 105   | gui                       | gui
# 106   | led                       | led
# 107   | development               | development
# 108   | unsuccessful              | unsuccessful
# 109   | apple                     | apple
# 110   | lisa                      | lisa
# 111   | followed                  | followed
# 112   | breakthrough              | breakthrough
# 113   | macintosh                 | macintosh
# 114   | first                     | first
# 115   | massproduced              | massproduced
# 116   | computer                  | computer
# 117   | gui                       | gui
# 118   | macintosh                 | macintosh
# 119   | introduced                | introduced
# 120   | desktop                   | desktop
# 121   | publishing                | publishing
# 122   | industry                  | industry
# 123   | addition                  | addition
# 124   | apple                     | apple
# 125   | laserwriter               | laserwriter
# 126   | first                     | first
# 127   | laser                     | laser
# 128   | printer                   | printer
# 129   | feature                   | feature
# 130   | vector                    | vector
# 131   | graphics                  | graphic
# 132   | jobs                      | job
# 133   | forced                    | forced
# 134   | apple                     | apple
# 135   | long                      | long
# 136   | power                     | power
# 137   | struggle                  | struggle
# 138   | companys                  | company
# 139   | board                     | board
# 140   | thenceo                   | thenceo
# 141   | john                      | john
# 142   | sculley                   | sculley
# 143   | year                      | year
# 144   | jobs                      | job
# 145   | took                      | took
# 146   | apple                     | apple
# 147   | employees                 | employee
# 148   | found                     | found
# 149   | next                      | next
# 150   | computer                  | computer
# 151   | platform                  | platform
# 152   | development               | development
# 153   | company                   | company
# 154   | specialized               | specialized
# 155   | computers                 | computer
# 156   | highereducation           | highereducation
# 157   | business                  | business
# 158   | markets                   | market
# 159   | addition                  | addition
# 160   | helped                    | helped
# 161   | develop                   | develop
# 162   | visual                    | visual
# 163   | effects                   | effect
# 164   | industry                  | industry
# 165   | funded                    | funded
# 166   | computer                  | computer
# 167   | graphics                  | graphic
# 168   | division                  | division
# 169   | george                    | george
# 170   | lucass                    | lucas
# 171   | lucasfilm                 | lucasfilm
# 172   | new                       | new
# 173   | company                   | company
# 174   | pixar                     | pixar
# 175   | produced                  | produced
# 176   | first                     | first
# 177   | computeranimated          | computeranimated
# 178   | feature                   | feature
# 179   | film                      | film
# 180   | toy                       | toy
# 181   | story                     | story
# 182   | went                      | went
# 183   | become                    | become
# 184   | major                     | major
# 185   | animation                 | animation
# 186   | studio                    | studio
# 187   | producing                 | producing
# 188   | films                     | film
# 189   | since                     | since
# 190   | jobs                      | job
# 191   | returned                  | returned
# 192   | apple                     | apple
# 193   | ceo                       | ceo
# 194   | companys                  | company
# 195   | acquisition               | acquisition
# 196   | next                      | next
# 197   | largely                   | largely
# 198   | responsible               | responsible
# 199   | reviving                  | reviving
# 200   | apple                     | apple
# 201   | verge                     | verge
# 202   | bankruptcy                | bankruptcy
# 203   | worked                    | worked
# 204   | closely                   | closely
# 205   | british                   | british
# 206   | designer                  | designer
# 207   | jony                      | jony
# 208   | ive                       | ive
# 209   | develop                   | develop
# 210   | line                      | line
# 211   | products                  | product
# 212   | larger                    | larger
# 213   | cultural                  | cultural
# 214   | ramifications             | ramification
# 215   | beginning                 | beginning
# 216   | think                     | think
# 217   | different                 | different
# 218   | advertising               | advertising
# 219   | campaign                  | campaign
# 220   | leading                   | leading
# 221   | apple                     | apple
# 222   | store                     | store
# 223   | app                       | app
# 224   | store                     | store
# 225   | ios                       | io
# 226   | imac                      | imac
# 227   | ipad                      | ipad
# 228   | ipod                      | ipod
# 229   | iphone                    | iphone
# 230   | itunes                    | itunes
# 231   | itunes                    | itunes
# 232   | store                     | store
# 233   | original                  | original
# 234   | mac                       | mac
# 235   | os                        | o
# 236   | replaced                  | replaced
# 237   | completely                | completely
# 238   | new                       | new
# 239   | mac                       | mac
# 240   | os                        | o
# 241   | x                         | x
# 242   | later                     | later
# 243   | known                     | known
# 244   | macos                     | macos
# 245   | based                     | based
# 246   | nexts                     | nexts
# 247   | nextstep                  | nextstep
# 248   | platform                  | platform
# 249   | giving                    | giving
# 250   | operating                 | operating
# 251   | system                    | system
# 252   | modern                    | modern
# 253   | unixbased                 | unixbased
# 254   | foundation                | foundation
# 255   | first                     | first
# 256   | time                      | time
# 257   | jobs                      | job
# 258   | diagnosed                 | diagnosed
# 259   | pancreatic                | pancreatic
# 260   | neuroendocrine            | neuroendocrine
# 261   | tumor                     | tumor
# 262   | died                      | died
# 263   | respiratory               | respiratory
# 264   | arrest                    | arrest
# 265   | related                   | related
# 266   | tumor                     | tumor
# 267   | age                       | age
# 268   | tim                       | tim
# 269   | cook                      | cook
# 270   | succeeding                | succeeding
# 271   | ceo                       | ceo
# 272   | apple                     | apple
# 273   | posthumously              | posthumously
# 274   | awarded                   | awarded
# 275   | presidential              | presidential
# 276   | medal                     | medal
# 277   | freedom                   | freedom
#
# COMPLETE LEMMATIZED TEXT:
# steven paul job february october american business magnate inventor investor cofounder chairman ceo apple chairman majority shareholder pixar member walt disney company board director following acquisition pixar founder chairman ceo next pioneer personal computer revolution along early business partner fellow apple cofounder steve wozniak job born san francisco syrian father germanamerican mother adopted shortly birth job attended reed college withdrawing year traveled india seeking enlightenment later studying zen buddhism wozniak cofounded apple sell wozniaks apple personal computer together duo gained fame wealth year later production sale apple ii one first highly successful massproduced microcomputer job saw commercial potential xerox alto mousedriven graphical user interface gui led development unsuccessful apple lisa followed breakthrough macintosh first massproduced computer gui macintosh introduced desktop publishing industry addition apple laserwriter first laser printer feature vector graphic job forced apple long power struggle company board thenceo john sculley year job took apple employee found next computer platform development company specialized computer highereducation business market addition helped develop visual effect industry funded computer graphic division george lucas lucasfilm new company pixar produced first computeranimated feature film toy story went become major animation studio producing film since job returned apple ceo company acquisition next largely responsible reviving apple verge bankruptcy worked closely british designer jony ive develop line product larger cultural ramification beginning think different advertising campaign leading apple store app store io imac ipad ipod iphone itunes itunes store original mac o replaced completely new mac o x later known macos based nexts nextstep platform giving operating system modern unixbased foundation first time job diagnosed pancreatic neuroendocrine tumor died respiratory arrest related tumor age tim cook succeeding ceo apple posthumously awarded presidential medal freedom
#
# STEMMING vs LEMMATIZATION COMPARISON:
# #     | Original Word             | Porter Stemmer       | Snowball Stemmer     | Lemmatized
# 1     | steven                    | steven               | steven               | steven
# 2     | paul                      | paul                 | paul                 | paul
# 3     | jobs                      | job                  | job                  | job
# 4     | february                  | februari             | februari             | february
# 5     | october                   | octob                | octob                | october
# 6     | american                  | american             | american             | american
# 7     | business                  | busi                 | busi                 | business
# 8     | magnate                   | magnat               | magnat               | magnate
# 9     | inventor                  | inventor             | inventor             | inventor
# 10    | investor                  | investor             | investor             | investor
# 11    | cofounder                 | cofound              | cofound              | cofounder
# 12    | chairman                  | chairman             | chairman             | chairman
# 13    | ceo                       | ceo                  | ceo                  | ceo
# 14    | apple                     | appl                 | appl                 | apple
# 15    | chairman                  | chairman             | chairman             | chairman
# 16    | majority                  | major                | major                | majority
# 17    | shareholder               | sharehold            | sharehold            | shareholder
# 18    | pixar                     | pixar                | pixar                | pixar
# 19    | member                    | member               | member               | member
# 20    | walt                      | walt                 | walt                 | walt
# 21    | disney                    | disney               | disney               | disney
# 22    | companys                  | compani              | compani              | company
# 23    | board                     | board                | board                | board
# 24    | directors                 | director             | director             | director
# 25    | following                 | follow               | follow               | following
# 26    | acquisition               | acquisit             | acquisit             | acquisition
# 27    | pixar                     | pixar                | pixar                | pixar
# 28    | founder                   | founder              | founder              | founder
# 29    | chairman                  | chairman             | chairman             | chairman
# 30    | ceo                       | ceo                  | ceo                  | ceo
# 31    | next                      | next                 | next                 | next
# 32    | pioneer                   | pioneer              | pioneer              | pioneer
# 33    | personal                  | person               | person               | personal
# 34    | computer                  | comput               | comput               | computer
# 35    | revolution                | revolut              | revolut              | revolution
# 36    | along                     | along                | along                | along
# 37    | early                     | earli                | earli                | early
# 38    | business                  | busi                 | busi                 | business
# 39    | partner                   | partner              | partner              | partner
# 40    | fellow                    | fellow               | fellow               | fellow
# 41    | apple                     | appl                 | appl                 | apple
# 42    | cofounder                 | cofound              | cofound              | cofounder
# 43    | steve                     | steve                | steve                | steve
# 44    | wozniak                   | wozniak              | wozniak              | wozniak
# 45    | jobs                      | job                  | job                  | job
# 46    | born                      | born                 | born                 | born
# 47    | san                       | san                  | san                  | san
# 48    | francisco                 | francisco            | francisco            | francisco
# 49    | syrian                    | syrian               | syrian               | syrian
# 50    | father                    | father               | father               | father
# 51    | germanamerican            | germanamerican       | germanamerican       | germanamerican
# 52    | mother                    | mother               | mother               | mother
# 53    | adopted                   | adopt                | adopt                | adopted
# 54    | shortly                   | shortli              | short                | shortly
# 55    | birth                     | birth                | birth                | birth
# 56    | jobs                      | job                  | job                  | job
# 57    | attended                  | attend               | attend               | attended
# 58    | reed                      | reed                 | reed                 | reed
# 59    | college                   | colleg               | colleg               | college
# 60    | withdrawing               | withdraw             | withdraw             | withdrawing
# 61    | year                      | year                 | year                 | year
# 62    | traveled                  | travel               | travel               | traveled
# 63    | india                     | india                | india                | india
# 64    | seeking                   | seek                 | seek                 | seeking
# 65    | enlightenment             | enlighten            | enlighten            | enlightenment
# 66    | later                     | later                | later                | later
# 67    | studying                  | studi                | studi                | studying
# 68    | zen                       | zen                  | zen                  | zen
# 69    | buddhism                  | buddhism             | buddhism             | buddhism
# 70    | wozniak                   | wozniak              | wozniak              | wozniak
# 71    | cofounded                 | cofound              | cofound              | cofounded
# 72    | apple                     | appl                 | appl                 | apple
# 73    | sell                      | sell                 | sell                 | sell
# 74    | wozniaks                  | wozniak              | wozniak              | wozniaks
# 75    | apple                     | appl                 | appl                 | apple
# 76    | personal                  | person               | person               | personal
# 77    | computer                  | comput               | comput               | computer
# 78    | together                  | togeth               | togeth               | together
# 79    | duo                       | duo                  | duo                  | duo
# 80    | gained                    | gain                 | gain                 | gained
# 81    | fame                      | fame                 | fame                 | fame
# 82    | wealth                    | wealth               | wealth               | wealth
# 83    | year                      | year                 | year                 | year
# 84    | later                     | later                | later                | later
# 85    | production                | product              | product              | production
# 86    | sale                      | sale                 | sale                 | sale
# 87    | apple                     | appl                 | appl                 | apple
# 88    | ii                        | ii                   | ii                   | ii
# 89    | one                       | one                  | one                  | one
# 90    | first                     | first                | first                | first
# 91    | highly                    | highli               | high                 | highly
# 92    | successful                | success              | success              | successful
# 93    | massproduced              | massproduc           | massproduc           | massproduced
# 94    | microcomputers            | microcomput          | microcomput          | microcomputer
# 95    | jobs                      | job                  | job                  | job
# 96    | saw                       | saw                  | saw                  | saw
# 97    | commercial                | commerci             | commerci             | commercial
# 98    | potential                 | potenti              | potenti              | potential
# 99    | xerox                     | xerox                | xerox                | xerox
# 100   | alto                      | alto                 | alto                 | alto
# 101   | mousedriven               | mousedriven          | mousedriven          | mousedriven
# 102   | graphical                 | graphic              | graphic              | graphical
# 103   | user                      | user                 | user                 | user
# 104   | interface                 | interfac             | interfac             | interface
# 105   | gui                       | gui                  | gui                  | gui
# 106   | led                       | led                  | led                  | led
# 107   | development               | develop              | develop              | development
# 108   | unsuccessful              | unsuccess            | unsuccess            | unsuccessful
# 109   | apple                     | appl                 | appl                 | apple
# 110   | lisa                      | lisa                 | lisa                 | lisa
# 111   | followed                  | follow               | follow               | followed
# 112   | breakthrough              | breakthrough         | breakthrough         | breakthrough
# 113   | macintosh                 | macintosh            | macintosh            | macintosh
# 114   | first                     | first                | first                | first
# 115   | massproduced              | massproduc           | massproduc           | massproduced
# 116   | computer                  | comput               | comput               | computer
# 117   | gui                       | gui                  | gui                  | gui
# 118   | macintosh                 | macintosh            | macintosh            | macintosh
# 119   | introduced                | introduc             | introduc             | introduced
# 120   | desktop                   | desktop              | desktop              | desktop
# 121   | publishing                | publish              | publish              | publishing
# 122   | industry                  | industri             | industri             | industry
# 123   | addition                  | addit                | addit                | addition
# 124   | apple                     | appl                 | appl                 | apple
# 125   | laserwriter               | laserwrit            | laserwrit            | laserwriter
# 126   | first                     | first                | first                | first
# 127   | laser                     | laser                | laser                | laser
# 128   | printer                   | printer              | printer              | printer
# 129   | feature                   | featur               | featur               | feature
# 130   | vector                    | vector               | vector               | vector
# 131   | graphics                  | graphic              | graphic              | graphic
# 132   | jobs                      | job                  | job                  | job
# 133   | forced                    | forc                 | forc                 | forced
# 134   | apple                     | appl                 | appl                 | apple
# 135   | long                      | long                 | long                 | long
# 136   | power                     | power                | power                | power
# 137   | struggle                  | struggl              | struggl              | struggle
# 138   | companys                  | compani              | compani              | company
# 139   | board                     | board                | board                | board
# 140   | thenceo                   | thenceo              | thenceo              | thenceo
# 141   | john                      | john                 | john                 | john
# 142   | sculley                   | sculley              | sculley              | sculley
# 143   | year                      | year                 | year                 | year
# 144   | jobs                      | job                  | job                  | job
# 145   | took                      | took                 | took                 | took
# 146   | apple                     | appl                 | appl                 | apple
# 147   | employees                 | employe              | employe              | employee
# 148   | found                     | found                | found                | found
# 149   | next                      | next                 | next                 | next
# 150   | computer                  | comput               | comput               | computer
# 151   | platform                  | platform             | platform             | platform
# 152   | development               | develop              | develop              | development
# 153   | company                   | compani              | compani              | company
# 154   | specialized               | special              | special              | specialized
# 155   | computers                 | comput               | comput               | computer
# 156   | highereducation           | highereduc           | highereduc           | highereducation
# 157   | business                  | busi                 | busi                 | business
# 158   | markets                   | market               | market               | market
# 159   | addition                  | addit                | addit                | addition
# 160   | helped                    | help                 | help                 | helped
# 161   | develop                   | develop              | develop              | develop
# 162   | visual                    | visual               | visual               | visual
# 163   | effects                   | effect               | effect               | effect
# 164   | industry                  | industri             | industri             | industry
# 165   | funded                    | fund                 | fund                 | funded
# 166   | computer                  | comput               | comput               | computer
# 167   | graphics                  | graphic              | graphic              | graphic
# 168   | division                  | divis                | divis                | division
# 169   | george                    | georg                | georg                | george
# 170   | lucass                    | lucass               | lucass               | lucas
# 171   | lucasfilm                 | lucasfilm            | lucasfilm            | lucasfilm
# 172   | new                       | new                  | new                  | new
# 173   | company                   | compani              | compani              | company
# 174   | pixar                     | pixar                | pixar                | pixar
# 175   | produced                  | produc               | produc               | produced
# 176   | first                     | first                | first                | first
# 177   | computeranimated          | computeranim         | computeranim         | computeranimated
# 178   | feature                   | featur               | featur               | feature
# 179   | film                      | film                 | film                 | film
# 180   | toy                       | toy                  | toy                  | toy
# 181   | story                     | stori                | stori                | story
# 182   | went                      | went                 | went                 | went
# 183   | become                    | becom                | becom                | become
# 184   | major                     | major                | major                | major
# 185   | animation                 | anim                 | anim                 | animation
# 186   | studio                    | studio               | studio               | studio
# 187   | producing                 | produc               | produc               | producing
# 188   | films                     | film                 | film                 | film
# 189   | since                     | sinc                 | sinc                 | since
# 190   | jobs                      | job                  | job                  | job
# 191   | returned                  | return               | return               | returned
# 192   | apple                     | appl                 | appl                 | apple
# 193   | ceo                       | ceo                  | ceo                  | ceo
# 194   | companys                  | compani              | compani              | company
# 195   | acquisition               | acquisit             | acquisit             | acquisition
# 196   | next                      | next                 | next                 | next
# 197   | largely                   | larg                 | larg                 | largely
# 198   | responsible               | respons              | respons              | responsible
# 199   | reviving                  | reviv                | reviv                | reviving
# 200   | apple                     | appl                 | appl                 | apple
# 201   | verge                     | verg                 | verg                 | verge
# 202   | bankruptcy                | bankruptci           | bankruptci           | bankruptcy
# 203   | worked                    | work                 | work                 | worked
# 204   | closely                   | close                | close                | closely
# 205   | british                   | british              | british              | british
# 206   | designer                  | design               | design               | designer
# 207   | jony                      | joni                 | joni                 | jony
# 208   | ive                       | ive                  | ive                  | ive
# 209   | develop                   | develop              | develop              | develop
# 210   | line                      | line                 | line                 | line
# 211   | products                  | product              | product              | product
# 212   | larger                    | larger               | larger               | larger
# 213   | cultural                  | cultur               | cultur               | cultural
# 214   | ramifications             | ramif                | ramif                | ramification
# 215   | beginning                 | begin                | begin                | beginning
# 216   | think                     | think                | think                | think
# 217   | different                 | differ               | differ               | different
# 218   | advertising               | advertis             | advertis             | advertising
# 219   | campaign                  | campaign             | campaign             | campaign
# 220   | leading                   | lead                 | lead                 | leading
# 221   | apple                     | appl                 | appl                 | apple
# 222   | store                     | store                | store                | store
# 223   | app                       | app                  | app                  | app
# 224   | store                     | store                | store                | store
# 225   | ios                       | io                   | io                   | io
# 226   | imac                      | imac                 | imac                 | imac
# 227   | ipad                      | ipad                 | ipad                 | ipad
# 228   | ipod                      | ipod                 | ipod                 | ipod
# 229   | iphone                    | iphon                | iphon                | iphone
# 230   | itunes                    | itun                 | itun                 | itunes
# 231   | itunes                    | itun                 | itun                 | itunes
# 232   | store                     | store                | store                | store
# 233   | original                  | origin               | origin               | original
# 234   | mac                       | mac                  | mac                  | mac
# 235   | os                        | os                   | os                   | o
# 236   | replaced                  | replac               | replac               | replaced
# 237   | completely                | complet              | complet              | completely
# 238   | new                       | new                  | new                  | new
# 239   | mac                       | mac                  | mac                  | mac
# 240   | os                        | os                   | os                   | o
# 241   | x                         | x                    | x                    | x
# 242   | later                     | later                | later                | later
# 243   | known                     | known                | known                | known
# 244   | macos                     | maco                 | maco                 | macos
# 245   | based                     | base                 | base                 | based
# 246   | nexts                     | next                 | next                 | nexts
# 247   | nextstep                  | nextstep             | nextstep             | nextstep
# 248   | platform                  | platform             | platform             | platform
# 249   | giving                    | give                 | give                 | giving
# 250   | operating                 | oper                 | oper                 | operating
# 251   | system                    | system               | system               | system
# 252   | modern                    | modern               | modern               | modern
# 253   | unixbased                 | unixbas              | unixbas              | unixbased
# 254   | foundation                | foundat              | foundat              | foundation
# 255   | first                     | first                | first                | first
# 256   | time                      | time                 | time                 | time
# 257   | jobs                      | job                  | job                  | job
# 258   | diagnosed                 | diagnos              | diagnos              | diagnosed
# 259   | pancreatic                | pancreat             | pancreat             | pancreatic
# 260   | neuroendocrine            | neuroendocrin        | neuroendocrin        | neuroendocrine
# 261   | tumor                     | tumor                | tumor                | tumor
# 262   | died                      | die                  | die                  | died
# 263   | respiratory               | respiratori          | respiratori          | respiratory
# 264   | arrest                    | arrest               | arrest               | arrest
# 265   | related                   | relat                | relat                | related
# 266   | tumor                     | tumor                | tumor                | tumor
# 267   | age                       | age                  | age                  | age
# 268   | tim                       | tim                  | tim                  | tim
# 269   | cook                      | cook                 | cook                 | cook
# 270   | succeeding                | succeed              | succeed              | succeeding
# 271   | ceo                       | ceo                  | ceo                  | ceo
# 272   | apple                     | appl                 | appl                 | apple
# 273   | posthumously              | posthum              | posthum              | posthumously
# 274   | awarded                   | award                | award                | awarded
# 275   | presidential              | presidenti           | presidenti           | presidential
# 276   | medal                     | medal                | medal                | medal
# 277   | freedom                   | freedom              | freedom              | freedom
#
# PERFORMANCE COMPARISON (Lemmatizer vs Stemmers):
# WordNetLemmatizer processing time (10 repetitions): 0.011826 seconds
# PorterStemmer processing time (10 repetitions): 0.032572 seconds
# SnowballStemmer processing time (10 repetitions): 0.015790 seconds
#
# Fastest: WordNetLemmatizer is 2.75x faster than Porter and 1.34x faster than Snowball

# %% [markdown]
# # 8. Part-of-Speech (POS) Tagging

# %%
# Cell 10: 8. POS Tagging (Part-of-Speech Tagging)
print("8. PART-OF-SPEECH (POS) TAGGING")

# Perform POS tagging on all filtered tokens
pos_tagged = pos_tag(filtered_tokens)

print("COMPLETE POS TAGGING RESULTS:")
print(f"{'#':<4} | {'Word':<20} | {'POS Tag':<10} | {'Description'}")

pos_descriptions = {
    'NN': 'Noun, singular', 'NNS': 'Noun, plural',
    'NNP': 'Proper noun, singular', 'NNPS': 'Proper noun, plural',
    'VB': 'Verb, base form', 'VBD': 'Verb, past tense',
    'VBG': 'Verb, gerund/present participle', 'VBN': 'Verb, past participle',
    'VBP': 'Verb, non-3rd person singular present', 'VBZ': 'Verb, 3rd person singular present',
    'JJ': 'Adjective', 'JJR': 'Adjective, comparative', 'JJS': 'Adjective, superlative',
    'RB': 'Adverb', 'RBR': 'Adverb, comparative', 'RBS': 'Adverb, superlative',
    'IN': 'Preposition/subordinating conjunction', 'DT': 'Determiner',
    'CC': 'Coordinating conjunction', 'PRP': 'Personal pronoun', 'PRP$': 'Possessive pronoun',
    'MD': 'Modal auxiliary', 'TO': 'to', 'UH': 'Interjection',
    'CD': 'Cardinal number', 'EX': 'Existential there', 'FW': 'Foreign word',
    'LS': 'List item marker', 'POS': 'Possessive ending', 'RP': 'Particle',
    'SYM': 'Symbol', 'WDT': 'Wh-determiner', 'WP': 'Wh-pronoun',
    'WP$': 'Possessive wh-pronoun', 'WRB': 'Wh-adverb'
}

for i, (word, tag) in enumerate(pos_tagged, 1):
    desc = pos_descriptions.get(tag, 'Other')
    print(f"{i:<4} | {word:<20} | {tag:<10} | {desc}")
# Out:
# 8. PART-OF-SPEECH (POS) TAGGING
# COMPLETE POS TAGGING RESULTS:
# #    | Word                 | POS Tag    | Description
# 1    | steven               | RB         | Adverb
# 2    | paul                 | NN         | Noun, singular
# 3    | jobs                 | NNS        | Noun, plural
# 4    | february             | JJ         | Adjective
# 5    | october              | JJ         | Adjective
# 6    | american             | JJ         | Adjective
# 7    | business             | NN         | Noun, singular
# 8    | magnate              | NN         | Noun, singular
# 9    | inventor             | NN         | Noun, singular
# 10   | investor             | NN         | Noun, singular
# 11   | cofounder            | NN         | Noun, singular
# 12   | chairman             | NN         | Noun, singular
# 13   | ceo                  | NN         | Noun, singular
# 14   | apple                | NN         | Noun, singular
# 15   | chairman             | NN         | Noun, singular
# 16   | majority             | NN         | Noun, singular
# 17   | shareholder          | NN         | Noun, singular
# 18   | pixar                | NN         | Noun, singular
# 19   | member               | NN         | Noun, singular
# 20   | walt                 | NN         | Noun, singular
# 21   | disney               | NN         | Noun, singular
# 22   | companys             | NN         | Noun, singular
# 23   | board                | NN         | Noun, singular
# 24   | directors            | NNS        | Noun, plural
# 25   | following            | VBG        | Verb, gerund/present participle
# 26   | acquisition          | NN         | Noun, singular
# 27   | pixar                | FW         | Foreign word
# 28   | founder              | NN         | Noun, singular
# 29   | chairman             | NN         | Noun, singular
# 30   | ceo                  | VBP        | Verb, non-3rd person singular present
# 31   | next                 | JJ         | Adjective
# 32   | pioneer              | NN         | Noun, singular
# 33   | personal             | JJ         | Adjective
# 34   | computer             | NN         | Noun, singular
# 35   | revolution           | NN         | Noun, singular
# 36   | along                | IN         | Preposition/subordinating conjunction
# 37   | early                | JJ         | Adjective
# 38   | business             | NN         | Noun, singular
# 39   | partner              | NN         | Noun, singular
# 40   | fellow               | JJ         | Adjective
# 41   | apple                | NN         | Noun, singular
# 42   | cofounder            | NN         | Noun, singular
# 43   | steve                | VBP        | Verb, non-3rd person singular present
# 44   | wozniak              | NN         | Noun, singular
# 45   | jobs                 | NNS        | Noun, plural
# 46   | born                 | VBN        | Verb, past participle
# 47   | san                  | JJ         | Adjective
# 48   | francisco            | NN         | Noun, singular
# 49   | syrian               | JJ         | Adjective
# 50   | father               | NN         | Noun, singular
# 51   | germanamerican       | JJ         | Adjective
# 52   | mother               | NN         | Noun, singular
# 53   | adopted              | VBN        | Verb, past participle
# 54   | shortly              | RB         | Adverb
# 55   | birth                | JJ         | Adjective
# 56   | jobs                 | NNS        | Noun, plural
# 57   | attended             | VBD        | Verb, past tense
# 58   | reed                 | NN         | Noun, singular
# 59   | college              | NN         | Noun, singular
# 60   | withdrawing          | VBG        | Verb, gerund/present participle
# 61   | year                 | NN         | Noun, singular
# 62   | traveled             | VBD        | Verb, past tense
# 63   | india                | NN         | Noun, singular
# 64   | seeking              | VBG        | Verb, gerund/present participle
# 65   | enlightenment        | NN         | Noun, singular
# 66   | later                | RB         | Adverb
# 67   | studying             | VBG        | Verb, gerund/present participle
# 68   | zen                  | JJ         | Adjective
# 69   | buddhism             | NN         | Noun, singular
# 70   | wozniak              | NN         | Noun, singular
# 71   | cofounded            | VBD        | Verb, past tense
# 72   | apple                | NN         | Noun, singular
# 73   | sell                 | NN         | Noun, singular
# 74   | wozniaks             | VBZ        | Verb, 3rd person singular present
# 75   | apple                | NN         | Noun, singular
# 76   | personal             | JJ         | Adjective
# 77   | computer             | NN         | Noun, singular
# 78   | together             | RB         | Adverb
# 79   | duo                  | NN         | Noun, singular
# 80   | gained               | VBD        | Verb, past tense
# 81   | fame                 | NN         | Noun, singular
# 82   | wealth               | NN         | Noun, singular
# 83   | year                 | NN         | Noun, singular
# 84   | later                | RB         | Adverb
# 85   | production           | NN         | Noun, singular
# 86   | sale                 | NN         | Noun, singular
# 87   | apple                | NN         | Noun, singular
# 88   | ii                   | VBP        | Verb, non-3rd person singular present
# 89   | one                  | CD         | Cardinal number
# 90   | first                | JJ         | Adjective
# 91   | highly               | RB         | Adverb
# 92   | successful           | JJ         | Adjective
# 93   | massproduced         | VBD        | Verb, past tense
# 94   | microcomputers       | NNS        | Noun, plural
# 95   | jobs                 | NNS        | Noun, plural
# 96   | saw                  | VBD        | Verb, past tense
# 97   | commercial           | JJ         | Adjective
# 98   | potential            | JJ         | Adjective
# 99   | xerox                | NNP        | Proper noun, singular
# 100  | alto                 | NN         | Noun, singular
# 101  | mousedriven          | RB         | Adverb
# 102  | graphical            | JJ         | Adjective
# 103  | user                 | NN         | Noun, singular
# 104  | interface            | NN         | Noun, singular
# 105  | gui                  | NN         | Noun, singular
# 106  | led                  | VBD        | Verb, past tense
# 107  | development          | NN         | Noun, singular
# 108  | unsuccessful         | JJ         | Adjective
# 109  | apple                | NN         | Noun, singular
# 110  | lisa                 | NN         | Noun, singular
# 111  | followed             | VBD        | Verb, past tense
# 112  | breakthrough         | IN         | Preposition/subordinating conjunction
# 113  | macintosh            | NN         | Noun, singular
# 114  | first                | RB         | Adverb
# 115  | massproduced         | VBD        | Verb, past tense
# 116  | computer             | NN         | Noun, singular
# 117  | gui                  | NN         | Noun, singular
# 118  | macintosh            | NN         | Noun, singular
# 119  | introduced           | VBN        | Verb, past participle
# 120  | desktop              | JJ         | Adjective
# 121  | publishing           | NN         | Noun, singular
# 122  | industry             | NN         | Noun, singular
# 123  | addition             | NN         | Noun, singular
# 124  | apple                | NN         | Noun, singular
# 125  | laserwriter          | NN         | Noun, singular
# 126  | first                | RB         | Adverb
# 127  | laser                | RBR        | Adverb, comparative
# 128  | printer              | JJ         | Adjective
# 129  | feature              | NN         | Noun, singular
# 130  | vector               | NN         | Noun, singular
# 131  | graphics             | NNS        | Noun, plural
# 132  | jobs                 | NNS        | Noun, plural
# 133  | forced               | VBD        | Verb, past tense
# 134  | apple                | NN         | Noun, singular
# 135  | long                 | JJ         | Adjective
# 136  | power                | NN         | Noun, singular
# 137  | struggle             | NN         | Noun, singular
# 138  | companys             | NN         | Noun, singular
# 139  | board                | NN         | Noun, singular
# 140  | thenceo              | NN         | Noun, singular
# 141  | john                 | NN         | Noun, singular
# 142  | sculley              | JJ         | Adjective
# 143  | year                 | NN         | Noun, singular
# 144  | jobs                 | NNS        | Noun, plural
# 145  | took                 | VBD        | Verb, past tense
# 146  | apple                | NN         | Noun, singular
# 147  | employees            | NNS        | Noun, plural
# 148  | found                | VBD        | Verb, past tense
# 149  | next                 | JJ         | Adjective
# 150  | computer             | NN         | Noun, singular
# 151  | platform             | NN         | Noun, singular
# 152  | development          | NN         | Noun, singular
# 153  | company              | NN         | Noun, singular
# 154  | specialized          | VBD        | Verb, past tense
# 155  | computers            | NNS        | Noun, plural
# 156  | highereducation      | NN         | Noun, singular
# 157  | business             | NN         | Noun, singular
# 158  | markets              | NNS        | Noun, plural
# 159  | addition             | NN         | Noun, singular
# 160  | helped               | VBD        | Verb, past tense
# 161  | develop              | VB         | Verb, base form
# 162  | visual               | JJ         | Adjective
# 163  | effects              | NNS        | Noun, plural
# 164  | industry             | NN         | Noun, singular
# 165  | funded               | VBD        | Verb, past tense
# 166  | computer             | NN         | Noun, singular
# 167  | graphics             | NNS        | Noun, plural
# 168  | division             | NN         | Noun, singular
# 169  | george               | NN         | Noun, singular
# 170  | lucass               | NN         | Noun, singular
# 171  | lucasfilm            | VBD        | Verb, past tense
# 172  | new                  | JJ         | Adjective
# 173  | company              | NN         | Noun, singular
# 174  | pixar                | NN         | Noun, singular
# 175  | produced             | VBD        | Verb, past tense
# 176  | first                | RB         | Adverb
# 177  | computeranimated     | VBN        | Verb, past participle
# 178  | feature              | NN         | Noun, singular
# 179  | film                 | NN         | Noun, singular
# 180  | toy                  | NN         | Noun, singular
# 181  | story                | NN         | Noun, singular
# 182  | went                 | VBD        | Verb, past tense
# 183  | become               | JJ         | Adjective
# 184  | major                | JJ         | Adjective
# 185  | animation            | NN         | Noun, singular
# 186  | studio               | NN         | Noun, singular
# 187  | producing            | VBG        | Verb, gerund/present participle
# 188  | films                | NNS        | Noun, plural
# 189  | since                | IN         | Preposition/subordinating conjunction
# 190  | jobs                 | NNS        | Noun, plural
# 191  | returned             | VBN        | Verb, past participle
# 192  | apple                | NN         | Noun, singular
# 193  | ceo                  | NN         | Noun, singular
# 194  | companys             | JJ         | Adjective
# 195  | acquisition          | NN         | Noun, singular
# 196  | next                 | IN         | Preposition/subordinating conjunction
# 197  | largely              | RB         | Adverb
# 198  | responsible          | JJ         | Adjective
# 199  | reviving             | VBG        | Verb, gerund/present participle
# 200  | apple                | NN         | Noun, singular
# 201  | verge                | NN         | Noun, singular
# 202  | bankruptcy           | NN         | Noun, singular
# 203  | worked               | VBD        | Verb, past tense
# 204  | closely              | RB         | Adverb
# 205  | british              | JJ         | Adjective
# 206  | designer             | NN         | Noun, singular
# 207  | jony                 | NN         | Noun, singular
# 208  | ive                  | JJ         | Adjective
# 209  | develop              | VB         | Verb, base form
# 210  | line                 | NN         | Noun, singular
# 211  | products             | NNS        | Noun, plural
# 212  | larger               | JJR        | Adjective, comparative
# 213  | cultural             | JJ         | Adjective
# 214  | ramifications        | NNS        | Noun, plural
# 215  | beginning            | VBG        | Verb, gerund/present participle
# 216  | think                | VBP        | Verb, non-3rd person singular present
# 217  | different            | JJ         | Adjective
# 218  | advertising          | NN         | Noun, singular
# 219  | campaign             | NN         | Noun, singular
# 220  | leading              | VBG        | Verb, gerund/present participle
# 221  | apple                | NN         | Noun, singular
# 222  | store                | NN         | Noun, singular
# 223  | app                  | NN         | Noun, singular
# 224  | store                | NN         | Noun, singular
# 225  | ios                  | NNS        | Noun, plural
# 226  | imac                 | VBP        | Verb, non-3rd person singular present
# 227  | ipad                 | JJ         | Adjective
# 228  | ipod                 | NN         | Noun, singular
# 229  | iphone               | NN         | Noun, singular
# 230  | itunes               | NNS        | Noun, plural
# 231  | itunes               | NNS        | Noun, plural
# 232  | store                | VBP        | Verb, non-3rd person singular present
# 233  | original             | JJ         | Adjective
# 234  | mac                  | NNS        | Noun, plural
# 235  | os                   | RB         | Adverb
# 236  | replaced             | VBD        | Verb, past tense
# 237  | completely           | RB         | Adverb
# 238  | new                  | JJ         | Adjective
# 239  | mac                  | NN         | Noun, singular
# 240  | os                   | NN         | Noun, singular
# 241  | x                    | NNP        | Proper noun, singular
# 242  | later                | RB         | Adverb
# 243  | known                | VBN        | Verb, past participle
# 244  | macos                | NNS        | Noun, plural
# 245  | based                | VBN        | Verb, past participle
# 246  | nexts                | JJ         | Adjective
# 247  | nextstep             | JJ         | Adjective
# 248  | platform             | NN         | Noun, singular
# 249  | giving               | VBG        | Verb, gerund/present participle
# 250  | operating            | NN         | Noun, singular
# 251  | system               | NN         | Noun, singular
# 252  | modern               | JJ         | Adjective
# 253  | unixbased            | JJ         | Adjective
# 254  | foundation           | NN         | Noun, singular
# 255  | first                | JJ         | Adjective
# 256  | time                 | NN         | Noun, singular
# 257  | jobs                 | NNS        | Noun, plural
# 258  | diagnosed            | VBN        | Verb, past participle
# 259  | pancreatic           | JJ         | Adjective
# 260  | neuroendocrine       | JJ         | Adjective
# 261  | tumor                | NN         | Noun, singular
# 262  | died                 | VBD        | Verb, past tense
# 263  | respiratory          | JJ         | Adjective
# 264  | arrest               | RB         | Adverb
# 265  | related              | JJ         | Adjective
# 266  | tumor                | NN         | Noun, singular
# 267  | age                  | NN         | Noun, singular
# 268  | tim                  | NN         | Noun, singular
# 269  | cook                 | NN         | Noun, singular
# 270  | succeeding           | VBG        | Verb, gerund/present participle
# 271  | ceo                  | NN         | Noun, singular
# 272  | apple                | NN         | Noun, singular
# 273  | posthumously         | RB         | Adverb
# 274  | awarded              | VBD        | Verb, past tense
# 275  | presidential         | JJ         | Adjective
# 276  | medal                | NN         | Noun, singular
# 277  | freedom              | NN         | Noun, singular

# %% [markdown]
# # 9. Chunking

# %%
# Define chunk grammar
chunk_grammar = r"""
    NP: {<DT>?<JJ>*<NN.*>+}
    NP: {<NNP>+}
    NP: {<NNP><POS>?<NNP>*}
    VP: {<VB.*><NP|PP|CLAUSE>+$}
    PP: {<IN><NP>}
"""
chunk_parser = RegexpParser(chunk_grammar)

# Process ALL sentences for chunking
all_sentences = sent_tokenize(text_lower)

for sent_idx, sentence in enumerate(all_sentences, 1):
    print(f"\nSentence {sent_idx}: {sentence}")

    # Tokenize and tag
    tokens = word_tokenize(sentence)
    pos_tags = pos_tag(tokens)

    # Parse chunks
    chunk_tree = chunk_parser.parse(pos_tags)

    print("Chunk Tree Structure:")
    print(chunk_tree)

    print("Chunks extracted:")
    for subtree in chunk_tree.subtrees():
        if subtree.label() in ['NP', 'VP', 'PP']:
            chunk_words = ' '.join(word for word, tag in subtree.leaves())
            print(f"  {subtree.label()}: {chunk_words}")
# Out:
# Sentence 1: steven paul jobs february ,  october ,  was an american business magnate, inventor, and investor.
# Chunk Tree Structure:
# (S
#   steven/RB
#   (NP paul/NN jobs/NNS)
#   february/JJ
#   ,/,
#   (NP october/NNP)
#   ,/,
#   was/VBD
#   (NP an/DT american/JJ business/NN magnate/NN)
#   ,/,
#   (NP inventor/NN)
#   ,/,
#   and/CC
#   (NP investor/NN)
#   ./.)
# Chunks extracted:
#   NP: paul jobs
#   NP: october
#   NP: an american business magnate
#   NP: inventor
#   NP: investor
#
# Sentence 2: he was the cofounder, chairman, and ceo of apple the chairman and majority shareholder of pixar a member of the walt disney companys board of directors following its acquisition of pixar and the founder, chairman, and ceo of next.
# Chunk Tree Structure:
# (S
#   he/PRP
#   was/VBD
#   (NP the/DT cofounder/NN)
#   ,/,
#   (NP chairman/NN)
#   ,/,
#   and/CC
#   (NP ceo/NN)
#   (PP of/IN (NP apple/NN))
#   (NP the/DT chairman/NN)
#   and/CC
#   (NP majority/NN shareholder/NN)
#   (PP of/IN (NP pixar/NN))
#   (NP a/DT member/NN)
#   (PP of/IN (NP the/DT walt/NN disney/NN))
#   companys/VBZ
#   (NP board/NN)
#   (PP of/IN (NP directors/NNS))
#   following/VBG
#   its/PRP$
#   (NP acquisition/NN)
#   (PP of/IN (NP pixar/NN))
#   and/CC
#   (NP the/DT founder/NN)
#   ,/,
#   (NP chairman/NN)
#   ,/,
#   and/CC
#   (NP ceo/NN)
#   of/IN
#   next/JJ
#   ./.)
# Chunks extracted:
#   NP: the cofounder
#   NP: chairman
#   NP: ceo
#   PP: of apple
#   NP: apple
#   NP: the chairman
#   NP: majority shareholder
#   PP: of pixar
#   NP: pixar
#   NP: a member
#   PP: of the walt disney
#   NP: the walt disney
#   NP: board
#   PP: of directors
#   NP: directors
#   NP: acquisition
#   PP: of pixar
#   NP: pixar
#   NP: the founder
#   NP: chairman
#   NP: ceo
#
# Sentence 3: he was a pioneer of the personal computer revolution of the s and s, along with his early business partner and fellow apple cofounder steve wozniak.
# Chunk Tree Structure:
# (S
#   he/PRP
#   was/VBD
#   (NP a/DT pioneer/NN)
#   (PP of/IN (NP the/DT personal/JJ computer/NN revolution/NN))
#   (PP of/IN (NP the/DT s/NN))
#   and/CC
#   (NP s/NN)
#   ,/,
#   along/IN
#   with/IN
#   his/PRP$
#   (NP early/JJ business/NN partner/NN)
#   and/CC
#   (NP fellow/JJ apple/NN cofounder/NN)
#   steve/VBP
#   (NP wozniak/NN)
#   ./.)
# Chunks extracted:
#   NP: a pioneer
#   PP: of the personal computer revolution
#   NP: the personal computer revolution
#   PP: of the s
#   NP: the s
#   NP: s
#   NP: early business partner
#   NP: fellow apple cofounder
#   NP: wozniak
#
# Sentence 4: jobs was born in san francisco to a syrian father and germanamerican mother.
# Chunk Tree Structure:
# (S
#   (NP jobs/NNS)
#   was/VBD
#   born/VBN
#   (PP in/IN (NP san/JJ francisco/NN))
#   to/TO
#   (NP a/DT syrian/JJ father/NN)
#   and/CC
#   (NP germanamerican/JJ mother/NN)
#   ./.)
# Chunks extracted:
#   NP: jobs
#   PP: in san francisco
#   NP: san francisco
#   NP: a syrian father
#   NP: germanamerican mother
#
# Sentence 5: he was adopted shortly after his birth.
# Chunk Tree Structure:
# (S
#   he/PRP
#   was/VBD
#   adopted/VBN
#   shortly/RB
#   after/IN
#   his/PRP$
#   (NP birth/NN)
#   ./.)
# Chunks extracted:
#   NP: birth
#
# Sentence 6: jobs attended reed college in before withdrawing that same year.
# Chunk Tree Structure:
# (S
#   (NP jobs/NNS)
#   attended/VBD
#   (NP reed/NN college/NN)
#   in/IN
#   before/IN
#   withdrawing/VBG
#   (NP that/DT same/JJ year/NN)
#   ./.)
# Chunks extracted:
#   NP: jobs
#   NP: reed college
#   NP: that same year
#
# Sentence 7: in , he traveled through india seeking enlightenment before later studying zen buddhism.
# Chunk Tree Structure:
# (S
#   in/IN
#   ,/,
#   he/PRP
#   traveled/VBD
#   (PP through/IN (NP india/NN))
#   seeking/VBG
#   (NP enlightenment/NN)
#   before/IN
#   later/JJ
#   studying/VBG
#   (NP zen/JJ buddhism/NN)
#   ./.)
# Chunks extracted:
#   PP: through india
#   NP: india
#   NP: enlightenment
#   NP: zen buddhism
#
# Sentence 8: he and wozniak cofounded apple in to sell wozniaks apple i personal computer.
# Chunk Tree Structure:
# (S
#   he/PRP
#   and/CC
#   wozniak/VB
#   cofounded/VBN
#   (NP apple/NN)
#   in/IN
#   to/TO
#   sell/VB
#   (NP wozniaks/JJ apple/NN i/NN)
#   (NP personal/JJ computer/NN)
#   ./.)
# Chunks extracted:
#   NP: apple
#   NP: wozniaks apple i
#   NP: personal computer
#
# Sentence 9: together the duo gained fame and wealth a year later with production and sale of the apple ii, one of the first highly successful massproduced microcomputers.
# Chunk Tree Structure:
# (S
#   together/RB
#   (NP the/DT duo/NN)
#   gained/VBD
#   (NP fame/NN)
#   and/CC
#   (NP wealth/NN)
#   (NP a/DT year/NN)
#   later/RB
#   (PP with/IN (NP production/NN))
#   and/CC
#   (NP sale/NN)
#   (PP of/IN (NP the/DT apple/NN ii/NN))
#   ,/,
#   one/CD
#   of/IN
#   the/DT
#   first/JJ
#   highly/RB
#   successful/JJ
#   massproduced/VBD
#   (NP microcomputers/NNS)
#   ./.)
# Chunks extracted:
#   NP: the duo
#   NP: fame
#   NP: wealth
#   NP: a year
#   PP: with production
#   NP: production
#   NP: sale
#   PP: of the apple ii
#   NP: the apple ii
#   NP: microcomputers
#
# Sentence 10: jobs saw the commercial potential of the xerox alto in , which was mousedriven and had a graphical user interface gui.
# Chunk Tree Structure:
# (S
#   (NP jobs/NNS)
#   saw/VBD
#   (NP the/DT commercial/JJ potential/NN)
#   (PP of/IN (NP the/DT xerox/NNP alto/NN))
#   in/IN
#   ,/,
#   which/WDT
#   was/VBD
#   mousedriven/VBN
#   and/CC
#   had/VBD
#   (NP a/DT graphical/JJ user/NN interface/NN gui/NN)
#   ./.)
# Chunks extracted:
#   NP: jobs
#   NP: the commercial potential
#   PP: of the xerox alto
#   NP: the xerox alto
#   NP: a graphical user interface gui
#
# Sentence 11: this led to the development of the unsuccessful apple lisa in , followed by the breakthrough macintosh in , the first massproduced computer with a gui.
# Chunk Tree Structure:
# (S
#   this/DT
#   led/VBD
#   to/TO
#   (NP the/DT development/NN)
#   (PP of/IN (NP the/DT unsuccessful/JJ apple/NN lisa/NN))
#   in/IN
#   ,/,
#   followed/VBN
#   (PP by/IN (NP the/DT breakthrough/NN macintosh/NN))
#   in/IN
#   ,/,
#   the/DT
#   first/JJ
#   massproduced/VBD
#   (NP computer/NN)
#   (PP with/IN (NP a/DT gui/NN))
#   ./.)
# Chunks extracted:
#   NP: the development
#   PP: of the unsuccessful apple lisa
#   NP: the unsuccessful apple lisa
#   PP: by the breakthrough macintosh
#   NP: the breakthrough macintosh
#   NP: computer
#   PP: with a gui
#   NP: a gui
#
# Sentence 12: the macintosh introduced the desktop publishing industry in with the addition of the apple laserwriter, the first laser printer to feature vector graphics.
# Chunk Tree Structure:
# (S
#   (NP the/DT macintosh/NN)
#   introduced/VBD
#   (NP the/DT desktop/NN publishing/NN industry/NN)
#   in/IN
#   (PP with/IN (NP the/DT addition/NN))
#   (PP of/IN (NP the/DT apple/NN laserwriter/NN))
#   ,/,
#   (NP the/DT first/JJ laser/NN printer/NN)
#   to/TO
#   feature/VB
#   (NP vector/NN graphics/NNS)
#   ./.)
# Chunks extracted:
#   NP: the macintosh
#   NP: the desktop publishing industry
#   PP: with the addition
#   NP: the addition
#   PP: of the apple laserwriter
#   NP: the apple laserwriter
#   NP: the first laser printer
#   NP: vector graphics
#
# Sentence 13: in , jobs was forced out of apple after a long power struggle with the companys board and its thenceo, john sculley.
# Chunk Tree Structure:
# (S
#   in/IN
#   ,/,
#   (NP jobs/NNS)
#   was/VBD
#   forced/VBN
#   out/IN
#   (PP of/IN (NP apple/NN))
#   (PP after/IN (NP a/DT long/JJ power/NN struggle/NN))
#   (PP with/IN (NP the/DT companys/NN board/NN))
#   and/CC
#   its/PRP$
#   (NP thenceo/NN)
#   ,/,
#   (NP john/NN sculley/NN)
#   ./.)
# Chunks extracted:
#   NP: jobs
#   PP: of apple
#   NP: apple
#   PP: after a long power struggle
#   NP: a long power struggle
#   PP: with the companys board
#   NP: the companys board
#   NP: thenceo
#   NP: john sculley
#
# Sentence 14: that same year, jobs took a few apple employees with him to found next, a computer platform development company that specialized in computers for highereducation and business markets.
# Chunk Tree Structure:
# (S
#   (NP that/DT same/JJ year/NN)
#   ,/,
#   (NP jobs/NNS)
#   took/VBD
#   (NP a/DT few/JJ apple/NN employees/NNS)
#   with/IN
#   him/PRP
#   to/TO
#   found/VB
#   next/RB
#   ,/,
#   (NP a/DT computer/NN platform/NN development/NN company/NN)
#   that/WDT
#   specialized/VBD
#   (PP in/IN (NP computers/NNS))
#   (PP for/IN (NP highereducation/NN))
#   and/CC
#   (NP business/NN markets/NNS)
#   ./.)
# Chunks extracted:
#   NP: that same year
#   NP: jobs
#   NP: a few apple employees
#   NP: a computer platform development company
#   PP: in computers
#   NP: computers
#   PP: for highereducation
#   NP: highereducation
#   NP: business markets
#
# Sentence 15: in addition, he helped to develop the visual effects industry when he funded the computer graphics division of george lucass lucasfilm in .
# Chunk Tree Structure:
# (S
#   (PP in/IN (NP addition/NN))
#   ,/,
#   he/PRP
#   helped/VBD
#   to/TO
#   develop/VB
#   (NP the/DT visual/JJ effects/NNS industry/NN)
#   when/WRB
#   he/PRP
#   funded/VBD
#   (NP the/DT computer/NN graphics/NNS division/NN)
#   (PP of/IN (NP george/NN lucass/NN lucasfilm/NN))
#   in/IN
#   ./.)
# Chunks extracted:
#   PP: in addition
#   NP: addition
#   NP: the visual effects industry
#   NP: the computer graphics division
#   PP: of george lucass lucasfilm
#   NP: george lucass lucasfilm
#
# Sentence 16: the new company was pixar, which produced the first d computeranimated feature film toy story  and went on to become a major animation studio, producing over films since.
# Chunk Tree Structure:
# (S
#   (NP the/DT new/JJ company/NN)
#   was/VBD
#   (NP pixar/NN)
#   ,/,
#   which/WDT
#   produced/VBD
#   (NP the/DT first/JJ d/NN)
#   computeranimated/VBN
#   (NP feature/NN film/NN toy/NN story/NN)
#   and/CC
#   went/VBD
#   on/IN
#   to/TO
#   become/VB
#   (NP a/DT major/JJ animation/NN studio/NN)
#   ,/,
#   producing/VBG
#   (PP over/IN (NP films/NNS))
#   since/IN
#   ./.)
# Chunks extracted:
#   NP: the new company
#   NP: pixar
#   NP: the first d
#   NP: feature film toy story
#   NP: a major animation studio
#   PP: over films
#   NP: films
#
# Sentence 17: in , jobs returned to apple as ceo after the companys acquisition of next.
# Chunk Tree Structure:
# (S
#   in/IN
#   ,/,
#   (NP jobs/NNS)
#   returned/VBD
#   to/TO
#   (NP apple/NN)
#   (PP as/IN (NP ceo/NN))
#   (PP after/IN (NP the/DT companys/JJ acquisition/NN))
#   of/IN
#   next/JJ
#   ./.)
# Chunks extracted:
#   NP: jobs
#   NP: apple
#   PP: as ceo
#   NP: ceo
#   PP: after the companys acquisition
#   NP: the companys acquisition
#
# Sentence 18: he was largely responsible for reviving apple, which was on the verge of bankruptcy.
# Chunk Tree Structure:
# (S
#   he/PRP
#   was/VBD
#   largely/RB
#   responsible/JJ
#   for/IN
#   reviving/VBG
#   (NP apple/NN)
#   ,/,
#   which/WDT
#   was/VBD
#   (PP on/IN (NP the/DT verge/NN))
#   (PP of/IN (NP bankruptcy/NN))
#   ./.)
# Chunks extracted:
#   NP: apple
#   PP: on the verge
#   NP: the verge
#   PP: of bankruptcy
#   NP: bankruptcy
#
# Sentence 19: he worked closely with british designer jony ive to develop a line of products that had larger cultural ramifications, beginning with the think different advertising campaign and leading to the apple store, app store ios, imac, ipad, ipod, iphone, itunes, and itunes store.
# Chunk Tree Structure:
# (S
#   he/PRP
#   worked/VBD
#   closely/RB
#   (PP with/IN (NP british/JJ designer/NN jony/NN ive/NN))
#   to/TO
#   develop/VB
#   (NP a/DT line/NN)
#   (PP of/IN (NP products/NNS))
#   that/WDT
#   had/VBD
#   larger/JJR
#   (NP cultural/JJ ramifications/NNS)
#   ,/,
#   beginning/VBG
#   (PP with/IN (NP the/DT think/NN))
#   (NP different/JJ advertising/NN campaign/NN)
#   and/CC
#   leading/VBG
#   to/TO
#   (NP the/DT apple/NN store/NN)
#   ,/,
#   (NP app/JJ store/NN ios/NNS)
#   ,/,
#   (NP imac/NN)
#   ,/,
#   (NP ipad/NN)
#   ,/,
#   (NP ipod/NN)
#   ,/,
#   (NP iphone/NN)
#   ,/,
#   (NP itunes/NNS)
#   ,/,
#   and/CC
#   (NP itunes/NNS store/NN)
#   ./.)
# Chunks extracted:
#   PP: with british designer jony ive
#   NP: british designer jony ive
#   NP: a line
#   PP: of products
#   NP: products
#   NP: cultural ramifications
#   PP: with the think
#   NP: the think
#   NP: different advertising campaign
#   NP: the apple store
#   NP: app store ios
#   NP: imac
#   NP: ipad
#   NP: ipod
#   NP: iphone
#   NP: itunes
#   NP: itunes store
#
# Sentence 20: in , the original mac os was replaced with the completely new mac os x later known as macos, based on nexts nextstep platform, giving the operating system a modern unixbased foundation for the first time.
# Chunk Tree Structure:
# (S
#   in/IN
#   ,/,
#   (NP the/DT original/JJ mac/NN os/NN)
#   was/VBD
#   replaced/VBN
#   with/IN
#   the/DT
#   completely/RB
#   (NP new/JJ mac/NN os/NN x/NNP)
#   later/RB
#   known/VBN
#   (PP as/IN (NP macos/NN))
#   ,/,
#   based/VBN
#   (PP on/IN (NP nexts/JJ nextstep/NN platform/NN))
#   ,/,
#   giving/VBG
#   (NP the/DT operating/NN system/NN)
#   (NP a/DT modern/JJ unixbased/JJ foundation/NN)
#   (PP for/IN (NP the/DT first/JJ time/NN))
#   ./.)
# Chunks extracted:
#   NP: the original mac os
#   NP: new mac os x
#   PP: as macos
#   NP: macos
#   PP: on nexts nextstep platform
#   NP: nexts nextstep platform
#   NP: the operating system
#   NP: a modern unixbased foundation
#   PP: for the first time
#   NP: the first time
#
# Sentence 21: in , jobs was diagnosed with a pancreatic neuroendocrine tumor.
# Chunk Tree Structure:
# (S
#   in/IN
#   ,/,
#   (NP jobs/NNS)
#   was/VBD
#   diagnosed/VBN
#   (PP with/IN (NP a/DT pancreatic/JJ neuroendocrine/NN tumor/NN))
#   ./.)
# Chunks extracted:
#   NP: jobs
#   PP: with a pancreatic neuroendocrine tumor
#   NP: a pancreatic neuroendocrine tumor
#
# Sentence 22: he died of respiratory arrest related to the tumor in , at the age of , with tim cook succeeding him as ceo of apple.
# Chunk Tree Structure:
# (S
#   he/PRP
#   died/VBD
#   (PP of/IN (NP respiratory/NN arrest/NN))
#   related/VBN
#   to/TO
#   (NP the/DT tumor/NN)
#   in/IN
#   ,/,
#   (PP at/IN (NP the/DT age/NN))
#   of/IN
#   ,/,
#   (PP with/IN (NP tim/JJ cook/NN))
#   succeeding/VBG
#   him/PRP
#   (PP as/IN (NP ceo/NN))
#   (PP of/IN (NP apple/NN))
#   ./.)
# Chunks extracted:
#   PP: of respiratory arrest
#   NP: respiratory arrest
#   NP: the tumor
#   PP: at the age
#   NP: the age
#   PP: with tim cook
#   NP: tim cook
#   PP: as ceo
#   NP: ceo
#   PP: of apple
#   NP: apple
#
# Sentence 23: in , he was posthumously awarded the presidential medal of freedom.
# Chunk Tree Structure:
# (S
#   in/IN
#   ,/,
#   he/PRP
#   was/VBD
#   posthumously/RB
#   awarded/VBN
#   (NP the/DT presidential/JJ medal/NN)
#   (PP of/IN (NP freedom/NN))
#   ./.)
# Chunks extracted:
#   NP: the presidential medal
#   PP: of freedom
#   NP: freedom

# %% [markdown]
# # 10. Parsing ( Dependency Parsing and Tree Structure Parsing )

# %%
# Process entire text with spaCy
doc = nlp(text_lower)

print("DEPENDENCY RELATIONS FOR ENTIRE TEXT:")

for token in doc:
    print(f"Word: '{token.text}'")
    print(f"  Head word: '{token.head.text}'")
    print(f"  Dependency relation: {token.dep_}")
    print(f"  Explanation: {spacy.explain(token.dep_)}")
    print(f"  Children: {[child.text for child in token.children]}")
# Out:
# DEPENDENCY RELATIONS FOR ENTIRE TEXT:
# Word: 'steven'
#   Head word: 'jobs'
#   Dependency relation: compound
#   Explanation: compound
#   Children: []
# Word: 'paul'
#   Head word: 'jobs'
#   Dependency relation: compound
#   Explanation: compound
#   Children: []
# Word: 'jobs'
#   Head word: 'february'
#   Dependency relation: compound
#   Explanation: compound
#   Children: ['steven', 'paul']
# Word: 'february'
#   Head word: 'was'
#   Dependency relation: nsubj
#   Explanation: nominal subject
#   Children: ['jobs', ',', 'october']
# Word: ','
#   Head word: 'february'
#   Dependency relation: punct
#   Explanation: punctuation
#   Children: [' ']
# Word: ' '
#   Head word: ','
#   Dependency relation: dep
#   Explanation: unclassified dependent
#   Children: []
# Word: 'october'
#   Head word: 'february'
#   Dependency relation: appos
#   Explanation: appositional modifier
#   Children: []
# Word: ','
#   Head word: 'was'
#   Dependency relation: punct
#   Explanation: punctuation
#   Children: [' ']
# Word: ' '
#   Head word: ','
#   Dependency relation: dep
#   Explanation: unclassified dependent
#   Children: []
# Word: 'was'
#   Head word: 'was'
#   Dependency relation: ROOT
#   Explanation: root
#   Children: ['february', ',', 'magnate', '.']
# Word: 'an'
#   Head word: 'magnate'
#   Dependency relation: det
#   Explanation: determiner
#   Children: []
# Word: 'american'
#   Head word: 'magnate'
#   Dependency relation: amod
#   Explanation: adjectival modifier
#   Children: []
# Word: 'business'
#   Head word: 'magnate'
#   Dependency relation: compound
#   Explanation: compound
#   Children: []
# Word: 'magnate'
#   Head word: 'was'
#   Dependency relation: attr
#   Explanation: attribute
#   Children: ['an', 'american', 'business', ',', 'inventor']
# Word: ','
#   Head word: 'magnate'
#   Dependency relation: punct
#   Explanation: punctuation
#   Children: []
# Word: 'inventor'
#   Head word: 'magnate'
#   Dependency relation: conj
#   Explanation: conjunct
#   Children: [',', 'and', 'investor']
# Word: ','
#   Head word: 'inventor'
#   Dependency relation: punct
#   Explanation: punctuation
#   Children: []
# Word: 'and'
#   Head word: 'inventor'
#   Dependency relation: cc
#   Explanation: coordinating conjunction
#   Children: []
# Word: 'investor'
#   Head word: 'inventor'
#   Dependency relation: conj
#   Explanation: conjunct
#   Children: []
# Word: '.'
#   Head word: 'was'
#   Dependency relation: punct
#   Explanation: punctuation
#   Children: []
# Word: 'he'
#   Head word: 'was'
#   Dependency relation: nsubj
#   Explanation: nominal subject
#   Children: []
# Word: 'was'
#   Head word: 'was'
#   Dependency relation: ROOT
#   Explanation: root
#   Children: ['he', 'cofounder', '.']
# Word: 'the'
#   Head word: 'cofounder'
#   Dependency relation: det
#   Explanation: determiner
#   Children: []
# Word: 'cofounder'
#   Head word: 'was'
#   Dependency relation: attr
#   Explanation: attribute
#   Children: ['the', ',', 'chairman', 'chairman', 'following']
# Word: ','
#   Head word: 'cofounder'
#   Dependency relation: punct
#   Explanation: punctuation
#   Children: []
# Word: 'chairman'
#   Head word: 'cofounder'
#   Dependency relation: conj
#   Explanation: conjunct
#   Children: [',', 'and', 'ceo']
# Word: ','
#   Head word: 'chairman'
#   Dependency relation: punct
#   Explanation: punctuation
#   Children: []
# Word: 'and'
#   Head word: 'chairman'
#   Dependency relation: cc
#   Explanation: coordinating conjunction
#   Children: []
# Word: 'ceo'
#   Head word: 'chairman'
#   Dependency relation: conj
#   Explanation: conjunct
#   Children: ['of']
# Word: 'of'
#   Head word: 'ceo'
#   Dependency relation: prep
#   Explanation: prepositional modifier
#   Children: ['apple']
# Word: 'apple'
#   Head word: 'of'
#   Dependency relation: pobj
#   Explanation: object of preposition
#   Children: []
# Word: 'the'
#   Head word: 'chairman'
#   Dependency relation: det
#   Explanation: determiner
#   Children: []
# Word: 'chairman'
#   Head word: 'cofounder'
#   Dependency relation: conj
#   Explanation: conjunct
#   Children: ['the', 'and', 'shareholder', 'of', 'member']
# Word: 'and'
#   Head word: 'chairman'
#   Dependency relation: cc
#   Explanation: coordinating conjunction
#   Children: []
# Word: 'majority'
#   Head word: 'shareholder'
#   Dependency relation: compound
#   Explanation: compound
#   Children: []
# Word: 'shareholder'
#   Head word: 'chairman'
#   Dependency relation: conj
#   Explanation: conjunct
#   Children: ['majority']
# Word: 'of'
#   Head word: 'chairman'
#   Dependency relation: prep
#   Explanation: prepositional modifier
#   Children: ['pixar']
# Word: 'pixar'
#   Head word: 'of'
#   Dependency relation: pobj
#   Explanation: object of preposition
#   Children: []
# Word: 'a'
#   Head word: 'member'
#   Dependency relation: det
#   Explanation: determiner
#   Children: []
# Word: 'member'
#   Head word: 'chairman'
#   Dependency relation: appos
#   Explanation: appositional modifier
#   Children: ['a', 'of']
# Word: 'of'
#   Head word: 'member'
#   Dependency relation: prep
#   Explanation: prepositional modifier
#   Children: ['board']
# Word: 'the'
#   Head word: 'board'
#   Dependency relation: det
#   Explanation: determiner
#   Children: []
# Word: 'walt'
#   Head word: 'disney'
#   Dependency relation: compound
#   Explanation: compound
#   Children: []
# Word: 'disney'
#   Head word: 'companys'
#   Dependency relation: compound
#   Explanation: compound
#   Children: ['walt']
# Word: 'companys'
#   Head word: 'board'
#   Dependency relation: compound
#   Explanation: compound
#   Children: ['disney']
# Word: 'board'
#   Head word: 'of'
#   Dependency relation: pobj
#   Explanation: object of preposition
#   Children: ['the', 'companys', 'of']
# Word: 'of'
#   Head word: 'board'
#   Dependency relation: prep
#   Explanation: prepositional modifier
#   Children: ['directors']
# Word: 'directors'
#   Head word: 'of'
#   Dependency relation: pobj
#   Explanation: object of preposition
#   Children: []
# Word: 'following'
#   Head word: 'cofounder'
#   Dependency relation: prep
#   Explanation: prepositional modifier
#   Children: ['acquisition']
# Word: 'its'
#   Head word: 'acquisition'
#   Dependency relation: poss
#   Explanation: possession modifier
#   Children: []
# Word: 'acquisition'
#   Head word: 'following'
#   Dependency relation: pobj
#   Explanation: object of preposition
#   Children: ['its', 'of', 'and', 'founder']
# Word: 'of'
#   Head word: 'acquisition'
#   Dependency relation: prep
#   Explanation: prepositional modifier
#   Children: ['pixar']
# Word: 'pixar'
#   Head word: 'of'
#   Dependency relation: pobj
#   Explanation: object of preposition
#   Children: []
# Word: 'and'
#   Head word: 'acquisition'
#   Dependency relation: cc
#   Explanation: coordinating conjunction
#   Children: []
# Word: 'the'
#   Head word: 'founder'
#   Dependency relation: det
#   Explanation: determiner
#   Children: []
# Word: 'founder'
#   Head word: 'acquisition'
#   Dependency relation: conj
#   Explanation: conjunct
#   Children: ['the', ',', 'chairman']
# Word: ','
#   Head word: 'founder'
#   Dependency relation: punct
#   Explanation: punctuation
#   Children: []
# Word: 'chairman'
#   Head word: 'founder'
#   Dependency relation: conj
#   Explanation: conjunct
#   Children: [',', 'and', 'ceo']
# Word: ','
#   Head word: 'chairman'
#   Dependency relation: punct
#   Explanation: punctuation
#   Children: []
# Word: 'and'
#   Head word: 'chairman'
#   Dependency relation: cc
#   Explanation: coordinating conjunction
#   Children: []
# Word: 'ceo'
#   Head word: 'chairman'
#   Dependency relation: conj
#   Explanation: conjunct
#   Children: ['of']
# Word: 'of'
#   Head word: 'ceo'
#   Dependency relation: prep
#   Explanation: prepositional modifier
#   Children: ['next']
# Word: 'next'
#   Head word: 'of'
#   Dependency relation: pobj
#   Explanation: object of preposition
#   Children: []
# Word: '.'
#   Head word: 'was'
#   Dependency relation: punct
#   Explanation: punctuation
#   Children: []
# Word: 'he'
#   Head word: 'was'
#   Dependency relation: nsubj
#   Explanation: nominal subject
#   Children: []
# Word: 'was'
#   Head word: 'was'
#   Dependency relation: ROOT
#   Explanation: root
#   Children: ['he', 'pioneer', '.']
# Word: 'a'
#   Head word: 'pioneer'
#   Dependency relation: det
#   Explanation: determiner
#   Children: []
# Word: 'pioneer'
#   Head word: 'was'
#   Dependency relation: attr
#   Explanation: attribute
#   Children: ['a', 'of', ',', 'along']
# Word: 'of'
#   Head word: 'pioneer'
#   Dependency relation: prep
#   Explanation: prepositional modifier
#   Children: ['revolution']
# Word: 'the'
#   Head word: 'revolution'
#   Dependency relation: det
#   Explanation: determiner
#   Children: []
# Word: 'personal'
#   Head word: 'computer'
#   Dependency relation: amod
#   Explanation: adjectival modifier
#   Children: []
# Word: 'computer'
#   Head word: 'revolution'
#   Dependency relation: compound
#   Explanation: compound
#   Children: ['personal']
# Word: 'revolution'
#   Head word: 'of'
#   Dependency relation: pobj
#   Explanation: object of preposition
#   Children: ['the', 'computer', 'of']
# Word: 'of'
#   Head word: 'revolution'
#   Dependency relation: prep
#   Explanation: prepositional modifier
#   Children: ['s']
# Word: 'the'
#   Head word: 's'
#   Dependency relation: det
#   Explanation: determiner
#   Children: []
# Word: 's'
#   Head word: 'of'
#   Dependency relation: pobj
#   Explanation: object of preposition
#   Children: ['the', 'and', 's']
# Word: 'and'
#   Head word: 's'
#   Dependency relation: cc
#   Explanation: coordinating conjunction
#   Children: []
# Word: 's'
#   Head word: 's'
#   Dependency relation: conj
#   Explanation: conjunct
#   Children: []
# Word: ','
#   Head word: 'pioneer'
#   Dependency relation: punct
#   Explanation: punctuation
#   Children: []
# Word: 'along'
#   Head word: 'pioneer'
#   Dependency relation: prep
#   Explanation: prepositional modifier
#   Children: ['with']
# Word: 'with'
#   Head word: 'along'
#   Dependency relation: prep
#   Explanation: prepositional modifier
#   Children: ['partner']
# Word: 'his'
#   Head word: 'partner'
#   Dependency relation: poss
#   Explanation: possession modifier
#   Children: []
# Word: 'early'
#   Head word: 'partner'
#   Dependency relation: amod
#   Explanation: adjectival modifier
#   Children: []
# Word: 'business'
#   Head word: 'partner'
#   Dependency relation: compound
#   Explanation: compound
#   Children: []
# Word: 'partner'
#   Head word: 'with'
#   Dependency relation: pobj
#   Explanation: object of preposition
#   Children: ['his', 'early', 'business', 'and', 'cofounder', 'wozniak']
# Word: 'and'
#   Head word: 'partner'
#   Dependency relation: cc
#   Explanation: coordinating conjunction
#   Children: []
# Word: 'fellow'
#   Head word: 'cofounder'
#   Dependency relation: amod
#   Explanation: adjectival modifier
#   Children: []
# Word: 'apple'
#   Head word: 'cofounder'
#   Dependency relation: compound
#   Explanation: compound
#   Children: []
# Word: 'cofounder'
#   Head word: 'partner'
#   Dependency relation: conj
#   Explanation: conjunct
#   Children: ['fellow', 'apple']
# Word: 'steve'
#   Head word: 'wozniak'
#   Dependency relation: compound
#   Explanation: compound
#   Children: []
# Word: 'wozniak'
#   Head word: 'partner'
#   Dependency relation: appos
#   Explanation: appositional modifier
#   Children: ['steve']
# Word: '.'
#   Head word: 'was'
#   Dependency relation: punct
#   Explanation: punctuation
#   Children: []
# Word: 'jobs'
#   Head word: 'born'
#   Dependency relation: nsubjpass
#   Explanation: nominal subject (passive)
#   Children: []
# Word: 'was'
#   Head word: 'born'
#   Dependency relation: auxpass
#   Explanation: auxiliary (passive)
#   Children: []
# Word: 'born'
#   Head word: 'born'
#   Dependency relation: ROOT
#   Explanation: root
#   Children: ['jobs', 'was', 'in', 'to', '.']
# Word: 'in'
#   Head word: 'born'
#   Dependency relation: prep
#   Explanation: prepositional modifier
#   Children: ['francisco']
# Word: 'san'
#   Head word: 'francisco'
#   Dependency relation: compound
#   Explanation: compound
#   Children: []
# Word: 'francisco'
#   Head word: 'in'
#   Dependency relation: pobj
#   Explanation: object of preposition
#   Children: ['san']
# Word: 'to'
#   Head word: 'born'
#   Dependency relation: prep
#   Explanation: prepositional modifier
#   Children: ['father']
# Word: 'a'
#   Head word: 'father'
#   Dependency relation: det
#   Explanation: determiner
#   Children: []
# Word: 'syrian'
#   Head word: 'father'
#   Dependency relation: amod
#   Explanation: adjectival modifier
#   Children: []
# Word: 'father'
#   Head word: 'to'
#   Dependency relation: pobj
#   Explanation: object of preposition
#   Children: ['a', 'syrian', 'and', 'mother']
# Word: 'and'
#   Head word: 'father'
#   Dependency relation: cc
#   Explanation: coordinating conjunction
#   Children: []
# Word: 'germanamerican'
#   Head word: 'mother'
#   Dependency relation: amod
#   Explanation: adjectival modifier
#   Children: []
# Word: 'mother'
#   Head word: 'father'
#   Dependency relation: conj
#   Explanation: conjunct
#   Children: ['germanamerican']
# Word: '.'
#   Head word: 'born'
#   Dependency relation: punct
#   Explanation: punctuation
#   Children: []
# Word: 'he'
#   Head word: 'adopted'
#   Dependency relation: nsubjpass
#   Explanation: nominal subject (passive)
#   Children: []
# Word: 'was'
#   Head word: 'adopted'
#   Dependency relation: auxpass
#   Explanation: auxiliary (passive)
#   Children: []
# Word: 'adopted'
#   Head word: 'adopted'
#   Dependency relation: ROOT
#   Explanation: root
#   Children: ['he', 'was', 'after', '.']
# Word: 'shortly'
#   Head word: 'after'
#   Dependency relation: advmod
#   Explanation: adverbial modifier
#   Children: []
# Word: 'after'
#   Head word: 'adopted'
#   Dependency relation: prep
#   Explanation: prepositional modifier
#   Children: ['shortly', 'birth']
# Word: 'his'
#   Head word: 'birth'
#   Dependency relation: poss
#   Explanation: possession modifier
#   Children: []
# Word: 'birth'
#   Head word: 'after'
#   Dependency relation: pobj
#   Explanation: object of preposition
#   Children: ['his']
# Word: '.'
#   Head word: 'adopted'
#   Dependency relation: punct
#   Explanation: punctuation
#   Children: []
# Word: 'jobs'
#   Head word: 'attended'
#   Dependency relation: nsubj
#   Explanation: nominal subject
#   Children: []
# Word: 'attended'
#   Head word: 'attended'
#   Dependency relation: ROOT
#   Explanation: root
#   Children: ['jobs', 'college', 'in', 'before', '.']
# Word: 'reed'
#   Head word: 'college'
#   Dependency relation: compound
#   Explanation: compound
#   Children: []
# Word: 'college'
#   Head word: 'attended'
#   Dependency relation: dobj
#   Explanation: direct object
#   Children: ['reed']
# Word: 'in'
#   Head word: 'attended'
#   Dependency relation: advmod
#   Explanation: adverbial modifier
#   Children: []
# Word: 'before'
#   Head word: 'attended'
#   Dependency relation: prep
#   Explanation: prepositional modifier
#   Children: ['withdrawing']
# Word: 'withdrawing'
#   Head word: 'before'
#   Dependency relation: pcomp
#   Explanation: complement of preposition
#   Children: ['year']
# Word: 'that'
#   Head word: 'year'
#   Dependency relation: det
#   Explanation: determiner
#   Children: []
# Word: 'same'
#   Head word: 'year'
#   Dependency relation: amod
#   Explanation: adjectival modifier
#   Children: []
# Word: 'year'
#   Head word: 'withdrawing'
#   Dependency relation: npadvmod
#   Explanation: noun phrase as adverbial modifier
#   Children: ['that', 'same']
# Word: '.'
#   Head word: 'attended'
#   Dependency relation: punct
#   Explanation: punctuation
#   Children: []
# Word: 'in'
#   Head word: 'traveled'
#   Dependency relation: advmod
#   Explanation: adverbial modifier
#   Children: []
# Word: ','
#   Head word: 'traveled'
#   Dependency relation: punct
#   Explanation: punctuation
#   Children: []
# Word: 'he'
#   Head word: 'traveled'
#   Dependency relation: nsubj
#   Explanation: nominal subject
#   Children: []
# Word: 'traveled'
#   Head word: 'traveled'
#   Dependency relation: ROOT
#   Explanation: root
#   Children: ['in', ',', 'he', 'through', 'seeking', '.']
# Word: 'through'
#   Head word: 'traveled'
#   Dependency relation: prep
#   Explanation: prepositional modifier
#   Children: ['india']
# Word: 'india'
#   Head word: 'through'
#   Dependency relation: pobj
#   Explanation: object of preposition
#   Children: []
# Word: 'seeking'
#   Head word: 'traveled'
#   Dependency relation: advcl
#   Explanation: adverbial clause modifier
#   Children: ['enlightenment', 'before']
# Word: 'enlightenment'
#   Head word: 'seeking'
#   Dependency relation: dobj
#   Explanation: direct object
#   Children: []
# Word: 'before'
#   Head word: 'seeking'
#   Dependency relation: prep
#   Explanation: prepositional modifier
#   Children: ['studying']
# Word: 'later'
#   Head word: 'studying'
#   Dependency relation: advmod
#   Explanation: adverbial modifier
#   Children: []
# Word: 'studying'
#   Head word: 'before'
#   Dependency relation: pcomp
#   Explanation: complement of preposition
#   Children: ['later', 'buddhism']
# Word: 'zen'
#   Head word: 'buddhism'
#   Dependency relation: amod
#   Explanation: adjectival modifier
#   Children: []
# Word: 'buddhism'
#   Head word: 'studying'
#   Dependency relation: dobj
#   Explanation: direct object
#   Children: ['zen']
# Word: '.'
#   Head word: 'traveled'
#   Dependency relation: punct
#   Explanation: punctuation
#   Children: []
# Word: 'he'
#   Head word: 'cofounded'
#   Dependency relation: nsubj
#   Explanation: nominal subject
#   Children: ['and', 'wozniak']
# Word: 'and'
#   Head word: 'he'
#   Dependency relation: cc
#   Explanation: coordinating conjunction
#   Children: []
# Word: 'wozniak'
#   Head word: 'he'
#   Dependency relation: conj
#   Explanation: conjunct
#   Children: []
# Word: 'cofounded'
#   Head word: 'cofounded'
#   Dependency relation: ROOT
#   Explanation: root
#   Children: ['he', 'apple', 'in', 'sell', '.']
# Word: 'apple'
#   Head word: 'cofounded'
#   Dependency relation: dobj
#   Explanation: direct object
#   Children: []
# Word: 'in'
#   Head word: 'cofounded'
#   Dependency relation: prt
#   Explanation: particle
#   Children: []
# Word: 'to'
#   Head word: 'sell'
#   Dependency relation: aux
#   Explanation: auxiliary
#   Children: []
# Word: 'sell'
#   Head word: 'cofounded'
#   Dependency relation: xcomp
#   Explanation: open clausal complement
#   Children: ['to', 'apple', 'computer']
# Word: 'wozniaks'
#   Head word: 'apple'
#   Dependency relation: amod
#   Explanation: adjectival modifier
#   Children: []
# Word: 'apple'
#   Head word: 'sell'
#   Dependency relation: dobj
#   Explanation: direct object
#   Children: ['wozniaks']
# Word: 'i'
#   Head word: 'computer'
#   Dependency relation: nmod
#   Explanation: modifier of nominal
#   Children: []
# Word: 'personal'
#   Head word: 'computer'
#   Dependency relation: amod
#   Explanation: adjectival modifier
#   Children: []
# Word: 'computer'
#   Head word: 'sell'
#   Dependency relation: dobj
#   Explanation: direct object
#   Children: ['i', 'personal']
# Word: '.'
#   Head word: 'cofounded'
#   Dependency relation: punct
#   Explanation: punctuation
#   Children: []
# Word: 'together'
#   Head word: 'gained'
#   Dependency relation: advmod
#   Explanation: adverbial modifier
#   Children: []
# Word: 'the'
#   Head word: 'duo'
#   Dependency relation: det
#   Explanation: determiner
#   Children: []
# Word: 'duo'
#   Head word: 'gained'
#   Dependency relation: nsubj
#   Explanation: nominal subject
#   Children: ['the']
# Word: 'gained'
#   Head word: 'gained'
#   Dependency relation: ROOT
#   Explanation: root
#   Children: ['together', 'duo', 'fame', 'later', 'with', '.']
# Word: 'fame'
#   Head word: 'gained'
#   Dependency relation: dobj
#   Explanation: direct object
#   Children: ['and', 'wealth']
# Word: 'and'
#   Head word: 'fame'
#   Dependency relation: cc
#   Explanation: coordinating conjunction
#   Children: []
# Word: 'wealth'
#   Head word: 'fame'
#   Dependency relation: conj
#   Explanation: conjunct
#   Children: []
# Word: 'a'
#   Head word: 'year'
#   Dependency relation: det
#   Explanation: determiner
#   Children: []
# Word: 'year'
#   Head word: 'later'
#   Dependency relation: npadvmod
#   Explanation: noun phrase as adverbial modifier
#   Children: ['a']
# Word: 'later'
#   Head word: 'gained'
#   Dependency relation: advmod
#   Explanation: adverbial modifier
#   Children: ['year']
# Word: 'with'
#   Head word: 'gained'
#   Dependency relation: prep
#   Explanation: prepositional modifier
#   Children: ['production']
# Word: 'production'
#   Head word: 'with'
#   Dependency relation: pobj
#   Explanation: object of preposition
#   Children: ['and', 'sale', 'of']
# Word: 'and'
#   Head word: 'production'
#   Dependency relation: cc
#   Explanation: coordinating conjunction
#   Children: []
# Word: 'sale'
#   Head word: 'production'
#   Dependency relation: conj
#   Explanation: conjunct
#   Children: []
# Word: 'of'
#   Head word: 'production'
#   Dependency relation: prep
#   Explanation: prepositional modifier
#   Children: ['ii']
# Word: 'the'
#   Head word: 'ii'
#   Dependency relation: det
#   Explanation: determiner
#   Children: []
# Word: 'apple'
#   Head word: 'ii'
#   Dependency relation: compound
#   Explanation: compound
#   Children: []
# Word: 'ii'
#   Head word: 'of'
#   Dependency relation: pobj
#   Explanation: object of preposition
#   Children: ['the', 'apple', ',', 'one']
# Word: ','
#   Head word: 'ii'
#   Dependency relation: punct
#   Explanation: punctuation
#   Children: []
# Word: 'one'
#   Head word: 'ii'
#   Dependency relation: appos
#   Explanation: appositional modifier
#   Children: ['of']
# Word: 'of'
#   Head word: 'one'
#   Dependency relation: prep
#   Explanation: prepositional modifier
#   Children: ['microcomputers']
# Word: 'the'
#   Head word: 'microcomputers'
#   Dependency relation: det
#   Explanation: determiner
#   Children: []
# Word: 'first'
#   Head word: 'microcomputers'
#   Dependency relation: amod
#   Explanation: adjectival modifier
#   Children: []
# Word: 'highly'
#   Head word: 'successful'
#   Dependency relation: advmod
#   Explanation: adverbial modifier
#   Children: []
# Word: 'successful'
#   Head word: 'microcomputers'
#   Dependency relation: amod
#   Explanation: adjectival modifier
#   Children: ['highly']
# Word: 'massproduced'
#   Head word: 'microcomputers'
#   Dependency relation: amod
#   Explanation: adjectival modifier
#   Children: []
# Word: 'microcomputers'
#   Head word: 'of'
#   Dependency relation: pobj
#   Explanation: object of preposition
#   Children: ['the', 'first', 'successful', 'massproduced']
# Word: '.'
#   Head word: 'gained'
#   Dependency relation: punct
#   Explanation: punctuation
#   Children: []
# Word: 'jobs'
#   Head word: 'saw'
#   Dependency relation: nsubj
#   Explanation: nominal subject
#   Children: []
# Word: 'saw'
#   Head word: 'saw'
#   Dependency relation: ROOT
#   Explanation: root
#   Children: ['jobs', 'potential', 'in', 'was', '.']
# Word: 'the'
#   Head word: 'potential'
#   Dependency relation: det
#   Explanation: determiner
#   Children: []
# Word: 'commercial'
#   Head word: 'potential'
#   Dependency relation: amod
#   Explanation: adjectival modifier
#   Children: []
# Word: 'potential'
#   Head word: 'saw'
#   Dependency relation: dobj
#   Explanation: direct object
#   Children: ['the', 'commercial', 'of']
# Word: 'of'
#   Head word: 'potential'
#   Dependency relation: prep
#   Explanation: prepositional modifier
#   Children: ['alto']
# Word: 'the'
#   Head word: 'alto'
#   Dependency relation: det
#   Explanation: determiner
#   Children: []
# Word: 'xerox'
#   Head word: 'alto'
#   Dependency relation: compound
#   Explanation: compound
#   Children: []
# Word: 'alto'
#   Head word: 'of'
#   Dependency relation: pobj
#   Explanation: object of preposition
#   Children: ['the', 'xerox']
# Word: 'in'
#   Head word: 'saw'
#   Dependency relation: prep
#   Explanation: prepositional modifier
#   Children: [',']
# Word: ','
#   Head word: 'in'
#   Dependency relation: punct
#   Explanation: punctuation
#   Children: []
# Word: 'which'
#   Head word: 'was'
#   Dependency relation: nsubj
#   Explanation: nominal subject
#   Children: []
# Word: 'was'
#   Head word: 'saw'
#   Dependency relation: ccomp
#   Explanation: clausal complement
#   Children: ['which', 'mousedriven', 'and', 'had']
# Word: 'mousedriven'
#   Head word: 'was'
#   Dependency relation: acomp
#   Explanation: adjectival complement
#   Children: []
# Word: 'and'
#   Head word: 'was'
#   Dependency relation: cc
#   Explanation: coordinating conjunction
#   Children: []
# Word: 'had'
#   Head word: 'was'
#   Dependency relation: conj
#   Explanation: conjunct
#   Children: ['gui']
# Word: 'a'
#   Head word: 'gui'
#   Dependency relation: det
#   Explanation: determiner
#   Children: []
# Word: 'graphical'
#   Head word: 'user'
#   Dependency relation: amod
#   Explanation: adjectival modifier
#   Children: []
# Word: 'user'
#   Head word: 'gui'
#   Dependency relation: compound
#   Explanation: compound
#   Children: ['graphical']
# Word: 'interface'
#   Head word: 'gui'
#   Dependency relation: compound
#   Explanation: compound
#   Children: []
# Word: 'gui'
#   Head word: 'had'
#   Dependency relation: dobj
#   Explanation: direct object
#   Children: ['a', 'user', 'interface']
# Word: '.'
#   Head word: 'saw'
#   Dependency relation: punct
#   Explanation: punctuation
#   Children: []
# Word: 'this'
#   Head word: 'led'
#   Dependency relation: nsubj
#   Explanation: nominal subject
#   Children: []
# Word: 'led'
#   Head word: 'led'
#   Dependency relation: ROOT
#   Explanation: root
#   Children: ['this', 'to', ',', 'followed', '.']
# Word: 'to'
#   Head word: 'led'
#   Dependency relation: prep
#   Explanation: prepositional modifier
#   Children: ['development']
# Word: 'the'
#   Head word: 'development'
#   Dependency relation: det
#   Explanation: determiner
#   Children: []
# Word: 'development'
#   Head word: 'to'
#   Dependency relation: pobj
#   Explanation: object of preposition
#   Children: ['the', 'of', 'in']
# Word: 'of'
#   Head word: 'development'
#   Dependency relation: prep
#   Explanation: prepositional modifier
#   Children: ['lisa']
# Word: 'the'
#   Head word: 'lisa'
#   Dependency relation: det
#   Explanation: determiner
#   Children: []
# Word: 'unsuccessful'
#   Head word: 'lisa'
#   Dependency relation: amod
#   Explanation: adjectival modifier
#   Children: []
# Word: 'apple'
#   Head word: 'lisa'
#   Dependency relation: compound
#   Explanation: compound
#   Children: []
# Word: 'lisa'
#   Head word: 'of'
#   Dependency relation: pobj
#   Explanation: object of preposition
#   Children: ['the', 'unsuccessful', 'apple']
# Word: 'in'
#   Head word: 'development'
#   Dependency relation: advmod
#   Explanation: adverbial modifier
#   Children: []
# Word: ','
#   Head word: 'led'
#   Dependency relation: punct
#   Explanation: punctuation
#   Children: []
# Word: 'followed'
#   Head word: 'led'
#   Dependency relation: advcl
#   Explanation: adverbial clause modifier
#   Children: ['by', ',', 'computer']
# Word: 'by'
#   Head word: 'followed'
#   Dependency relation: agent
#   Explanation: agent
#   Children: ['macintosh']
# Word: 'the'
#   Head word: 'macintosh'
#   Dependency relation: det
#   Explanation: determiner
#   Children: []
# Word: 'breakthrough'
#   Head word: 'macintosh'
#   Dependency relation: compound
#   Explanation: compound
#   Children: []
# Word: 'macintosh'
#   Head word: 'by'
#   Dependency relation: pobj
#   Explanation: object of preposition
#   Children: ['the', 'breakthrough', 'in']
# Word: 'in'
#   Head word: 'macintosh'
#   Dependency relation: advmod
#   Explanation: adverbial modifier
#   Children: []
# Word: ','
#   Head word: 'followed'
#   Dependency relation: punct
#   Explanation: punctuation
#   Children: []
# Word: 'the'
#   Head word: 'computer'
#   Dependency relation: det
#   Explanation: determiner
#   Children: []
# Word: 'first'
#   Head word: 'computer'
#   Dependency relation: amod
#   Explanation: adjectival modifier
#   Children: []
# Word: 'massproduced'
#   Head word: 'computer'
#   Dependency relation: amod
#   Explanation: adjectival modifier
#   Children: []
# Word: 'computer'
#   Head word: 'followed'
#   Dependency relation: dobj
#   Explanation: direct object
#   Children: ['the', 'first', 'massproduced', 'with']
# Word: 'with'
#   Head word: 'computer'
#   Dependency relation: prep
#   Explanation: prepositional modifier
#   Children: ['gui']
# Word: 'a'
#   Head word: 'gui'
#   Dependency relation: det
#   Explanation: determiner
#   Children: []
# Word: 'gui'
#   Head word: 'with'
#   Dependency relation: pobj
#   Explanation: object of preposition
#   Children: ['a']
# Word: '.'
#   Head word: 'led'
#   Dependency relation: punct
#   Explanation: punctuation
#   Children: []
# Word: 'the'
#   Head word: 'macintosh'
#   Dependency relation: det
#   Explanation: determiner
#   Children: []
# Word: 'macintosh'
#   Head word: 'introduced'
#   Dependency relation: nsubj
#   Explanation: nominal subject
#   Children: ['the']
# Word: 'introduced'
#   Head word: 'introduced'
#   Dependency relation: ROOT
#   Explanation: root
#   Children: ['macintosh', 'industry', 'in', 'with', '.']
# Word: 'the'
#   Head word: 'industry'
#   Dependency relation: det
#   Explanation: determiner
#   Children: []
# Word: 'desktop'
#   Head word: 'publishing'
#   Dependency relation: compound
#   Explanation: compound
#   Children: []
# Word: 'publishing'
#   Head word: 'industry'
#   Dependency relation: compound
#   Explanation: compound
#   Children: ['desktop']
# Word: 'industry'
#   Head word: 'introduced'
#   Dependency relation: dobj
#   Explanation: direct object
#   Children: ['the', 'publishing']
# Word: 'in'
#   Head word: 'introduced'
#   Dependency relation: prep
#   Explanation: prepositional modifier
#   Children: []
# Word: 'with'
#   Head word: 'introduced'
#   Dependency relation: prep
#   Explanation: prepositional modifier
#   Children: ['addition']
# Word: 'the'
#   Head word: 'addition'
#   Dependency relation: det
#   Explanation: determiner
#   Children: []
# Word: 'addition'
#   Head word: 'with'
#   Dependency relation: pobj
#   Explanation: object of preposition
#   Children: ['the', 'of']
# Word: 'of'
#   Head word: 'addition'
#   Dependency relation: prep
#   Explanation: prepositional modifier
#   Children: ['laserwriter']
# Word: 'the'
#   Head word: 'laserwriter'
#   Dependency relation: det
#   Explanation: determiner
#   Children: []
# Word: 'apple'
#   Head word: 'laserwriter'
#   Dependency relation: compound
#   Explanation: compound
#   Children: []
# Word: 'laserwriter'
#   Head word: 'of'
#   Dependency relation: pobj
#   Explanation: object of preposition
#   Children: ['the', 'apple', ',', 'printer']
# Word: ','
#   Head word: 'laserwriter'
#   Dependency relation: punct
#   Explanation: punctuation
#   Children: []
# Word: 'the'
#   Head word: 'printer'
#   Dependency relation: det
#   Explanation: determiner
#   Children: []
# Word: 'first'
#   Head word: 'printer'
#   Dependency relation: amod
#   Explanation: adjectival modifier
#   Children: []
# Word: 'laser'
#   Head word: 'printer'
#   Dependency relation: compound
#   Explanation: compound
#   Children: []
# Word: 'printer'
#   Head word: 'laserwriter'
#   Dependency relation: appos
#   Explanation: appositional modifier
#   Children: ['the', 'first', 'laser', 'feature']
# Word: 'to'
#   Head word: 'feature'
#   Dependency relation: aux
#   Explanation: auxiliary
#   Children: []
# Word: 'feature'
#   Head word: 'printer'
#   Dependency relation: relcl
#   Explanation: relative clause modifier
#   Children: ['to', 'graphics']
# Word: 'vector'
#   Head word: 'graphics'
#   Dependency relation: compound
#   Explanation: compound
#   Children: []
# Word: 'graphics'
#   Head word: 'feature'
#   Dependency relation: dobj
#   Explanation: direct object
#   Children: ['vector']
# Word: '.'
#   Head word: 'introduced'
#   Dependency relation: punct
#   Explanation: punctuation
#   Children: []
# Word: 'in'
#   Head word: 'forced'
#   Dependency relation: prep
#   Explanation: prepositional modifier
#   Children: []
# Word: ','
#   Head word: 'forced'
#   Dependency relation: punct
#   Explanation: punctuation
#   Children: []
# Word: 'jobs'
#   Head word: 'forced'
#   Dependency relation: nsubjpass
#   Explanation: nominal subject (passive)
#   Children: []
# Word: 'was'
#   Head word: 'forced'
#   Dependency relation: auxpass
#   Explanation: auxiliary (passive)
#   Children: []
# Word: 'forced'
#   Head word: 'sculley'
#   Dependency relation: ccomp
#   Explanation: clausal complement
#   Children: ['in', ',', 'jobs', 'was', 'out', 'after']
# Word: 'out'
#   Head word: 'forced'
#   Dependency relation: prep
#   Explanation: prepositional modifier
#   Children: ['of']
# Word: 'of'
#   Head word: 'out'
#   Dependency relation: prep
#   Explanation: prepositional modifier
#   Children: ['apple']
# Word: 'apple'
#   Head word: 'of'
#   Dependency relation: pobj
#   Explanation: object of preposition
#   Children: []
# Word: 'after'
#   Head word: 'forced'
#   Dependency relation: prep
#   Explanation: prepositional modifier
#   Children: ['struggle']
# Word: 'a'
#   Head word: 'struggle'
#   Dependency relation: det
#   Explanation: determiner
#   Children: []
# Word: 'long'
#   Head word: 'struggle'
#   Dependency relation: amod
#   Explanation: adjectival modifier
#   Children: []
# Word: 'power'
#   Head word: 'struggle'
#   Dependency relation: compound
#   Explanation: compound
#   Children: []
# Word: 'struggle'
#   Head word: 'after'
#   Dependency relation: pobj
#   Explanation: object of preposition
#   Children: ['a', 'long', 'power', 'with']
# Word: 'with'
#   Head word: 'struggle'
#   Dependency relation: prep
#   Explanation: prepositional modifier
#   Children: ['board']
# Word: 'the'
#   Head word: 'board'
#   Dependency relation: det
#   Explanation: determiner
#   Children: []
# Word: 'companys'
#   Head word: 'board'
#   Dependency relation: compound
#   Explanation: compound
#   Children: []
# Word: 'board'
#   Head word: 'with'
#   Dependency relation: pobj
#   Explanation: object of preposition
#   Children: ['the', 'companys', 'and', 'thenceo']
# Word: 'and'
#   Head word: 'board'
#   Dependency relation: cc
#   Explanation: coordinating conjunction
#   Children: []
# Word: 'its'
#   Head word: 'thenceo'
#   Dependency relation: poss
#   Explanation: possession modifier
#   Children: []
# Word: 'thenceo'
#   Head word: 'board'
#   Dependency relation: conj
#   Explanation: conjunct
#   Children: ['its']
# Word: ','
#   Head word: 'sculley'
#   Dependency relation: punct
#   Explanation: punctuation
#   Children: []
# Word: 'john'
#   Head word: 'sculley'
#   Dependency relation: compound
#   Explanation: compound
#   Children: []
# Word: 'sculley'
#   Head word: 'sculley'
#   Dependency relation: ROOT
#   Explanation: root
#   Children: ['forced', ',', 'john', '.']
# Word: '.'
#   Head word: 'sculley'
#   Dependency relation: punct
#   Explanation: punctuation
#   Children: []
# Word: 'that'
#   Head word: 'year'
#   Dependency relation: det
#   Explanation: determiner
#   Children: []
# Word: 'same'
#   Head word: 'year'
#   Dependency relation: amod
#   Explanation: adjectival modifier
#   Children: []
# Word: 'year'
#   Head word: 'took'
#   Dependency relation: npadvmod
#   Explanation: noun phrase as adverbial modifier
#   Children: ['that', 'same']
# Word: ','
#   Head word: 'took'
#   Dependency relation: punct
#   Explanation: punctuation
#   Children: []
# Word: 'jobs'
#   Head word: 'took'
#   Dependency relation: nsubj
#   Explanation: nominal subject
#   Children: []
# Word: 'took'
#   Head word: 'took'
#   Dependency relation: ROOT
#   Explanation: root
#   Children: ['year', ',', 'jobs', 'employees', 'with', 'found', ',', 'company', '.']
# Word: 'a'
#   Head word: 'few'
#   Dependency relation: quantmod
#   Explanation: modifier of quantifier
#   Children: []
# Word: 'few'
#   Head word: 'employees'
#   Dependency relation: amod
#   Explanation: adjectival modifier
#   Children: ['a']
# Word: 'apple'
#   Head word: 'employees'
#   Dependency relation: compound
#   Explanation: compound
#   Children: []
# Word: 'employees'
#   Head word: 'took'
#   Dependency relation: dobj
#   Explanation: direct object
#   Children: ['few', 'apple']
# Word: 'with'
#   Head word: 'took'
#   Dependency relation: prep
#   Explanation: prepositional modifier
#   Children: ['him']
# Word: 'him'
#   Head word: 'with'
#   Dependency relation: pobj
#   Explanation: object of preposition
#   Children: []
# Word: 'to'
#   Head word: 'found'
#   Dependency relation: aux
#   Explanation: auxiliary
#   Children: []
# Word: 'found'
#   Head word: 'took'
#   Dependency relation: advcl
#   Explanation: adverbial clause modifier
#   Children: ['to', 'next']
# Word: 'next'
#   Head word: 'found'
#   Dependency relation: advmod
#   Explanation: adverbial modifier
#   Children: []
# Word: ','
#   Head word: 'took'
#   Dependency relation: punct
#   Explanation: punctuation
#   Children: []
# Word: 'a'
#   Head word: 'company'
#   Dependency relation: det
#   Explanation: determiner
#   Children: []
# Word: 'computer'
#   Head word: 'platform'
#   Dependency relation: compound
#   Explanation: compound
#   Children: []
# Word: 'platform'
#   Head word: 'development'
#   Dependency relation: compound
#   Explanation: compound
#   Children: ['computer']
# Word: 'development'
#   Head word: 'company'
#   Dependency relation: compound
#   Explanation: compound
#   Children: ['platform']
# Word: 'company'
#   Head word: 'took'
#   Dependency relation: dobj
#   Explanation: direct object
#   Children: ['a', 'development', 'specialized']
# Word: 'that'
#   Head word: 'specialized'
#   Dependency relation: nsubj
#   Explanation: nominal subject
#   Children: []
# Word: 'specialized'
#   Head word: 'company'
#   Dependency relation: relcl
#   Explanation: relative clause modifier
#   Children: ['that', 'in']
# Word: 'in'
#   Head word: 'specialized'
#   Dependency relation: prep
#   Explanation: prepositional modifier
#   Children: ['computers']
# Word: 'computers'
#   Head word: 'in'
#   Dependency relation: pobj
#   Explanation: object of preposition
#   Children: ['for']
# Word: 'for'
#   Head word: 'computers'
#   Dependency relation: prep
#   Explanation: prepositional modifier
#   Children: ['markets']
# Word: 'highereducation'
#   Head word: 'markets'
#   Dependency relation: nmod
#   Explanation: modifier of nominal
#   Children: ['and', 'business']
# Word: 'and'
#   Head word: 'highereducation'
#   Dependency relation: cc
#   Explanation: coordinating conjunction
#   Children: []
# Word: 'business'
#   Head word: 'highereducation'
#   Dependency relation: conj
#   Explanation: conjunct
#   Children: []
# Word: 'markets'
#   Head word: 'for'
#   Dependency relation: pobj
#   Explanation: object of preposition
#   Children: ['highereducation']
# Word: '.'
#   Head word: 'took'
#   Dependency relation: punct
#   Explanation: punctuation
#   Children: []
# Word: 'in'
#   Head word: 'helped'
#   Dependency relation: prep
#   Explanation: prepositional modifier
#   Children: ['addition']
# Word: 'addition'
#   Head word: 'in'
#   Dependency relation: pobj
#   Explanation: object of preposition
#   Children: []
# Word: ','
#   Head word: 'helped'
#   Dependency relation: punct
#   Explanation: punctuation
#   Children: []
# Word: 'he'
#   Head word: 'helped'
#   Dependency relation: nsubj
#   Explanation: nominal subject
#   Children: []
# Word: 'helped'
#   Head word: 'helped'
#   Dependency relation: ROOT
#   Explanation: root
#   Children: ['in', ',', 'he', 'develop', '.']
# Word: 'to'
#   Head word: 'develop'
#   Dependency relation: aux
#   Explanation: auxiliary
#   Children: []
# Word: 'develop'
#   Head word: 'helped'
#   Dependency relation: xcomp
#   Explanation: open clausal complement
#   Children: ['to', 'industry', 'funded']
# Word: 'the'
#   Head word: 'industry'
#   Dependency relation: det
#   Explanation: determiner
#   Children: []
# Word: 'visual'
#   Head word: 'effects'
#   Dependency relation: amod
#   Explanation: adjectival modifier
#   Children: []
# Word: 'effects'
#   Head word: 'industry'
#   Dependency relation: compound
#   Explanation: compound
#   Children: ['visual']
# Word: 'industry'
#   Head word: 'develop'
#   Dependency relation: dobj
#   Explanation: direct object
#   Children: ['the', 'effects']
# Word: 'when'
#   Head word: 'funded'
#   Dependency relation: advmod
#   Explanation: adverbial modifier
#   Children: []
# Word: 'he'
#   Head word: 'funded'
#   Dependency relation: nsubj
#   Explanation: nominal subject
#   Children: []
# Word: 'funded'
#   Head word: 'develop'
#   Dependency relation: advcl
#   Explanation: adverbial clause modifier
#   Children: ['when', 'he', 'division', 'in']
# Word: 'the'
#   Head word: 'division'
#   Dependency relation: det
#   Explanation: determiner
#   Children: []
# Word: 'computer'
#   Head word: 'graphics'
#   Dependency relation: compound
#   Explanation: compound
#   Children: []
# Word: 'graphics'
#   Head word: 'division'
#   Dependency relation: compound
#   Explanation: compound
#   Children: ['computer']
# Word: 'division'
#   Head word: 'funded'
#   Dependency relation: dobj
#   Explanation: direct object
#   Children: ['the', 'graphics', 'of']
# Word: 'of'
#   Head word: 'division'
#   Dependency relation: prep
#   Explanation: prepositional modifier
#   Children: ['lucasfilm']
# Word: 'george'
#   Head word: 'lucass'
#   Dependency relation: compound
#   Explanation: compound
#   Children: []
# Word: 'lucass'
#   Head word: 'lucasfilm'
#   Dependency relation: compound
#   Explanation: compound
#   Children: ['george']
# Word: 'lucasfilm'
#   Head word: 'of'
#   Dependency relation: pobj
#   Explanation: object of preposition
#   Children: ['lucass']
# Word: 'in'
#   Head word: 'funded'
#   Dependency relation: prep
#   Explanation: prepositional modifier
#   Children: []
# Word: '.'
#   Head word: 'helped'
#   Dependency relation: punct
#   Explanation: punctuation
#   Children: []
# Word: 'the'
#   Head word: 'company'
#   Dependency relation: det
#   Explanation: determiner
#   Children: []
# Word: 'new'
#   Head word: 'company'
#   Dependency relation: amod
#   Explanation: adjectival modifier
#   Children: []
# Word: 'company'
#   Head word: 'was'
#   Dependency relation: nsubj
#   Explanation: nominal subject
#   Children: ['the', 'new']
# Word: 'was'
#   Head word: 'was'
#   Dependency relation: ROOT
#   Explanation: root
#   Children: ['company', 'pixar', '.']
# Word: 'pixar'
#   Head word: 'was'
#   Dependency relation: attr
#   Explanation: attribute
#   Children: [',', 'produced']
# Word: ','
#   Head word: 'pixar'
#   Dependency relation: punct
#   Explanation: punctuation
#   Children: []
# Word: 'which'
#   Head word: 'produced'
#   Dependency relation: nsubj
#   Explanation: nominal subject
#   Children: []
# Word: 'produced'
#   Head word: 'pixar'
#   Dependency relation: relcl
#   Explanation: relative clause modifier
#   Children: ['which', 'story', 'and', 'went']
# Word: 'the'
#   Head word: 'story'
#   Dependency relation: det
#   Explanation: determiner
#   Children: []
# Word: 'first'
#   Head word: 'story'
#   Dependency relation: amod
#   Explanation: adjectival modifier
#   Children: []
# Word: 'd'
#   Head word: 'story'
#   Dependency relation: nmod
#   Explanation: modifier of nominal
#   Children: []
# Word: 'computeranimated'
#   Head word: 'story'
#   Dependency relation: amod
#   Explanation: adjectival modifier
#   Children: []
# Word: 'feature'
#   Head word: 'toy'
#   Dependency relation: compound
#   Explanation: compound
#   Children: []
# Word: 'film'
#   Head word: 'toy'
#   Dependency relation: compound
#   Explanation: compound
#   Children: []
# Word: 'toy'
#   Head word: 'story'
#   Dependency relation: compound
#   Explanation: compound
#   Children: ['feature', 'film']
# Word: 'story'
#   Head word: 'produced'
#   Dependency relation: dobj
#   Explanation: direct object
#   Children: ['the', 'first', 'd', 'computeranimated', 'toy', ' ']
# Word: ' '
#   Head word: 'story'
#   Dependency relation: dep
#   Explanation: unclassified dependent
#   Children: []
# Word: 'and'
#   Head word: 'produced'
#   Dependency relation: cc
#   Explanation: coordinating conjunction
#   Children: []
# Word: 'went'
#   Head word: 'produced'
#   Dependency relation: conj
#   Explanation: conjunct
#   Children: ['on', 'become', ',', 'producing']
# Word: 'on'
#   Head word: 'went'
#   Dependency relation: prt
#   Explanation: particle
#   Children: []
# Word: 'to'
#   Head word: 'become'
#   Dependency relation: aux
#   Explanation: auxiliary
#   Children: []
# Word: 'become'
#   Head word: 'went'
#   Dependency relation: advcl
#   Explanation: adverbial clause modifier
#   Children: ['to', 'studio']
# Word: 'a'
#   Head word: 'studio'
#   Dependency relation: det
#   Explanation: determiner
#   Children: []
# Word: 'major'
#   Head word: 'studio'
#   Dependency relation: amod
#   Explanation: adjectival modifier
#   Children: []
# Word: 'animation'
#   Head word: 'studio'
#   Dependency relation: compound
#   Explanation: compound
#   Children: []
# Word: 'studio'
#   Head word: 'become'
#   Dependency relation: attr
#   Explanation: attribute
#   Children: ['a', 'major', 'animation']
# Word: ','
#   Head word: 'went'
#   Dependency relation: punct
#   Explanation: punctuation
#   Children: []
# Word: 'producing'
#   Head word: 'went'
#   Dependency relation: advcl
#   Explanation: adverbial clause modifier
#   Children: ['over', 'since']
# Word: 'over'
#   Head word: 'producing'
#   Dependency relation: prep
#   Explanation: prepositional modifier
#   Children: ['films']
# Word: 'films'
#   Head word: 'over'
#   Dependency relation: pobj
#   Explanation: object of preposition
#   Children: []
# Word: 'since'
#   Head word: 'producing'
#   Dependency relation: advmod
#   Explanation: adverbial modifier
#   Children: []
# Word: '.'
#   Head word: 'was'
#   Dependency relation: punct
#   Explanation: punctuation
#   Children: []
# Word: 'in'
#   Head word: 'returned'
#   Dependency relation: prep
#   Explanation: prepositional modifier
#   Children: []
# Word: ','
#   Head word: 'returned'
#   Dependency relation: punct
#   Explanation: punctuation
#   Children: []
# Word: 'jobs'
#   Head word: 'returned'
#   Dependency relation: nsubj
#   Explanation: nominal subject
#   Children: []
# Word: 'returned'
#   Head word: 'returned'
#   Dependency relation: ROOT
#   Explanation: root
#   Children: ['in', ',', 'jobs', 'to', 'as', 'after', '.']
# Word: 'to'
#   Head word: 'returned'
#   Dependency relation: prep
#   Explanation: prepositional modifier
#   Children: ['apple']
# Word: 'apple'
#   Head word: 'to'
#   Dependency relation: pobj
#   Explanation: object of preposition
#   Children: []
# Word: 'as'
#   Head word: 'returned'
#   Dependency relation: prep
#   Explanation: prepositional modifier
#   Children: ['ceo']
# Word: 'ceo'
#   Head word: 'as'
#   Dependency relation: pobj
#   Explanation: object of preposition
#   Children: []
# Word: 'after'
#   Head word: 'returned'
#   Dependency relation: prep
#   Explanation: prepositional modifier
#   Children: ['acquisition']
# Word: 'the'
#   Head word: 'acquisition'
#   Dependency relation: det
#   Explanation: determiner
#   Children: []
# Word: 'companys'
#   Head word: 'acquisition'
#   Dependency relation: compound
#   Explanation: compound
#   Children: []
# Word: 'acquisition'
#   Head word: 'after'
#   Dependency relation: pobj
#   Explanation: object of preposition
#   Children: ['the', 'companys', 'of']
# Word: 'of'
#   Head word: 'acquisition'
#   Dependency relation: prep
#   Explanation: prepositional modifier
#   Children: ['next']
# Word: 'next'
#   Head word: 'of'
#   Dependency relation: pobj
#   Explanation: object of preposition
#   Children: []
# Word: '.'
#   Head word: 'returned'
#   Dependency relation: punct
#   Explanation: punctuation
#   Children: []
# Word: 'he'
#   Head word: 'was'
#   Dependency relation: nsubj
#   Explanation: nominal subject
#   Children: []
# Word: 'was'
#   Head word: 'was'
#   Dependency relation: ROOT
#   Explanation: root
#   Children: ['he', 'responsible', '.']
# Word: 'largely'
#   Head word: 'responsible'
#   Dependency relation: advmod
#   Explanation: adverbial modifier
#   Children: []
# Word: 'responsible'
#   Head word: 'was'
#   Dependency relation: acomp
#   Explanation: adjectival complement
#   Children: ['largely', 'for']
# Word: 'for'
#   Head word: 'responsible'
#   Dependency relation: prep
#   Explanation: prepositional modifier
#   Children: ['reviving']
# Word: 'reviving'
#   Head word: 'for'
#   Dependency relation: pcomp
#   Explanation: complement of preposition
#   Children: ['apple']
# Word: 'apple'
#   Head word: 'reviving'
#   Dependency relation: dobj
#   Explanation: direct object
#   Children: [',', 'was']
# Word: ','
#   Head word: 'apple'
#   Dependency relation: punct
#   Explanation: punctuation
#   Children: []
# Word: 'which'
#   Head word: 'was'
#   Dependency relation: nsubj
#   Explanation: nominal subject
#   Children: []
# Word: 'was'
#   Head word: 'apple'
#   Dependency relation: relcl
#   Explanation: relative clause modifier
#   Children: ['which', 'on']
# Word: 'on'
#   Head word: 'was'
#   Dependency relation: prep
#   Explanation: prepositional modifier
#   Children: ['verge']
# Word: 'the'
#   Head word: 'verge'
#   Dependency relation: det
#   Explanation: determiner
#   Children: []
# Word: 'verge'
#   Head word: 'on'
#   Dependency relation: pobj
#   Explanation: object of preposition
#   Children: ['the', 'of']
# Word: 'of'
#   Head word: 'verge'
#   Dependency relation: prep
#   Explanation: prepositional modifier
#   Children: ['bankruptcy']
# Word: 'bankruptcy'
#   Head word: 'of'
#   Dependency relation: pobj
#   Explanation: object of preposition
#   Children: []
# Word: '.'
#   Head word: 'was'
#   Dependency relation: punct
#   Explanation: punctuation
#   Children: []
# Word: 'he'
#   Head word: 'worked'
#   Dependency relation: nsubj
#   Explanation: nominal subject
#   Children: []
# Word: 'worked'
#   Head word: 'worked'
#   Dependency relation: ROOT
#   Explanation: root
#   Children: ['he', 'closely', 'with', 've', '.']
# Word: 'closely'
#   Head word: 'worked'
#   Dependency relation: advmod
#   Explanation: adverbial modifier
#   Children: []
# Word: 'with'
#   Head word: 'worked'
#   Dependency relation: prep
#   Explanation: prepositional modifier
#   Children: ['jony']
# Word: 'british'
#   Head word: 'designer'
#   Dependency relation: amod
#   Explanation: adjectival modifier
#   Children: []
# Word: 'designer'
#   Head word: 'jony'
#   Dependency relation: compound
#   Explanation: compound
#   Children: ['british']
# Word: 'jony'
#   Head word: 'with'
#   Dependency relation: pobj
#   Explanation: object of preposition
#   Children: ['designer']
# Word: 'i'
#   Head word: 've'
#   Dependency relation: nsubj
#   Explanation: nominal subject
#   Children: []
# Word: 've'
#   Head word: 'worked'
#   Dependency relation: conj
#   Explanation: conjunct
#   Children: ['i', 'develop']
# Word: 'to'
#   Head word: 'develop'
#   Dependency relation: aux
#   Explanation: auxiliary
#   Children: []
# Word: 'develop'
#   Head word: 've'
#   Dependency relation: xcomp
#   Explanation: open clausal complement
#   Children: ['to', 'line', ',', 'beginning']
# Word: 'a'
#   Head word: 'line'
#   Dependency relation: det
#   Explanation: determiner
#   Children: []
# Word: 'line'
#   Head word: 'develop'
#   Dependency relation: dobj
#   Explanation: direct object
#   Children: ['a', 'of']
# Word: 'of'
#   Head word: 'line'
#   Dependency relation: prep
#   Explanation: prepositional modifier
#   Children: ['products']
# Word: 'products'
#   Head word: 'of'
#   Dependency relation: pobj
#   Explanation: object of preposition
#   Children: ['had']
# Word: 'that'
#   Head word: 'had'
#   Dependency relation: nsubj
#   Explanation: nominal subject
#   Children: []
# Word: 'had'
#   Head word: 'products'
#   Dependency relation: relcl
#   Explanation: relative clause modifier
#   Children: ['that', 'ramifications']
# Word: 'larger'
#   Head word: 'ramifications'
#   Dependency relation: amod
#   Explanation: adjectival modifier
#   Children: []
# Word: 'cultural'
#   Head word: 'ramifications'
#   Dependency relation: amod
#   Explanation: adjectival modifier
#   Children: []
# Word: 'ramifications'
#   Head word: 'had'
#   Dependency relation: dobj
#   Explanation: direct object
#   Children: ['larger', 'cultural']
# Word: ','
#   Head word: 'develop'
#   Dependency relation: punct
#   Explanation: punctuation
#   Children: []
# Word: 'beginning'
#   Head word: 'develop'
#   Dependency relation: advcl
#   Explanation: adverbial clause modifier
#   Children: ['with', 'and', 'leading']
# Word: 'with'
#   Head word: 'beginning'
#   Dependency relation: prep
#   Explanation: prepositional modifier
#   Children: ['campaign']
# Word: 'the'
#   Head word: 'campaign'
#   Dependency relation: det
#   Explanation: determiner
#   Children: []
# Word: 'think'
#   Head word: 'campaign'
#   Dependency relation: amod
#   Explanation: adjectival modifier
#   Children: []
# Word: 'different'
#   Head word: 'campaign'
#   Dependency relation: amod
#   Explanation: adjectival modifier
#   Children: []
# Word: 'advertising'
#   Head word: 'campaign'
#   Dependency relation: compound
#   Explanation: compound
#   Children: []
# Word: 'campaign'
#   Head word: 'with'
#   Dependency relation: pobj
#   Explanation: object of preposition
#   Children: ['the', 'think', 'different', 'advertising']
# Word: 'and'
#   Head word: 'beginning'
#   Dependency relation: cc
#   Explanation: coordinating conjunction
#   Children: []
# Word: 'leading'
#   Head word: 'beginning'
#   Dependency relation: conj
#   Explanation: conjunct
#   Children: ['to', ',', 'ios']
# Word: 'to'
#   Head word: 'leading'
#   Dependency relation: prep
#   Explanation: prepositional modifier
#   Children: ['store']
# Word: 'the'
#   Head word: 'store'
#   Dependency relation: det
#   Explanation: determiner
#   Children: []
# Word: 'apple'
#   Head word: 'store'
#   Dependency relation: compound
#   Explanation: compound
#   Children: []
# Word: 'store'
#   Head word: 'to'
#   Dependency relation: pobj
#   Explanation: object of preposition
#   Children: ['the', 'apple']
# Word: ','
#   Head word: 'leading'
#   Dependency relation: punct
#   Explanation: punctuation
#   Children: []
# Word: 'app'
#   Head word: 'ios'
#   Dependency relation: compound
#   Explanation: compound
#   Children: []
# Word: 'store'
#   Head word: 'ios'
#   Dependency relation: compound
#   Explanation: compound
#   Children: []
# Word: 'ios'
#   Head word: 'leading'
#   Dependency relation: conj
#   Explanation: conjunct
#   Children: ['app', 'store', ',', 'imac']
# Word: ','
#   Head word: 'ios'
#   Dependency relation: punct
#   Explanation: punctuation
#   Children: []
# Word: 'imac'
#   Head word: 'ios'
#   Dependency relation: conj
#   Explanation: conjunct
#   Children: [',', 'ipad']
# Word: ','
#   Head word: 'imac'
#   Dependency relation: punct
#   Explanation: punctuation
#   Children: []
# Word: 'ipad'
#   Head word: 'imac'
#   Dependency relation: conj
#   Explanation: conjunct
#   Children: [',', 'ipod']
# Word: ','
#   Head word: 'ipad'
#   Dependency relation: punct
#   Explanation: punctuation
#   Children: []
# Word: 'ipod'
#   Head word: 'ipad'
#   Dependency relation: conj
#   Explanation: conjunct
#   Children: [',', 'iphone']
# Word: ','
#   Head word: 'ipod'
#   Dependency relation: punct
#   Explanation: punctuation
#   Children: []
# Word: 'iphone'
#   Head word: 'ipod'
#   Dependency relation: conj
#   Explanation: conjunct
#   Children: [',', 'itunes']
# Word: ','
#   Head word: 'iphone'
#   Dependency relation: punct
#   Explanation: punctuation
#   Children: []
# Word: 'itunes'
#   Head word: 'iphone'
#   Dependency relation: conj
#   Explanation: conjunct
#   Children: [',', 'and', 'store']
# Word: ','
#   Head word: 'itunes'
#   Dependency relation: punct
#   Explanation: punctuation
#   Children: []
# Word: 'and'
#   Head word: 'itunes'
#   Dependency relation: cc
#   Explanation: coordinating conjunction
#   Children: []
# Word: 'itunes'
#   Head word: 'store'
#   Dependency relation: compound
#   Explanation: compound
#   Children: []
# Word: 'store'
#   Head word: 'itunes'
#   Dependency relation: conj
#   Explanation: conjunct
#   Children: ['itunes']
# Word: '.'
#   Head word: 'worked'
#   Dependency relation: punct
#   Explanation: punctuation
#   Children: []
# Word: 'in'
#   Head word: 'replaced'
#   Dependency relation: prep
#   Explanation: prepositional modifier
#   Children: []
# Word: ','
#   Head word: 'replaced'
#   Dependency relation: punct
#   Explanation: punctuation
#   Children: []
# Word: 'the'
#   Head word: 'mac'
#   Dependency relation: det
#   Explanation: determiner
#   Children: []
# Word: 'original'
#   Head word: 'mac'
#   Dependency relation: amod
#   Explanation: adjectival modifier
#   Children: []
# Word: 'mac'
#   Head word: 'os'
#   Dependency relation: compound
#   Explanation: compound
#   Children: ['the', 'original']
# Word: 'os'
#   Head word: 'replaced'
#   Dependency relation: nsubjpass
#   Explanation: nominal subject (passive)
#   Children: ['mac']
# Word: 'was'
#   Head word: 'replaced'
#   Dependency relation: auxpass
#   Explanation: auxiliary (passive)
#   Children: []
# Word: 'replaced'
#   Head word: 'replaced'
#   Dependency relation: ROOT
#   Explanation: root
#   Children: ['in', ',', 'os', 'was', 'with', 'based', ',', 'giving', '.']
# Word: 'with'
#   Head word: 'replaced'
#   Dependency relation: prep
#   Explanation: prepositional modifier
#   Children: ['os']
# Word: 'the'
#   Head word: 'mac'
#   Dependency relation: det
#   Explanation: determiner
#   Children: []
# Word: 'completely'
#   Head word: 'new'
#   Dependency relation: advmod
#   Explanation: adverbial modifier
#   Children: []
# Word: 'new'
#   Head word: 'mac'
#   Dependency relation: amod
#   Explanation: adjectival modifier
#   Children: ['completely']
# Word: 'mac'
#   Head word: 'os'
#   Dependency relation: compound
#   Explanation: compound
#   Children: ['the', 'new']
# Word: 'os'
#   Head word: 'with'
#   Dependency relation: pobj
#   Explanation: object of preposition
#   Children: ['mac', 'x', 'known', ',']
# Word: 'x'
#   Head word: 'os'
#   Dependency relation: punct
#   Explanation: punctuation
#   Children: []
# Word: 'later'
#   Head word: 'known'
#   Dependency relation: advmod
#   Explanation: adverbial modifier
#   Children: []
# Word: 'known'
#   Head word: 'os'
#   Dependency relation: acl
#   Explanation: clausal modifier of noun (adjectival clause)
#   Children: ['later', 'as']
# Word: 'as'
#   Head word: 'known'
#   Dependency relation: prep
#   Explanation: prepositional modifier
#   Children: ['macos']
# Word: 'macos'
#   Head word: 'as'
#   Dependency relation: pobj
#   Explanation: object of preposition
#   Children: []
# Word: ','
#   Head word: 'os'
#   Dependency relation: punct
#   Explanation: punctuation
#   Children: []
# Word: 'based'
#   Head word: 'replaced'
#   Dependency relation: prep
#   Explanation: prepositional modifier
#   Children: ['on']
# Word: 'on'
#   Head word: 'based'
#   Dependency relation: prep
#   Explanation: prepositional modifier
#   Children: ['platform']
# Word: 'nexts'
#   Head word: 'platform'
#   Dependency relation: compound
#   Explanation: compound
#   Children: []
# Word: 'nextstep'
#   Head word: 'platform'
#   Dependency relation: compound
#   Explanation: compound
#   Children: []
# Word: 'platform'
#   Head word: 'on'
#   Dependency relation: pobj
#   Explanation: object of preposition
#   Children: ['nexts', 'nextstep']
# Word: ','
#   Head word: 'replaced'
#   Dependency relation: punct
#   Explanation: punctuation
#   Children: []
# Word: 'giving'
#   Head word: 'replaced'
#   Dependency relation: advcl
#   Explanation: adverbial clause modifier
#   Children: ['system', 'foundation']
# Word: 'the'
#   Head word: 'system'
#   Dependency relation: det
#   Explanation: determiner
#   Children: []
# Word: 'operating'
#   Head word: 'system'
#   Dependency relation: compound
#   Explanation: compound
#   Children: []
# Word: 'system'
#   Head word: 'giving'
#   Dependency relation: dative
#   Explanation: dative
#   Children: ['the', 'operating']
# Word: 'a'
#   Head word: 'foundation'
#   Dependency relation: det
#   Explanation: determiner
#   Children: []
# Word: 'modern'
#   Head word: 'foundation'
#   Dependency relation: amod
#   Explanation: adjectival modifier
#   Children: []
# Word: 'unixbased'
#   Head word: 'foundation'
#   Dependency relation: amod
#   Explanation: adjectival modifier
#   Children: []
# Word: 'foundation'
#   Head word: 'giving'
#   Dependency relation: dobj
#   Explanation: direct object
#   Children: ['a', 'modern', 'unixbased', 'for']
# Word: 'for'
#   Head word: 'foundation'
#   Dependency relation: prep
#   Explanation: prepositional modifier
#   Children: ['time']
# Word: 'the'
#   Head word: 'time'
#   Dependency relation: det
#   Explanation: determiner
#   Children: []
# Word: 'first'
#   Head word: 'time'
#   Dependency relation: amod
#   Explanation: adjectival modifier
#   Children: []
# Word: 'time'
#   Head word: 'for'
#   Dependency relation: pobj
#   Explanation: object of preposition
#   Children: ['the', 'first']
# Word: '.'
#   Head word: 'replaced'
#   Dependency relation: punct
#   Explanation: punctuation
#   Children: []
# Word: 'in'
#   Head word: 'diagnosed'
#   Dependency relation: prep
#   Explanation: prepositional modifier
#   Children: []
# Word: ','
#   Head word: 'diagnosed'
#   Dependency relation: punct
#   Explanation: punctuation
#   Children: []
# Word: 'jobs'
#   Head word: 'diagnosed'
#   Dependency relation: nsubjpass
#   Explanation: nominal subject (passive)
#   Children: []
# Word: 'was'
#   Head word: 'diagnosed'
#   Dependency relation: auxpass
#   Explanation: auxiliary (passive)
#   Children: []
# Word: 'diagnosed'
#   Head word: 'diagnosed'
#   Dependency relation: ROOT
#   Explanation: root
#   Children: ['in', ',', 'jobs', 'was', 'with', '.']
# Word: 'with'
#   Head word: 'diagnosed'
#   Dependency relation: prep
#   Explanation: prepositional modifier
#   Children: ['tumor']
# Word: 'a'
#   Head word: 'tumor'
#   Dependency relation: det
#   Explanation: determiner
#   Children: []
# Word: 'pancreatic'
#   Head word: 'tumor'
#   Dependency relation: amod
#   Explanation: adjectival modifier
#   Children: []
# Word: 'neuroendocrine'
#   Head word: 'tumor'
#   Dependency relation: compound
#   Explanation: compound
#   Children: []
# Word: 'tumor'
#   Head word: 'with'
#   Dependency relation: pobj
#   Explanation: object of preposition
#   Children: ['a', 'pancreatic', 'neuroendocrine']
# Word: '.'
#   Head word: 'diagnosed'
#   Dependency relation: punct
#   Explanation: punctuation
#   Children: []
# Word: 'he'
#   Head word: 'died'
#   Dependency relation: nsubj
#   Explanation: nominal subject
#   Children: []
# Word: 'died'
#   Head word: 'died'
#   Dependency relation: ROOT
#   Explanation: root
#   Children: ['he', 'of', ',', 'at', 'with', '.']
# Word: 'of'
#   Head word: 'died'
#   Dependency relation: prep
#   Explanation: prepositional modifier
#   Children: ['arrest']
# Word: 'respiratory'
#   Head word: 'arrest'
#   Dependency relation: amod
#   Explanation: adjectival modifier
#   Children: []
# Word: 'arrest'
#   Head word: 'of'
#   Dependency relation: pobj
#   Explanation: object of preposition
#   Children: ['respiratory', 'related']
# Word: 'related'
#   Head word: 'arrest'
#   Dependency relation: acl
#   Explanation: clausal modifier of noun (adjectival clause)
#   Children: ['to', 'in']
# Word: 'to'
#   Head word: 'related'
#   Dependency relation: prep
#   Explanation: prepositional modifier
#   Children: ['tumor']
# Word: 'the'
#   Head word: 'tumor'
#   Dependency relation: det
#   Explanation: determiner
#   Children: []
# Word: 'tumor'
#   Head word: 'to'
#   Dependency relation: pobj
#   Explanation: object of preposition
#   Children: ['the']
# Word: 'in'
#   Head word: 'related'
#   Dependency relation: advmod
#   Explanation: adverbial modifier
#   Children: []
# Word: ','
#   Head word: 'died'
#   Dependency relation: punct
#   Explanation: punctuation
#   Children: []
# Word: 'at'
#   Head word: 'died'
#   Dependency relation: prep
#   Explanation: prepositional modifier
#   Children: ['age', ',']
# Word: 'the'
#   Head word: 'age'
#   Dependency relation: det
#   Explanation: determiner
#   Children: []
# Word: 'age'
#   Head word: 'at'
#   Dependency relation: pobj
#   Explanation: object of preposition
#   Children: ['the', 'of']
# Word: 'of'
#   Head word: 'age'
#   Dependency relation: prep
#   Explanation: prepositional modifier
#   Children: []
# Word: ','
#   Head word: 'at'
#   Dependency relation: punct
#   Explanation: punctuation
#   Children: []
# Word: 'with'
#   Head word: 'died'
#   Dependency relation: prep
#   Explanation: prepositional modifier
#   Children: ['succeeding']
# Word: 'tim'
#   Head word: 'cook'
#   Dependency relation: compound
#   Explanation: compound
#   Children: []
# Word: 'cook'
#   Head word: 'succeeding'
#   Dependency relation: nsubj
#   Explanation: nominal subject
#   Children: ['tim']
# Word: 'succeeding'
#   Head word: 'with'
#   Dependency relation: pcomp
#   Explanation: complement of preposition
#   Children: ['cook', 'him', 'as']
# Word: 'him'
#   Head word: 'succeeding'
#   Dependency relation: dobj
#   Explanation: direct object
#   Children: []
# Word: 'as'
#   Head word: 'succeeding'
#   Dependency relation: prep
#   Explanation: prepositional modifier
#   Children: ['ceo']
# Word: 'ceo'
#   Head word: 'as'
#   Dependency relation: pobj
#   Explanation: object of preposition
#   Children: ['of']
# Word: 'of'
#   Head word: 'ceo'
#   Dependency relation: prep
#   Explanation: prepositional modifier
#   Children: ['apple']
# Word: 'apple'
#   Head word: 'of'
#   Dependency relation: pobj
#   Explanation: object of preposition
#   Children: []
# Word: '.'
#   Head word: 'died'
#   Dependency relation: punct
#   Explanation: punctuation
#   Children: []
# Word: 'in'
#   Head word: 'awarded'
#   Dependency relation: prep
#   Explanation: prepositional modifier
#   Children: []
# Word: ','
#   Head word: 'awarded'
#   Dependency relation: punct
#   Explanation: punctuation
#   Children: []
# Word: 'he'
#   Head word: 'awarded'
#   Dependency relation: nsubjpass
#   Explanation: nominal subject (passive)
#   Children: []
# Word: 'was'
#   Head word: 'awarded'
#   Dependency relation: auxpass
#   Explanation: auxiliary (passive)
#   Children: []
# Word: 'posthumously'
#   Head word: 'awarded'
#   Dependency relation: advmod
#   Explanation: adverbial modifier
#   Children: []
# Word: 'awarded'
#   Head word: 'awarded'
#   Dependency relation: ROOT
#   Explanation: root
#   Children: ['in', ',', 'he', 'was', 'posthumously', 'medal', '.']
# Word: 'the'
#   Head word: 'medal'
#   Dependency relation: det
#   Explanation: determiner
#   Children: []
# Word: 'presidential'
#   Head word: 'medal'
#   Dependency relation: amod
#   Explanation: adjectival modifier
#   Children: []
# Word: 'medal'
#   Head word: 'awarded'
#   Dependency relation: dobj
#   Explanation: direct object
#   Children: ['the', 'presidential', 'of']
# Word: 'of'
#   Head word: 'medal'
#   Dependency relation: prep
#   Explanation: prepositional modifier
#   Children: ['freedom']
# Word: 'freedom'
#   Head word: 'of'
#   Dependency relation: pobj
#   Explanation: object of preposition
#   Children: []
# Word: '.'
#   Head word: 'awarded'
#   Dependency relation: punct
#   Explanation: punctuation
#   Children: []

# %%
all_sentences = sent_tokenize(text_lower)

for sent_idx, sentence in enumerate(all_sentences, 1):
    print(f"\nSentence {sent_idx}: {sentence}")

    # Tokenize and tag
    tokens = word_tokenize(sentence)
    pos_tags = pos_tag(tokens)

    # Create a simple binary tree structure for visualization
    def create_simple_tree(tokens, pos_tags):
        """Create a simple constituency-like tree structure"""
        if len(tokens) == 1:
            return Tree(pos_tags[0][1], [tokens[0]])
        else:
            mid = len(tokens) // 2
            left_tree = create_simple_tree(tokens[:mid], pos_tags[:mid])
            right_tree = create_simple_tree(tokens[mid:], pos_tags[mid:])
            return Tree('S', [left_tree, right_tree])

    try:
        constituency_tree = create_simple_tree(tokens, pos_tags)
        print("Constituency Tree:")
        constituency_tree.pretty_print()

        print("Tree in bracketed notation:")
        print(constituency_tree)
    except Exception as e:
        print(f"Error creating tree: {e}")

print("\nALTERNATIVE TREE VISUALIZATION (ALL SENTENCES - Detailed NP chunks):")

# More detailed tree structure for ALL sentences
for sent_idx, sentence in enumerate(all_sentences, 1):
    print(f"\nSentence {sent_idx}: {sentence}")

    tokens = word_tokenize(sentence)
    pos_tags = pos_tag(tokens)

    # Manual tree building
    tree = Tree('S', [])
    current_np = []

    for word, tag in pos_tags:
        if tag.startswith('NN') or tag.startswith('JJ') or tag == 'DT':
            current_np.append((word, tag))
        else:
            if current_np:
                np_tree = Tree('NP', [f"{w}/{t}" for w, t in current_np])
                tree.append(np_tree)
                current_np = []
            tree.append(f"{word}/{tag}")

    if current_np:
        np_tree = Tree('NP', [f"{w}/{t}" for w, t in current_np])
        tree.append(np_tree)

    print("Detailed Constituency Tree (NP chunks):")
    tree.pretty_print()
    print("\nTree as string:")
    print(tree)
# Out:
# Sentence 1: steven paul jobs february ,  october ,  was an american business magnate, inventor, and investor.
# Constituency Tree:
#                                                                    S
#                                         ___________________________|_______________________________________________
#                                        S                                                                           S
#                   _____________________|_______________                                       _____________________|______________
#                  |                                     S                                     |                                    S
#                  |                          ___________|___                                  |                             _______|_____
#                  S                         |               S                                 S                            |             S
#          ________|________                 |            ___|___                  ____________|___________                 |        _____|______
#         S                 S                S           |       S                S                        S                S       |            S
#    _____|___          ____|_____        ___|_____      |    ___|___       ______|_____              _____|___       ______|___    |      ______|___
#   RB        NN      NNS         JJ     ,        NNP    ,  VBD      DT    JJ           NN           NN        ,     NN         ,   CC    NN         .
#   |         |        |          |      |         |     |   |       |     |            |            |         |     |          |   |     |          |
# steven     paul     jobs     february  ,      october  ,  was      an american     business     magnate      ,  inventor      ,  and investor      .
#
# Tree in bracketed notation:
# (S
#   (S
#     (S (S (RB steven) (NN paul)) (S (NNS jobs) (JJ february)))
#     (S (S (, ,) (NNP october)) (S (, ,) (S (VBD was) (DT an)))))
#   (S
#     (S (S (JJ american) (NN business)) (S (NN magnate) (, ,)))
#     (S (S (NN inventor) (, ,)) (S (CC and) (S (NN investor) (. .))))))
#
# Sentence 2: he was the cofounder, chairman, and ceo of apple the chairman and majority shareholder of pixar a member of the walt disney companys board of directors following its acquisition of pixar and the founder, chairman, and ceo of next.
# Constituency Tree:
#                                                                                                                                                          S
#                                                                       ___________________________________________________________________________________|____________________________________________________________________________________________
#                                                                      S                                                                                                                                                                                S
#                                       _______________________________|__________________________________________________                                                                                ______________________________________________|_________________________________________
#                                      S                                                                                  S                                                                              S                                                                                        S
#               _______________________|______________                                        ____________________________|_____________                                          _______________________|____________________                                              ______________________|___________
#              S                                      S                                      S                                          S                                        S                                            S                                            S                                  S
#       _______|______                         _______|_______                   ____________|_____                             ________|__________                  ____________|_______                           __________|________________                   _________|_____                      _______|_______
#      |              S                       S               S                 |                  S                           S                   S                |                    S                         S                           S                 |               S                    S               S
#      |        ______|______           ______|___         ___|___              |             _____|______                 ____|____          _____|___             |             _______|____            _________|______              _______|___              |          _____|___              ___|___         ___|____
#      S       |             S         |          S       |       S             S            |            S               |         S        |         S            S            |            S          |                S            |           S             S         |         S            |       S       |        S
#   ___|___    |       ______|___      |       ___|___    |    ___|____      ___|_____       |      ______|_______        |     ____|___     |      ___|___     ____|____        |        ____|___       |          ______|___         |        ___|____      ___|___      |      ___|_____       |    ___|___    |    ____|___
# PRP     VBD  DT     NN         ,     NN     ,       CC  NN  IN       NN   DT        NN     CC    NN             NN      IN   NN       DT   NN    IN      DT  NN        NN     VBZ      NN       IN    NNS       VBG        PRP$      NN      IN       NN   CC      DT    NN    ,         NN     ,   CC      NN  IN  JJ       .
#  |       |   |      |          |     |      |       |   |   |        |    |         |      |     |              |       |    |        |    |     |       |   |         |       |       |        |      |         |          |        |       |        |    |       |     |     |         |      |   |       |   |   |        |
#  he     was the cofounder      ,  chairman  ,      and ceo  of     apple the     chairman and majority     shareholder  of pixar      a  member  of     the walt     disney companys board      of directors following     its  acquisition  of     pixar and     the founder  ,      chairman  ,  and     ceo  of next      .
#
# Tree in bracketed notation:
# (S
#   (S
#     (S
#       (S
#         (S (PRP he) (VBD was))
#         (S (DT the) (S (NN cofounder) (, ,))))
#       (S
#         (S (NN chairman) (S (, ,) (CC and)))
#         (S (NN ceo) (S (IN of) (NN apple)))))
#     (S
#       (S
#         (S (DT the) (NN chairman))
#         (S (CC and) (S (NN majority) (NN shareholder))))
#       (S
#         (S (IN of) (S (NN pixar) (DT a)))
#         (S (NN member) (S (IN of) (DT the))))))
#   (S
#     (S
#       (S
#         (S (NN walt) (NN disney))
#         (S (VBZ companys) (S (NN board) (IN of))))
#       (S
#         (S (NNS directors) (S (VBG following) (PRP$ its)))
#         (S (NN acquisition) (S (IN of) (NN pixar)))))
#     (S
#       (S
#         (S (CC and) (DT the))
#         (S (NN founder) (S (, ,) (NN chairman))))
#       (S
#         (S (, ,) (S (CC and) (NN ceo)))
#         (S (IN of) (S (JJ next) (. .)))))))
#
# Sentence 3: he was a pioneer of the personal computer revolution of the s and s, along with his early business partner and fellow apple cofounder steve wozniak.
# Constituency Tree:
#                                                                                                           S
#                                                 __________________________________________________________|________________________________________________________
#                                                S                                                                                                                   S
#                     ___________________________|__________________________________                                                _________________________________|_____________________________
#                    S                                                              S                                              S                                                               S
#       _____________|_____________                                  _______________|___________                      _____________|______________                               __________________|________________
#      S                           S                                S                           S                    S                            S                             S                                   S
#   ___|___                 _______|_______                _________|_______             _______|_______         ____|____               _________|____________             ____|_____                     _________|___________
#  |       S               S               S              |                 S           S               S       |         S             S                      S           |          S                   S                     S
#  |    ___|___       _____|___         ___|_____         |          _______|___     ___|___         ___|___    |     ____|___      ____|____            ______|_____      |     _____|____         ______|____            _____|___
# PRP VBD      DT    NN        IN      DT        JJ       NN        NN          IN  DT      NN      CC      NN  ,    IN       IN  PRP$       JJ         NN           NN    CC   JJ         NN      NN         VBP         NN        .
#  |   |       |     |         |       |         |        |         |           |   |       |       |       |   |    |        |    |         |          |            |     |    |          |       |           |          |         |
#  he was      a  pioneer      of     the     personal computer revolution      of the      s      and      s   ,  along     with his      early     business     partner and fellow     apple cofounder     steve     wozniak      .
#
# Tree in bracketed notation:
# (S
#   (S
#     (S
#       (S (PRP he) (S (VBD was) (DT a)))
#       (S (S (NN pioneer) (IN of)) (S (DT the) (JJ personal))))
#     (S
#       (S (NN computer) (S (NN revolution) (IN of)))
#       (S (S (DT the) (NN s)) (S (CC and) (NN s)))))
#   (S
#     (S
#       (S (, ,) (S (IN along) (IN with)))
#       (S (S (PRP$ his) (JJ early)) (S (NN business) (NN partner))))
#     (S
#       (S (CC and) (S (JJ fellow) (NN apple)))
#       (S (S (NN cofounder) (VBP steve)) (S (NN wozniak) (. .))))))
#
# Sentence 4: jobs was born in san francisco to a syrian father and germanamerican mother.
# Constituency Tree:
#                                                  S
#                     _____________________________|_________________________
#                    S                                                       S
#        ____________|___________                            ________________|______________________
#       S                        S                          S                                       S
#   ____|___              _______|_____________         ____|_____                __________________|__________
#  |        S            S                     S       |          S              S                             S
#  |     ___|___      ___|___            ______|___    |     _____|____       ___|________                _____|___
# NNS  VBD     VBN   IN      JJ         NN         TO  DT   JJ         NN    CC           JJ             NN        .
#  |    |       |    |       |          |          |   |    |          |     |            |              |         |
# jobs was     born  in     san     francisco      to  a  syrian     father and     germanamerican     mother      .
#
# Tree in bracketed notation:
# (S
#   (S
#     (S (NNS jobs) (S (VBD was) (VBN born)))
#     (S (S (IN in) (JJ san)) (S (NN francisco) (TO to))))
#   (S
#     (S (DT a) (S (JJ syrian) (NN father)))
#     (S (S (CC and) (JJ germanamerican)) (S (NN mother) (. .)))))
#
# Sentence 5: he was adopted shortly after his birth.
# Constituency Tree:
#                                S
#               _________________|____________________
#              S                                      S
#       _______|___________                   ________|_________
#      S                   S                 S                  S
#   ___|___           _____|_____        ____|___           ____|___
# PRP     VBD       VBN          RB     IN      PRP$       NN       .
#  |       |         |           |      |        |         |        |
#  he     was     adopted     shortly after     his      birth      .
#
# Tree in bracketed notation:
# (S
#   (S (S (PRP he) (VBD was)) (S (VBN adopted) (RB shortly)))
#   (S (S (IN after) (PRP$ his)) (S (NN birth) (. .))))
#
# Sentence 6: jobs attended reed college in before withdrawing that same year.
# Constituency Tree:
#                                          S
#                     _____________________|_____________________
#                    S                                           S
#        ____________|______                          ___________|_________
#       |                   S                        S                     S
#       |             ______|_____          _________|_______          ____|____
#       S            |            S        |                 S        |         S
#   ____|_____       |       _____|___     |          _______|___     |     ____|___
# NNS        VBD     NN     NN        IN   IN       VBG          DT   JJ   NN       .
#  |          |      |      |         |    |         |           |    |    |        |
# jobs     attended reed college      in before withdrawing     that same year      .
#
# Tree in bracketed notation:
# (S
#   (S
#     (S (NNS jobs) (VBD attended))
#     (S (NN reed) (S (NN college) (IN in))))
#   (S
#     (S (IN before) (S (VBG withdrawing) (DT that)))
#     (S (JJ same) (S (NN year) (. .)))))
#
# Sentence 7: in , he traveled through india seeking enlightenment before later studying zen buddhism.
# Constituency Tree:
#                                                       S
#                     __________________________________|______________________________________
#                    S                                                                         S
#       _____________|__________________                                      _________________|______________
#      S                                S                                    S                                S
#   ___|___                  ___________|_________                  _________|_____                    _______|____________
#  |       S                S                     S                |               S                  S                    S
#  |    ___|___       ______|_____            ____|_____           |          _____|____        ______|___           ______|___
#  IN  ,      PRP   VBD           IN         NN        VBG         NN        IN         JJ    VBG         JJ        NN         .
#  |   |       |     |            |          |          |          |         |          |      |          |         |          |
#  in  ,       he traveled     through     india     seeking enlightenment before     later studying     zen     buddhism      .
#
# Tree in bracketed notation:
# (S
#   (S
#     (S (IN in) (S (, ,) (PRP he)))
#     (S (S (VBD traveled) (IN through)) (S (NN india) (VBG seeking))))
#   (S
#     (S (NN enlightenment) (S (IN before) (JJ later)))
#     (S (S (VBG studying) (JJ zen)) (S (NN buddhism) (. .)))))
#
# Sentence 8: he and wozniak cofounded apple in to sell wozniaks apple i personal computer.
# Constituency Tree:
#                                                      S
#                          ____________________________|___________________________
#                         S                                                        S
#       __________________|________________                        ________________|________________
#      S                                   S                      S                                 S
#   ___|___                       _________|_______         ______|______               ____________|____________
#  |       S                     S                 S       |             S             S                         S
#  |    ___|_____          ______|____          ___|___    |       ______|____      ___|_____              ______|___
# PRP  CC        VB      VBN          NN       IN      TO  VB     JJ          NN   NN        JJ           NN         .
#  |   |         |        |           |        |       |   |      |           |    |         |            |          |
#  he and     wozniak cofounded     apple      in      to sell wozniaks     apple  i      personal     computer      .
#
# Tree in bracketed notation:
# (S
#   (S
#     (S (PRP he) (S (CC and) (VB wozniak)))
#     (S (S (VBN cofounded) (NN apple)) (S (IN in) (TO to))))
#   (S
#     (S (VB sell) (S (JJ wozniaks) (NN apple)))
#     (S (S (NN i) (JJ personal)) (S (NN computer) (. .)))))
#
# Sentence 9: together the duo gained fame and wealth a year later with production and sale of the apple ii, one of the first highly successful massproduced microcomputers.
# Constituency Tree:
#                                                                                                             S
#                                                     ________________________________________________________|______________________________________________
#                                                    S                                                                                                       S
#                         ___________________________|________________________                                                        _______________________|___________________________
#                        S                                                    S                                                      S                                                   S
#            ____________|______________                        ______________|___________________                      _____________|___________                      __________________|________________________
#           S                           S                      S                                  S                    S                         S                    S                                           S
#     ______|___                ________|_______            ___|____                ______________|_______          ___|___               _______|_______         ____|____                       ________________|__________________
#    |          S              S                S          |        S              S                      S        |       S             S               S       |         S                     S                                   S
#    |       ___|___      _____|___          ___|____      |    ____|____      ____|______             ___|___     |    ___|____      ___|___         ___|___    |     ____|____          _______|_______                   _________|___
#    RB     DT      NN  VBD        NN       CC       NN    DT  NN        RB   IN          NN          CC      NN   IN  DT       NN   NN      ,       CD      IN  DT   JJ        RB       JJ             VBD               NNS            .
#    |      |       |    |         |        |        |     |   |         |    |           |           |       |    |   |        |    |       |       |       |   |    |         |        |               |                 |             |
# together the     duo gained     fame     and     wealth  a  year     later with     production     and     sale  of the     apple  ii      ,      one      of the first     highly successful     massproduced     microcomputers      .
#
# Tree in bracketed notation:
# (S
#   (S
#     (S
#       (S (RB together) (S (DT the) (NN duo)))
#       (S (S (VBD gained) (NN fame)) (S (CC and) (NN wealth))))
#     (S
#       (S (DT a) (S (NN year) (RB later)))
#       (S (S (IN with) (NN production)) (S (CC and) (NN sale)))))
#   (S
#     (S
#       (S (IN of) (S (DT the) (NN apple)))
#       (S (S (NN ii) (, ,)) (S (CD one) (IN of))))
#     (S
#       (S (DT the) (S (JJ first) (RB highly)))
#       (S
#         (S (JJ successful) (VBD massproduced))
#         (S (NNS microcomputers) (. .))))))
#
# Sentence 10: jobs saw the commercial potential of the xerox alto in , which was mousedriven and had a graphical user interface gui.
# Constituency Tree:
#                                                                           S
#                                             ______________________________|_________________________________________
#                                            S                                                                        S
#                ____________________________|____________                                         ___________________|_________________
#               S                                         S                                       S                                     S
#        _______|______                           ________|_________                   ___________|_______                    __________|______________
#       |              S                         S                  S                 |                   S                  S                         S
#       |        ______|_______               ___|___           ____|___              |            _______|___         ______|______             ______|___
#       S       |              S             |       S         |        S             S           |           S       |             S           |          S
#   ____|___    |       _______|______       |    ___|____     |     ___|___      ____|___        |        ___|___    |       ______|___        |       ___|___
# NNS      VBD  DT     JJ             NN     IN  DT      NNP   NN   IN      ,   WDT      VBD     VBN      CC     VBD  DT     JJ         NN      NN     NN      .
#  |        |   |      |              |      |   |        |    |    |       |    |        |       |       |       |   |      |          |       |      |       |
# jobs     saw the commercial     potential  of the     xerox alto  in      ,  which     was mousedriven and     had  a  graphical     user interface gui      .
#
# Tree in bracketed notation:
# (S
#   (S
#     (S
#       (S (NNS jobs) (VBD saw))
#       (S (DT the) (S (JJ commercial) (NN potential))))
#     (S
#       (S (IN of) (S (DT the) (NNP xerox)))
#       (S (NN alto) (S (IN in) (, ,)))))
#   (S
#     (S
#       (S (WDT which) (VBD was))
#       (S (VBN mousedriven) (S (CC and) (VBD had))))
#     (S
#       (S (DT a) (S (JJ graphical) (NN user)))
#       (S (NN interface) (S (NN gui) (. .))))))
#
# Sentence 11: this led to the development of the unsuccessful apple lisa in , followed by the breakthrough macintosh in , the first massproduced computer with a gui.
# Constituency Tree:
#                                                                                                        S
#                                            ____________________________________________________________|______________________________________________________
#                                           S                                                                                                                   S
#                ___________________________|__________________________                                                               __________________________|___________________________________
#               S                                                      S                                                             S                                                              S
#        _______|___________                         __________________|____________                          _______________________|______________                           _____________________|____________
#       S                   S                       S                               S                        S                                      S                         S                                  S
#   ____|___         _______|_______         _______|________                _______|_______              ___|___                            _______|_______          ________|________                   _______|_______
#  |        S       |               S       |                S              S               S            |       S                          S               S        |                 S                 S               S
#  |     ___|___    |        _______|___    |        ________|____      ____|___         ___|_____       |    ___|_______             ______|___         ___|___     |         ________|_____        ____|___         ___|___
#  DT  VBD      TO  DT      NN          IN  DT      JJ            NN   NN       IN      ,        VBN     IN  DT          NN          NN         IN      ,       DT   JJ      VBD             NN     IN       DT      NN      .
#  |    |       |   |       |           |   |       |             |    |        |       |         |      |   |           |           |          |       |       |    |        |              |      |        |       |       |
# this led      to the development      of the unsuccessful     apple lisa      in      ,      followed  by the     breakthrough macintosh      in      ,      the first massproduced     computer with      a      gui      .
#
# Tree in bracketed notation:
# (S
#   (S
#     (S
#       (S (DT this) (S (VBD led) (TO to)))
#       (S (DT the) (S (NN development) (IN of))))
#     (S
#       (S (DT the) (S (JJ unsuccessful) (NN apple)))
#       (S (S (NN lisa) (IN in)) (S (, ,) (VBN followed)))))
#   (S
#     (S
#       (S (IN by) (S (DT the) (NN breakthrough)))
#       (S (S (NN macintosh) (IN in)) (S (, ,) (DT the))))
#     (S
#       (S (JJ first) (S (VBD massproduced) (NN computer)))
#       (S (S (IN with) (DT a)) (S (NN gui) (. .))))))
#
# Sentence 12: the macintosh introduced the desktop publishing industry in with the addition of the apple laserwriter, the first laser printer to feature vector graphics.
# Constituency Tree:
#                                                                                                     S
#                                                   __________________________________________________|____________________________________________
#                                                  S                                                                                               S
#                        __________________________|________________________                                             __________________________|______________________
#                       S                                                   S                                           S                                                 S
#          _____________|_____________                               _______|__________                     ____________|___________                       _______________|________________
#         S                           S                             S                  S                   S                        S                     S                                S
#   ______|______                _____|_____                  ______|___          _____|______         ____|____                 ___|___            ______|_____                 __________|____________
#  |             S              |           S                |          S        |            S       |         S               |       S          |            S               S                       S
#  |       ______|______        |      _____|______          |       ___|___     |      ______|___    |     ____|_______        |    ___|____      |       _____|___       _____|____             ______|___
#  DT     NN           VBD      DT    NN           NN        NN     IN      IN   DT    NN         IN  DT   NN           NN      ,   DT       JJ    NN     NN        TO    VB         NN         NNS         .
#  |      |             |       |     |            |         |      |       |    |     |          |   |    |            |       |   |        |     |      |         |     |          |           |          |
# the macintosh     introduced the desktop     publishing industry  in     with the addition      of the apple     laserwriter  ,  the     first laser printer      to feature     vector     graphics      .
#
# Tree in bracketed notation:
# (S
#   (S
#     (S
#       (S (DT the) (S (NN macintosh) (VBD introduced)))
#       (S (DT the) (S (NN desktop) (NN publishing))))
#     (S
#       (S (NN industry) (S (IN in) (IN with)))
#       (S (DT the) (S (NN addition) (IN of)))))
#   (S
#     (S
#       (S (DT the) (S (NN apple) (NN laserwriter)))
#       (S (, ,) (S (DT the) (JJ first))))
#     (S
#       (S (NN laser) (S (NN printer) (TO to)))
#       (S (S (VB feature) (NN vector)) (S (NNS graphics) (. .))))))
#
# Sentence 13: in , jobs was forced out of apple after a long power struggle with the companys board and its thenceo, john sculley.
# Constituency Tree:
#                                                                        S
#                                   _____________________________________|_____________________________________________
#                                  S                                                                                   S
#               ___________________|__________________                                           ______________________|____________________
#              S                                      S                                         S                                           S
#       _______|_________                    _________|________                         ________|_____________                     _________|__________
#      S                 S                  S                  S                       S                      S                   S                    S
#   ___|___          ____|_____         ____|____           ___|____             ______|____           _______|____         ______|_____         ______|_____
#  |       S        |          S       |         S         |        S           |           S         |            S       |            S       |            S
#  |    ___|___     |     _____|___    |     ____|____     |    ____|____       |       ____|___      |        ____|___    |       _____|___    |       _____|___
#  IN  ,      NNS  VBD  VBN        IN  IN   NN        IN   DT  JJ        NN     NN     IN       DT    NN      NN       CC PRP$    NN        ,   NN     NN        .
#  |   |       |    |    |         |   |    |         |    |   |         |      |      |        |     |       |        |   |      |         |   |      |         |
#  in  ,      jobs was forced     out  of apple     after  a  long     power struggle with     the companys board     and its  thenceo      ,  john sculley      .
#
# Tree in bracketed notation:
# (S
#   (S
#     (S
#       (S (IN in) (S (, ,) (NNS jobs)))
#       (S (VBD was) (S (VBN forced) (IN out))))
#     (S
#       (S (IN of) (S (NN apple) (IN after)))
#       (S (DT a) (S (JJ long) (NN power)))))
#   (S
#     (S
#       (S (NN struggle) (S (IN with) (DT the)))
#       (S (NN companys) (S (NN board) (CC and))))
#     (S
#       (S (PRP$ its) (S (NN thenceo) (, ,)))
#       (S (NN john) (S (NN sculley) (. .))))))
#
# Sentence 14: that same year, jobs took a few apple employees with him to found next, a computer platform development company that specialized in computers for highereducation and business markets.
# Constituency Tree:
#                                                                                                                       S
#                                                    ___________________________________________________________________|______________________________________________________________________________
#                                                   S                                                                                                                                                  S
#                      _____________________________|_______________________________                                                                    _______________________________________________|___________________________________________
#                     S                                                             S                                                                  S                                                                                           S
#        _____________|____________                                _________________|________________                                __________________|______________________________                                            _________________|__________________________
#       S                          S                              S                                  S                              S                                                 S                                          S                                            S
#   ____|____              ________|________             _________|_____________              _______|_________              _______|____________                          ___________|________                     _____________|_______                         ____________|___________
#  |         S            S                 S           S                       S            S                 S            S                    S                        S                    S                   S                     S                       S                        S
#  |     ____|___      ___|___          ____|___     ___|____             ______|___      ___|___          ____|___      ___|___           ______|_____            _______|_____           ____|_______         ___|______            ___|_________           ___|_____              _____|___
#  DT   JJ       NN   ,      NNS      VBD       DT  JJ       NN         NNS         IN  PRP      TO       VB       RB   ,       DT        NN           NN         NN            NN       WDT          VBD      IN        NNS         IN            NN        CC        NN          NNS        .
#  |    |        |    |       |        |        |   |        |           |          |    |       |        |        |    |       |         |            |          |             |         |            |       |          |          |             |         |         |            |         |
# that same     year  ,      jobs     took      a  few     apple     employees     with him      to     found     next  ,       a      computer     platform development     company     that     specialized  in     computers     for     highereducation and     business     markets      .
#
# Tree in bracketed notation:
# (S
#   (S
#     (S
#       (S (DT that) (S (JJ same) (NN year)))
#       (S (S (, ,) (NNS jobs)) (S (VBD took) (DT a))))
#     (S
#       (S (S (JJ few) (NN apple)) (S (NNS employees) (IN with)))
#       (S (S (PRP him) (TO to)) (S (VB found) (RB next)))))
#   (S
#     (S
#       (S (S (, ,) (DT a)) (S (NN computer) (NN platform)))
#       (S
#         (S (NN development) (NN company))
#         (S (WDT that) (VBD specialized))))
#     (S
#       (S
#         (S (IN in) (NNS computers))
#         (S (IN for) (NN highereducation)))
#       (S (S (CC and) (NN business)) (S (NNS markets) (. .))))))
#
# Sentence 15: in addition, he helped to develop the visual effects industry when he funded the computer graphics division of george lucass lucasfilm in .
# Constituency Tree:
#                                                                                      S
#                                       _______________________________________________|_______________________________________________
#                                      S                                                                                               S
#                    __________________|____________________                                                ___________________________|______________________
#                   S                                       S                                              S                                                  S
#         __________|________                       ________|_______________                      _________|______________                          __________|_______________
#        S                   S                     S                        S                    S                        S                        S                          S
#   _____|______         ____|_____           _____|___              _______|______          ____|_____           ________|______              ____|_____               ______|___
#  |            S       |          S         |         S            |              S        |          S         |               S            |          S             |          S
#  |      ______|___    |     _____|___      |      ___|____        |        ______|___     |     _____|___      |         ______|_____       |     _____|____         |       ___|___
#  IN    NN         ,  PRP  VBD        TO    VB    DT       JJ     NNS      NN        WRB  PRP  VBD        DT    NN      NNS           NN     IN   NN         NN       NN     IN      .
#  |     |          |   |    |         |     |     |        |       |       |          |    |    |         |     |        |            |      |    |          |        |      |       |
#  in addition      ,   he helped      to develop the     visual effects industry     when  he funded     the computer graphics     division  of george     lucass lucasfilm  in      .
#
# Tree in bracketed notation:
# (S
#   (S
#     (S
#       (S (IN in) (S (NN addition) (, ,)))
#       (S (PRP he) (S (VBD helped) (TO to))))
#     (S
#       (S (VB develop) (S (DT the) (JJ visual)))
#       (S (NNS effects) (S (NN industry) (WRB when)))))
#   (S
#     (S
#       (S (PRP he) (S (VBD funded) (DT the)))
#       (S (NN computer) (S (NNS graphics) (NN division))))
#     (S
#       (S (IN of) (S (NN george) (NN lucass)))
#       (S (NN lucasfilm) (S (IN in) (. .))))))
#
# Sentence 16: the new company was pixar, which produced the first d computeranimated feature film toy story  and went on to become a major animation studio, producing over films since.
# Constituency Tree:
#                                                                                                                                        S
#                                                         _______________________________________________________________________________|_________________________________________________________
#                                                        S                                                                                                                                         S
#                       _________________________________|____________________________                                                                              _______________________________|________________________________________
#                      S                                                              S                                                                            S                                                                        S
#       _______________|_____________                                    _____________|________________________________                                ____________|__________________                                        ______________|_____________________
#      S                             S                                  S                                              S                              S                               S                                      S                                    S
#   ___|___                 _________|_______                    _______|_________                          ___________|________               _______|________             __________|_______                     __________|_______                    _________|_________
#  |       S               S                 S                  S                 S                        S                    S             S                S           S                  S                   S                  S                  S                   S
#  |    ___|_____       ___|____          ___|____        ______|___          ____|___           __________|_____           ____|___      ____|___         ____|___     ___|____           ___|____         ______|____           ___|______        ____|____           ____|___
#  DT  JJ        NN   VBD       NN       ,       WDT    VBD         DT       JJ       NN       VBN               NN        NN       NN   NN       CC     VBD       IN  TO       VB        DT       JJ      NN          NN        ,         VBG     IN       NNS        IN       .
#  |   |         |     |        |        |        |      |          |        |        |         |                |         |        |    |        |       |        |   |        |         |        |       |           |         |          |      |         |         |        |
# the new     company was     pixar      ,      which produced     the     first      d  computeranimated     feature     film     toy story     and     went      on  to     become      a      major animation     studio      ,      producing over     films     since      .
#
# Tree in bracketed notation:
# (S
#   (S
#     (S
#       (S (DT the) (S (JJ new) (NN company)))
#       (S (S (VBD was) (NN pixar)) (S (, ,) (WDT which))))
#     (S
#       (S (S (VBD produced) (DT the)) (S (JJ first) (NN d)))
#       (S
#         (S (VBN computeranimated) (NN feature))
#         (S (NN film) (NN toy)))))
#   (S
#     (S
#       (S (S (NN story) (CC and)) (S (VBD went) (IN on)))
#       (S (S (TO to) (VB become)) (S (DT a) (JJ major))))
#     (S
#       (S (S (NN animation) (NN studio)) (S (, ,) (VBG producing)))
#       (S (S (IN over) (NNS films)) (S (IN since) (. .))))))
#
# Sentence 17: in , jobs returned to apple as ceo after the companys acquisition of next.
# Constituency Tree:
#                                                      S
#                      ________________________________|___________________________
#                     S                                                            S
#       ______________|______________                                 _____________|__________________________
#      S                             S                               S                                        S
#   ___|___                   _______|_________             _________|_______                          _______|________
# ...
# ,/, took/VBD with/IN him/PRP to/TO found/VB next/RB ,/, that/WDT specialized/VBD in/IN for/IN and/CC ./. that/DT same/JJ year/NN jobs/NNS a/DT few/JJ apple/NN employees/NNS a/DT computer/NN platform/NN development/NN company/NN computers/NNS highereducation/ business/NN     markets/NNS
#                                                                                                                                                                                                                                                          NN
#
#
# Tree as string:
# (S
#   (NP that/DT same/JJ year/NN)
#   ,/,
#   (NP jobs/NNS)
#   took/VBD
#   (NP a/DT few/JJ apple/NN employees/NNS)
#   with/IN
#   him/PRP
#   to/TO
#   found/VB
#   next/RB
#   ,/,
#   (NP a/DT computer/NN platform/NN development/NN company/NN)
#   that/WDT
#   specialized/VBD
#   in/IN
#   (NP computers/NNS)
#   for/IN
#   (NP highereducation/NN)
#   and/CC
#   (NP business/NN markets/NNS)
#   ./.)
#
# Sentence 15: in addition, he helped to develop the visual effects industry when he funded the computer graphics division of george lucass lucasfilm in .
# Detailed Constituency Tree (NP chunks):
#                                                                                      S
#    __________________________________________________________________________________|_________________________________________________________________________________________________________________
#   |    |    |        |        |       |         |       |        |        |     |    |       NP                NP                                        NP                                            NP
#   |    |    |        |        |       |         |       |        |        |     |    |       |         ________|______________________          _________|________________________            _________|__________
# in/IN ,/, he/PRP helped/VBD to/TO develop/VB when/WRB he/PRP funded/VBD of/IN in/IN ./. addition/NN the/DT visual/JJ effects/NNS industry/NN the/DT computer/NN graphics/NNS division/NN george/NN lucass/NN lucasfilm/NN
#
#
# Tree as string:
# (S
#   in/IN
#   (NP addition/NN)
#   ,/,
#   he/PRP
#   helped/VBD
#   to/TO
#   develop/VB
#   (NP the/DT visual/JJ effects/NNS industry/NN)
#   when/WRB
#   he/PRP
#   funded/VBD
#   (NP the/DT computer/NN graphics/NNS division/NN)
#   of/IN
#   (NP george/NN lucass/NN lucasfilm/NN)
#   in/IN
#   ./.)
#
# Sentence 16: the new company was pixar, which produced the first d computeranimated feature film toy story  and went on to become a major animation studio, producing over films since.
# Detailed Constituency Tree (NP chunks):
#                                                                                                                                     S
#     ________________________________________________________________________________________________________________________________|________________________________________________________________________________________________________________________________
#    |     |      |          |               |           |       |       |     |       |      |        |          |       |      |           NP                 NP              NP                       NP                           NP                               NP
#    |     |      |          |               |           |       |       |     |       |      |        |          |       |      |     ______|________          |        _______|______         _________|______________        ______|______________________          |
# was/VBD ,/, which/WDT produced/VBD computeranimated/ and/CC went/VBD on/IN to/TO become/VB ,/, producing/VBG over/IN since/IN ./. the/DT new/JJ company/NN pixar/NN the/DT first/JJ d/NN feature/NN film/NN toy/NN story/NN a/DT major/JJ animation/NN studio/NN films/NNS
#                                           VBN
#
#
# Tree as string:
# (S
#   (NP the/DT new/JJ company/NN)
#   was/VBD
#   (NP pixar/NN)
#   ,/,
#   which/WDT
#   produced/VBD
#   (NP the/DT first/JJ d/NN)
#   computeranimated/VBN
#   (NP feature/NN film/NN toy/NN story/NN)
#   and/CC
#   went/VBD
#   on/IN
#   to/TO
#   become/VB
#   (NP a/DT major/JJ animation/NN studio/NN)
#   ,/,
#   producing/VBG
#   over/IN
#   (NP films/NNS)
#   since/IN
#   ./.)
#
# Sentence 17: in , jobs returned to apple as ceo after the companys acquisition of next.
# Detailed Constituency Tree (NP chunks):
#                                                    S
#    ________________________________________________|________________________________________________________________
#   |    |       |         |     |      |       |    |     NP       NP      NP               NP                       NP
#   |    |       |         |     |      |       |    |     |        |       |       _________|____________            |
# in/IN ,/, returned/VBD to/TO as/IN after/IN of/IN ./. jobs/NNS apple/NN ceo/NN the/DT companys/JJ acquisition/NN next/JJ
#
#
# Tree as string:
# (S
#   in/IN
#   ,/,
#   (NP jobs/NNS)
#   returned/VBD
#   to/TO
#   (NP apple/NN)
#   as/IN
#   (NP ceo/NN)
#   after/IN
#   (NP the/DT companys/JJ acquisition/NN)
#   of/IN
#   (NP next/JJ)
#   ./.)
#
# Sentence 18: he was largely responsible for reviving apple, which was on the verge of bankruptcy.
# Detailed Constituency Tree (NP chunks):
#                                                                S
#    ____________________________________________________________|______________________________________________________________________
#   |       |        |        |         |        |      |        |      |     |    |        NP          NP            NP                NP
#   |       |        |        |         |        |      |        |      |     |    |        |           |        _____|_____            |
# he/PRP was/VBD largely/RB for/IN reviving/VBG ,/, which/WDT was/VBD on/IN of/IN ./. responsible/JJ apple/NN the/DT     verge/NN bankruptcy/NN
#
#
# Tree as string:
# (S
#   he/PRP
#   was/VBD
#   largely/RB
#   (NP responsible/JJ)
#   for/IN
#   reviving/VBG
#   (NP apple/NN)
#   ,/,
#   which/WDT
#   was/VBD
#   on/IN
#   (NP the/DT verge/NN)
#   of/IN
#   (NP bankruptcy/NN)
#   ./.)
#
# Sentence 19: he worked closely with british designer jony ive to develop a line of products that had larger cultural ramifications, beginning with the think different advertising campaign and leading to the apple store, app store ios, imac, ipad, ipod, iphone, itunes, and itunes store.
# Detailed Constituency Tree (NP chunks):
#                                                                                                                                                                                        S
#    ____________________________________________________________________________________________________________________________________________________________________________________|___________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________
#   |        |          |         |      |       |        |      |        |     |        |          |      |         |        |    |   |   |   |   |   |   |    |     |                  NP                          NP              NP                      NP                                         NP                                           NP                       NP               NP      NP      NP       NP        NP                 NP
#   |        |          |         |      |       |        |      |        |     |        |          |      |         |        |    |   |   |   |   |   |   |    |     |       ___________|________________       ____|_____          |            ___________|____________            __________________|___________________________          _______|________         _______|________        |       |       |        |         |           _______|_____
# he/PRP worked/VBD closely/RB with/IN to/TO develop/VB of/IN that/WDT had/VBD ,/, beginning/VBG with/IN and/CC leading/VBG to/TO ,/, ,/, ,/, ,/, ,/, ,/, ,/, and/CC ./. british/JJ designer/NN jony/NN ive/NN a/DT     line/NN products/NNS larger/JJR cultural/JJ ramifications/ the/DT think/NN different/JJ advertising/NN campaign/NN the/DT apple/NN store/NN app/JJ store/NN ios/NNS imac/NN ipad/NN ipod/NN iphone/NN itunes/NNS itunes/NNS     store/NN
#                                                                                                                                                                                                                                                                        NNS
#
#
# Tree as string:
# (S
#   he/PRP
#   worked/VBD
#   closely/RB
#   with/IN
#   (NP british/JJ designer/NN jony/NN ive/NN)
#   to/TO
#   develop/VB
#   (NP a/DT line/NN)
#   of/IN
#   (NP products/NNS)
#   that/WDT
#   had/VBD
#   (NP larger/JJR cultural/JJ ramifications/NNS)
#   ,/,
#   beginning/VBG
#   with/IN
#   (NP the/DT think/NN different/JJ advertising/NN campaign/NN)
#   and/CC
#   leading/VBG
#   to/TO
#   (NP the/DT apple/NN store/NN)
#   ,/,
#   (NP app/JJ store/NN ios/NNS)
#   ,/,
#   (NP imac/NN)
#   ,/,
#   (NP ipad/NN)
#   ,/,
#   (NP ipod/NN)
#   ,/,
#   (NP iphone/NN)
#   ,/,
#   (NP itunes/NNS)
#   ,/,
#   and/CC
#   (NP itunes/NNS store/NN)
#   ./.)
#
# Sentence 20: in , the original mac os was replaced with the completely new mac os x later known as macos, based on nexts nextstep platform, giving the operating system a modern unixbased foundation for the first time.
# Detailed Constituency Tree (NP chunks):
#                                                                                                                                                         S
#    _____________________________________________________________________________________________________________________________________________________|________________________________________________________________________________________________________________________________________________________________
#   |    |     |         |          |          |          |         |       |    |      |       |    |      |        |     |              NP                    NP            NP                  NP                  NP                                                NP                                                 NP
#   |    |     |         |          |          |          |         |       |    |      |       |    |      |        |     |     _________|_______________      |       ______|____________       |         __________|___________          ____________________________|________________________________           _______|________
# in/IN ,/, was/VBD replaced/VBN with/IN completely/RB later/RB known/VBN as/IN ,/, based/VBN on/IN ,/, giving/VBG for/IN ./. the/DT original/JJ mac/NN os/NN the/DT new/JJ mac/NN os/NN x/NNP macos/NN nexts/JJ nextstep/NN platform/NN the/DT operating/NN system/NN a/DT modern/JJ unixbased/JJ foundation/NN the/DT first/JJ time/NN
#
#
# Tree as string:
# (S
#   in/IN
#   ,/,
#   (NP the/DT original/JJ mac/NN os/NN)
#   was/VBD
#   replaced/VBN
#   with/IN
#   (NP the/DT)
#   completely/RB
#   (NP new/JJ mac/NN os/NN x/NNP)
#   later/RB
#   known/VBN
#   as/IN
#   (NP macos/NN)
#   ,/,
#   based/VBN
#   on/IN
#   (NP nexts/JJ nextstep/NN platform/NN)
#   ,/,
#   giving/VBG
#   (NP
#     the/DT
#     operating/NN
#     system/NN
#     a/DT
#     modern/JJ
#     unixbased/JJ
#     foundation/NN)
#   for/IN
#   (NP the/DT first/JJ time/NN)
#   ./.)
#
# Sentence 21: in , jobs was diagnosed with a pancreatic neuroendocrine tumor.
# Detailed Constituency Tree (NP chunks):
#                                          S
#    ______________________________________|______________________
#   |    |     |          |          |     |     NP               NP
#   |    |     |          |          |     |     |       _________|__________________________
# in/IN ,/, was/VBD diagnosed/VBN with/IN ./. jobs/NNS a/DT pancreatic/JJ neuroendocrine/ tumor/NN
#                                                                                NN
#
#
# Tree as string:
# (S
#   in/IN
#   ,/,
#   (NP jobs/NNS)
#   was/VBD
#   diagnosed/VBN
#   with/IN
#   (NP a/DT pancreatic/JJ neuroendocrine/NN tumor/NN)
#   ./.)
#
# Sentence 22: he died of respiratory arrest related to the tumor in , at the age of , with tim cook succeeding him as ceo of apple.
# Detailed Constituency Tree (NP chunks):
#                                                                                             S
#    _________________________________________________________________________________________|____________________________________________________________________________________________________________________
#   |       |       |        |        |     |    |    |     |    |     |          |           |      |     |    |                  NP                   NP                  NP                NP           NP      NP
#   |       |       |        |        |     |    |    |     |    |     |          |           |      |     |    |         _________|______         _____|_____         _____|____        _____|_____       |       |
# he/PRP died/VBD of/IN related/VBN to/TO in/IN ,/, at/IN of/IN ,/, with/IN succeeding/VBG him/PRP as/IN of/IN ./. respiratory/NN     arrest/NN the/DT     tumor/NN the/DT     age/NN tim/JJ     cook/NN ceo/NN apple/NN
#
#
# Tree as string:
# (S
#   he/PRP
#   died/VBD
#   of/IN
#   (NP respiratory/NN arrest/NN)
#   related/VBN
#   to/TO
#   (NP the/DT tumor/NN)
#   in/IN
#   ,/,
#   at/IN
#   (NP the/DT age/NN)
#   of/IN
#   ,/,
#   with/IN
#   (NP tim/JJ cook/NN)
#   succeeding/VBG
#   him/PRP
#   as/IN
#   (NP ceo/NN)
#   of/IN
#   (NP apple/NN)
#   ./.)
#
# Sentence 23: in , he was posthumously awarded the presidential medal of freedom.
# Detailed Constituency Tree (NP chunks):
#                                               S
#    ___________________________________________|____________________________________________________
#   |    |    |       |           |             |        |    |                NP                    NP
#   |    |    |       |           |             |        |    |     ___________|___________          |
# in/IN ,/, he/PRP was/VBD posthumously/RB awarded/VBN of/IN ./. the/DT presidential/JJ medal/NN freedom/NN
#
#
# Tree as string:
# (S
#   in/IN
#   ,/,
#   he/PRP
#   was/VBD
#   posthumously/RB
#   awarded/VBN
#   (NP the/DT presidential/JJ medal/NN)
#   of/IN
#   (NP freedom/NN)
#   ./.)

# %% [markdown]
# # 11. Hypernyms and Hyponyms (WordNet)

# %%
# Extract ALL unique words from filtered tokens
unique_words = list(set(filtered_tokens))

for word in unique_words:
    print(f"\nWORD: '{word}'")

    # Get synsets for the word
    synsets = wn.synsets(word)

    if not synsets:
        print(f"  No synsets found for '{word}'")
        continue

    # Take first synset
    synset = synsets[0]
    print(f"  Definition: {synset.definition()}")
    print(f"  Example: {synset.examples() if synset.examples() else 'No example'}")

    # Hypernyms (more general concepts)
    hypernyms = synset.hypernyms()
    if hypernyms:
        print(f"\n  HYPERNYMS (more general): {len(hypernyms)} found")
        for hyp in hypernyms:
            print(f"    → {hyp.name()}")
            print(f"      Definition: {hyp.definition()}")
            # Get path hypernyms (higher level)
            hyper_paths = hyp.hypernyms()
            if hyper_paths:
                for path_hyp in hyper_paths:
                    print(f"        ↑ {path_hyp.name()}: {path_hyp.definition()}")
    else:
        print(f"\n  HYPERNYMS: None found")

    # Hyponyms (more specific concepts)
    hyponyms = synset.hyponyms()
    if hyponyms:
        print(f"\n  HYPONYMS (more specific): {len(hyponyms)} found")
        for hyp in hyponyms:
            print(f"    → {hyp.name()}")
            print(f"      Definition: {hyp.definition()}")
    else:
        print(f"\n  HYPONYMS: None found")

    # Full hierarchy path (no depth limit)
    print(f"\n  HIERARCHY PATH (up to root):")
    def show_path(s, level=0):
        print(f"    {'  ' * level}└─ {s.name()}")
        for hyp in s.hypernyms():
            show_path(hyp, level + 1)

    show_path(synset)

# Detailed example for ALL specific words from the text
print("\nDETAILED EXAMPLE FOR KEY WORDS FROM TEXT")

key_words = ['apple', 'computer', 'company', 'inventor', 'founder', 'ceo', 'pixar', 'next']

for word in key_words:
    print(f"\nDEEP ANALYSIS FOR: '{word}'")

    synsets = wn.synsets(word)
    if synsets:
        primary_synset = synsets[0]

        print(f"  Definition: {primary_synset.definition()}")
        print(f"  Lemmas: {primary_synset.lemma_names()}")

        # Get all hypernym paths (no limit)
        print("\n  All Hypernym Paths:")
        hypernym_paths = primary_synset.hypernym_paths()
        for i, path in enumerate(hypernym_paths, 1):
            print(f"    Path {i}: {' -> '.join([s.name().split('.')[0] for s in path])}")

        # Get all hyponyms (no limit on display)
        all_hyponyms = primary_synset.hyponyms()
        print(f"\n  Total hyponyms found: {len(all_hyponyms)}")
        if all_hyponyms:
            print("  All hyponyms:")
            for hyp in all_hyponyms:
                print(f"    - {hyp.name()}: {hyp.definition()}")
# Out:
# WORD: 'together'
#   Definition: mentally and emotionally stable
#   Example: ["she's really together"]
#
#   HYPERNYMS: None found
#
#   HYPONYMS: None found
#
#   HIERARCHY PATH (up to root):
#     └─ together.s.01
#
# WORD: 'visual'
#   Definition: relating to or using sight
#   Example: ['ocular inspection', 'an optical illusion', 'visual powers', 'visual navigation']
#
#   HYPERNYMS: None found
#
#   HYPONYMS: None found
#
#   HIERARCHY PATH (up to root):
#     └─ ocular.a.02
#
# WORD: 'store'
#   Definition: a mercantile establishment for the retail sale of goods or services
#   Example: ['he bought it at a shop on Cape Cod']
#
#   HYPERNYMS (more general): 1 found
#     → mercantile_establishment.n.01
#       Definition: a place of business for retailing goods
#         ↑ place_of_business.n.01: an establishment (a factory or an assembly plant or retail store or warehouse etc.) where business is conducted, goods are made or stored or processed or where services are rendered
#
#   HYPONYMS (more specific): 39 found
#     → florist.n.02
#       Definition: a shop where flowers and ornamental plants are sold
#     → cleaners.n.01
#       Definition: shop where dry cleaning is done
#     → shoe_shop.n.01
#       Definition: a shop where shoes are sold
#     → specialty_store.n.01
#       Definition: a store that sells only one kind of merchandise
#     → gift_shop.n.01
#       Definition: a shop that sells miscellaneous articles appropriate as gifts
#     → toyshop.n.01
#       Definition: shop where toys are sold
#     → booth.n.04
#       Definition: a small shop at a fair; for selling goods or entertainment
#     → canteen.n.02
#       Definition: sells food and personal items to personnel at an institution or school or camp etc.
#     → pizzeria.n.01
#       Definition: a shop where pizzas are made and sold
#     → boutique.n.01
#       Definition: a shop that sells women's clothes and jewelry
#     → repair_shop.n.01
#       Definition: a shop specializing in repairs and maintenance
#     → delicatessen.n.02
#       Definition: a shop selling ready-to-eat food products
#     → betting_shop.n.01
#       Definition: a licensed bookmaker's shop that is not at the race track
#     → building_supply_store.n.01
#       Definition: a store where builders can purchase materials for building houses and related structures
#     → package_store.n.01
#       Definition: a store that sells alcoholic beverages for consumption elsewhere
#     → barbershop.n.01
#       Definition: a shop where men can get their hair cut
#     → tobacco_shop.n.01
#       Definition: a shop that sells pipes and pipe tobacco and cigars and cigarettes
#     → pawnbroker's_shop.n.01
#       Definition: a shop where loans are made with personal property as security
#     → butcher_shop.n.01
#       Definition: a shop in which meat and poultry (and sometimes fish) are sold
#     → bazaar.n.01
#       Definition: a shop where a variety of goods are sold
#     → computer_store.n.01
#       Definition: a store that sells computers to the small businessperson or personal user
#     → thriftshop.n.01
#       Definition: a shop that sells secondhand goods at reduced prices
#     → junk_shop.n.01
#       Definition: a shop that sells cheap secondhand goods
#     → bookshop.n.01
#       Definition: a shop where books are sold
#     → bakery.n.01
#       Definition: a workplace where baked goods (breads and cakes and pastries) are produced or sold
#     → bodega.n.01
#       Definition: a small Hispanic shop selling wine and groceries
#     → perfumery.n.02
#       Definition: store where perfumes are sold
#     → commissary.n.01
#       Definition: a retail store that sells equipment and provisions (usually to military personnel)
#     → salon.n.02
#       Definition: a shop where hairdressers and beauticians work
#     → pet_shop.n.01
#       Definition: a shop where pet animals can be purchased
#     → convenience_store.n.01
#       Definition: a store selling a limited variety of food and pharmaceutical items; open long hours for the convenience of customers
#     → head_shop.n.01
#       Definition: a shop specializing in articles of interest to drug users
#     → outfitter.n.02
#       Definition: a shop that provides equipment for some specific purpose
#     → confectionery.n.02
#       Definition: a confectioner's shop
#     → hardware_store.n.01
#       Definition: a store selling hardware
#     → drugstore.n.01
#       Definition: a retail shop where medicine and other articles are sold
#     → millinery.n.01
#       Definition: shop selling women's hats
#     → clothing_store.n.01
#       Definition: a store where men's clothes are sold
#     → chain_store.n.01
#       Definition: one of a chain of retail stores under the same management and selling the same merchandise
#
#   HIERARCHY PATH (up to root):
#     └─ shop.n.01
#       └─ mercantile_establishment.n.01
#         └─ place_of_business.n.01
#           └─ establishment.n.04
#             └─ structure.n.01
#               └─ artifact.n.01
#                 └─ whole.n.02
#                   └─ object.n.01
#                     └─ physical_entity.n.01
#                       └─ entity.n.01
#
# WORD: 'board'
#   Definition: a committee having supervisory powers
#   Example: ['the board has seven members']
#
#   HYPERNYMS (more general): 1 found
#     → committee.n.01
#       Definition: a special group delegated to consider some matter;  - Milton Berle
#         ↑ administrative_unit.n.01: a unit with administrative responsibilities
#
#   HYPONYMS (more specific): 9 found
#     → federal_reserve_board.n.01
#       Definition: the seven-member board governing the Federal Reserve System
#     → appeal_board.n.01
#       Definition: a board of officials that are not judicial but are appointed to hear appeals
#     → zoning_board.n.01
#       Definition: a board of officials who divide an area into zones that are subject to different restrictions
#     → board_of_selectmen.n.01
#       Definition: a board of officials elected to administer the public business of a New England town
#     → school_board.n.01
#       Definition: a board in charge of local public schools
#     → governing_board.n.01
#       Definition: a board that manages the affairs of an institution
#     → draft_board.n.01
#       Definition: a board to select personnel for involuntary military service
#     → directorate.n.01
#       Definition: a group of persons chosen to govern the affairs of a corporation or other large institution
#     → advisory_board.n.01
#       Definition: a board appointed to advise the chief administrator
#
#   HIERARCHY PATH (up to root):
#     └─ board.n.01
#       └─ committee.n.01
#         └─ administrative_unit.n.01
#           └─ unit.n.03
#             └─ organization.n.01
#               └─ social_group.n.01
#                 └─ group.n.01
#                   └─ abstraction.n.06
#                     └─ entity.n.01
#
# WORD: 'india'
#   Definition: a republic in the Asian subcontinent in southern Asia; second most populous country in the world; achieved independence from the United Kingdom in 1947
#   Example: No example
#
#   HYPERNYMS: None found
#
#   HYPONYMS: None found
#
#   HIERARCHY PATH (up to root):
#     └─ india.n.01
#
# WORD: 'attended'
#   Definition: be present at (meetings, church services, university), etc.
#   Example: ['She attends class regularly', 'I rarely attend services at my church', 'did you go to the meeting?']
#
#   HYPERNYMS (more general): 1 found
#     → be.v.03
#       Definition: occupy a certain position or area; be somewhere
#
#   HYPONYMS (more specific): 2 found
#     → worship.v.03
#       Definition: attend religious services
#     → sit_in.v.01
#       Definition: attend as a visitor
#
#   HIERARCHY PATH (up to root):
#     └─ attend.v.01
#       └─ be.v.03
#
# WORD: 'studio'
#   Definition: workplace for the teaching or practice of an art
#   Example: ['she ran a dance studio', 'the music department provided studios for their students', "you don't need a studio to make a passport photograph"]
#
#   HYPERNYMS (more general): 1 found
#     → workplace.n.01
#       Definition: a place where work is done
#         ↑ geographic_point.n.01: a point on the surface of the Earth
#
#   HYPONYMS (more specific): 3 found
#     → artist's_workroom.n.01
#       Definition: a studio especially for an artist or designer
#     → recording_studio.n.01
#       Definition: studio where tapes and records are recorded
#     → broadcasting_studio.n.01
#       Definition: a studio where broadcasts originate
#
#   HIERARCHY PATH (up to root):
#     └─ studio.n.01
#       └─ workplace.n.01
#         └─ geographic_point.n.01
#           └─ point.n.02
#             └─ location.n.01
#               └─ object.n.01
#                 └─ physical_entity.n.01
#                   └─ entity.n.01
#
# WORD: 'ramifications'
#   Definition: the act of branching out or dividing into branches
#   Example: No example
#
#   HYPERNYMS (more general): 1 found
#     → division.n.03
#       Definition: the act or process of dividing
#         ↑ separation.n.09: the act of dividing or disconnecting
#
#   HYPONYMS (more specific): 4 found
#     → bifurcation.n.03
#       Definition: the act of splitting into two branches
#     → divarication.n.01
#       Definition: branching at a wide angle
#     → trifurcation.n.01
#       Definition: the act of splitting into three branches
#     → fibrillation.n.02
#       Definition: act or process of forming fibrils
#
#   HIERARCHY PATH (up to root):
#     └─ branching.n.01
#       └─ division.n.03
#         └─ separation.n.09
#           └─ change_of_integrity.n.01
#             └─ change.n.03
#               └─ action.n.01
#                 └─ act.n.02
#                   └─ event.n.01
#                     └─ psychological_feature.n.01
#                       └─ abstraction.n.06
#                         └─ entity.n.01
#
# WORD: 'october'
#   Definition: the month following September and preceding November
#   Example: No example
#
#   HYPERNYMS (more general): 1 found
#     → gregorian_calendar_month.n.01
#       Definition: a month in the Gregorian calendar
#         ↑ calendar_month.n.01: one of the twelve divisions of the calendar year
#
#   HYPONYMS: None found
#
#   HIERARCHY PATH (up to root):
#     └─ october.n.01
#       └─ gregorian_calendar_month.n.01
#         └─ calendar_month.n.01
#           └─ time_period.n.01
#             └─ fundamental_quantity.n.01
#               └─ measure.n.02
#                 └─ abstraction.n.06
#                   └─ entity.n.01
#
# WORD: 'original'
#   Definition: an original creation (i.e., an audio recording) from which copies can be made
#   Example: No example
#
#   HYPERNYMS (more general): 1 found
#     → creation.n.02
#       Definition: an artifact that has been brought into existence by someone
#         ↑ artifact.n.01: a man-made object taken as a whole
#
#   HYPONYMS: None found
#
#   HIERARCHY PATH (up to root):
#     └─ master.n.06
#       └─ creation.n.02
#         └─ artifact.n.01
#           └─ whole.n.02
#             └─ object.n.01
#               └─ physical_entity.n.01
#                 └─ entity.n.01
#
# WORD: 'computeranimated'
#   No synsets found for 'computeranimated'
#
# WORD: 'new'
#   Definition: not of long duration; having just (or relatively recently) come into being or been made or acquired or discovered
#   Example: ['a new law', 'new cars', 'a new comet', 'a new friend', 'a new year', 'the New World']
#
#   HYPERNYMS: None found
#
#   HYPONYMS: None found
#
#   HIERARCHY PATH (up to root):
#     └─ new.a.01
#
# WORD: 'college'
#   Definition: the body of faculty and students of a college
#   Example: No example
#
#   HYPERNYMS (more general): 1 found
#     → body.n.02
#       Definition: a group of persons associated by some common tie or occupation and regarded as an entity
#         ↑ social_group.n.01: people sharing some social relation
#
#   HYPONYMS: None found
#
#   HIERARCHY PATH (up to root):
#     └─ college.n.01
#       └─ body.n.02
#         └─ social_group.n.01
#           └─ group.n.01
#             └─ abstraction.n.06
#               └─ entity.n.01
#
# WORD: 'unsuccessful'
#   Definition: not successful; having failed or having an unfavorable outcome
#   Example: No example
#
#   HYPERNYMS: None found
#
#   HYPONYMS: None found
#
#   HIERARCHY PATH (up to root):
#     └─ unsuccessful.a.01
#
# WORD: 'freedom'
#   Definition: the condition of being free; the power to act or speak or think without externally imposed restraints
#   Example: No example
#
#   HYPERNYMS (more general): 1 found
#     → state.n.02
#       Definition: the way something is with respect to its main attributes
#         ↑ attribute.n.02: an abstraction belonging to or characteristic of an entity
#
#   HYPONYMS (more specific): 10 found
#     → liberty.n.02
#       Definition: freedom of choice
#     → svoboda.n.01
#       Definition: (Russia) freedom
#     → freedom_of_the_seas.n.01
#       Definition: the right of merchant ships to travel freely in international waters
#     → enfranchisement.n.01
#       Definition: freedom from political subjugation or servitude
#     → liberty.n.03
#       Definition: personal freedom from servitude or confinement or oppression
#     → academic_freedom.n.01
#       Definition: the freedom of teachers and students to express their ideas in school without religious or political or institutional restrictions
#     → free_hand.n.01
#       Definition: freedom to do as you see fit
#     → independence.n.01
#       Definition: freedom from control or influence of another or others
#     → civil_liberty.n.01
#       Definition: one's freedom to exercise one's rights as guaranteed under the laws of the country
#     → free_rein.n.01
#       Definition: the removal of constraints
#
#   HIERARCHY PATH (up to root):
#     └─ freedom.n.01
#       └─ state.n.02
#         └─ attribute.n.02
#           └─ abstraction.n.06
#             └─ entity.n.01
#
# WORD: 'year'
#   Definition: a period of time containing 365 (or 366) days
#   Example: ['she is 4 years old', 'in the year 1920']
#
#   HYPERNYMS (more general): 1 found
#     → time_period.n.01
#       Definition: an amount of time
#         ↑ fundamental_quantity.n.01: one of the four quantities that are the basis of systems of measurement
#
#   HYPONYMS (more specific): 12 found
#     → off_year.n.01
#       Definition: a year in which productivity is low or inferior
#     → calendar_year.n.01
#       Definition: the year (reckoned from January 1 to December 31) according to Gregorian calendar
#     → y2k.n.01
#       Definition: the year 2000 in the Gregorian calendar
#     → new_year.n.01
#       Definition: the calendar year just begun
#     → year_of_grace.n.01
#       Definition: any year of the Christian era
#     → off_year.n.02
#       Definition: a year in which no major political elections are held
#     → annum.n.01
#       Definition: (Latin) year
#     → church_year.n.01
#       Definition: the year in the ecclesiastical calendar; especially feast days and special seasons
#     → common_year.n.01
#       Definition: a year that is not a leap year
#     → holy_year.n.01
#       Definition: (Roman Catholic Church) a period of remission from sin (usually granted every 25 years)
#     → leap_year.n.01
#       Definition: in the Gregorian calendar: any year divisible by 4 except centenary years divisible by 400
#     → fiscal_year.n.01
#       Definition: any accounting period of 12 months
#
#   HIERARCHY PATH (up to root):
#     └─ year.n.01
#       └─ time_period.n.01
#         └─ fundamental_quantity.n.01
#           └─ measure.n.02
#             └─ abstraction.n.06
#               └─ entity.n.01
#
# WORD: 'become'
#   Definition: enter or assume a certain state or condition
#   Example: ['He became annoyed when he heard the bad news', 'It must be getting more serious', 'her face went red with anger', 'She went into ecstasy', 'Get going!']
#
#   HYPERNYMS (more general): 1 found
#     → change_state.v.01
#       Definition: undergo a transformation or a change of position or action
#         ↑ change.v.02: undergo a change; become different in essence; losing one's or its original nature
#
#   HYPONYMS (more specific): 8 found
#     → sober_up.v.01
#       Definition: become sober after excessive alcohol consumption
#     → take_effect.v.01
#       Definition: go into effect or become effective or operative
#     → break.v.16
#       Definition: come into being
#     → take.v.29
#       Definition: be seized or affected in a specified way
#     → run.v.14
#       Definition: change from one state to another
#     → settle.v.08
#       Definition: become resolved, fixed, established, or quiet
#     → sober_up.v.02
#       Definition: become more realistic
#     → work.v.27
#       Definition: arrive at a certain condition through repeated motion
#
#   HIERARCHY PATH (up to root):
#     └─ become.v.01
#       └─ change_state.v.01
#         └─ change.v.02
#
# WORD: 'major'
#   Definition: a commissioned military officer in the United States Army or Air Force or Marines; below lieutenant colonel and above captain
#   Example: No example
#
#   HYPERNYMS (more general): 1 found
#     → commissioned_military_officer.n.01
#       Definition: a commissioned officer in the Army or Air Force or Marine Corps
#         ↑ commissioned_officer.n.01: a military officer holding a commission
#
#   HYPONYMS: None found
#
#   HIERARCHY PATH (up to root):
#     └─ major.n.01
#       └─ commissioned_military_officer.n.01
#         └─ commissioned_officer.n.01
#           └─ military_officer.n.01
#             └─ serviceman.n.01
#               └─ skilled_worker.n.01
#                 └─ worker.n.01
#                   └─ person.n.01
#                     └─ causal_agent.n.01
#                       └─ physical_entity.n.01
#                         └─ entity.n.01
#                     └─ organism.n.01
#                       └─ living_thing.n.01
#                         └─ whole.n.02
#                           └─ object.n.01
#                             └─ physical_entity.n.01
#                               └─ entity.n.01
#
# WORD: 'xerox'
#   Definition: a copy made by a xerographic printer
#   Example: No example
#
#   HYPERNYMS (more general): 1 found
#     → copy.n.02
#       Definition: a thing made to be similar or identical to another thing
#         ↑ representation.n.02: a creation that is a visual or tangible rendering of someone or something
#
#   HYPONYMS: None found
#
#   HIERARCHY PATH (up to root):
#     └─ xerox.n.01
#       └─ copy.n.02
#         └─ representation.n.02
#           └─ creation.n.02
#             └─ artifact.n.01
#               └─ whole.n.02
#                 └─ object.n.01
#                   └─ physical_entity.n.01
#                     └─ entity.n.01
#
# WORD: 'mac'
#   Definition: a waterproof raincoat made of rubberized fabric
#   Example: No example
#
#   HYPERNYMS (more general): 1 found
#     → raincoat.n.01
#       Definition: a water-resistant coat
#         ↑ coat.n.01: an outer garment that has sleeves and covers the body from shoulder down; worn outdoors
#
#   HYPONYMS (more specific): 1 found
#     → oilskin.n.01
#       Definition: a macintosh made from cotton fabric treated with oil and pigment to make it waterproof
#
#   HIERARCHY PATH (up to root):
#     └─ macintosh.n.02
#       └─ raincoat.n.01
#         └─ coat.n.01
#           └─ overgarment.n.01
#             └─ garment.n.01
#               └─ clothing.n.01
#                 └─ covering.n.02
#                   └─ artifact.n.01
#                     └─ whole.n.02
#                       └─ object.n.01
#                         └─ physical_entity.n.01
#                           └─ entity.n.01
#                 └─ consumer_goods.n.01
#                   └─ commodity.n.01
#                     └─ artifact.n.01
#                       └─ whole.n.02
#                         └─ object.n.01
#                           └─ physical_entity.n.01
#                             └─ entity.n.01
#
# WORD: 'toy'
#   Definition: an artifact designed to be played with
#   Example: No example
#
#   HYPERNYMS (more general): 1 found
#     → artifact.n.01
#       Definition: a man-made object taken as a whole
#         ↑ whole.n.02: an assemblage of parts that is regarded as a single entity
#
#   HYPONYMS (more specific): 33 found
#     → hula-hoop.n.01
#       Definition: plaything consisting of a tubular plastic hoop for swinging around the hips
#     → kite.n.03
#       Definition: plaything consisting of a light frame covered with tissue paper; flown in wind at end of a string
#     → stick_horse.n.01
#       Definition: a child's plaything consisting on an imitation horse's head on one end of a stick
#     → doll.n.01
#       Definition: a small replica of a person; used as a toy
#     → seesaw.n.01
#       Definition: a plaything consisting of a board balanced on a fulcrum; the board is ridden up and down by children at either end
#     → kaleidoscope.n.02
#       Definition: an optical toy in a tube; it produces symmetrical patterns as bits of colored glass are reflected by mirrors
#     → jungle_gym.n.01
#       Definition: a structure of vertical and horizontal rods where children can climb and play
#     → pea_shooter.n.01
#       Definition: a straight narrow tube through which pellets (as dried peas) can be blown at a target
#     → water_pistol.n.01
#       Definition: plaything consisting of a toy pistol that squirts water
#     → popgun.n.01
#       Definition: plaything consisting of a toy gun that makes a popping sound
#     → top.n.08
#       Definition: a conical child's plaything tapering to a steel point on which it can be made to spin
#     → jack-in-the-box.n.01
#       Definition: plaything consisting of a toy clown that jumps out of a box when the lid is opened
#     → train_set.n.01
#       Definition: a toy consisting of small models of railroad trains and the track for them to run on
#     → rattle.n.02
#       Definition: a baby's toy that makes percussive noises when shaken
#     → sandbox.n.02
#       Definition: a plaything consisting of a pile of sand or a box filled with sand for children to play in
#     → slingshot.n.01
#       Definition: a plaything consisting of a Y-shaped stick with elastic between the arms; used to propel small stones
#     → teddy.n.01
#       Definition: plaything consisting of a child's toy bear (usually plush and stuffed with soft materials)
#     → ball.n.06
#       Definition: a spherical object used as a plaything
#     → jumping_jack.n.01
#       Definition: plaything consisting of a toy figure with movable joints that can be made to dance by pulling strings
#     → meccano.n.01
#       Definition: a child's construction set for making mechanical models
#     → yo-yo.n.01
#       Definition: a toy consisting of a spool that is reeled up and down on a string by motions of the hand
#     → dollhouse.n.02
#       Definition: a small model of a house used as a toy by children
#     → frisbee.n.01
#       Definition: a light, plastic disk about 10 inches in diameter; propelled with a flip of the wrist for recreation or competition
#     → hobby.n.02
#       Definition: a child's plaything consisting of an imitation horse mounted on rockers; the child straddles it and pretends to ride
#     → pinata.n.01
#       Definition: plaything consisting of a container filled with toys and candy; suspended from a height for blindfolded children to break with sticks
#     → swing.n.02
#       Definition: mechanical device used as a plaything to support someone swinging back and forth
#     → slide.n.04
#       Definition: plaything consisting of a sloping chute down which children can slide
#     → cockhorse.n.01
#       Definition: anything used as a toy horse (such as a rocking horse or one knee of an adult)
#     → playhouse.n.01
#       Definition: plaything consisting of a small model of a house that children can play inside of
#     → balloon.n.02
#       Definition: small thin inflatable rubber bag with narrow neck
#     → pinwheel.n.03
#       Definition: a toy consisting of vanes of colored paper or plastic that is pinned to a stick and spins when it is pointed into the wind
#     → pogo_stick.n.01
#       Definition: plaything consisting of a pole with foot rests and a strong spring; propelled by jumping
#     → lego.n.01
#       Definition: (trademark) a child's plastic construction set for making mechanical models
#
#   HIERARCHY PATH (up to root):
#     └─ plaything.n.01
#       └─ artifact.n.01
#         └─ whole.n.02
#           └─ object.n.01
#             └─ physical_entity.n.01
#               └─ entity.n.01
#
# WORD: 'giving'
#   Definition: the act of giving
#   Example: No example
#
#   HYPERNYMS (more general): 1 found
#     → sharing.n.04
#       Definition: a distribution in shares
#         ↑ distribution.n.03: the act of distributing or spreading or apportioning
#
#   HYPONYMS (more specific): 7 found
#     → endowment.n.03
#       Definition: the act of endowing with a permanent source of income
#     → contribution.n.03
#       Definition: act of giving in common with others for a common purpose especially to a charity
#     → alms-giving.n.01
#       Definition: making voluntary contributions to aid the poor
#     → oblation.n.01
#       Definition: the act of contributing to the funds of a church or charity
#     → accordance.n.02
#       Definition: the act of granting rights
#     → charity.n.03
#       Definition: an activity or gift that benefits the public at large
#     → bestowal.n.01
#       Definition: the act of conferring an honor or presenting a gift
#
#   HIERARCHY PATH (up to root):
#     └─ giving.n.01
#       └─ sharing.n.04
#         └─ distribution.n.03
#           └─ act.n.02
#             └─ event.n.01
#               └─ psychological_feature.n.01
#                 └─ abstraction.n.06
#                   └─ entity.n.01
#
# WORD: 'modern'
#   Definition: a contemporary person
#   Example: No example
#
#   HYPERNYMS (more general): 1 found
#     → person.n.01
#       Definition: a human being
#         ↑ causal_agent.n.01: any entity that produces an effect or is responsible for events or results
#         ↑ organism.n.01: a living thing that has (or can develop) the ability to act or function independently
#
#   HYPONYMS: None found
#
#   HIERARCHY PATH (up to root):
#     └─ modern.n.01
#       └─ person.n.01
#         └─ causal_agent.n.01
#           └─ physical_entity.n.01
#             └─ entity.n.01
#         └─ organism.n.01
#           └─ living_thing.n.01
#             └─ whole.n.02
#               └─ object.n.01
#                 └─ physical_entity.n.01
#                   └─ entity.n.01
#
# WORD: 'companys'
#   Definition: an institution created to conduct business
#   Example: ['he only invests in large well-established companies', 'he started the company in his garage']
#
#   HYPERNYMS (more general): 1 found
#     → institution.n.01
#       Definition: an organization founded and united for a specific purpose
#         ↑ organization.n.01: a group of people who work together
#
#   HYPONYMS (more specific): 36 found
#     → target_company.n.01
#       Definition: a company that has been chosen as attractive for takeover by a potential acquirer
#     → oil_company.n.01
#       Definition: a company that sells oil
#     → east_india_company.n.01
#       Definition: an English company formed in 1600 to develop trade with the new British colonies in India and southeastern Asia; in the 18th century it assumed administrative control of Bengal and held it until the British army took over in 1858 after the Indian Mutiny
#     → bureau_de_change.n.01
#       Definition: (French) an establishment where you can exchange foreign money
#     → broadcasting_company.n.01
#       Definition: a company that manages tv or radio stations
#     → closed_shop.n.01
#       Definition: a company that hires only union members
#     → think_tank.n.01
#       Definition: a company that does research for hire and issues reports on the implications
#     → furniture_company.n.01
#       Definition: a company that sells furniture
#     → dot-com.n.01
#       Definition: a company that operates its business primarily on the internet using a URL that ends in `.com'
#     → steel_company.n.01
#       Definition: a company that makes and sells steel
#     → shipping_company.n.01
#       Definition: a company that provides shipping services
#     → food_company.n.01
#       Definition: a company that processes and sells food
#     → mover.n.04
#       Definition: a company that moves the possessions of a family or business from one site to another
#     → transportation_company.n.01
#       Definition: a company providing transportation
#     → union_shop.n.01
#       Definition: a company allowed to hire nonunion workers on the condition that they will join the union within a specified time
#     → pipeline_company.n.01
#       Definition: a company that operates oil pipelines for the oil industry
#     → mining_company.n.01
#       Definition: a company that owns and manages mines
#     → open_shop.n.01
#       Definition: a company whose workers are hired without regard to their membership in a labor union
#     → joint-stock_company.n.01
#       Definition: a company (usually unincorporated) which has the capital of its members pooled in a common fund; transferable shares represent ownership interest; shareholders are legally liable for all debts of the company
#     → printing_concern.n.01
#       Definition: a company that does commercial printing
#     → stock_company.n.01
#       Definition: a company whose capital is represented by stock
#     → white_knight.n.01
#       Definition: a company that is a friendly acquirer in a takeover
#     → film_company.n.01
#       Definition: a company that makes, advertises, and distributes movies
#     → distributor.n.03
#       Definition: a company that markets merchandise
#     → drug_company.n.01
#       Definition: a company that makes and sells pharmaceuticals
#     → shipper.n.02
#       Definition: a company in the business of shipping freight
#     → service.n.04
#       Definition: a company or agency that performs a public service; subject to government regulation
#     → limited_company.n.01
#       Definition: a company that is organized to give its owners limited liability
#     → livery_company.n.01
#       Definition: one of the chartered companies of London originating with the craft guilds
#     → record_company.n.01
#       Definition: a company that makes and sells musical recordings
#     → electronics_company.n.01
#       Definition: a company that makes and sells electronic instruments
#     → subsidiary_company.n.01
#       Definition: a company that is completely controlled by another company
#     → corporate_investor.n.01
#       Definition: a company that invests in (acquires control of) other companies
#     → car_company.n.01
#       Definition: a company that makes and sells automobiles
#     → packaging_company.n.01
#       Definition: a company that packages goods for sale or shipment or storage
#     → holding_company.n.01
#       Definition: a company with controlling shares in other companies
#
#   HIERARCHY PATH (up to root):
#     └─ company.n.01
#       └─ institution.n.01
#         └─ organization.n.01
#           └─ social_group.n.01
#             └─ group.n.01
#               └─ abstraction.n.06
#                 └─ entity.n.01
#
# WORD: 'traveled'
#   Definition: change location; move, travel, or proceed, also metaphorically
#   Example: ['How fast does your new car go?', 'We travelled from Rome to Naples by bus', 'The policemen went from door to door looking for the suspect', 'The soldiers moved towards the city in an attempt to take it before night fell', 'news travelled fast']
#
#   HYPERNYMS: None found
#
#   HYPONYMS (more specific): 123 found
#     → ease.v.01
#       Definition: move gently or carefully
#     → pass_over.v.04
#       Definition: fly over
#     → island_hop.v.01
#       Definition: travel from one island to the next
#     → wheel.v.03
#       Definition: move along on or as if on wheels or a wheeled vehicle
#     → whine.v.01
#       Definition: move with a whining sound
#     → step.v.01
#       Definition: shift or move by taking a step
#     → precede.v.04
#       Definition: move ahead (of others) in time or space
#     → crawl.v.01
#       Definition: move slowly; in the case of people or animals with the body near the ground
#     → beetle.v.02
#       Definition: fly or go in a manner resembling a beetle
#     → roll.v.12
#       Definition: move about aimlessly or without any destination, often in search of food or employment
#     → slice_into.v.01
#       Definition: move through a body or an object with a slicing motion
#     → swim.v.01
#       Definition: travel through water
#     → pursue.v.02
#       Definition: follow in or as if in pursuit
#     → retreat.v.02
#       Definition: move away, as for privacy
#     → billow.v.02
#       Definition: move with great difficulty
#     → prance.v.02
#       Definition: spring forward on the hind legs
#     → taxi.v.01
#       Definition: travel slowly
#     → travel.v.05
#       Definition: undergo transportation as in a vehicle
#     → ride.v.04
#       Definition: move like a floating object
#     → speed.v.04
#       Definition: travel at an excessive or illegal velocity
#     → fall.v.15
#       Definition: move in a specified direction
#     → tram.v.01
#       Definition: travel by tram
#     → forge.v.05
#       Definition: move or act with a sudden increase in speed or energy
#     → plow.v.03
#       Definition: move in a way resembling that of a plow cutting into or going through the soil
#     → weave.v.04
#       Definition: to move or cause to move in a sinuous, spiral, or circular course
#     → follow.v.04
#       Definition: travel along a certain course
#     → flock.v.01
#       Definition: move as a crowd or in a group
#     → proceed.v.02
#       Definition: move ahead; travel onward in time or space
#     → angle.v.01
#       Definition: move or proceed at an angle
#     → career.v.01
#       Definition: move headlong at high speed
#     → repair.v.03
#       Definition: move, travel, or proceed toward some place
#     → scramble.v.01
#       Definition: to move hurriedly
#     → rush.v.01
#       Definition: move fast
#     → propagate.v.02
#       Definition: travel through the air
#     → back.v.02
#       Definition: travel backward
#     → ride.v.10
#       Definition: sit on and control a vehicle
#     → seek.v.04
#       Definition: go to or towards
#     → travel.v.04
#       Definition: travel upon or across
#     → run.v.11
#       Definition: move about freely and without restraint, or act as if running around in an uncontrolled way
#     → betake_oneself.v.01
#       Definition: displace oneself; go from one location to another
#     → float.v.05
#       Definition: move lightly, as if suspended
#     → precess.v.01
#       Definition: move in a gyrating fashion
#     → fly.v.01
#       Definition: travel through the air; be airborne
#     → float.v.02
#       Definition: be afloat either on or below a liquid surface and not sink to the bottom
#     → ski.v.01
#       Definition: move along on skis
#     → descend.v.01
#       Definition: move downward and lower, but not necessarily all the way
#     → hurtle.v.01
#       Definition: move with or as if with a rushing sound
#     → bounce.v.03
#       Definition: move up and down repeatedly
#     → cruise.v.02
#       Definition: travel at a moderate speed
#     → bang.v.04
#       Definition: move noisily
#     → circle.v.02
#       Definition: move in circles
#     → go_around.v.02
#       Definition: become widely known and passed on
#     → circulate.v.07
#       Definition: move around freely
#     → withdraw.v.01
#       Definition: pull back or move away or backward
#     → stray.v.02
#       Definition: wander from a direct course or at random
#     → swim.v.05
#       Definition: move as if gliding through water
#     → pass.v.01
#       Definition: go across or through
#     → step.v.02
#       Definition: put down or press the foot, place the foot
#     → whistle.v.02
#       Definition: move with, or as with, a whistling sound
#     → trundle.v.01
#       Definition: move heavily
#     → drive.v.02
#       Definition: travel or be transported in a vehicle
#     → fall.v.01
#       Definition: descend in free fall under the influence of gravity
#     → travel.v.06
#       Definition: travel from place to place, as for the purpose of finding work, preaching, or acting as a judge
#     → snowshoe.v.01
#       Definition: travel on snowshoes
#     → play.v.09
#       Definition: move or seem to move quickly, lightly, or irregularly
#     → carry.v.36
#       Definition: cover a certain distance or advance beyond
#     → swap.v.02
#       Definition: move (a piece of a program) into memory, in computer science
#     → swing.v.03
#       Definition: change direction with a swinging motion; turn
#     → return.v.01
#       Definition: go or come back to place, condition, or activity where one has been before
#     → automobile.v.01
#       Definition: travel in an automobile
#     → caravan.v.01
#       Definition: travel in a caravan
#     → turn.v.06
#       Definition: pass to the other side of
#     → ghost.v.01
#       Definition: move like a ghost
#     → steamer.v.01
#       Definition: travel by means of steam power
#     → draw.v.12
#       Definition: move or go steadily or gradually
#     → get_around.v.04
#       Definition: move around; move from place to place
#     → drive.v.14
#       Definition: move by being propelled by a force
#     → walk.v.01
#       Definition: use one's feet to advance; advance by steps
#     → outflank.v.01
#       Definition: go around the flank of (an opposing army)
#     → hiss.v.02
#       Definition: move with a whooshing sound
#     → sift.v.01
#       Definition: move as if through a sieve
#     → travel_purposefully.v.01
#       Definition: travel volitionally and in a certain direction with a certain goal
#     → come.v.11
#       Definition: cover a certain distance
#     → whish.v.02
#       Definition: move with a whishing sound
#     → push.v.09
#       Definition: move strenuously and with effort
#     → ride.v.01
#       Definition: sit and travel on the back of animal, usually while controlling its motions
#     → zoom.v.02
#       Definition: move with a low humming noise
#     → circle.v.01
#       Definition: travel around something
#     → zigzag.v.01
#       Definition: travel along a zigzag path
#     → ferry.v.03
#       Definition: travel by ferry
#     → raft.v.02
#       Definition: travel by raft in water
#     → lance.v.01
#       Definition: move quickly, as if by cutting one's way
#     → pace.v.02
#       Definition: go at a pace
#     → step.v.06
#       Definition: move with one's feet in a specific manner
#     → accompany.v.02
#       Definition: go or travel along with
#     → ascend.v.01
#       Definition: travel up,
#     → shuttle.v.01
#       Definition: travel back and forth between two points
#     → lurch.v.03
#       Definition: move slowly and unsteadily
#     → advance.v.01
#       Definition: move forward, also in the metaphorical sense
#     → rise.v.01
#       Definition: move upward
#     → do.v.13
#       Definition: travel or traverse (a distance)
#     → float.v.01
#       Definition: be in motion due to some air or water current
#     → whisk.v.02
#       Definition: move quickly and nimbly
#     → travel_rapidly.v.01
#       Definition: move very fast
#     → pan.v.01
#       Definition: make a sweeping movement
#     → circuit.v.01
#       Definition: make a circuit
#     → slither.v.01
#       Definition: to pass or move unobtrusively or smoothly
#     → fly.v.06
#       Definition: be dispersed or disseminated
#     → transfer.v.06
#       Definition: change from one vehicle or transportation line to another
#     → wend.v.01
#       Definition: direct one's course or way
#     → drag.v.04
#       Definition: move slowly and as if with great effort
#     → come.v.01
#       Definition: move toward, travel toward something or somebody or approach something or somebody
#     → travel_by.v.01
#       Definition: move past
#     → breeze.v.02
#       Definition: to proceed quickly and easily
#     → derail.v.02
#       Definition: run off or leave the rails
#     → run.v.34
#       Definition: travel rapidly, by any (unspecified) means
#     → walk.v.10
#       Definition: take a walk; go for a walk; walk for pleasure
#     → trail.v.03
#       Definition: move, proceed, or walk draggingly or slowly
#     → follow.v.01
#       Definition: to travel behind, go after, come after
#     → swash.v.01
#       Definition: make violent, noisy movements
#     → round.v.01
#       Definition: wind around; move along a circular course
#     → glide.v.01
#       Definition: move smoothly and effortlessly
#     → retrograde.v.02
#       Definition: move in a direction contrary to the usual one
#
#   HIERARCHY PATH (up to root):
#     └─ travel.v.01
#
# WORD: 'founder'
#   Definition: inflammation of the laminated tissue that attaches the hoof to the foot of a horse
#   Example: No example
#
#   HYPERNYMS (more general): 1 found
#     → inflammation.n.01
#       Definition: a response of body tissues to injury or irritation; characterized by pain and swelling and redness and heat
#         ↑ symptom.n.01: (medicine) any sensation or change in bodily function that is experienced by a patient and is associated with a particular disease
#
#   HYPONYMS: None found
#
#   HIERARCHY PATH (up to root):
#     └─ laminitis.n.01
#       └─ inflammation.n.01
#         └─ symptom.n.01
#           └─ evidence.n.01
#             └─ information.n.02
#               └─ cognition.n.01
#                 └─ psychological_feature.n.01
#                   └─ abstraction.n.06
#                     └─ entity.n.01
#
# WORD: 'reviving'
#   Definition: cause to regain consciousness
#   Example: ['The doctors revived the comatose man']
#
#   HYPERNYMS (more general): 1 found
#     → bring_to.v.01
#       Definition: return to consciousness
#         ↑ awaken.v.01: cause to become awake or conscious
#
#   HYPONYMS (more specific): 2 found
#     → boot.v.02
#       Definition: cause to load (an operating system) and start the initial processes
#     → resurrect.v.01
#       Definition: cause to become alive again
#
#   HIERARCHY PATH (up to root):
#     └─ resuscitate.v.01
#       └─ bring_to.v.01
#         └─ awaken.v.01
#           └─ change.v.01
#
# WORD: 'verge'
#   Definition: a region marking a boundary
#   Example: No example
#
#   HYPERNYMS (more general): 1 found
#     → boundary.n.02
#       Definition: a line determining the limits of an area
#         ↑ line.n.04: a length (straight or curved) without breadth or thickness; the trace of a moving point
#
#   HYPONYMS: None found
#
#   HIERARCHY PATH (up to root):
#     └─ brink.n.01
#       └─ boundary.n.02
#         └─ line.n.04
#           └─ shape.n.02
#             └─ attribute.n.02
#               └─ abstraction.n.06
#                 └─ entity.n.01
#
# WORD: 'walt'
#   No synsets found for 'walt'
#
# WORD: 'inventor'
#   Definition: someone who is the first to think of or make something
#   Example: No example
#
#   HYPERNYMS (more general): 1 found
#     → creator.n.02
#       Definition: a person who grows or makes or invents things
#         ↑ person.n.01: a human being
#
#   HYPONYMS (more specific): 1 found
#     → patentee.n.01
#       Definition: the inventor to whom a patent is issued
#
#   HIERARCHY PATH (up to root):
#     └─ inventor.n.01
#       └─ creator.n.02
#         └─ person.n.01
#           └─ causal_agent.n.01
#             └─ physical_entity.n.01
#               └─ entity.n.01
#           └─ organism.n.01
#             └─ living_thing.n.01
#               └─ whole.n.02
#                 └─ object.n.01
#                   └─ physical_entity.n.01
#                     └─ entity.n.01
#
# WORD: 'production'
#   Definition: the act or process of producing something
#   Example: ["Shakespeare's production of poetry was enormous", 'the production of white blood cells']
#
#   HYPERNYMS (more general): 1 found
#     → act.n.02
#       Definition: something that people do or cause to happen
#         ↑ event.n.01: something that happens at a given place and time
#
#   HYPONYMS (more specific): 6 found
#     → growing.n.02
#       Definition: (electronics) the production of (semiconductor) crystals by slow crystallization from the molten state
#     → canalization.n.01
#       Definition: the production of a canal or a conversion to canals
#     → rainmaking.n.01
#       Definition: activity intended to produce rain
#     → devising.n.01
#       Definition: the act that results in something coming to be
#     → foliation.n.04
#       Definition: the production of foil by cutting or beating metal into thin leaves
#     → steel_production.n.01
#       Definition: making steel from pig iron
#
#   HIERARCHY PATH (up to root):
#     └─ production.n.01
#       └─ act.n.02
#         └─ event.n.01
#           └─ psychological_feature.n.01
#             └─ abstraction.n.06
#               └─ entity.n.01
#
# WORD: 'jony'
#   No synsets found for 'jony'
#
# WORD: 'successful'
#   Definition: having succeeded or being marked by a favorable outcome
#   Example: ['a successful architect', 'a successful business venture']
#
#   HYPERNYMS: None found
#
#   HYPONYMS: None found
#
#   HIERARCHY PATH (up to root):
#     └─ successful.a.01
#
# WORD: 'iphone'
#   No synsets found for 'iphone'
#
# WORD: 'producing'
#   Definition: bring forth or yield
#   Example: ['The tree would not produce fruit']
#
#   HYPERNYMS (more general): 1 found
#     → make.v.03
#       Definition: make or cause to be or to become
#
#   HYPONYMS (more specific): 4 found
#     → manufacture.v.03
#       Definition: produce naturally
#     → give_birth.v.01
#       Definition: cause to be born
#     → sporulate.v.01
#       Definition: produce spores
#     → grind_out.v.01
#       Definition: produce in a routine or monotonous manner
#
#   HIERARCHY PATH (up to root):
#     └─ produce.v.01
#       └─ make.v.03
#
# WORD: 'age'
#   Definition: how long something has existed
#   Example: ['it was replaced because of its age']
#
#   HYPERNYMS (more general): 1 found
#     → property.n.02
#       Definition: a basic or essential attribute shared by all members of a class
#         ↑ attribute.n.02: an abstraction belonging to or characteristic of an entity
#
#   HYPONYMS (more specific): 9 found
#     → oldness.n.01
#       Definition: the opposite of youngness
#     → bone_age.n.01
#       Definition: a person's age measured by matching their bone development (as shown by X rays) with bone development of an average person of known chronological age
#     → oldness.n.02
#       Definition: the quality of being old; the opposite of newness
#     → developmental_age.n.01
#       Definition: a measure of a child's development (in body size or motor skill or psychological function) expressed in terms of age norms
#     → fetal_age.n.01
#       Definition: the age of an embryo counting from the time of fertilization
#     → newness.n.01
#       Definition: the quality of being new; the opposite of oldness
#     → mental_age.n.01
#       Definition: the level of intellectual development as measured by an intelligence test
#     → youngness.n.01
#       Definition: the opposite of oldness
#     → chronological_age.n.01
#       Definition: age measured by the time (years and months) that something or someone has existed
#
#   HIERARCHY PATH (up to root):
#     └─ age.n.01
#       └─ property.n.02
#         └─ attribute.n.02
#           └─ abstraction.n.06
#             └─ entity.n.01
#
# WORD: 'interface'
#   Definition: (chemistry) a surface forming a common boundary between two things (two objects or liquids or chemical phases)
#   Example: No example
#
#   HYPERNYMS (more general): 1 found
#     → surface.n.02
#       Definition: the extended two-dimensional outer boundary of a three-dimensional object
#         ↑ boundary.n.01: the line or plane indicating the limit or extent of something
#
#   HYPONYMS (more specific): 1 found
#     → oil-water_interface.n.01
#       Definition: an interface forming the boundary between the non-miscible liquids oil and water
#
#   HIERARCHY PATH (up to root):
#     └─ interface.n.01
#       └─ surface.n.02
#         └─ boundary.n.01
#           └─ extremity.n.04
#             └─ region.n.01
#               └─ location.n.01
#                 └─ object.n.01
#                   └─ physical_entity.n.01
#                     └─ entity.n.01
#
# WORD: 'different'
#   Definition: unlike in nature or quality or form or degree
#   Example: ['took different approaches to the problem', 'came to a different conclusion', 'different parts of the country', 'on different sides of the issue', 'this meeting was different from the earlier one']
#
#   HYPERNYMS: None found
#
#   HYPONYMS: None found
#
#   HIERARCHY PATH (up to root):
#     └─ different.a.01
#
# WORD: 'first'
#   Definition: the first or highest in an ordering or series
#   Example: ['He wanted to be the first']
#
#   HYPERNYMS (more general): 1 found
#     → rank.n.02
#       Definition: relative status
#         ↑ status.n.01: the relative position or standing of things or especially persons in a society
#
#   HYPONYMS (more specific): 1 found
#     → former.n.01
#       Definition: the first of two or the first mentioned of two
#
#   HIERARCHY PATH (up to root):
#     └─ first.n.01
#       └─ rank.n.02
#         └─ status.n.01
#           └─ state.n.02
#             └─ attribute.n.02
#               └─ abstraction.n.06
#                 └─ entity.n.01
#
# WORD: 'graphical'
#   Definition: relating to or presented by a graph
#   Example: ['a graphic presentation of the data']
#
#   HYPERNYMS: None found
#
#   HYPONYMS: None found
#
#   HIERARCHY PATH (up to root):
#     └─ graphic.a.04
#
# ...
#     → lurch.v.03
#       Definition: move slowly and unsteadily
#     → advance.v.01
#       Definition: move forward, also in the metaphorical sense
#     → rise.v.01
#       Definition: move upward
#     → do.v.13
#       Definition: travel or traverse (a distance)
#     → float.v.01
#       Definition: be in motion due to some air or water current
#     → whisk.v.02
#       Definition: move quickly and nimbly
#     → travel_rapidly.v.01
#       Definition: move very fast
#     → pan.v.01
#       Definition: make a sweeping movement
#     → circuit.v.01
#       Definition: make a circuit
#     → slither.v.01
#       Definition: to pass or move unobtrusively or smoothly
#     → fly.v.06
#       Definition: be dispersed or disseminated
#     → transfer.v.06
#       Definition: change from one vehicle or transportation line to another
#     → wend.v.01
#       Definition: direct one's course or way
#     → drag.v.04
#       Definition: move slowly and as if with great effort
#     → come.v.01
#       Definition: move toward, travel toward something or somebody or approach something or somebody
#     → travel_by.v.01
#       Definition: move past
#     → breeze.v.02
#       Definition: to proceed quickly and easily
#     → derail.v.02
#       Definition: run off or leave the rails
#     → run.v.34
#       Definition: travel rapidly, by any (unspecified) means
#     → walk.v.10
#       Definition: take a walk; go for a walk; walk for pleasure
#     → trail.v.03
#       Definition: move, proceed, or walk draggingly or slowly
#     → follow.v.01
#       Definition: to travel behind, go after, come after
#     → swash.v.01
#       Definition: make violent, noisy movements
#     → round.v.01
#       Definition: wind around; move along a circular course
#     → glide.v.01
#       Definition: move smoothly and effortlessly
#     → retrograde.v.02
#       Definition: move in a direction contrary to the usual one
#
#   HIERARCHY PATH (up to root):
#     └─ travel.v.01
#
# WORD: 'germanamerican'
#   No synsets found for 'germanamerican'
#
# WORD: 'jobs'
#   Definition: the principal activity in your life that you do to earn money
#   Example: ["he's not in my line of business"]
#
#   HYPERNYMS (more general): 1 found
#     → activity.n.01
#       Definition: any specific behavior
#         ↑ act.n.02: something that people do or cause to happen
#
#   HYPONYMS (more specific): 15 found
#     → career.n.01
#       Definition: the particular occupation for which you are trained
#     → treadmill.n.03
#       Definition: a job involving drudgery and confinement
#     → farming.n.02
#       Definition: agriculture considered as an occupation or way of life
#     → photography.n.03
#       Definition: the occupation of taking and printing photographs or making movies
#     → profession.n.02
#       Definition: an occupation requiring special education (especially in the liberal arts or sciences)
#     → position.n.06
#       Definition: a job in an organization
#     → employment.n.02
#       Definition: the occupation for which you are paid
#     → sport.n.02
#       Definition: the occupation of athletes who compete for pay
#     → catering.n.01
#       Definition: providing food and services
#     → accountancy.n.01
#       Definition: the occupation of maintaining and auditing records and preparing financial reports for a business
#     → confectionery.n.03
#       Definition: the occupation and skills of a confectioner
#     → appointment.n.05
#       Definition: the job to which you are (or hope to be) appointed
#     → metier.n.02
#       Definition: an occupation for which you are especially well suited
#     → game.n.10
#       Definition: your occupation or line of work
#     → trade.n.02
#       Definition: the skilled practice of a practical occupation
#
#   HIERARCHY PATH (up to root):
#     └─ occupation.n.01
#       └─ activity.n.01
#         └─ act.n.02
#           └─ event.n.01
#             └─ psychological_feature.n.01
#               └─ abstraction.n.06
#                 └─ entity.n.01
#
# WORD: 'mother'
#   Definition: a woman who has given birth to a child (also used as a term of address to your mother)
#   Example: ['the mother of three children']
#
#   HYPERNYMS (more general): 1 found
#     → parent.n.01
#       Definition: a father or mother; one who begets or one who gives birth to or nurtures and raises a child; a relative who plays the role of guardian
#         ↑ genitor.n.01: a natural father or mother
#
#   HYPONYMS (more specific): 9 found
#     → supermom.n.01
#       Definition: an informal term for a mother who can combine childcare and full-time employment
#     → mother-in-law.n.01
#       Definition: the mother of your spouse
#     → quadripara.n.01
#       Definition: (obstetrics) woman who has given birth to a viable infant in each of four pregnancies
#     → quintipara.n.01
#       Definition: (obstetrics) woman who has given birth to a viable infant in each of five pregnancies
#     → surrogate_mother.n.01
#       Definition: a woman who bears a child for a couple where the wife is unable to do so
#     → primipara.n.01
#       Definition: (obstetrics) woman who has been delivered of a child for the first time
#     → ma.n.01
#       Definition: informal terms for a mother
#     → mater.n.01
#       Definition: an informal use of the Latin word for mother; sometimes used by British schoolboys or used facetiously
#     → puerpera.n.01
#       Definition: a woman in childbirth or shortly thereafter
#
#   HIERARCHY PATH (up to root):
#     └─ mother.n.01
#       └─ parent.n.01
#         └─ genitor.n.01
#           └─ progenitor.n.01
#             └─ ancestor.n.01
#               └─ relative.n.01
#                 └─ person.n.01
#                   └─ causal_agent.n.01
#                     └─ physical_entity.n.01
#                       └─ entity.n.01
#                   └─ organism.n.01
#                     └─ living_thing.n.01
#                       └─ whole.n.02
#                         └─ object.n.01
#                           └─ physical_entity.n.01
#                             └─ entity.n.01
#
# WORD: 'birth'
#   Definition: the time when something begins (especially life)
#   Example: ['they divorced after the birth of the child', 'his election signaled the birth of a new age']
#
#   HYPERNYMS (more general): 1 found
#     → beginning.n.02
#       Definition: the time at which something is supposed to begin
#         ↑ point.n.06: an instant of time
#
#   HYPONYMS (more specific): 1 found
#     → cradle.n.03
#       Definition: birth of a person
#
#   HIERARCHY PATH (up to root):
#     └─ birth.n.01
#       └─ beginning.n.02
#         └─ point.n.06
#           └─ measure.n.02
#             └─ abstraction.n.06
#               └─ entity.n.01
#
# WORD: 'potential'
#   Definition: the inherent capacity for coming into being
#   Example: No example
#
#   HYPERNYMS (more general): 1 found
#     → possibility.n.02
#       Definition: capability of existing or happening or being true
#         ↑ being.n.01: the state or fact of existing
#
#   HYPONYMS (more specific): 2 found
#     → prospect.n.01
#       Definition: the possibility of future success
#     → latency.n.03
#       Definition: the state of being not yet evident or active
#
#   HIERARCHY PATH (up to root):
#     └─ potential.n.01
#       └─ possibility.n.02
#         └─ being.n.01
#           └─ state.n.02
#             └─ attribute.n.02
#               └─ abstraction.n.06
#                 └─ entity.n.01
#
# WORD: 'microcomputers'
#   Definition: a small digital computer based on a microprocessor and designed to be used by one person at a time
#   Example: No example
#
#   HYPERNYMS (more general): 1 found
#     → digital_computer.n.01
#       Definition: a computer that represents information by numerical (binary) digits
#         ↑ computer.n.01: a machine for performing calculations automatically
#
#   HYPONYMS (more specific): 2 found
#     → desktop_computer.n.01
#       Definition: a personal computer small enough to fit conveniently in an individual workspace
#     → portable_computer.n.01
#       Definition: a personal computer that can easily be carried by hand
#
#   HIERARCHY PATH (up to root):
#     └─ personal_computer.n.01
#       └─ digital_computer.n.01
#         └─ computer.n.01
#           └─ machine.n.01
#             └─ device.n.01
#               └─ instrumentality.n.03
#                 └─ artifact.n.01
#                   └─ whole.n.02
#                     └─ object.n.01
#                       └─ physical_entity.n.01
#                         └─ entity.n.01
#
# DETAILED EXAMPLE FOR KEY WORDS FROM TEXT
#
# DEEP ANALYSIS FOR: 'apple'
#   Definition: fruit with red or yellow or green skin and sweet to tart crisp whitish flesh
#   Lemmas: ['apple']
#
#   All Hypernym Paths:
#     Path 1: entity -> physical_entity -> object -> whole -> natural_object -> plant_part -> plant_organ -> reproductive_structure -> fruit -> edible_fruit -> apple
#     Path 2: entity -> physical_entity -> matter -> solid -> food -> produce -> edible_fruit -> apple
#     Path 3: entity -> physical_entity -> object -> whole -> natural_object -> plant_part -> plant_organ -> reproductive_structure -> fruit -> pome -> apple
#
#   Total hyponyms found: 3
#   All hyponyms:
#     - eating_apple.n.01: an apple used primarily for eating raw without cooking
#     - crab_apple.n.03: small sour apple; suitable for preserving
#     - cooking_apple.n.01: an apple used primarily in cooking for pies and applesauce etc
#
# DEEP ANALYSIS FOR: 'computer'
#   Definition: a machine for performing calculations automatically
#   Lemmas: ['computer', 'computing_machine', 'computing_device', 'data_processor', 'electronic_computer', 'information_processing_system']
#
#   All Hypernym Paths:
#     Path 1: entity -> physical_entity -> object -> whole -> artifact -> instrumentality -> device -> machine -> computer
#
#   Total hyponyms found: 10
#   All hyponyms:
#     - digital_computer.n.01: a computer that represents information by numerical (binary) digits
#     - predictor.n.03: a computer for controlling antiaircraft fire that computes the position of an aircraft at the instant of a shell's arrival
#     - web_site.n.01: a computer connected to the internet that maintains a series of web pages on the World Wide Web
#     - server.n.03: (computer science) a computer that provides client stations with access to files and printers as shared resources to a computer network
#     - analog_computer.n.01: a computer that represents information by variable quantities (e.g., positions or voltages)
#     - turing_machine.n.01: a hypothetical computer with an infinitely long memory tape
#     - number_cruncher.n.02: a computer capable of performing a large number of mathematical operations per second
#     - home_computer.n.01: a computer intended for use in the home
#     - pari-mutuel_machine.n.01: computer that registers bets and divides the total amount bet among those who won
#     - node.n.08: (computer science) any computer that is hooked up to a computer network
#
# DEEP ANALYSIS FOR: 'company'
#   Definition: an institution created to conduct business
#   Lemmas: ['company']
#
#   All Hypernym Paths:
#     Path 1: entity -> abstraction -> group -> social_group -> organization -> institution -> company
#
#   Total hyponyms found: 36
#   All hyponyms:
#     - target_company.n.01: a company that has been chosen as attractive for takeover by a potential acquirer
#     - oil_company.n.01: a company that sells oil
#     - east_india_company.n.01: an English company formed in 1600 to develop trade with the new British colonies in India and southeastern Asia; in the 18th century it assumed administrative control of Bengal and held it until the British army took over in 1858 after the Indian Mutiny
#     - bureau_de_change.n.01: (French) an establishment where you can exchange foreign money
#     - broadcasting_company.n.01: a company that manages tv or radio stations
#     - closed_shop.n.01: a company that hires only union members
#     - think_tank.n.01: a company that does research for hire and issues reports on the implications
#     - furniture_company.n.01: a company that sells furniture
#     - dot-com.n.01: a company that operates its business primarily on the internet using a URL that ends in `.com'
#     - steel_company.n.01: a company that makes and sells steel
#     - shipping_company.n.01: a company that provides shipping services
#     - food_company.n.01: a company that processes and sells food
#     - mover.n.04: a company that moves the possessions of a family or business from one site to another
#     - transportation_company.n.01: a company providing transportation
#     - union_shop.n.01: a company allowed to hire nonunion workers on the condition that they will join the union within a specified time
#     - pipeline_company.n.01: a company that operates oil pipelines for the oil industry
#     - mining_company.n.01: a company that owns and manages mines
#     - open_shop.n.01: a company whose workers are hired without regard to their membership in a labor union
#     - joint-stock_company.n.01: a company (usually unincorporated) which has the capital of its members pooled in a common fund; transferable shares represent ownership interest; shareholders are legally liable for all debts of the company
#     - printing_concern.n.01: a company that does commercial printing
#     - stock_company.n.01: a company whose capital is represented by stock
#     - white_knight.n.01: a company that is a friendly acquirer in a takeover
#     - film_company.n.01: a company that makes, advertises, and distributes movies
#     - distributor.n.03: a company that markets merchandise
#     - drug_company.n.01: a company that makes and sells pharmaceuticals
#     - shipper.n.02: a company in the business of shipping freight
#     - service.n.04: a company or agency that performs a public service; subject to government regulation
#     - limited_company.n.01: a company that is organized to give its owners limited liability
#     - livery_company.n.01: one of the chartered companies of London originating with the craft guilds
#     - record_company.n.01: a company that makes and sells musical recordings
#     - electronics_company.n.01: a company that makes and sells electronic instruments
#     - subsidiary_company.n.01: a company that is completely controlled by another company
#     - corporate_investor.n.01: a company that invests in (acquires control of) other companies
#     - car_company.n.01: a company that makes and sells automobiles
#     - packaging_company.n.01: a company that packages goods for sale or shipment or storage
#     - holding_company.n.01: a company with controlling shares in other companies
#
# DEEP ANALYSIS FOR: 'inventor'
#   Definition: someone who is the first to think of or make something
#   Lemmas: ['inventor', 'discoverer', 'artificer']
#
#   All Hypernym Paths:
#     Path 1: entity -> physical_entity -> causal_agent -> person -> creator -> inventor
#     Path 2: entity -> physical_entity -> object -> whole -> living_thing -> organism -> person -> creator -> inventor
#
#   Total hyponyms found: 1
#   All hyponyms:
#     - patentee.n.01: the inventor to whom a patent is issued
#
# DEEP ANALYSIS FOR: 'founder'
#   Definition: inflammation of the laminated tissue that attaches the hoof to the foot of a horse
#   Lemmas: ['laminitis', 'founder']
#
#   All Hypernym Paths:
#     Path 1: entity -> abstraction -> psychological_feature -> cognition -> information -> evidence -> symptom -> inflammation -> laminitis
#
#   Total hyponyms found: 0
#
# DEEP ANALYSIS FOR: 'ceo'
#   Definition: the corporate executive responsible for the operations of the firm; reports to a board of directors; may appoint other managers (including a president)
#   Lemmas: ['chief_executive_officer', 'CEO', 'chief_operating_officer']
#
#   All Hypernym Paths:
#     Path 1: entity -> physical_entity -> causal_agent -> person -> leader -> head -> administrator -> executive -> corporate_executive -> chief_executive_officer
#     Path 2: entity -> physical_entity -> object -> whole -> living_thing -> organism -> person -> leader -> head -> administrator -> executive -> corporate_executive -> chief_executive_officer
#
#   Total hyponyms found: 0
#
# DEEP ANALYSIS FOR: 'pixar'
#
# DEEP ANALYSIS FOR: 'next'
#   Definition: immediately following in time or order
#   Lemmas: ['following', 'next']
#
#   All Hypernym Paths:
#     Path 1: following
#
#   Total hyponyms found: 0

# %% [markdown]
# # Summary of All Operations

# %%
# Cell 15: Summary of All Operations
print("SUMMARY OF ALL OPERATIONS PERFORMED")

print(f"1. CLEANING:")
print(f"   - Original text length: {len(raw_text)} characters")
print(f"   - Cleaned text length: {len(text_cleaned)} characters")
print(f"   - Characters removed: {len(raw_text) - len(text_cleaned)}")

print(f"\n2. LOWERCASING:")
print(f"   - Original text length: {len(text_cleaned)} characters")
print(f"   - Lowercased text length: {len(text_lower)} characters")

print(f"\n3. PUNCTUATION REMOVAL:")
print(f"   - Before removal: {len(text_lower)} characters")
print(f"   - After removal: {len(text_no_punct)} characters")
print(f"   - Punctuation removed: {len(text_lower) - len(text_no_punct)}")

print(f"\n4. STOPWORD REMOVAL:")
print(f"   - Tokens before: {len(tokens)}")
print(f"   - Tokens after: {len(filtered_tokens)}")
print(f"   - Stopwords removed: {len(tokens) - len(filtered_tokens)}")

print(f"\n5. TOKENIZATION:")
print(f"   - Number of sentences: {len(sentences)}")
print(f"   - Number of words: {len(words)}")
print(f"   - Number of characters (no spaces): {len(chars)}")

print(f"\n6. STEMMING:")
print(f"   - Original tokens: {len(filtered_tokens)}")
print(f"   - Porter stemmed tokens: {len(porter_stemmed_tokens)}")
print(f"   - Snowball stemmed tokens: {len(snowball_stemmed_tokens)}")

print(f"\n7. LEMMATIZATION:")
print(f"   - Original tokens: {len(filtered_tokens)}")
print(f"   - Lemmatized tokens: {len(lemmatized_tokens)}")

print(f"\n8. POS TAGGING:")
print(f"   - Number of words tagged: {len(pos_tagged)}")

print(f"\n9. CHUNKING:")
print(f"   - Processed all sentences: {len(all_sentences)} sentences")

print(f"\n10. PARSING:")
print(f"    - Dependency parsing: Complete text processed (Full output shown)")
print(f"    - Tree parsing: All sentences processed (Full output shown)")

print(f"\n11. HYPERNYMS & HYPONYMS:")
print(f"    - Unique words analyzed: {len(unique_words)} words")
print(f"    - Key words analyzed: {len(key_words)} words")
# Out:
# SUMMARY OF ALL OPERATIONS PERFORMED
# 1. CLEANING:
#    - Original text length: 3038 characters
#    - Cleaned text length: 2913 characters
#    - Characters removed: 125
#
# 2. LOWERCASING:
#    - Original text length: 2913 characters
#    - Lowercased text length: 2913 characters
#
# 3. PUNCTUATION REMOVAL:
#    - Before removal: 2913 characters
#    - After removal: 2851 characters
#    - Punctuation removed: 62
#
# 4. STOPWORD REMOVAL:
#    - Tokens before: 12
#    - Tokens after: 277
#    - Stopwords removed: -265
#
# 5. TOKENIZATION:
#    - Number of sentences: 23
#    - Number of words: 534
#    - Number of characters (no spaces): 2425
#
# 6. STEMMING:
#    - Original tokens: 277
#    - Porter stemmed tokens: 277
#    - Snowball stemmed tokens: 277
#
# 7. LEMMATIZATION:
#    - Original tokens: 277
#    - Lemmatized tokens: 277
#
# 8. POS TAGGING:
#    - Number of words tagged: 277
#
# 9. CHUNKING:
#    - Processed all sentences: 23 sentences
#
# 10. PARSING:
#     - Dependency parsing: Complete text processed (Full output shown)
#     - Tree parsing: All sentences processed (Full output shown)
#
# 11. HYPERNYMS & HYPONYMS:
#     - Unique words analyzed: 210 words
#     - Key words analyzed: 8 words
