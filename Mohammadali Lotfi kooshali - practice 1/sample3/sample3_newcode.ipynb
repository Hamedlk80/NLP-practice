# %% [markdown]
# # practice one

# %% [markdown]
# # mabahese vizhe

# %% [markdown]
# # Mohammadali Lotfi kooshali      -        404198471

# %% [markdown]
# # install , download and import libraries

# %%
# !pip install spacy nltk
# !python -m spacy download en_core_web_sm

import re
import spacy
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize, sent_tokenize
from nltk.stem import PorterStemmer, WordNetLemmatizer, SnowballStemmer
from nltk import pos_tag
from nltk.corpus import wordnet as wn
from string import punctuation
from nltk.chunk import RegexpParser
from nltk import Tree
import time

# Download required NLTK data
nltk.download('punkt')
nltk.download('stopwords')
nltk.download('wordnet')
nltk.download('averaged_perceptron_tagger')
nltk.download('omw-1.4')

# Load spaCy model
nlp = spacy.load("en_core_web_sm")
# Out:
# Requirement already satisfied: spacy in D:\.venv\Lib\site-packages (3.8.14)
# Requirement already satisfied: nltk in D:\.venv\Lib\site-packages (3.9.4)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in D:\.venv\Lib\site-packages (from spacy) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in D:\.venv\Lib\site-packages (from spacy) (1.0.0)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in D:\.venv\Lib\site-packages (from spacy) (1.0.10)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in D:\.venv\Lib\site-packages (from spacy) (2.0.13)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in D:\.venv\Lib\site-packages (from spacy) (3.0.13)
# Requirement already satisfied: thinc<8.4.0,>=8.3.12 in D:\.venv\Lib\site-packages (from spacy) (8.3.13)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in D:\.venv\Lib\site-packages (from spacy) (0.10.1)
# Requirement already satisfied: srsly<3.0.0,>=2.5.3 in D:\.venv\Lib\site-packages (from spacy) (2.5.3)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in D:\.venv\Lib\site-packages (from spacy) (2.0.10)
# Requirement already satisfied: weasel<2.0.0,>=1.0.0 in D:\.venv\Lib\site-packages (from spacy) (1.0.0)
# Requirement already satisfied: confection<2.0.0,>=1.3.2 in D:\.venv\Lib\site-packages (from spacy) (1.3.3)
# Requirement already satisfied: typer<1.0.0,>=0.3.0 in D:\.venv\Lib\site-packages (from spacy) (0.23.1)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in D:\.venv\Lib\site-packages (from spacy) (4.67.3)
# Requirement already satisfied: numpy>=1.19.0 in D:\.venv\Lib\site-packages (from spacy) (2.3.5)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in D:\.venv\Lib\site-packages (from spacy) (2.32.5)
# Requirement already satisfied: pydantic<3.0.0,>=2.0.0 in D:\.venv\Lib\site-packages (from spacy) (2.12.5)
# Requirement already satisfied: jinja2 in D:\.venv\Lib\site-packages (from spacy) (3.1.6)
# Requirement already satisfied: setuptools in D:\.venv\Lib\site-packages (from spacy) (81.0.0)
# Requirement already satisfied: packaging>=20.0 in D:\.venv\Lib\site-packages (from spacy) (25.0)
# Requirement already satisfied: annotated-types>=0.6.0 in D:\.venv\Lib\site-packages (from pydantic<3.0.0,>=2.0.0->spacy) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in D:\.venv\Lib\site-packages (from pydantic<3.0.0,>=2.0.0->spacy) (2.41.5)
# Requirement already satisfied: typing-extensions>=4.14.1 in D:\.venv\Lib\site-packages (from pydantic<3.0.0,>=2.0.0->spacy) (4.15.0)
# Requirement already satisfied: typing-inspection>=0.4.2 in D:\.venv\Lib\site-packages (from pydantic<3.0.0,>=2.0.0->spacy) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in D:\.venv\Lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in D:\.venv\Lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in D:\.venv\Lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (2.6.3)
# Requirement already satisfied: certifi>=2017.4.17 in D:\.venv\Lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (2026.1.4)
# Requirement already satisfied: blis<1.4.0,>=1.3.0 in D:\.venv\Lib\site-packages (from thinc<8.4.0,>=8.3.12->spacy) (1.3.3)
# Requirement already satisfied: colorama in D:\.venv\Lib\site-packages (from tqdm<5.0.0,>=4.38.0->spacy) (0.4.6)
# Requirement already satisfied: click>=8.0.0 in D:\.venv\Lib\site-packages (from typer<1.0.0,>=0.3.0->spacy) (8.3.1)
# Requirement already satisfied: shellingham>=1.3.0 in D:\.venv\Lib\site-packages (from typer<1.0.0,>=0.3.0->spacy) (1.5.4)
# Requirement already satisfied: rich>=10.11.0 in D:\.venv\Lib\site-packages (from typer<1.0.0,>=0.3.0->spacy) (14.3.2)
# Requirement already satisfied: annotated-doc>=0.0.2 in D:\.venv\Lib\site-packages (from typer<1.0.0,>=0.3.0->spacy) (0.0.4)
# Requirement already satisfied: cloudpathlib>=0.7.0 in D:\.venv\Lib\site-packages (from weasel<2.0.0,>=1.0.0->spacy) (0.23.0)
# Requirement already satisfied: smart-open>=5.2.1 in D:\.venv\Lib\site-packages (from weasel<2.0.0,>=1.0.0->spacy) (7.6.0)
# Requirement already satisfied: httpx>=0.24.0 in D:\.venv\Lib\site-packages (from weasel<2.0.0,>=1.0.0->spacy) (0.28.1)
# Requirement already satisfied: joblib in D:\.venv\Lib\site-packages (from nltk) (1.5.3)
# Requirement already satisfied: regex>=2021.8.3 in D:\.venv\Lib\site-packages (from nltk) (2026.1.15)
# Requirement already satisfied: anyio in D:\.venv\Lib\site-packages (from httpx>=0.24.0->weasel<2.0.0,>=1.0.0->spacy) (4.12.1)
# Requirement already satisfied: httpcore==1.* in D:\.venv\Lib\site-packages (from httpx>=0.24.0->weasel<2.0.0,>=1.0.0->spacy) (1.0.9)
# Requirement already satisfied: h11>=0.16 in D:\.venv\Lib\site-packages (from httpcore==1.*->httpx>=0.24.0->weasel<2.0.0,>=1.0.0->spacy) (0.16.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in D:\.venv\Lib\site-packages (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in D:\.venv\Lib\site-packages (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in D:\.venv\Lib\site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy) (0.1.2)
# Requirement already satisfied: wrapt in D:\.venv\Lib\site-packages (from smart-open>=5.2.1->weasel<2.0.0,>=1.0.0->spacy) (2.1.2)
# Requirement already satisfied: MarkupSafe>=2.0 in D:\.venv\Lib\site-packages (from jinja2->spacy) (3.0.3)
# Collecting en-core-web-sm==3.8.0
#   WARNING: Retrying (Retry(total=4, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ProtocolError('Connection aborted.', ConnectionResetError(10054, 'An existing connection was forcibly closed by the remote host', None, 10054, None))': /github-production-release-asset/84940268/15132ab6-4050-4914-8fe8-ac2c2fdcb9cf?sp=r&sv=2018-11-09&sr=b&spr=https&se=2026-04-27T21%3A07%3A06Z&rscd=attachment%3B+filename%3Den_core_web_sm-3.8.0-py3-none-any.whl&rsct=application%2Foctet-stream&skoid=96c2d410-5711-43a1-aedd-ab1947aa7ab0&sktid=398a6654-997b-47e9-b12b-9515b896b4de&skt=2026-04-27T20%3A06%3A40Z&ske=2026-04-27T21%3A07%3A06Z&sks=b&skv=2018-11-09&sig=3%2FeUPVrDIvmRiERqFRuCwNyQB0SMIcIC76Pq%2B0YbEfI%3D&jwt=eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9.eyJpc3MiOiJnaXRodWIuY29tIiwiYXVkIjoicmVsZWFzZS1hc3NldHMuZ2l0aHVidXNlcmNvbnRlbnQuY29tIiwia2V5Ijoia2V5MSIsImV4cCI6MTc3NzMyMjMzMCwibmJmIjoxNzc3MzIwNTMwLCJwYXRoIjoicmVsZWFzZWFzc2V0cHJvZHVjdGlvbi5ibG9iLmNvcmUud2luZG93cy5uZXQifQ.yD9R2RSe6HMK1iUytq0h1MAgQtZdzQznB02wFOsrt5M&response-content-disposition=attachment%3B%20filename%3Den_core_web_sm-3.8.0-py3-none-any.whl&response-content-type=application%2Foctet-stream
#   WARNING: Retrying (Retry(total=3, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ProtocolError('Connection aborted.', ConnectionResetError(10054, 'An existing connection was forcibly closed by the remote host', None, 10054, None))': /github-production-release-asset/84940268/15132ab6-4050-4914-8fe8-ac2c2fdcb9cf?sp=r&sv=2018-11-09&sr=b&spr=https&se=2026-04-27T21%3A07%3A06Z&rscd=attachment%3B+filename%3Den_core_web_sm-3.8.0-py3-none-any.whl&rsct=application%2Foctet-stream&skoid=96c2d410-5711-43a1-aedd-ab1947aa7ab0&sktid=398a6654-997b-47e9-b12b-9515b896b4de&skt=2026-04-27T20%3A06%3A40Z&ske=2026-04-27T21%3A07%3A06Z&sks=b&skv=2018-11-09&sig=3%2FeUPVrDIvmRiERqFRuCwNyQB0SMIcIC76Pq%2B0YbEfI%3D&jwt=eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9.eyJpc3MiOiJnaXRodWIuY29tIiwiYXVkIjoicmVsZWFzZS1hc3NldHMuZ2l0aHVidXNlcmNvbnRlbnQuY29tIiwia2V5Ijoia2V5MSIsImV4cCI6MTc3NzMyMjMzMCwibmJmIjoxNzc3MzIwNTMwLCJwYXRoIjoicmVsZWFzZWFzc2V0cHJvZHVjdGlvbi5ibG9iLmNvcmUud2luZG93cy5uZXQifQ.yD9R2RSe6HMK1iUytq0h1MAgQtZdzQznB02wFOsrt5M&response-content-disposition=attachment%3B%20filename%3Den_core_web_sm-3.8.0-py3-none-any.whl&response-content-type=application%2Foctet-stream
#   WARNING: Retrying (Retry(total=2, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ProtocolError('Connection aborted.', ConnectionResetError(10054, 'An existing connection was forcibly closed by the remote host', None, 10054, None))': /github-production-release-asset/84940268/15132ab6-4050-4914-8fe8-ac2c2fdcb9cf?sp=r&sv=2018-11-09&sr=b&spr=https&se=2026-04-27T21%3A07%3A06Z&rscd=attachment%3B+filename%3Den_core_web_sm-3.8.0-py3-none-any.whl&rsct=application%2Foctet-stream&skoid=96c2d410-5711-43a1-aedd-ab1947aa7ab0&sktid=398a6654-997b-47e9-b12b-9515b896b4de&skt=2026-04-27T20%3A06%3A40Z&ske=2026-04-27T21%3A07%3A06Z&sks=b&skv=2018-11-09&sig=3%2FeUPVrDIvmRiERqFRuCwNyQB0SMIcIC76Pq%2B0YbEfI%3D&jwt=eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9.eyJpc3MiOiJnaXRodWIuY29tIiwiYXVkIjoicmVsZWFzZS1hc3NldHMuZ2l0aHVidXNlcmNvbnRlbnQuY29tIiwia2V5Ijoia2V5MSIsImV4cCI6MTc3NzMyMjMzMCwibmJmIjoxNzc3MzIwNTMwLCJwYXRoIjoicmVsZWFzZWFzc2V0cHJvZHVjdGlvbi5ibG9iLmNvcmUud2luZG93cy5uZXQifQ.yD9R2RSe6HMK1iUytq0h1MAgQtZdzQznB02wFOsrt5M&response-content-disposition=attachment%3B%20filename%3Den_core_web_sm-3.8.0-py3-none-any.whl&response-content-type=application%2Foctet-stream
#   WARNING: Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ProtocolError('Connection aborted.', ConnectionResetError(10054, 'An existing connection was forcibly closed by the remote host', None, 10054, None))': /github-production-release-asset/84940268/15132ab6-4050-4914-8fe8-ac2c2fdcb9cf?sp=r&sv=2018-11-09&sr=b&spr=https&se=2026-04-27T21%3A07%3A06Z&rscd=attachment%3B+filename%3Den_core_web_sm-3.8.0-py3-none-any.whl&rsct=application%2Foctet-stream&skoid=96c2d410-5711-43a1-aedd-ab1947aa7ab0&sktid=398a6654-997b-47e9-b12b-9515b896b4de&skt=2026-04-27T20%3A06%3A40Z&ske=2026-04-27T21%3A07%3A06Z&sks=b&skv=2018-11-09&sig=3%2FeUPVrDIvmRiERqFRuCwNyQB0SMIcIC76Pq%2B0YbEfI%3D&jwt=eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9.eyJpc3MiOiJnaXRodWIuY29tIiwiYXVkIjoicmVsZWFzZS1hc3NldHMuZ2l0aHVidXNlcmNvbnRlbnQuY29tIiwia2V5Ijoia2V5MSIsImV4cCI6MTc3NzMyMjMzMCwibmJmIjoxNzc3MzIwNTMwLCJwYXRoIjoicmVsZWFzZWFzc2V0cHJvZHVjdGlvbi5ibG9iLmNvcmUud2luZG93cy5uZXQifQ.yD9R2RSe6HMK1iUytq0h1MAgQtZdzQznB02wFOsrt5M&response-content-disposition=attachment%3B%20filename%3Den_core_web_sm-3.8.0-py3-none-any.whl&response-content-type=application%2Foctet-stream
#   WARNING: Retrying (Retry(total=0, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ProtocolError('Connection aborted.', ConnectionResetError(10054, 'An existing connection was forcibly closed by the remote host', None, 10054, None))': /github-production-release-asset/84940268/15132ab6-4050-4914-8fe8-ac2c2fdcb9cf?sp=r&sv=2018-11-09&sr=b&spr=https&se=2026-04-27T21%3A07%3A06Z&rscd=attachment%3B+filename%3Den_core_web_sm-3.8.0-py3-none-any.whl&rsct=application%2Foctet-stream&skoid=96c2d410-5711-43a1-aedd-ab1947aa7ab0&sktid=398a6654-997b-47e9-b12b-9515b896b4de&skt=2026-04-27T20%3A06%3A40Z&ske=2026-04-27T21%3A07%3A06Z&sks=b&skv=2018-11-09&sig=3%2FeUPVrDIvmRiERqFRuCwNyQB0SMIcIC76Pq%2B0YbEfI%3D&jwt=eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9.eyJpc3MiOiJnaXRodWIuY29tIiwiYXVkIjoicmVsZWFzZS1hc3NldHMuZ2l0aHVidXNlcmNvbnRlbnQuY29tIiwia2V5Ijoia2V5MSIsImV4cCI6MTc3NzMyMjMzMCwibmJmIjoxNzc3MzIwNTMwLCJwYXRoIjoicmVsZWFzZWFzc2V0cHJvZHVjdGlvbi5ibG9iLmNvcmUud2luZG93cy5uZXQifQ.yD9R2RSe6HMK1iUytq0h1MAgQtZdzQznB02wFOsrt5M&response-content-disposition=attachment%3B%20filename%3Den_core_web_sm-3.8.0-py3-none-any.whl&response-content-type=application%2Foctet-stream
# ERROR: Could not install packages due to an OSError: HTTPSConnectionPool(host='release-assets.githubusercontent.com', port=443): Max retries exceeded with url: /github-production-release-asset/84940268/15132ab6-4050-4914-8fe8-ac2c2fdcb9cf?sp=r&sv=2018-11-09&sr=b&spr=https&se=2026-04-27T21%3A07%3A06Z&rscd=attachment%3B+filename%3Den_core_web_sm-3.8.0-py3-none-any.whl&rsct=application%2Foctet-stream&skoid=96c2d410-5711-43a1-aedd-ab1947aa7ab0&sktid=398a6654-997b-47e9-b12b-9515b896b4de&skt=2026-04-27T20%3A06%3A40Z&ske=2026-04-27T21%3A07%3A06Z&sks=b&skv=2018-11-09&sig=3%2FeUPVrDIvmRiERqFRuCwNyQB0SMIcIC76Pq%2B0YbEfI%3D&jwt=eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9.eyJpc3MiOiJnaXRodWIuY29tIiwiYXVkIjoicmVsZWFzZS1hc3NldHMuZ2l0aHVidXNlcmNvbnRlbnQuY29tIiwia2V5Ijoia2V5MSIsImV4cCI6MTc3NzMyMjMzMCwibmJmIjoxNzc3MzIwNTMwLCJwYXRoIjoicmVsZWFzZWFzc2V0cHJvZHVjdGlvbi5ibG9iLmNvcmUud2luZG93cy5uZXQifQ.yD9R2RSe6HMK1iUytq0h1MAgQtZdzQznB02wFOsrt5M&response-content-disposition=attachment%3B%20filename%3Den_core_web_sm-3.8.0-py3-none-any.whl&response-content-type=application%2Foctet-stream (Caused by ProtocolError('Connection aborted.', ConnectionResetError(10054, 'An existing connection was forcibly closed by the remote host', None, 10054, None)))
#
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\ASUS\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\ASUS\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\ASUS\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     C:\Users\ASUS\AppData\Roaming\nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package omw-1.4 to
# [nltk_data]     C:\Users\ASUS\AppData\Roaming\nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!

# %% [markdown]
# # reading text file

# %%
with open('sample3.txt', 'r', encoding='utf-8') as file:
    raw_text = file.read()

print("original text:")
print(raw_text)
print(f"Total characters: {len(raw_text)}")
# Out:
# original text:
# 'Quod equidem non reprehendo;\nLorem ipsum dolor sit amet, consectetur adipiscing elit. Quibus natura iure responderit non esse verum aliunde finem beate vivendi, a se principia rei gerendae peti; Quae enim adhuc protulisti, popularia sunt, ego autem a te elegantiora desidero. Duo Reges: constructio interrete. Tum Lucius: Mihi vero ista valde probata sunt, quod item fratri puto. Bestiarum vero nullum iudicium puto. Nihil enim iam habes, quod ad corpus referas; Deinde prima illa, quae in congressu solemus: Quid tu, inquit, huc? Et homini, qui ceteris animantibus plurimum praestat, praecipue a natura nihil datum esse dicemus?\n\nIam id ipsum absurdum, maximum malum neglegi. Quod ea non occurrentia fingunt, vincunt Aristonem; Atqui perspicuum est hominem e corpore animoque constare, cum primae sint animi partes, secundae corporis. Fieri, inquam, Triari, nullo pacto potest, ut non dicas, quid non probes eius, a quo dissentias. Equidem e Cn. An dubium est, quin virtus ita maximam partem optineat in rebus humanis, ut reliquas obruat?\n\nQuis istum dolorem timet?\nSummus dolor plures dies manere non potest? Dicet pro me ipsa virtus nec dubitabit isti vestro beato M. Tubulum fuisse, qua illum, cuius is condemnatus est rogatione, P. Quod si ita sit, cur opera philosophiae sit danda nescio.\n\nEx eorum enim scriptis et institutis cum omnis doctrina liberalis, omnis historia.\nQuod si ita est, sequitur id ipsum, quod te velle video, omnes semper beatos esse sapientes. Cum enim fertur quasi torrens oratio, quamvis multa cuiusque modi rapiat, nihil tamen teneas, nihil apprehendas, nusquam orationem rapidam coerceas. Ita redarguitur ipse a sese, convincunturque scripta eius probitate ipsius ac moribus. At quanta conantur! Mundum hunc omnem oppidum esse nostrum! Incendi igitur eos, qui audiunt, vides. Vide, ne magis, inquam, tuum fuerit, cum re idem tibi, quod mihi, videretur, non nova te rebus nomina inponere. Qui-vere falsone, quaerere mittimus-dicitur oculis se privasse; Si ista mala sunt, in quae potest incidere sapiens, sapientem esse non esse ad beate vivendum satis. At vero si ad vitem sensus accesserit, ut appetitum quendam habeat et per se ipsa moveatur, quid facturam putas?\n\nQuem si tenueris, non modo meum Ciceronem, sed etiam me ipsum abducas licebit.\nStulti autem malorum memoria torquentur, sapientes bona praeterita grata recordatione renovata delectant.\nEsse enim quam vellet iniquus iustus poterat inpune.\nQuae autem natura suae primae institutionis oblita est?\nVerum tamen cum de rebus grandioribus dicas, ipsae res verba rapiunt;\nHoc est non modo cor non habere, sed ne palatum quidem.\nVoluptatem cum summum bonum diceret, primum in eo ipso parum vidit, deinde hoc quoque alienum; Sed tu istuc dixti bene Latine, parum plane. Nam haec ipsa mihi erunt in promptu, quae modo audivi, nec ante aggrediar, quam te ab istis, quos dicis, instructum videro. Fatebuntur Stoici haec omnia dicta esse praeclare, neque eam causam Zenoni desciscendi fuisse. Non autem hoc: igitur ne illud quidem. Ratio quidem vestra sic cogit. Cum audissem Antiochum, Brute, ut solebam, cum M. An quod ita callida est, ut optime possit architectari voluptates?\n\nIdemne, quod iucunde?\nHaec mihi videtur delicatior, ut ita dicam, molliorque ratio, quam virtutis vis gravitasque postulat. Sed quoniam et advesperascit et mihi ad villam revertendum est, nunc quidem hactenus; Cuius ad naturam apta ratio vera illa et summa lex a philosophis dicitur. Neque solum ea communia, verum etiam paria esse dixerunt. Sed nunc, quod agimus; A mene tu?'
# Total characters: 3563

# %% [markdown]
# # 1. Cleaning Text with re.sub

# %%
# Remove numbers
text_no_numbers = re.sub(r'\d+', '', raw_text)
print("After removing numbers:")
print(text_no_numbers)
print("-" * 80)

# Remove extra whitespaces
text_cleaned = re.sub(r'\s+', ' ', text_no_numbers)
print("After removing extra whitespaces:")
print(text_cleaned)
print("-" * 80)

# Remove special characters (keep letters, spaces, dots, commas)
text_cleaned = re.sub(r'[^\w\s\.\,]', '', text_cleaned)
print("After removing special characters:")
print(text_cleaned)
print(f"Cleaned text length: {len(text_cleaned)} characters")
# Out:
# After removing numbers:
# 'Quod equidem non reprehendo;\nLorem ipsum dolor sit amet, consectetur adipiscing elit. Quibus natura iure responderit non esse verum aliunde finem beate vivendi, a se principia rei gerendae peti; Quae enim adhuc protulisti, popularia sunt, ego autem a te elegantiora desidero. Duo Reges: constructio interrete. Tum Lucius: Mihi vero ista valde probata sunt, quod item fratri puto. Bestiarum vero nullum iudicium puto. Nihil enim iam habes, quod ad corpus referas; Deinde prima illa, quae in congressu solemus: Quid tu, inquit, huc? Et homini, qui ceteris animantibus plurimum praestat, praecipue a natura nihil datum esse dicemus?\n\nIam id ipsum absurdum, maximum malum neglegi. Quod ea non occurrentia fingunt, vincunt Aristonem; Atqui perspicuum est hominem e corpore animoque constare, cum primae sint animi partes, secundae corporis. Fieri, inquam, Triari, nullo pacto potest, ut non dicas, quid non probes eius, a quo dissentias. Equidem e Cn. An dubium est, quin virtus ita maximam partem optineat in rebus humanis, ut reliquas obruat?\n\nQuis istum dolorem timet?\nSummus dolor plures dies manere non potest? Dicet pro me ipsa virtus nec dubitabit isti vestro beato M. Tubulum fuisse, qua illum, cuius is condemnatus est rogatione, P. Quod si ita sit, cur opera philosophiae sit danda nescio.\n\nEx eorum enim scriptis et institutis cum omnis doctrina liberalis, omnis historia.\nQuod si ita est, sequitur id ipsum, quod te velle video, omnes semper beatos esse sapientes. Cum enim fertur quasi torrens oratio, quamvis multa cuiusque modi rapiat, nihil tamen teneas, nihil apprehendas, nusquam orationem rapidam coerceas. Ita redarguitur ipse a sese, convincunturque scripta eius probitate ipsius ac moribus. At quanta conantur! Mundum hunc omnem oppidum esse nostrum! Incendi igitur eos, qui audiunt, vides. Vide, ne magis, inquam, tuum fuerit, cum re idem tibi, quod mihi, videretur, non nova te rebus nomina inponere. Qui-vere falsone, quaerere mittimus-dicitur oculis se privasse; Si ista mala sunt, in quae potest incidere sapiens, sapientem esse non esse ad beate vivendum satis. At vero si ad vitem sensus accesserit, ut appetitum quendam habeat et per se ipsa moveatur, quid facturam putas?\n\nQuem si tenueris, non modo meum Ciceronem, sed etiam me ipsum abducas licebit.\nStulti autem malorum memoria torquentur, sapientes bona praeterita grata recordatione renovata delectant.\nEsse enim quam vellet iniquus iustus poterat inpune.\nQuae autem natura suae primae institutionis oblita est?\nVerum tamen cum de rebus grandioribus dicas, ipsae res verba rapiunt;\nHoc est non modo cor non habere, sed ne palatum quidem.\nVoluptatem cum summum bonum diceret, primum in eo ipso parum vidit, deinde hoc quoque alienum; Sed tu istuc dixti bene Latine, parum plane. Nam haec ipsa mihi erunt in promptu, quae modo audivi, nec ante aggrediar, quam te ab istis, quos dicis, instructum videro. Fatebuntur Stoici haec omnia dicta esse praeclare, neque eam causam Zenoni desciscendi fuisse. Non autem hoc: igitur ne illud quidem. Ratio quidem vestra sic cogit. Cum audissem Antiochum, Brute, ut solebam, cum M. An quod ita callida est, ut optime possit architectari voluptates?\n\nIdemne, quod iucunde?\nHaec mihi videtur delicatior, ut ita dicam, molliorque ratio, quam virtutis vis gravitasque postulat. Sed quoniam et advesperascit et mihi ad villam revertendum est, nunc quidem hactenus; Cuius ad naturam apta ratio vera illa et summa lex a philosophis dicitur. Neque solum ea communia, verum etiam paria esse dixerunt. Sed nunc, quod agimus; A mene tu?'
# --------------------------------------------------------------------------------
# After removing extra whitespaces:
# 'Quod equidem non reprehendo;\nLorem ipsum dolor sit amet, consectetur adipiscing elit. Quibus natura iure responderit non esse verum aliunde finem beate vivendi, a se principia rei gerendae peti; Quae enim adhuc protulisti, popularia sunt, ego autem a te elegantiora desidero. Duo Reges: constructio interrete. Tum Lucius: Mihi vero ista valde probata sunt, quod item fratri puto. Bestiarum vero nullum iudicium puto. Nihil enim iam habes, quod ad corpus referas; Deinde prima illa, quae in congressu solemus: Quid tu, inquit, huc? Et homini, qui ceteris animantibus plurimum praestat, praecipue a natura nihil datum esse dicemus?\n\nIam id ipsum absurdum, maximum malum neglegi. Quod ea non occurrentia fingunt, vincunt Aristonem; Atqui perspicuum est hominem e corpore animoque constare, cum primae sint animi partes, secundae corporis. Fieri, inquam, Triari, nullo pacto potest, ut non dicas, quid non probes eius, a quo dissentias. Equidem e Cn. An dubium est, quin virtus ita maximam partem optineat in rebus humanis, ut reliquas obruat?\n\nQuis istum dolorem timet?\nSummus dolor plures dies manere non potest? Dicet pro me ipsa virtus nec dubitabit isti vestro beato M. Tubulum fuisse, qua illum, cuius is condemnatus est rogatione, P. Quod si ita sit, cur opera philosophiae sit danda nescio.\n\nEx eorum enim scriptis et institutis cum omnis doctrina liberalis, omnis historia.\nQuod si ita est, sequitur id ipsum, quod te velle video, omnes semper beatos esse sapientes. Cum enim fertur quasi torrens oratio, quamvis multa cuiusque modi rapiat, nihil tamen teneas, nihil apprehendas, nusquam orationem rapidam coerceas. Ita redarguitur ipse a sese, convincunturque scripta eius probitate ipsius ac moribus. At quanta conantur! Mundum hunc omnem oppidum esse nostrum! Incendi igitur eos, qui audiunt, vides. Vide, ne magis, inquam, tuum fuerit, cum re idem tibi, quod mihi, videretur, non nova te rebus nomina inponere. Qui-vere falsone, quaerere mittimus-dicitur oculis se privasse; Si ista mala sunt, in quae potest incidere sapiens, sapientem esse non esse ad beate vivendum satis. At vero si ad vitem sensus accesserit, ut appetitum quendam habeat et per se ipsa moveatur, quid facturam putas?\n\nQuem si tenueris, non modo meum Ciceronem, sed etiam me ipsum abducas licebit.\nStulti autem malorum memoria torquentur, sapientes bona praeterita grata recordatione renovata delectant.\nEsse enim quam vellet iniquus iustus poterat inpune.\nQuae autem natura suae primae institutionis oblita est?\nVerum tamen cum de rebus grandioribus dicas, ipsae res verba rapiunt;\nHoc est non modo cor non habere, sed ne palatum quidem.\nVoluptatem cum summum bonum diceret, primum in eo ipso parum vidit, deinde hoc quoque alienum; Sed tu istuc dixti bene Latine, parum plane. Nam haec ipsa mihi erunt in promptu, quae modo audivi, nec ante aggrediar, quam te ab istis, quos dicis, instructum videro. Fatebuntur Stoici haec omnia dicta esse praeclare, neque eam causam Zenoni desciscendi fuisse. Non autem hoc: igitur ne illud quidem. Ratio quidem vestra sic cogit. Cum audissem Antiochum, Brute, ut solebam, cum M. An quod ita callida est, ut optime possit architectari voluptates?\n\nIdemne, quod iucunde?\nHaec mihi videtur delicatior, ut ita dicam, molliorque ratio, quam virtutis vis gravitasque postulat. Sed quoniam et advesperascit et mihi ad villam revertendum est, nunc quidem hactenus; Cuius ad naturam apta ratio vera illa et summa lex a philosophis dicitur. Neque solum ea communia, verum etiam paria esse dixerunt. Sed nunc, quod agimus; A mene tu?'
# --------------------------------------------------------------------------------
# After removing special characters:
# Quod equidem non reprehendonLorem ipsum dolor sit amet, consectetur adipiscing elit. Quibus natura iure responderit non esse verum aliunde finem beate vivendi, a se principia rei gerendae peti Quae enim adhuc protulisti, popularia sunt, ego autem a te elegantiora desidero. Duo Reges constructio interrete. Tum Lucius Mihi vero ista valde probata sunt, quod item fratri puto. Bestiarum vero nullum iudicium puto. Nihil enim iam habes, quod ad corpus referas Deinde prima illa, quae in congressu solemus Quid tu, inquit, huc Et homini, qui ceteris animantibus plurimum praestat, praecipue a natura nihil datum esse dicemusnnIam id ipsum absurdum, maximum malum neglegi. Quod ea non occurrentia fingunt, vincunt Aristonem Atqui perspicuum est hominem e corpore animoque constare, cum primae sint animi partes, secundae corporis. Fieri, inquam, Triari, nullo pacto potest, ut non dicas, quid non probes eius, a quo dissentias. Equidem e Cn. An dubium est, quin virtus ita maximam partem optineat in rebus humanis, ut reliquas obruatnnQuis istum dolorem timetnSummus dolor plures dies manere non potest Dicet pro me ipsa virtus nec dubitabit isti vestro beato M. Tubulum fuisse, qua illum, cuius is condemnatus est rogatione, P. Quod si ita sit, cur opera philosophiae sit danda nescio.nnEx eorum enim scriptis et institutis cum omnis doctrina liberalis, omnis historia.nQuod si ita est, sequitur id ipsum, quod te velle video, omnes semper beatos esse sapientes. Cum enim fertur quasi torrens oratio, quamvis multa cuiusque modi rapiat, nihil tamen teneas, nihil apprehendas, nusquam orationem rapidam coerceas. Ita redarguitur ipse a sese, convincunturque scripta eius probitate ipsius ac moribus. At quanta conantur Mundum hunc omnem oppidum esse nostrum Incendi igitur eos, qui audiunt, vides. Vide, ne magis, inquam, tuum fuerit, cum re idem tibi, quod mihi, videretur, non nova te rebus nomina inponere. Quivere falsone, quaerere mittimusdicitur oculis se privasse Si ista mala sunt, in quae potest incidere sapiens, sapientem esse non esse ad beate vivendum satis. At vero si ad vitem sensus accesserit, ut appetitum quendam habeat et per se ipsa moveatur, quid facturam putasnnQuem si tenueris, non modo meum Ciceronem, sed etiam me ipsum abducas licebit.nStulti autem malorum memoria torquentur, sapientes bona praeterita grata recordatione renovata delectant.nEsse enim quam vellet iniquus iustus poterat inpune.nQuae autem natura suae primae institutionis oblita estnVerum tamen cum de rebus grandioribus dicas, ipsae res verba rapiuntnHoc est non modo cor non habere, sed ne palatum quidem.nVoluptatem cum summum bonum diceret, primum in eo ipso parum vidit, deinde hoc quoque alienum Sed tu istuc dixti bene Latine, parum plane. Nam haec ipsa mihi erunt in promptu, quae modo audivi, nec ante aggrediar, quam te ab istis, quos dicis, instructum videro. Fatebuntur Stoici haec omnia dicta esse praeclare, neque eam causam Zenoni desciscendi fuisse. Non autem hoc igitur ne illud quidem. Ratio quidem vestra sic cogit. Cum audissem Antiochum, Brute, ut solebam, cum M. An quod ita callida est, ut optime possit architectari voluptatesnnIdemne, quod iucundenHaec mihi videtur delicatior, ut ita dicam, molliorque ratio, quam virtutis vis gravitasque postulat. Sed quoniam et advesperascit et mihi ad villam revertendum est, nunc quidem hactenus Cuius ad naturam apta ratio vera illa et summa lex a philosophis dicitur. Neque solum ea communia, verum etiam paria esse dixerunt. Sed nunc, quod agimus A mene tu
# Cleaned text length: 3514 characters

# %% [markdown]
# # 2. Lowercasing

# %%
text_lower = text_cleaned.lower()
print("Text after lowercasing:")
print(text_lower)
# Out:
# Text after lowercasing:
# quod equidem non reprehendonlorem ipsum dolor sit amet, consectetur adipiscing elit. quibus natura iure responderit non esse verum aliunde finem beate vivendi, a se principia rei gerendae peti quae enim adhuc protulisti, popularia sunt, ego autem a te elegantiora desidero. duo reges constructio interrete. tum lucius mihi vero ista valde probata sunt, quod item fratri puto. bestiarum vero nullum iudicium puto. nihil enim iam habes, quod ad corpus referas deinde prima illa, quae in congressu solemus quid tu, inquit, huc et homini, qui ceteris animantibus plurimum praestat, praecipue a natura nihil datum esse dicemusnniam id ipsum absurdum, maximum malum neglegi. quod ea non occurrentia fingunt, vincunt aristonem atqui perspicuum est hominem e corpore animoque constare, cum primae sint animi partes, secundae corporis. fieri, inquam, triari, nullo pacto potest, ut non dicas, quid non probes eius, a quo dissentias. equidem e cn. an dubium est, quin virtus ita maximam partem optineat in rebus humanis, ut reliquas obruatnnquis istum dolorem timetnsummus dolor plures dies manere non potest dicet pro me ipsa virtus nec dubitabit isti vestro beato m. tubulum fuisse, qua illum, cuius is condemnatus est rogatione, p. quod si ita sit, cur opera philosophiae sit danda nescio.nnex eorum enim scriptis et institutis cum omnis doctrina liberalis, omnis historia.nquod si ita est, sequitur id ipsum, quod te velle video, omnes semper beatos esse sapientes. cum enim fertur quasi torrens oratio, quamvis multa cuiusque modi rapiat, nihil tamen teneas, nihil apprehendas, nusquam orationem rapidam coerceas. ita redarguitur ipse a sese, convincunturque scripta eius probitate ipsius ac moribus. at quanta conantur mundum hunc omnem oppidum esse nostrum incendi igitur eos, qui audiunt, vides. vide, ne magis, inquam, tuum fuerit, cum re idem tibi, quod mihi, videretur, non nova te rebus nomina inponere. quivere falsone, quaerere mittimusdicitur oculis se privasse si ista mala sunt, in quae potest incidere sapiens, sapientem esse non esse ad beate vivendum satis. at vero si ad vitem sensus accesserit, ut appetitum quendam habeat et per se ipsa moveatur, quid facturam putasnnquem si tenueris, non modo meum ciceronem, sed etiam me ipsum abducas licebit.nstulti autem malorum memoria torquentur, sapientes bona praeterita grata recordatione renovata delectant.nesse enim quam vellet iniquus iustus poterat inpune.nquae autem natura suae primae institutionis oblita estnverum tamen cum de rebus grandioribus dicas, ipsae res verba rapiuntnhoc est non modo cor non habere, sed ne palatum quidem.nvoluptatem cum summum bonum diceret, primum in eo ipso parum vidit, deinde hoc quoque alienum sed tu istuc dixti bene latine, parum plane. nam haec ipsa mihi erunt in promptu, quae modo audivi, nec ante aggrediar, quam te ab istis, quos dicis, instructum videro. fatebuntur stoici haec omnia dicta esse praeclare, neque eam causam zenoni desciscendi fuisse. non autem hoc igitur ne illud quidem. ratio quidem vestra sic cogit. cum audissem antiochum, brute, ut solebam, cum m. an quod ita callida est, ut optime possit architectari voluptatesnnidemne, quod iucundenhaec mihi videtur delicatior, ut ita dicam, molliorque ratio, quam virtutis vis gravitasque postulat. sed quoniam et advesperascit et mihi ad villam revertendum est, nunc quidem hactenus cuius ad naturam apta ratio vera illa et summa lex a philosophis dicitur. neque solum ea communia, verum etiam paria esse dixerunt. sed nunc, quod agimus a mene tu

# %% [markdown]
# # 3. Punctuation Removal

# %%
print("Punctuation removed:", punctuation)
text_no_punct = ''.join([char for char in text_lower if char not in punctuation])
print("Text after punctuation removal:")
print(text_no_punct)
# Out:
# Punctuation removed: !"#$%&'()*+,-./:;<=>?@[\]^_`{|}~
# Text after punctuation removal:
# quod equidem non reprehendonlorem ipsum dolor sit amet consectetur adipiscing elit quibus natura iure responderit non esse verum aliunde finem beate vivendi a se principia rei gerendae peti quae enim adhuc protulisti popularia sunt ego autem a te elegantiora desidero duo reges constructio interrete tum lucius mihi vero ista valde probata sunt quod item fratri puto bestiarum vero nullum iudicium puto nihil enim iam habes quod ad corpus referas deinde prima illa quae in congressu solemus quid tu inquit huc et homini qui ceteris animantibus plurimum praestat praecipue a natura nihil datum esse dicemusnniam id ipsum absurdum maximum malum neglegi quod ea non occurrentia fingunt vincunt aristonem atqui perspicuum est hominem e corpore animoque constare cum primae sint animi partes secundae corporis fieri inquam triari nullo pacto potest ut non dicas quid non probes eius a quo dissentias equidem e cn an dubium est quin virtus ita maximam partem optineat in rebus humanis ut reliquas obruatnnquis istum dolorem timetnsummus dolor plures dies manere non potest dicet pro me ipsa virtus nec dubitabit isti vestro beato m tubulum fuisse qua illum cuius is condemnatus est rogatione p quod si ita sit cur opera philosophiae sit danda nescionnex eorum enim scriptis et institutis cum omnis doctrina liberalis omnis historianquod si ita est sequitur id ipsum quod te velle video omnes semper beatos esse sapientes cum enim fertur quasi torrens oratio quamvis multa cuiusque modi rapiat nihil tamen teneas nihil apprehendas nusquam orationem rapidam coerceas ita redarguitur ipse a sese convincunturque scripta eius probitate ipsius ac moribus at quanta conantur mundum hunc omnem oppidum esse nostrum incendi igitur eos qui audiunt vides vide ne magis inquam tuum fuerit cum re idem tibi quod mihi videretur non nova te rebus nomina inponere quivere falsone quaerere mittimusdicitur oculis se privasse si ista mala sunt in quae potest incidere sapiens sapientem esse non esse ad beate vivendum satis at vero si ad vitem sensus accesserit ut appetitum quendam habeat et per se ipsa moveatur quid facturam putasnnquem si tenueris non modo meum ciceronem sed etiam me ipsum abducas licebitnstulti autem malorum memoria torquentur sapientes bona praeterita grata recordatione renovata delectantnesse enim quam vellet iniquus iustus poterat inpunenquae autem natura suae primae institutionis oblita estnverum tamen cum de rebus grandioribus dicas ipsae res verba rapiuntnhoc est non modo cor non habere sed ne palatum quidemnvoluptatem cum summum bonum diceret primum in eo ipso parum vidit deinde hoc quoque alienum sed tu istuc dixti bene latine parum plane nam haec ipsa mihi erunt in promptu quae modo audivi nec ante aggrediar quam te ab istis quos dicis instructum videro fatebuntur stoici haec omnia dicta esse praeclare neque eam causam zenoni desciscendi fuisse non autem hoc igitur ne illud quidem ratio quidem vestra sic cogit cum audissem antiochum brute ut solebam cum m an quod ita callida est ut optime possit architectari voluptatesnnidemne quod iucundenhaec mihi videtur delicatior ut ita dicam molliorque ratio quam virtutis vis gravitasque postulat sed quoniam et advesperascit et mihi ad villam revertendum est nunc quidem hactenus cuius ad naturam apta ratio vera illa et summa lex a philosophis dicitur neque solum ea communia verum etiam paria esse dixerunt sed nunc quod agimus a mene tu

# %% [markdown]
# # 4. Stopword Removal

# %%
# Get English stopwords
stop_words = set(stopwords.words('english'))
print("English stopwords :")
print(list(stop_words))

# Tokenize first
tokens = word_tokenize(text_no_punct)
print(f"Total tokens before stopword removal: {len(tokens)}")
print("tokens before removal:")
print(tokens)

# Remove stopwords
filtered_tokens = [word for word in tokens if word not in stop_words]
print(f"Total tokens after stopword removal: {len(filtered_tokens)}")
print("tokens after removal:")
print(filtered_tokens)

# Convert back to text
text_no_stopwords = ' '.join(filtered_tokens)
print("Complete text after stopword removal:")
print(text_no_stopwords)
# Out:
# English stopwords :
# ['these', "don't", 'them', 're', 'where', 'which', 'themselves', 'been', "hadn't", 'himself', 'or', 'over', "they'll", 't', 'what', 'those', 'her', 'should', 'any', 'hers', 'did', 'mightn', 'theirs', "we're", "couldn't", 'such', 'when', "you're", 'for', "isn't", 'didn', "that'll", 'their', 'to', 'while', 'aren', 'its', 'couldn', "i'm", 'at', 'that', 'she', 'from', 'our', 'isn', 'am', "they've", "he's", "doesn't", "hasn't", 'against', 's', "weren't", 'whom', 'before', 'doing', "didn't", 'up', 'other', "he'd", 'own', "we've", 'all', "it'll", 'o', 'mustn', 'shouldn', 'of', 'through', 'myself', 'do', 'down', 'hasn', 'most', "mustn't", 'shan', 'out', 'i', 'have', 'same', "it's", 'was', 'wasn', 'we', 'until', 'are', 'is', "should've", 'after', 'me', 'nor', 'ours', 'between', 'more', 'they', 'he', 'here', "i've", 'only', 'hadn', 'being', 'you', "you'd", 'yourself', 'my', 'it', 'some', 'then', 'won', "she'd", 'above', "haven't", "shan't", 'how', 'under', "wasn't", 'wouldn', 'as', 'with', 'm', 'll', 'about', 'who', 'no', 'yours', 'below', 'so', 'a', 'be', 'herself', "they're", 'were', "mightn't", 'can', 'don', 'too', "you've", 'each', "she's", 'in', "they'd", 'by', 'just', "we'd", 'doesn', 'why', 'during', "you'll", "wouldn't", 'few', 'his', 'because', "aren't", 'but', 'into', "shouldn't", 'off', 'ma', 'if', 'will', 'now', 'ourselves', 'both', 'your', "won't", 'needn', 'this', 'itself', 'weren', 'than', "i'd", 'having', 'there', 'does', 'on', 'the', 'and', 'again', "needn't", 'further', "i'll", "we'll", 've', 'him', 'yourselves', 'an', 'not', "he'll", "it'd", 'has', "she'll", 'y', 'haven', 'had', 'ain', 'very', 'once', 'd']
# Total tokens before stopword removal: 531
# tokens before removal:
# ['quod', 'equidem', 'non', 'reprehendonlorem', 'ipsum', 'dolor', 'sit', 'amet', 'consectetur', 'adipiscing', 'elit', 'quibus', 'natura', 'iure', 'responderit', 'non', 'esse', 'verum', 'aliunde', 'finem', 'beate', 'vivendi', 'a', 'se', 'principia', 'rei', 'gerendae', 'peti', 'quae', 'enim', 'adhuc', 'protulisti', 'popularia', 'sunt', 'ego', 'autem', 'a', 'te', 'elegantiora', 'desidero', 'duo', 'reges', 'constructio', 'interrete', 'tum', 'lucius', 'mihi', 'vero', 'ista', 'valde', 'probata', 'sunt', 'quod', 'item', 'fratri', 'puto', 'bestiarum', 'vero', 'nullum', 'iudicium', 'puto', 'nihil', 'enim', 'iam', 'habes', 'quod', 'ad', 'corpus', 'referas', 'deinde', 'prima', 'illa', 'quae', 'in', 'congressu', 'solemus', 'quid', 'tu', 'inquit', 'huc', 'et', 'homini', 'qui', 'ceteris', 'animantibus', 'plurimum', 'praestat', 'praecipue', 'a', 'natura', 'nihil', 'datum', 'esse', 'dicemusnniam', 'id', 'ipsum', 'absurdum', 'maximum', 'malum', 'neglegi', 'quod', 'ea', 'non', 'occurrentia', 'fingunt', 'vincunt', 'aristonem', 'atqui', 'perspicuum', 'est', 'hominem', 'e', 'corpore', 'animoque', 'constare', 'cum', 'primae', 'sint', 'animi', 'partes', 'secundae', 'corporis', 'fieri', 'inquam', 'triari', 'nullo', 'pacto', 'potest', 'ut', 'non', 'dicas', 'quid', 'non', 'probes', 'eius', 'a', 'quo', 'dissentias', 'equidem', 'e', 'cn', 'an', 'dubium', 'est', 'quin', 'virtus', 'ita', 'maximam', 'partem', 'optineat', 'in', 'rebus', 'humanis', 'ut', 'reliquas', 'obruatnnquis', 'istum', 'dolorem', 'timetnsummus', 'dolor', 'plures', 'dies', 'manere', 'non', 'potest', 'dicet', 'pro', 'me', 'ipsa', 'virtus', 'nec', 'dubitabit', 'isti', 'vestro', 'beato', 'm', 'tubulum', 'fuisse', 'qua', 'illum', 'cuius', 'is', 'condemnatus', 'est', 'rogatione', 'p', 'quod', 'si', 'ita', 'sit', 'cur', 'opera', 'philosophiae', 'sit', 'danda', 'nescionnex', 'eorum', 'enim', 'scriptis', 'et', 'institutis', 'cum', 'omnis', 'doctrina', 'liberalis', 'omnis', 'historianquod', 'si', 'ita', 'est', 'sequitur', 'id', 'ipsum', 'quod', 'te', 'velle', 'video', 'omnes', 'semper', 'beatos', 'esse', 'sapientes', 'cum', 'enim', 'fertur', 'quasi', 'torrens', 'oratio', 'quamvis', 'multa', 'cuiusque', 'modi', 'rapiat', 'nihil', 'tamen', 'teneas', 'nihil', 'apprehendas', 'nusquam', 'orationem', 'rapidam', 'coerceas', 'ita', 'redarguitur', 'ipse', 'a', 'sese', 'convincunturque', 'scripta', 'eius', 'probitate', 'ipsius', 'ac', 'moribus', 'at', 'quanta', 'conantur', 'mundum', 'hunc', 'omnem', 'oppidum', 'esse', 'nostrum', 'incendi', 'igitur', 'eos', 'qui', 'audiunt', 'vides', 'vide', 'ne', 'magis', 'inquam', 'tuum', 'fuerit', 'cum', 're', 'idem', 'tibi', 'quod', 'mihi', 'videretur', 'non', 'nova', 'te', 'rebus', 'nomina', 'inponere', 'quivere', 'falsone', 'quaerere', 'mittimusdicitur', 'oculis', 'se', 'privasse', 'si', 'ista', 'mala', 'sunt', 'in', 'quae', 'potest', 'incidere', 'sapiens', 'sapientem', 'esse', 'non', 'esse', 'ad', 'beate', 'vivendum', 'satis', 'at', 'vero', 'si', 'ad', 'vitem', 'sensus', 'accesserit', 'ut', 'appetitum', 'quendam', 'habeat', 'et', 'per', 'se', 'ipsa', 'moveatur', 'quid', 'facturam', 'putasnnquem', 'si', 'tenueris', 'non', 'modo', 'meum', 'ciceronem', 'sed', 'etiam', 'me', 'ipsum', 'abducas', 'licebitnstulti', 'autem', 'malorum', 'memoria', 'torquentur', 'sapientes', 'bona', 'praeterita', 'grata', 'recordatione', 'renovata', 'delectantnesse', 'enim', 'quam', 'vellet', 'iniquus', 'iustus', 'poterat', 'inpunenquae', 'autem', 'natura', 'suae', 'primae', 'institutionis', 'oblita', 'estnverum', 'tamen', 'cum', 'de', 'rebus', 'grandioribus', 'dicas', 'ipsae', 'res', 'verba', 'rapiuntnhoc', 'est', 'non', 'modo', 'cor', 'non', 'habere', 'sed', 'ne', 'palatum', 'quidemnvoluptatem', 'cum', 'summum', 'bonum', 'diceret', 'primum', 'in', 'eo', 'ipso', 'parum', 'vidit', 'deinde', 'hoc', 'quoque', 'alienum', 'sed', 'tu', 'istuc', 'dixti', 'bene', 'latine', 'parum', 'plane', 'nam', 'haec', 'ipsa', 'mihi', 'erunt', 'in', 'promptu', 'quae', 'modo', 'audivi', 'nec', 'ante', 'aggrediar', 'q ...
# Total tokens after stopword removal: 509
# tokens after removal:
# ['quod', 'equidem', 'non', 'reprehendonlorem', 'ipsum', 'dolor', 'sit', 'amet', 'consectetur', 'adipiscing', 'elit', 'quibus', 'natura', 'iure', 'responderit', 'non', 'esse', 'verum', 'aliunde', 'finem', 'beate', 'vivendi', 'se', 'principia', 'rei', 'gerendae', 'peti', 'quae', 'enim', 'adhuc', 'protulisti', 'popularia', 'sunt', 'ego', 'autem', 'te', 'elegantiora', 'desidero', 'duo', 'reges', 'constructio', 'interrete', 'tum', 'lucius', 'mihi', 'vero', 'ista', 'valde', 'probata', 'sunt', 'quod', 'item', 'fratri', 'puto', 'bestiarum', 'vero', 'nullum', 'iudicium', 'puto', 'nihil', 'enim', 'iam', 'habes', 'quod', 'ad', 'corpus', 'referas', 'deinde', 'prima', 'illa', 'quae', 'congressu', 'solemus', 'quid', 'tu', 'inquit', 'huc', 'et', 'homini', 'qui', 'ceteris', 'animantibus', 'plurimum', 'praestat', 'praecipue', 'natura', 'nihil', 'datum', 'esse', 'dicemusnniam', 'id', 'ipsum', 'absurdum', 'maximum', 'malum', 'neglegi', 'quod', 'ea', 'non', 'occurrentia', 'fingunt', 'vincunt', 'aristonem', 'atqui', 'perspicuum', 'est', 'hominem', 'e', 'corpore', 'animoque', 'constare', 'cum', 'primae', 'sint', 'animi', 'partes', 'secundae', 'corporis', 'fieri', 'inquam', 'triari', 'nullo', 'pacto', 'potest', 'ut', 'non', 'dicas', 'quid', 'non', 'probes', 'eius', 'quo', 'dissentias', 'equidem', 'e', 'cn', 'dubium', 'est', 'quin', 'virtus', 'ita', 'maximam', 'partem', 'optineat', 'rebus', 'humanis', 'ut', 'reliquas', 'obruatnnquis', 'istum', 'dolorem', 'timetnsummus', 'dolor', 'plures', 'dies', 'manere', 'non', 'potest', 'dicet', 'pro', 'ipsa', 'virtus', 'nec', 'dubitabit', 'isti', 'vestro', 'beato', 'tubulum', 'fuisse', 'qua', 'illum', 'cuius', 'condemnatus', 'est', 'rogatione', 'p', 'quod', 'si', 'ita', 'sit', 'cur', 'opera', 'philosophiae', 'sit', 'danda', 'nescionnex', 'eorum', 'enim', 'scriptis', 'et', 'institutis', 'cum', 'omnis', 'doctrina', 'liberalis', 'omnis', 'historianquod', 'si', 'ita', 'est', 'sequitur', 'id', 'ipsum', 'quod', 'te', 'velle', 'video', 'omnes', 'semper', 'beatos', 'esse', 'sapientes', 'cum', 'enim', 'fertur', 'quasi', 'torrens', 'oratio', 'quamvis', 'multa', 'cuiusque', 'modi', 'rapiat', 'nihil', 'tamen', 'teneas', 'nihil', 'apprehendas', 'nusquam', 'orationem', 'rapidam', 'coerceas', 'ita', 'redarguitur', 'ipse', 'sese', 'convincunturque', 'scripta', 'eius', 'probitate', 'ipsius', 'ac', 'moribus', 'quanta', 'conantur', 'mundum', 'hunc', 'omnem', 'oppidum', 'esse', 'nostrum', 'incendi', 'igitur', 'eos', 'qui', 'audiunt', 'vides', 'vide', 'ne', 'magis', 'inquam', 'tuum', 'fuerit', 'cum', 'idem', 'tibi', 'quod', 'mihi', 'videretur', 'non', 'nova', 'te', 'rebus', 'nomina', 'inponere', 'quivere', 'falsone', 'quaerere', 'mittimusdicitur', 'oculis', 'se', 'privasse', 'si', 'ista', 'mala', 'sunt', 'quae', 'potest', 'incidere', 'sapiens', 'sapientem', 'esse', 'non', 'esse', 'ad', 'beate', 'vivendum', 'satis', 'vero', 'si', 'ad', 'vitem', 'sensus', 'accesserit', 'ut', 'appetitum', 'quendam', 'habeat', 'et', 'per', 'se', 'ipsa', 'moveatur', 'quid', 'facturam', 'putasnnquem', 'si', 'tenueris', 'non', 'modo', 'meum', 'ciceronem', 'sed', 'etiam', 'ipsum', 'abducas', 'licebitnstulti', 'autem', 'malorum', 'memoria', 'torquentur', 'sapientes', 'bona', 'praeterita', 'grata', 'recordatione', 'renovata', 'delectantnesse', 'enim', 'quam', 'vellet', 'iniquus', 'iustus', 'poterat', 'inpunenquae', 'autem', 'natura', 'suae', 'primae', 'institutionis', 'oblita', 'estnverum', 'tamen', 'cum', 'de', 'rebus', 'grandioribus', 'dicas', 'ipsae', 'res', 'verba', 'rapiuntnhoc', 'est', 'non', 'modo', 'cor', 'non', 'habere', 'sed', 'ne', 'palatum', 'quidemnvoluptatem', 'cum', 'summum', 'bonum', 'diceret', 'primum', 'eo', 'ipso', 'parum', 'vidit', 'deinde', 'hoc', 'quoque', 'alienum', 'sed', 'tu', 'istuc', 'dixti', 'bene', 'latine', 'parum', 'plane', 'nam', 'haec', 'ipsa', 'mihi', 'erunt', 'promptu', 'quae', 'modo', 'audivi', 'nec', 'ante', 'aggrediar', 'quam', 'te', 'ab', 'istis', 'quos', 'dicis', 'instructum', 'videro', 'fatebuntur', 'stoici', 'haec', 'o ...
# Complete text after stopword removal:
# quod equidem non reprehendonlorem ipsum dolor sit amet consectetur adipiscing elit quibus natura iure responderit non esse verum aliunde finem beate vivendi se principia rei gerendae peti quae enim adhuc protulisti popularia sunt ego autem te elegantiora desidero duo reges constructio interrete tum lucius mihi vero ista valde probata sunt quod item fratri puto bestiarum vero nullum iudicium puto nihil enim iam habes quod ad corpus referas deinde prima illa quae congressu solemus quid tu inquit huc et homini qui ceteris animantibus plurimum praestat praecipue natura nihil datum esse dicemusnniam id ipsum absurdum maximum malum neglegi quod ea non occurrentia fingunt vincunt aristonem atqui perspicuum est hominem e corpore animoque constare cum primae sint animi partes secundae corporis fieri inquam triari nullo pacto potest ut non dicas quid non probes eius quo dissentias equidem e cn dubium est quin virtus ita maximam partem optineat rebus humanis ut reliquas obruatnnquis istum dolorem timetnsummus dolor plures dies manere non potest dicet pro ipsa virtus nec dubitabit isti vestro beato tubulum fuisse qua illum cuius condemnatus est rogatione p quod si ita sit cur opera philosophiae sit danda nescionnex eorum enim scriptis et institutis cum omnis doctrina liberalis omnis historianquod si ita est sequitur id ipsum quod te velle video omnes semper beatos esse sapientes cum enim fertur quasi torrens oratio quamvis multa cuiusque modi rapiat nihil tamen teneas nihil apprehendas nusquam orationem rapidam coerceas ita redarguitur ipse sese convincunturque scripta eius probitate ipsius ac moribus quanta conantur mundum hunc omnem oppidum esse nostrum incendi igitur eos qui audiunt vides vide ne magis inquam tuum fuerit cum idem tibi quod mihi videretur non nova te rebus nomina inponere quivere falsone quaerere mittimusdicitur oculis se privasse si ista mala sunt quae potest incidere sapiens sapientem esse non esse ad beate vivendum satis vero si ad vitem sensus accesserit ut appetitum quendam habeat et per se ipsa moveatur quid facturam putasnnquem si tenueris non modo meum ciceronem sed etiam ipsum abducas licebitnstulti autem malorum memoria torquentur sapientes bona praeterita grata recordatione renovata delectantnesse enim quam vellet iniquus iustus poterat inpunenquae autem natura suae primae institutionis oblita estnverum tamen cum de rebus grandioribus dicas ipsae res verba rapiuntnhoc est non modo cor non habere sed ne palatum quidemnvoluptatem cum summum bonum diceret primum eo ipso parum vidit deinde hoc quoque alienum sed tu istuc dixti bene latine parum plane nam haec ipsa mihi erunt promptu quae modo audivi nec ante aggrediar quam te ab istis quos dicis instructum videro fatebuntur stoici haec omnia dicta esse praeclare neque eam causam zenoni desciscendi fuisse non autem hoc igitur ne illud quidem ratio quidem vestra sic cogit cum audissem antiochum brute ut solebam cum quod ita callida est ut optime possit architectari voluptatesnnidemne quod iucundenhaec mihi videtur delicatior ut ita dicam molliorque ratio quam virtutis vis gravitasque postulat sed quoniam et advesperascit et mihi ad villam revertendum est nunc quidem hactenus cuius ad naturam apta ratio vera illa et summa lex philosophis dicitur neque solum ea communia verum etiam paria esse dixerunt sed nunc quod agimus mene tu

# %% [markdown]
# # 5. Tokenization (Sentence, Word, Character)

# %%
# Sentence Tokenization
sentences = sent_tokenize(text_lower)
print("Sentence Tokenization:")
print(f"Total number of sentences: {len(sentences)}")
print("All sentences:")
for i, sent in enumerate(sentences, 1):
    print(f"{i}. {sent}")

# Word Tokenization
words = word_tokenize(text_lower)
print("Word Tokenization:")
print(f"Total number of words: {len(words)}")
print("All words:")
print(words)

# Character Tokenization
chars = [char for char in text_lower if char != ' ']
print("Character Tokenization:")
print(f"Total number of characters (without spaces): {len(chars)}")
print("All characters:")
print(chars)
# Out:
# Sentence Tokenization:
# Total number of sentences: 24
# All sentences:
# 1. quod equidem non reprehendonlorem ipsum dolor sit amet, consectetur adipiscing elit.
# 2. quibus natura iure responderit non esse verum aliunde finem beate vivendi, a se principia rei gerendae peti quae enim adhuc protulisti, popularia sunt, ego autem a te elegantiora desidero.
# 3. duo reges constructio interrete.
# 4. tum lucius mihi vero ista valde probata sunt, quod item fratri puto.
# 5. bestiarum vero nullum iudicium puto.
# 6. nihil enim iam habes, quod ad corpus referas deinde prima illa, quae in congressu solemus quid tu, inquit, huc et homini, qui ceteris animantibus plurimum praestat, praecipue a natura nihil datum esse dicemusnniam id ipsum absurdum, maximum malum neglegi.
# 7. quod ea non occurrentia fingunt, vincunt aristonem atqui perspicuum est hominem e corpore animoque constare, cum primae sint animi partes, secundae corporis.
# 8. fieri, inquam, triari, nullo pacto potest, ut non dicas, quid non probes eius, a quo dissentias.
# 9. equidem e cn.
# 10. an dubium est, quin virtus ita maximam partem optineat in rebus humanis, ut reliquas obruatnnquis istum dolorem timetnsummus dolor plures dies manere non potest dicet pro me ipsa virtus nec dubitabit isti vestro beato m. tubulum fuisse, qua illum, cuius is condemnatus est rogatione, p. quod si ita sit, cur opera philosophiae sit danda nescio.nnex eorum enim scriptis et institutis cum omnis doctrina liberalis, omnis historia.nquod si ita est, sequitur id ipsum, quod te velle video, omnes semper beatos esse sapientes.
# 11. cum enim fertur quasi torrens oratio, quamvis multa cuiusque modi rapiat, nihil tamen teneas, nihil apprehendas, nusquam orationem rapidam coerceas.
# 12. ita redarguitur ipse a sese, convincunturque scripta eius probitate ipsius ac moribus.
# 13. at quanta conantur mundum hunc omnem oppidum esse nostrum incendi igitur eos, qui audiunt, vides.
# 14. vide, ne magis, inquam, tuum fuerit, cum re idem tibi, quod mihi, videretur, non nova te rebus nomina inponere.
# 15. quivere falsone, quaerere mittimusdicitur oculis se privasse si ista mala sunt, in quae potest incidere sapiens, sapientem esse non esse ad beate vivendum satis.
# 16. at vero si ad vitem sensus accesserit, ut appetitum quendam habeat et per se ipsa moveatur, quid facturam putasnnquem si tenueris, non modo meum ciceronem, sed etiam me ipsum abducas licebit.nstulti autem malorum memoria torquentur, sapientes bona praeterita grata recordatione renovata delectant.nesse enim quam vellet iniquus iustus poterat inpune.nquae autem natura suae primae institutionis oblita estnverum tamen cum de rebus grandioribus dicas, ipsae res verba rapiuntnhoc est non modo cor non habere, sed ne palatum quidem.nvoluptatem cum summum bonum diceret, primum in eo ipso parum vidit, deinde hoc quoque alienum sed tu istuc dixti bene latine, parum plane.
# 17. nam haec ipsa mihi erunt in promptu, quae modo audivi, nec ante aggrediar, quam te ab istis, quos dicis, instructum videro.
# 18. fatebuntur stoici haec omnia dicta esse praeclare, neque eam causam zenoni desciscendi fuisse.
# 19. non autem hoc igitur ne illud quidem.
# 20. ratio quidem vestra sic cogit.
# 21. cum audissem antiochum, brute, ut solebam, cum m. an quod ita callida est, ut optime possit architectari voluptatesnnidemne, quod iucundenhaec mihi videtur delicatior, ut ita dicam, molliorque ratio, quam virtutis vis gravitasque postulat.
# 22. sed quoniam et advesperascit et mihi ad villam revertendum est, nunc quidem hactenus cuius ad naturam apta ratio vera illa et summa lex a philosophis dicitur.
# 23. neque solum ea communia, verum etiam paria esse dixerunt.
# 24. sed nunc, quod agimus a mene tu
# Word Tokenization:
# Total number of words: 629
# All words:
# ['quod', 'equidem', 'non', 'reprehendonlorem', 'ipsum', 'dolor', 'sit', 'amet', ',', 'consectetur', 'adipiscing', 'elit', '.', 'quibus', 'natura', 'iure', 'responderit', 'non', 'esse', 'verum', 'aliunde', 'finem', 'beate', 'vivendi', ',', 'a', 'se', 'principia', 'rei', 'gerendae', 'peti', 'quae', 'enim', 'adhuc', 'protulisti', ',', 'popularia', 'sunt', ',', 'ego', 'autem', 'a', 'te', 'elegantiora', 'desidero', '.', 'duo', 'reges', 'constructio', 'interrete', '.', 'tum', 'lucius', 'mihi', 'vero', 'ista', 'valde', 'probata', 'sunt', ',', 'quod', 'item', 'fratri', 'puto', '.', 'bestiarum', 'vero', 'nullum', 'iudicium', 'puto', '.', 'nihil', 'enim', 'iam', 'habes', ',', 'quod', 'ad', 'corpus', 'referas', 'deinde', 'prima', 'illa', ',', 'quae', 'in', 'congressu', 'solemus', 'quid', 'tu', ',', 'inquit', ',', 'huc', 'et', 'homini', ',', 'qui', 'ceteris', 'animantibus', 'plurimum', 'praestat', ',', 'praecipue', 'a', 'natura', 'nihil', 'datum', 'esse', 'dicemusnniam', 'id', 'ipsum', 'absurdum', ',', 'maximum', 'malum', 'neglegi', '.', 'quod', 'ea', 'non', 'occurrentia', 'fingunt', ',', 'vincunt', 'aristonem', 'atqui', 'perspicuum', 'est', 'hominem', 'e', 'corpore', 'animoque', 'constare', ',', 'cum', 'primae', 'sint', 'animi', 'partes', ',', 'secundae', 'corporis', '.', 'fieri', ',', 'inquam', ',', 'triari', ',', 'nullo', 'pacto', 'potest', ',', 'ut', 'non', 'dicas', ',', 'quid', 'non', 'probes', 'eius', ',', 'a', 'quo', 'dissentias', '.', 'equidem', 'e', 'cn', '.', 'an', 'dubium', 'est', ',', 'quin', 'virtus', 'ita', 'maximam', 'partem', 'optineat', 'in', 'rebus', 'humanis', ',', 'ut', 'reliquas', 'obruatnnquis', 'istum', 'dolorem', 'timetnsummus', 'dolor', 'plures', 'dies', 'manere', 'non', 'potest', 'dicet', 'pro', 'me', 'ipsa', 'virtus', 'nec', 'dubitabit', 'isti', 'vestro', 'beato', 'm.', 'tubulum', 'fuisse', ',', 'qua', 'illum', ',', 'cuius', 'is', 'condemnatus', 'est', 'rogatione', ',', 'p.', 'quod', 'si', 'ita', 'sit', ',', 'cur', 'opera', 'philosophiae', 'sit', 'danda', 'nescio.nnex', 'eorum', 'enim', 'scriptis', 'et', 'institutis', 'cum', 'omnis', 'doctrina', 'liberalis', ',', 'omnis', 'historia.nquod', 'si', 'ita', 'est', ',', 'sequitur', 'id', 'ipsum', ',', 'quod', 'te', 'velle', 'video', ',', 'omnes', 'semper', 'beatos', 'esse', 'sapientes', '.', 'cum', 'enim', 'fertur', 'quasi', 'torrens', 'oratio', ',', 'quamvis', 'multa', 'cuiusque', 'modi', 'rapiat', ',', 'nihil', 'tamen', 'teneas', ',', 'nihil', 'apprehendas', ',', 'nusquam', 'orationem', 'rapidam', 'coerceas', '.', 'ita', 'redarguitur', 'ipse', 'a', 'sese', ',', 'convincunturque', 'scripta', 'eius', 'probitate', 'ipsius', 'ac', 'moribus', '.', 'at', 'quanta', 'conantur', 'mundum', 'hunc', 'omnem', 'oppidum', 'esse', 'nostrum', 'incendi', 'igitur', 'eos', ',', 'qui', 'audiunt', ',', 'vides', '.', 'vide', ',', 'ne', 'magis', ',', 'inquam', ',', 'tuum', 'fuerit', ',', 'cum', 're', 'idem', 'tibi', ',', 'quod', 'mihi', ',', 'videretur', ',', 'non', 'nova', 'te', 'rebus', 'nomina', 'inponere', '.', 'quivere', 'falsone', ',', 'quaerere', 'mittimusdicitur', 'oculis', 'se', 'privasse', 'si', 'ista', 'mala', 'sunt', ',', 'in', 'quae', 'potest', 'incidere', 'sapiens', ',', 'sapientem', 'esse', 'non', 'esse', 'ad', 'beate', 'vivendum', 'satis', '.', 'at', 'vero', 'si', 'ad', 'vitem', 'sensus', 'accesserit', ',', 'ut', 'appetitum', 'quendam', 'habeat', 'et', 'per', 'se', 'ipsa', 'moveatur', ',', 'quid', 'facturam', 'putasnnquem', 'si', 'tenueris', ',', 'non', 'modo', 'meum', 'ciceronem', ',', 'sed', 'etiam', 'me', 'ipsum', 'abducas', 'licebit.nstulti', 'autem', 'malorum', 'memoria', 'torquentur', ',', 'sapientes', 'bona', 'praeterita', 'grata', 'recordatione', 'renovata', 'delectant.nesse', 'enim', 'quam', 'vellet', 'iniquus', 'iustus', 'poterat', 'inpune.nquae', 'autem', 'natura', 'suae', 'primae', 'institutionis', 'oblita', 'estnverum', 'tamen', 'cum', 'de', 'rebus', 'grandioribus', 'dicas', ',', 'ipsae', 'res', 'verba', 'rapiuntnhoc', 'est', 'non', 'modo', 'cor', 'non', 'haber ...
# Character Tokenization:
# Total number of characters (without spaces): 2984
# All characters:
# ['q', 'u', 'o', 'd', 'e', 'q', 'u', 'i', 'd', 'e', 'm', 'n', 'o', 'n', 'r', 'e', 'p', 'r', 'e', 'h', 'e', 'n', 'd', 'o', 'n', 'l', 'o', 'r', 'e', 'm', 'i', 'p', 's', 'u', 'm', 'd', 'o', 'l', 'o', 'r', 's', 'i', 't', 'a', 'm', 'e', 't', ',', 'c', 'o', 'n', 's', 'e', 'c', 't', 'e', 't', 'u', 'r', 'a', 'd', 'i', 'p', 'i', 's', 'c', 'i', 'n', 'g', 'e', 'l', 'i', 't', '.', 'q', 'u', 'i', 'b', 'u', 's', 'n', 'a', 't', 'u', 'r', 'a', 'i', 'u', 'r', 'e', 'r', 'e', 's', 'p', 'o', 'n', 'd', 'e', 'r', 'i', 't', 'n', 'o', 'n', 'e', 's', 's', 'e', 'v', 'e', 'r', 'u', 'm', 'a', 'l', 'i', 'u', 'n', 'd', 'e', 'f', 'i', 'n', 'e', 'm', 'b', 'e', 'a', 't', 'e', 'v', 'i', 'v', 'e', 'n', 'd', 'i', ',', 'a', 's', 'e', 'p', 'r', 'i', 'n', 'c', 'i', 'p', 'i', 'a', 'r', 'e', 'i', 'g', 'e', 'r', 'e', 'n', 'd', 'a', 'e', 'p', 'e', 't', 'i', 'q', 'u', 'a', 'e', 'e', 'n', 'i', 'm', 'a', 'd', 'h', 'u', 'c', 'p', 'r', 'o', 't', 'u', 'l', 'i', 's', 't', 'i', ',', 'p', 'o', 'p', 'u', 'l', 'a', 'r', 'i', 'a', 's', 'u', 'n', 't', ',', 'e', 'g', 'o', 'a', 'u', 't', 'e', 'm', 'a', 't', 'e', 'e', 'l', 'e', 'g', 'a', 'n', 't', 'i', 'o', 'r', 'a', 'd', 'e', 's', 'i', 'd', 'e', 'r', 'o', '.', 'd', 'u', 'o', 'r', 'e', 'g', 'e', 's', 'c', 'o', 'n', 's', 't', 'r', 'u', 'c', 't', 'i', 'o', 'i', 'n', 't', 'e', 'r', 'r', 'e', 't', 'e', '.', 't', 'u', 'm', 'l', 'u', 'c', 'i', 'u', 's', 'm', 'i', 'h', 'i', 'v', 'e', 'r', 'o', 'i', 's', 't', 'a', 'v', 'a', 'l', 'd', 'e', 'p', 'r', 'o', 'b', 'a', 't', 'a', 's', 'u', 'n', 't', ',', 'q', 'u', 'o', 'd', 'i', 't', 'e', 'm', 'f', 'r', 'a', 't', 'r', 'i', 'p', 'u', 't', 'o', '.', 'b', 'e', 's', 't', 'i', 'a', 'r', 'u', 'm', 'v', 'e', 'r', 'o', 'n', 'u', 'l', 'l', 'u', 'm', 'i', 'u', 'd', 'i', 'c', 'i', 'u', 'm', 'p', 'u', 't', 'o', '.', 'n', 'i', 'h', 'i', 'l', 'e', 'n', 'i', 'm', 'i', 'a', 'm', 'h', 'a', 'b', 'e', 's', ',', 'q', 'u', 'o', 'd', 'a', 'd', 'c', 'o', 'r', 'p', 'u', 's', 'r', 'e', 'f', 'e', 'r', 'a', 's', 'd', 'e', 'i', 'n', 'd', 'e', 'p', 'r', 'i', 'm', 'a', 'i', 'l', 'l', 'a', ',', 'q', 'u', 'a', 'e', 'i', 'n', 'c', 'o', 'n', 'g', 'r', 'e', 's', 's', 'u', 's', 'o', 'l', 'e', 'm', 'u', 's', 'q', 'u', 'i', 'd', 't', 'u', ',', 'i', 'n', 'q', 'u', 'i', 't', ',', 'h', 'u', 'c', 'e', 't', 'h', 'o', 'm', 'i', 'n', 'i', ',', 'q', 'u', 'i', 'c', 'e', 't', 'e', 'r', 'i', 's', 'a', 'n', 'i', 'm', 'a', 'n', 't', 'i', 'b', 'u', 's', 'p', 'l', 'u', 'r', 'i', 'm', 'u', 'm', 'p', 'r', 'a', 'e', 's', 't', 'a', 't', ',', 'p', 'r', 'a', 'e', 'c', 'i', 'p', 'u', 'e', 'a', 'n', 'a', 't', 'u', 'r', 'a', 'n', 'i', 'h', 'i', 'l', 'd', 'a', 't', 'u', 'm', 'e', 's', 's', 'e', 'd', 'i', 'c', 'e', 'm', 'u', 's', 'n', 'n', 'i', 'a', 'm', 'i', 'd', 'i', 'p', 's', 'u', 'm', 'a', 'b', 's', 'u', 'r', 'd', 'u', 'm', ',', 'm', 'a', 'x', 'i', 'm', 'u', 'm', 'm', 'a', 'l', 'u', 'm', 'n', 'e', 'g', 'l', 'e', 'g', 'i', '.', 'q', 'u', 'o', 'd', 'e', 'a', 'n', 'o', 'n', 'o', 'c', 'c', 'u', 'r', 'r', 'e', 'n', 't', 'i', 'a', 'f', 'i', 'n', 'g', 'u', 'n', 't', ',', 'v', 'i', 'n', 'c', 'u', 'n', 't', 'a', 'r', 'i', 's', 't', 'o', 'n', 'e', 'm', 'a', 't', 'q', 'u', 'i', 'p', 'e', 'r', 's', 'p', 'i', 'c', 'u', 'u', 'm', 'e', 's', 't', 'h', 'o', 'm', 'i', 'n', 'e', 'm', 'e', 'c', 'o', 'r', 'p', 'o', 'r', 'e', 'a', 'n', 'i', 'm', 'o', 'q', 'u', 'e', 'c', 'o', 'n', 's', 't', 'a', 'r', 'e', ',', 'c', 'u', 'm', 'p', 'r', 'i', 'm', 'a', 'e', 's', 'i', 'n', 't', 'a', 'n', 'i', 'm', 'i', 'p', 'a', 'r', 't', 'e', 's', ',', 's', 'e', 'c', 'u', 'n', 'd', 'a', 'e', 'c', 'o', 'r', 'p', 'o', 'r', 'i', 's', '.', 'f', 'i', 'e', 'r', 'i', ',', 'i', 'n', 'q', 'u', 'a', 'm', ',', 't', 'r', 'i', 'a', 'r', 'i', ',', 'n', 'u', 'l', 'l', 'o', 'p', 'a', 'c', 't', 'o', 'p', 'o', 't', 'e', 's', 't', ',', 'u', 't', 'n', 'o', 'n', 'd', 'i', 'c', 'a', 's', ',', 'q', 'u', 'i', 'd', 'n', 'o', 'n', 'p', 'r', 'o', 'b', 'e', 's', 'e', 'i', 'u', 's', ',', 'a', 'q', 'u', 'o', 'd', 'i', 's', 's', 'e', 'n', 't', 'i', 'a', 's', '.', 'e', 'q', 'u', 'i', 'd', 'e', 'm', 'e', 'c', 'n', '.', 'a', 'n', 'd', ...

# %% [markdown]
# # 6. Stemming (PorterStemmer and SnowballStemmer)

# %%
# Initialize both stemmers
porter_stemmer = PorterStemmer()
snowball_stemmer = SnowballStemmer("english")

# Apply both stemmers
porter_stemmed_tokens = [porter_stemmer.stem(word) for word in filtered_tokens]
snowball_stemmed_tokens = [snowball_stemmer.stem(word) for word in filtered_tokens]

print("COMPLETE COMPARISON (Original vs Porter vs Snowball):")
print(f"{'#':<5} | {'Original Word':<25} | {'Porter Stemmer':<20} | {'Snowball Stemmer':<20} | {'Difference'}")

difference_count = 0
for i, (original, porter, snowball) in enumerate(zip(filtered_tokens, porter_stemmed_tokens, snowball_stemmed_tokens), 1):
    difference = "DIFFERENT" if porter != snowball else "SAME"
    if porter != snowball:
        difference_count += 1
    print(f"{i:<5} | {original:<25} | {porter:<20} | {snowball:<20} | {difference}")

print(f"\nTotal words with different stemming results: {difference_count} out of {len(filtered_tokens)}")
print(f"Percentage of differences: {(difference_count/len(filtered_tokens))*100:.2f}%")

# Show detailed comparison for words that differ
print("\nDETAILED COMPARISON FOR WORDS WITH DIFFERENT STEMMING RESULTS:")

different_words = []
for original, porter, snowball in zip(filtered_tokens, porter_stemmed_tokens, snowball_stemmed_tokens):
    if porter != snowball:
        different_words.append((original, porter, snowball))

if different_words:
    print(f"{'#':<5} | {'Original Word':<25} | {'Porter Result':<20} | {'Snowball Result':<20} | {'Analysis'}")
    for i, (original, porter, snowball) in enumerate(different_words, 1):
        analysis = ""
        if len(porter) < len(snowball):
            analysis = "Porter shorter"
        elif len(snowball) < len(porter):
            analysis = "Snowball shorter"
        elif porter.endswith('ing') and not snowball.endswith('ing'):
            analysis = "Porter keeps -ing"
        elif snowball.endswith('ing') and not porter.endswith('ing'):
            analysis = "Snowball keeps -ing"
        else:
            analysis = "Different algorithm"
        print(f"{i:<5} | {original:<25} | {porter:<20} | {snowball:<20} | {analysis}")
else:
    print("No differences found between Porter and Snowball stemmers for this text.")

# Show complete stemmed texts
print("\nCOMPLETE PORTER STEMMED TEXT:")
porter_stemmed_text = ' '.join(porter_stemmed_tokens)
print(porter_stemmed_text)

print("\nCOMPLETE SNOWBALL STEMMED TEXT:")
snowball_stemmed_text = ' '.join(snowball_stemmed_tokens)
print(snowball_stemmed_text)

# Performance comparison
print("\nPERFORMANCE COMPARISON:")

# Test Porter speed
start_time = time.time()
for word in filtered_tokens * 10:
    porter_stemmer.stem(word)
porter_time = time.time() - start_time

# Test Snowball speed
start_time = time.time()
for word in filtered_tokens * 10:
    snowball_stemmer.stem(word)
snowball_time = time.time() - start_time

print(f"PorterStemmer processing time (10 repetitions): {porter_time:.6f} seconds")
print(f"SnowballStemmer processing time (10 repetitions): {snowball_time:.6f} seconds")
if porter_time > snowball_time:
    print(f"SnowballStemmer is {porter_time/snowball_time:.2f}x faster than PorterStemmer")
else:
    print(f"PorterStemmer is {snowball_time/porter_time:.2f}x faster than SnowballStemmer")
# Out:
# COMPLETE COMPARISON (Original vs Porter vs Snowball):
# #     | Original Word             | Porter Stemmer       | Snowball Stemmer     | Difference
# 1     | quod                      | quod                 | quod                 | SAME
# 2     | equidem                   | equidem              | equidem              | SAME
# 3     | non                       | non                  | non                  | SAME
# 4     | reprehendonlorem          | reprehendonlorem     | reprehendonlorem     | SAME
# 5     | ipsum                     | ipsum                | ipsum                | SAME
# 6     | dolor                     | dolor                | dolor                | SAME
# 7     | sit                       | sit                  | sit                  | SAME
# 8     | amet                      | amet                 | amet                 | SAME
# 9     | consectetur               | consectetur          | consectetur          | SAME
# 10    | adipiscing                | adipisc              | adipisc              | SAME
# 11    | elit                      | elit                 | elit                 | SAME
# 12    | quibus                    | quibu                | quibus               | DIFFERENT
# 13    | natura                    | natura               | natura               | SAME
# 14    | iure                      | iur                  | iur                  | SAME
# 15    | responderit               | responderit          | responderit          | SAME
# 16    | non                       | non                  | non                  | SAME
# 17    | esse                      | ess                  | ess                  | SAME
# 18    | verum                     | verum                | verum                | SAME
# 19    | aliunde                   | aliund               | aliund               | SAME
# 20    | finem                     | finem                | finem                | SAME
# 21    | beate                     | beat                 | beat                 | SAME
# 22    | vivendi                   | vivendi              | vivendi              | SAME
# 23    | se                        | se                   | se                   | SAME
# 24    | principia                 | principia            | principia            | SAME
# 25    | rei                       | rei                  | rei                  | SAME
# 26    | gerendae                  | gerenda              | gerenda              | SAME
# 27    | peti                      | peti                 | peti                 | SAME
# 28    | quae                      | quae                 | quae                 | SAME
# 29    | enim                      | enim                 | enim                 | SAME
# 30    | adhuc                     | adhuc                | adhuc                | SAME
# 31    | protulisti                | protulisti           | protulisti           | SAME
# 32    | popularia                 | popularia            | popularia            | SAME
# 33    | sunt                      | sunt                 | sunt                 | SAME
# 34    | ego                       | ego                  | ego                  | SAME
# 35    | autem                     | autem                | autem                | SAME
# 36    | te                        | te                   | te                   | SAME
# 37    | elegantiora               | elegantiora          | elegantiora          | SAME
# 38    | desidero                  | desidero             | desidero             | SAME
# 39    | duo                       | duo                  | duo                  | SAME
# 40    | reges                     | rege                 | rege                 | SAME
# 41    | constructio               | constructio          | constructio          | SAME
# 42    | interrete                 | interret             | interret             | SAME
# 43    | tum                       | tum                  | tum                  | SAME
# 44    | lucius                    | luciu                | lucius               | DIFFERENT
# 45    | mihi                      | mihi                 | mihi                 | SAME
# 46    | vero                      | vero                 | vero                 | SAME
# 47    | ista                      | ista                 | ista                 | SAME
# 48    | valde                     | vald                 | vald                 | SAME
# 49    | probata                   | probata              | probata              | SAME
# 50    | sunt                      | sunt                 | sunt                 | SAME
# 51    | quod                      | quod                 | quod                 | SAME
# 52    | item                      | item                 | item                 | SAME
# 53    | fratri                    | fratri               | fratri               | SAME
# 54    | puto                      | puto                 | puto                 | SAME
# 55    | bestiarum                 | bestiarum            | bestiarum            | SAME
# 56    | vero                      | vero                 | vero                 | SAME
# 57    | nullum                    | nullum               | nullum               | SAME
# 58    | iudicium                  | iudicium             | iudicium             | SAME
# 59    | puto                      | puto                 | puto                 | SAME
# 60    | nihil                     | nihil                | nihil                | SAME
# 61    | enim                      | enim                 | enim                 | SAME
# 62    | iam                       | iam                  | iam                  | SAME
# 63    | habes                     | habe                 | habe                 | SAME
# 64    | quod                      | quod                 | quod                 | SAME
# 65    | ad                        | ad                   | ad                   | SAME
# 66    | corpus                    | corpu                | corpus               | DIFFERENT
# 67    | referas                   | refera               | refera               | SAME
# 68    | deinde                    | deind                | deind                | SAME
# 69    | prima                     | prima                | prima                | SAME
# 70    | illa                      | illa                 | illa                 | SAME
# 71    | quae                      | quae                 | quae                 | SAME
# 72    | congressu                 | congressu            | congressu            | SAME
# 73    | solemus                   | solemu               | solemus              | DIFFERENT
# 74    | quid                      | quid                 | quid                 | SAME
# 75    | tu                        | tu                   | tu                   | SAME
# 76    | inquit                    | inquit               | inquit               | SAME
# 77    | huc                       | huc                  | huc                  | SAME
# 78    | et                        | et                   | et                   | SAME
# 79    | homini                    | homini               | homini               | SAME
# 80    | qui                       | qui                  | qui                  | SAME
# 81    | ceteris                   | ceteri               | ceteri               | SAME
# 82    | animantibus               | animantibu           | animantibus          | DIFFERENT
# 83    | plurimum                  | plurimum             | plurimum             | SAME
# 84    | praestat                  | praestat             | praestat             | SAME
# 85    | praecipue                 | praecipu             | praecipu             | SAME
# 86    | natura                    | natura               | natura               | SAME
# 87    | nihil                     | nihil                | nihil                | SAME
# 88    | datum                     | datum                | datum                | SAME
# 89    | esse                      | ess                  | ess                  | SAME
# 90    | dicemusnniam              | dicemusnniam         | dicemusnniam         | SAME
# 91    | id                        | id                   | id                   | SAME
# 92    | ipsum                     | ipsum                | ipsum                | SAME
# 93    | absurdum                  | absurdum             | absurdum             | SAME
# 94    | maximum                   | maximum              | maximum              | SAME
# 95    | malum                     | malum                | malum                | SAME
# 96    | neglegi                   | neglegi              | neglegi              | SAME
# 97    | quod                      | quod                 | quod                 | SAME
# 98    | ea                        | ea                   | ea                   | SAME
# 99    | non                       | non                  | non                  | SAME
# 100   | occurrentia               | occurrentia          | occurrentia          | SAME
# 101   | fingunt                   | fingunt              | fingunt              | SAME
# 102   | vincunt                   | vincunt              | vincunt              | SAME
# 103   | aristonem                 | aristonem            | aristonem            | SAME
# 104   | atqui                     | atqui                | atqui                | SAME
# 105   | perspicuum                | perspicuum           | perspicuum           | SAME
# 106   | est                       | est                  | est                  | SAME
# 107   | hominem                   | hominem              | hominem              | SAME
# 108   | e                         | e                    | e                    | SAME
# 109   | corpore                   | corpor               | corpor               | SAME
# 110   | animoque                  | animoqu              | animoqu              | SAME
# 111   | constare                  | constar              | constar              | SAME
# 112   | cum                       | cum                  | cum                  | SAME
# 113   | primae                    | prima                | prima                | SAME
# 114   | sint                      | sint                 | sint                 | SAME
# 115   | animi                     | animi                | animi                | SAME
# 116   | partes                    | part                 | part                 | SAME
# 117   | secundae                  | secunda              | secunda              | SAME
# 118   | corporis                  | corpori              | corpori              | SAME
# 119   | fieri                     | fieri                | fieri                | SAME
# 120   | inquam                    | inquam               | inquam               | SAME
# 121   | triari                    | triari               | triari               | SAME
# 122   | nullo                     | nullo                | nullo                | SAME
# 123   | pacto                     | pacto                | pacto                | SAME
# 124   | potest                    | potest               | potest               | SAME
# 125   | ut                        | ut                   | ut                   | SAME
# 126   | non                       | non                  | non                  | SAME
# 127   | dicas                     | dica                 | dica                 | SAME
# 128   | quid                      | quid                 | quid                 | SAME
# 129   | non                       | non                  | non                  | SAME
# 130   | probes                    | probe                | probe                | SAME
# 131   | eius                      | eiu                  | eius                 | DIFFERENT
# 132   | quo                       | quo                  | quo                  | SAME
# 133   | dissentias                | dissentia            | dissentia            | SAME
# 134   | equidem                   | equidem              | equidem              | SAME
# 135   | e                         | e                    | e                    | SAME
# 136   | cn                        | cn                   | cn                   | SAME
# 137   | dubium                    | dubium               | dubium               | SAME
# 138   | est                       | est                  | est                  | SAME
# 139   | quin                      | quin                 | quin                 | SAME
# 140   | virtus                    | virtu                | virtus               | DIFFERENT
# 141   | ita                       | ita                  | ita                  | SAME
# 142   | maximam                   | maximam              | maximam              | SAME
# 143   | partem                    | partem               | partem               | SAME
# 144   | optineat                  | optineat             | optineat             | SAME
# 145   | rebus                     | rebu                 | rebus                | DIFFERENT
# 146   | humanis                   | humani               | humani               | SAME
# 147   | ut                        | ut                   | ut                   | SAME
# 148   | reliquas                  | reliqua              | reliqua              | SAME
# 149   | obruatnnquis              | obruatnnqui          | obruatnnqui          | SAME
# 150   | istum                     | istum                | istum                | SAME
# 151   | dolorem                   | dolorem              | dolorem              | SAME
# 152   | timetnsummus              | timetnsummu          | timetnsummus         | DIFFERENT
# 153   | dolor                     | dolor                | dolor                | SAME
# 154   | plures                    | plure                | plure                | SAME
# 155   | dies                      | die                  | die                  | SAME
# 156   | manere                    | maner                | maner                | SAME
# 157   | non                       | non                  | non                  | SAME
# 158   | potest                    | potest               | potest               | SAME
# 159   | dicet                     | dicet                | dicet                | SAME
# 160   | pro                       | pro                  | pro                  | SAME
# 161   | ipsa                      | ipsa                 | ipsa                 | SAME
# 162   | virtus                    | virtu                | virtus               | DIFFERENT
# 163   | nec                       | nec                  | nec                  | SAME
# 164   | dubitabit                 | dubitabit            | dubitabit            | SAME
# 165   | isti                      | isti                 | isti                 | SAME
# 166   | vestro                    | vestro               | vestro               | SAME
# 167   | beato                     | beato                | beato                | SAME
# 168   | tubulum                   | tubulum              | tubulum              | SAME
# 169   | fuisse                    | fuiss                | fuiss                | SAME
# 170   | qua                       | qua                  | qua                  | SAME
# 171   | illum                     | illum                | illum                | SAME
# 172   | cuius                     | cuiu                 | cuius                | DIFFERENT
# 173   | condemnatus               | condemnatu           | condemnatus          | DIFFERENT
# 174   | est                       | est                  | est                  | SAME
# 175   | rogatione                 | rogation             | rogation             | SAME
# 176   | p                         | p                    | p                    | SAME
# 177   | quod                      | quod                 | quod                 | SAME
# 178   | si                        | si                   | si                   | SAME
# 179   | ita                       | ita                  | ita                  | SAME
# 180   | sit                       | sit                  | sit                  | SAME
# 181   | cur                       | cur                  | cur                  | SAME
# 182   | opera                     | opera                | opera                | SAME
# 183   | philosophiae              | philosophia          | philosophia          | SAME
# 184   | sit                       | sit                  | sit                  | SAME
# 185   | danda                     | danda                | danda                | SAME
# 186   | nescionnex                | nescionnex           | nescionnex           | SAME
# 187   | eorum                     | eorum                | eorum                | SAME
# 188   | enim                      | enim                 | enim                 | SAME
# 189   | scriptis                  | scripti              | scripti              | SAME
# 190   | et                        | et                   | et                   | SAME
# 191   | institutis                | instituti            | instituti            | SAME
# 192   | cum                       | cum                  | cum                  | SAME
# 193   | omnis                     | omni                 | omni                 | SAME
# 194   | doctrina                  | doctrina             | doctrina             | SAME
# 195   | liberalis                 | liberali             | liberali             | SAME
# 196   | omnis                     | omni                 | omni                 | SAME
# 197   | historianquod             | historianquod        | historianquod        | SAME
# 198   | si                        | si                   | si                   | SAME
# 199   | ita                       | ita                  | ita                  | SAME
# 200   | est                       | est                  | est                  | SAME
# 201   | sequitur                  | sequitur             | sequitur             | SAME
# 202   | id                        | id                   | id                   | SAME
# 203   | ipsum                     | ipsum                | ipsum                | SAME
# 204   | quod                      | quod                 | quod                 | SAME
# 205   | te                        | te                   | te                   | SAME
# 206   | velle                     | vell                 | vell                 | SAME
# 207   | video                     | video                | video                | SAME
# 208   | omnes                     | omn                  | omn                  | SAME
# 209   | semper                    | semper               | semper               | SAME
# 210   | beatos                    | beato                | beato                | SAME
# 211   | esse                      | ess                  | ess                  | SAME
# 212   | sapientes                 | sapient              | sapient              | SAME
# 213   | cum                       | cum                  | cum                  | SAME
# 214   | enim                      | enim                 | enim                 | SAME
# 215   | fertur                    | fertur               | fertur               | SAME
# 216   | quasi                     | quasi                | quasi                | SAME
# 217   | torrens                   | torren               | torren               | SAME
# 218   | oratio                    | oratio               | oratio               | SAME
# 219   | quamvis                   | quamvi               | quamvi               | SAME
# 220   | multa                     | multa                | multa                | SAME
# 221   | cuiusque                  | cuiusqu              | cuiusqu              | SAME
# 222   | modi                      | modi                 | modi                 | SAME
# 223   | rapiat                    | rapiat               | rapiat               | SAME
# 224   | nihil                     | nihil                | nihil                | SAME
# 225   | tamen                     | tamen                | tamen                | SAME
# 226   | teneas                    | tenea                | tenea                | SAME
# 227   | nihil                     | nihil                | nihil                | SAME
# 228   | apprehendas               | apprehenda           | apprehenda           | SAME
# 229   | nusquam                   | nusquam              | nusquam              | SAME
# 230   | orationem                 | orationem            | orationem            | SAME
# 231   | rapidam                   | rapidam              | rapidam              | SAME
# 232   | coerceas                  | coercea              | coercea              | SAME
# 233   | ita                       | ita                  | ita                  | SAME
# 234   | redarguitur               | redarguitur          | redarguitur          | SAME
# 235   | ipse                      | ips                  | ips                  | SAME
# 236   | sese                      | sese                 | sese                 | SAME
# 237   | convincunturque           | convincunturqu       | convincunturqu       | SAME
# 238   | scripta                   | scripta              | scripta              | SAME
# 239   | eius                      | eiu                  | eius                 | DIFFERENT
# 240   | probitate                 | probit               | probit               | SAME
# 241   | ipsius                    | ipsiu                | ipsius               | DIFFERENT
# 242   | ac                        | ac                   | ac                   | SAME
# 243   | moribus                   | moribu               | moribus              | DIFFERENT
# 244   | quanta                    | quanta               | quanta               | SAME
# 245   | conantur                  | conantur             | conantur             | SAME
# 246   | mundum                    | mundum               | mundum               | SAME
# 247   | hunc                      | hunc                 | hunc                 | SAME
# 248   | omnem                     | omnem                | omnem                | SAME
# 249   | oppidum                   | oppidum              | oppidum              | SAME
# 250   | esse                      | ess                  | ess                  | SAME
# 251   | nostrum                   | nostrum              | nostrum              | SAME
# 252   | incendi                   | incendi              | incendi              | SAME
# 253   | igitur                    | igitur               | igitur               | SAME
# 254   | eos                       | eo                   | eo                   | SAME
# 255   | qui                       | qui                  | qui                  | SAME
# 256   | audiunt                   | audiunt              | audiunt              | SAME
# 257   | vides                     | vide                 | vide                 | SAME
# 258   | vide                      | vide                 | vide                 | SAME
# 259   | ne                        | ne                   | ne                   | SAME
# 260   | magis                     | magi                 | magi                 | SAME
# 261   | inquam                    | inquam               | inquam               | SAME
# 262   | tuum                      | tuum                 | tuum                 | SAME
# 263   | fuerit                    | fuerit               | fuerit               | SAME
# 264   | cum                       | cum                  | cum                  | SAME
# 265   | idem                      | idem                 | idem                 | SAME
# 266   | tibi                      | tibi                 | tibi                 | SAME
# 267   | quod                      | quod                 | quod                 | SAME
# 268   | mihi                      | mihi                 | mihi                 | SAME
# 269   | videretur                 | videretur            | videretur            | SAME
# 270   | non                       | non                  | non                  | SAME
# 271   | nova                      | nova                 | nova                 | SAME
# 272   | te                        | te                   | te                   | SAME
# 273   | rebus                     | rebu                 | rebus                | DIFFERENT
# 274   | nomina                    | nomina               | nomina               | SAME
# 275   | inponere                  | inponer              | inponer              | SAME
# 276   | quivere                   | quiver               | quiver               | SAME
# 277   | falsone                   | falson               | falson               | SAME
# 278   | quaerere                  | quaerer              | quaerer              | SAME
# 279   | mittimusdicitur           | mittimusdicitur      | mittimusdicitur      | SAME
# 280   | oculis                    | oculi                | oculi                | SAME
# 281   | se                        | se                   | se                   | SAME
# 282   | privasse                  | privass              | privass              | SAME
# 283   | si                        | si                   | si                   | SAME
# 284   | ista                      | ista                 | ista                 | SAME
# 285   | mala                      | mala                 | mala                 | SAME
# 286   | sunt                      | sunt                 | sunt                 | SAME
# 287   | quae                      | quae                 | quae                 | SAME
# 288   | potest                    | potest               | potest               | SAME
# 289   | incidere                  | incider              | incider              | SAME
# 290   | sapiens                   | sapien               | sapien               | SAME
# 291   | sapientem                 | sapientem            | sapientem            | SAME
# 292   | esse                      | ess                  | ess                  | SAME
# 293   | non                       | non                  | non                  | SAME
# 294   | esse                      | ess                  | ess                  | SAME
# 295   | ad                        | ad                   | ad                   | SAME
# 296   | beate                     | beat                 | beat                 | SAME
# 297   | vivendum                  | vivendum             | vivendum             | SAME
# 298   | satis                     | sati                 | sati                 | SAME
# 299   | vero                      | vero                 | vero                 | SAME
# 300   | si                        | si                   | si                   | SAME
# 301   | ad                        | ad                   | ad                   | SAME
# 302   | vitem                     | vitem                | vitem                | SAME
# 303   | sensus                    | sensu                | sensus               | DIFFERENT
# 304   | accesserit                | accesserit           | accesserit           | SAME
# 305   | ut                        | ut                   | ut                   | SAME
# 306   | appetitum                 | appetitum            | appetitum            | SAME
# 307   | quendam                   | quendam              | quendam              | SAME
# 308   | habeat                    | habeat               | habeat               | SAME
# 309   | et                        | et                   | et                   | SAME
# 310   | per                       | per                  | per                  | SAME
# 311   | se                        | se                   | se                   | SAME
# 312   | ipsa                      | ipsa                 | ipsa                 | SAME
# 313   | moveatur                  | moveatur             | moveatur             | SAME
# 314   | quid                      | quid                 | quid                 | SAME
# 315   | facturam                  | facturam             | facturam             | SAME
# 316   | putasnnquem               | putasnnquem          | putasnnquem          | SAME
# 317   | si                        | si                   | si                   | SAME
# 318   | tenueris                  | tenueri              | tenueri              | SAME
# 319   | non                       | non                  | non                  | SAME
# 320   | modo                      | modo                 | modo                 | SAME
# 321   | meum                      | meum                 | meum                 | SAME
# 322   | ciceronem                 | ciceronem            | ciceronem            | SAME
# 323   | sed                       | sed                  | sed                  | SAME
# 324   | etiam                     | etiam                | etiam                | SAME
# 325   | ipsum                     | ipsum                | ipsum                | SAME
# 326   | abducas                   | abduca               | abduca               | SAME
# 327   | licebitnstulti            | licebitnstulti       | licebitnstulti       | SAME
# 328   | autem                     | autem                | autem                | SAME
# 329   | malorum                   | malorum              | malorum              | SAME
# 330   | memoria                   | memoria              | memoria              | SAME
# 331   | torquentur                | torquentur           | torquentur           | SAME
# 332   | sapientes                 | sapient              | sapient              | SAME
# 333   | bona                      | bona                 | bona                 | SAME
# 334   | praeterita                | praeterita           | praeterita           | SAME
# 335   | grata                     | grata                | grata                | SAME
# 336   | recordatione              | recordation          | recordation          | SAME
# 337   | renovata                  | renovata             | renovata             | SAME
# 338   | delectantnesse            | delectantness        | delectantness        | SAME
# 339   | enim                      | enim                 | enim                 | SAME
# 340   | quam                      | quam                 | quam                 | SAME
# 341   | vellet                    | vellet               | vellet               | SAME
# 342   | iniquus                   | iniquu               | iniquus              | DIFFERENT
# 343   | iustus                    | iustu                | iustus               | DIFFERENT
# 344   | poterat                   | poterat              | poterat              | SAME
# 345   | inpunenquae               | inpunenqua           | inpunenqua           | SAME
# 346   | autem                     | autem                | autem                | SAME
# 347   | natura                    | natura               | natura               | SAME
# 348   | suae                      | suae                 | suae                 | SAME
# 349   | primae                    | prima                | prima                | SAME
# 350   | institutionis             | institutioni         | institutioni         | SAME
# 351   | oblita                    | oblita               | oblita               | SAME
# 352   | estnverum                 | estnverum            | estnverum            | SAME
# 353   | tamen                     | tamen                | tamen                | SAME
# 354   | cum                       | cum                  | cum                  | SAME
# 355   | de                        | de                   | de                   | SAME
# 356   | rebus                     | rebu                 | rebus                | DIFFERENT
# 357   | grandioribus              | grandioribu          | grandioribus         | DIFFERENT
# 358   | dicas                     | dica                 | dica                 | SAME
# 359   | ipsae                     | ipsa                 | ipsa                 | SAME
# 360   | res                       | re                   | res                  | DIFFERENT
# 361   | verba                     | verba                | verba                | SAME
# 362   | rapiuntnhoc               | rapiuntnhoc          | rapiuntnhoc          | SAME
# 363   | est                       | est                  | est                  | SAME
# 364   | non                       | non                  | non                  | SAME
# 365   | modo                      | modo                 | modo                 | SAME
# 366   | cor                       | cor                  | cor                  | SAME
# 367   | non                       | non                  | non                  | SAME
# 368   | habere                    | haber                | haber                | SAME
# 369   | sed                       | sed                  | sed                  | SAME
# 370   | ne                        | ne                   | ne                   | SAME
# 371   | palatum                   | palatum              | palatum              | SAME
# 372   | quidemnvoluptatem         | quidemnvoluptatem    | quidemnvoluptatem    | SAME
# 373   | cum                       | cum                  | cum                  | SAME
# 374   | summum                    | summum               | summum               | SAME
# 375   | bonum                     | bonum                | bonum                | SAME
# 376   | diceret                   | diceret              | diceret              | SAME
# 377   | primum                    | primum               | primum               | SAME
# 378   | eo                        | eo                   | eo                   | SAME
# 379   | ipso                      | ipso                 | ipso                 | SAME
# 380   | parum                     | parum                | parum                | SAME
# 381   | vidit                     | vidit                | vidit                | SAME
# 382   | deinde                    | deind                | deind                | SAME
# 383   | hoc                       | hoc                  | hoc                  | SAME
# 384   | quoque                    | quoqu                | quoqu                | SAME
# 385   | alienum                   | alienum              | alienum              | SAME
# 386   | sed                       | sed                  | sed                  | SAME
# 387   | tu                        | tu                   | tu                   | SAME
# 388   | istuc                     | istuc                | istuc                | SAME
# 389   | dixti                     | dixti                | dixti                | SAME
# 390   | bene                      | bene                 | bene                 | SAME
# 391   | latine                    | latin                | latin                | SAME
# 392   | parum                     | parum                | parum                | SAME
# 393   | plane                     | plane                | plane                | SAME
# 394   | nam                       | nam                  | nam                  | SAME
# 395   | haec                      | haec                 | haec                 | SAME
# 396   | ipsa                      | ipsa                 | ipsa                 | SAME
# 397   | mihi                      | mihi                 | mihi                 | SAME
# 398   | erunt                     | erunt                | erunt                | SAME
# 399   | promptu                   | promptu              | promptu              | SAME
# 400   | quae                      | quae                 | quae                 | SAME
# 401   | modo                      | modo                 | modo                 | SAME
# 402   | audivi                    | audivi               | audivi               | SAME
# 403   | nec                       | nec                  | nec                  | SAME
# 404   | ante                      | ant                  | ant                  | SAME
# 405   | aggrediar                 | aggrediar            | aggrediar            | SAME
# 406   | quam                      | quam                 | quam                 | SAME
# 407   | te                        | te                   | te                   | SAME
# 408   | ab                        | ab                   | ab                   | SAME
# 409   | istis                     | isti                 | isti                 | SAME
# 410   | quos                      | quo                  | quo                  | SAME
# 411   | dicis                     | dici                 | dici                 | SAME
# 412   | instructum                | instructum           | instructum           | SAME
# 413   | videro                    | videro               | videro               | SAME
# 414   | fatebuntur                | fatebuntur           | fatebuntur           | SAME
# 415   | stoici                    | stoici               | stoici               | SAME
# 416   | haec                      | haec                 | haec                 | SAME
# 417   | omnia                     | omnia                | omnia                | SAME
# 418   | dicta                     | dicta                | dicta                | SAME
# 419   | esse                      | ess                  | ess                  | SAME
# 420   | praeclare                 | praeclar             | praeclar             | SAME
# 421   | neque                     | nequ                 | nequ                 | SAME
# 422   | eam                       | eam                  | eam                  | SAME
# 423   | causam                    | causam               | causam               | SAME
# 424   | zenoni                    | zenoni               | zenoni               | SAME
# 425   | desciscendi               | desciscendi          | desciscendi          | SAME
# 426   | fuisse                    | fuiss                | fuiss                | SAME
# 427   | non                       | non                  | non                  | SAME
# 428   | autem                     | autem                | autem                | SAME
# 429   | hoc                       | hoc                  | hoc                  | SAME
# 430   | igitur                    | igitur               | igitur               | SAME
# 431   | ne                        | ne                   | ne                   | SAME
# 432   | illud                     | illud                | illud                | SAME
# 433   | quidem                    | quidem               | quidem               | SAME
# 434   | ratio                     | ratio                | ratio                | SAME
# 435   | quidem                    | quidem               | quidem               | SAME
# 436   | vestra                    | vestra               | vestra               | SAME
# 437   | sic                       | sic                  | sic                  | SAME
# 438   | cogit                     | cogit                | cogit                | SAME
# 439   | cum                       | cum                  | cum                  | SAME
# 440   | audissem                  | audissem             | audissem             | SAME
# 441   | antiochum                 | antiochum            | antiochum            | SAME
# 442   | brute                     | brute                | brute                | SAME
# 443   | ut                        | ut                   | ut                   | SAME
# 444   | solebam                   | solebam              | solebam              | SAME
# 445   | cum                       | cum                  | cum                  | SAME
# 446   | quod                      | quod                 | quod                 | SAME
# 447   | ita                       | ita                  | ita                  | SAME
# 448   | callida                   | callida              | callida              | SAME
# 449   | est                       | est                  | est                  | SAME
# 450   | ut                        | ut                   | ut                   | SAME
# 451   | optime                    | optim                | optim                | SAME
# 452   | possit                    | possit               | possit               | SAME
# 453   | architectari              | architectari         | architectari         | SAME
# 454   | voluptatesnnidemne        | voluptatesnnidemn    | voluptatesnnidemn    | SAME
# 455   | quod                      | quod                 | quod                 | SAME
# 456   | iucundenhaec              | iucundenhaec         | iucundenhaec         | SAME
# 457   | mihi                      | mihi                 | mihi                 | SAME
# 458   | videtur                   | videtur              | videtur              | SAME
# 459   | delicatior                | delicatior           | delicatior           | SAME
# 460   | ut                        | ut                   | ut                   | SAME
# 461   | ita                       | ita                  | ita                  | SAME
# 462   | dicam                     | dicam                | dicam                | SAME
# 463   | molliorque                | molliorqu            | molliorqu            | SAME
# 464   | ratio                     | ratio                | ratio                | SAME
# 465   | quam                      | quam                 | quam                 | SAME
# 466   | virtutis                  | virtuti              | virtuti              | SAME
# 467   | vis                       | vi                   | vis                  | DIFFERENT
# 468   | gravitasque               | gravitasqu           | gravitasqu           | SAME
# 469   | postulat                  | postulat             | postulat             | SAME
# 470   | sed                       | sed                  | sed                  | SAME
# 471   | quoniam                   | quoniam              | quoniam              | SAME
# 472   | et                        | et                   | et                   | SAME
# 473   | advesperascit             | advesperascit        | advesperascit        | SAME
# 474   | et                        | et                   | et                   | SAME
# 475   | mihi                      | mihi                 | mihi                 | SAME
# 476   | ad                        | ad                   | ad                   | SAME
# 477   | villam                    | villam               | villam               | SAME
# 478   | revertendum               | revertendum          | revertendum          | SAME
# 479   | est                       | est                  | est                  | SAME
# 480   | nunc                      | nunc                 | nunc                 | SAME
# 481   | quidem                    | quidem               | quidem               | SAME
# 482   | hactenus                  | hactenu              | hactenus             | DIFFERENT
# 483   | cuius                     | cuiu                 | cuius                | DIFFERENT
# 484   | ad                        | ad                   | ad                   | SAME
# 485   | naturam                   | naturam              | naturam              | SAME
# 486   | apta                      | apta                 | apta                 | SAME
# 487   | ratio                     | ratio                | ratio                | SAME
# 488   | vera                      | vera                 | vera                 | SAME
# 489   | illa                      | illa                 | illa                 | SAME
# 490   | et                        | et                   | et                   | SAME
# 491   | summa                     | summa                | summa                | SAME
# 492   | lex                       | lex                  | lex                  | SAME
# 493   | philosophis               | philosophi           | philosophi           | SAME
# 494   | dicitur                   | dicitur              | dicitur              | SAME
# 495   | neque                     | nequ                 | nequ                 | SAME
# 496   | solum                     | solum                | solum                | SAME
# 497   | ea                        | ea                   | ea                   | SAME
# 498   | communia                  | communia             | communia             | SAME
# 499   | verum                     | verum                | verum                | SAME
# 500   | etiam                     | etiam                | etiam                | SAME
# 501   | paria                     | paria                | paria                | SAME
# 502   | esse                      | ess                  | ess                  | SAME
# 503   | dixerunt                  | dixerunt             | dixerunt             | SAME
# 504   | sed                       | sed                  | sed                  | SAME
# 505   | nunc                      | nunc                 | nunc                 | SAME
# 506   | quod                      | quod                 | quod                 | SAME
# 507   | agimus                    | agimu                | agimus               | DIFFERENT
# 508   | mene                      | mene                 | mene                 | SAME
# 509   | tu                        | tu                   | tu                   | SAME
#
# Total words with different stemming results: 26 out of 509
# Percentage of differences: 5.11%
#
# DETAILED COMPARISON FOR WORDS WITH DIFFERENT STEMMING RESULTS:
# #     | Original Word             | Porter Result        | Snowball Result      | Analysis
# 1     | quibus                    | quibu                | quibus               | Porter shorter
# 2     | lucius                    | luciu                | lucius               | Porter shorter
# 3     | corpus                    | corpu                | corpus               | Porter shorter
# 4     | solemus                   | solemu               | solemus              | Porter shorter
# 5     | animantibus               | animantibu           | animantibus          | Porter shorter
# 6     | eius                      | eiu                  | eius                 | Porter shorter
# 7     | virtus                    | virtu                | virtus               | Porter shorter
# 8     | rebus                     | rebu                 | rebus                | Porter shorter
# 9     | timetnsummus              | timetnsummu          | timetnsummus         | Porter shorter
# 10    | virtus                    | virtu                | virtus               | Porter shorter
# 11    | cuius                     | cuiu                 | cuius                | Porter shorter
# 12    | condemnatus               | condemnatu           | condemnatus          | Porter shorter
# 13    | eius                      | eiu                  | eius                 | Porter shorter
# 14    | ipsius                    | ipsiu                | ipsius               | Porter shorter
# 15    | moribus                   | moribu               | moribus              | Porter shorter
# 16    | rebus                     | rebu                 | rebus                | Porter shorter
# 17    | sensus                    | sensu                | sensus               | Porter shorter
# 18    | iniquus                   | iniquu               | iniquus              | Porter shorter
# 19    | iustus                    | iustu                | iustus               | Porter shorter
# 20    | rebus                     | rebu                 | rebus                | Porter shorter
# 21    | grandioribus              | grandioribu          | grandioribus         | Porter shorter
# 22    | res                       | re                   | res                  | Porter shorter
# 23    | vis                       | vi                   | vis                  | Porter shorter
# 24    | hactenus                  | hactenu              | hactenus             | Porter shorter
# 25    | cuius                     | cuiu                 | cuius                | Porter shorter
# 26    | agimus                    | agimu                | agimus               | Porter shorter
#
# COMPLETE PORTER STEMMED TEXT:
# quod equidem non reprehendonlorem ipsum dolor sit amet consectetur adipisc elit quibu natura iur responderit non ess verum aliund finem beat vivendi se principia rei gerenda peti quae enim adhuc protulisti popularia sunt ego autem te elegantiora desidero duo rege constructio interret tum luciu mihi vero ista vald probata sunt quod item fratri puto bestiarum vero nullum iudicium puto nihil enim iam habe quod ad corpu refera deind prima illa quae congressu solemu quid tu inquit huc et homini qui ceteri animantibu plurimum praestat praecipu natura nihil datum ess dicemusnniam id ipsum absurdum maximum malum neglegi quod ea non occurrentia fingunt vincunt aristonem atqui perspicuum est hominem e corpor animoqu constar cum prima sint animi part secunda corpori fieri inquam triari nullo pacto potest ut non dica quid non probe eiu quo dissentia equidem e cn dubium est quin virtu ita maximam partem optineat rebu humani ut reliqua obruatnnqui istum dolorem timetnsummu dolor plure die maner non potest dicet pro ipsa virtu nec dubitabit isti vestro beato tubulum fuiss qua illum cuiu condemnatu est rogation p quod si ita sit cur opera philosophia sit danda nescionnex eorum enim scripti et instituti cum omni doctrina liberali omni historianquod si ita est sequitur id ipsum quod te vell video omn semper beato ess sapient cum enim fertur quasi torren oratio quamvi multa cuiusqu modi rapiat nihil tamen tenea nihil apprehenda nusquam orationem rapidam coercea ita redarguitur ips sese convincunturqu scripta eiu probit ipsiu ac moribu quanta conantur mundum hunc omnem oppidum ess nostrum incendi igitur eo qui audiunt vide vide ne magi inquam tuum fuerit cum idem tibi quod mihi videretur non nova te rebu nomina inponer quiver falson quaerer mittimusdicitur oculi se privass si ista mala sunt quae potest incider sapien sapientem ess non ess ad beat vivendum sati vero si ad vitem sensu accesserit ut appetitum quendam habeat et per se ipsa moveatur quid facturam putasnnquem si tenueri non modo meum ciceronem sed etiam ipsum abduca licebitnstulti autem malorum memoria torquentur sapient bona praeterita grata recordation renovata delectantness enim quam vellet iniquu iustu poterat inpunenqua autem natura suae prima institutioni oblita estnverum tamen cum de rebu grandioribu dica ipsa re verba rapiuntnhoc est non modo cor non haber sed ne palatum quidemnvoluptatem cum summum bonum diceret primum eo ipso parum vidit deind hoc quoqu alienum sed tu istuc dixti bene latin parum plane nam haec ipsa mihi erunt promptu quae modo audivi nec ant aggrediar quam te ab isti quo dici instructum videro fatebuntur stoici haec omnia dicta ess praeclar nequ eam causam zenoni desciscendi fuiss non autem hoc igitur ne illud quidem ratio quidem vestra sic cogit cum audissem antiochum brute ut solebam cum quod ita callida est ut optim possit architectari voluptatesnnidemn quod iucundenhaec mihi videtur delicatior ut ita dicam molliorqu ratio quam virtuti vi gravitasqu postulat sed quoniam et advesperascit et mihi ad villam revertendum est nunc quidem hactenu cuiu ad naturam apta ratio vera illa et summa lex philosophi dicitur nequ solum ea communia verum etiam paria ess dixerunt sed nunc quod agimu mene tu
#
# COMPLETE SNOWBALL STEMMED TEXT:
# quod equidem non reprehendonlorem ipsum dolor sit amet consectetur adipisc elit quibus natura iur responderit non ess verum aliund finem beat vivendi se principia rei gerenda peti quae enim adhuc protulisti popularia sunt ego autem te elegantiora desidero duo rege constructio interret tum lucius mihi vero ista vald probata sunt quod item fratri puto bestiarum vero nullum iudicium puto nihil enim iam habe quod ad corpus refera deind prima illa quae congressu solemus quid tu inquit huc et homini qui ceteri animantibus plurimum praestat praecipu natura nihil datum ess dicemusnniam id ipsum absurdum maximum malum neglegi quod ea non occurrentia fingunt vincunt aristonem atqui perspicuum est hominem e corpor animoqu constar cum prima sint animi part secunda corpori fieri inquam triari nullo pacto potest ut non dica quid non probe eius quo dissentia equidem e cn dubium est quin virtus ita maximam partem optineat rebus humani ut reliqua obruatnnqui istum dolorem timetnsummus dolor plure die maner non potest dicet pro ipsa virtus nec dubitabit isti vestro beato tubulum fuiss qua illum cuius condemnatus est rogation p quod si ita sit cur opera philosophia sit danda nescionnex eorum enim scripti et instituti cum omni doctrina liberali omni historianquod si ita est sequitur id ipsum quod te vell video omn semper beato ess sapient cum enim fertur quasi torren oratio quamvi multa cuiusqu modi rapiat nihil tamen tenea nihil apprehenda nusquam orationem rapidam coercea ita redarguitur ips sese convincunturqu scripta eius probit ipsius ac moribus quanta conantur mundum hunc omnem oppidum ess nostrum incendi igitur eo qui audiunt vide vide ne magi inquam tuum fuerit cum idem tibi quod mihi videretur non nova te rebus nomina inponer quiver falson quaerer mittimusdicitur oculi se privass si ista mala sunt quae potest incider sapien sapientem ess non ess ad beat vivendum sati vero si ad vitem sensus accesserit ut appetitum quendam habeat et per se ipsa moveatur quid facturam putasnnquem si tenueri non modo meum ciceronem sed etiam ipsum abduca licebitnstulti autem malorum memoria torquentur sapient bona praeterita grata recordation renovata delectantness enim quam vellet iniquus iustus poterat inpunenqua autem natura suae prima institutioni oblita estnverum tamen cum de rebus grandioribus dica ipsa res verba rapiuntnhoc est non modo cor non haber sed ne palatum quidemnvoluptatem cum summum bonum diceret primum eo ipso parum vidit deind hoc quoqu alienum sed tu istuc dixti bene latin parum plane nam haec ipsa mihi erunt promptu quae modo audivi nec ant aggrediar quam te ab isti quo dici instructum videro fatebuntur stoici haec omnia dicta ess praeclar nequ eam causam zenoni desciscendi fuiss non autem hoc igitur ne illud quidem ratio quidem vestra sic cogit cum audissem antiochum brute ut solebam cum quod ita callida est ut optim possit architectari voluptatesnnidemn quod iucundenhaec mihi videtur delicatior ut ita dicam molliorqu ratio quam virtuti vis gravitasqu postulat sed quoniam et advesperascit et mihi ad villam revertendum est nunc quidem hactenus cuius ad naturam apta ratio vera illa et summa lex philosophi dicitur nequ solum ea communia verum etiam paria ess dixerunt sed nunc quod agimus mene tu
#
# PERFORMANCE COMPARISON:
# PorterStemmer processing time (10 repetitions): 0.053269 seconds
# SnowballStemmer processing time (10 repetitions): 0.034530 seconds
# SnowballStemmer is 1.54x faster than PorterStemmer

# %% [markdown]
# # 7. Lemmatization (WordNetLemmatizer)

# %%
lemmatizer = WordNetLemmatizer()
lemmatized_tokens = [lemmatizer.lemmatize(word) for word in filtered_tokens]

print("COMPLETE COMPARISON (Original vs Lemmatized):")
print(f"{'#':<5} | {'Original Word':<25} | {'Lemmatized':<25}")
for i, (original, lemmatized) in enumerate(zip(filtered_tokens, lemmatized_tokens), 1):
    print(f"{i:<5} | {original:<25} | {lemmatized:<25}")

lemmatized_text = ' '.join(lemmatized_tokens)
print("\nCOMPLETE LEMMATIZED TEXT:")
print(lemmatized_text)

print("\nSTEMMING vs LEMMATIZATION COMPARISON:")
print(f"{'#':<5} | {'Original Word':<25} | {'Porter Stemmer':<20} | {'Snowball Stemmer':<20} | {'Lemmatized':<25}")
for i, (original, porter, snowball, lemmatized) in enumerate(zip(filtered_tokens, porter_stemmed_tokens, snowball_stemmed_tokens, lemmatized_tokens), 1):
    print(f"{i:<5} | {original:<25} | {porter:<20} | {snowball:<20} | {lemmatized:<25}")

# Performance comparison for Lemmatizer
print("\nPERFORMANCE COMPARISON (Lemmatizer vs Stemmers):")

# Test Lemmatizer speed
start_time = time.time()
for word in filtered_tokens * 10:
    lemmatizer.lemmatize(word)
lemmatizer_time = time.time() - start_time

print(f"WordNetLemmatizer processing time (10 repetitions): {lemmatizer_time:.6f} seconds")
print(f"PorterStemmer processing time (10 repetitions): {porter_time:.6f} seconds")
print(f"SnowballStemmer processing time (10 repetitions): {snowball_time:.6f} seconds")

# Find fastest
fastest_time = min(porter_time, snowball_time, lemmatizer_time)
if porter_time == fastest_time:
    fastest = "PorterStemmer"
    print(f"\nFastest: {fastest} is {snowball_time/fastest_time:.2f}x faster than Snowball and {lemmatizer_time/fastest_time:.2f}x faster than Lemmatizer")
elif snowball_time == fastest_time:
    fastest = "SnowballStemmer"
    print(f"\nFastest: {fastest} is {porter_time/fastest_time:.2f}x faster than Porter and {lemmatizer_time/fastest_time:.2f}x faster than Lemmatizer")
else:
    fastest = "WordNetLemmatizer"
    print(f"\nFastest: {fastest} is {porter_time/fastest_time:.2f}x faster than Porter and {snowball_time/fastest_time:.2f}x faster than Snowball")
# Out:
# COMPLETE COMPARISON (Original vs Lemmatized):
# #     | Original Word             | Lemmatized
# 1     | quod                      | quod
# 2     | equidem                   | equidem
# 3     | non                       | non
# 4     | reprehendonlorem          | reprehendonlorem
# 5     | ipsum                     | ipsum
# 6     | dolor                     | dolor
# 7     | sit                       | sit
# 8     | amet                      | amet
# 9     | consectetur               | consectetur
# 10    | adipiscing                | adipiscing
# 11    | elit                      | elit
# 12    | quibus                    | quibus
# 13    | natura                    | natura
# 14    | iure                      | iure
# 15    | responderit               | responderit
# 16    | non                       | non
# 17    | esse                      | esse
# 18    | verum                     | verum
# 19    | aliunde                   | aliunde
# 20    | finem                     | finem
# 21    | beate                     | beate
# 22    | vivendi                   | vivendi
# 23    | se                        | se
# 24    | principia                 | principia
# 25    | rei                       | rei
# 26    | gerendae                  | gerendae
# 27    | peti                      | peti
# 28    | quae                      | quae
# 29    | enim                      | enim
# 30    | adhuc                     | adhuc
# 31    | protulisti                | protulisti
# 32    | popularia                 | popularia
# 33    | sunt                      | sunt
# 34    | ego                       | ego
# 35    | autem                     | autem
# 36    | te                        | te
# 37    | elegantiora               | elegantiora
# 38    | desidero                  | desidero
# 39    | duo                       | duo
# 40    | reges                     | reges
# 41    | constructio               | constructio
# 42    | interrete                 | interrete
# 43    | tum                       | tum
# 44    | lucius                    | lucius
# 45    | mihi                      | mihi
# 46    | vero                      | vero
# 47    | ista                      | ista
# 48    | valde                     | valde
# 49    | probata                   | probata
# 50    | sunt                      | sunt
# 51    | quod                      | quod
# 52    | item                      | item
# 53    | fratri                    | fratri
# 54    | puto                      | puto
# 55    | bestiarum                 | bestiarum
# 56    | vero                      | vero
# 57    | nullum                    | nullum
# 58    | iudicium                  | iudicium
# 59    | puto                      | puto
# 60    | nihil                     | nihil
# 61    | enim                      | enim
# 62    | iam                       | iam
# 63    | habes                     | habes
# 64    | quod                      | quod
# 65    | ad                        | ad
# 66    | corpus                    | corpus
# 67    | referas                   | referas
# 68    | deinde                    | deinde
# 69    | prima                     | prima
# 70    | illa                      | illa
# 71    | quae                      | quae
# 72    | congressu                 | congressu
# 73    | solemus                   | solemus
# 74    | quid                      | quid
# 75    | tu                        | tu
# 76    | inquit                    | inquit
# 77    | huc                       | huc
# 78    | et                        | et
# 79    | homini                    | homini
# 80    | qui                       | qui
# 81    | ceteris                   | ceteris
# 82    | animantibus               | animantibus
# 83    | plurimum                  | plurimum
# 84    | praestat                  | praestat
# 85    | praecipue                 | praecipue
# 86    | natura                    | natura
# 87    | nihil                     | nihil
# 88    | datum                     | datum
# 89    | esse                      | esse
# 90    | dicemusnniam              | dicemusnniam
# 91    | id                        | id
# 92    | ipsum                     | ipsum
# 93    | absurdum                  | absurdum
# 94    | maximum                   | maximum
# 95    | malum                     | malum
# 96    | neglegi                   | neglegi
# 97    | quod                      | quod
# 98    | ea                        | ea
# 99    | non                       | non
# 100   | occurrentia               | occurrentia
# 101   | fingunt                   | fingunt
# 102   | vincunt                   | vincunt
# 103   | aristonem                 | aristonem
# 104   | atqui                     | atqui
# 105   | perspicuum                | perspicuum
# 106   | est                       | est
# 107   | hominem                   | hominem
# 108   | e                         | e
# 109   | corpore                   | corpore
# 110   | animoque                  | animoque
# 111   | constare                  | constare
# 112   | cum                       | cum
# 113   | primae                    | primae
# 114   | sint                      | sint
# 115   | animi                     | animi
# 116   | partes                    | partes
# 117   | secundae                  | secundae
# 118   | corporis                  | corporis
# 119   | fieri                     | fieri
# 120   | inquam                    | inquam
# 121   | triari                    | triari
# 122   | nullo                     | nullo
# 123   | pacto                     | pacto
# 124   | potest                    | potest
# 125   | ut                        | ut
# 126   | non                       | non
# 127   | dicas                     | dicas
# 128   | quid                      | quid
# 129   | non                       | non
# 130   | probes                    | probe
# 131   | eius                      | eius
# 132   | quo                       | quo
# 133   | dissentias                | dissentias
# 134   | equidem                   | equidem
# 135   | e                         | e
# 136   | cn                        | cn
# 137   | dubium                    | dubium
# 138   | est                       | est
# 139   | quin                      | quin
# 140   | virtus                    | virtu
# 141   | ita                       | ita
# 142   | maximam                   | maximam
# 143   | partem                    | partem
# 144   | optineat                  | optineat
# 145   | rebus                     | rebus
# 146   | humanis                   | humanis
# 147   | ut                        | ut
# 148   | reliquas                  | reliquas
# 149   | obruatnnquis              | obruatnnquis
# 150   | istum                     | istum
# 151   | dolorem                   | dolorem
# 152   | timetnsummus              | timetnsummus
# 153   | dolor                     | dolor
# 154   | plures                    | plures
# 155   | dies                      | dy
# 156   | manere                    | manere
# 157   | non                       | non
# 158   | potest                    | potest
# 159   | dicet                     | dicet
# 160   | pro                       | pro
# 161   | ipsa                      | ipsa
# 162   | virtus                    | virtu
# 163   | nec                       | nec
# 164   | dubitabit                 | dubitabit
# 165   | isti                      | isti
# 166   | vestro                    | vestro
# 167   | beato                     | beato
# 168   | tubulum                   | tubulum
# 169   | fuisse                    | fuisse
# 170   | qua                       | qua
# 171   | illum                     | illum
# 172   | cuius                     | cuius
# 173   | condemnatus               | condemnatus
# 174   | est                       | est
# 175   | rogatione                 | rogatione
# 176   | p                         | p
# 177   | quod                      | quod
# 178   | si                        | si
# 179   | ita                       | ita
# 180   | sit                       | sit
# 181   | cur                       | cur
# 182   | opera                     | opera
# 183   | philosophiae              | philosophiae
# 184   | sit                       | sit
# 185   | danda                     | danda
# 186   | nescionnex                | nescionnex
# 187   | eorum                     | eorum
# 188   | enim                      | enim
# 189   | scriptis                  | scriptis
# 190   | et                        | et
# 191   | institutis                | institutis
# 192   | cum                       | cum
# 193   | omnis                     | omnis
# 194   | doctrina                  | doctrina
# 195   | liberalis                 | liberalis
# 196   | omnis                     | omnis
# 197   | historianquod             | historianquod
# 198   | si                        | si
# 199   | ita                       | ita
# 200   | est                       | est
# 201   | sequitur                  | sequitur
# 202   | id                        | id
# 203   | ipsum                     | ipsum
# 204   | quod                      | quod
# 205   | te                        | te
# 206   | velle                     | velle
# 207   | video                     | video
# 208   | omnes                     | omnes
# 209   | semper                    | semper
# 210   | beatos                    | beatos
# 211   | esse                      | esse
# 212   | sapientes                 | sapientes
# 213   | cum                       | cum
# 214   | enim                      | enim
# 215   | fertur                    | fertur
# 216   | quasi                     | quasi
# 217   | torrens                   | torrens
# 218   | oratio                    | oratio
# 219   | quamvis                   | quamvis
# 220   | multa                     | multa
# 221   | cuiusque                  | cuiusque
# 222   | modi                      | modi
# 223   | rapiat                    | rapiat
# 224   | nihil                     | nihil
# 225   | tamen                     | tamen
# 226   | teneas                    | teneas
# 227   | nihil                     | nihil
# 228   | apprehendas               | apprehendas
# 229   | nusquam                   | nusquam
# 230   | orationem                 | orationem
# 231   | rapidam                   | rapidam
# 232   | coerceas                  | coerceas
# 233   | ita                       | ita
# 234   | redarguitur               | redarguitur
# 235   | ipse                      | ipse
# 236   | sese                      | sese
# 237   | convincunturque           | convincunturque
# 238   | scripta                   | scripta
# 239   | eius                      | eius
# 240   | probitate                 | probitate
# 241   | ipsius                    | ipsius
# 242   | ac                        | ac
# 243   | moribus                   | moribus
# 244   | quanta                    | quantum
# 245   | conantur                  | conantur
# 246   | mundum                    | mundum
# 247   | hunc                      | hunc
# 248   | omnem                     | omnem
# 249   | oppidum                   | oppidum
# 250   | esse                      | esse
# 251   | nostrum                   | nostrum
# 252   | incendi                   | incendi
# 253   | igitur                    | igitur
# 254   | eos                       | eos
# 255   | qui                       | qui
# 256   | audiunt                   | audiunt
# 257   | vides                     | vides
# 258   | vide                      | vide
# 259   | ne                        | ne
# 260   | magis                     | magi
# 261   | inquam                    | inquam
# 262   | tuum                      | tuum
# 263   | fuerit                    | fuerit
# 264   | cum                       | cum
# 265   | idem                      | idem
# 266   | tibi                      | tibi
# 267   | quod                      | quod
# 268   | mihi                      | mihi
# 269   | videretur                 | videretur
# 270   | non                       | non
# 271   | nova                      | nova
# 272   | te                        | te
# 273   | rebus                     | rebus
# 274   | nomina                    | nomina
# 275   | inponere                  | inponere
# 276   | quivere                   | quivere
# 277   | falsone                   | falsone
# 278   | quaerere                  | quaerere
# 279   | mittimusdicitur           | mittimusdicitur
# 280   | oculis                    | oculis
# 281   | se                        | se
# 282   | privasse                  | privasse
# 283   | si                        | si
# 284   | ista                      | ista
# 285   | mala                      | mala
# 286   | sunt                      | sunt
# 287   | quae                      | quae
# 288   | potest                    | potest
# 289   | incidere                  | incidere
# 290   | sapiens                   | sapiens
# 291   | sapientem                 | sapientem
# 292   | esse                      | esse
# 293   | non                       | non
# 294   | esse                      | esse
# 295   | ad                        | ad
# 296   | beate                     | beate
# 297   | vivendum                  | vivendum
# 298   | satis                     | satis
# 299   | vero                      | vero
# 300   | si                        | si
# 301   | ad                        | ad
# 302   | vitem                     | vitem
# 303   | sensus                    | sensus
# 304   | accesserit                | accesserit
# 305   | ut                        | ut
# 306   | appetitum                 | appetitum
# 307   | quendam                   | quendam
# 308   | habeat                    | habeat
# 309   | et                        | et
# 310   | per                       | per
# 311   | se                        | se
# 312   | ipsa                      | ipsa
# 313   | moveatur                  | moveatur
# 314   | quid                      | quid
# 315   | facturam                  | facturam
# 316   | putasnnquem               | putasnnquem
# 317   | si                        | si
# 318   | tenueris                  | tenueris
# 319   | non                       | non
# 320   | modo                      | modo
# 321   | meum                      | meum
# 322   | ciceronem                 | ciceronem
# 323   | sed                       | sed
# 324   | etiam                     | etiam
# 325   | ipsum                     | ipsum
# 326   | abducas                   | abducas
# 327   | licebitnstulti            | licebitnstulti
# 328   | autem                     | autem
# 329   | malorum                   | malorum
# 330   | memoria                   | memoria
# 331   | torquentur                | torquentur
# 332   | sapientes                 | sapientes
# 333   | bona                      | bona
# 334   | praeterita                | praeterita
# 335   | grata                     | grata
# 336   | recordatione              | recordatione
# 337   | renovata                  | renovata
# 338   | delectantnesse            | delectantnesse
# 339   | enim                      | enim
# 340   | quam                      | quam
# 341   | vellet                    | vellet
# 342   | iniquus                   | iniquus
# 343   | iustus                    | iustus
# 344   | poterat                   | poterat
# 345   | inpunenquae               | inpunenquae
# 346   | autem                     | autem
# 347   | natura                    | natura
# 348   | suae                      | suae
# 349   | primae                    | primae
# 350   | institutionis             | institutionis
# 351   | oblita                    | oblita
# 352   | estnverum                 | estnverum
# 353   | tamen                     | tamen
# 354   | cum                       | cum
# 355   | de                        | de
# 356   | rebus                     | rebus
# 357   | grandioribus              | grandioribus
# 358   | dicas                     | dicas
# 359   | ipsae                     | ipsae
# 360   | res                       | re
# 361   | verba                     | verba
# 362   | rapiuntnhoc               | rapiuntnhoc
# 363   | est                       | est
# 364   | non                       | non
# 365   | modo                      | modo
# 366   | cor                       | cor
# 367   | non                       | non
# 368   | habere                    | habere
# 369   | sed                       | sed
# 370   | ne                        | ne
# 371   | palatum                   | palatum
# 372   | quidemnvoluptatem         | quidemnvoluptatem
# 373   | cum                       | cum
# 374   | summum                    | summum
# 375   | bonum                     | bonum
# 376   | diceret                   | diceret
# 377   | primum                    | primum
# 378   | eo                        | eo
# 379   | ipso                      | ipso
# 380   | parum                     | parum
# 381   | vidit                     | vidit
# 382   | deinde                    | deinde
# 383   | hoc                       | hoc
# 384   | quoque                    | quoque
# 385   | alienum                   | alienum
# 386   | sed                       | sed
# 387   | tu                        | tu
# 388   | istuc                     | istuc
# 389   | dixti                     | dixti
# 390   | bene                      | bene
# 391   | latine                    | latine
# 392   | parum                     | parum
# 393   | plane                     | plane
# 394   | nam                       | nam
# 395   | haec                      | haec
# 396   | ipsa                      | ipsa
# 397   | mihi                      | mihi
# 398   | erunt                     | erunt
# 399   | promptu                   | promptu
# 400   | quae                      | quae
# 401   | modo                      | modo
# 402   | audivi                    | audivi
# 403   | nec                       | nec
# 404   | ante                      | ante
# 405   | aggrediar                 | aggrediar
# 406   | quam                      | quam
# 407   | te                        | te
# 408   | ab                        | ab
# 409   | istis                     | istis
# 410   | quos                      | quos
# 411   | dicis                     | dicis
# 412   | instructum                | instructum
# 413   | videro                    | videro
# 414   | fatebuntur                | fatebuntur
# 415   | stoici                    | stoici
# 416   | haec                      | haec
# 417   | omnia                     | omnia
# 418   | dicta                     | dictum
# 419   | esse                      | esse
# 420   | praeclare                 | praeclare
# 421   | neque                     | neque
# 422   | eam                       | eam
# 423   | causam                    | causam
# 424   | zenoni                    | zenoni
# 425   | desciscendi               | desciscendi
# 426   | fuisse                    | fuisse
# 427   | non                       | non
# 428   | autem                     | autem
# 429   | hoc                       | hoc
# 430   | igitur                    | igitur
# 431   | ne                        | ne
# 432   | illud                     | illud
# 433   | quidem                    | quidem
# 434   | ratio                     | ratio
# 435   | quidem                    | quidem
# 436   | vestra                    | vestra
# 437   | sic                       | sic
# 438   | cogit                     | cogit
# 439   | cum                       | cum
# 440   | audissem                  | audissem
# 441   | antiochum                 | antiochum
# 442   | brute                     | brute
# 443   | ut                        | ut
# 444   | solebam                   | solebam
# 445   | cum                       | cum
# 446   | quod                      | quod
# 447   | ita                       | ita
# 448   | callida                   | callida
# 449   | est                       | est
# 450   | ut                        | ut
# 451   | optime                    | optime
# 452   | possit                    | possit
# 453   | architectari              | architectari
# 454   | voluptatesnnidemne        | voluptatesnnidemne
# 455   | quod                      | quod
# 456   | iucundenhaec              | iucundenhaec
# 457   | mihi                      | mihi
# 458   | videtur                   | videtur
# 459   | delicatior                | delicatior
# 460   | ut                        | ut
# 461   | ita                       | ita
# 462   | dicam                     | dicam
# 463   | molliorque                | molliorque
# 464   | ratio                     | ratio
# 465   | quam                      | quam
# 466   | virtutis                  | virtutis
# 467   | vis                       | vi
# 468   | gravitasque               | gravitasque
# 469   | postulat                  | postulat
# 470   | sed                       | sed
# 471   | quoniam                   | quoniam
# 472   | et                        | et
# 473   | advesperascit             | advesperascit
# 474   | et                        | et
# 475   | mihi                      | mihi
# 476   | ad                        | ad
# 477   | villam                    | villam
# 478   | revertendum               | revertendum
# 479   | est                       | est
# 480   | nunc                      | nunc
# 481   | quidem                    | quidem
# 482   | hactenus                  | hactenus
# 483   | cuius                     | cuius
# 484   | ad                        | ad
# 485   | naturam                   | naturam
# 486   | apta                      | apta
# 487   | ratio                     | ratio
# 488   | vera                      | vera
# 489   | illa                      | illa
# 490   | et                        | et
# 491   | summa                     | summa
# 492   | lex                       | lex
# 493   | philosophis               | philosophis
# 494   | dicitur                   | dicitur
# 495   | neque                     | neque
# 496   | solum                     | solum
# 497   | ea                        | ea
# 498   | communia                  | communia
# 499   | verum                     | verum
# 500   | etiam                     | etiam
# 501   | paria                     | paria
# 502   | esse                      | esse
# 503   | dixerunt                  | dixerunt
# 504   | sed                       | sed
# 505   | nunc                      | nunc
# 506   | quod                      | quod
# 507   | agimus                    | agimus
# 508   | mene                      | mene
# 509   | tu                        | tu
#
# COMPLETE LEMMATIZED TEXT:
# quod equidem non reprehendonlorem ipsum dolor sit amet consectetur adipiscing elit quibus natura iure responderit non esse verum aliunde finem beate vivendi se principia rei gerendae peti quae enim adhuc protulisti popularia sunt ego autem te elegantiora desidero duo reges constructio interrete tum lucius mihi vero ista valde probata sunt quod item fratri puto bestiarum vero nullum iudicium puto nihil enim iam habes quod ad corpus referas deinde prima illa quae congressu solemus quid tu inquit huc et homini qui ceteris animantibus plurimum praestat praecipue natura nihil datum esse dicemusnniam id ipsum absurdum maximum malum neglegi quod ea non occurrentia fingunt vincunt aristonem atqui perspicuum est hominem e corpore animoque constare cum primae sint animi partes secundae corporis fieri inquam triari nullo pacto potest ut non dicas quid non probe eius quo dissentias equidem e cn dubium est quin virtu ita maximam partem optineat rebus humanis ut reliquas obruatnnquis istum dolorem timetnsummus dolor plures dy manere non potest dicet pro ipsa virtu nec dubitabit isti vestro beato tubulum fuisse qua illum cuius condemnatus est rogatione p quod si ita sit cur opera philosophiae sit danda nescionnex eorum enim scriptis et institutis cum omnis doctrina liberalis omnis historianquod si ita est sequitur id ipsum quod te velle video omnes semper beatos esse sapientes cum enim fertur quasi torrens oratio quamvis multa cuiusque modi rapiat nihil tamen teneas nihil apprehendas nusquam orationem rapidam coerceas ita redarguitur ipse sese convincunturque scripta eius probitate ipsius ac moribus quantum conantur mundum hunc omnem oppidum esse nostrum incendi igitur eos qui audiunt vides vide ne magi inquam tuum fuerit cum idem tibi quod mihi videretur non nova te rebus nomina inponere quivere falsone quaerere mittimusdicitur oculis se privasse si ista mala sunt quae potest incidere sapiens sapientem esse non esse ad beate vivendum satis vero si ad vitem sensus accesserit ut appetitum quendam habeat et per se ipsa moveatur quid facturam putasnnquem si tenueris non modo meum ciceronem sed etiam ipsum abducas licebitnstulti autem malorum memoria torquentur sapientes bona praeterita grata recordatione renovata delectantnesse enim quam vellet iniquus iustus poterat inpunenquae autem natura suae primae institutionis oblita estnverum tamen cum de rebus grandioribus dicas ipsae re verba rapiuntnhoc est non modo cor non habere sed ne palatum quidemnvoluptatem cum summum bonum diceret primum eo ipso parum vidit deinde hoc quoque alienum sed tu istuc dixti bene latine parum plane nam haec ipsa mihi erunt promptu quae modo audivi nec ante aggrediar quam te ab istis quos dicis instructum videro fatebuntur stoici haec omnia dictum esse praeclare neque eam causam zenoni desciscendi fuisse non autem hoc igitur ne illud quidem ratio quidem vestra sic cogit cum audissem antiochum brute ut solebam cum quod ita callida est ut optime possit architectari voluptatesnnidemne quod iucundenhaec mihi videtur delicatior ut ita dicam molliorque ratio quam virtutis vi gravitasque postulat sed quoniam et advesperascit et mihi ad villam revertendum est nunc quidem hactenus cuius ad naturam apta ratio vera illa et summa lex philosophis dicitur neque solum ea communia verum etiam paria esse dixerunt sed nunc quod agimus mene tu
#
# STEMMING vs LEMMATIZATION COMPARISON:
# #     | Original Word             | Porter Stemmer       | Snowball Stemmer     | Lemmatized
# 1     | quod                      | quod                 | quod                 | quod
# 2     | equidem                   | equidem              | equidem              | equidem
# 3     | non                       | non                  | non                  | non
# 4     | reprehendonlorem          | reprehendonlorem     | reprehendonlorem     | reprehendonlorem
# 5     | ipsum                     | ipsum                | ipsum                | ipsum
# 6     | dolor                     | dolor                | dolor                | dolor
# 7     | sit                       | sit                  | sit                  | sit
# 8     | amet                      | amet                 | amet                 | amet
# 9     | consectetur               | consectetur          | consectetur          | consectetur
# 10    | adipiscing                | adipisc              | adipisc              | adipiscing
# 11    | elit                      | elit                 | elit                 | elit
# 12    | quibus                    | quibu                | quibus               | quibus
# 13    | natura                    | natura               | natura               | natura
# 14    | iure                      | iur                  | iur                  | iure
# 15    | responderit               | responderit          | responderit          | responderit
# 16    | non                       | non                  | non                  | non
# 17    | esse                      | ess                  | ess                  | esse
# 18    | verum                     | verum                | verum                | verum
# 19    | aliunde                   | aliund               | aliund               | aliunde
# 20    | finem                     | finem                | finem                | finem
# 21    | beate                     | beat                 | beat                 | beate
# 22    | vivendi                   | vivendi              | vivendi              | vivendi
# 23    | se                        | se                   | se                   | se
# 24    | principia                 | principia            | principia            | principia
# 25    | rei                       | rei                  | rei                  | rei
# 26    | gerendae                  | gerenda              | gerenda              | gerendae
# 27    | peti                      | peti                 | peti                 | peti
# 28    | quae                      | quae                 | quae                 | quae
# 29    | enim                      | enim                 | enim                 | enim
# 30    | adhuc                     | adhuc                | adhuc                | adhuc
# 31    | protulisti                | protulisti           | protulisti           | protulisti
# 32    | popularia                 | popularia            | popularia            | popularia
# 33    | sunt                      | sunt                 | sunt                 | sunt
# 34    | ego                       | ego                  | ego                  | ego
# 35    | autem                     | autem                | autem                | autem
# 36    | te                        | te                   | te                   | te
# 37    | elegantiora               | elegantiora          | elegantiora          | elegantiora
# 38    | desidero                  | desidero             | desidero             | desidero
# 39    | duo                       | duo                  | duo                  | duo
# 40    | reges                     | rege                 | rege                 | reges
# 41    | constructio               | constructio          | constructio          | constructio
# 42    | interrete                 | interret             | interret             | interrete
# 43    | tum                       | tum                  | tum                  | tum
# 44    | lucius                    | luciu                | lucius               | lucius
# 45    | mihi                      | mihi                 | mihi                 | mihi
# 46    | vero                      | vero                 | vero                 | vero
# 47    | ista                      | ista                 | ista                 | ista
# 48    | valde                     | vald                 | vald                 | valde
# 49    | probata                   | probata              | probata              | probata
# 50    | sunt                      | sunt                 | sunt                 | sunt
# 51    | quod                      | quod                 | quod                 | quod
# 52    | item                      | item                 | item                 | item
# 53    | fratri                    | fratri               | fratri               | fratri
# 54    | puto                      | puto                 | puto                 | puto
# 55    | bestiarum                 | bestiarum            | bestiarum            | bestiarum
# 56    | vero                      | vero                 | vero                 | vero
# 57    | nullum                    | nullum               | nullum               | nullum
# 58    | iudicium                  | iudicium             | iudicium             | iudicium
# 59    | puto                      | puto                 | puto                 | puto
# 60    | nihil                     | nihil                | nihil                | nihil
# 61    | enim                      | enim                 | enim                 | enim
# 62    | iam                       | iam                  | iam                  | iam
# 63    | habes                     | habe                 | habe                 | habes
# 64    | quod                      | quod                 | quod                 | quod
# 65    | ad                        | ad                   | ad                   | ad
# 66    | corpus                    | corpu                | corpus               | corpus
# 67    | referas                   | refera               | refera               | referas
# 68    | deinde                    | deind                | deind                | deinde
# 69    | prima                     | prima                | prima                | prima
# 70    | illa                      | illa                 | illa                 | illa
# 71    | quae                      | quae                 | quae                 | quae
# 72    | congressu                 | congressu            | congressu            | congressu
# 73    | solemus                   | solemu               | solemus              | solemus
# 74    | quid                      | quid                 | quid                 | quid
# 75    | tu                        | tu                   | tu                   | tu
# 76    | inquit                    | inquit               | inquit               | inquit
# 77    | huc                       | huc                  | huc                  | huc
# 78    | et                        | et                   | et                   | et
# 79    | homini                    | homini               | homini               | homini
# 80    | qui                       | qui                  | qui                  | qui
# 81    | ceteris                   | ceteri               | ceteri               | ceteris
# 82    | animantibus               | animantibu           | animantibus          | animantibus
# 83    | plurimum                  | plurimum             | plurimum             | plurimum
# 84    | praestat                  | praestat             | praestat             | praestat
# 85    | praecipue                 | praecipu             | praecipu             | praecipue
# 86    | natura                    | natura               | natura               | natura
# 87    | nihil                     | nihil                | nihil                | nihil
# 88    | datum                     | datum                | datum                | datum
# 89    | esse                      | ess                  | ess                  | esse
# 90    | dicemusnniam              | dicemusnniam         | dicemusnniam         | dicemusnniam
# 91    | id                        | id                   | id                   | id
# 92    | ipsum                     | ipsum                | ipsum                | ipsum
# 93    | absurdum                  | absurdum             | absurdum             | absurdum
# 94    | maximum                   | maximum              | maximum              | maximum
# 95    | malum                     | malum                | malum                | malum
# 96    | neglegi                   | neglegi              | neglegi              | neglegi
# 97    | quod                      | quod                 | quod                 | quod
# 98    | ea                        | ea                   | ea                   | ea
# 99    | non                       | non                  | non                  | non
# 100   | occurrentia               | occurrentia          | occurrentia          | occurrentia
# 101   | fingunt                   | fingunt              | fingunt              | fingunt
# 102   | vincunt                   | vincunt              | vincunt              | vincunt
# 103   | aristonem                 | aristonem            | aristonem            | aristonem
# 104   | atqui                     | atqui                | atqui                | atqui
# 105   | perspicuum                | perspicuum           | perspicuum           | perspicuum
# 106   | est                       | est                  | est                  | est
# 107   | hominem                   | hominem              | hominem              | hominem
# 108   | e                         | e                    | e                    | e
# 109   | corpore                   | corpor               | corpor               | corpore
# 110   | animoque                  | animoqu              | animoqu              | animoque
# 111   | constare                  | constar              | constar              | constare
# 112   | cum                       | cum                  | cum                  | cum
# 113   | primae                    | prima                | prima                | primae
# 114   | sint                      | sint                 | sint                 | sint
# 115   | animi                     | animi                | animi                | animi
# 116   | partes                    | part                 | part                 | partes
# 117   | secundae                  | secunda              | secunda              | secundae
# 118   | corporis                  | corpori              | corpori              | corporis
# ...
# 365   | modo                      | modo                 | modo                 | modo
# 366   | cor                       | cor                  | cor                  | cor
# 367   | non                       | non                  | non                  | non
# 368   | habere                    | haber                | haber                | habere
# 369   | sed                       | sed                  | sed                  | sed
# 370   | ne                        | ne                   | ne                   | ne
# 371   | palatum                   | palatum              | palatum              | palatum
# 372   | quidemnvoluptatem         | quidemnvoluptatem    | quidemnvoluptatem    | quidemnvoluptatem
# 373   | cum                       | cum                  | cum                  | cum
# 374   | summum                    | summum               | summum               | summum
# 375   | bonum                     | bonum                | bonum                | bonum
# 376   | diceret                   | diceret              | diceret              | diceret
# 377   | primum                    | primum               | primum               | primum
# 378   | eo                        | eo                   | eo                   | eo
# 379   | ipso                      | ipso                 | ipso                 | ipso
# 380   | parum                     | parum                | parum                | parum
# 381   | vidit                     | vidit                | vidit                | vidit
# 382   | deinde                    | deind                | deind                | deinde
# 383   | hoc                       | hoc                  | hoc                  | hoc
# 384   | quoque                    | quoqu                | quoqu                | quoque
# 385   | alienum                   | alienum              | alienum              | alienum
# 386   | sed                       | sed                  | sed                  | sed
# 387   | tu                        | tu                   | tu                   | tu
# 388   | istuc                     | istuc                | istuc                | istuc
# 389   | dixti                     | dixti                | dixti                | dixti
# 390   | bene                      | bene                 | bene                 | bene
# 391   | latine                    | latin                | latin                | latine
# 392   | parum                     | parum                | parum                | parum
# 393   | plane                     | plane                | plane                | plane
# 394   | nam                       | nam                  | nam                  | nam
# 395   | haec                      | haec                 | haec                 | haec
# 396   | ipsa                      | ipsa                 | ipsa                 | ipsa
# 397   | mihi                      | mihi                 | mihi                 | mihi
# 398   | erunt                     | erunt                | erunt                | erunt
# 399   | promptu                   | promptu              | promptu              | promptu
# 400   | quae                      | quae                 | quae                 | quae
# 401   | modo                      | modo                 | modo                 | modo
# 402   | audivi                    | audivi               | audivi               | audivi
# 403   | nec                       | nec                  | nec                  | nec
# 404   | ante                      | ant                  | ant                  | ante
# 405   | aggrediar                 | aggrediar            | aggrediar            | aggrediar
# 406   | quam                      | quam                 | quam                 | quam
# 407   | te                        | te                   | te                   | te
# 408   | ab                        | ab                   | ab                   | ab
# 409   | istis                     | isti                 | isti                 | istis
# 410   | quos                      | quo                  | quo                  | quos
# 411   | dicis                     | dici                 | dici                 | dicis
# 412   | instructum                | instructum           | instructum           | instructum
# 413   | videro                    | videro               | videro               | videro
# 414   | fatebuntur                | fatebuntur           | fatebuntur           | fatebuntur
# 415   | stoici                    | stoici               | stoici               | stoici
# 416   | haec                      | haec                 | haec                 | haec
# 417   | omnia                     | omnia                | omnia                | omnia
# 418   | dicta                     | dicta                | dicta                | dictum
# 419   | esse                      | ess                  | ess                  | esse
# 420   | praeclare                 | praeclar             | praeclar             | praeclare
# 421   | neque                     | nequ                 | nequ                 | neque
# 422   | eam                       | eam                  | eam                  | eam
# 423   | causam                    | causam               | causam               | causam
# 424   | zenoni                    | zenoni               | zenoni               | zenoni
# 425   | desciscendi               | desciscendi          | desciscendi          | desciscendi
# 426   | fuisse                    | fuiss                | fuiss                | fuisse
# 427   | non                       | non                  | non                  | non
# 428   | autem                     | autem                | autem                | autem
# 429   | hoc                       | hoc                  | hoc                  | hoc
# 430   | igitur                    | igitur               | igitur               | igitur
# 431   | ne                        | ne                   | ne                   | ne
# 432   | illud                     | illud                | illud                | illud
# 433   | quidem                    | quidem               | quidem               | quidem
# 434   | ratio                     | ratio                | ratio                | ratio
# 435   | quidem                    | quidem               | quidem               | quidem
# 436   | vestra                    | vestra               | vestra               | vestra
# 437   | sic                       | sic                  | sic                  | sic
# 438   | cogit                     | cogit                | cogit                | cogit
# 439   | cum                       | cum                  | cum                  | cum
# 440   | audissem                  | audissem             | audissem             | audissem
# 441   | antiochum                 | antiochum            | antiochum            | antiochum
# 442   | brute                     | brute                | brute                | brute
# 443   | ut                        | ut                   | ut                   | ut
# 444   | solebam                   | solebam              | solebam              | solebam
# 445   | cum                       | cum                  | cum                  | cum
# 446   | quod                      | quod                 | quod                 | quod
# 447   | ita                       | ita                  | ita                  | ita
# 448   | callida                   | callida              | callida              | callida
# 449   | est                       | est                  | est                  | est
# 450   | ut                        | ut                   | ut                   | ut
# 451   | optime                    | optim                | optim                | optime
# 452   | possit                    | possit               | possit               | possit
# 453   | architectari              | architectari         | architectari         | architectari
# 454   | voluptatesnnidemne        | voluptatesnnidemn    | voluptatesnnidemn    | voluptatesnnidemne
# 455   | quod                      | quod                 | quod                 | quod
# 456   | iucundenhaec              | iucundenhaec         | iucundenhaec         | iucundenhaec
# 457   | mihi                      | mihi                 | mihi                 | mihi
# 458   | videtur                   | videtur              | videtur              | videtur
# 459   | delicatior                | delicatior           | delicatior           | delicatior
# 460   | ut                        | ut                   | ut                   | ut
# 461   | ita                       | ita                  | ita                  | ita
# 462   | dicam                     | dicam                | dicam                | dicam
# 463   | molliorque                | molliorqu            | molliorqu            | molliorque
# 464   | ratio                     | ratio                | ratio                | ratio
# 465   | quam                      | quam                 | quam                 | quam
# 466   | virtutis                  | virtuti              | virtuti              | virtutis
# 467   | vis                       | vi                   | vis                  | vi
# 468   | gravitasque               | gravitasqu           | gravitasqu           | gravitasque
# 469   | postulat                  | postulat             | postulat             | postulat
# 470   | sed                       | sed                  | sed                  | sed
# 471   | quoniam                   | quoniam              | quoniam              | quoniam
# 472   | et                        | et                   | et                   | et
# 473   | advesperascit             | advesperascit        | advesperascit        | advesperascit
# 474   | et                        | et                   | et                   | et
# 475   | mihi                      | mihi                 | mihi                 | mihi
# 476   | ad                        | ad                   | ad                   | ad
# 477   | villam                    | villam               | villam               | villam
# 478   | revertendum               | revertendum          | revertendum          | revertendum
# 479   | est                       | est                  | est                  | est
# 480   | nunc                      | nunc                 | nunc                 | nunc
# 481   | quidem                    | quidem               | quidem               | quidem
# 482   | hactenus                  | hactenu              | hactenus             | hactenus
# 483   | cuius                     | cuiu                 | cuius                | cuius
# 484   | ad                        | ad                   | ad                   | ad
# 485   | naturam                   | naturam              | naturam              | naturam
# 486   | apta                      | apta                 | apta                 | apta
# 487   | ratio                     | ratio                | ratio                | ratio
# 488   | vera                      | vera                 | vera                 | vera
# 489   | illa                      | illa                 | illa                 | illa
# 490   | et                        | et                   | et                   | et
# 491   | summa                     | summa                | summa                | summa
# 492   | lex                       | lex                  | lex                  | lex
# 493   | philosophis               | philosophi           | philosophi           | philosophis
# 494   | dicitur                   | dicitur              | dicitur              | dicitur
# 495   | neque                     | nequ                 | nequ                 | neque
# 496   | solum                     | solum                | solum                | solum
# 497   | ea                        | ea                   | ea                   | ea
# 498   | communia                  | communia             | communia             | communia
# 499   | verum                     | verum                | verum                | verum
# 500   | etiam                     | etiam                | etiam                | etiam
# 501   | paria                     | paria                | paria                | paria
# 502   | esse                      | ess                  | ess                  | esse
# 503   | dixerunt                  | dixerunt             | dixerunt             | dixerunt
# 504   | sed                       | sed                  | sed                  | sed
# 505   | nunc                      | nunc                 | nunc                 | nunc
# 506   | quod                      | quod                 | quod                 | quod
# 507   | agimus                    | agimu                | agimus               | agimus
# 508   | mene                      | mene                 | mene                 | mene
# 509   | tu                        | tu                   | tu                   | tu
#
# PERFORMANCE COMPARISON (Lemmatizer vs Stemmers):
# WordNetLemmatizer processing time (10 repetitions): 0.016869 seconds
# PorterStemmer processing time (10 repetitions): 0.053269 seconds
# SnowballStemmer processing time (10 repetitions): 0.034530 seconds
#
# Fastest: WordNetLemmatizer is 3.16x faster than Porter and 2.05x faster than Snowball

# %% [markdown]
# # 8. Part-of-Speech (POS) Tagging

# %%
# Cell 10: 8. POS Tagging (Part-of-Speech Tagging)
print("8. PART-OF-SPEECH (POS) TAGGING")

# Perform POS tagging on all filtered tokens
pos_tagged = pos_tag(filtered_tokens)

print("COMPLETE POS TAGGING RESULTS:")
print(f"{'#':<4} | {'Word':<20} | {'POS Tag':<10} | {'Description'}")

pos_descriptions = {
    'NN': 'Noun, singular', 'NNS': 'Noun, plural',
    'NNP': 'Proper noun, singular', 'NNPS': 'Proper noun, plural',
    'VB': 'Verb, base form', 'VBD': 'Verb, past tense',
    'VBG': 'Verb, gerund/present participle', 'VBN': 'Verb, past participle',
    'VBP': 'Verb, non-3rd person singular present', 'VBZ': 'Verb, 3rd person singular present',
    'JJ': 'Adjective', 'JJR': 'Adjective, comparative', 'JJS': 'Adjective, superlative',
    'RB': 'Adverb', 'RBR': 'Adverb, comparative', 'RBS': 'Adverb, superlative',
    'IN': 'Preposition/subordinating conjunction', 'DT': 'Determiner',
    'CC': 'Coordinating conjunction', 'PRP': 'Personal pronoun', 'PRP$': 'Possessive pronoun',
    'MD': 'Modal auxiliary', 'TO': 'to', 'UH': 'Interjection',
    'CD': 'Cardinal number', 'EX': 'Existential there', 'FW': 'Foreign word',
    'LS': 'List item marker', 'POS': 'Possessive ending', 'RP': 'Particle',
    'SYM': 'Symbol', 'WDT': 'Wh-determiner', 'WP': 'Wh-pronoun',
    'WP$': 'Possessive wh-pronoun', 'WRB': 'Wh-adverb'
}

for i, (word, tag) in enumerate(pos_tagged, 1):
    desc = pos_descriptions.get(tag, 'Other')
    print(f"{i:<4} | {word:<20} | {tag:<10} | {desc}")
# Out:
# 8. PART-OF-SPEECH (POS) TAGGING
# COMPLETE POS TAGGING RESULTS:
# #    | Word                 | POS Tag    | Description
# 1    | quod                 | NN         | Noun, singular
# 2    | equidem              | NN         | Noun, singular
# 3    | non                  | NN         | Noun, singular
# 4    | reprehendonlorem     | NN         | Noun, singular
# 5    | ipsum                | NN         | Noun, singular
# 6    | dolor                | NN         | Noun, singular
# 7    | sit                  | NN         | Noun, singular
# 8    | amet                 | VBD        | Verb, past tense
# 9    | consectetur          | JJ         | Adjective
# 10   | adipiscing           | VBG        | Verb, gerund/present participle
# 11   | elit                 | JJ         | Adjective
# 12   | quibus               | NN         | Noun, singular
# 13   | natura               | NN         | Noun, singular
# 14   | iure                 | NN         | Noun, singular
# 15   | responderit          | NN         | Noun, singular
# 16   | non                  | FW         | Foreign word
# 17   | esse                 | FW         | Foreign word
# 18   | verum                | NN         | Noun, singular
# 19   | aliunde              | NN         | Noun, singular
# 20   | finem                | NN         | Noun, singular
# 21   | beate                | NN         | Noun, singular
# 22   | vivendi              | NN         | Noun, singular
# 23   | se                   | NN         | Noun, singular
# 24   | principia            | NN         | Noun, singular
# 25   | rei                  | NN         | Noun, singular
# 26   | gerendae             | NN         | Noun, singular
# 27   | peti                 | NN         | Noun, singular
# 28   | quae                 | NN         | Noun, singular
# 29   | enim                 | NN         | Noun, singular
# 30   | adhuc                | NN         | Noun, singular
# 31   | protulisti           | NN         | Noun, singular
# 32   | popularia            | NN         | Noun, singular
# 33   | sunt                 | NN         | Noun, singular
# 34   | ego                  | NN         | Noun, singular
# 35   | autem                | NN         | Noun, singular
# 36   | te                   | JJ         | Adjective
# 37   | elegantiora          | NN         | Noun, singular
# 38   | desidero             | NN         | Noun, singular
# 39   | duo                  | NN         | Noun, singular
# 40   | reges                | NNS        | Noun, plural
# 41   | constructio          | VBP        | Verb, non-3rd person singular present
# 42   | interrete            | JJ         | Adjective
# 43   | tum                  | NN         | Noun, singular
# 44   | lucius               | NN         | Noun, singular
# 45   | mihi                 | NN         | Noun, singular
# 46   | vero                 | NN         | Noun, singular
# 47   | ista                 | NN         | Noun, singular
# 48   | valde                | NN         | Noun, singular
# 49   | probata              | NN         | Noun, singular
# 50   | sunt                 | NN         | Noun, singular
# 51   | quod                 | JJ         | Adjective
# 52   | item                 | NN         | Noun, singular
# 53   | fratri               | JJ         | Adjective
# 54   | puto                 | NN         | Noun, singular
# 55   | bestiarum            | NN         | Noun, singular
# 56   | vero                 | NN         | Noun, singular
# 57   | nullum               | NN         | Noun, singular
# 58   | iudicium             | NN         | Noun, singular
# 59   | puto                 | NN         | Noun, singular
# 60   | nihil                | JJ         | Adjective
# 61   | enim                 | NN         | Noun, singular
# 62   | iam                  | NN         | Noun, singular
# 63   | habes                | NNS        | Noun, plural
# 64   | quod                 | VBP        | Verb, non-3rd person singular present
# 65   | ad                   | NN         | Noun, singular
# 66   | corpus               | NN         | Noun, singular
# 67   | referas              | VBP        | Verb, non-3rd person singular present
# 68   | deinde               | NN         | Noun, singular
# 69   | prima                | NN         | Noun, singular
# 70   | illa                 | NN         | Noun, singular
# 71   | quae                 | NN         | Noun, singular
# 72   | congressu            | NN         | Noun, singular
# 73   | solemus              | NN         | Noun, singular
# 74   | quid                 | NN         | Noun, singular
# 75   | tu                   | NN         | Noun, singular
# 76   | inquit               | NN         | Noun, singular
# 77   | huc                  | NN         | Noun, singular
# 78   | et                   | FW         | Foreign word
# 79   | homini               | NN         | Noun, singular
# 80   | qui                  | NN         | Noun, singular
# 81   | ceteris              | NN         | Noun, singular
# 82   | animantibus          | NN         | Noun, singular
# 83   | plurimum             | JJ         | Adjective
# 84   | praestat             | NN         | Noun, singular
# 85   | praecipue            | NN         | Noun, singular
# 86   | natura               | NN         | Noun, singular
# 87   | nihil                | JJ         | Adjective
# 88   | datum                | NN         | Noun, singular
# 89   | esse                 | NN         | Noun, singular
# 90   | dicemusnniam         | NN         | Noun, singular
# 91   | id                   | NN         | Noun, singular
# 92   | ipsum                | NN         | Noun, singular
# 93   | absurdum             | NN         | Noun, singular
# 94   | maximum              | JJ         | Adjective
# 95   | malum                | NN         | Noun, singular
# 96   | neglegi              | NN         | Noun, singular
# 97   | quod                 | NN         | Noun, singular
# 98   | ea                   | NN         | Noun, singular
# 99   | non                  | JJ         | Adjective
# 100  | occurrentia          | NN         | Noun, singular
# 101  | fingunt              | NN         | Noun, singular
# 102  | vincunt              | NN         | Noun, singular
# 103  | aristonem            | NN         | Noun, singular
# 104  | atqui                | NN         | Noun, singular
# 105  | perspicuum           | NN         | Noun, singular
# 106  | est                  | JJS        | Adjective, superlative
# 107  | hominem              | NN         | Noun, singular
# 108  | e                    | NN         | Noun, singular
# 109  | corpore              | NN         | Noun, singular
# 110  | animoque             | NN         | Noun, singular
# 111  | constare             | NN         | Noun, singular
# 112  | cum                  | NN         | Noun, singular
# 113  | primae               | NN         | Noun, singular
# 114  | sint                 | NN         | Noun, singular
# 115  | animi                | NN         | Noun, singular
# 116  | partes               | VBZ        | Verb, 3rd person singular present
# 117  | secundae             | JJ         | Adjective
# 118  | corporis             | NN         | Noun, singular
# 119  | fieri                | NN         | Noun, singular
# 120  | inquam               | NN         | Noun, singular
# 121  | triari               | NN         | Noun, singular
# 122  | nullo                | FW         | Foreign word
# 123  | pacto                | NN         | Noun, singular
# 124  | potest               | JJS        | Adjective, superlative
# 125  | ut                   | JJ         | Adjective
# 126  | non                  | NN         | Noun, singular
# 127  | dicas                | NN         | Noun, singular
# 128  | quid                 | NN         | Noun, singular
# 129  | non                  | NN         | Noun, singular
# 130  | probes               | NNS        | Noun, plural
# 131  | eius                 | VBP        | Verb, non-3rd person singular present
# 132  | quo                  | JJ         | Adjective
# 133  | dissentias           | NN         | Noun, singular
# 134  | equidem              | NN         | Noun, singular
# 135  | e                    | NN         | Noun, singular
# 136  | cn                   | NN         | Noun, singular
# 137  | dubium               | NN         | Noun, singular
# 138  | est                  | JJS        | Adjective, superlative
# 139  | quin                 | NN         | Noun, singular
# 140  | virtus               | NN         | Noun, singular
# 141  | ita                  | JJ         | Adjective
# 142  | maximam              | NN         | Noun, singular
# 143  | partem               | NN         | Noun, singular
# 144  | optineat             | NN         | Noun, singular
# 145  | rebus                | NN         | Noun, singular
# 146  | humanis              | NN         | Noun, singular
# 147  | ut                   | JJ         | Adjective
# 148  | reliquas             | NN         | Noun, singular
# 149  | obruatnnquis         | NN         | Noun, singular
# 150  | istum                | NN         | Noun, singular
# 151  | dolorem              | NN         | Noun, singular
# 152  | timetnsummus         | NN         | Noun, singular
# 153  | dolor                | NN         | Noun, singular
# 154  | plures               | VBZ        | Verb, 3rd person singular present
# 155  | dies                 | NNS        | Noun, plural
# 156  | manere               | RB         | Adverb
# 157  | non                  | RB         | Adverb
# 158  | potest               | JJS        | Adjective, superlative
# 159  | dicet                | JJ         | Adjective
# 160  | pro                  | JJ         | Adjective
# 161  | ipsa                 | NN         | Noun, singular
# 162  | virtus               | NN         | Noun, singular
# 163  | nec                  | JJ         | Adjective
# 164  | dubitabit            | NN         | Noun, singular
# 165  | isti                 | JJ         | Adjective
# 166  | vestro               | NN         | Noun, singular
# 167  | beato                | NN         | Noun, singular
# 168  | tubulum              | NN         | Noun, singular
# 169  | fuisse               | NN         | Noun, singular
# 170  | qua                  | NN         | Noun, singular
# 171  | illum                | NN         | Noun, singular
# 172  | cuius                | NN         | Noun, singular
# 173  | condemnatus          | NN         | Noun, singular
# 174  | est                  | VBP        | Verb, non-3rd person singular present
# 175  | rogatione            | NN         | Noun, singular
# 176  | p                    | NN         | Noun, singular
# 177  | quod                 | NN         | Noun, singular
# 178  | si                   | NN         | Noun, singular
# 179  | ita                  | JJ         | Adjective
# 180  | sit                  | NN         | Noun, singular
# 181  | cur                  | NN         | Noun, singular
# 182  | opera                | NN         | Noun, singular
# 183  | philosophiae         | NN         | Noun, singular
# 184  | sit                  | NN         | Noun, singular
# 185  | danda                | NN         | Noun, singular
# 186  | nescionnex           | JJ         | Adjective
# 187  | eorum                | NN         | Noun, singular
# 188  | enim                 | NN         | Noun, singular
# 189  | scriptis             | NN         | Noun, singular
# 190  | et                   | FW         | Foreign word
# 191  | institutis           | NN         | Noun, singular
# 192  | cum                  | NN         | Noun, singular
# 193  | omnis                | IN         | Preposition/subordinating conjunction
# 194  | doctrina             | NN         | Noun, singular
# 195  | liberalis            | NN         | Noun, singular
# 196  | omnis                | NN         | Noun, singular
# 197  | historianquod        | NN         | Noun, singular
# 198  | si                   | NN         | Noun, singular
# 199  | ita                  | NN         | Noun, singular
# 200  | est                  | JJS        | Adjective, superlative
# 201  | sequitur             | NN         | Noun, singular
# 202  | id                   | NN         | Noun, singular
# 203  | ipsum                | NN         | Noun, singular
# 204  | quod                 | NN         | Noun, singular
# 205  | te                   | NN         | Noun, singular
# 206  | velle                | FW         | Foreign word
# 207  | video                | NN         | Noun, singular
# 208  | omnes                | NNS        | Noun, plural
# 209  | semper               | RBR        | Adverb, comparative
# 210  | beatos               | NNS        | Noun, plural
# 211  | esse                 | VBP        | Verb, non-3rd person singular present
# 212  | sapientes            | NNS        | Noun, plural
# 213  | cum                  | VBP        | Verb, non-3rd person singular present
# 214  | enim                 | JJ         | Adjective
# 215  | fertur               | NN         | Noun, singular
# 216  | quasi                | NN         | Noun, singular
# 217  | torrens              | NNS        | Noun, plural
# 218  | oratio               | VBP        | Verb, non-3rd person singular present
# 219  | quamvis              | JJ         | Adjective
# 220  | multa                | NN         | Noun, singular
# 221  | cuiusque             | NN         | Noun, singular
# 222  | modi                 | NN         | Noun, singular
# 223  | rapiat               | NN         | Noun, singular
# 224  | nihil                | JJ         | Adjective
# 225  | tamen                | NNS        | Noun, plural
# 226  | teneas               | VBP        | Verb, non-3rd person singular present
# 227  | nihil                | JJ         | Adjective
# 228  | apprehendas          | NNS        | Noun, plural
# 229  | nusquam              | JJ         | Adjective
# 230  | orationem            | JJ         | Adjective
# 231  | rapidam              | NN         | Noun, singular
# 232  | coerceas             | NNS        | Noun, plural
# 233  | ita                  | VBP        | Verb, non-3rd person singular present
# 234  | redarguitur          | NN         | Noun, singular
# 235  | ipse                 | NN         | Noun, singular
# 236  | sese                 | JJ         | Adjective
# 237  | convincunturque      | NN         | Noun, singular
# 238  | scripta              | NN         | Noun, singular
# 239  | eius                 | NN         | Noun, singular
# 240  | probitate            | NN         | Noun, singular
# 241  | ipsius               | NN         | Noun, singular
# 242  | ac                   | NN         | Noun, singular
# 243  | moribus              | NN         | Noun, singular
# 244  | quanta               | NN         | Noun, singular
# 245  | conantur             | NN         | Noun, singular
# 246  | mundum               | NN         | Noun, singular
# 247  | hunc                 | NN         | Noun, singular
# 248  | omnem                | NN         | Noun, singular
# 249  | oppidum              | NN         | Noun, singular
# 250  | esse                 | FW         | Foreign word
# 251  | nostrum              | NN         | Noun, singular
# 252  | incendi              | NN         | Noun, singular
# 253  | igitur               | NN         | Noun, singular
# 254  | eos                  | VBP        | Verb, non-3rd person singular present
# 255  | qui                  | NN         | Noun, singular
# 256  | audiunt              | NN         | Noun, singular
# 257  | vides                | NNS        | Noun, plural
# 258  | vide                 | IN         | Preposition/subordinating conjunction
# 259  | ne                   | JJ         | Adjective
# 260  | magis                | NN         | Noun, singular
# 261  | inquam               | NN         | Noun, singular
# 262  | tuum                 | NN         | Noun, singular
# 263  | fuerit               | NN         | Noun, singular
# 264  | cum                  | NN         | Noun, singular
# 265  | idem                 | NN         | Noun, singular
# 266  | tibi                 | NN         | Noun, singular
# 267  | quod                 | NN         | Noun, singular
# 268  | mihi                 | NN         | Noun, singular
# 269  | videretur            | NN         | Noun, singular
# 270  | non                  | NN         | Noun, singular
# 271  | nova                 | JJ         | Adjective
# 272  | te                   | NN         | Noun, singular
# 273  | rebus                | NN         | Noun, singular
# 274  | nomina               | NN         | Noun, singular
# 275  | inponere             | RB         | Adverb
# 276  | quivere              | RB         | Adverb
# 277  | falsone              | NN         | Noun, singular
# 278  | quaerere             | RB         | Adverb
# 279  | mittimusdicitur      | JJ         | Adjective
# 280  | oculis               | NNS        | Noun, plural
# 281  | se                   | VBP        | Verb, non-3rd person singular present
# 282  | privasse             | JJ         | Adjective
# 283  | si                   | NN         | Noun, singular
# 284  | ista                 | NN         | Noun, singular
# 285  | mala                 | NN         | Noun, singular
# 286  | sunt                 | NN         | Noun, singular
# 287  | quae                 | NN         | Noun, singular
# 288  | potest               | NN         | Noun, singular
# 289  | incidere             | RB         | Adverb
# 290  | sapiens              | VBZ        | Verb, 3rd person singular present
# 291  | sapientem            | NN         | Noun, singular
# 292  | esse                 | JJ         | Adjective
# 293  | non                  | JJ         | Adjective
# 294  | esse                 | NN         | Noun, singular
# 295  | ad                   | NN         | Noun, singular
# 296  | beate                | NN         | Noun, singular
# 297  | vivendum             | NN         | Noun, singular
# 298  | satis                | NN         | Noun, singular
# 299  | vero                 | NN         | Noun, singular
# 300  | si                   | NN         | Noun, singular
# 301  | ad                   | NN         | Noun, singular
# 302  | vitem                | NN         | Noun, singular
# 303  | sensus               | NN         | Noun, singular
# 304  | accesserit           | NN         | Noun, singular
# 305  | ut                   | JJ         | Adjective
# 306  | appetitum            | NN         | Noun, singular
# 307  | quendam              | NN         | Noun, singular
# 308  | habeat               | NN         | Noun, singular
# 309  | et                   | FW         | Foreign word
# 310  | per                  | IN         | Preposition/subordinating conjunction
# 311  | se                   | FW         | Foreign word
# 312  | ipsa                 | NN         | Noun, singular
# 313  | moveatur             | NN         | Noun, singular
# 314  | quid                 | NN         | Noun, singular
# 315  | facturam             | NN         | Noun, singular
# 316  | putasnnquem          | NN         | Noun, singular
# 317  | si                   | NN         | Noun, singular
# 318  | tenueris             | NN         | Noun, singular
# 319  | non                  | JJ         | Adjective
# 320  | modo                 | NN         | Noun, singular
# 321  | meum                 | NN         | Noun, singular
# 322  | ciceronem            | NN         | Noun, singular
# 323  | sed                  | VBD        | Verb, past tense
# 324  | etiam                | JJ         | Adjective
# 325  | ipsum                | NN         | Noun, singular
# 326  | abducas              | NN         | Noun, singular
# 327  | licebitnstulti       | NN         | Noun, singular
# 328  | autem                | NN         | Noun, singular
# 329  | malorum              | NN         | Noun, singular
# 330  | memoria              | NN         | Noun, singular
# 331  | torquentur           | NN         | Noun, singular
# 332  | sapientes            | VBZ        | Verb, 3rd person singular present
# 333  | bona                 | IN         | Preposition/subordinating conjunction
# 334  | praeterita           | NN         | Noun, singular
# 335  | grata                | NN         | Noun, singular
# 336  | recordatione         | NN         | Noun, singular
# 337  | renovata             | NN         | Noun, singular
# 338  | delectantnesse       | NN         | Noun, singular
# 339  | enim                 | NN         | Noun, singular
# 340  | quam                 | JJ         | Adjective
# 341  | vellet               | NN         | Noun, singular
# 342  | iniquus              | NN         | Noun, singular
# 343  | iustus               | NN         | Noun, singular
# 344  | poterat              | NN         | Noun, singular
# 345  | inpunenquae          | NN         | Noun, singular
# 346  | autem                | NN         | Noun, singular
# 347  | natura               | JJ         | Adjective
# 348  | suae                 | NN         | Noun, singular
# 349  | primae               | NN         | Noun, singular
# 350  | institutionis        | NN         | Noun, singular
# 351  | oblita               | JJ         | Adjective
# 352  | estnverum            | NN         | Noun, singular
# 353  | tamen                | NNS        | Noun, plural
# 354  | cum                  | VBP        | Verb, non-3rd person singular present
# 355  | de                   | IN         | Preposition/subordinating conjunction
# 356  | rebus                | FW         | Foreign word
# 357  | grandioribus         | FW         | Foreign word
# 358  | dicas                | FW         | Foreign word
# 359  | ipsae                | NN         | Noun, singular
# 360  | res                  | NNS        | Noun, plural
# 361  | verba                | VBP        | Verb, non-3rd person singular present
# 362  | rapiuntnhoc          | NN         | Noun, singular
# 363  | est                  | JJS        | Adjective, superlative
# 364  | non                  | NN         | Noun, singular
# 365  | modo                 | NN         | Noun, singular
# 366  | cor                  | NN         | Noun, singular
# 367  | non                  | NN         | Noun, singular
# 368  | habere               | RB         | Adverb
# 369  | sed                  | VBN        | Verb, past participle
# 370  | ne                   | JJ         | Adjective
# 371  | palatum              | NN         | Noun, singular
# 372  | quidemnvoluptatem    | NN         | Noun, singular
# 373  | cum                  | JJ         | Adjective
# 374  | summum               | JJ         | Adjective
# 375  | bonum                | NN         | Noun, singular
# 376  | diceret              | NN         | Noun, singular
# 377  | primum               | NN         | Noun, singular
# 378  | eo                   | NN         | Noun, singular
# 379  | ipso                 | NN         | Noun, singular
# 380  | parum                | NN         | Noun, singular
# 381  | vidit                | NN         | Noun, singular
# 382  | deinde               | NN         | Noun, singular
# 383  | hoc                  | NN         | Noun, singular
# 384  | quoque               | NN         | Noun, singular
# 385  | alienum              | NN         | Noun, singular
# 386  | sed                  | VBD        | Verb, past tense
# 387  | tu                   | JJ         | Adjective
# 388  | istuc                | NN         | Noun, singular
# 389  | dixti                | NN         | Noun, singular
# 390  | bene                 | NN         | Noun, singular
# 391  | latine               | NN         | Noun, singular
# 392  | parum                | NN         | Noun, singular
# 393  | plane                | NN         | Noun, singular
# 394  | nam                  | JJ         | Adjective
# 395  | haec                 | NN         | Noun, singular
# 396  | ipsa                 | NN         | Noun, singular
# 397  | mihi                 | NN         | Noun, singular
# 398  | erunt                | NN         | Noun, singular
# 399  | promptu              | NN         | Noun, singular
# 400  | quae                 | NN         | Noun, singular
# 401  | modo                 | NN         | Noun, singular
# 402  | audivi               | NN         | Noun, singular
# 403  | nec                  | JJ         | Adjective
# 404  | ante                 | NN         | Noun, singular
# 405  | aggrediar            | NN         | Noun, singular
# 406  | quam                 | NN         | Noun, singular
# 407  | te                   | NN         | Noun, singular
# 408  | ab                   | NN         | Noun, singular
# 409  | istis                | NN         | Noun, singular
# 410  | quos                 | NN         | Noun, singular
# 411  | dicis                | NN         | Noun, singular
# 412  | instructum           | NN         | Noun, singular
# 413  | videro               | NN         | Noun, singular
# 414  | fatebuntur           | NN         | Noun, singular
# 415  | stoici               | NN         | Noun, singular
# 416  | haec                 | NN         | Noun, singular
# 417  | omnia                | NN         | Noun, singular
# 418  | dicta                | NN         | Noun, singular
# 419  | esse                 | NN         | Noun, singular
# 420  | praeclare            | NN         | Noun, singular
# 421  | neque                | JJ         | Adjective
# 422  | eam                  | NN         | Noun, singular
# 423  | causam               | NN         | Noun, singular
# 424  | zenoni               | NNP        | Proper noun, singular
# 425  | desciscendi          | NN         | Noun, singular
# 426  | fuisse               | NN         | Noun, singular
# 427  | non                  | NN         | Noun, singular
# 428  | autem                | NN         | Noun, singular
# 429  | hoc                  | NN         | Noun, singular
# 430  | igitur               | NN         | Noun, singular
# 431  | ne                   | JJ         | Adjective
# 432  | illud                | NN         | Noun, singular
# 433  | quidem               | NN         | Noun, singular
# 434  | ratio                | NN         | Noun, singular
# 435  | quidem               | NN         | Noun, singular
# 436  | vestra               | JJ         | Adjective
# 437  | sic                  | JJ         | Adjective
# 438  | cogit                | NN         | Noun, singular
# 439  | cum                  | NN         | Noun, singular
# 440  | audissem             | NN         | Noun, singular
# 441  | antiochum            | IN         | Preposition/subordinating conjunction
# 442  | brute                | NN         | Noun, singular
# 443  | ut                   | JJ         | Adjective
# 444  | solebam              | NN         | Noun, singular
# 445  | cum                  | NN         | Noun, singular
# 446  | quod                 | NN         | Noun, singular
# 447  | ita                  | JJ         | Adjective
# 448  | callida              | NN         | Noun, singular
# 449  | est                  | JJS        | Adjective, superlative
# 450  | ut                   | JJ         | Adjective
# 451  | optime               | JJ         | Adjective
# 452  | possit               | NN         | Noun, singular
# 453  | architectari         | NN         | Noun, singular
# 454  | voluptatesnnidemne   | NN         | Noun, singular
# 455  | quod                 | NN         | Noun, singular
# 456  | iucundenhaec         | NN         | Noun, singular
# 457  | mihi                 | NN         | Noun, singular
# 458  | videtur              | NN         | Noun, singular
# 459  | delicatior           | JJ         | Adjective
# 460  | ut                   | JJ         | Adjective
# 461  | ita                  | NN         | Noun, singular
# 462  | dicam                | NN         | Noun, singular
# 463  | molliorque           | NN         | Noun, singular
# 464  | ratio                | NN         | Noun, singular
# 465  | quam                 | NN         | Noun, singular
# 466  | virtutis             | NN         | Noun, singular
# 467  | vis                  | FW         | Foreign word
# 468  | gravitasque          | NN         | Noun, singular
# 469  | postulat             | NN         | Noun, singular
# 470  | sed                  | VBD        | Verb, past tense
# 471  | quoniam              | JJ         | Adjective
# 472  | et                   | NN         | Noun, singular
# 473  | advesperascit        | NN         | Noun, singular
# 474  | et                   | FW         | Foreign word
# 475  | mihi                 | NN         | Noun, singular
# 476  | ad                   | NN         | Noun, singular
# 477  | villam               | NN         | Noun, singular
# 478  | revertendum          | NN         | Noun, singular
# 479  | est                  | JJS        | Adjective, superlative
# 480  | nunc                 | JJ         | Adjective
# 481  | quidem               | NN         | Noun, singular
# 482  | hactenus             | NN         | Noun, singular
# 483  | cuius                | NN         | Noun, singular
# 484  | ad                   | NN         | Noun, singular
# 485  | naturam              | NN         | Noun, singular
# 486  | apta                 | NN         | Noun, singular
# 487  | ratio                | NN         | Noun, singular
# 488  | vera                 | NN         | Noun, singular
# 489  | illa                 | NN         | Noun, singular
# 490  | et                   | FW         | Foreign word
# 491  | summa                | NN         | Noun, singular
# 492  | lex                  | FW         | Foreign word
# 493  | philosophis          | NN         | Noun, singular
# 494  | dicitur              | NN         | Noun, singular
# 495  | neque                | NN         | Noun, singular
# 496  | solum                | NN         | Noun, singular
# 497  | ea                   | NN         | Noun, singular
# 498  | communia             | NN         | Noun, singular
# 499  | verum                | NN         | Noun, singular
# 500  | etiam                | NN         | Noun, singular
# 501  | paria                | NN         | Noun, singular
# 502  | esse                 | NN         | Noun, singular
# 503  | dixerunt             | NN         | Noun, singular
# 504  | sed                  | VBD        | Verb, past tense
# 505  | nunc                 | JJ         | Adjective
# 506  | quod                 | NN         | Noun, singular
# 507  | agimus               | NN         | Noun, singular
# 508  | mene                 | NN         | Noun, singular
# 509  | tu                   | NN         | Noun, singular

# %% [markdown]
# # 9. Chunking

# %%
# Define chunk grammar
chunk_grammar = r"""
    NP: {<DT>?<JJ>*<NN.*>+}
    NP: {<NNP>+}
    NP: {<NNP><POS>?<NNP>*}
    VP: {<VB.*><NP|PP|CLAUSE>+$}
    PP: {<IN><NP>}
"""
chunk_parser = RegexpParser(chunk_grammar)

# Process ALL sentences for chunking
all_sentences = sent_tokenize(text_lower)

for sent_idx, sentence in enumerate(all_sentences, 1):
    print(f"\nSentence {sent_idx}: {sentence}")

    # Tokenize and tag
    tokens = word_tokenize(sentence)
    pos_tags = pos_tag(tokens)

    # Parse chunks
    chunk_tree = chunk_parser.parse(pos_tags)

    print("Chunk Tree Structure:")
    print(chunk_tree)

    print("Chunks extracted:")
    for subtree in chunk_tree.subtrees():
        if subtree.label() in ['NP', 'VP', 'PP']:
            chunk_words = ' '.join(word for word, tag in subtree.leaves())
            print(f"  {subtree.label()}: {chunk_words}")
# Out:
# Sentence 1: quod equidem non reprehendonlorem ipsum dolor sit amet, consectetur adipiscing elit.
# Chunk Tree Structure:
# (S
#   (NP
#     quod/NN
#     equidem/NN
#     non/NN
#     reprehendonlorem/NN
#     ipsum/NN
#     dolor/NN
#     sit/NN
#     amet/NN)
#   ,/,
#   (NP consectetur/NN)
#   adipiscing/VBG
#   (NP elit/NN)
#   ./.)
# Chunks extracted:
#   NP: quod equidem non reprehendonlorem ipsum dolor sit amet
#   NP: consectetur
#   NP: elit
#
# Sentence 2: quibus natura iure responderit non esse verum aliunde finem beate vivendi, a se principia rei gerendae peti quae enim adhuc protulisti, popularia sunt, ego autem a te elegantiora desidero.
# Chunk Tree Structure:
# (S
#   (NP quibus/NN natura/NN iure/NN responderit/NN)
#   non/FW
#   esse/FW
#   (NP verum/NN aliunde/NN finem/NN beate/NN vivendi/NN)
#   ,/,
#   (NP
#     a/DT
#     se/NN
#     principia/NN
#     rei/NN
#     gerendae/NN
#     peti/NN
#     quae/NN
#     enim/NN
#     adhuc/NN
#     protulisti/NN)
#   ,/,
#   (NP popularia/NN sunt/NN)
#   ,/,
#   (NP ego/NN autem/NN)
#   (NP a/DT te/NN elegantiora/NN desidero/NN)
#   ./.)
# Chunks extracted:
#   NP: quibus natura iure responderit
#   NP: verum aliunde finem beate vivendi
#   NP: a se principia rei gerendae peti quae enim adhuc protulisti
#   NP: popularia sunt
#   NP: ego autem
#   NP: a te elegantiora desidero
#
# Sentence 3: duo reges constructio interrete.
# Chunk Tree Structure:
# (S (NP duo/NN reges/NNS) constructio/VBP (NP interrete/NN) ./.)
# Chunks extracted:
#   NP: duo reges
#   NP: interrete
#
# Sentence 4: tum lucius mihi vero ista valde probata sunt, quod item fratri puto.
# Chunk Tree Structure:
# (S
#   (NP
#     tum/NN
#     lucius/NN
#     mihi/NN
#     vero/NN
#     ista/NN
#     valde/NN
#     probata/NN
#     sunt/NN)
#   ,/,
#   (NP quod/JJ item/NN)
#   (NP fratri/JJ puto/NN)
#   ./.)
# Chunks extracted:
#   NP: tum lucius mihi vero ista valde probata sunt
#   NP: quod item
#   NP: fratri puto
#
# Sentence 5: bestiarum vero nullum iudicium puto.
# Chunk Tree Structure:
# (S (NP bestiarum/NN vero/NN nullum/NN iudicium/NN puto/NN) ./.)
# Chunks extracted:
#   NP: bestiarum vero nullum iudicium puto
#
# Sentence 6: nihil enim iam habes, quod ad corpus referas deinde prima illa, quae in congressu solemus quid tu, inquit, huc et homini, qui ceteris animantibus plurimum praestat, praecipue a natura nihil datum esse dicemusnniam id ipsum absurdum, maximum malum neglegi.
# Chunk Tree Structure:
# (S
#   (NP nihil/JJ enim/NN iam/NN habes/NNS)
#   ,/,
#   (NP quod/NN ad/NN corpus/NN)
#   referas/VBP
#   (NP deinde/NN prima/NN illa/NN)
#   ,/,
#   (NP quae/NN)
#   (PP in/IN (NP congressu/NN solemus/NN quid/NN tu/NN))
#   ,/,
#   (NP inquit/NN)
#   ,/,
#   (NP huc/NN et/NN homini/NN)
#   ,/,
#   (NP qui/JJ ceteris/NN animantibus/NN plurimum/NN praestat/NN)
#   ,/,
#   praecipue/VB
#   (NP
#     a/DT
#     natura/NN
#     nihil/NN
#     datum/NN
#     esse/NN
#     dicemusnniam/NN
#     id/NN
#     ipsum/NN
#     absurdum/NN)
#   ,/,
#   (NP maximum/JJ malum/NN neglegi/NN)
#   ./.)
# Chunks extracted:
#   NP: nihil enim iam habes
#   NP: quod ad corpus
#   NP: deinde prima illa
#   NP: quae
#   PP: in congressu solemus quid tu
#   NP: congressu solemus quid tu
#   NP: inquit
#   NP: huc et homini
#   NP: qui ceteris animantibus plurimum praestat
#   NP: a natura nihil datum esse dicemusnniam id ipsum absurdum
#   NP: maximum malum neglegi
#
# Sentence 7: quod ea non occurrentia fingunt, vincunt aristonem atqui perspicuum est hominem e corpore animoque constare, cum primae sint animi partes, secundae corporis.
# Chunk Tree Structure:
# (S
#   (NP quod/NN ea/NN)
#   (NP non/JJ occurrentia/NN fingunt/NN)
#   ,/,
#   (NP vincunt/NN aristonem/NN atqui/NN perspicuum/NN)
#   est/JJS
#   (NP hominem/NN e/NN corpore/NN animoque/NN constare/NN)
#   ,/,
#   (NP cum/NN primae/NN sint/NN animi/NN partes/NNS)
#   ,/,
#   (NP secundae/JJ corporis/NN)
#   ./.)
# Chunks extracted:
#   NP: quod ea
#   NP: non occurrentia fingunt
#   NP: vincunt aristonem atqui perspicuum
#   NP: hominem e corpore animoque constare
#   NP: cum primae sint animi partes
#   NP: secundae corporis
#
# Sentence 8: fieri, inquam, triari, nullo pacto potest, ut non dicas, quid non probes eius, a quo dissentias.
# Chunk Tree Structure:
# (S
#   (NP fieri/NN)
#   ,/,
#   (NP inquam/NN)
#   ,/,
#   (NP triari/NN)
#   ,/,
#   (NP nullo/JJ pacto/NN potest/NN)
#   ,/,
#   (NP ut/JJ non/NN dicas/NN)
#   ,/,
#   (NP quid/NN non/NN probes/NNS)
#   eius/VBP
#   ,/,
#   (NP a/DT quo/NN dissentias/NN)
#   ./.)
# Chunks extracted:
#   NP: fieri
#   NP: inquam
#   NP: triari
#   NP: nullo pacto potest
#   NP: ut non dicas
#   NP: quid non probes
#   NP: a quo dissentias
#
# Sentence 9: equidem e cn.
# Chunk Tree Structure:
# (S (NP equidem/NN e/NN cn/NN) ./.)
# Chunks extracted:
#   NP: equidem e cn
#
# Sentence 10: an dubium est, quin virtus ita maximam partem optineat in rebus humanis, ut reliquas obruatnnquis istum dolorem timetnsummus dolor plures dies manere non potest dicet pro me ipsa virtus nec dubitabit isti vestro beato m. tubulum fuisse, qua illum, cuius is condemnatus est rogatione, p. quod si ita sit, cur opera philosophiae sit danda nescio.nnex eorum enim scriptis et institutis cum omnis doctrina liberalis, omnis historia.nquod si ita est, sequitur id ipsum, quod te velle video, omnes semper beatos esse sapientes.
# Chunk Tree Structure:
# (S
#   (NP an/DT dubium/NN est/NN)
#   ,/,
#   (NP quin/JJ virtus/NN ita/NN maximam/NN partem/NN optineat/NN)
#   (PP in/IN (NP rebus/NN humanis/NN))
#   ,/,
#   (NP
#     ut/JJ
#     reliquas/NN
#     obruatnnquis/NN
#     istum/NN
#     dolorem/NN
#     timetnsummus/NN
#     dolor/NN)
#   plures/VBZ
#   (NP dies/NNS)
#   manere/RB
#   non/RB
#   potest/JJS
#   dicet/JJ
#   pro/FW
#   me/PRP
#   (NP ipsa/JJ virtus/NN)
#   (NP nec/JJ dubitabit/NN)
#   (NP isti/JJ vestro/NN beato/NN m./NN tubulum/NN fuisse/NN)
#   ,/,
#   (NP qua/NN illum/NN)
#   ,/,
#   (NP cuius/NN)
#   is/VBZ
#   condemnatus/JJ
#   est/RB
#   (NP rogatione/NN)
#   ,/,
#   (NP p./NN quod/NN si/NN)
#   (NP ita/JJ sit/NN)
#   ,/,
#   cur/VBP
#   (NP opera/NN philosophiae/NN sit/NN danda/NN)
#   (NP nescio.nnex/JJ eorum/NN enim/NN scriptis/NN)
#   et/FW
#   (NP institutis/NN cum/NN)
#   (PP omnis/IN (NP doctrina/NN liberalis/NN))
#   ,/,
#   (NP omnis/NN historia.nquod/NN si/NN ita/NN est/NN)
#   ,/,
#   (NP sequitur/JJ id/NN ipsum/NN)
#   ,/,
#   (NP quod/JJ te/NN velle/NN video/NN)
#   ,/,
#   omnes/VBZ
#   semper/JJR
#   (NP beatos/NN esse/NN sapientes/NNS)
#   ./.)
# Chunks extracted:
#   NP: an dubium est
#   NP: quin virtus ita maximam partem optineat
#   PP: in rebus humanis
#   NP: rebus humanis
#   NP: ut reliquas obruatnnquis istum dolorem timetnsummus dolor
#   NP: dies
#   NP: ipsa virtus
#   NP: nec dubitabit
#   NP: isti vestro beato m. tubulum fuisse
#   NP: qua illum
#   NP: cuius
#   NP: rogatione
#   NP: p. quod si
#   NP: ita sit
#   NP: opera philosophiae sit danda
#   NP: nescio.nnex eorum enim scriptis
#   NP: institutis cum
#   PP: omnis doctrina liberalis
#   NP: doctrina liberalis
#   NP: omnis historia.nquod si ita est
#   NP: sequitur id ipsum
#   NP: quod te velle video
#   NP: beatos esse sapientes
#
# Sentence 11: cum enim fertur quasi torrens oratio, quamvis multa cuiusque modi rapiat, nihil tamen teneas, nihil apprehendas, nusquam orationem rapidam coerceas.
# Chunk Tree Structure:
# (S
#   (NP cum/NN enim/NN fertur/NN quasi/NN torrens/NNS)
#   oratio/VBP
#   ,/,
#   (NP quamvis/JJ multa/NN cuiusque/NN modi/NN rapiat/NN)
#   ,/,
#   (NP nihil/JJ tamen/NNS teneas/NNS)
#   ,/,
#   (NP nihil/JJ apprehendas/NN)
#   ,/,
#   (NP nusquam/JJ orationem/NN rapidam/NN coerceas/NNS)
#   ./.)
# Chunks extracted:
#   NP: cum enim fertur quasi torrens
#   NP: quamvis multa cuiusque modi rapiat
#   NP: nihil tamen teneas
#   NP: nihil apprehendas
#   NP: nusquam orationem rapidam coerceas
#
# Sentence 12: ita redarguitur ipse a sese, convincunturque scripta eius probitate ipsius ac moribus.
# Chunk Tree Structure:
# (S
#   (NP ita/JJ redarguitur/NN ipse/NN)
#   a/DT
#   sese/JJ
#   ,/,
#   (NP
#     convincunturque/JJ
#     scripta/NN
#     eius/NN
#     probitate/NN
#     ipsius/NN
#     ac/NN
#     moribus/NN)
#   ./.)
# Chunks extracted:
#   NP: ita redarguitur ipse
#   NP: convincunturque scripta eius probitate ipsius ac moribus
#
# Sentence 13: at quanta conantur mundum hunc omnem oppidum esse nostrum incendi igitur eos, qui audiunt, vides.
# Chunk Tree Structure:
# (S
#   (PP
#     at/IN
#     (NP quanta/JJ conantur/NN mundum/NN hunc/NN omnem/NN oppidum/NN))
#   esse/FW
#   (NP nostrum/NN incendi/NN igitur/NN eos/NN)
#   ,/,
#   (NP qui/NN audiunt/NN)
#   ,/,
#   (NP vides/NNS)
#   ./.)
# Chunks extracted:
#   PP: at quanta conantur mundum hunc omnem oppidum
#   NP: quanta conantur mundum hunc omnem oppidum
#   NP: nostrum incendi igitur eos
#   NP: qui audiunt
#   NP: vides
#
# Sentence 14: vide, ne magis, inquam, tuum fuerit, cum re idem tibi, quod mihi, videretur, non nova te rebus nomina inponere.
# Chunk Tree Structure:
# (S
#   (NP vide/NN)
#   ,/,
#   (NP ne/JJ magis/NN)
#   ,/,
#   (NP inquam/NN)
#   ,/,
#   (NP tuum/NN fuerit/NN)
#   ,/,
#   (NP cum/NN re/NN idem/NN tibi/NN)
#   ,/,
#   (NP quod/JJ mihi/NN)
#   ,/,
#   (NP videretur/NN)
#   ,/,
#   non/JJ
#   nova/FW
#   (NP te/NN rebus/NN nomina/NN)
#   inponere/RB
#   ./.)
# Chunks extracted:
#   NP: vide
#   NP: ne magis
#   NP: inquam
#   NP: tuum fuerit
#   NP: cum re idem tibi
#   NP: quod mihi
#   NP: videretur
#   NP: te rebus nomina
#
# Sentence 15: quivere falsone, quaerere mittimusdicitur oculis se privasse si ista mala sunt, in quae potest incidere sapiens, sapientem esse non esse ad beate vivendum satis.
# Chunk Tree Structure:
# (S
#   quivere/RB
#   (NP falsone/NN)
#   ,/,
#   quaerere/RB
#   (NP mittimusdicitur/JJ oculis/NNS)
#   se/VBP
#   (NP privasse/JJ si/NN ista/NN mala/NN sunt/NN)
#   ,/,
#   (PP in/IN (NP quae/JJ potest/NN incidere/NN sapiens/NNS))
#   ,/,
#   (NP sapientem/NN)
#   esse/FW
#   non/FW
#   esse/FW
#   (NP ad/NN beate/NN vivendum/NN satis/NN)
#   ./.)
# Chunks extracted:
#   NP: falsone
#   NP: mittimusdicitur oculis
#   NP: privasse si ista mala sunt
#   PP: in quae potest incidere sapiens
#   NP: quae potest incidere sapiens
#   NP: sapientem
#   NP: ad beate vivendum satis
#
# Sentence 16: at vero si ad vitem sensus accesserit, ut appetitum quendam habeat et per se ipsa moveatur, quid facturam putasnnquem si tenueris, non modo meum ciceronem, sed etiam me ipsum abducas licebit.nstulti autem malorum memoria torquentur, sapientes bona praeterita grata recordatione renovata delectant.nesse enim quam vellet iniquus iustus poterat inpune.nquae autem natura suae primae institutionis oblita estnverum tamen cum de rebus grandioribus dicas, ipsae res verba rapiuntnhoc est non modo cor non habere, sed ne palatum quidem.nvoluptatem cum summum bonum diceret, primum in eo ipso parum vidit, deinde hoc quoque alienum sed tu istuc dixti bene latine, parum plane.
# Chunk Tree Structure:
# (S
#   (PP
#     at/IN
#     (NP vero/NN si/NN ad/NN vitem/NN sensus/NN accesserit/NN))
#   ,/,
#   (NP ut/JJ appetitum/NN quendam/NN habeat/NN)
#   et/FW
#   per/IN
#   se/FW
#   (NP ipsa/NN moveatur/NN)
#   ,/,
#   (NP quid/JJ facturam/NN putasnnquem/NN si/NN tenueris/NN)
#   ,/,
#   (NP non/JJ modo/NN meum/NN ciceronem/NN)
#   ,/,
#   sed/VBD
#   etiam/IN
#   me/PRP
#   (NP
#     ipsum/JJ
#     abducas/JJ
#     licebit.nstulti/NN
#     autem/NN
#     malorum/NN
#     memoria/NN
#     torquentur/NN)
#   ,/,
#   sapientes/VBZ
#   (NP
#     bona/JJ
#     praeterita/NN
#     grata/NN
#     recordatione/NN
#     renovata/NN
#     delectant.nesse/NN
#     enim/NN)
#   (NP
#     quam/JJ
#     vellet/NN
#     iniquus/NN
#     iustus/NN
#     poterat/NN
#     inpune.nquae/NN
#     autem/NN)
#   (NP natura/JJ suae/NN primae/NN institutionis/NN)
#   (NP oblita/JJ estnverum/NN tamen/NNS)
#   cum/VBP
#   de/IN
#   rebus/FW
#   (NP grandioribus/NN dicas/NN)
#   ,/,
#   (NP ipsae/JJ res/NNS)
#   verba/VBP
#   (NP rapiuntnhoc/NN)
#   est/JJS
#   (NP non/NN modo/NN cor/NN non/NN)
#   habere/RB
#   ,/,
#   sed/VBD
#   (NP ne/JJ palatum/NN quidem.nvoluptatem/NN)
#   (NP cum/JJ summum/JJ bonum/NN diceret/NN)
#   ,/,
#   (NP primum/NN)
#   (PP in/IN (NP eo/JJ ipso/NN parum/NN vidit/NN))
#   ,/,
#   (NP deinde/NN hoc/NN quoque/NN alienum/NN)
#   sed/VBD
#   (NP tu/JJ istuc/NN dixti/NN bene/NN latine/NN)
#   ,/,
#   (NP parum/NN plane/NN)
#   ./.)
# Chunks extracted:
#   PP: at vero si ad vitem sensus accesserit
#   NP: vero si ad vitem sensus accesserit
#   NP: ut appetitum quendam habeat
#   NP: ipsa moveatur
#   NP: quid facturam putasnnquem si tenueris
#   NP: non modo meum ciceronem
#   NP: ipsum abducas licebit.nstulti autem malorum memoria torquentur
#   NP: bona praeterita grata recordatione renovata delectant.nesse enim
#   NP: quam vellet iniquus iustus poterat inpune.nquae autem
#   NP: natura suae primae institutionis
#   NP: oblita estnverum tamen
#   NP: grandioribus dicas
#   NP: ipsae res
#   NP: rapiuntnhoc
#   NP: non modo cor non
#   NP: ne palatum quidem.nvoluptatem
#   NP: cum summum bonum diceret
#   NP: primum
#   PP: in eo ipso parum vidit
#   NP: eo ipso parum vidit
#   NP: deinde hoc quoque alienum
#   NP: tu istuc dixti bene latine
#   NP: parum plane
#
# Sentence 17: nam haec ipsa mihi erunt in promptu, quae modo audivi, nec ante aggrediar, quam te ab istis, quos dicis, instructum videro.
# Chunk Tree Structure:
# (S
#   (NP nam/JJ haec/NN ipsa/NN mihi/NN erunt/NN)
#   (PP in/IN (NP promptu/NN))
#   ,/,
#   (NP quae/JJ modo/NN audivi/NN)
#   ,/,
#   (NP nec/JJ ante/NN aggrediar/NN)
#   ,/,
#   (NP quam/NN te/NN ab/NN istis/NN)
#   ,/,
#   (NP quos/JJ dicis/NN)
#   ,/,
#   (NP instructum/NN videro/NN)
#   ./.)
# Chunks extracted:
#   NP: nam haec ipsa mihi erunt
#   PP: in promptu
#   NP: promptu
#   NP: quae modo audivi
#   NP: nec ante aggrediar
#   NP: quam te ab istis
#   NP: quos dicis
#   NP: instructum videro
#
# Sentence 18: fatebuntur stoici haec omnia dicta esse praeclare, neque eam causam zenoni desciscendi fuisse.
# Chunk Tree Structure:
# (S
#   (NP
#     fatebuntur/NN
#     stoici/NN
#     haec/NN
#     omnia/NN
#     dicta/NN
#     esse/NN
#     praeclare/NN)
#   ,/,
#   (NP neque/JJ eam/NN causam/NN zenoni/NNP desciscendi/NN fuisse/NN)
#   ./.)
# Chunks extracted:
#   NP: fatebuntur stoici haec omnia dicta esse praeclare
#   NP: neque eam causam zenoni desciscendi fuisse
#
# Sentence 19: non autem hoc igitur ne illud quidem.
# Chunk Tree Structure:
# (S
#   (NP non/JJ autem/NN hoc/NN igitur/NN)
#   (NP ne/JJ illud/NN quidem/NN)
#   ./.)
# Chunks extracted:
#   NP: non autem hoc igitur
#   NP: ne illud quidem
#
# Sentence 20: ratio quidem vestra sic cogit.
# Chunk Tree Structure:
# (S (NP ratio/NN quidem/NN) (NP vestra/JJ sic/JJ cogit/NN) ./.)
# Chunks extracted:
#   NP: ratio quidem
#   NP: vestra sic cogit
#
# Sentence 21: cum audissem antiochum, brute, ut solebam, cum m. an quod ita callida est, ut optime possit architectari voluptatesnnidemne, quod iucundenhaec mihi videtur delicatior, ut ita dicam, molliorque ratio, quam virtutis vis gravitasque postulat.
# Chunk Tree Structure:
# (S
#   (NP cum/NN audissem/NN antiochum/NN)
#   ,/,
#   (NP brute/NN)
#   ,/,
#   (NP ut/JJ solebam/NN)
#   ,/,
#   (NP cum/NN)
#   m./VBD
#   (NP an/DT quod/NN ita/NN callida/NN est/NN)
#   ,/,
#   (NP
#     ut/JJ
#     optime/JJ
#     possit/NN
#     architectari/NN
#     voluptatesnnidemne/NN)
#   ,/,
#   (NP quod/JJ iucundenhaec/NN mihi/NN videtur/NN delicatior/NN)
#   ,/,
#   (NP ut/JJ ita/NN dicam/NN)
#   ,/,
#   (NP molliorque/NN ratio/NN)
#   ,/,
#   quam/FW
#   virtutis/FW
#   vis/FW
#   (NP gravitasque/NN postulat/NN)
#   ./.)
# Chunks extracted:
#   NP: cum audissem antiochum
#   NP: brute
#   NP: ut solebam
#   NP: cum
#   NP: an quod ita callida est
#   NP: ut optime possit architectari voluptatesnnidemne
#   NP: quod iucundenhaec mihi videtur delicatior
#   NP: ut ita dicam
#   NP: molliorque ratio
#   NP: gravitasque postulat
#
# Sentence 22: sed quoniam et advesperascit et mihi ad villam revertendum est, nunc quidem hactenus cuius ad naturam apta ratio vera illa et summa lex a philosophis dicitur.
# Chunk Tree Structure:
# (S
#   sed/VBN
#   (NP quoniam/JJ et/NN advesperascit/NN)
#   et/FW
#   (NP mihi/NN ad/NN villam/NN revertendum/NN)
#   est/JJS
#   ,/,
#   (NP
#     nunc/JJ
#     quidem/NN
#     hactenus/NN
#     cuius/NN
#     ad/NN
#     naturam/NN
#     apta/NN
#     ratio/NN
#     vera/NN
#     illa/NN)
#   et/FW
#   (NP summa/NN)
#   lex/VBZ
#   (NP a/DT philosophis/NN dicitur/NN)
#   ./.)
# Chunks extracted:
#   NP: quoniam et advesperascit
#   NP: mihi ad villam revertendum
#   NP: nunc quidem hactenus cuius ad naturam apta ratio vera illa
#   NP: summa
#   NP: a philosophis dicitur
#
# Sentence 23: neque solum ea communia, verum etiam paria esse dixerunt.
# Chunk Tree Structure:
# (S
#   (NP neque/JJ solum/NN ea/NN communia/NN)
#   ,/,
#   (NP verum/NN etiam/NN paria/NN esse/NN dixerunt/NN)
#   ./.)
# Chunks extracted:
#   NP: neque solum ea communia
#   NP: verum etiam paria esse dixerunt
#
# Sentence 24: sed nunc, quod agimus a mene tu
# Chunk Tree Structure:
# (S
#   sed/VBN
#   (NP nunc/NN)
#   ,/,
#   quod/JJ
#   (VP agimus/VBP (NP a/DT mene/NN tu/NN)))
# Chunks extracted:
#   NP: nunc
#   VP: agimus a mene tu
#   NP: a mene tu

# %% [markdown]
# # 10. Parsing ( Dependency Parsing and Tree Structure Parsing )

# %%
# Process entire text with spaCy
doc = nlp(text_lower)

print("DEPENDENCY RELATIONS FOR ENTIRE TEXT:")

for token in doc:
    print(f"Word: '{token.text}'")
    print(f"  Head word: '{token.head.text}'")
    print(f"  Dependency relation: {token.dep_}")
    print(f"  Explanation: {spacy.explain(token.dep_)}")
    print(f"  Children: {[child.text for child in token.children]}")
# Out:
# DEPENDENCY RELATIONS FOR ENTIRE TEXT:
# Word: 'quod'
#   Head word: 'equidem'
#   Dependency relation: compound
#   Explanation: compound
#   Children: []
# Word: 'equidem'
#   Head word: 'dolor'
#   Dependency relation: compound
#   Explanation: compound
#   Children: ['quod']
# Word: 'non'
#   Head word: 'dolor'
#   Dependency relation: compound
#   Explanation: compound
#   Children: []
# Word: 'reprehendonlorem'
#   Head word: 'dolor'
#   Dependency relation: compound
#   Explanation: compound
#   Children: []
# Word: 'ipsum'
#   Head word: 'dolor'
#   Dependency relation: compound
#   Explanation: compound
#   Children: []
# Word: 'dolor'
#   Head word: 'amet'
#   Dependency relation: compound
#   Explanation: compound
#   Children: ['equidem', 'non', 'reprehendonlorem', 'ipsum']
# Word: 'sit'
#   Head word: 'amet'
#   Dependency relation: compound
#   Explanation: compound
#   Children: []
# Word: 'amet'
#   Head word: 'amet'
#   Dependency relation: ROOT
#   Explanation: root
#   Children: ['dolor', 'sit', ',', 'elit', '.']
# Word: ','
#   Head word: 'amet'
#   Dependency relation: punct
#   Explanation: punctuation
#   Children: []
# Word: 'consectetur'
#   Head word: 'adipiscing'
#   Dependency relation: npadvmod
#   Explanation: noun phrase as adverbial modifier
#   Children: []
# Word: 'adipiscing'
#   Head word: 'elit'
#   Dependency relation: amod
#   Explanation: adjectival modifier
#   Children: ['consectetur']
# Word: 'elit'
#   Head word: 'amet'
#   Dependency relation: appos
#   Explanation: appositional modifier
#   Children: ['adipiscing']
# Word: '.'
#   Head word: 'amet'
#   Dependency relation: punct
#   Explanation: punctuation
#   Children: []
# Word: 'quibus'
#   Head word: 'iure'
#   Dependency relation: compound
#   Explanation: compound
#   Children: []
# Word: 'natura'
#   Head word: 'iure'
#   Dependency relation: compound
#   Explanation: compound
#   Children: []
# Word: 'iure'
#   Head word: 'responderit'
#   Dependency relation: compound
#   Explanation: compound
#   Children: ['quibus', 'natura']
# Word: 'responderit'
#   Head word: 'vivendi'
#   Dependency relation: nmod
#   Explanation: modifier of nominal
#   Children: ['iure']
# Word: 'non'
#   Head word: 'esse'
#   Dependency relation: nmod
#   Explanation: modifier of nominal
#   Children: []
# Word: 'esse'
#   Head word: 'aliunde'
#   Dependency relation: nmod
#   Explanation: modifier of nominal
#   Children: ['non']
# Word: 'verum'
#   Head word: 'aliunde'
#   Dependency relation: compound
#   Explanation: compound
#   Children: []
# Word: 'aliunde'
#   Head word: 'vivendi'
#   Dependency relation: compound
#   Explanation: compound
#   Children: ['esse', 'verum']
# Word: 'finem'
#   Head word: 'vivendi'
#   Dependency relation: compound
#   Explanation: compound
#   Children: []
# Word: 'beate'
#   Head word: 'vivendi'
#   Dependency relation: compound
#   Explanation: compound
#   Children: []
# Word: 'vivendi'
#   Head word: 'gerendae'
#   Dependency relation: nsubj
#   Explanation: nominal subject
#   Children: ['responderit', 'aliunde', 'finem', 'beate', ',', 'rei']
# Word: ','
#   Head word: 'vivendi'
#   Dependency relation: punct
#   Explanation: punctuation
#   Children: []
# Word: 'a'
#   Head word: 'rei'
#   Dependency relation: det
#   Explanation: determiner
#   Children: []
# Word: 'se'
#   Head word: 'rei'
#   Dependency relation: amod
#   Explanation: adjectival modifier
#   Children: []
# Word: 'principia'
#   Head word: 'rei'
#   Dependency relation: compound
#   Explanation: compound
#   Children: []
# Word: 'rei'
#   Head word: 'vivendi'
#   Dependency relation: appos
#   Explanation: appositional modifier
#   Children: ['a', 'se', 'principia']
# Word: 'gerendae'
#   Head word: 'gerendae'
#   Dependency relation: ROOT
#   Explanation: root
#   Children: ['vivendi', 'protulisti', '.']
# Word: 'peti'
#   Head word: 'protulisti'
#   Dependency relation: amod
#   Explanation: adjectival modifier
#   Children: []
# Word: 'quae'
#   Head word: 'protulisti'
#   Dependency relation: compound
#   Explanation: compound
#   Children: []
# Word: 'enim'
#   Head word: 'protulisti'
#   Dependency relation: compound
#   Explanation: compound
#   Children: []
# Word: 'adhuc'
#   Head word: 'protulisti'
#   Dependency relation: compound
#   Explanation: compound
#   Children: []
# Word: 'protulisti'
#   Head word: 'gerendae'
#   Dependency relation: dobj
#   Explanation: direct object
#   Children: ['peti', 'quae', 'enim', 'adhuc', ',', 'sunt', 'autem']
# Word: ','
#   Head word: 'protulisti'
#   Dependency relation: punct
#   Explanation: punctuation
#   Children: []
# Word: 'popularia'
#   Head word: 'sunt'
#   Dependency relation: compound
#   Explanation: compound
#   Children: []
# Word: 'sunt'
#   Head word: 'protulisti'
#   Dependency relation: conj
#   Explanation: conjunct
#   Children: ['popularia', ',']
# Word: ','
#   Head word: 'sunt'
#   Dependency relation: punct
#   Explanation: punctuation
#   Children: []
# Word: 'ego'
#   Head word: 'autem'
#   Dependency relation: amod
#   Explanation: adjectival modifier
#   Children: []
# Word: 'autem'
#   Head word: 'protulisti'
#   Dependency relation: appos
#   Explanation: appositional modifier
#   Children: ['ego', 'desidero']
# Word: 'a'
#   Head word: 'desidero'
#   Dependency relation: det
#   Explanation: determiner
#   Children: []
# Word: 'te'
#   Head word: 'elegantiora'
#   Dependency relation: compound
#   Explanation: compound
#   Children: []
# Word: 'elegantiora'
#   Head word: 'desidero'
#   Dependency relation: compound
#   Explanation: compound
#   Children: ['te']
# Word: 'desidero'
#   Head word: 'autem'
#   Dependency relation: appos
#   Explanation: appositional modifier
#   Children: ['a', 'elegantiora']
# Word: '.'
#   Head word: 'gerendae'
#   Dependency relation: punct
#   Explanation: punctuation
#   Children: []
# Word: 'duo'
#   Head word: 'reges'
#   Dependency relation: compound
#   Explanation: compound
#   Children: []
# Word: 'reges'
#   Head word: 'constructio'
#   Dependency relation: nsubj
#   Explanation: nominal subject
#   Children: ['duo']
# Word: 'constructio'
#   Head word: 'constructio'
#   Dependency relation: ROOT
#   Explanation: root
#   Children: ['reges', 'interrete', '.']
# Word: 'interrete'
#   Head word: 'constructio'
#   Dependency relation: advmod
#   Explanation: adverbial modifier
#   Children: []
# Word: '.'
#   Head word: 'constructio'
#   Dependency relation: punct
#   Explanation: punctuation
#   Children: []
# Word: 'tum'
#   Head word: 'lucius'
#   Dependency relation: compound
#   Explanation: compound
#   Children: []
# Word: 'lucius'
#   Head word: 'mihi'
#   Dependency relation: compound
#   Explanation: compound
#   Children: ['tum']
# Word: 'mihi'
#   Head word: 'sunt'
#   Dependency relation: compound
#   Explanation: compound
#   Children: ['lucius']
# Word: 'vero'
#   Head word: 'sunt'
#   Dependency relation: compound
#   Explanation: compound
#   Children: []
# Word: 'ista'
#   Head word: 'sunt'
#   Dependency relation: compound
#   Explanation: compound
#   Children: []
# Word: 'valde'
#   Head word: 'sunt'
#   Dependency relation: compound
#   Explanation: compound
#   Children: []
# Word: 'probata'
#   Head word: 'sunt'
#   Dependency relation: compound
#   Explanation: compound
#   Children: []
# Word: 'sunt'
#   Head word: 'sunt'
#   Dependency relation: ROOT
#   Explanation: root
#   Children: ['mihi', 'vero', 'ista', 'valde', 'probata', ',', 'puto', '.']
# Word: ','
#   Head word: 'sunt'
#   Dependency relation: punct
#   Explanation: punctuation
#   Children: []
# Word: 'quod'
#   Head word: 'item'
#   Dependency relation: compound
#   Explanation: compound
#   Children: []
# Word: 'item'
#   Head word: 'puto'
#   Dependency relation: compound
#   Explanation: compound
#   Children: ['quod']
# Word: 'fratri'
#   Head word: 'puto'
#   Dependency relation: amod
#   Explanation: adjectival modifier
#   Children: []
# Word: 'puto'
#   Head word: 'sunt'
#   Dependency relation: conj
#   Explanation: conjunct
#   Children: ['item', 'fratri']
# Word: '.'
#   Head word: 'sunt'
#   Dependency relation: punct
#   Explanation: punctuation
#   Children: []
# Word: 'bestiarum'
#   Head word: 'puto'
#   Dependency relation: compound
#   Explanation: compound
#   Children: []
# Word: 'vero'
#   Head word: 'puto'
#   Dependency relation: compound
#   Explanation: compound
#   Children: []
# Word: 'nullum'
#   Head word: 'puto'
#   Dependency relation: compound
#   Explanation: compound
#   Children: []
# Word: 'iudicium'
#   Head word: 'puto'
#   Dependency relation: compound
#   Explanation: compound
#   Children: []
# Word: 'puto'
#   Head word: 'puto'
#   Dependency relation: ROOT
#   Explanation: root
#   Children: ['bestiarum', 'vero', 'nullum', 'iudicium', '.']
# Word: '.'
#   Head word: 'puto'
#   Dependency relation: punct
#   Explanation: punctuation
#   Children: []
# Word: 'nihil'
#   Head word: 'habes'
#   Dependency relation: compound
#   Explanation: compound
#   Children: []
# Word: 'enim'
#   Head word: 'habes'
#   Dependency relation: compound
#   Explanation: compound
#   Children: []
# Word: 'iam'
#   Head word: 'habes'
#   Dependency relation: compound
#   Explanation: compound
#   Children: []
# Word: 'habes'
#   Head word: 'deinde'
#   Dependency relation: nsubj
#   Explanation: nominal subject
#   Children: ['nihil', 'enim', 'iam', ',', 'corpus']
# Word: ','
#   Head word: 'habes'
#   Dependency relation: punct
#   Explanation: punctuation
#   Children: []
# Word: 'quod'
#   Head word: 'corpus'
#   Dependency relation: compound
#   Explanation: compound
#   Children: []
# Word: 'ad'
#   Head word: 'corpus'
#   Dependency relation: compound
#   Explanation: compound
#   Children: []
# Word: 'corpus'
#   Head word: 'habes'
#   Dependency relation: appos
#   Explanation: appositional modifier
#   Children: ['quod', 'ad', 'referas']
# Word: 'referas'
#   Head word: 'corpus'
#   Dependency relation: appos
#   Explanation: appositional modifier
#   Children: []
# Word: 'deinde'
#   Head word: 'deinde'
#   Dependency relation: ROOT
#   Explanation: root
#   Children: ['habes', 'illa', ',', 'praecipue', '.']
# Word: 'prima'
#   Head word: 'illa'
#   Dependency relation: compound
#   Explanation: compound
#   Children: []
# Word: 'illa'
#   Head word: 'deinde'
#   Dependency relation: dobj
#   Explanation: direct object
#   Children: ['prima', ',', 'quae']
# Word: ','
#   Head word: 'illa'
#   Dependency relation: punct
#   Explanation: punctuation
#   Children: []
# Word: 'quae'
#   Head word: 'illa'
#   Dependency relation: conj
#   Explanation: conjunct
#   Children: ['in', 'tu']
# Word: 'in'
#   Head word: 'quae'
#   Dependency relation: prep
#   Explanation: prepositional modifier
#   Children: ['solemus']
# Word: 'congressu'
#   Head word: 'solemus'
#   Dependency relation: compound
#   Explanation: compound
#   Children: []
# Word: 'solemus'
#   Head word: 'in'
#   Dependency relation: pobj
#   Explanation: object of preposition
#   Children: ['congressu']
# Word: 'quid'
#   Head word: 'tu'
#   Dependency relation: amod
#   Explanation: adjectival modifier
#   Children: []
# Word: 'tu'
#   Head word: 'quae'
#   Dependency relation: conj
#   Explanation: conjunct
#   Children: ['quid', ',', 'inquit', 'homini', ',', 'praestat']
# Word: ','
#   Head word: 'tu'
#   Dependency relation: punct
#   Explanation: punctuation
#   Children: []
# Word: 'inquit'
#   Head word: 'tu'
#   Dependency relation: appos
#   Explanation: appositional modifier
#   Children: [',']
# Word: ','
#   Head word: 'inquit'
#   Dependency relation: punct
#   Explanation: punctuation
#   Children: []
# Word: 'huc'
#   Head word: 'homini'
#   Dependency relation: compound
#   Explanation: compound
#   Children: []
# Word: 'et'
#   Head word: 'homini'
#   Dependency relation: compound
#   Explanation: compound
#   Children: []
# Word: 'homini'
#   Head word: 'tu'
#   Dependency relation: appos
#   Explanation: appositional modifier
#   Children: ['huc', 'et']
# Word: ','
#   Head word: 'tu'
#   Dependency relation: punct
#   Explanation: punctuation
#   Children: []
# Word: 'qui'
#   Head word: 'praestat'
#   Dependency relation: compound
#   Explanation: compound
#   Children: []
# Word: 'ceteris'
#   Head word: 'praestat'
#   Dependency relation: nmod
#   Explanation: modifier of nominal
#   Children: []
# Word: 'animantibus'
#   Head word: 'praestat'
#   Dependency relation: compound
#   Explanation: compound
#   Children: []
# Word: 'plurimum'
#   Head word: 'praestat'
#   Dependency relation: compound
#   Explanation: compound
#   Children: []
# Word: 'praestat'
#   Head word: 'tu'
#   Dependency relation: appos
#   Explanation: appositional modifier
#   Children: ['qui', 'ceteris', 'animantibus', 'plurimum']
# Word: ','
#   Head word: 'deinde'
#   Dependency relation: punct
#   Explanation: punctuation
#   Children: []
# Word: 'praecipue'
#   Head word: 'deinde'
#   Dependency relation: conj
#   Explanation: conjunct
#   Children: ['absurdum']
# Word: 'a'
#   Head word: 'absurdum'
#   Dependency relation: det
#   Explanation: determiner
#   Children: []
# Word: 'natura'
#   Head word: 'datum'
#   Dependency relation: compound
#   Explanation: compound
#   Children: []
# Word: 'nihil'
#   Head word: 'datum'
#   Dependency relation: compound
#   Explanation: compound
#   Children: []
# Word: 'datum'
#   Head word: 'ipsum'
#   Dependency relation: compound
#   Explanation: compound
#   Children: ['natura', 'nihil']
# Word: 'esse'
#   Head word: 'ipsum'
#   Dependency relation: nmod
#   Explanation: modifier of nominal
#   Children: []
# Word: 'dicemusnniam'
#   Head word: 'ipsum'
#   Dependency relation: nmod
#   Explanation: modifier of nominal
#   Children: []
# Word: 'i'
#   Head word: 'ipsum'
#   Dependency relation: compound
#   Explanation: compound
#   Children: []
# Word: 'd'
#   Head word: 'ipsum'
#   Dependency relation: compound
#   Explanation: compound
#   Children: []
# Word: 'ipsum'
#   Head word: 'absurdum'
#   Dependency relation: compound
#   Explanation: compound
#   Children: ['datum', 'esse', 'dicemusnniam', 'i', 'd']
# Word: 'absurdum'
#   Head word: 'praecipue'
#   Dependency relation: dobj
#   Explanation: direct object
#   Children: ['a', 'ipsum', ',', 'neglegi']
# Word: ','
#   Head word: 'absurdum'
#   Dependency relation: punct
#   Explanation: punctuation
#   Children: []
# Word: 'maximum'
#   Head word: 'malum'
#   Dependency relation: compound
#   Explanation: compound
#   Children: []
# Word: 'malum'
#   Head word: 'neglegi'
#   Dependency relation: compound
#   Explanation: compound
#   Children: ['maximum']
# Word: 'neglegi'
#   Head word: 'absurdum'
#   Dependency relation: conj
#   Explanation: conjunct
#   Children: ['malum']
# Word: '.'
#   Head word: 'deinde'
#   Dependency relation: punct
#   Explanation: punctuation
#   Children: []
# Word: 'quod'
#   Head word: 'fingunt'
#   Dependency relation: compound
#   Explanation: compound
#   Children: []
# Word: 'ea'
#   Head word: 'fingunt'
#   Dependency relation: compound
#   Explanation: compound
#   Children: []
# Word: 'non'
#   Head word: 'fingunt'
#   Dependency relation: compound
#   Explanation: compound
#   Children: []
# Word: 'occurrentia'
#   Head word: 'fingunt'
#   Dependency relation: compound
#   Explanation: compound
#   Children: []
# Word: 'fingunt'
#   Head word: 'fingunt'
#   Dependency relation: ROOT
#   Explanation: root
#   Children: ['quod', 'ea', 'non', 'occurrentia', ',', 'constare', 'corporis', '.']
# Word: ','
#   Head word: 'fingunt'
#   Dependency relation: punct
#   Explanation: punctuation
#   Children: []
# Word: 'vincunt'
#   Head word: 'perspicuum'
#   Dependency relation: compound
#   Explanation: compound
#   Children: []
# Word: 'aristonem'
#   Head word: 'perspicuum'
#   Dependency relation: compound
#   Explanation: compound
#   Children: []
# Word: 'atqui'
#   Head word: 'perspicuum'
#   Dependency relation: compound
#   Explanation: compound
#   Children: []
# Word: 'perspicuum'
#   Head word: 'constare'
#   Dependency relation: compound
#   Explanation: compound
#   Children: ['vincunt', 'aristonem', 'atqui']
# Word: 'est'
#   Head word: 'constare'
#   Dependency relation: compound
#   Explanation: compound
#   Children: []
# Word: 'hominem'
#   Head word: 'constare'
#   Dependency relation: compound
#   Explanation: compound
#   Children: []
# Word: 'e'
#   Head word: 'constare'
#   Dependency relation: compound
#   Explanation: compound
#   Children: []
# Word: 'corpore'
#   Head word: 'constare'
#   Dependency relation: compound
#   Explanation: compound
#   Children: []
# Word: 'animoque'
#   Head word: 'constare'
#   Dependency relation: compound
#   Explanation: compound
#   Children: []
# Word: 'constare'
#   Head word: 'fingunt'
#   Dependency relation: appos
#   Explanation: appositional modifier
#   Children: ['perspicuum', 'est', 'hominem', 'e', 'corpore', 'animoque', ',', 'partes']
# Word: ','
#   Head word: 'constare'
#   Dependency relation: punct
#   Explanation: punctuation
#   Children: []
# Word: 'cum'
#   Head word: 'primae'
#   Dependency relation: compound
#   Explanation: compound
#   Children: []
# Word: 'primae'
#   Head word: 'partes'
#   Dependency relation: compound
#   Explanation: compound
#   Children: ['cum']
# Word: 'sint'
#   Head word: 'partes'
#   Dependency relation: compound
#   Explanation: compound
#   Children: []
# Word: 'animi'
#   Head word: 'partes'
#   Dependency relation: compound
#   Explanation: compound
#   Children: []
# Word: 'partes'
#   Head word: 'constare'
#   Dependency relation: appos
#   Explanation: appositional modifier
#   Children: ['primae', 'sint', 'animi', ',']
# Word: ','
#   Head word: 'partes'
#   Dependency relation: punct
#   Explanation: punctuation
#   Children: []
# Word: 'secundae'
#   Head word: 'corporis'
#   Dependency relation: compound
#   Explanation: compound
#   Children: []
# Word: 'corporis'
#   Head word: 'fingunt'
#   Dependency relation: npadvmod
#   Explanation: noun phrase as adverbial modifier
#   Children: ['secundae']
# Word: '.'
#   Head word: 'fingunt'
#   Dependency relation: punct
#   Explanation: punctuation
#   Children: []
# Word: 'fieri'
#   Head word: 'probes'
#   Dependency relation: nsubj
#   Explanation: nominal subject
#   Children: [',', 'inquam']
# Word: ','
#   Head word: 'fieri'
#   Dependency relation: punct
#   Explanation: punctuation
#   Children: []
# Word: 'inquam'
#   Head word: 'fieri'
#   Dependency relation: conj
#   Explanation: conjunct
#   Children: [',', 'triari']
# Word: ','
#   Head word: 'inquam'
#   Dependency relation: punct
#   Explanation: punctuation
#   Children: []
# Word: 'triari'
#   Head word: 'inquam'
#   Dependency relation: conj
#   Explanation: conjunct
#   Children: [',', 'potest']
# Word: ','
#   Head word: 'triari'
#   Dependency relation: punct
#   Explanation: punctuation
#   Children: []
# Word: 'nullo'
#   Head word: 'potest'
#   Dependency relation: compound
#   Explanation: compound
#   Children: []
# Word: 'pacto'
#   Head word: 'potest'
#   Dependency relation: compound
#   Explanation: compound
#   Children: []
# Word: 'potest'
#   Head word: 'triari'
#   Dependency relation: conj
#   Explanation: conjunct
#   Children: ['nullo', 'pacto', ',', 'dicas']
# Word: ','
#   Head word: 'potest'
#   Dependency relation: punct
#   Explanation: punctuation
#   Children: []
# Word: 'ut'
#   Head word: 'dicas'
#   Dependency relation: compound
#   Explanation: compound
#   Children: []
# Word: 'non'
#   Head word: 'dicas'
#   Dependency relation: compound
#   Explanation: compound
#   Children: []
# Word: 'dicas'
#   Head word: 'potest'
#   Dependency relation: appos
#   Explanation: appositional modifier
#   Children: ['ut', 'non']
# Word: ','
#   Head word: 'probes'
#   Dependency relation: punct
#   Explanation: punctuation
#   Children: []
# Word: 'quid'
#   Head word: 'probes'
#   Dependency relation: nsubj
#   Explanation: nominal subject
#   Children: []
# Word: 'non'
#   Head word: 'probes'
#   Dependency relation: nsubj
#   Explanation: nominal subject
#   Children: []
# Word: 'probes'
#   Head word: 'probes'
#   Dependency relation: ROOT
#   Explanation: root
#   Children: ['fieri', ',', 'quid', 'non', 'eius', '.']
# Word: 'eius'
#   Head word: 'probes'
#   Dependency relation: dobj
#   Explanation: direct object
#   Children: [',', 'dissentias']
# Word: ','
#   Head word: 'eius'
#   Dependency relation: punct
#   Explanation: punctuation
#   Children: []
# Word: 'a'
#   Head word: 'dissentias'
#   Dependency relation: det
#   Explanation: determiner
#   Children: []
# Word: 'quo'
#   Head word: 'dissentias'
#   Dependency relation: compound
#   Explanation: compound
#   Children: []
# Word: 'dissentias'
#   Head word: 'eius'
#   Dependency relation: appos
#   Explanation: appositional modifier
#   Children: ['a', 'quo']
# Word: '.'
#   Head word: 'probes'
#   Dependency relation: punct
#   Explanation: punctuation
#   Children: []
# Word: 'equidem'
#   Head word: 'cn'
#   Dependency relation: compound
#   Explanation: compound
#   Children: []
# Word: 'e'
#   Head word: 'cn'
#   Dependency relation: compound
#   Explanation: compound
#   Children: []
# Word: 'cn'
#   Head word: 'cn'
#   Dependency relation: ROOT
#   Explanation: root
#   Children: ['equidem', 'e', '.']
# Word: '.'
#   Head word: 'cn'
#   Dependency relation: punct
#   Explanation: punctuation
#   Children: []
# Word: 'an'
#   Head word: 'est'
#   Dependency relation: det
#   Explanation: determiner
#   Children: []
# Word: 'dubium'
#   Head word: 'est'
#   Dependency relation: nmod
#   Explanation: modifier of nominal
#   Children: []
# Word: 'est'
#   Head word: 'optineat'
#   Dependency relation: amod
#   Explanation: adjectival modifier
#   Children: ['an', 'dubium', ',']
# Word: ','
#   Head word: 'est'
#   Dependency relation: punct
#   Explanation: punctuation
#   Children: []
# Word: 'quin'
#   Head word: 'virtus'
#   Dependency relation: compound
#   Explanation: compound
#   Children: []
# Word: 'virtus'
#   Head word: 'optineat'
#   Dependency relation: compound
#   Explanation: compound
#   Children: ['quin']
# Word: 'ita'
#   Head word: 'maximam'
#   Dependency relation: compound
#   Explanation: compound
#   Children: []
# Word: 'maximam'
#   Head word: 'partem'
#   Dependency relation: compound
#   Explanation: compound
#   Children: ['ita']
# Word: 'partem'
#   Head word: 'optineat'
#   Dependency relation: compound
#   Explanation: compound
#   Children: ['maximam']
# Word: 'optineat'
#   Head word: 'dies'
#   Dependency relation: advcl
#   Explanation: adverbial clause modifier
#   Children: ['est', 'virtus', 'partem', 'in']
# Word: 'in'
#   Head word: 'optineat'
#   Dependency relation: prep
#   Explanation: prepositional modifier
#   Children: ['humanis']
# Word: 'rebus'
#   Head word: 'humanis'
#   Dependency relation: compound
#   Explanation: compound
#   Children: []
# Word: 'humanis'
#   Head word: 'in'
#   Dependency relation: pobj
#   Explanation: object of preposition
#   Children: ['rebus']
# Word: ','
#   Head word: 'dies'
#   Dependency relation: punct
#   Explanation: punctuation
#   Children: []
# Word: 'ut'
#   Head word: 'istum'
#   Dependency relation: compound
#   Explanation: compound
#   Children: []
# Word: 'reliquas'
#   Head word: 'istum'
#   Dependency relation: compound
#   Explanation: compound
#   Children: []
# Word: 'obruatnnquis'
#   Head word: 'istum'
#   Dependency relation: compound
#   Explanation: compound
#   Children: []
# Word: 'istum'
#   Head word: 'dolorem'
#   Dependency relation: compound
#   Explanation: compound
#   Children: ['ut', 'reliquas', 'obruatnnquis']
# Word: 'dolorem'
#   Head word: 'plures'
#   Dependency relation: amod
#   Explanation: adjectival modifier
#   Children: ['istum']
# Word: 'timetnsummus'
#   Head word: 'dolor'
#   Dependency relation: compound
#   Explanation: compound
#   Children: []
# Word: 'dolor'
#   Head word: 'plures'
#   Dependency relation: compound
#   Explanation: compound
#   Children: ['timetnsummus']
# Word: 'plures'
#   Head word: 'dies'
#   Dependency relation: nsubj
#   Explanation: nominal subject
#   Children: ['dolorem', 'dolor']
# Word: 'dies'
#   Head word: 'dies'
#   Dependency relation: ROOT
#   Explanation: root
#   Children: ['optineat', ',', 'plures', 'manere', 'potest']
# Word: 'manere'
#   Head word: 'dies'
#   Dependency relation: advmod
#   Explanation: adverbial modifier
#   Children: []
# Word: 'non'
#   Head word: 'potest'
#   Dependency relation: compound
#   Explanation: compound
#   Children: []
# Word: 'potest'
#   Head word: 'dies'
#   Dependency relation: dobj
#   Explanation: direct object
#   Children: ['non']
# Word: 'dicet'
#   Head word: 'virtus'
#   Dependency relation: compound
#   Explanation: compound
#   Children: []
# Word: 'pro'
#   Head word: 'virtus'
#   Dependency relation: amod
#   Explanation: adjectival modifier
#   Children: []
# Word: 'me'
#   Head word: 'virtus'
#   Dependency relation: nmod
#   Explanation: modifier of nominal
#   Children: []
# Word: 'ipsa'
#   Head word: 'virtus'
#   Dependency relation: compound
#   Explanation: compound
#   Children: []
# Word: 'virtus'
#   Head word: 'dubitabit'
#   Dependency relation: nsubj
#   Explanation: nominal subject
#   Children: ['dicet', 'pro', 'me', 'ipsa']
# Word: 'nec'
#   Head word: 'dubitabit'
#   Dependency relation: nsubj
#   Explanation: nominal subject
#   Children: []
# Word: 'dubitabit'
#   Head word: 'is'
#   Dependency relation: advcl
#   Explanation: adverbial clause modifier
#   Children: ['virtus', 'nec', 'fuisse']
# Word: 'isti'
#   Head word: 'fuisse'
#   Dependency relation: compound
#   Explanation: compound
#   Children: []
# Word: 'vestro'
#   Head word: 'beato'
#   Dependency relation: compound
#   Explanation: compound
#   Children: []
# Word: 'beato'
#   Head word: 'm.'
#   Dependency relation: compound
#   Explanation: compound
#   Children: ['vestro']
# Word: 'm.'
#   Head word: 'fuisse'
#   Dependency relation: compound
#   Explanation: compound
#   Children: ['beato']
# Word: 'tubulum'
#   Head word: 'fuisse'
#   Dependency relation: compound
#   Explanation: compound
#   Children: []
# Word: 'fuisse'
#   Head word: 'dubitabit'
#   Dependency relation: dobj
#   Explanation: direct object
#   Children: ['isti', 'm.', 'tubulum', ',', 'illum']
# Word: ','
#   Head word: 'fuisse'
#   Dependency relation: punct
#   Explanation: punctuation
#   Children: []
# Word: 'qua'
#   Head word: 'illum'
#   Dependency relation: compound
#   Explanation: compound
#   Children: []
# Word: 'illum'
#   Head word: 'fuisse'
#   Dependency relation: conj
#   Explanation: conjunct
#   Children: ['qua']
# Word: ','
#   Head word: 'is'
#   Dependency relation: punct
#   Explanation: punctuation
#   Children: []
# Word: 'cuius'
#   Head word: 'is'
#   Dependency relation: nsubj
#   Explanation: nominal subject
#   Children: []
# Word: 'is'
#   Head word: 'is'
#   Dependency relation: ROOT
#   Explanation: root
#   Children: ['dubitabit', ',', 'cuius', 'condemnatus', 'est', 'rogatione', ',', 'sit', 'omnis', '.']
# Word: 'condemnatus'
#   Head word: 'is'
#   Dependency relation: attr
#   Explanation: attribute
#   Children: []
# Word: 'est'
#   Head word: 'is'
#   Dependency relation: prep
#   Explanation: prepositional modifier
#   Children: []
# Word: 'rogatione'
#   Head word: 'is'
#   Dependency relation: attr
#   Explanation: attribute
#   Children: []
# Word: ','
#   Head word: 'is'
#   Dependency relation: punct
#   Explanation: punctuation
#   Children: []
# Word: 'p.'
#   Head word: 'ita'
#   Dependency relation: compound
#   Explanation: compound
#   Children: []
# Word: 'quod'
#   Head word: 'ita'
#   Dependency relation: compound
#   Explanation: compound
#   Children: []
# Word: 'si'
#   Head word: 'ita'
#   Dependency relation: compound
#   Explanation: compound
#   Children: []
# Word: 'ita'
#   Head word: 'philosophiae'
#   Dependency relation: nmod
#   Explanation: modifier of nominal
#   Children: ['p.', 'quod', 'si', 'sit']
# Word: 'sit'
#   Head word: 'ita'
#   Dependency relation: appos
#   Explanation: appositional modifier
#   Children: [',']
# Word: ','
#   Head word: 'sit'
#   Dependency relation: punct
#   Explanation: punctuation
#   Children: []
# Word: 'cur'
#   Head word: 'philosophiae'
#   Dependency relation: amod
#   Explanation: adjectival modifier
#   Children: []
# Word: 'opera'
#   Head word: 'philosophiae'
#   Dependency relation: compound
#   Explanation: compound
#   Children: []
# Word: 'philosophiae'
#   Head word: 'sit'
#   Dependency relation: nsubj
#   Explanation: nominal subject
#   Children: ['ita', 'cur', 'opera']
# Word: 'sit'
#   Head word: 'is'
#   Dependency relation: conj
#   Explanation: conjunct
#   Children: ['philosophiae', 'omnis', ',']
# Word: 'danda'
#   Head word: 'nescio.nnex'
#   Dependency relation: compound
#   Explanation: compound
#   Children: []
# Word: 'nescio.nnex'
#   Head word: 'scriptis'
#   Dependency relation: nmod
#   Explanation: modifier of nominal
#   Children: ['danda']
# Word: 'eorum'
#   Head word: 'enim'
#   Dependency relation: compound
#   Explanation: compound
#   Children: []
# Word: 'enim'
#   Head word: 'scriptis'
#   Dependency relation: compound
#   Explanation: compound
#   Children: ['eorum']
# Word: 'scriptis'
#   Head word: 'et'
#   Dependency relation: compound
#   Explanation: compound
#   Children: ['nescio.nnex', 'enim']
# Word: 'et'
#   Head word: 'cum'
#   Dependency relation: compound
#   Explanation: compound
#   Children: ['scriptis']
# Word: 'institutis'
#   Head word: 'cum'
#   Dependency relation: compound
#   Explanation: compound
#   Children: []
# Word: 'cum'
#   Head word: 'omnis'
#   Dependency relation: nsubj
#   Explanation: nominal subject
#   Children: ['et', 'institutis']
# Word: 'omnis'
#   Head word: 'sit'
#   Dependency relation: ccomp
#   Explanation: clausal complement
#   Children: ['cum', 'liberalis']
# Word: 'doctrina'
#   Head word: 'liberalis'
#   Dependency relation: compound
#   Explanation: compound
#   Children: []
# Word: 'liberalis'
#   Head word: 'omnis'
#   Dependency relation: dobj
#   Explanation: direct object
#   Children: ['doctrina']
# Word: ','
#   Head word: 'sit'
#   Dependency relation: punct
#   Explanation: punctuation
#   Children: []
# Word: 'omnis'
#   Head word: 'is'
#   Dependency relation: conj
#   Explanation: conjunct
#   Children: ['ita', 'est', ',', 'ipsum']
# Word: 'historia.nquod'
#   Head word: 'ita'
#   Dependency relation: compound
#   Explanation: compound
#   Children: []
# Word: 'si'
#   Head word: 'ita'
#   Dependency relation: compound
#   Explanation: compound
#   Children: []
# Word: 'ita'
#   Head word: 'omnis'
#   Dependency relation: dobj
#   Explanation: direct object
#   Children: ['historia.nquod', 'si']
# Word: 'est'
#   Head word: 'omnis'
#   Dependency relation: dep
#   Explanation: unclassified dependent
#   Children: []
# Word: ','
#   Head word: 'omnis'
#   Dependency relation: punct
#   Explanation: punctuation
#   Children: []
# Word: 'sequitur'
#   Head word: 'ipsum'
#   Dependency relation: compound
#   Explanation: compound
#   Children: []
# Word: 'i'
#   Head word: 'ipsum'
#   Dependency relation: compound
#   Explanation: compound
#   Children: []
# Word: 'd'
#   Head word: 'ipsum'
#   Dependency relation: compound
#   Explanation: compound
#   Children: []
# Word: 'ipsum'
#   Head word: 'omnis'
#   Dependency relation: conj
#   Explanation: conjunct
#   Children: ['sequitur', 'i', 'd', ',', 'video']
# Word: ','
#   Head word: 'ipsum'
#   Dependency relation: punct
#   Explanation: punctuation
#   Children: []
# Word: 'quod'
#   Head word: 'video'
#   Dependency relation: compound
#   Explanation: compound
#   Children: []
# Word: 'te'
#   Head word: 'video'
#   Dependency relation: nmod
#   Explanation: modifier of nominal
#   Children: []
# Word: 'velle'
#   Head word: 'video'
#   Dependency relation: compound
#   Explanation: compound
#   Children: []
# Word: 'video'
#   Head word: 'ipsum'
#   Dependency relation: conj
#   Explanation: conjunct
#   Children: ['quod', 'te', 'velle', ',', 'sapientes']
# Word: ','
#   Head word: 'video'
#   Dependency relation: punct
#   Explanation: punctuation
#   Children: []
# Word: 'omnes'
#   Head word: 'sapientes'
#   Dependency relation: amod
#   Explanation: adjectival modifier
#   Children: []
# Word: 'semper'
#   Head word: 'sapientes'
#   Dependency relation: compound
#   Explanation: compound
#   Children: []
# Word: 'beatos'
#   Head word: 'esse'
#   Dependency relation: compound
#   Explanation: compound
#   Children: []
# Word: 'esse'
#   Head word: 'sapientes'
#   Dependency relation: compound
#   Explanation: compound
#   Children: ['beatos']
# Word: 'sapientes'
#   Head word: 'video'
#   Dependency relation: conj
#   Explanation: conjunct
#   Children: ['omnes', 'semper', 'esse']
# Word: '.'
#   Head word: 'is'
#   Dependency relation: punct
#   Explanation: punctuation
#   Children: []
# Word: 'cum'
#   Head word: 'enim'
#   Dependency relation: compound
#   Explanation: compound
#   Children: []
# Word: 'enim'
#   Head word: 'quasi'
#   Dependency relation: compound
#   Explanation: compound
#   Children: ['cum']
# Word: 'fertur'
#   Head word: 'quasi'
#   Dependency relation: compound
#   Explanation: compound
#   Children: []
# Word: 'quasi'
#   Head word: 'oratio'
#   Dependency relation: compound
#   Explanation: compound
#   Children: ['enim', 'fertur']
# Word: 'torrens'
#   Head word: 'oratio'
#   Dependency relation: compound
#   Explanation: compound
#   Children: []
# Word: 'oratio'
#   Head word: 'modi'
#   Dependency relation: nsubj
#   Explanation: nominal subject
#   Children: ['quasi', 'torrens', ',']
# Word: ','
#   Head word: 'oratio'
#   Dependency relation: punct
#   Explanation: punctuation
#   Children: []
# Word: 'quamvis'
#   Head word: 'cuiusque'
#   Dependency relation: compound
#   Explanation: compound
#   Children: []
# Word: 'multa'
#   Head word: 'cuiusque'
#   Dependency relation: compound
#   Explanation: compound
#   Children: []
# Word: 'cuiusque'
#   Head word: 'modi'
#   Dependency relation: nsubj
#   Explanation: nominal subject
#   Children: ['quamvis', 'multa']
# Word: 'modi'
#   Head word: 'modi'
#   Dependency relation: ROOT
#   Explanation: root
#   Children: ['oratio', 'cuiusque', 'rapiat', ',', 'teneas', '.']
# Word: 'rapiat'
#   Head word: 'modi'
#   Dependency relation: dobj
#   Explanation: direct object
#   Children: []
# Word: ','
#   Head word: 'modi'
#   Dependency relation: punct
#   Explanation: punctuation
#   Children: []
# Word: 'nihil'
#   Head word: 'teneas'
#   Dependency relation: compound
#   Explanation: compound
#   Children: []
# Word: 'tamen'
#   Head word: 'teneas'
#   Dependency relation: compound
#   Explanation: compound
#   Children: []
# Word: 'teneas'
#   Head word: 'modi'
#   Dependency relation: conj
#   Explanation: conjunct
#   Children: ['nihil', 'tamen', ',', 'apprehendas']
# Word: ','
#   Head word: 'teneas'
#   Dependency relation: punct
#   Explanation: punctuation
#   Children: []
# Word: 'nihil'
#   Head word: 'apprehendas'
#   Dependency relation: compound
#   Explanation: compound
#   Children: []
# Word: 'apprehendas'
#   Head word: 'teneas'
#   Dependency relation: conj
#   Explanation: conjunct
#   Children: ['nihil', ',', 'coerceas']
# Word: ','
#   Head word: 'apprehendas'
#   Dependency relation: punct
#   Explanation: punctuation
#   Children: []
# Word: 'nusquam'
#   Head word: 'orationem'
#   Dependency relation: compound
#   Explanation: compound
#   Children: []
# Word: 'orationem'
#   Head word: 'coerceas'
#   Dependency relation: nmod
#   Explanation: modifier of nominal
#   Children: ['nusquam']
# Word: 'rapidam'
#   Head word: 'coerceas'
#   Dependency relation: amod
#   Explanation: adjectival modifier
#   Children: []
# Word: 'coerceas'
#   Head word: 'apprehendas'
#   Dependency relation: conj
#   Explanation: conjunct
#   Children: ['orationem', 'rapidam']
# Word: '.'
#   Head word: 'modi'
#   Dependency relation: punct
#   Explanation: punctuation
#   Children: []
# Word: 'ita'
#   Head word: 'redarguitur'
#   Dependency relation: compound
#   Explanation: compound
#   Children: []
# Word: 'redarguitur'
#   Head word: 'ipse'
#   Dependency relation: nsubj
#   Explanation: nominal subject
#   Children: ['ita']
# Word: 'ipse'
#   Head word: 'ipse'
#   Dependency relation: ROOT
#   Explanation: root
#   Children: ['redarguitur', 'sese', ',', 'probitate', '.']
# Word: 'a'
#   Head word: 'sese'
#   Dependency relation: det
#   Explanation: determiner
#   Children: []
# Word: 'sese'
#   Head word: 'ipse'
#   Dependency relation: dobj
#   Explanation: direct object
#   Children: ['a']
# Word: ','
#   Head word: 'ipse'
#   Dependency relation: punct
#   Explanation: punctuation
#   Children: []
# Word: 'convincunturque'
#   Head word: 'scripta'
#   Dependency relation: compound
#   Explanation: compound
#   Children: []
# Word: 'scripta'
#   Head word: 'eius'
#   Dependency relation: compound
#   Explanation: compound
#   Children: ['convincunturque']
# Word: 'eius'
#   Head word: 'probitate'
#   Dependency relation: nsubj
#   Explanation: nominal subject
#   Children: ['scripta']
# Word: 'probitate'
#   Head word: 'ipse'
#   Dependency relation: conj
#   Explanation: conjunct
#   Children: ['eius', 'moribus']
# Word: 'ipsius'
#   Head word: 'moribus'
#   Dependency relation: compound
#   Explanation: compound
#   Children: []
# Word: 'ac'
#   Head word: 'moribus'
#   Dependency relation: compound
#   Explanation: compound
#   Children: []
# Word: 'moribus'
#   Head word: 'probitate'
#   Dependency relation: dobj
#   Explanation: direct object
#   Children: ['ipsius', 'ac']
# Word: '.'
#   Head word: 'ipse'
#   Dependency relation: punct
#   Explanation: punctuation
#   Children: []
# Word: 'at'
#   Head word: 'incendi'
#   Dependency relation: prep
#   Explanation: prepositional modifier
#   Children: ['conantur']
# Word: 'quanta'
#   Head word: 'conantur'
#   Dependency relation: compound
#   Explanation: compound
#   Children: []
# Word: 'conantur'
#   Head word: 'at'
#   Dependency relation: pobj
#   Explanation: object of preposition
#   Children: ['quanta']
# Word: 'mundum'
#   Head word: 'esse'
#   Dependency relation: compound
#   Explanation: compound
#   Children: []
# Word: 'hunc'
#   Head word: 'esse'
#   Dependency relation: compound
#   Explanation: compound
#   Children: []
# Word: 'omnem'
#   Head word: 'esse'
#   Dependency relation: compound
#   Explanation: compound
#   Children: []
# Word: 'oppidum'
#   Head word: 'esse'
#   Dependency relation: compound
#   Explanation: compound
#   Children: []
# Word: 'esse'
#   Head word: 'nostrum'
#   Dependency relation: compound
#   Explanation: compound
#   Children: ['mundum', 'hunc', 'omnem', 'oppidum']
# Word: 'nostrum'
#   Head word: 'incendi'
#   Dependency relation: nsubj
#   Explanation: nominal subject
#   Children: ['esse']
# Word: 'incendi'
#   Head word: 'incendi'
#   Dependency relation: ROOT
#   Explanation: root
#   Children: ['at', 'nostrum', 'eos', 'vides', '.']
# Word: 'igitur'
#   Head word: 'eos'
#   Dependency relation: compound
#   Explanation: compound
#   Children: []
# Word: 'eos'
#   Head word: 'incendi'
#   Dependency relation: dobj
#   Explanation: direct object
#   Children: ['igitur', ',', 'audiunt', ',']
# Word: ','
#   Head word: 'eos'
#   Dependency relation: punct
#   Explanation: punctuation
#   Children: []
# Word: 'qui'
#   Head word: 'audiunt'
#   Dependency relation: compound
#   Explanation: compound
#   Children: []
# Word: 'audiunt'
#   Head word: 'eos'
#   Dependency relation: appos
#   Explanation: appositional modifier
#   Children: ['qui']
# Word: ','
#   Head word: 'eos'
#   Dependency relation: punct
#   Explanation: punctuation
#   Children: []
# Word: 'vides'
#   Head word: 'incendi'
#   Dependency relation: conj
#   Explanation: conjunct
#   Children: []
# Word: '.'
#   Head word: 'incendi'
#   Dependency relation: punct
#   Explanation: punctuation
#   Children: []
# Word: 'vide'
#   Head word: 'vide'
#   Dependency relation: ROOT
#   Explanation: root
#   Children: [',', 'magis', 'cum', ',', 'mihi', '.']
# Word: ','
#   Head word: 'vide'
#   Dependency relation: punct
#   Explanation: punctuation
#   Children: []
# Word: 'ne'
#   Head word: 'magis'
#   Dependency relation: compound
#   Explanation: compound
#   Children: []
# Word: 'magis'
#   Head word: 'vide'
#   Dependency relation: conj
#   Explanation: conjunct
#   Children: ['ne', ',', 'inquam']
# Word: ','
#   Head word: 'magis'
#   Dependency relation: punct
#   Explanation: punctuation
#   Children: []
# Word: 'inquam'
#   Head word: 'magis'
#   Dependency relation: conj
#   Explanation: conjunct
#   Children: [',', 'fuerit']
# Word: ','
#   Head word: 'inquam'
#   Dependency relation: punct
#   Explanation: punctuation
#   Children: []
# Word: 'tuum'
#   Head word: 'fuerit'
#   Dependency relation: compound
#   Explanation: compound
#   Children: []
# Word: 'fuerit'
#   Head word: 'inquam'
#   Dependency relation: conj
#   Explanation: conjunct
#   Children: ['tuum', ',']
# Word: ','
#   Head word: 'fuerit'
#   Dependency relation: punct
#   Explanation: punctuation
#   Children: []
# Word: 'cum'
#   Head word: 'vide'
#   Dependency relation: appos
#   Explanation: appositional modifier
#   Children: ['re']
# Word: 're'
#   Head word: 'cum'
#   Dependency relation: prep
#   Explanation: prepositional modifier
#   Children: ['tibi']
# Word: 'idem'
#   Head word: 'tibi'
#   Dependency relation: compound
#   Explanation: compound
#   Children: []
# Word: 'tibi'
#   Head word: 're'
#   Dependency relation: pobj
#   Explanation: object of preposition
#   Children: ['idem']
# Word: ','
#   Head word: 'vide'
#   Dependency relation: punct
#   Explanation: punctuation
#   Children: []
# Word: 'quod'
#   Head word: 'mihi'
#   Dependency relation: compound
#   Explanation: compound
#   Children: []
# Word: 'mihi'
#   Head word: 'vide'
#   Dependency relation: conj
#   Explanation: conjunct
#   Children: ['quod', ',', 'videretur', ',', 'nomina']
# Word: ','
#   Head word: 'mihi'
#   Dependency relation: punct
#   Explanation: punctuation
#   Children: []
# Word: 'videretur'
#   Head word: 'mihi'
#   Dependency relation: appos
#   Explanation: appositional modifier
#   Children: []
# Word: ','
#   Head word: 'mihi'
#   Dependency relation: punct
#   Explanation: punctuation
#   Children: []
# Word: 'non'
#   Head word: 'nomina'
#   Dependency relation: compound
#   Explanation: compound
#   Children: []
# Word: 'nova'
#   Head word: 'nomina'
#   Dependency relation: compound
#   Explanation: compound
#   Children: []
# Word: 'te'
#   Head word: 'nomina'
#   Dependency relation: compound
#   Explanation: compound
#   Children: []
# Word: 'rebus'
#   Head word: 'nomina'
#   Dependency relation: compound
#   Explanation: compound
#   Children: []
# Word: 'nomina'
#   Head word: 'mihi'
#   Dependency relation: appos
#   Explanation: appositional modifier
#   Children: ['non', 'nova', 'te', 'rebus', 'inponere']
# Word: 'inponere'
#   Head word: 'nomina'
#   Dependency relation: advmod
#   Explanation: adverbial modifier
#   Children: []
# Word: '.'
#   Head word: 'vide'
#   Dependency relation: punct
#   Explanation: punctuation
#   Children: []
# Word: 'quivere'
#   Head word: 'falsone'
#   Dependency relation: advmod
#   Explanation: adverbial modifier
#   Children: []
# Word: 'falsone'
#   Head word: 'falsone'
#   Dependency relation: ROOT
#   Explanation: root
#   Children: ['quivere', ',', 'sunt', ',', 'in', 'satis', '.']
# Word: ','
#   Head word: 'falsone'
#   Dependency relation: punct
#   Explanation: punctuation
#   Children: []
# Word: 'quaerere'
#   Head word: 'sunt'
#   Dependency relation: advmod
#   Explanation: adverbial modifier
#   Children: []
# Word: 'mittimusdicitur'
#   Head word: 'oculis'
#   Dependency relation: compound
#   Explanation: compound
#   Children: []
# Word: 'oculis'
#   Head word: 'sunt'
#   Dependency relation: nmod
#   Explanation: modifier of nominal
#   Children: ['mittimusdicitur']
# Word: 'se'
#   Head word: 'privasse'
#   Dependency relation: nmod
#   Explanation: modifier of nominal
#   Children: []
# Word: 'privasse'
#   Head word: 'sunt'
#   Dependency relation: amod
#   Explanation: adjectival modifier
#   Children: ['se']
# Word: 'si'
#   Head word: 'ista'
#   Dependency relation: compound
#   Explanation: compound
#   Children: []
# Word: 'ista'
#   Head word: 'sunt'
#   Dependency relation: compound
#   Explanation: compound
#   Children: ['si']
# Word: 'mala'
#   Head word: 'sunt'
#   Dependency relation: compound
#   Explanation: compound
#   Children: []
# Word: 'sunt'
#   Head word: 'falsone'
#   Dependency relation: appos
#   Explanation: appositional modifier
#   Children: ['quaerere', 'oculis', 'privasse', 'ista', 'mala']
# Word: ','
#   Head word: 'falsone'
#   Dependency relation: punct
#   Explanation: punctuation
#   Children: []
# Word: 'in'
#   Head word: 'falsone'
#   Dependency relation: prep
#   Explanation: prepositional modifier
#   Children: ['sapiens']
# Word: 'quae'
#   Head word: 'sapiens'
#   Dependency relation: compound
#   Explanation: compound
#   Children: []
# Word: 'potest'
#   Head word: 'sapiens'
#   Dependency relation: compound
#   Explanation: compound
#   Children: []
# Word: 'incidere'
#   Head word: 'sapiens'
#   Dependency relation: compound
#   Explanation: compound
#   Children: []
# Word: 'sapiens'
#   Head word: 'in'
#   Dependency relation: pobj
#   Explanation: object of preposition
#   Children: ['quae', 'potest', 'incidere']
# Word: ','
#   Head word: 'satis'
#   Dependency relation: punct
#   Explanation: punctuation
#   Children: []
# Word: 'sapientem'
#   Head word: 'esse'
#   Dependency relation: compound
#   Explanation: compound
#   Children: []
# Word: 'esse'
#   Head word: 'satis'
#   Dependency relation: nmod
#   Explanation: modifier of nominal
#   Children: ['sapientem']
# Word: 'non'
#   Head word: 'esse'
#   Dependency relation: compound
#   Explanation: compound
#   Children: []
# Word: 'esse'
#   Head word: 'satis'
#   Dependency relation: compound
#   Explanation: compound
#   Children: ['non']
# Word: 'ad'
#   Head word: 'vivendum'
#   Dependency relation: compound
#   Explanation: compound
#   Children: []
# Word: 'beate'
#   Head word: 'vivendum'
#   Dependency relation: compound
#   Explanation: compound
#   Children: []
# Word: 'vivendum'
#   Head word: 'satis'
#   Dependency relation: compound
#   Explanation: compound
#   Children: ['ad', 'beate']
# Word: 'satis'
#   Head word: 'falsone'
#   Dependency relation: npadvmod
#   Explanation: noun phrase as adverbial modifier
#   Children: [',', 'esse', 'esse', 'vivendum']
# Word: '.'
#   Head word: 'falsone'
#   Dependency relation: punct
#   Explanation: punctuation
#   Children: []
# Word: 'at'
#   Head word: 'abducas'
#   Dependency relation: prep
#   Explanation: prepositional modifier
#   Children: ['accesserit']
# Word: 'vero'
#   Head word: 'accesserit'
#   Dependency relation: compound
#   Explanation: compound
#   Children: []
# Word: 'si'
#   Head word: 'accesserit'
#   Dependency relation: compound
#   Explanation: compound
#   Children: []
# Word: 'ad'
#   Head word: 'vitem'
#   Dependency relation: compound
#   Explanation: compound
#   Children: []
# Word: 'vitem'
#   Head word: 'accesserit'
#   Dependency relation: compound
#   Explanation: compound
#   Children: ['ad']
# Word: 'sensus'
#   Head word: 'accesserit'
#   Dependency relation: compound
#   Explanation: compound
#   Children: []
# Word: 'accesserit'
#   Head word: 'at'
#   Dependency relation: pobj
#   Explanation: object of preposition
#   Children: ['vero', 'si', 'vitem', 'sensus']
# Word: ','
#   Head word: 'abducas'
#   Dependency relation: punct
#   Explanation: punctuation
#   Children: []
# Word: 'ut'
#   Head word: 'et'
#   Dependency relation: compound
#   Explanation: compound
#   Children: []
# Word: 'appetitum'
#   Head word: 'et'
#   Dependency relation: compound
#   Explanation: compound
#   Children: []
# Word: 'quendam'
#   Head word: 'et'
#   Dependency relation: compound
#   Explanation: compound
#   Children: []
# Word: 'habeat'
#   Head word: 'et'
#   Dependency relation: compound
#   Explanation: compound
#   Children: []
# Word: 'et'
#   Head word: 'moveatur'
#   Dependency relation: compound
#   Explanation: compound
#   Children: ['ut', 'appetitum', 'quendam', 'habeat']
# Word: 'per'
#   Head word: 'moveatur'
#   Dependency relation: nmod
#   Explanation: modifier of nominal
#   Children: ['se']
# Word: 'se'
#   Head word: 'per'
#   Dependency relation: pobj
#   Explanation: object of preposition
#   Children: []
# Word: 'ipsa'
#   Head word: 'moveatur'
#   Dependency relation: compound
#   Explanation: compound
#   Children: []
# Word: 'moveatur'
#   Head word: 'sed'
#   Dependency relation: nsubj
#   Explanation: nominal subject
#   Children: ['et', 'per', 'ipsa', ',', 'tenueris', ',']
# Word: ','
#   Head word: 'moveatur'
#   Dependency relation: punct
#   Explanation: punctuation
#   Children: []
# Word: 'quid'
#   Head word: 'putasnnquem'
#   Dependency relation: amod
#   Explanation: adjectival modifier
#   Children: []
# Word: 'facturam'
#   Head word: 'putasnnquem'
#   Dependency relation: compound
#   Explanation: compound
#   Children: []
# Word: 'putasnnquem'
#   Head word: 'tenueris'
#   Dependency relation: compound
#   Explanation: compound
#   Children: ['quid', 'facturam']
# Word: 'si'
#   Head word: 'tenueris'
#   Dependency relation: compound
#   Explanation: compound
#   Children: []
# Word: 'tenueris'
#   Head word: 'moveatur'
#   Dependency relation: conj
#   Explanation: conjunct
#   Children: ['putasnnquem', 'si', ',', 'ciceronem']
# Word: ','
#   Head word: 'tenueris'
#   Dependency relation: punct
#   Explanation: punctuation
#   Children: []
# Word: 'non'
#   Head word: 'ciceronem'
#   Dependency relation: compound
#   Explanation: compound
#   Children: []
# Word: 'modo'
#   Head word: 'ciceronem'
#   Dependency relation: compound
#   Explanation: compound
#   Children: []
# Word: 'meum'
#   Head word: 'ciceronem'
#   Dependency relation: compound
#   Explanation: compound
#   Children: []
# Word: 'ciceronem'
#   Head word: 'tenueris'
#   Dependency relation: conj
#   Explanation: conjunct
#   Children: ['non', 'modo', 'meum']
# Word: ','
#   Head word: 'moveatur'
#   Dependency relation: punct
#   Explanation: punctuation
#   Children: []
# Word: 'sed'
#   Head word: 'ipsum'
#   Dependency relation: amod
#   Explanation: adjectival modifier
#   Children: ['moveatur', 'etiam']
# Word: 'etiam'
#   Head word: 'sed'
#   Dependency relation: dobj
#   Explanation: direct object
#   Children: []
# Word: 'me'
#   Head word: 'ipsum'
#   Dependency relation: compound
#   Explanation: compound
#   Children: []
# Word: 'ipsum'
#   Head word: 'abducas'
#   Dependency relation: nsubj
#   Explanation: nominal subject
#   Children: ['sed', 'me']
# Word: 'abducas'
#   Head word: 'abducas'
#   Dependency relation: ROOT
#   Explanation: root
#   Children: ['at', ',', 'ipsum', 'autem', 'torquentur', ',', 'oblita', 'res', 'est', 'habere', ',', 'diceret', 'deinde', '.']
# Word: 'licebit.nstulti'
#   Head word: 'autem'
#   Dependency relation: compound
#   Explanation: compound
#   Children: []
# Word: 'autem'
#   Head word: 'abducas'
#   Dependency relation: dobj
#   Explanation: direct object
#   Children: ['licebit.nstulti']
# Word: 'malorum'
#   Head word: 'torquentur'
#   Dependency relation: compound
#   Explanation: compound
#   Children: []
# Word: 'memoria'
#   Head word: 'torquentur'
#   Dependency relation: compound
#   Explanation: compound
#   Children: []
# Word: 'torquentur'
#   Head word: 'abducas'
# ...
#   Children: ['promptu']
# Word: 'promptu'
#   Head word: 'in'
#   Dependency relation: pobj
#   Explanation: object of preposition
#   Children: [',', 'audivi']
# Word: ','
#   Head word: 'promptu'
#   Dependency relation: punct
#   Explanation: punctuation
#   Children: []
# Word: 'quae'
#   Head word: 'audivi'
#   Dependency relation: compound
#   Explanation: compound
#   Children: []
# Word: 'modo'
#   Head word: 'audivi'
#   Dependency relation: compound
#   Explanation: compound
#   Children: []
# Word: 'audivi'
#   Head word: 'promptu'
#   Dependency relation: conj
#   Explanation: conjunct
#   Children: ['quae', 'modo', ',', 'aggrediar']
# Word: ','
#   Head word: 'audivi'
#   Dependency relation: punct
#   Explanation: punctuation
#   Children: []
# Word: 'nec'
#   Head word: 'aggrediar'
#   Dependency relation: compound
#   Explanation: compound
#   Children: []
# Word: 'ante'
#   Head word: 'aggrediar'
#   Dependency relation: compound
#   Explanation: compound
#   Children: []
# Word: 'aggrediar'
#   Head word: 'audivi'
#   Dependency relation: conj
#   Explanation: conjunct
#   Children: ['nec', 'ante', ',', 'istis']
# Word: ','
#   Head word: 'aggrediar'
#   Dependency relation: punct
#   Explanation: punctuation
#   Children: []
# Word: 'quam'
#   Head word: 'istis'
#   Dependency relation: compound
#   Explanation: compound
#   Children: []
# Word: 'te'
#   Head word: 'istis'
#   Dependency relation: compound
#   Explanation: compound
#   Children: []
# Word: 'ab'
#   Head word: 'istis'
#   Dependency relation: compound
#   Explanation: compound
#   Children: []
# Word: 'istis'
#   Head word: 'aggrediar'
#   Dependency relation: conj
#   Explanation: conjunct
#   Children: ['quam', 'te', 'ab', ',', 'dicis']
# Word: ','
#   Head word: 'istis'
#   Dependency relation: punct
#   Explanation: punctuation
#   Children: []
# Word: 'quos'
#   Head word: 'dicis'
#   Dependency relation: compound
#   Explanation: compound
#   Children: []
# Word: 'dicis'
#   Head word: 'istis'
#   Dependency relation: conj
#   Explanation: conjunct
#   Children: ['quos', ',', 'videro']
# Word: ','
#   Head word: 'dicis'
#   Dependency relation: punct
#   Explanation: punctuation
#   Children: []
# Word: 'instructum'
#   Head word: 'videro'
#   Dependency relation: amod
#   Explanation: adjectival modifier
#   Children: []
# Word: 'videro'
#   Head word: 'dicis'
#   Dependency relation: conj
#   Explanation: conjunct
#   Children: ['instructum']
# Word: '.'
#   Head word: 'erunt'
#   Dependency relation: punct
#   Explanation: punctuation
#   Children: []
# Word: 'fatebuntur'
#   Head word: 'haec'
#   Dependency relation: compound
#   Explanation: compound
#   Children: []
# Word: 'stoici'
#   Head word: 'haec'
#   Dependency relation: compound
#   Explanation: compound
#   Children: []
# Word: 'haec'
#   Head word: 'praeclare'
#   Dependency relation: compound
#   Explanation: compound
#   Children: ['fatebuntur', 'stoici']
# Word: 'omnia'
#   Head word: 'praeclare'
#   Dependency relation: compound
#   Explanation: compound
#   Children: []
# Word: 'dicta'
#   Head word: 'praeclare'
#   Dependency relation: compound
#   Explanation: compound
#   Children: []
# Word: 'esse'
#   Head word: 'praeclare'
#   Dependency relation: compound
#   Explanation: compound
#   Children: []
# Word: 'praeclare'
#   Head word: 'praeclare'
#   Dependency relation: ROOT
#   Explanation: root
#   Children: ['haec', 'omnia', 'dicta', 'esse', ',', 'fuisse', '.']
# Word: ','
#   Head word: 'praeclare'
#   Dependency relation: punct
#   Explanation: punctuation
#   Children: []
# Word: 'neque'
#   Head word: 'fuisse'
#   Dependency relation: compound
#   Explanation: compound
#   Children: []
# Word: 'eam'
#   Head word: 'fuisse'
#   Dependency relation: compound
#   Explanation: compound
#   Children: []
# Word: 'causam'
#   Head word: 'zenoni'
#   Dependency relation: compound
#   Explanation: compound
#   Children: []
# Word: 'zenoni'
#   Head word: 'fuisse'
#   Dependency relation: compound
#   Explanation: compound
#   Children: ['causam']
# Word: 'desciscendi'
#   Head word: 'fuisse'
#   Dependency relation: compound
#   Explanation: compound
#   Children: []
# Word: 'fuisse'
#   Head word: 'praeclare'
#   Dependency relation: conj
#   Explanation: conjunct
#   Children: ['neque', 'eam', 'zenoni', 'desciscendi']
# Word: '.'
#   Head word: 'praeclare'
#   Dependency relation: punct
#   Explanation: punctuation
#   Children: []
# Word: 'non'
#   Head word: 'autem'
#   Dependency relation: compound
#   Explanation: compound
#   Children: []
# Word: 'autem'
#   Head word: 'igitur'
#   Dependency relation: dep
#   Explanation: unclassified dependent
#   Children: ['non']
# Word: 'hoc'
#   Head word: 'igitur'
#   Dependency relation: compound
#   Explanation: compound
#   Children: []
# Word: 'igitur'
#   Head word: 'quidem'
#   Dependency relation: nsubj
#   Explanation: nominal subject
#   Children: ['autem', 'hoc', 'ne']
# Word: 'ne'
#   Head word: 'igitur'
#   Dependency relation: punct
#   Explanation: punctuation
#   Children: []
# Word: 'illud'
#   Head word: 'quidem'
#   Dependency relation: compound
#   Explanation: compound
#   Children: []
# Word: 'quidem'
#   Head word: 'quidem'
#   Dependency relation: ROOT
#   Explanation: root
#   Children: ['igitur', 'illud', '.']
# Word: '.'
#   Head word: 'quidem'
#   Dependency relation: punct
#   Explanation: punctuation
#   Children: []
# Word: 'ratio'
#   Head word: 'cogit'
#   Dependency relation: compound
#   Explanation: compound
#   Children: []
# Word: 'quidem'
#   Head word: 'cogit'
#   Dependency relation: compound
#   Explanation: compound
#   Children: []
# Word: 'vestra'
#   Head word: 'cogit'
#   Dependency relation: compound
#   Explanation: compound
#   Children: []
# Word: 'sic'
#   Head word: 'cogit'
#   Dependency relation: compound
#   Explanation: compound
#   Children: []
# Word: 'cogit'
#   Head word: 'cogit'
#   Dependency relation: ROOT
#   Explanation: root
#   Children: ['ratio', 'quidem', 'vestra', 'sic', '.']
# Word: '.'
#   Head word: 'cogit'
#   Dependency relation: punct
#   Explanation: punctuation
#   Children: []
# Word: 'cum'
#   Head word: 'audissem'
#   Dependency relation: compound
#   Explanation: compound
#   Children: []
# Word: 'audissem'
#   Head word: 'antiochum'
#   Dependency relation: compound
#   Explanation: compound
#   Children: ['cum']
# Word: 'antiochum'
#   Head word: 'iucundenhaec'
#   Dependency relation: nsubj
#   Explanation: nominal subject
#   Children: ['audissem', ',', 'brute', 'm.', ',', 'voluptatesnnidemne']
# Word: ','
#   Head word: 'antiochum'
#   Dependency relation: punct
#   Explanation: punctuation
#   Children: []
# Word: 'brute'
#   Head word: 'antiochum'
#   Dependency relation: conj
#   Explanation: conjunct
#   Children: [',', 'ut']
# Word: ','
#   Head word: 'brute'
#   Dependency relation: punct
#   Explanation: punctuation
#   Children: []
# Word: 'ut'
#   Head word: 'brute'
#   Dependency relation: conj
#   Explanation: conjunct
#   Children: ['solebam']
# Word: 'solebam'
#   Head word: 'ut'
#   Dependency relation: pobj
#   Explanation: object of preposition
#   Children: [',']
# Word: ','
#   Head word: 'solebam'
#   Dependency relation: punct
#   Explanation: punctuation
#   Children: []
# Word: 'cum'
#   Head word: 'm.'
#   Dependency relation: compound
#   Explanation: compound
#   Children: []
# Word: 'm.'
#   Head word: 'antiochum'
#   Dependency relation: appos
#   Explanation: appositional modifier
#   Children: ['cum', 'callida']
# Word: 'an'
#   Head word: 'callida'
#   Dependency relation: det
#   Explanation: determiner
#   Children: []
# Word: 'quod'
#   Head word: 'ita'
#   Dependency relation: compound
#   Explanation: compound
#   Children: []
# Word: 'ita'
#   Head word: 'callida'
#   Dependency relation: compound
#   Explanation: compound
#   Children: ['quod']
# Word: 'callida'
#   Head word: 'm.'
#   Dependency relation: npadvmod
#   Explanation: noun phrase as adverbial modifier
#   Children: ['an', 'ita', 'est']
# Word: 'est'
#   Head word: 'callida'
#   Dependency relation: nummod
#   Explanation: numeric modifier
#   Children: []
# Word: ','
#   Head word: 'antiochum'
#   Dependency relation: punct
#   Explanation: punctuation
#   Children: []
# Word: 'ut'
#   Head word: 'voluptatesnnidemne'
#   Dependency relation: advmod
#   Explanation: adverbial modifier
#   Children: []
# Word: 'optime'
#   Head word: 'possit'
#   Dependency relation: amod
#   Explanation: adjectival modifier
#   Children: []
# Word: 'possit'
#   Head word: 'voluptatesnnidemne'
#   Dependency relation: compound
#   Explanation: compound
#   Children: ['optime']
# Word: 'architectari'
#   Head word: 'voluptatesnnidemne'
#   Dependency relation: compound
#   Explanation: compound
#   Children: []
# Word: 'voluptatesnnidemne'
#   Head word: 'antiochum'
#   Dependency relation: appos
#   Explanation: appositional modifier
#   Children: ['ut', 'possit', 'architectari']
# Word: ','
#   Head word: 'iucundenhaec'
#   Dependency relation: punct
#   Explanation: punctuation
#   Children: []
# Word: 'quod'
#   Head word: 'iucundenhaec'
#   Dependency relation: nsubj
#   Explanation: nominal subject
#   Children: []
# Word: 'iucundenhaec'
#   Head word: 'iucundenhaec'
#   Dependency relation: ROOT
#   Explanation: root
#   Children: ['antiochum', ',', 'quod', 'delicatior', ',', 'dicam', '.']
# Word: 'mihi'
#   Head word: 'videtur'
#   Dependency relation: compound
#   Explanation: compound
#   Children: []
# Word: 'videtur'
#   Head word: 'delicatior'
#   Dependency relation: compound
#   Explanation: compound
#   Children: ['mihi']
# Word: 'delicatior'
#   Head word: 'iucundenhaec'
#   Dependency relation: dobj
#   Explanation: direct object
#   Children: ['videtur']
# Word: ','
#   Head word: 'iucundenhaec'
#   Dependency relation: punct
#   Explanation: punctuation
#   Children: []
# Word: 'ut'
#   Head word: 'dicam'
#   Dependency relation: compound
#   Explanation: compound
#   Children: []
# Word: 'ita'
#   Head word: 'dicam'
#   Dependency relation: compound
#   Explanation: compound
#   Children: []
# Word: 'dicam'
#   Head word: 'iucundenhaec'
#   Dependency relation: dobj
#   Explanation: direct object
#   Children: ['ut', 'ita', ',', 'ratio']
# Word: ','
#   Head word: 'dicam'
#   Dependency relation: punct
#   Explanation: punctuation
#   Children: []
# Word: 'molliorque'
#   Head word: 'ratio'
#   Dependency relation: compound
#   Explanation: compound
#   Children: []
# Word: 'ratio'
#   Head word: 'dicam'
#   Dependency relation: conj
#   Explanation: conjunct
#   Children: ['molliorque', ',', 'virtutis']
# Word: ','
#   Head word: 'ratio'
#   Dependency relation: punct
#   Explanation: punctuation
#   Children: []
# Word: 'quam'
#   Head word: 'virtutis'
#   Dependency relation: compound
#   Explanation: compound
#   Children: []
# Word: 'virtutis'
#   Head word: 'ratio'
#   Dependency relation: conj
#   Explanation: conjunct
#   Children: ['quam', 'vis']
# Word: 'vis'
#   Head word: 'virtutis'
#   Dependency relation: prep
#   Explanation: prepositional modifier
#   Children: ['postulat']
# Word: 'gravitasque'
#   Head word: 'postulat'
#   Dependency relation: amod
#   Explanation: adjectival modifier
#   Children: []
# Word: 'postulat'
#   Head word: 'vis'
#   Dependency relation: pobj
#   Explanation: object of preposition
#   Children: ['gravitasque']
# Word: '.'
#   Head word: 'iucundenhaec'
#   Dependency relation: punct
#   Explanation: punctuation
#   Children: []
# Word: 'sed'
#   Head word: 'est'
#   Dependency relation: amod
#   Explanation: adjectival modifier
#   Children: []
# Word: 'quoniam'
#   Head word: 'est'
#   Dependency relation: compound
#   Explanation: compound
#   Children: []
# Word: 'et'
#   Head word: 'est'
#   Dependency relation: compound
#   Explanation: compound
#   Children: []
# Word: 'advesperascit'
#   Head word: 'mihi'
#   Dependency relation: compound
#   Explanation: compound
#   Children: []
# Word: 'et'
#   Head word: 'mihi'
#   Dependency relation: compound
#   Explanation: compound
#   Children: []
# Word: 'mihi'
#   Head word: 'est'
#   Dependency relation: compound
#   Explanation: compound
#   Children: ['advesperascit', 'et']
# Word: 'ad'
#   Head word: 'est'
#   Dependency relation: compound
#   Explanation: compound
#   Children: []
# Word: 'villam'
#   Head word: 'est'
#   Dependency relation: compound
#   Explanation: compound
#   Children: []
# Word: 'revertendum'
#   Head word: 'est'
#   Dependency relation: compound
#   Explanation: compound
#   Children: []
# Word: 'est'
#   Head word: 'est'
#   Dependency relation: ROOT
#   Explanation: root
#   Children: ['sed', 'quoniam', 'et', 'mihi', 'ad', 'villam', 'revertendum', ',', 'illa', '.']
# Word: ','
#   Head word: 'est'
#   Dependency relation: punct
#   Explanation: punctuation
#   Children: []
# Word: 'nunc'
#   Head word: 'illa'
#   Dependency relation: compound
#   Explanation: compound
#   Children: []
# Word: 'quidem'
#   Head word: 'hactenus'
#   Dependency relation: amod
#   Explanation: adjectival modifier
#   Children: []
# Word: 'hactenus'
#   Head word: 'illa'
#   Dependency relation: compound
#   Explanation: compound
#   Children: ['quidem']
# Word: 'cuius'
#   Head word: 'illa'
#   Dependency relation: compound
#   Explanation: compound
#   Children: []
# Word: 'ad'
#   Head word: 'naturam'
#   Dependency relation: compound
#   Explanation: compound
#   Children: []
# Word: 'naturam'
#   Head word: 'illa'
#   Dependency relation: compound
#   Explanation: compound
#   Children: ['ad']
# Word: 'apta'
#   Head word: 'ratio'
#   Dependency relation: compound
#   Explanation: compound
#   Children: []
# Word: 'ratio'
#   Head word: 'vera'
#   Dependency relation: compound
#   Explanation: compound
#   Children: ['apta']
# Word: 'vera'
#   Head word: 'illa'
#   Dependency relation: compound
#   Explanation: compound
#   Children: ['ratio']
# Word: 'illa'
#   Head word: 'est'
#   Dependency relation: conj
#   Explanation: conjunct
#   Children: ['nunc', 'hactenus', 'cuius', 'naturam', 'vera', 'lex', 'dicitur']
# Word: 'et'
#   Head word: 'lex'
#   Dependency relation: compound
#   Explanation: compound
#   Children: []
# Word: 'summa'
#   Head word: 'lex'
#   Dependency relation: compound
#   Explanation: compound
#   Children: []
# Word: 'lex'
#   Head word: 'illa'
#   Dependency relation: npadvmod
#   Explanation: noun phrase as adverbial modifier
#   Children: ['et', 'summa']
# Word: 'a'
#   Head word: 'dicitur'
#   Dependency relation: det
#   Explanation: determiner
#   Children: []
# Word: 'philosophis'
#   Head word: 'dicitur'
#   Dependency relation: compound
#   Explanation: compound
#   Children: []
# Word: 'dicitur'
#   Head word: 'illa'
#   Dependency relation: appos
#   Explanation: appositional modifier
#   Children: ['a', 'philosophis']
# Word: '.'
#   Head word: 'est'
#   Dependency relation: punct
#   Explanation: punctuation
#   Children: []
# Word: 'neque'
#   Head word: 'solum'
#   Dependency relation: compound
#   Explanation: compound
#   Children: []
# Word: 'solum'
#   Head word: 'verum'
#   Dependency relation: nsubj
#   Explanation: nominal subject
#   Children: ['neque', 'communia', ',']
# Word: 'ea'
#   Head word: 'communia'
#   Dependency relation: compound
#   Explanation: compound
#   Children: []
# Word: 'communia'
#   Head word: 'solum'
#   Dependency relation: appos
#   Explanation: appositional modifier
#   Children: ['ea']
# Word: ','
#   Head word: 'solum'
#   Dependency relation: punct
#   Explanation: punctuation
#   Children: []
# Word: 'verum'
#   Head word: 'verum'
#   Dependency relation: ROOT
#   Explanation: root
#   Children: ['solum', 'dixerunt', '.']
# Word: 'etiam'
#   Head word: 'dixerunt'
#   Dependency relation: compound
#   Explanation: compound
#   Children: []
# Word: 'paria'
#   Head word: 'dixerunt'
#   Dependency relation: compound
#   Explanation: compound
#   Children: []
# Word: 'esse'
#   Head word: 'dixerunt'
#   Dependency relation: compound
#   Explanation: compound
#   Children: []
# Word: 'dixerunt'
#   Head word: 'verum'
#   Dependency relation: dobj
#   Explanation: direct object
#   Children: ['etiam', 'paria', 'esse']
# Word: '.'
#   Head word: 'verum'
#   Dependency relation: punct
#   Explanation: punctuation
#   Children: []
# Word: 'sed'
#   Head word: 'nunc'
#   Dependency relation: amod
#   Explanation: adjectival modifier
#   Children: []
# Word: 'nunc'
#   Head word: 'agimus'
#   Dependency relation: nsubj
#   Explanation: nominal subject
#   Children: ['sed', ',']
# Word: ','
#   Head word: 'nunc'
#   Dependency relation: punct
#   Explanation: punctuation
#   Children: []
# Word: 'quod'
#   Head word: 'agimus'
#   Dependency relation: nsubj
#   Explanation: nominal subject
#   Children: []
# Word: 'agimus'
#   Head word: 'agimus'
#   Dependency relation: ROOT
#   Explanation: root
#   Children: ['nunc', 'quod', 'tu']
# Word: 'a'
#   Head word: 'tu'
#   Dependency relation: det
#   Explanation: determiner
#   Children: []
# Word: 'mene'
#   Head word: 'tu'
#   Dependency relation: compound
#   Explanation: compound
#   Children: []
# Word: 'tu'
#   Head word: 'agimus'
#   Dependency relation: dobj
#   Explanation: direct object
#   Children: ['a', 'mene']

# %%
all_sentences = sent_tokenize(text_lower)

for sent_idx, sentence in enumerate(all_sentences, 1):
    print(f"\nSentence {sent_idx}: {sentence}")

    # Tokenize and tag
    tokens = word_tokenize(sentence)
    pos_tags = pos_tag(tokens)

    # Create a simple binary tree structure for visualization
    def create_simple_tree(tokens, pos_tags):
        """Create a simple constituency-like tree structure"""
        if len(tokens) == 1:
            return Tree(pos_tags[0][1], [tokens[0]])
        else:
            mid = len(tokens) // 2
            left_tree = create_simple_tree(tokens[:mid], pos_tags[:mid])
            right_tree = create_simple_tree(tokens[mid:], pos_tags[mid:])
            return Tree('S', [left_tree, right_tree])

    try:
        constituency_tree = create_simple_tree(tokens, pos_tags)
        print("Constituency Tree:")
        constituency_tree.pretty_print()

        print("Tree in bracketed notation:")
        print(constituency_tree)
    except Exception as e:
        print(f"Error creating tree: {e}")

print("\nALTERNATIVE TREE VISUALIZATION (ALL SENTENCES - Detailed NP chunks):")

# More detailed tree structure for ALL sentences
for sent_idx, sentence in enumerate(all_sentences, 1):
    print(f"\nSentence {sent_idx}: {sentence}")

    tokens = word_tokenize(sentence)
    pos_tags = pos_tag(tokens)

    # Manual tree building
    tree = Tree('S', [])
    current_np = []

    for word, tag in pos_tags:
        if tag.startswith('NN') or tag.startswith('JJ') or tag == 'DT':
            current_np.append((word, tag))
        else:
            if current_np:
                np_tree = Tree('NP', [f"{w}/{t}" for w, t in current_np])
                tree.append(np_tree)
                current_np = []
            tree.append(f"{word}/{tag}")

    if current_np:
        np_tree = Tree('NP', [f"{w}/{t}" for w, t in current_np])
        tree.append(np_tree)

    print("Detailed Constituency Tree (NP chunks):")
    tree.pretty_print()
    print("\nTree as string:")
    print(tree)
# Out:
# Sentence 1: quod equidem non reprehendonlorem ipsum dolor sit amet, consectetur adipiscing elit.
# Constituency Tree:
#                                                        S
#                    ____________________________________|____________________
#                   S                                                         S
#          _________|_____________________                    ________________|______________________
#         S                               S                  S                                       S
#   ______|_____               ___________|____           ___|____                     ______________|________
#  |            S             |                S         |        S                   S                       S
#  |       _____|___          |            ____|____     |    ____|___         _______|______             ____|___
#  NN     NN        NN        NN          NN        NN   NN  NN       ,       NN            VBG          NN       .
#  |      |         |         |           |         |    |   |        |       |              |           |        |
# quod equidem     non reprehendonlorem ipsum     dolor sit amet      ,  consectetur     adipiscing     elit      .
#
# Tree in bracketed notation:
# (S
#   (S
#     (S (NN quod) (S (NN equidem) (NN non)))
#     (S (NN reprehendonlorem) (S (NN ipsum) (NN dolor))))
#   (S
#     (S (NN sit) (S (NN amet) (, ,)))
#     (S (S (NN consectetur) (VBG adipiscing)) (S (NN elit) (. .)))))
#
# Sentence 2: quibus natura iure responderit non esse verum aliunde finem beate vivendi, a se principia rei gerendae peti quae enim adhuc protulisti, popularia sunt, ego autem a te elegantiora desidero.
# Constituency Tree:
#                                                                                                                                                        S
#                                                                           _____________________________________________________________________________|____________________________________________________________________________
#                                                                          |                                                                                                                                                          S
#                                                                          |                                                                                                           _______________________________________________|______________________________
#                                                                          S                                                                                                          |                                                                              S
#                                      ____________________________________|_____________________________________                                                                     |                                                             _________________|_______________
#                                     S                                                                          S                                                                    S                                                            |                                 S
#                     ________________|____________________                                       _______________|_______________                                         ____________|_________________________                                   |                      ___________|_________
#                    S                                     S                                     S                               S                                       S                                      S                                  S                     |                     S
#          __________|________                     ________|_________                   _________|___________             _______|_____________                  ________|________                ______________|_______                    _______|_______              |            _________|______
#         S                   S                   S                  S                 S                     S           S                     S                S                 S              S                      S                  S               S             S           |                S
#    _____|____           ____|_______         ___|___           ____|_____        ____|____            _____|___     ___|___            ______|___       ______|___          ____|___       ____|______             ___|______        ____|___         ___|____      ___|___        |          ______|___
#   NN         NN        NN           NN      FW      FW        NN         NN     NN        NN         NN        ,   DT      NN         NN         NN    NN         NN       NN       NN    NN          NN          ,          NN     NN       ,       NN       NN   DT      NN      NN        NN         .
#   |          |         |            |       |       |         |          |      |         |          |         |   |       |          |          |     |          |        |        |     |           |           |          |      |        |       |        |    |       |       |         |          |
# quibus     natura     iure     responderit non     esse     verum     aliunde finem     beate     vivendi      ,   a       se     principia     rei gerendae     peti     quae     enim adhuc     protulisti      ,      popularia sunt      ,      ego     autem  a       te elegantiora desidero      .
#
# Tree in bracketed notation:
# (S
#   (S
#     (S
#       (S (S (NN quibus) (NN natura)) (S (NN iure) (NN responderit)))
#       (S (S (FW non) (FW esse)) (S (NN verum) (NN aliunde))))
#     (S
#       (S (S (NN finem) (NN beate)) (S (NN vivendi) (, ,)))
#       (S (S (DT a) (NN se)) (S (NN principia) (NN rei)))))
#   (S
#     (S
#       (S (S (NN gerendae) (NN peti)) (S (NN quae) (NN enim)))
#       (S (S (NN adhuc) (NN protulisti)) (S (, ,) (NN popularia))))
#     (S
#       (S (S (NN sunt) (, ,)) (S (NN ego) (NN autem)))
#       (S
#         (S (DT a) (NN te))
#         (S (NN elegantiora) (S (NN desidero) (. .)))))))
#
# Sentence 3: duo reges constructio interrete.
# Constituency Tree:
#                    S
#       _____________|__________
#      |                        S
#      |              __________|______
#      S             |                 S
#   ___|____         |           ______|___
#  NN      NNS      VBP         NN         .
#  |        |        |          |          |
# duo     reges constructio interrete      .
#
# Tree in bracketed notation:
# (S
#   (S (NN duo) (NNS reges))
#   (S (VBP constructio) (S (NN interrete) (. .))))
#
# Sentence 4: tum lucius mihi vero ista valde probata sunt, quod item fratri puto.
# Constituency Tree:
#                                                    S
#                       _____________________________|_______________________
#                      S                                                     S
#        ______________|_____________                            ____________|_______________
#       S                            S                          S                            S
#   ____|_____               ________|_________             ____|___               __________|________
#  |          S             S                  S           |        S             S                   S
#  |     _____|___      ____|___           ____|_____      |     ___|___      ____|____           ____|___
#  NN   NN        NN   NN       NN        NN         NN    NN   ,       JJ   NN        JJ        NN       .
#  |    |         |    |        |         |          |     |    |       |    |         |         |        |
# tum lucius     mihi vero     ista     valde     probata sunt  ,      quod item     fratri     puto      .
#
# Tree in bracketed notation:
# (S
#   (S
#     (S (NN tum) (S (NN lucius) (NN mihi)))
#     (S (S (NN vero) (NN ista)) (S (NN valde) (NN probata))))
#   (S
#     (S (NN sunt) (S (, ,) (JJ quod)))
#     (S (S (NN item) (JJ fratri)) (S (NN puto) (. .)))))
#
# Sentence 5: bestiarum vero nullum iudicium puto.
# Constituency Tree:
#                      S
#             _________|______________
#            S                        S
#      ______|____              ______|____
#     |           S            |           S
#     |       ____|____        |       ____|___
#     NN     NN        NN      NN     NN       .
#     |      |         |       |      |        |
# bestiarum vero     nullum iudicium puto      .
#
# Tree in bracketed notation:
# (S
#   (S (NN bestiarum) (S (NN vero) (NN nullum)))
#   (S (NN iudicium) (S (NN puto) (. .))))
#
# Sentence 6: nihil enim iam habes, quod ad corpus referas deinde prima illa, quae in congressu solemus quid tu, inquit, huc et homini, qui ceteris animantibus plurimum praestat, praecipue a natura nihil datum esse dicemusnniam id ipsum absurdum, maximum malum neglegi.
# Constituency Tree:
#                                                                                                                                                                S
#                                                                                 _______________________________________________________________________________|___________________________________________________________________________________________
#                                                                                S                                                                                                                                                                           S
#                                    ____________________________________________|_____________________________________                                                                                  ____________________________________________________|________________________________________________
#                                   S                                                                                  S                                                                                S                                                                                                     S
#                  _________________|_____________                                             ________________________|__________________                                       _______________________|_____________________________                                              __________________________|_______________________
#                 S                               S                                           S                                           S                                     S                                                     S                                            S                                                  S
#         ________|____                   ________|______________                      _______|___________                         _______|__________                  _________|_________                                  __________|_____________                       ________|_________________                        _________|_____________
#        |             S                 S                       S                    S                   S                       S                  S                S                   S                                S                        S                     S                          S                      S                       S
#        |         ____|____         ____|___              ______|_____           ____|___          ______|______             ____|___          _____|___         ____|_____         _____|_____                   ________|______            ______|___             _____|____              ________|___             ______|___              ______|_____
#        S        |         S       |        S            |            S         |        S        |             S           |        S        |         S       |          S       |           S                 |               S          |          S           |          S            |            S           |          S            |            S
#    ____|___     |     ____|___    |     ___|____        |       _____|____     |     ___|___     |       ______|_____      |     ___|___     |      ___|___    |     _____|___    |      _____|_______          |         ______|___       |       ___|____       |      ____|___         |         ___|____       |       ___|_____       |       _____|___
#   JJ       NN   NN  NNS       ,   NN   NN       NN     VBP     NN         NN   NN   ,       NN   IN     NN           NN    NN   NN      ,    NN    ,       NN  NN   NN        ,   JJ    NN            NN        NN       NN         ,      VB     DT       NN     NN    NN       NN       NN       NN       NN     NN     ,         JJ     NN     NN        .
#   |        |    |    |        |   |    |        |       |      |          |    |    |       |    |      |            |     |    |       |    |     |       |   |    |         |   |     |             |         |        |          |      |      |        |      |     |        |        |        |        |      |      |         |      |      |         |
# nihil     enim iam habes      ,  quod  ad     corpus referas deinde     prima illa  ,      quae  in congressu     solemus quid  tu      ,  inquit  ,      huc  et homini      ,  qui ceteris     animantibus plurimum praestat      ,  praecipue  a      natura nihil datum     esse dicemusnniam  id     ipsum absurdum  ,      maximum malum neglegi      .
#
# Tree in bracketed notation:
# (S
#   (S
#     (S
#       (S (S (JJ nihil) (NN enim)) (S (NN iam) (S (NNS habes) (, ,))))
#       (S
#         (S (NN quod) (S (NN ad) (NN corpus)))
#         (S (VBP referas) (S (NN deinde) (NN prima)))))
#     (S
#       (S
#         (S (NN illa) (S (, ,) (NN quae)))
#         (S (IN in) (S (NN congressu) (NN solemus))))
#       (S
#         (S (NN quid) (S (NN tu) (, ,)))
#         (S (NN inquit) (S (, ,) (NN huc))))))
#   (S
#     (S
#       (S
#         (S (NN et) (S (NN homini) (, ,)))
#         (S (JJ qui) (S (NN ceteris) (NN animantibus))))
#       (S
#         (S (NN plurimum) (S (NN praestat) (, ,)))
#         (S (VB praecipue) (S (DT a) (NN natura)))))
#     (S
#       (S
#         (S (NN nihil) (S (NN datum) (NN esse)))
#         (S (NN dicemusnniam) (S (NN id) (NN ipsum))))
#       (S
#         (S (NN absurdum) (S (, ,) (JJ maximum)))
#         (S (NN malum) (S (NN neglegi) (. .)))))))
#
# Sentence 7: quod ea non occurrentia fingunt, vincunt aristonem atqui perspicuum est hominem e corpore animoque constare, cum primae sint animi partes, secundae corporis.
# Constituency Tree:
#                                                                                                              S
#                                                  ____________________________________________________________|____________________________________________________
#                                                 S                                                                                                                 S
#                _________________________________|____________________________                                                            _________________________|_____________________
#               S                                                              S                                                          S                                               S
#        _______|_________________                          ___________________|_______________                               ____________|__________                      _______________|________________
#       S                         S                        S                                   S                             S                       S                    S                                S
#   ____|___             _________|_____           ________|______                      _______|___________           _______|______              ___|___            _____|____                ____________|____________
#  |        S           |               S         |               S                    S                   S         |              S            |       S          |          S              S                         S
#  |     ___|___        |          _____|___      |         ______|____         _______|___           _____|___      |        ______|_____       |    ___|____      |      ____|____       ___|_____              ______|___
#  NN   NN      JJ      NN        NN        ,     NN       NN          NN      NN         JJS        NN        NN    NN      NN           NN     ,   NN       NN    NN    NN       NNS    ,         JJ           NN         .
#  |    |       |       |         |         |     |        |           |       |           |         |         |     |       |            |      |   |        |     |     |         |     |         |            |          |
# quod  ea     non occurrentia fingunt      ,  vincunt aristonem     atqui perspicuum     est     hominem      e  corpore animoque     constare  ,  cum     primae sint animi     partes  ,      secundae     corporis      .
#
# Tree in bracketed notation:
# (S
#   (S
#     (S
#       (S (NN quod) (S (NN ea) (JJ non)))
#       (S (NN occurrentia) (S (NN fingunt) (, ,))))
#     (S
#       (S (NN vincunt) (S (NN aristonem) (NN atqui)))
#       (S (S (NN perspicuum) (JJS est)) (S (NN hominem) (NN e)))))
#   (S
#     (S
#       (S (NN corpore) (S (NN animoque) (NN constare)))
#       (S (, ,) (S (NN cum) (NN primae))))
#     (S
#       (S (NN sint) (S (NN animi) (NNS partes)))
#       (S (S (, ,) (JJ secundae)) (S (NN corporis) (. .))))))
#
# Sentence 8: fieri, inquam, triari, nullo pacto potest, ut non dicas, quid non probes eius, a quo dissentias.
# Constituency Tree:
#                                                                             S
#                                       ______________________________________|_______________________________
#                                      S                                                                      S
#                  ____________________|______________                                       _________________|__________________
#                 S                                   S                                     S                                    S
#         ________|_____                     _________|___________                  ________|________                     _______|__________
#        |              S                   S                     S                S                 S                   S                  S
#        |         _____|___            ____|____            _____|___         ____|____         ____|___            ____|___         ______|_______
#        S        |         S          |         S          |         S       |         S       |        S          |        S       |              S
#    ____|___     |      ___|____      |     ____|____      |      ___|___    |     ____|___    |     ___|____      |     ___|___    |       _______|___
#   NN       ,    NN    ,        NN    ,    JJ        NN    NN    ,       JJ  NN   NN       ,   NN   NN      NNS   VBP   ,       DT  NN     NN          .
#   |        |    |     |        |     |    |         |     |     |       |   |    |        |   |    |        |     |    |       |   |      |           |
# fieri      ,  inquam  ,      triari  ,  nullo     pacto potest  ,       ut non dicas      ,  quid non     probes eius  ,       a  quo dissentias      .
#
# Tree in bracketed notation:
# (S
#   (S
#     (S (S (NN fieri) (, ,)) (S (NN inquam) (S (, ,) (NN triari))))
#     (S
#       (S (, ,) (S (JJ nullo) (NN pacto)))
#       (S (NN potest) (S (, ,) (JJ ut)))))
#   (S
#     (S
#       (S (NN non) (S (NN dicas) (, ,)))
#       (S (NN quid) (S (NN non) (NNS probes))))
#     (S
#       (S (VBP eius) (S (, ,) (DT a)))
#       (S (NN quo) (S (NN dissentias) (. .))))))
#
# Sentence 9: equidem e cn.
# Constituency Tree:
#                  S
#           _______|_______
#          S               S
#     _____|___         ___|___
#    NN        NN      NN      .
#    |         |       |       |
# equidem      e       cn      .
#
# Tree in bracketed notation:
# (S (S (NN equidem) (NN e)) (S (NN cn) (. .)))
#
# Sentence 10: an dubium est, quin virtus ita maximam partem optineat in rebus humanis, ut reliquas obruatnnquis istum dolorem timetnsummus dolor plures dies manere non potest dicet pro me ipsa virtus nec dubitabit isti vestro beato m. tubulum fuisse, qua illum, cuius is condemnatus est rogatione, p. quod si ita sit, cur opera philosophiae sit danda nescio.nnex eorum enim scriptis et institutis cum omnis doctrina liberalis, omnis historia.nquod si ita est, sequitur id ipsum, quod te velle video, omnes semper beatos esse sapientes.
# Constituency Tree:
#                                                                                                                                                                                                                                                                                                                                                         S
#                                                                                                                                                                                      ___________________________________________________________________________________________________________________________________________________________________|______________________________________________________________________________________________________________________________________________________________________________
#                                                                                                                                                                                     S                                                                                                                                                                                                                                                                                                                                                  S
#                                                                                   __________________________________________________________________________________________________|____________________________________________________________________________________                                                                                                                                                                 _____________________________________________________________________________________________|____________________________________________________________________________________________
#                                                                                  S                                                                                                                                                                                       S                                                                                                                                                               S                                                                                                                                                                                          S
#                                    ______________________________________________|_________________________________________                                                                                                   ___________________________________________|______________________________________                                                                                    _____________________________________|____________________________________________                                                                                                        ______________________________________|________________________________
#                                   S                                                                                        S                                                                                                 S                                                                                  S                                                                                  S                                                                                  S                                                                                                      S                                                                       S
#                  _________________|_______________                                                 ________________________|______________________________                                                ___________________|_____________                                               ______________________|_________________                                                 ________________|___________                                             __________________________|________________________                                                   ___________________________|___________                                         ___________________|_____________________
#                 S                                 S                                               S                                                       S                                              S                                 S                                             S                                        S                                               S                            S                                           S                                                   S                                                 S                                       S                                       S                                         S
#       __________|___                     _________|______________                        _________|_________                                 _____________|_______________                       ________|______                  _________|____________                         ________|____________                    ________|_________                         _____________|___                  _______|_______                            ________|_________________                        __________|____________                             ________|_________                       _______|____________                   ________|__________                     __________|_____________
#      |              S                   S                        S                      S                   S                               S                             S                     |               S                S                      S                       S                     S                  S                  S                       |                 S                S               S                          S                          S                      S                       S                           |                  S                     S                    S                 S                   S                   S                        S
#      |           ___|___           _____|___              _______|______          ______|_____         _____|______                   ______|_____                   _____|_____                |         ______|____         ___|____            ______|______           ______|____           ______|_____         ____|____          ____|___                    |              ___|___          ___|___         ___|___               ________|___               ________|____            ______|___                ____|____                       |         _________|_________         ___|___           ______|___           ___|____          _____|____          _____|_____            _______|______
#      S          |       S         |         S            |              S        |            S       |            S                 |            S                 |           S               S        |           S       |        S          |             S         |           S         |            S       |         S        |        S                   S             |       S        |       S       |       S             |            S             |             S          |          S              |         S                      S        |                   S       |       S         |          S         |        S        |          S        |           S          |              S
#   ___|____      |    ___|___      |      ___|_____       |        ______|___     |       _____|___    |      ______|_______          |       _____|_______          |      _____|___       _____|___     |       ____|___    |    ____|____      |       ______|___      |       ____|___      |       _____|___    |     ____|___     |     ___|_______         ___|______       |    ___|___     |    ___|___    |    ___|____         |         ___|____         |         ____|___       |       ___|______        |     ____|_____           ______|___     |          _________|___    |    ___|___      |       ___|____     |    ____|___     |      ____|___     |      _____|____      |        ______|___
#  DT       NN    NN  ,       JJ    NN    NN        NN     NN      NN         IN   NN     NN        ,   JJ    NN             NN        NN     NN            NN        NN   VBZ       NNS    RB        RB  JJS     JJ       FW PRP  JJ        NN    JJ     NN         JJ    NN     NN       NN    NN     NN        ,   NN   NN       ,    NN  VBZ          JJ      RB         NN     ,   NN      NN   NN  JJ      NN  ,  VBP       NN       NN       NN       NN       JJ       NN       NN     NN     FW         NN      NN   IN         NN        NN         ,    NN        NN            NN  NN  NN      ,     JJ     NN       NN   ,   JJ       NN   NN    NN       ,   VBZ   JJR         NN    NN     NNS         .
#  |        |     |   |       |     |     |         |      |       |          |    |      |         |   |     |              |         |      |             |         |     |         |     |         |    |      |        |   |   |         |     |      |          |     |      |        |     |      |         |   |    |        |    |    |           |       |          |      |   |       |    |   |       |   |   |        |        |        |        |        |        |        |      |      |          |       |    |          |         |          |    |         |             |   |   |       |     |      |        |    |   |        |    |     |        |    |     |          |     |       |          |
#  an     dubium est  ,      quin virtus ita     maximam partem optineat      in rebus humanis      ,   ut reliquas     obruatnnquis istum dolorem     timetnsummus dolor plures     dies manere     non potest dicet     pro  me ipsa     virtus nec dubitabit     isti vestro beato      m. tubulum fuisse      ,  qua illum      ,  cuius  is     condemnatus est     rogatione  ,   p.     quod  si ita     sit  ,  cur     opera philosophiae sit     danda nescio.nnex eorum     enim scriptis  et     institutis cum omnis     doctrina liberalis      ,  omnis historia.nquod      si ita est      ,  sequitur  id     ipsum  ,  quod      te velle video      ,  omnes semper     beatos esse sapientes      .
#
# Tree in bracketed notation:
# (S
#   (S
#     (S
#       (S
#         (S (S (DT an) (NN dubium)) (S (NN est) (S (, ,) (JJ quin))))
#         (S
#           (S (NN virtus) (S (NN ita) (NN maximam)))
#           (S (NN partem) (S (NN optineat) (IN in)))))
#       (S
#         (S
#           (S (NN rebus) (S (NN humanis) (, ,)))
#           (S (JJ ut) (S (NN reliquas) (NN obruatnnquis))))
#         (S
#           (S (NN istum) (S (NN dolorem) (NN timetnsummus)))
#           (S (NN dolor) (S (VBZ plures) (NNS dies))))))
#     (S
#       (S
#         (S
#           (S (RB manere) (RB non))
#           (S (JJS potest) (S (JJ dicet) (FW pro))))
#         (S
#           (S (PRP me) (S (JJ ipsa) (NN virtus)))
#           (S (JJ nec) (S (NN dubitabit) (JJ isti)))))
#       (S
#         (S
#           (S (NN vestro) (S (NN beato) (NN m.)))
#           (S (NN tubulum) (S (NN fuisse) (, ,))))
#         (S
#           (S (NN qua) (S (NN illum) (, ,)))
#           (S (NN cuius) (S (VBZ is) (JJ condemnatus)))))))
#   (S
#     (S
#       (S
#         (S
#           (S (RB est) (NN rogatione))
#           (S (, ,) (S (NN p.) (NN quod))))
#         (S
#           (S (NN si) (S (JJ ita) (NN sit)))
#           (S (, ,) (S (VBP cur) (NN opera)))))
#       (S
#         (S
#           (S (NN philosophiae) (S (NN sit) (NN danda)))
#           (S (JJ nescio.nnex) (S (NN eorum) (NN enim))))
#         (S
#           (S (NN scriptis) (S (FW et) (NN institutis)))
#           (S (NN cum) (S (IN omnis) (NN doctrina))))))
#     (S
#       (S
#         (S
#           (S (NN liberalis) (, ,))
#           (S (NN omnis) (S (NN historia.nquod) (NN si))))
#         (S
#           (S (NN ita) (S (NN est) (, ,)))
#           (S (JJ sequitur) (S (NN id) (NN ipsum)))))
#       (S
#         (S
#           (S (, ,) (S (JJ quod) (NN te)))
#           (S (NN velle) (S (NN video) (, ,))))
#         (S
#           (S (VBZ omnes) (S (JJR semper) (NN beatos)))
#           (S (NN esse) (S (NNS sapientes) (. .))))))))
#
# Sentence 11: cum enim fertur quasi torrens oratio, quamvis multa cuiusque modi rapiat, nihil tamen teneas, nihil apprehendas, nusquam orationem rapidam coerceas.
# Constituency Tree:
#                                                                                              S
#                                          ____________________________________________________|____________________________________________
#                                         S                                                                                                 S
#                 ________________________|______________________                                              _____________________________|__________________________
#                S                                               S                                            S                                                        S
#       _________|_____________                        __________|_____________                      _________|___________                           __________________|__________________
#      S                       S                      S                        S                    S                     S                         S                                     S
#   ___|____             ______|_____            _____|_____             ______|____            ____|____            _____|___               _______|___                       ___________|____________
#  |        S           |            S          |           S           |           S          |         S          |         S             |           S                     S                        S
#  |    ____|____       |       _____|____      |      _____|____       |       ____|____      |     ____|____      |      ___|____         |        ___|_____          ______|_____             ______|___
#  NN  NN        NN     NN    NNS        VBP    ,     JJ         NN     NN     NN        NN    ,    JJ       NNS   NNS    ,        JJ       NN      ,         JJ       NN           NN         NNS         .
#  |   |         |      |      |          |     |     |          |      |      |         |     |    |         |     |     |        |        |       |         |        |            |           |          |
# cum enim     fertur quasi torrens     oratio  ,  quamvis     multa cuiusque modi     rapiat  ,  nihil     tamen teneas  ,      nihil apprehendas  ,      nusquam orationem     rapidam     coerceas      .
#
# Tree in bracketed notation:
# (S
#   (S
#     (S
#       (S (NN cum) (S (NN enim) (NN fertur)))
#       (S (NN quasi) (S (NNS torrens) (VBP oratio))))
#     (S
#       (S (, ,) (S (JJ quamvis) (NN multa)))
#       (S (NN cuiusque) (S (NN modi) (NN rapiat)))))
#   (S
#     (S
#       (S (, ,) (S (JJ nihil) (NNS tamen)))
#       (S (NNS teneas) (S (, ,) (JJ nihil))))
#     (S
#       (S (NN apprehendas) (S (, ,) (JJ nusquam)))
#       (S (S (NN orationem) (NN rapidam)) (S (NNS coerceas) (. .))))))
#
# Sentence 12: ita redarguitur ipse a sese, convincunturque scripta eius probitate ipsius ac moribus.
# Constituency Tree:
#                                                          S
#                            ______________________________|_____________________________________
#                           S                                                                    S
#           ________________|____________                                     ___________________|_____________
#          S                             S                                   S                                 S
#   _______|_______              ________|_______                       _____|____                      _______|___________
#  |               S            S                S                     |          S                    S                   S
#  |        _______|___      ___|___          ___|_________            |      ____|______         _____|___           _____|___
#  JJ      NN          NN   DT      JJ       ,             JJ          NN    NN          NN      NN        NN        NN        .
#  |       |           |    |       |        |             |           |     |           |       |         |         |         |
# ita redarguitur     ipse  a      sese      ,      convincunturque scripta eius     probitate ipsius      ac     moribus      .
#
# Tree in bracketed notation:
# (S
#   (S
#     (S (JJ ita) (S (NN redarguitur) (NN ipse)))
#     (S (S (DT a) (JJ sese)) (S (, ,) (JJ convincunturque))))
#   (S
#     (S (NN scripta) (S (NN eius) (NN probitate)))
#     (S (S (NN ipsius) (NN ac)) (S (NN moribus) (. .)))))
#
# Sentence 13: at quanta conantur mundum hunc omnem oppidum esse nostrum incendi igitur eos, qui audiunt, vides.
# Constituency Tree:
#                                                                           S
#                                          _________________________________|________________________________________
#                                         S                                                                          S
#                  _______________________|________________                                           _______________|_______________
#                 |                                        S                                         |                               S
#                 |                             ___________|_____                                    |                    ___________|____
#                 S                            |                 S                                   S                   |                S
#       __________|____________                |            _____|____                     __________|_______            |            ____|____
#      S                       S               S           |          S                   S                  S           S           |         S
#   ___|____             ______|____       ____|____       |      ____|_____         _____|____           ___|___     ___|_____      |     ____|___
#  IN       JJ          NN          NN    NN        NN     NN    FW         NN      NN         NN        NN      ,   NN        NN    ,   NNS       .
#  |        |           |           |     |         |      |     |          |       |          |         |       |   |         |     |    |        |
#  at     quanta     conantur     mundum hunc     omnem oppidum esse     nostrum incendi     igitur     eos      ,  qui     audiunt  ,  vides      .
#
# Tree in bracketed notation:
# (S
#   (S
#     (S (S (IN at) (JJ quanta)) (S (NN conantur) (NN mundum)))
#     (S
#       (S (NN hunc) (NN omnem))
#       (S (NN oppidum) (S (FW esse) (NN nostrum)))))
#   (S
#     (S (S (NN incendi) (NN igitur)) (S (NN eos) (, ,)))
#     (S (S (NN qui) (NN audiunt)) (S (, ,) (S (NNS vides) (. .))))))
#
# Sentence 14: vide, ne magis, inquam, tuum fuerit, cum re idem tibi, quod mihi, videretur, non nova te rebus nomina inponere.
# Constituency Tree:
#                                                                                         S
#                                         ________________________________________________|________________________________________________
#                                        S                                                                                                 S
#                ________________________|___________________                                                ______________________________|_____________________
#               S                                            S                                              S                                                    S
#        _______|_________                    _______________|___________                       ____________|____________                           _____________|_______________
#       S                 S                  S                           S                     S                         S                         S                             S
#   ____|___          ____|___            ___|____                _______|_______          ____|___               _______|_____________         ___|____               __________|____________
#  |        S        |        S          |        S              S               S        |        S             S                     S       |        S             S                       S
#  |     ___|___     |     ___|____      |    ____|____       ___|___         ___|___     |     ___|___      ____|___            ______|___    |    ____|___      ____|____             ______|___
#  NN   ,       JJ   NN   ,        NN    ,   NN        NN    ,       NN      NN      NN   NN   ,       JJ   NN       ,          NN         ,   JJ  FW       NN   NN        NN          RB         .
#  |    |       |    |    |        |     |   |         |     |       |       |       |    |    |       |    |        |          |          |   |   |        |    |         |           |          |
# vide  ,       ne magis  ,      inquam  ,  tuum     fuerit  ,      cum      re     idem tibi  ,      quod mihi      ,      videretur      ,  non nova      te rebus     nomina     inponere      .
#
# Tree in bracketed notation:
# (S
#   (S
#     (S
#       (S (NN vide) (S (, ,) (JJ ne)))
#       (S (NN magis) (S (, ,) (NN inquam))))
#     (S
#       (S (, ,) (S (NN tuum) (NN fuerit)))
#       (S (S (, ,) (NN cum)) (S (NN re) (NN idem)))))
#   (S
#     (S
#       (S (NN tibi) (S (, ,) (JJ quod)))
#       (S (S (NN mihi) (, ,)) (S (NN videretur) (, ,))))
#     (S
#       (S (JJ non) (S (FW nova) (NN te)))
#       (S (S (NN rebus) (NN nomina)) (S (RB inponere) (. .))))))
#
# Sentence 15: quivere falsone, quaerere mittimusdicitur oculis se privasse si ista mala sunt, in quae potest incidere sapiens, sapientem esse non esse ad beate vivendum satis.
# Constituency Tree:
#                                                                                                                          S
# ...
#    _________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________|_____________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________
#   |    |    |     |      |    |   |   |     |       |       |     |        |          |      |      |      |      |         |      |     |     |    |    |     |     |   |                  NP                                              NP                                    NP                                       NP                                   NP                                                                NP                                                                                                                                                             NP                                                                                                                                       NP                    NP                                  NP                                                             NP                                     NP             NP                                 NP                                          NP                                NP
#   |    |    |     |      |    |   |   |     |       |       |     |        |          |      |      |      |      |         |      |     |     |    |    |     |     |   |      ____________|____________________________           ________|______________________          _____|_______           ______________________|___________________          _______|_________________            ____________________________________|_________________________________            _________________________________________________________________________________________________________________|_________________________________________________________________________________________________________________              _________|_____          ______|_____            __________________|_____________________        _________________________________|___________________________           |        ______|________________           _______|__________________          _______________|_________________          ______|_____
# at/IN ,/, et/FW per/IN se/FW ,/, ,/, ,/, sed/VBD etiam/IN me/PRP ,/, sapientes/VBZ cum/VBP de/IN rebus/FW ,/, verba/VBP habere/RB ,/, sed/VBD ,/, in/IN ,/, sed/VBD ,/, ./. vero/NN si/NN ad/NN vitem/NN sensus/NN accesserit/NN ut/JJ appetitum/NN quendam/NN habeat/NN ipsa/NN     moveatur/NN quid/JJ facturam/NN putasnnquem/NN si/NN tenueris/NN non/JJ modo/NN meum/NN ciceronem/NN ipsum/JJ abducas/JJ licebit.nstulti/ autem/NN malorum/NN memoria/NN torquentur/NN bona/JJ praeterita/NN grata/NN recordatione/NN renovata/NN delectant.nesse/ enim/NN quam/JJ vellet/NN iniquus/NN iustus/NN poterat/NN inpune.nquae/NN autem/NN natura/JJ suae/NN primae/NN institutionis/NN oblita/JJ estnverum/NN tamen/NNS grandioribus/NN     dicas/NN ipsae/JJ     res/NNS rapiuntnhoc/NN est/JJS non/NN modo/NN cor/NN non/NN ne/JJ palatum/NN quidem.nvoluptat cum/JJ summum/JJ bonum/NN diceret/NN primum/NN eo/JJ ipso/NN parum/NN vidit/NN deinde/NN hoc/NN quoque/NN alienum/NN tu/JJ istuc/NN dixti/NN bene/NN latine/NN parum/NN     plane/NN
#                                                                                                                                                                                                                                                                                                                                                                                                                      NN                                                                                                                       NN                                                                                                                                                                                                                                                                                                     em/NN
#
#
# Tree as string:
# (S
#   at/IN
#   (NP vero/NN si/NN ad/NN vitem/NN sensus/NN accesserit/NN)
#   ,/,
#   (NP ut/JJ appetitum/NN quendam/NN habeat/NN)
#   et/FW
#   per/IN
#   se/FW
#   (NP ipsa/NN moveatur/NN)
#   ,/,
#   (NP quid/JJ facturam/NN putasnnquem/NN si/NN tenueris/NN)
#   ,/,
#   (NP non/JJ modo/NN meum/NN ciceronem/NN)
#   ,/,
#   sed/VBD
#   etiam/IN
#   me/PRP
#   (NP
#     ipsum/JJ
#     abducas/JJ
#     licebit.nstulti/NN
#     autem/NN
#     malorum/NN
#     memoria/NN
#     torquentur/NN)
#   ,/,
#   sapientes/VBZ
#   (NP
#     bona/JJ
#     praeterita/NN
#     grata/NN
#     recordatione/NN
#     renovata/NN
#     delectant.nesse/NN
#     enim/NN
#     quam/JJ
#     vellet/NN
#     iniquus/NN
#     iustus/NN
#     poterat/NN
#     inpune.nquae/NN
#     autem/NN
#     natura/JJ
#     suae/NN
#     primae/NN
#     institutionis/NN
#     oblita/JJ
#     estnverum/NN
#     tamen/NNS)
#   cum/VBP
#   de/IN
#   rebus/FW
#   (NP grandioribus/NN dicas/NN)
#   ,/,
#   (NP ipsae/JJ res/NNS)
#   verba/VBP
#   (NP rapiuntnhoc/NN est/JJS non/NN modo/NN cor/NN non/NN)
#   habere/RB
#   ,/,
#   sed/VBD
#   (NP
#     ne/JJ
#     palatum/NN
#     quidem.nvoluptatem/NN
#     cum/JJ
#     summum/JJ
#     bonum/NN
#     diceret/NN)
#   ,/,
#   (NP primum/NN)
#   in/IN
#   (NP eo/JJ ipso/NN parum/NN vidit/NN)
#   ,/,
#   (NP deinde/NN hoc/NN quoque/NN alienum/NN)
#   sed/VBD
#   (NP tu/JJ istuc/NN dixti/NN bene/NN latine/NN)
#   ,/,
#   (NP parum/NN plane/NN)
#   ./.)
#
# Sentence 17: nam haec ipsa mihi erunt in promptu, quae modo audivi, nec ante aggrediar, quam te ab istis, quos dicis, instructum videro.
# Detailed Constituency Tree (NP chunks):
#                                                                                     S
#    _________________________________________________________________________________|___________________________________________________________________________________________________________________
#   |    |   |   |   |   |   |                    NP                        NP                NP                       NP                          NP                          NP                         NP
#   |    |   |   |   |   |   |     _______________|_______________          |          _______|________         _______|_________            ______|____________          _____|_____             ________|______
# in/IN ,/, ,/, ,/, ,/, ,/, ./. nam/JJ haec/NN ipsa/NN mihi/NN erunt/NN promptu/NN quae/JJ modo/NN audivi/NN nec/JJ ante/NN aggrediar/NN quam/NN te/NN ab/NN istis/NN quos/JJ     dicis/NN instructum/NN     videro/NN
#
#
# Tree as string:
# (S
#   (NP nam/JJ haec/NN ipsa/NN mihi/NN erunt/NN)
#   in/IN
#   (NP promptu/NN)
#   ,/,
#   (NP quae/JJ modo/NN audivi/NN)
#   ,/,
#   (NP nec/JJ ante/NN aggrediar/NN)
#   ,/,
#   (NP quam/NN te/NN ab/NN istis/NN)
#   ,/,
#   (NP quos/JJ dicis/NN)
#   ,/,
#   (NP instructum/NN videro/NN)
#   ./.)
#
# Sentence 18: fatebuntur stoici haec omnia dicta esse praeclare, neque eam causam zenoni desciscendi fuisse.
# Detailed Constituency Tree (NP chunks):
#                                                              S
#   ___________________________________________________________|_____________________________________
#  |   |                                     NP                                                      NP
#  |   |         ____________________________|___________________________            ________________|___________________________________
# ,/, ./. fatebuntur/NN stoici/NN haec/NN omnia/NN dicta/NN esse/NN praeclare/NN neque/JJ eam/NN causam/NN zenoni/NNP desciscendi/NN fuisse/NN
#
#
# Tree as string:
# (S
#   (NP
#     fatebuntur/NN
#     stoici/NN
#     haec/NN
#     omnia/NN
#     dicta/NN
#     esse/NN
#     praeclare/NN)
#   ,/,
#   (NP neque/JJ eam/NN causam/NN zenoni/NNP desciscendi/NN fuisse/NN)
#   ./.)
#
# Sentence 19: non autem hoc igitur ne illud quidem.
# Detailed Constituency Tree (NP chunks):
#                       S
#   ____________________|________
#  |                             NP
#  |     ________________________|________________________
# ./. non/JJ autem/NN hoc/NN igitur/NN ne/JJ illud/NN quidem/NN
#
#
# Tree as string:
# (S
#   (NP non/JJ autem/NN hoc/NN igitur/NN ne/JJ illud/NN quidem/NN)
#   ./.)
#
# Sentence 20: ratio quidem vestra sic cogit.
# Detailed Constituency Tree (NP chunks):
#                  S
#   _______________|_________
#  |                         NP
#  |      ___________________|_______________
# ./. ratio/NN quidem/NN vestra/JJ sic/JJ cogit/NN
#
#
# Tree as string:
# (S (NP ratio/NN quidem/NN vestra/JJ sic/JJ cogit/NN) ./.)
#
# Sentence 21: cum audissem antiochum, brute, ut solebam, cum m. an quod ita callida est, ut optime possit architectari voluptatesnnidemne, quod iucundenhaec mihi videtur delicatior, ut ita dicam, molliorque ratio, quam virtutis vis gravitasque postulat.
# Detailed Constituency Tree (NP chunks):
#                                                                                                                                              S
#   ___________________________________________________________________________________________________________________________________________|_________________________________________________________________________________________________________________________________________________________________________________________________________________________
#  |   |   |    |     |   |   |   |   |     |         |        |     |              NP                     NP           NP              NP                   NP                                         NP                                                                NP                                    NP                           NP                          NP
#  |   |   |    |     |   |   |   |   |     |         |        |     |     _________|___________           |        ____|______         |       _____________|_________________        _________________|____________________________              _______________________|_____________________           _____|_______             ________|_____             _________|_______
# ,/, ,/, ,/, m./VBD ,/, ,/, ,/, ,/, ,/, quam/FW virtutis/FW vis/FW ./. cum/NN audissem/NN antiochum/NN brute/NN ut/JJ     solebam/NN cum/NN an/DT quod/NN ita/NN callida/NN est/NN ut/JJ optime/JJ possit/NN architectari/NN voluptatesnnidem quod/JJ iucundenhaec/NN mihi/NN videtur/NN delicatior/NN ut/JJ ita/NN dicam/NN molliorque/NN     ratio/NN gravitasque/NN     postulat/NN
#                                                                                                                                                                                                                                  ne/NN
#
#
# Tree as string:
# (S
#   (NP cum/NN audissem/NN antiochum/NN)
#   ,/,
#   (NP brute/NN)
#   ,/,
#   (NP ut/JJ solebam/NN)
#   ,/,
#   (NP cum/NN)
#   m./VBD
#   (NP an/DT quod/NN ita/NN callida/NN est/NN)
#   ,/,
#   (NP
#     ut/JJ
#     optime/JJ
#     possit/NN
#     architectari/NN
#     voluptatesnnidemne/NN)
#   ,/,
#   (NP quod/JJ iucundenhaec/NN mihi/NN videtur/NN delicatior/NN)
#   ,/,
#   (NP ut/JJ ita/NN dicam/NN)
#   ,/,
#   (NP molliorque/NN ratio/NN)
#   ,/,
#   quam/FW
#   virtutis/FW
#   vis/FW
#   (NP gravitasque/NN postulat/NN)
#   ./.)
#
# Sentence 22: sed quoniam et advesperascit et mihi ad villam revertendum est, nunc quidem hactenus cuius ad naturam apta ratio vera illa et summa lex a philosophis dicitur.
# Detailed Constituency Tree (NP chunks):
#                                                                                                                 S
#     ____________________________________________________________________________________________________________|_________________________________________________________________________________________________________________
#    |      |    |    |      |     |               NP                                     NP                                                                    NP                                                 NP               NP
#    |      |    |    |      |     |       ________|__________              ______________|_______________________         _____________________________________|__________________________________________        |       _________|____________
# sed/VBN et/FW ,/, et/FW lex/VBZ ./. quoniam/JJ et/NN advesperascit/NN mihi/NN ad/NN villam/NN revertendum/NN est/JJS nunc/JJ quidem/NN hactenus/NN cuius/NN ad/NN naturam/NN apta/NN ratio/NN vera/NN illa/NN summa/NN a/DT philosophis/NN dicitur/NN
#
#
# Tree as string:
# (S
#   sed/VBN
#   (NP quoniam/JJ et/NN advesperascit/NN)
#   et/FW
#   (NP mihi/NN ad/NN villam/NN revertendum/NN est/JJS)
#   ,/,
#   (NP
#     nunc/JJ
#     quidem/NN
#     hactenus/NN
#     cuius/NN
#     ad/NN
#     naturam/NN
#     apta/NN
#     ratio/NN
#     vera/NN
#     illa/NN)
#   et/FW
#   (NP summa/NN)
#   lex/VBZ
#   (NP a/DT philosophis/NN dicitur/NN)
#   ./.)
#
# Sentence 23: neque solum ea communia, verum etiam paria esse dixerunt.
# Detailed Constituency Tree (NP chunks):
#                                      S
#   ___________________________________|___________________________
#  |   |              NP                                           NP
#  |   |      ________|________________           _________________|__________________
# ,/, ./. neque/JJ solum/NN ea/NN communia/NN verum/NN etiam/NN paria/NN esse/NN dixerunt/NN
#
#
# Tree as string:
# (S
#   (NP neque/JJ solum/NN ea/NN communia/NN)
#   ,/,
#   (NP verum/NN etiam/NN paria/NN esse/NN dixerunt/NN)
#   ./.)
#
# Sentence 24: sed nunc, quod agimus a mene tu
# Detailed Constituency Tree (NP chunks):
#                           S
#     ______________________|____________________
#    |     |      |         NP      NP           NP
#    |     |      |         |       |      ______|______
# sed/VBN ,/, agimus/VBP nunc/NN quod/JJ a/DT mene/NN tu/NN
#
#
# Tree as string:
# (S
#   sed/VBN
#   (NP nunc/NN)
#   ,/,
#   (NP quod/JJ)
#   agimus/VBP
#   (NP a/DT mene/NN tu/NN))

# %% [markdown]
# # 11. Hypernyms and Hyponyms (WordNet)

# %%
# Extract ALL unique words from filtered tokens
unique_words = list(set(filtered_tokens))

for word in unique_words:
    print(f"\nWORD: '{word}'")

    # Get synsets for the word
    synsets = wn.synsets(word)

    if not synsets:
        print(f"  No synsets found for '{word}'")
        continue

    # Take first synset
    synset = synsets[0]
    print(f"  Definition: {synset.definition()}")
    print(f"  Example: {synset.examples() if synset.examples() else 'No example'}")

    # Hypernyms (more general concepts)
    hypernyms = synset.hypernyms()
    if hypernyms:
        print(f"\n  HYPERNYMS (more general): {len(hypernyms)} found")
        for hyp in hypernyms:
            print(f"    → {hyp.name()}")
            print(f"      Definition: {hyp.definition()}")
            # Get path hypernyms (higher level)
            hyper_paths = hyp.hypernyms()
            if hyper_paths:
                for path_hyp in hyper_paths:
                    print(f"        ↑ {path_hyp.name()}: {path_hyp.definition()}")
    else:
        print(f"\n  HYPERNYMS: None found")

    # Hyponyms (more specific concepts)
    hyponyms = synset.hyponyms()
    if hyponyms:
        print(f"\n  HYPONYMS (more specific): {len(hyponyms)} found")
        for hyp in hyponyms:
            print(f"    → {hyp.name()}")
            print(f"      Definition: {hyp.definition()}")
    else:
        print(f"\n  HYPONYMS: None found")

    # Full hierarchy path (no depth limit)
    print(f"\n  HIERARCHY PATH (up to root):")
    def show_path(s, level=0):
        print(f"    {'  ' * level}└─ {s.name()}")
        for hyp in s.hypernyms():
            show_path(hyp, level + 1)

    show_path(synset)

# Detailed example for ALL specific words from the text
print("\nDETAILED EXAMPLE FOR KEY WORDS FROM TEXT")

key_words = ['apple', 'computer', 'company', 'inventor', 'founder', 'ceo', 'pixar', 'next']

for word in key_words:
    print(f"\nDEEP ANALYSIS FOR: '{word}'")

    synsets = wn.synsets(word)
    if synsets:
        primary_synset = synsets[0]

        print(f"  Definition: {primary_synset.definition()}")
        print(f"  Lemmas: {primary_synset.lemma_names()}")

        # Get all hypernym paths (no limit)
        print("\n  All Hypernym Paths:")
        hypernym_paths = primary_synset.hypernym_paths()
        for i, path in enumerate(hypernym_paths, 1):
            print(f"    Path {i}: {' -> '.join([s.name().split('.')[0] for s in path])}")

        # Get all hyponyms (no limit on display)
        all_hyponyms = primary_synset.hyponyms()
        print(f"\n  Total hyponyms found: {len(all_hyponyms)}")
        if all_hyponyms:
            print("  All hyponyms:")
            for hyp in all_hyponyms:
                print(f"    - {hyp.name()}: {hyp.definition()}")
# Out:
# WORD: 'ceteris'
#   No synsets found for 'ceteris'
#
# WORD: 'rapidam'
#   No synsets found for 'rapidam'
#
# WORD: 'estnverum'
#   No synsets found for 'estnverum'
#
# WORD: 'promptu'
#   No synsets found for 'promptu'
#
# WORD: 'reprehendonlorem'
#   No synsets found for 'reprehendonlorem'
#
# WORD: 'istuc'
#   No synsets found for 'istuc'
#
# WORD: 'hunc'
#   No synsets found for 'hunc'
#
# WORD: 'liberalis'
#   No synsets found for 'liberalis'
#
# WORD: 'finem'
#   No synsets found for 'finem'
#
# WORD: 'istis'
#   No synsets found for 'istis'
#
# WORD: 'timetnsummus'
#   No synsets found for 'timetnsummus'
#
# WORD: 'dicta'
#   Definition: an authoritative declaration
#   Example: No example
#
#   HYPERNYMS (more general): 1 found
#     → declaration.n.01
#       Definition: a statement that is emphatic and explicit (spoken or written)
#         ↑ statement.n.01: a message that is stated or declared; a communication (oral or written) setting forth particulars or facts etc
#
#   HYPONYMS (more specific): 1 found
#     → directive.n.01
#       Definition: a pronouncement encouraging or banning some activity
#
#   HIERARCHY PATH (up to root):
#     └─ pronouncement.n.01
#       └─ declaration.n.01
#         └─ statement.n.01
#           └─ message.n.02
#             └─ communication.n.02
#               └─ abstraction.n.06
#                 └─ entity.n.01
#
# WORD: 'iure'
#   No synsets found for 'iure'
#
# WORD: 'recordatione'
#   No synsets found for 'recordatione'
#
# WORD: 'vestra'
#   No synsets found for 'vestra'
#
# WORD: 'videro'
#   No synsets found for 'videro'
#
# WORD: 'praecipue'
#   No synsets found for 'praecipue'
#
# WORD: 'modi'
#   No synsets found for 'modi'
#
# WORD: 'malorum'
#   No synsets found for 'malorum'
#
# WORD: 'quendam'
#   No synsets found for 'quendam'
#
# WORD: 'quibus'
#   No synsets found for 'quibus'
#
# WORD: 'quin'
#   Definition: one of five children born at the same time from the same pregnancy
#   Example: No example
#
#   HYPERNYMS (more general): 1 found
#     → sibling.n.01
#       Definition: a person's brother or sister
#         ↑ relative.n.01: a person related by blood or marriage
#
#   HYPONYMS: None found
#
#   HIERARCHY PATH (up to root):
#     └─ quintuplet.n.02
#       └─ sibling.n.01
#         └─ relative.n.01
#           └─ person.n.01
#             └─ causal_agent.n.01
#               └─ physical_entity.n.01
#                 └─ entity.n.01
#             └─ organism.n.01
#               └─ living_thing.n.01
#                 └─ whole.n.02
#                   └─ object.n.01
#                     └─ physical_entity.n.01
#                       └─ entity.n.01
#
# WORD: 'cor'
#   No synsets found for 'cor'
#
# WORD: 'tenueris'
#   No synsets found for 'tenueris'
#
# WORD: 'satis'
#   No synsets found for 'satis'
#
# WORD: 'doctrina'
#   No synsets found for 'doctrina'
#
# WORD: 'adipiscing'
#   No synsets found for 'adipiscing'
#
# WORD: 'praeterita'
#   No synsets found for 'praeterita'
#
# WORD: 'manere'
#   No synsets found for 'manere'
#
# WORD: 'primum'
#   No synsets found for 'primum'
#
# WORD: 'elegantiora'
#   No synsets found for 'elegantiora'
#
# WORD: 'partes'
#   Definition: go one's own way; move apart
#   Example: ['The friends separated after the party']
#
#   HYPERNYMS (more general): 1 found
#     → move.v.03
#       Definition: move so as to change position, perform a nontranslational motion
#
#   HYPONYMS (more specific): 3 found
#     → disperse.v.04
#       Definition: move away from each other
#     → break_up.v.03
#       Definition: come apart
#     → diffract.v.01
#       Definition: undergo diffraction
#
#   HIERARCHY PATH (up to root):
#     └─ separate.v.09
#       └─ move.v.03
#
# WORD: 'secundae'
#   No synsets found for 'secundae'
#
# WORD: 'dubium'
#   No synsets found for 'dubium'
#
# WORD: 'scriptis'
#   No synsets found for 'scriptis'
#
# WORD: 'instructum'
#   No synsets found for 'instructum'
#
# WORD: 'summum'
#   No synsets found for 'summum'
#
# WORD: 'congressu'
#   No synsets found for 'congressu'
#
# WORD: 'iudicium'
#   No synsets found for 'iudicium'
#
# WORD: 'huc'
#   No synsets found for 'huc'
#
# WORD: 'optineat'
#   No synsets found for 'optineat'
#
# WORD: 'oratio'
#   No synsets found for 'oratio'
#
# WORD: 'erunt'
#   No synsets found for 'erunt'
#
# WORD: 'quid'
#   Definition: the basic unit of money in Great Britain and Northern Ireland; equal to 100 pence
#   Example: No example
#
#   HYPERNYMS (more general): 1 found
#     → british_monetary_unit.n.01
#       Definition: monetary unit in Great Britain
#         ↑ monetary_unit.n.01: a unit of money
#
#   HYPONYMS: None found
#
#   HIERARCHY PATH (up to root):
#     └─ british_pound.n.01
#       └─ british_monetary_unit.n.01
#         └─ monetary_unit.n.01
#           └─ unit_of_measurement.n.01
#             └─ definite_quantity.n.01
#               └─ measure.n.02
#                 └─ abstraction.n.06
#                   └─ entity.n.01
#
# WORD: 'diceret'
#   No synsets found for 'diceret'
#
# WORD: 'orationem'
#   No synsets found for 'orationem'
#
# WORD: 'grandioribus'
#   No synsets found for 'grandioribus'
#
# WORD: 'nam'
#   No synsets found for 'nam'
#
# WORD: 'quae'
#   No synsets found for 'quae'
#
# WORD: 'nec'
#   Definition: an acute inflammatory disease occurring in the intestines of premature infants; necrosis of intestinal tissue may follow
#   Example: No example
#
#   HYPERNYMS (more general): 1 found
#     → inflammatory_disease.n.01
#       Definition: a disease characterized by inflammation
#         ↑ disease.n.01: an impairment of health or a condition of abnormal functioning
#
#   HYPONYMS: None found
#
#   HIERARCHY PATH (up to root):
#     └─ necrotizing_enterocolitis.n.01
#       └─ inflammatory_disease.n.01
#         └─ disease.n.01
#           └─ illness.n.01
#             └─ ill_health.n.01
#               └─ pathological_state.n.01
#                 └─ physical_condition.n.01
#                   └─ condition.n.01
#                     └─ state.n.02
#                       └─ attribute.n.02
#                         └─ abstraction.n.06
#                           └─ entity.n.01
#
# WORD: 'principia'
#   No synsets found for 'principia'
#
# WORD: 'torrens'
#   No synsets found for 'torrens'
#
# WORD: 'naturam'
#   No synsets found for 'naturam'
#
# WORD: 'philosophis'
#   No synsets found for 'philosophis'
#
# WORD: 'illa'
#   No synsets found for 'illa'
#
# WORD: 'animantibus'
#   No synsets found for 'animantibus'
#
# WORD: 'sunt'
#   No synsets found for 'sunt'
#
# WORD: 'antiochum'
#   No synsets found for 'antiochum'
#
# WORD: 'homini'
#   No synsets found for 'homini'
#
# WORD: 'ac'
#   Definition: a radioactive element of the actinide series; found in uranium ores
#   Example: No example
#
#   HYPERNYMS (more general): 1 found
#     → chemical_element.n.01
#       Definition: any of the more than 100 known substances (of which 92 occur naturally) that cannot be separated into simpler substances and that singly or in combination constitute all matter
#         ↑ substance.n.01: the real physical matter of which a person or thing consists
#
#   HYPONYMS: None found
#
#   HIERARCHY PATH (up to root):
#     └─ actinium.n.01
#       └─ chemical_element.n.01
#         └─ substance.n.01
#           └─ part.n.01
#             └─ relation.n.01
#               └─ abstraction.n.06
#                 └─ entity.n.01
#           └─ matter.n.03
#             └─ physical_entity.n.01
#               └─ entity.n.01
#
# WORD: 'habere'
#   No synsets found for 'habere'
#
# WORD: 'ipsa'
#   No synsets found for 'ipsa'
#
# WORD: 'virtutis'
#   No synsets found for 'virtutis'
#
# WORD: 'iam'
#   No synsets found for 'iam'
#
# WORD: 'bonum'
#   No synsets found for 'bonum'
#
# WORD: 'quasi'
#   Definition: having some resemblance
#   Example: ['a quasi success', 'a quasi contract']
#
#   HYPERNYMS: None found
#
#   HYPONYMS: None found
#
#   HIERARCHY PATH (up to root):
#     └─ quasi.s.01
#
# WORD: 'rebus'
#   Definition: a puzzle where you decode a message consisting of pictures representing syllables and words
#   Example: No example
#
#   HYPERNYMS (more general): 1 found
#     → problem.n.02
#       Definition: a question raised for consideration or solution
#         ↑ question.n.02: the subject matter at issue
#
#   HYPONYMS: None found
#
#   HIERARCHY PATH (up to root):
#     └─ rebus.n.01
#       └─ problem.n.02
#         └─ question.n.02
#           └─ subject.n.01
#             └─ message.n.02
#               └─ communication.n.02
#                 └─ abstraction.n.06
#                   └─ entity.n.01
#
# WORD: 'oculis'
#   No synsets found for 'oculis'
#
# WORD: 'se'
#   Definition: a toxic nonmetallic element related to sulfur and tellurium; occurs in several allotropic forms; a stable grey metallike allotrope conducts electricity better in the light than in the dark and is used in photocells; occurs in sulfide ores (as pyrite)
#   Example: No example
#
#   HYPERNYMS (more general): 2 found
#     → antioxidant.n.01
#       Definition: substance that inhibits oxidation or inhibits reactions promoted by oxygen or peroxides
#         ↑ inhibitor.n.01: a substance that retards or stops an activity
#     → chemical_element.n.01
#       Definition: any of the more than 100 known substances (of which 92 occur naturally) that cannot be separated into simpler substances and that singly or in combination constitute all matter
#         ↑ substance.n.01: the real physical matter of which a person or thing consists
#
#   HYPONYMS: None found
#
#   HIERARCHY PATH (up to root):
#     └─ selenium.n.01
#       └─ antioxidant.n.01
#         └─ inhibitor.n.01
#           └─ substance.n.07
#             └─ matter.n.03
#               └─ physical_entity.n.01
#                 └─ entity.n.01
#       └─ chemical_element.n.01
#         └─ substance.n.01
#           └─ part.n.01
#             └─ relation.n.01
#               └─ abstraction.n.06
#                 └─ entity.n.01
#           └─ matter.n.03
#             └─ physical_entity.n.01
#               └─ entity.n.01
#
# WORD: 'bona'
#   No synsets found for 'bona'
#
# WORD: 'fratri'
#   No synsets found for 'fratri'
#
# WORD: 'etiam'
#   No synsets found for 'etiam'
#
# WORD: 'postulat'
#   No synsets found for 'postulat'
#
# WORD: 'optime'
#   No synsets found for 'optime'
#
# WORD: 'vidit'
#   No synsets found for 'vidit'
#
# WORD: 'revertendum'
#   No synsets found for 'revertendum'
#
# WORD: 'apta'
#   No synsets found for 'apta'
#
# WORD: 'licebitnstulti'
#   No synsets found for 'licebitnstulti'
#
# WORD: 'haec'
#   No synsets found for 'haec'
#
# WORD: 'oppidum'
#   No synsets found for 'oppidum'
#
# WORD: 'gerendae'
#   No synsets found for 'gerendae'
#
# WORD: 'protulisti'
#   No synsets found for 'protulisti'
#
# WORD: 'appetitum'
#   No synsets found for 'appetitum'
#
# WORD: 'institutis'
#   No synsets found for 'institutis'
#
# WORD: 'condemnatus'
#   No synsets found for 'condemnatus'
#
# WORD: 'aristonem'
#   No synsets found for 'aristonem'
#
# WORD: 'deinde'
#   No synsets found for 'deinde'
#
# WORD: 'ipsius'
#   No synsets found for 'ipsius'
#
# WORD: 'peti'
#   No synsets found for 'peti'
#
# WORD: 'nomina'
#   No synsets found for 'nomina'
#
# WORD: 'torquentur'
#   No synsets found for 'torquentur'
#
# WORD: 'enim'
#   No synsets found for 'enim'
#
# WORD: 'delectantnesse'
#   No synsets found for 'delectantnesse'
#
# WORD: 'nescionnex'
#   No synsets found for 'nescionnex'
#
# WORD: 'illum'
#   No synsets found for 'illum'
#
# WORD: 'obruatnnquis'
#   No synsets found for 'obruatnnquis'
#
# WORD: 'alienum'
#   No synsets found for 'alienum'
#
# WORD: 'prima'
#   Definition: used primarily as eating apples
#   Example: No example
#
#   HYPERNYMS (more general): 1 found
#     → eating_apple.n.01
#       Definition: an apple used primarily for eating raw without cooking
#         ↑ apple.n.01: fruit with red or yellow or green skin and sweet to tart crisp whitish flesh
#
#   HYPONYMS: None found
#
#   HIERARCHY PATH (up to root):
#     └─ prima.n.01
#       └─ eating_apple.n.01
#         └─ apple.n.01
#           └─ pome.n.01
#             └─ fruit.n.01
#               └─ reproductive_structure.n.01
#                 └─ plant_organ.n.01
#                   └─ plant_part.n.01
#                     └─ natural_object.n.01
#                       └─ whole.n.02
#                         └─ object.n.01
#                           └─ physical_entity.n.01
#                             └─ entity.n.01
#           └─ edible_fruit.n.01
#             └─ fruit.n.01
#               └─ reproductive_structure.n.01
#                 └─ plant_organ.n.01
#                   └─ plant_part.n.01
#                     └─ natural_object.n.01
#                       └─ whole.n.02
#                         └─ object.n.01
#                           └─ physical_entity.n.01
#                             └─ entity.n.01
#             └─ produce.n.01
#               └─ food.n.02
#                 └─ solid.n.01
#                   └─ matter.n.03
#                     └─ physical_entity.n.01
#                       └─ entity.n.01
#
# WORD: 'danda'
#   No synsets found for 'danda'
#
# WORD: 'summa'
#   No synsets found for 'summa'
#
# WORD: 'partem'
#   No synsets found for 'partem'
#
# WORD: 'datum'
#   Definition: an item of factual information derived from measurement or research
#   Example: No example
#
#   HYPERNYMS (more general): 1 found
#     → information.n.02
#       Definition: knowledge acquired through study or experience or instruction
#         ↑ cognition.n.01: the psychological result of perception and learning and reasoning
#
#   HYPONYMS (more specific): 2 found
#     → statistic.n.01
#       Definition: a datum that can be represented numerically
#     → reading.n.03
#       Definition: a datum about some physical state that is presented to a user by a meter or similar instrument
#
#   HIERARCHY PATH (up to root):
#     └─ datum.n.01
#       └─ information.n.02
#         └─ cognition.n.01
#           └─ psychological_feature.n.01
#             └─ abstraction.n.06
#               └─ entity.n.01
#
# WORD: 'dicet'
#   No synsets found for 'dicet'
#
# WORD: 'neglegi'
#   No synsets found for 'neglegi'
#
# WORD: 'qua'
#   No synsets found for 'qua'
#
# WORD: 'meum'
#   No synsets found for 'meum'
#
# WORD: 'triari'
#   No synsets found for 'triari'
#
# WORD: 'dixti'
#   No synsets found for 'dixti'
#
# WORD: 'corpus'
#   Definition: capital as contrasted with the income derived from it
#   Example: No example
#
#   HYPERNYMS (more general): 1 found
#     → capital.n.02
#       Definition: wealth in the form of money or property owned by a person or business and human resources of economic value
#         ↑ assets.n.01: anything of material value or usefulness that is owned by a person or company
#
#   HYPONYMS: None found
#
#   HIERARCHY PATH (up to root):
#     └─ principal.n.04
#       └─ capital.n.02
#         └─ assets.n.01
#           └─ possession.n.02
#             └─ relation.n.01
#               └─ abstraction.n.06
#                 └─ entity.n.01
#
# WORD: 'cn'
#   No synsets found for 'cn'
#
# WORD: 'nunc'
#   No synsets found for 'nunc'
#
# WORD: 'omnem'
#   No synsets found for 'omnem'
#
# WORD: 'ipso'
#   No synsets found for 'ipso'
#
# WORD: 'cogit'
#   No synsets found for 'cogit'
#
# WORD: 'duo'
#   Definition: two items of the same kind
#   Example: No example
#
#   HYPERNYMS (more general): 1 found
#     → two.n.01
#       Definition: the cardinal number that is the sum of one and one or a numeral representing this number
#         ↑ digit.n.01: one of the elements that collectively form a system of numeration
#
#   HYPONYMS (more specific): 1 found
#     → doubleton.n.01
#       Definition: (bridge) a pair of playing cards that are the only cards in their suit in the hand dealt to a player
#
#   HIERARCHY PATH (up to root):
#     └─ couple.n.04
#       └─ two.n.01
#         └─ digit.n.01
#           └─ integer.n.01
#             └─ number.n.02
#               └─ definite_quantity.n.01
#                 └─ measure.n.02
#                   └─ abstraction.n.06
#                     └─ entity.n.01
#
# WORD: 'mene'
#   No synsets found for 'mene'
#
# WORD: 'palatum'
#   No synsets found for 'palatum'
#
# WORD: 'inquit'
#   No synsets found for 'inquit'
#
# WORD: 'ista'
#   No synsets found for 'ista'
#
# WORD: 'velle'
#   No synsets found for 'velle'
#
# WORD: 'tubulum'
#   No synsets found for 'tubulum'
#
# WORD: 'beatos'
#   No synsets found for 'beatos'
#
# WORD: 'mala'
#   No synsets found for 'mala'
#
# WORD: 'ita'
#   No synsets found for 'ita'
#
# WORD: 'ut'
#   Definition: the local time at the 0 meridian passing through Greenwich, England; it is the same everywhere
#   Example: No example
#
#   HYPERNYMS (more general): 1 found
#     → time.n.05
#       Definition: the continuum of experience in which events pass from the future through the present to the past
#         ↑ attribute.n.02: an abstraction belonging to or characteristic of an entity
#
#   HYPONYMS (more specific): 1 found
#     → coordinated_universal_time.n.01
#       Definition: Greenwich Mean Time updated with leap seconds
#
#   HIERARCHY PATH (up to root):
#     └─ greenwich_mean_time.n.01
#       └─ time.n.05
#         └─ attribute.n.02
#           └─ abstraction.n.06
#             └─ entity.n.01
#
# WORD: 'quod'
#   No synsets found for 'quod'
#
# WORD: 'per'
#   No synsets found for 'per'
#
# WORD: 'autem'
#   No synsets found for 'autem'
#
# WORD: 'sapientes'
#   No synsets found for 'sapientes'
#
# WORD: 'rogatione'
#   No synsets found for 'rogatione'
#
# WORD: 'voluptatesnnidemne'
#   No synsets found for 'voluptatesnnidemne'
#
# WORD: 'interrete'
#   No synsets found for 'interrete'
#
# WORD: 'lucius'
#   No synsets found for 'lucius'
#
# WORD: 'sed'
#   No synsets found for 'sed'
#
# WORD: 'igitur'
#   No synsets found for 'igitur'
#
# WORD: 'inquam'
#   No synsets found for 'inquam'
#
# WORD: 'philosophiae'
#   No synsets found for 'philosophiae'
#
# WORD: 'vide'
#   No synsets found for 'vide'
#
# WORD: 'tum'
#   Definition: an enlarged and muscular saclike organ of the alimentary canal; the principal organ of digestion
#   Example: No example
#
#   HYPERNYMS (more general): 1 found
#     → internal_organ.n.01
#       Definition: a main organ that is situated inside the body
#         ↑ organ.n.01: a fully differentiated structural and functional unit in an animal that is specialized for some particular function
#
#   HYPONYMS (more specific): 5 found
#     → rumen.n.01
#       Definition: the first compartment of the stomach of a ruminant; here food is collected and returned to the mouth as cud for chewing
#     → reticulum.n.03
#       Definition: the second compartment of the stomach of a ruminant
#     → craw.n.01
#       Definition: a pouch in many birds and some lower animals that resembles a stomach for storage and preliminary maceration of food
#     → abomasum.n.01
#       Definition: the fourth compartment of the stomach of a ruminant; the one where digestion takes place
#     → psalterium.n.01
#       Definition: the third compartment of the stomach of a ruminant
#
#   HIERARCHY PATH (up to root):
#     └─ stomach.n.01
#       └─ internal_organ.n.01
#         └─ organ.n.01
#           └─ body_part.n.01
#             └─ part.n.03
#               └─ thing.n.12
#                 └─ physical_entity.n.01
#                   └─ entity.n.01
#
# WORD: 'semper'
#   No synsets found for 'semper'
#
# WORD: 'quamvis'
#   No synsets found for 'quamvis'
#
# WORD: 'latine'
#   No synsets found for 'latine'
#
# WORD: 'dicam'
#   No synsets found for 'dicam'
#
# WORD: 'dicis'
#   No synsets found for 'dicis'
#
# WORD: 'plures'
#   No synsets found for 'plures'
#
# WORD: 'tibi'
#   No synsets found for 'tibi'
#
# WORD: 'fatebuntur'
#   No synsets found for 'fatebuntur'
#
# WORD: 'vera'
#   No synsets found for 'vera'
#
# WORD: 'multa'
#   No synsets found for 'multa'
#
# WORD: 'nova'
#   Definition: a star that ejects some of its material in the form of a cloud and become more luminous in the process
#   Example: No example
#
#   HYPERNYMS (more general): 1 found
#     → star.n.01
#       Definition: (astronomy) a celestial body of hot gases that radiates energy derived from thermonuclear reactions in the interior
#         ↑ celestial_body.n.01: natural objects visible in the sky
#
#   HYPONYMS: None found
#
#   HIERARCHY PATH (up to root):
#     └─ nova.n.01
#       └─ star.n.01
#         └─ celestial_body.n.01
#           └─ natural_object.n.01
#             └─ whole.n.02
#               └─ object.n.01
#                 └─ physical_entity.n.01
#                   └─ entity.n.01
#
# WORD: 'dicitur'
#   No synsets found for 'dicitur'
#
# WORD: 'eo'
#   No synsets found for 'eo'
#
# WORD: 'probitate'
#   No synsets found for 'probitate'
#
# WORD: 'illud'
#   No synsets found for 'illud'
#
# WORD: 'et'
#   No synsets found for 'et'
#
# WORD: 'rapiuntnhoc'
#   No synsets found for 'rapiuntnhoc'
#
# WORD: 'falsone'
#   No synsets found for 'falsone'
#
# WORD: 'constructio'
#   No synsets found for 'constructio'
#
# WORD: 'scripta'
#   No synsets found for 'scripta'
#
# WORD: 'cuiusque'
#   No synsets found for 'cuiusque'
#
# WORD: 'modo'
#   No synsets found for 'modo'
#
# WORD: 'res'
#   Definition: a widely distributed system consisting of all the cells able to ingest bacteria or colloidal particles etc, except for certain white blood cells
#   Example: No example
#
#   HYPERNYMS (more general): 1 found
#     → system.n.06
#       Definition: a group of physiologically or anatomically related organs or parts
#         ↑ body_part.n.01: any part of an organism such as an organ or extremity
#
#   HYPONYMS: None found
#
#   HIERARCHY PATH (up to root):
#     └─ reticuloendothelial_system.n.01
#       └─ system.n.06
#         └─ body_part.n.01
#           └─ part.n.03
#             └─ thing.n.12
#               └─ physical_entity.n.01
#                 └─ entity.n.01
#
# WORD: 'perspicuum'
#   No synsets found for 'perspicuum'
#
# WORD: 'solebam'
#   No synsets found for 'solebam'
#
# WORD: 'virtus'
#   Definition: love of or taste for fine objects of art
#   Example: No example
#
#   HYPERNYMS (more general): 1 found
#     → taste.n.03
#       Definition: delicate discrimination (especially of aesthetic values)
#         ↑ discrimination.n.02: the cognitive process whereby two or more stimuli are distinguished
#
#   HYPONYMS: None found
#
#   HIERARCHY PATH (up to root):
#     └─ virtu.n.01
#       └─ taste.n.03
#         └─ discrimination.n.02
#           └─ basic_cognitive_process.n.01
#             └─ process.n.02
#               └─ cognition.n.01
#                 └─ psychological_feature.n.01
#                   └─ abstraction.n.06
#                     └─ entity.n.01
#
# WORD: 'incidere'
#   No synsets found for 'incidere'
#
# WORD: 'moveatur'
#   No synsets found for 'moveatur'
#
# WORD: 'fuisse'
#   No synsets found for 'fuisse'
#
# WORD: 'equidem'
#   No synsets found for 'equidem'
#
# WORD: 'praeclare'
#   No synsets found for 'praeclare'
#
# WORD: 'istum'
#   No synsets found for 'istum'
#
# WORD: 'vincunt'
#   No synsets found for 'vincunt'
#
# WORD: 'quoniam'
#   No synsets found for 'quoniam'
#
# WORD: 'quos'
#   No synsets found for 'quos'
#
# WORD: 'fertur'
#   No synsets found for 'fertur'
#
# WORD: 'ea'
#   Definition: the Babylonian god of wisdom; son of Apsu and father of Marduk; counterpart of the Sumerian Enki; as one of the supreme triad including Anu and Bel he was assigned control of the watery element
#   Example: No example
#
#   HYPERNYMS: None found
#
#   HYPONYMS: None found
#
#   HIERARCHY PATH (up to root):
#     └─ ea.n.01
#
# WORD: 'solum'
#   No synsets found for 'solum'
#
# WORD: 'gravitasque'
#   No synsets found for 'gravitasque'
#
# WORD: 'omnia'
#   No synsets found for 'omnia'
#
# WORD: 'nullo'
#   No synsets found for 'nullo'
#
# WORD: 'verum'
#   No synsets found for 'verum'
#
# WORD: 'iucundenhaec'
#   No synsets found for 'iucundenhaec'
#
# WORD: 'grata'
#   No synsets found for 'grata'
#
# WORD: 'ego'
#   Definition: an inflated feeling of pride in your superiority to others
#   Example: No example
#
#   HYPERNYMS (more general): 1 found
#     → pride.n.01
#       Definition: a feeling of self-respect and personal worth
#         ↑ feeling.n.01: the experiencing of affective and emotional states
#
#   HYPONYMS: None found
#
#   HIERARCHY PATH (up to root):
#     └─ ego.n.01
#       └─ pride.n.01
#         └─ feeling.n.01
#           └─ state.n.02
#             └─ attribute.n.02
#               └─ abstraction.n.06
#                 └─ entity.n.01
#
# WORD: 'audivi'
#   No synsets found for 'audivi'
#
# WORD: 'molliorque'
#   No synsets found for 'molliorque'
#
# WORD: 'pro'
#   Definition: an athlete who plays for pay
#   Example: No example
#
#   HYPERNYMS (more general): 1 found
#     → athlete.n.01
#       Definition: a person trained to compete in sports
#         ↑ contestant.n.01: a person who participates in competitions
#
#   HYPONYMS (more specific): 2 found
#     → semiprofessional.n.01
#       Definition: an athlete who plays for pay on a part-time basis
#     → free_agent.n.01
#       Definition: (sports) a professional athlete who is free to sign a contract to play for any team
#
#   HIERARCHY PATH (up to root):
#     └─ professional.n.02
#       └─ athlete.n.01
#         └─ contestant.n.01
#           └─ person.n.01
#             └─ causal_agent.n.01
#               └─ physical_entity.n.01
#                 └─ entity.n.01
#             └─ organism.n.01
#               └─ living_thing.n.01
#                 └─ whole.n.02
#                   └─ object.n.01
#                     └─ physical_entity.n.01
#                       └─ entity.n.01
#
# WORD: 'hoc'
#   No synsets found for 'hoc'
#
# WORD: 'e'
#   Definition: a fat-soluble vitamin that is essential for normal reproduction; an important antioxidant that neutralizes free radicals in the body
#   Example: No example
#
#   HYPERNYMS (more general): 2 found
#     → fat-soluble_vitamin.n.01
#       Definition: any vitamin that is soluble in fats
#         ↑ vitamin.n.01: any of a group of organic substances essential in small quantities to normal metabolism
#     → antioxidant.n.01
#       Definition: substance that inhibits oxidation or inhibits reactions promoted by oxygen or peroxides
#         ↑ inhibitor.n.01: a substance that retards or stops an activity
#
#   HYPONYMS (more specific): 1 found
#     → alpha-tocopheral.n.01
#       Definition: a potent form of vitamin E obtained from germ oils or by synthesis
#
#   HIERARCHY PATH (up to root):
#     └─ vitamin_e.n.01
#       └─ fat-soluble_vitamin.n.01
#         └─ vitamin.n.01
#           └─ nutriment.n.01
#             └─ food.n.01
#               └─ substance.n.07
#                 └─ matter.n.03
#                   └─ physical_entity.n.01
#                     └─ entity.n.01
#       └─ antioxidant.n.01
#         └─ inhibitor.n.01
#           └─ substance.n.07
#             └─ matter.n.03
#               └─ physical_entity.n.01
#                 └─ entity.n.01
#
# WORD: 'esse'
#   No synsets found for 'esse'
#
# WORD: 'ipsae'
#   No synsets found for 'ipsae'
#
# WORD: 'beato'
#   No synsets found for 'beato'
#
# WORD: 'item'
#   Definition: a distinct part that can be specified separately in a group of things that could be enumerated on a list
#   Example: ['he noticed an item in the New York Times', 'she had several items on her shopping list', 'the main point on the agenda was taken up first']
#
#   HYPERNYMS (more general): 1 found
#     → part.n.01
#       Definition: something determined in relation to something that includes it
#         ↑ relation.n.01: an abstraction belonging to or characteristic of two entities or parts together
#
#   HYPONYMS (more specific): 6 found
#     → news_item.n.01
#       Definition: an item in a newspaper
#     → place.n.15
#       Definition: an item on a list or in a sequence
#     → incidental.n.02
#       Definition: an item that is incidental
#     → line_item.n.01
#       Definition: an item in an appropriation bill
#     → inventory_item.n.01
#       Definition: an item listed in an inventory
#     → agenda_item.n.01
#       Definition: one of the items to be considered
#
#   HIERARCHY PATH (up to root):
#     └─ item.n.01
#       └─ part.n.01
#         └─ relation.n.01
#           └─ abstraction.n.06
#             └─ entity.n.01
#
# WORD: 'desciscendi'
#   No synsets found for 'desciscendi'
#
# WORD: 'inpunenquae'
#   No synsets found for 'inpunenquae'
#
# WORD: 'quanta'
#   Definition: a discrete amount of something that is analogous to the quantities in quantum theory
#   Example: No example
#
#   HYPERNYMS (more general): 1 found
#     → quantity.n.03
#       Definition: the concept that something has a magnitude and can be represented in mathematical expressions by a constant or a variable
#         ↑ concept.n.01: an abstract or general idea inferred or derived from specific instances
#
#   HYPONYMS: None found
#
#   HIERARCHY PATH (up to root):
#     └─ quantum.n.01
#       └─ quantity.n.03
#         └─ concept.n.01
#           └─ idea.n.01
#             └─ content.n.05
#               └─ cognition.n.01
#                 └─ psychological_feature.n.01
#                   └─ abstraction.n.06
#                     └─ entity.n.01
#
# WORD: 'eorum'
#   No synsets found for 'eorum'
#
# WORD: 'dixerunt'
#   No synsets found for 'dixerunt'
#
# WORD: 'plurimum'
#   No synsets found for 'plurimum'
#
# WORD: 'vivendum'
#   No synsets found for 'vivendum'
#
# WORD: 'elit'
#   No synsets found for 'elit'
#
# WORD: 'sic'
#   Definition: urge to attack someone
#   Example: ['The owner sicked his dogs on the intruders', 'the shaman sics sorcerers on the evil spirits']
#
#   HYPERNYMS (more general): 1 found
#     → assail.v.01
#       Definition: attack someone physically or emotionally
#
#   HYPONYMS: None found
#
#   HIERARCHY PATH (up to root):
#     └─ sic.v.01
#       └─ assail.v.01
#
# WORD: 'accesserit'
#   No synsets found for 'accesserit'
#
# WORD: 'omnes'
#   No synsets found for 'omnes'
#
# WORD: 'nusquam'
#   No synsets found for 'nusquam'
#
# WORD: 'aggrediar'
#   No synsets found for 'aggrediar'
#
# WORD: 'neque'
#   No synsets found for 'neque'
#
# WORD: 'hominem'
#   No synsets found for 'hominem'
#
# WORD: 'paria'
#   No synsets found for 'paria'
#
# WORD: 'beate'
#   No synsets found for 'beate'
#
# WORD: 'non'
#   Definition: negation of a word or group of words
#   Example: ['he does not speak French', 'she is not going', 'they are not friends', 'not many', 'not much', 'not at all']
#
#   HYPERNYMS: None found
#
#   HYPONYMS: None found
#
#   HIERARCHY PATH (up to root):
#     └─ not.r.01
#
# WORD: 'natura'
#   No synsets found for 'natura'
#
# WORD: 'bestiarum'
#   No synsets found for 'bestiarum'
#
# WORD: 'vestro'
#   No synsets found for 'vestro'
#
# WORD: 'oblita'
#   No synsets found for 'oblita'
#
# WORD: 'delicatior'
#   No synsets found for 'delicatior'
#
# WORD: 'cum'
#   Definition: the thick white fluid containing spermatozoa that is ejaculated by the male genital tract
#   Example: No example
#
#   HYPERNYMS (more general): 1 found
#     → liquid_body_substance.n.01
#       Definition: the liquid parts of the body
#         ↑ body_substance.n.01: the substance of the body
#
#   HYPONYMS (more specific): 1 found
#     → milt.n.02
#       Definition: seminal fluid produced by male fish
#
#   HIERARCHY PATH (up to root):
#     └─ semen.n.01
#       └─ liquid_body_substance.n.01
#         └─ body_substance.n.01
#           └─ substance.n.01
#             └─ part.n.01
#               └─ relation.n.01
#                 └─ abstraction.n.06
#                   └─ entity.n.01
#             └─ matter.n.03
#               └─ physical_entity.n.01
#                 └─ entity.n.01
#
# WORD: 'si'
#   Definition: a tetravalent nonmetallic element; next to oxygen it is the most abundant element in the earth's crust; occurs in clay and feldspar and granite and quartz and sand; used as a semiconductor in transistors
#   Example: No example
#
#   HYPERNYMS (more general): 2 found
#     → semiconductor.n.01
#       Definition: a substance as germanium or silicon whose electrical conductivity is intermediate between that of a metal and an insulator; its conductivity increases with temperature and in the presence of impurities
#         ↑ conductor.n.02: a substance that readily conducts e.g. electricity and heat
#     → chemical_element.n.01
#       Definition: any of the more than 100 known substances (of which 92 occur naturally) that cannot be separated into simpler substances and that singly or in combination constitute all matter
#         ↑ substance.n.01: the real physical matter of which a person or thing consists
#
#   HYPONYMS: None found
#
#   HIERARCHY PATH (up to root):
#     └─ silicon.n.01
#       └─ semiconductor.n.01
#         └─ conductor.n.02
#           └─ material.n.01
#             └─ substance.n.01
#               └─ part.n.01
#                 └─ relation.n.01
#                   └─ abstraction.n.06
#                     └─ entity.n.01
#               └─ matter.n.03
#                 └─ physical_entity.n.01
#                   └─ entity.n.01
#       └─ chemical_element.n.01
#         └─ substance.n.01
#           └─ part.n.01
#             └─ relation.n.01
#               └─ abstraction.n.06
#                 └─ entity.n.01
#           └─ matter.n.03
#             └─ physical_entity.n.01
#               └─ entity.n.01
#
# WORD: 'putasnnquem'
#   No synsets found for 'putasnnquem'
#
# WORD: 'hactenus'
#   No synsets found for 'hactenus'
#
# WORD: 'inponere'
#   No synsets found for 'inponere'
#
# WORD: 'vivendi'
#   No synsets found for 'vivendi'
#
# WORD: 'quam'
#   No synsets found for 'quam'
#
# WORD: 'nullum'
#   No synsets found for 'nullum'
#
# WORD: 'fingunt'
#   No synsets found for 'fingunt'
#
# WORD: 'responderit'
#   No synsets found for 'responderit'
#
# WORD: 'eam'
#   No synsets found for 'eam'
#
# WORD: 'nostrum'
#   Definition: hypothetical remedy for all ills or diseases; once sought by the alchemists
#   Example: No example
#
#   HYPERNYMS (more general): 1 found
#     → remedy.n.02
#       Definition: a medicine or therapy that cures disease or relieve pain
#         ↑ medicine.n.02: (medicine) something that treats or prevents or alleviates the symptoms of disease
#
#   HYPONYMS (more specific): 1 found
#     → elixir.n.03
#       Definition: a substance believed to cure all ills
#
#   HIERARCHY PATH (up to root):
#     └─ panacea.n.02
#       └─ remedy.n.02
#         └─ medicine.n.02
#           └─ drug.n.01
#             └─ agent.n.03
#               └─ causal_agent.n.01
#                 └─ physical_entity.n.01
#                   └─ entity.n.01
#               └─ substance.n.07
#                 └─ matter.n.03
#                   └─ physical_entity.n.01
#                     └─ entity.n.01
#
# WORD: 'referas'
#   No synsets found for 'referas'
#
# WORD: 'communia'
#   No synsets found for 'communia'
#
# WORD: 'mundum'
#   No synsets found for 'mundum'
#
# WORD: 'tuum'
#   No synsets found for 'tuum'
#
# WORD: 'fieri'
#   No synsets found for 'fieri'
#
# WORD: 'zenoni'
#   No synsets found for 'zenoni'
#
# WORD: 'vis'
#   Definition: the cardinal number that is the sum of five and one
#   Example: No example
#
#   HYPERNYMS (more general): 1 found
#     → digit.n.01
#       Definition: one of the elements that collectively form a system of numeration
#         ↑ integer.n.01: any of the natural numbers (positive or negative) or zero
#
#   HYPONYMS: None found
#
#   HIERARCHY PATH (up to root):
#     └─ six.n.01
#       └─ digit.n.01
#         └─ integer.n.01
#           └─ number.n.02
#             └─ definite_quantity.n.01
#               └─ measure.n.02
#                 └─ abstraction.n.06
#                   └─ entity.n.01
#
# WORD: 'convincunturque'
#   No synsets found for 'convincunturque'
#
# WORD: 'bene'
#   No synsets found for 'bene'
#
# WORD: 'potest'
#   No synsets found for 'potest'
#
# WORD: 'plane'
#   Definition: an aircraft that has a fixed wing and is powered by propellers or jets
#   Example: ['the flight was delayed due to trouble with the airplane']
#
#   HYPERNYMS (more general): 1 found
#     → heavier-than-air_craft.n.01
#       Definition: a non-buoyant aircraft that requires a source of power to hold it aloft and to propel it
#         ↑ aircraft.n.01: a vehicle that can fly
#
#   HYPONYMS (more specific): 15 found
#     → hangar_queen.n.01
#       Definition: an airplane with a bad maintenance record
#     → monoplane.n.01
#       Definition: an airplane with a single wing
#     → propeller_plane.n.01
#       Definition: an airplane that is driven by a propeller
#     → seaplane.n.01
#       Definition: an airplane that can land on or take off from water
#     → tanker_plane.n.01
#       Definition: an airplane constructed to transport chemicals that can be dropped in order to fight a forest fire
#     → delta_wing.n.01
#       Definition: an airplane with wings that give it the appearance of an isosceles triangle
#     → bomber.n.01
#       Definition: a military aircraft that drops bombs during flight
#     → biplane.n.01
#       Definition: old fashioned airplane; has two wings one above the other
#     → fighter.n.02
#       Definition: a high-speed military or naval airplane designed to destroy enemy aircraft in the air
#     → jet.n.01
#       Definition: an airplane powered by one or more jet engines
#     → multiengine_airplane.n.01
#       Definition: a plane with two or more engines
#     → ski-plane.n.01
#       Definition: an airplane equipped with skis so it can land on a snowfield
#     → reconnaissance_plane.n.01
#       Definition: a military airplane used to gain information about an enemy
#     → amphibian.n.02
#       Definition: an airplane designed to take off and land on water
#     → airliner.n.01
#       Definition: a commercial airplane that carries passengers
#
#   HIERARCHY PATH (up to root):
#     └─ airplane.n.01
#       └─ heavier-than-air_craft.n.01
#         └─ aircraft.n.01
#           └─ craft.n.02
#             └─ vehicle.n.01
#               └─ conveyance.n.03
#                 └─ instrumentality.n.03
#                   └─ artifact.n.01
#                     └─ whole.n.02
#                       └─ object.n.01
#                         └─ physical_entity.n.01
#                           └─ entity.n.01
#
# WORD: 'quaerere'
#   No synsets found for 'quaerere'
#
# WORD: 'causam'
#   No synsets found for 'causam'
#
# WORD: 'humanis'
#   No synsets found for 'humanis'
#
# WORD: 'incendi'
#   No synsets found for 'incendi'
#
# WORD: 'abducas'
#   No synsets found for 'abducas'
#
# WORD: 'sapientem'
#   No synsets found for 'sapientem'
#
# WORD: 'praestat'
#   No synsets found for 'praestat'
#
# WORD: 'memoria'
#   No synsets found for 'memoria'
#
# WORD: 'dolorem'
#   No synsets found for 'dolorem'
#
# WORD: 'poterat'
#   No synsets found for 'poterat'
#
# WORD: 'de'
#   Definition: a Mid-Atlantic state; one of the original 13 colonies
#   Example: No example
#
#   HYPERNYMS: None found
#
#   HYPONYMS: None found
#
#   HIERARCHY PATH (up to root):
#     └─ delaware.n.04
#
# WORD: 'ab'
#   Definition: a bachelor's degree in arts and sciences
#   Example: No example
#
#   HYPERNYMS (more general): 1 found
#     → bachelor's_degree.n.01
#       Definition: an academic degree conferred on someone who has successfully completed undergraduate studies
#         ↑ academic_degree.n.01: an award conferred by a college or university signifying that the recipient has satisfactorily completed a course of study
#
#   HYPONYMS: None found
#
#   HIERARCHY PATH (up to root):
#     └─ bachelor_of_arts.n.01
#       └─ bachelor's_degree.n.01
#         └─ academic_degree.n.01
#           └─ award.n.02
#             └─ symbol.n.01
#               └─ signal.n.01
#                 └─ communication.n.02
#                   └─ abstraction.n.06
#                     └─ entity.n.01
#
# WORD: 'pacto'
#   No synsets found for 'pacto'
#
# WORD: 'est'
#   Definition: standard time in the 5th time zone west of Greenwich, reckoned at the 75th meridian; used in the eastern United States
#   Example: No example
#
#   HYPERNYMS (more general): 1 found
#     → civil_time.n.01
#       Definition: the official time in a local region (adjusted for location around the Earth); established by law or custom
#         ↑ time.n.05: the continuum of experience in which events pass from the future through the present to the past
#
#   HYPONYMS: None found
#
#   HIERARCHY PATH (up to root):
#     └─ eastern_time.n.01
#       └─ civil_time.n.01
#         └─ time.n.05
#           └─ attribute.n.02
#             └─ abstraction.n.06
#               └─ entity.n.01
#
# WORD: 'verba'
#   No synsets found for 'verba'
#
# WORD: 'quidem'
#   No synsets found for 'quidem'
#
# WORD: 'habeat'
#   No synsets found for 'habeat'
#
# WORD: 'tamen'
#   No synsets found for 'tamen'
#
# WORD: 'videtur'
#   No synsets found for 'videtur'
#
# WORD: 'absurdum'
#   No synsets found for 'absurdum'
#
# WORD: 'id'
#   Definition: a state in the Rocky Mountains
#   Example: No example
#
#   HYPERNYMS: None found
#
#   HYPONYMS: None found
#
#   HIERARCHY PATH (up to root):
#     └─ idaho.n.01
#
# WORD: 'maximam'
#   No synsets found for 'maximam'
#
# WORD: 'sequitur'
#   No synsets found for 'sequitur'
#
# WORD: 'ratio'
#   Definition: the relative magnitudes of two quantities (usually expressed as a quotient)
#   Example: No example
#
#   HYPERNYMS (more general): 1 found
#     → magnitude_relation.n.01
#       Definition: a relation between magnitudes
#         ↑ relation.n.01: an abstraction belonging to or characteristic of two entities or parts together
#
#   HYPONYMS (more specific): 37 found
#     → signal-to-noise_ratio.n.01
#       Definition: the ratio of signal intensity to noise intensity
#     → mechanical_advantage.n.01
#       Definition: the ratio of the force exerted by a machine to the force applied to it
#     → focal_ratio.n.01
#       Definition: the ratio of the focal length to the diameter of a (camera) lens system
#     → prevalence.n.02
#       Definition: (epidemiology) the ratio (for a given time period) of the number of occurrences of a disease or event to the number of units at risk in the population
#     → efficiency.n.01
#       Definition: the ratio of the output to the input of any system
#     → safety_factor.n.01
#       Definition: the ratio of the breaking stress of a structure to the estimated maximum stress in ordinary use
#     → loss_ratio.n.01
#       Definition: the ratio of the annual claims paid by an insurance company to the premiums received
#     → mileage.n.02
#       Definition: the ratio of the number of miles traveled to the number of gallons of gasoline burned
#     → proportionality.n.01
#       Definition: a ratio of two quantities that is constant
#     → abundance.n.02
#       Definition: (physics) the ratio of the number of atoms of a specific isotope of an element to the total number of isotopes present
#     → loading.n.03
#       Definition: the ratio of the gross weight of an airplane to some factor determining its lift
#     → aspect_ratio.n.01
#       Definition: the ratio of the width to the height of a tv picture
#     → quotient.n.01
#       Definition: the ratio of two quantities to be divided
#     → stoichiometry.n.01
#       Definition: (chemistry) the relation between the quantities of substances that take part in a reaction or form a compound (typically a ratio of whole integers)
#     → time_constant.n.02
#       Definition: the ratio of the inductance of a circuit in henries to its resistance in ohms
#     → margin_of_profit.n.01
#       Definition: the ratio gross profits divided by net sales
#     → employee_turnover.n.01
#       Definition: the ratio of the number of workers that had to be replaced in a given time period to the average number of workers
#     → relative_humidity.n.01
#       Definition: the ratio of the amount of water in the air at a give temperature to the maximum amount it could hold at that temperature; expressed as a percentage
#     → load_factor.n.01
#       Definition: (aeronautics) the ratio of an external load to the weight of the aircraft (measured in g)
#     → abundance.n.03
#       Definition: (chemistry) the ratio of the total mass of an element in the earth's crust to the total mass of the earth's crust; expressed as a percentage or in parts per million
#     → intelligence_quotient.n.01
#       Definition: a measure of a person's intelligence as indicated by an intelligence test; the ratio of a person's mental age to their chronological age (multiplied by 100)
#     → productivity.n.02
#       Definition: (economics) the ratio of the quantity and quality of units produced to the labor per unit of time
#     → facial_index.n.01
#       Definition: the ratio (in percent) of the maximum width to the maximum height of the face
#     → hematocrit.n.01
#       Definition: the ratio of the volume occupied by packed red blood cells to the volume of the whole blood as measured by a hematocrit
#     → cephalic_index.n.01
#       Definition: ratio (in percent) of the maximum breadth to the maximum length of a skull
#     → order_of_magnitude.n.02
#       Definition: a number assigned to the ratio of two quantities; two quantities are of the same order of magnitude if one is less than 10 times as large as the other; the number of magnitudes that the quantities differ is specified to within a power of 10
#     → mach_number.n.01
#       Definition: the ratio of the speed of a moving body to the speed of sound
#     → average.n.02
#       Definition: (sports) the ratio of successful performances to opportunities
#     → magnification.n.02
#       Definition: the ratio of the size of an image to the size of the object
#     → odds.n.02
#       Definition: the ratio by which one better's wager is greater than that of another
#     → refractive_index.n.01
#       Definition: the ratio of the velocity of light in a vacuum to that in a medium
#     → output-to-input_ratio.n.01
#       Definition: the output power of a transducer divided by the input power
#     → respiratory_quotient.n.01
#       Definition: the ratio of the volume of carbon dioxide expired to the volume of oxygen consumed by an organism or cell in a given period of time
#     → albedo.n.01
#       Definition: the ratio of reflected to incident light
#     → frequency.n.02
#       Definition: the ratio of the number of observations in a statistical category to the total number of observations
#     → eccentricity.n.02
#       Definition: (geometry) a ratio describing the shape of a conic section; the ratio of the distance between the foci to the length of the major axis
#     → price-to-earnings_ratio.n.01
#       Definition: (stock market) the price of a stock divided by its earnings
#
#   HIERARCHY PATH (up to root):
#     └─ ratio.n.01
#       └─ magnitude_relation.n.01
#         └─ relation.n.01
#           └─ abstraction.n.06
#             └─ entity.n.01
#
# WORD: 'agimus'
#   No synsets found for 'agimus'
#
# WORD: 'habes'
#   No synsets found for 'habes'
#
# WORD: 'suae'
#   No synsets found for 'suae'
#
# WORD: 'dicemusnniam'
#   No synsets found for 'dicemusnniam'
#
# WORD: 'valde'
#   No synsets found for 'valde'
#
# WORD: 'constare'
#   No synsets found for 'constare'
#
# WORD: 'video'
#   Definition: the visible part of a television transmission
#   Example: ['they could still receive the sound but the picture was gone']
#
#   HYPERNYMS (more general): 1 found
#     → visual_communication.n.01
#       Definition: communication that relies on vision
#         ↑ communication.n.02: something that is communicated by or to or between people or groups
#
#   HYPONYMS: None found
#
#   HIERARCHY PATH (up to root):
#     └─ video.n.01
#       └─ visual_communication.n.01
#         └─ communication.n.02
#           └─ abstraction.n.06
#             └─ entity.n.01
#
# WORD: 'mihi'
#   No synsets found for 'mihi'
#
# WORD: 'ciceronem'
#   No synsets found for 'ciceronem'
#
# WORD: 'coerceas'
#   No synsets found for 'coerceas'
#
# WORD: 'quidemnvoluptatem'
#   No synsets found for 'quidemnvoluptatem'
#
# WORD: 'malum'
#   No synsets found for 'malum'
#
# WORD: 'sint'
#   No synsets found for 'sint'
#
# WORD: 'puto'
#   No synsets found for 'puto'
#
# WORD: 'vides'
#   No synsets found for 'vides'
#
# WORD: 'sensus'
#   No synsets found for 'sensus'
#
# WORD: 'institutionis'
#   No synsets found for 'institutionis'
#
# WORD: 'ipsum'
#   No synsets found for 'ipsum'
#
# WORD: 'lex'
#   No synsets found for 'lex'
#
# WORD: 'videretur'
#   No synsets found for 'videretur'
#
# WORD: 'dubitabit'
#   No synsets found for 'dubitabit'
#
# WORD: 'eos'
#   Definition: (Greek mythology) the winged goddess of the dawn in ancient mythology; daughter of Hyperion; identified with Roman Aurora
#   Example: No example
#
#   HYPERNYMS: None found
#
#   HYPONYMS: None found
#
#   HIERARCHY PATH (up to root):
#     └─ eos.n.01
#
# WORD: 'animoque'
#   No synsets found for 'animoque'
#
# WORD: 'vero'
#   No synsets found for 'vero'
#
# WORD: 'quoque'
#   No synsets found for 'quoque'
#
# WORD: 'quo'
#   No synsets found for 'quo'
#
# WORD: 'advesperascit'
#   No synsets found for 'advesperascit'
#
# WORD: 'vellet'
#   No synsets found for 'vellet'
#
# WORD: 'ipse'
#   No synsets found for 'ipse'
#
# WORD: 'atqui'
#   No synsets found for 'atqui'
#
# WORD: 'reges'
#   No synsets found for 'reges'
#
# WORD: 'p'
#   Definition: a multivalent nonmetallic element of the nitrogen family that occurs commonly in inorganic phosphate rocks and as organic phosphates in all living cells; is highly reactive and occurs in several allotropic forms
#   Example: No example
#
#   HYPERNYMS (more general): 1 found
#     → chemical_element.n.01
#       Definition: any of the more than 100 known substances (of which 92 occur naturally) that cannot be separated into simpler substances and that singly or in combination constitute all matter
#         ↑ substance.n.01: the real physical matter of which a person or thing consists
#
#   HYPONYMS: None found
#
#   HIERARCHY PATH (up to root):
#     └─ phosphorus.n.01
#       └─ chemical_element.n.01
#         └─ substance.n.01
#           └─ part.n.01
#             └─ relation.n.01
#               └─ abstraction.n.06
#                 └─ entity.n.01
#           └─ matter.n.03
#             └─ physical_entity.n.01
#               └─ entity.n.01
#
# WORD: 'cur'
#   Definition: an inferior dog or one of mixed breed
#   Example: No example
#
#   HYPERNYMS (more general): 1 found
#     → dog.n.01
# ...
#               └─ entity.n.01
#
# WORD: 'primae'
#   No synsets found for 'primae'
#
# WORD: 'maximum'
#   Definition: the largest possible quantity
#   Example: No example
#
#   HYPERNYMS (more general): 2 found
#     → extremum.n.02
#       Definition: the most extreme possible amount or value
#         ↑ limit.n.06: the greatest amount of something that is possible or allowed
#     → large_indefinite_quantity.n.01
#       Definition: an indefinite quantity that is above the average in size or magnitude
#         ↑ indefinite_quantity.n.01: an estimated quantity
#
#   HYPONYMS: None found
#
#   HIERARCHY PATH (up to root):
#     └─ maximum.n.01
#       └─ extremum.n.02
#         └─ limit.n.06
#           └─ indefinite_quantity.n.01
#             └─ measure.n.02
#               └─ abstraction.n.06
#                 └─ entity.n.01
#       └─ large_indefinite_quantity.n.01
#         └─ indefinite_quantity.n.01
#           └─ measure.n.02
#             └─ abstraction.n.06
#               └─ entity.n.01
#
# WORD: 'vitem'
#   No synsets found for 'vitem'
#
# WORD: 'dies'
#   Definition: a small cube with 1 to 6 spots on the six faces; used in gambling to generate random numbers
#   Example: No example
#
#   HYPERNYMS (more general): 1 found
#     → cube.n.05
#       Definition: a block in the (approximate) shape of a cube
#         ↑ block.n.01: a solid piece of something (usually having flat rectangular sides)
#
#   HYPONYMS (more specific): 4 found
#     → one-spot.n.01
#       Definition: a domino or die whose upward face shows one pip
#     → four-spot.n.01
#       Definition: a playing card or domino or die whose upward face shows four pips
#     → five-spot.n.03
#       Definition: a playing card or a domino or a die whose upward face shows five pips
#     → six-spot.n.01
#       Definition: a playing card or domino or die whose upward face shows six pips
#
#   HIERARCHY PATH (up to root):
#     └─ die.n.01
#       └─ cube.n.05
#         └─ block.n.01
#           └─ artifact.n.01
#             └─ whole.n.02
#               └─ object.n.01
#                 └─ physical_entity.n.01
#                   └─ entity.n.01
#
# WORD: 'parum'
#   No synsets found for 'parum'
#
# WORD: 'probes'
#   Definition: an inquiry into unfamiliar or questionable activities
#   Example: ['there was a congressional probe into the scandal']
#
#   HYPERNYMS (more general): 1 found
#     → inquiry.n.01
#       Definition: a search for knowledge
#         ↑ problem_solving.n.02: the thought processes involved in solving a problem
#
#   HYPONYMS (more specific): 1 found
#     → fishing_expedition.n.01
#       Definition: an investigation undertaken in the hope (but not the stated purpose) of discovering information
#
#   HIERARCHY PATH (up to root):
#     └─ probe.n.01
#       └─ inquiry.n.01
#         └─ problem_solving.n.02
#           └─ thinking.n.01
#             └─ higher_cognitive_process.n.01
#               └─ process.n.02
#                 └─ cognition.n.01
#                   └─ psychological_feature.n.01
#                     └─ abstraction.n.06
#                       └─ entity.n.01
#
# WORD: 'dicas'
#   No synsets found for 'dicas'
#
# WORD: 'adhuc'
#   No synsets found for 'adhuc'
#
# WORD: 'privasse'
#   No synsets found for 'privasse'
#
# WORD: 'probata'
#   No synsets found for 'probata'
#
# WORD: 'occurrentia'
#   No synsets found for 'occurrentia'
#
# WORD: 'dissentias'
#   No synsets found for 'dissentias'
#
# WORD: 'villam'
#   No synsets found for 'villam'
#
# WORD: 'audissem'
#   No synsets found for 'audissem'
#
# WORD: 'sapiens'
#   Definition: of or relating to or characteristic of Homo sapiens
#   Example: No example
#
#   HYPERNYMS: None found
#
#   HYPONYMS: None found
#
#   HIERARCHY PATH (up to root):
#     └─ sapiens.a.01
#
# WORD: 'ad'
#   Definition: a public promotion of some product or service
#   Example: No example
#
#   HYPERNYMS (more general): 1 found
#     → promotion.n.01
#       Definition: a message issued in behalf of some product or cause or idea or person or institution
#         ↑ message.n.02: what a communication that is about something is about
#
#   HYPONYMS (more specific): 9 found
#     → newspaper_ad.n.01
#       Definition: a printed advertisement that is published in a newspaper
#     → mailer.n.03
#       Definition: an advertisement that is sent by mail
#     → teaser.n.03
#       Definition: an advertisement that offers something free in order to arouse customers' interest
#     → top_billing.n.01
#       Definition: the advertisement of a star's name at the top of a theatrical poster
#     → preview.n.01
#       Definition: an advertisement consisting of short scenes from a motion picture that will appear in the near future
#     → advertorial.n.01
#       Definition: an advertisement that is written and presented in the style of an editorial or journalistic report
#     → direct_mail.n.01
#       Definition: advertising sent directly to prospective customers via the mail
#     → commercial.n.01
#       Definition: a commercially sponsored ad on radio or television
#     → circular.n.01
#       Definition: an advertisement (usually printed on a page or in a leaflet) intended for wide distribution
#
#   HIERARCHY PATH (up to root):
#     └─ ad.n.01
#       └─ promotion.n.01
#         └─ message.n.02
#           └─ communication.n.02
#             └─ abstraction.n.06
#               └─ entity.n.01
#
# WORD: 'opera'
#   Definition: a drama set to music; consists of singing with orchestral accompaniment and an orchestral overture and interludes
#   Example: No example
#
#   HYPERNYMS (more general): 1 found
#     → classical_music.n.01
#       Definition: traditional genre of music conforming to an established form and appealing to critical interest and developed musical taste
#         ↑ music_genre.n.01: an expressive style of music
#
#   HYPONYMS (more specific): 3 found
#     → musical_drama.n.01
#       Definition: opera in which the musical and dramatic elements are equally important; the music is appropriate to the action
#     → comic_opera.n.01
#       Definition: opera with a happy ending and in which some of the text is spoken
#     → grand_opera.n.01
#       Definition: opera in which all the text is sung
#
#   HIERARCHY PATH (up to root):
#     └─ opera.n.01
#       └─ classical_music.n.01
#         └─ music_genre.n.01
#           └─ music.n.01
#             └─ auditory_communication.n.01
#               └─ communication.n.02
#                 └─ abstraction.n.06
#                   └─ entity.n.01
#           └─ expressive_style.n.01
#             └─ communication.n.02
#               └─ abstraction.n.06
#                 └─ entity.n.01
#
# WORD: 'rei'
#   No synsets found for 'rei'
#
# WORD: 'reliquas'
#   No synsets found for 'reliquas'
#
# WORD: 'solemus'
#   No synsets found for 'solemus'
#
# WORD: 'redarguitur'
#   No synsets found for 'redarguitur'
#
# WORD: 'moribus'
#   No synsets found for 'moribus'
#
# WORD: 'tu'
#   No synsets found for 'tu'
#
# WORD: 'aliunde'
#   No synsets found for 'aliunde'
#
# WORD: 'historianquod'
#   No synsets found for 'historianquod'
#
# WORD: 'sese'
#   No synsets found for 'sese'
#
# WORD: 'architectari'
#   No synsets found for 'architectari'
#
# WORD: 'magis'
#   Definition: (New Testament) the sages who visited Jesus and Mary and Joseph shortly after Jesus was born; the Gospel According to Matthew says they were guided by a star and brought gifts of gold and frankincense and myrrh; because there were three gifts it is usually assumed that there were three of them
#   Example: No example
#
#   HYPERNYMS: None found
#
#   HYPONYMS: None found
#
#   HIERARCHY PATH (up to root):
#     └─ wise_men.n.01
#
# WORD: 'brute'
#   Definition: a cruelly rapacious person
#   Example: No example
#
#   HYPERNYMS (more general): 1 found
#     → attacker.n.01
#       Definition: someone who attacks
#         ↑ wrongdoer.n.01: a person who transgresses moral or civil law
#
#   HYPONYMS: None found
#
#   HIERARCHY PATH (up to root):
#     └─ beast.n.02
#       └─ attacker.n.01
#         └─ wrongdoer.n.01
#           └─ bad_person.n.01
#             └─ person.n.01
#               └─ causal_agent.n.01
#                 └─ physical_entity.n.01
#                   └─ entity.n.01
#               └─ organism.n.01
#                 └─ living_thing.n.01
#                   └─ whole.n.02
#                     └─ object.n.01
#                       └─ physical_entity.n.01
#                         └─ entity.n.01
#
# WORD: 'fuerit'
#   No synsets found for 'fuerit'
#
# WORD: 'popularia'
#   No synsets found for 'popularia'
#
# WORD: 'desidero'
#   No synsets found for 'desidero'
#
# DETAILED EXAMPLE FOR KEY WORDS FROM TEXT
#
# DEEP ANALYSIS FOR: 'apple'
#   Definition: fruit with red or yellow or green skin and sweet to tart crisp whitish flesh
#   Lemmas: ['apple']
#
#   All Hypernym Paths:
#     Path 1: entity -> physical_entity -> object -> whole -> natural_object -> plant_part -> plant_organ -> reproductive_structure -> fruit -> pome -> apple
#     Path 2: entity -> physical_entity -> object -> whole -> natural_object -> plant_part -> plant_organ -> reproductive_structure -> fruit -> edible_fruit -> apple
#     Path 3: entity -> physical_entity -> matter -> solid -> food -> produce -> edible_fruit -> apple
#
#   Total hyponyms found: 3
#   All hyponyms:
#     - cooking_apple.n.01: an apple used primarily in cooking for pies and applesauce etc
#     - eating_apple.n.01: an apple used primarily for eating raw without cooking
#     - crab_apple.n.03: small sour apple; suitable for preserving
#
# DEEP ANALYSIS FOR: 'computer'
#   Definition: a machine for performing calculations automatically
#   Lemmas: ['computer', 'computing_machine', 'computing_device', 'data_processor', 'electronic_computer', 'information_processing_system']
#
#   All Hypernym Paths:
#     Path 1: entity -> physical_entity -> object -> whole -> artifact -> instrumentality -> device -> machine -> computer
#
#   Total hyponyms found: 10
#   All hyponyms:
#     - server.n.03: (computer science) a computer that provides client stations with access to files and printers as shared resources to a computer network
#     - analog_computer.n.01: a computer that represents information by variable quantities (e.g., positions or voltages)
#     - turing_machine.n.01: a hypothetical computer with an infinitely long memory tape
#     - web_site.n.01: a computer connected to the internet that maintains a series of web pages on the World Wide Web
#     - home_computer.n.01: a computer intended for use in the home
#     - pari-mutuel_machine.n.01: computer that registers bets and divides the total amount bet among those who won
#     - predictor.n.03: a computer for controlling antiaircraft fire that computes the position of an aircraft at the instant of a shell's arrival
#     - node.n.08: (computer science) any computer that is hooked up to a computer network
#     - digital_computer.n.01: a computer that represents information by numerical (binary) digits
#     - number_cruncher.n.02: a computer capable of performing a large number of mathematical operations per second
#
# DEEP ANALYSIS FOR: 'company'
#   Definition: an institution created to conduct business
#   Lemmas: ['company']
#
#   All Hypernym Paths:
#     Path 1: entity -> abstraction -> group -> social_group -> organization -> institution -> company
#
#   Total hyponyms found: 36
#   All hyponyms:
#     - transportation_company.n.01: a company providing transportation
#     - food_company.n.01: a company that processes and sells food
#     - mover.n.04: a company that moves the possessions of a family or business from one site to another
#     - open_shop.n.01: a company whose workers are hired without regard to their membership in a labor union
#     - union_shop.n.01: a company allowed to hire nonunion workers on the condition that they will join the union within a specified time
#     - pipeline_company.n.01: a company that operates oil pipelines for the oil industry
#     - mining_company.n.01: a company that owns and manages mines
#     - joint-stock_company.n.01: a company (usually unincorporated) which has the capital of its members pooled in a common fund; transferable shares represent ownership interest; shareholders are legally liable for all debts of the company
#     - printing_concern.n.01: a company that does commercial printing
#     - stock_company.n.01: a company whose capital is represented by stock
#     - white_knight.n.01: a company that is a friendly acquirer in a takeover
#     - film_company.n.01: a company that makes, advertises, and distributes movies
#     - distributor.n.03: a company that markets merchandise
#     - drug_company.n.01: a company that makes and sells pharmaceuticals
#     - shipper.n.02: a company in the business of shipping freight
#     - service.n.04: a company or agency that performs a public service; subject to government regulation
#     - limited_company.n.01: a company that is organized to give its owners limited liability
#     - record_company.n.01: a company that makes and sells musical recordings
#     - electronics_company.n.01: a company that makes and sells electronic instruments
#     - subsidiary_company.n.01: a company that is completely controlled by another company
#     - livery_company.n.01: one of the chartered companies of London originating with the craft guilds
#     - corporate_investor.n.01: a company that invests in (acquires control of) other companies
#     - car_company.n.01: a company that makes and sells automobiles
#     - packaging_company.n.01: a company that packages goods for sale or shipment or storage
#     - holding_company.n.01: a company with controlling shares in other companies
#     - target_company.n.01: a company that has been chosen as attractive for takeover by a potential acquirer
#     - oil_company.n.01: a company that sells oil
#     - east_india_company.n.01: an English company formed in 1600 to develop trade with the new British colonies in India and southeastern Asia; in the 18th century it assumed administrative control of Bengal and held it until the British army took over in 1858 after the Indian Mutiny
#     - bureau_de_change.n.01: (French) an establishment where you can exchange foreign money
#     - broadcasting_company.n.01: a company that manages tv or radio stations
#     - closed_shop.n.01: a company that hires only union members
#     - dot-com.n.01: a company that operates its business primarily on the internet using a URL that ends in `.com'
#     - think_tank.n.01: a company that does research for hire and issues reports on the implications
#     - furniture_company.n.01: a company that sells furniture
#     - steel_company.n.01: a company that makes and sells steel
#     - shipping_company.n.01: a company that provides shipping services
#
# DEEP ANALYSIS FOR: 'inventor'
#   Definition: someone who is the first to think of or make something
#   Lemmas: ['inventor', 'discoverer', 'artificer']
#
#   All Hypernym Paths:
#     Path 1: entity -> physical_entity -> causal_agent -> person -> creator -> inventor
#     Path 2: entity -> physical_entity -> object -> whole -> living_thing -> organism -> person -> creator -> inventor
#
#   Total hyponyms found: 1
#   All hyponyms:
#     - patentee.n.01: the inventor to whom a patent is issued
#
# DEEP ANALYSIS FOR: 'founder'
#   Definition: inflammation of the laminated tissue that attaches the hoof to the foot of a horse
#   Lemmas: ['laminitis', 'founder']
#
#   All Hypernym Paths:
#     Path 1: entity -> abstraction -> psychological_feature -> cognition -> information -> evidence -> symptom -> inflammation -> laminitis
#
#   Total hyponyms found: 0
#
# DEEP ANALYSIS FOR: 'ceo'
#   Definition: the corporate executive responsible for the operations of the firm; reports to a board of directors; may appoint other managers (including a president)
#   Lemmas: ['chief_executive_officer', 'CEO', 'chief_operating_officer']
#
#   All Hypernym Paths:
#     Path 1: entity -> physical_entity -> causal_agent -> person -> leader -> head -> administrator -> executive -> corporate_executive -> chief_executive_officer
#     Path 2: entity -> physical_entity -> object -> whole -> living_thing -> organism -> person -> leader -> head -> administrator -> executive -> corporate_executive -> chief_executive_officer
#
#   Total hyponyms found: 0
#
# DEEP ANALYSIS FOR: 'pixar'
#
# DEEP ANALYSIS FOR: 'next'
#   Definition: immediately following in time or order
#   Lemmas: ['following', 'next']
#
#   All Hypernym Paths:
#     Path 1: following
#
#   Total hyponyms found: 0

# %% [markdown]
# # Summary of All Operations

# %%
# Cell 15: Summary of All Operations
print("SUMMARY OF ALL OPERATIONS PERFORMED")

print(f"1. CLEANING:")
print(f"   - Original text length: {len(raw_text)} characters")
print(f"   - Cleaned text length: {len(text_cleaned)} characters")
print(f"   - Characters removed: {len(raw_text) - len(text_cleaned)}")

print(f"\n2. LOWERCASING:")
print(f"   - Original text length: {len(text_cleaned)} characters")
print(f"   - Lowercased text length: {len(text_lower)} characters")

print(f"\n3. PUNCTUATION REMOVAL:")
print(f"   - Before removal: {len(text_lower)} characters")
print(f"   - After removal: {len(text_no_punct)} characters")
print(f"   - Punctuation removed: {len(text_lower) - len(text_no_punct)}")

print(f"\n4. STOPWORD REMOVAL:")
print(f"   - Tokens before: {len(tokens)}")
print(f"   - Tokens after: {len(filtered_tokens)}")
print(f"   - Stopwords removed: {len(tokens) - len(filtered_tokens)}")

print(f"\n5. TOKENIZATION:")
print(f"   - Number of sentences: {len(sentences)}")
print(f"   - Number of words: {len(words)}")
print(f"   - Number of characters (no spaces): {len(chars)}")

print(f"\n6. STEMMING:")
print(f"   - Original tokens: {len(filtered_tokens)}")
print(f"   - Porter stemmed tokens: {len(porter_stemmed_tokens)}")
print(f"   - Snowball stemmed tokens: {len(snowball_stemmed_tokens)}")

print(f"\n7. LEMMATIZATION:")
print(f"   - Original tokens: {len(filtered_tokens)}")
print(f"   - Lemmatized tokens: {len(lemmatized_tokens)}")

print(f"\n8. POS TAGGING:")
print(f"   - Number of words tagged: {len(pos_tagged)}")

print(f"\n9. CHUNKING:")
print(f"   - Processed all sentences: {len(all_sentences)} sentences")

print(f"\n10. PARSING:")
print(f"    - Dependency parsing: Complete text processed (Full output shown)")
print(f"    - Tree parsing: All sentences processed (Full output shown)")

print(f"\n11. HYPERNYMS & HYPONYMS:")
print(f"    - Unique words analyzed: {len(unique_words)} words")
print(f"    - Key words analyzed: {len(key_words)} words")
# Out:
# SUMMARY OF ALL OPERATIONS PERFORMED
# 1. CLEANING:
#    - Original text length: 3563 characters
#    - Cleaned text length: 3514 characters
#    - Characters removed: 49
#
# 2. LOWERCASING:
#    - Original text length: 3514 characters
#    - Lowercased text length: 3514 characters
#
# 3. PUNCTUATION REMOVAL:
#    - Before removal: 3514 characters
#    - After removal: 3407 characters
#    - Punctuation removed: 107
#
# 4. STOPWORD REMOVAL:
#    - Tokens before: 8
#    - Tokens after: 509
#    - Stopwords removed: -501
#
# 5. TOKENIZATION:
#    - Number of sentences: 24
#    - Number of words: 629
#    - Number of characters (no spaces): 2984
#
# 6. STEMMING:
#    - Original tokens: 509
#    - Porter stemmed tokens: 509
#    - Snowball stemmed tokens: 509
#
# 7. LEMMATIZATION:
#    - Original tokens: 509
#    - Lemmatized tokens: 509
#
# 8. POS TAGGING:
#    - Number of words tagged: 509
#
# 9. CHUNKING:
#    - Processed all sentences: 24 sentences
#
# 10. PARSING:
#     - Dependency parsing: Complete text processed (Full output shown)
#     - Tree parsing: All sentences processed (Full output shown)
#
# 11. HYPERNYMS & HYPONYMS:
#     - Unique words analyzed: 359 words
#     - Key words analyzed: 8 words
